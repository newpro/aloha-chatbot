# %% [markdown]
# ## Overview
#
# * This file read in result of previous pipeline (pipe 0) which provides all dialog1, 2 in a single csv file.
# * This file output sentence features.

# %%
import pandas as pd
from time import time
import csv
import os

# %%
import spacy

# spacy.prefer_gpu()
nlp = spacy.load("en_core_web_lg")

# %%
# doc = nlp(u'What I need is...somebody who listens to me.')
doc = nlp(u'What are you talking about?')

for token in doc:
    print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
# Out:
# What pobj about ADP []
# are aux talking VERB []
# you nsubj talking VERB []
# talking ROOT talking VERB [are, you, about, ?]
# about prep talking VERB [What]
# ? punct talking VERB []

# %%
print('|', list(nlp('Both a bit fast, are they? Yeah no kidding.').sents)[-1], '|')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8443174a3a77> in <module>
# ----> 1 print('|', list(nlp('Both a bit fast, are they? Yeah no kidding.').sents)[-1], '|')
#
# NameError: name 'nlp' is not defined

# %%
DEPS = set(['nsubj', 'dobj', 'amod', 'advmod'])
SPEC = '-PRON-'

def _lemma(token, ent_map):
    if token.lemma_ == SPEC:
        return token.text.lower()
    l = token.lemma_
    if l in ent_map:
        return ent_map[l]
    return l

def _entities(doc):
    res = {}  # key: name, value: type of entity
    for ent in doc.ents:
        for e in ent.text.split():
            res[e] = ent.label_
    return res
#         print(ent.text, ent.start_char, ent.end_char, ent.label_)

def _get_tree(doc):
    res = []
    ents = _entities(doc)
    if len(list(doc)) < 4:
        return []
    for token in doc:
#         if token.dep_ in DEPS:
#         if token.tag_ == Noun:
        res.append(('POS', token.tag_, _lemma(token, ents), _lemma(token, ents), token.idx, token.is_stop,))
        res.append(('DEP', token.dep_, _lemma(token, ents), _lemma(token.head, ents), (token.head.idx - token.idx), token.is_stop,))
    return res

def parse(sent):
    # tuple format: (dep relation, word1, word2, relative pos)
    # break multiple sentences, question mark have priority, and later sentence have lower priority. 
    sents = list(nlp(sent).sents)
    res = []
    for s in sents[::-1]:
        if s.text.strip()[-1] == '?':
            q_res = _get_tree(s)
            if len(q_res) < 3:
                continue
            return q_res
        if not res:
            res = _get_tree(s)
        if len(res) < 3:
            res = []
    if len(res) < 3:
        return []
    return res

def parse_all(sent):
    # same as last parse function, except not break the sentence to pieces.
    res = _get_tree(nlp(sent))
    if len(res) < 3:
        return []
    return res

def test_sent_parser(sent, check_root):
    # sentence root is used to determine if the correct sentence is parsed.
    print('------')
    print('INPUT:|{}|\nROOT:|{}|'.format(sent, check_root))
    _res = parse(sent)
    print('RESULT:{}'.format(_res))
    if not check_root:  # indicate result has to be empty
        assert len(_res) == 0
        return  # end check
    for e in _res:
        if e[1] == 'ROOT':
            assert e[2] == check_root
            print()  # nice view format
            return
    if not len(_res):
        raise Exception('No return results.')
    raise Exception('Can not find root, function return result is broken: |{}|'.format(sent))

# # question sentence has priority (due to it is dialog1, so dialog 2 most likely response to question sentence).
test_sent_parser('What are you talking about? Kill Kevin if you can.', 'talk')

# question sentence has priority, however the sentence lack of structure and content
# Therefore second sentence has priority.
test_sent_parser('What? Kill Kevin if you can.', 'kill')

# Same as last one, should parse the first sentence.
test_sent_parser(u'Kill Kevin if you can. What?', 'kill')

# Both first and second sentence lacks of structure and content, empty is returned.
test_sent_parser(u'What? Kill Kevin.', check_root=None)

# Only the last sentence has structure.
test_sent_parser(u'What. Kill Kevin if you can.', check_root='kill')

# The question sentence has priority.
test_sent_parser(u'What. Kill Kevin if you can. What are you doing?', check_root='do')

# Only the first sentence has structure.
test_sent_parser(u'Kill Kevin if you can. What.', check_root='kill')

# both of the sentence has complete structure, the later sentence has priority
test_sent_parser(u'Kill Kevin if you can. What are you doing.', check_root='do')
# Out:
# ------
# INPUT:|What are you talking about? Kill Kevin if you can.|
# ROOT:|talk|
# RESULT:[('POS', 'WP', 'what', 'what', 0, True), ('DEP', 'pobj', 'what', 'about', 21, True), ('POS', 'VBP', 'be', 'be', 5, True), ('DEP', 'aux', 'be', 'talk', 8, True), ('POS', 'PRP', 'you', 'you', 9, True), ('DEP', 'nsubj', 'you', 'talk', 4, True), ('POS', 'VBG', 'talk', 'talk', 13, False), ('DEP', 'ROOT', 'talk', 'talk', 0, False), ('POS', 'IN', 'about', 'about', 21, True), ('DEP', 'prep', 'about', 'talk', -8, True), ('POS', '.', '?', '?', 26, False), ('DEP', 'punct', '?', 'talk', -13, False)]
#
# ------
# INPUT:|What? Kill Kevin if you can.|
# ROOT:|kill|
# RESULT:[('POS', 'VB', 'kill', 'kill', 6, False), ('DEP', 'ROOT', 'kill', 'kill', 0, False), ('POS', 'NNP', 'PERSON', 'PERSON', 11, False), ('DEP', 'dobj', 'PERSON', 'kill', -5, False), ('POS', 'IN', 'if', 'if', 17, True), ('DEP', 'mark', 'if', 'can', 7, True), ('POS', 'PRP', 'you', 'you', 20, True), ('DEP', 'nsubj', 'you', 'can', 4, True), ('POS', 'MD', 'can', 'can', 24, True), ('DEP', 'advcl', 'can', 'kill', -18, True), ('POS', '.', '.', '.', 27, False), ('DEP', 'punct', '.', 'kill', -21, False)]
#
# ------
# INPUT:|Kill Kevin if you can. What?|
# ROOT:|kill|
# RESULT:[('POS', 'VB', 'kill', 'kill', 0, False), ('DEP', 'ROOT', 'kill', 'kill', 0, False), ('POS', 'NNP', 'PERSON', 'PERSON', 5, False), ('DEP', 'dobj', 'PERSON', 'kill', -5, False), ('POS', 'IN', 'if', 'if', 11, True), ('DEP', 'mark', 'if', 'can', 7, True), ('POS', 'PRP', 'you', 'you', 14, True), ('DEP', 'nsubj', 'you', 'can', 4, True), ('POS', 'MD', 'can', 'can', 18, True), ('DEP', 'advcl', 'can', 'kill', -18, True), ('POS', '.', '.', '.', 21, False), ('DEP', 'punct', '.', 'kill', -21, False)]
#
# ------
# INPUT:|What? Kill Kevin.|
# ROOT:|None|
# RESULT:[]
# ------
# INPUT:|What. Kill Kevin if you can.|
# ROOT:|kill|
# RESULT:[('POS', 'VB', 'kill', 'kill', 6, False), ('DEP', 'ROOT', 'kill', 'kill', 0, False), ('POS', 'NNP', 'PERSON', 'PERSON', 11, False), ('DEP', 'dobj', 'PERSON', 'kill', -5, False), ('POS', 'IN', 'if', 'if', 17, True), ('DEP', 'mark', 'if', 'can', 7, True), ('POS', 'PRP', 'you', 'you', 20, True), ('DEP', 'nsubj', 'you', 'can', 4, True), ('POS', 'MD', 'can', 'can', 24, True), ('DEP', 'advcl', 'can', 'kill', -18, True), ('POS', '.', '.', '.', 27, False), ('DEP', 'punct', '.', 'kill', -21, False)]
#
# ------
# INPUT:|What. Kill Kevin if you can. What are you doing?|
# ROOT:|do|
# RESULT:[('POS', 'WP', 'what', 'what', 29, True), ('DEP', 'dobj', 'what', 'do', 13, True), ('POS', 'VBP', 'be', 'be', 34, True), ('DEP', 'aux', 'be', 'do', 8, True), ('POS', 'PRP', 'you', 'you', 38, True), ('DEP', 'nsubj', 'you', 'do', 4, True), ('POS', 'VBG', 'do', 'do', 42, True), ('DEP', 'ROOT', 'do', 'do', 0, True), ('POS', '.', '?', '?', 47, False), ('DEP', 'punct', '?', 'do', -5, False)]
#
# ------
# INPUT:|Kill Kevin if you can. What.|
# ROOT:|kill|
# RESULT:[('POS', 'VB', 'kill', 'kill', 0, False), ('DEP', 'ROOT', 'kill', 'kill', 0, False), ('POS', 'NNP', 'PERSON', 'PERSON', 5, False), ('DEP', 'dobj', 'PERSON', 'kill', -5, False), ('POS', 'IN', 'if', 'if', 11, True), ('DEP', 'mark', 'if', 'can', 7, True), ('POS', 'PRP', 'you', 'you', 14, True), ('DEP', 'nsubj', 'you', 'can', 4, True), ('POS', 'MD', 'can', 'can', 18, True), ('DEP', 'advcl', 'can', 'kill', -18, True), ('POS', '.', '.', '.', 21, False), ('DEP', 'punct', '.', 'kill', -21, False)]
#
# ------
# INPUT:|Kill Kevin if you can. What are you doing.|
# ROOT:|do|
# RESULT:[('POS', 'WP', 'what', 'what', 23, True), ('DEP', 'dobj', 'what', 'do', 13, True), ('POS', 'VBP', 'be', 'be', 28, True), ('DEP', 'aux', 'be', 'do', 8, True), ('POS', 'PRP', 'you', 'you', 32, True), ('DEP', 'nsubj', 'you', 'do', 4, True), ('POS', 'VBG', 'do', 'do', 36, True), ('DEP', 'ROOT', 'do', 'do', 0, True), ('POS', '.', '.', '.', 41, False), ('DEP', 'punct', '.', 'do', -5, False)]

# %%
parse_all("Surely you don't expect me to believe that?")
# Out:
# [('POS', 'RB', 'surely', 'surely', 0, False),
#  ('DEP', 'advmod', 'surely', 'expect', 17, False),
#  ('POS', 'PRP', 'you', 'you', 7, True),
#  ('DEP', 'nsubj', 'you', 'expect', 10, True),
#  ('POS', 'VBP', 'do', 'do', 11, True),
#  ('DEP', 'aux', 'do', 'expect', 6, True),
#  ('POS', 'RB', 'not', 'not', 13, True),
#  ('DEP', 'neg', 'not', 'expect', 4, True),
#  ('POS', 'VB', 'expect', 'expect', 17, False),
#  ('DEP', 'ROOT', 'expect', 'expect', 0, False),
#  ('POS', 'PRP', 'me', 'me', 24, True),
#  ('DEP', 'nsubj', 'me', 'believe', 6, True),
#  ('POS', 'TO', 'to', 'to', 27, True),
#  ('DEP', 'aux', 'to', 'believe', 3, True),
#  ('POS', 'VB', 'believe', 'believe', 30, False),
#  ('DEP', 'ccomp', 'believe', 'expect', -13, False),
#  ('POS', 'DT', 'that', 'that', 38, True),
#  ('DEP', 'dobj', 'that', 'believe', -8, True),
#  ('POS', '.', '?', '?', 42, False),
#  ('DEP', 'punct', '?', 'expect', -25, False)]

# %%
parse_all("I want to eat the apple.")
# Out:
# [('PRP', 'i', 'i', 0),
#  ('nsubj', 'i', 'want', 2),
#  ('VBP', 'want', 'want', 2),
#  ('ROOT', 'want', 'want', 0),
#  ('TO', 'to', 'to', 7),
#  ('aux', 'to', 'eat', 3),
#  ('VB', 'eat', 'eat', 10),
#  ('xcomp', 'eat', 'want', -8),
#  ('DT', 'the', 'the', 14),
#  ('det', 'the', 'apple', 4),
#  ('NN', 'apple', 'apple', 18),
#  ('dobj', 'apple', 'eat', -8),
#  ('.', '.', '.', 23),
#  ('punct', '.', 'want', -21)]

# %%
dialogs = pd.read_csv('all_dialogs.csv')
dialogs
# Out:
#              show_id      char_name char_id  \
# 0          DoctorWho  FOURTH DOCTOR   l8653
# 1          DoctorWho  FOURTH DOCTOR   l8653
# 2          DoctorWho  FOURTH DOCTOR   l8653
# 3          DoctorWho  FOURTH DOCTOR   l8653
# 4          DoctorWho  FOURTH DOCTOR   l8653
# 5          DoctorWho  FOURTH DOCTOR   l8653
# 6          DoctorWho  FOURTH DOCTOR   l8653
# 7          DoctorWho  FOURTH DOCTOR   l8653
# 8          DoctorWho  FOURTH DOCTOR   l8653
# 9          DoctorWho  FOURTH DOCTOR   l8653
# 10         DoctorWho  FOURTH DOCTOR   l8653
# 11         DoctorWho  FOURTH DOCTOR   l8653
# 12         DoctorWho  FOURTH DOCTOR   l8653
# 13         DoctorWho  FOURTH DOCTOR   l8653
# 14         DoctorWho  FOURTH DOCTOR   l8653
# 15         DoctorWho  FOURTH DOCTOR   l8653
# 16         DoctorWho  FOURTH DOCTOR   l8653
# 17         DoctorWho  FOURTH DOCTOR   l8653
# 18         DoctorWho  FOURTH DOCTOR   l8653
# 19         DoctorWho  FOURTH DOCTOR   l8653
# 20         DoctorWho  FOURTH DOCTOR   l8653
# 21         DoctorWho  FOURTH DOCTOR   l8653
# 22         DoctorWho  FOURTH DOCTOR   l8653
# 23         DoctorWho  FOURTH DOCTOR   l8653
# 24         DoctorWho  FOURTH DOCTOR   l8653
# 25         DoctorWho  FOURTH DOCTOR   l8653
# 26         DoctorWho  FOURTH DOCTOR   l8653
# 27         DoctorWho  FOURTH DOCTOR   l8653
# 28         DoctorWho  FOURTH DOCTOR   l8653
# 29         DoctorWho  FOURTH DOCTOR   l8653
# ...              ...            ...     ...
# 1073014  QueerAsFolk          DAVID  l22351
# 1073015  QueerAsFolk          DAVID  l22351
# 1073016  QueerAsFolk          DAVID  l22351
# 1073017  QueerAsFolk          DAVID  l22351
# 1073018  QueerAsFolk          DAVID  l22351
# 1073019  QueerAsFolk          DAVID  l22351
# 1073020  QueerAsFolk          DAVID  l22351
# 1073021  QueerAsFolk          DAVID  l22351
# 1073022  QueerAsFolk          DAVID  l22351
# 1073023  QueerAsFolk          DAVID  l22351
# 1073024  QueerAsFolk          DAVID  l22351
# 1073025  QueerAsFolk          DAVID  l22351
# 1073026  QueerAsFolk          DAVID  l22351
# 1073027  QueerAsFolk          DAVID  l22351
# 1073028  QueerAsFolk          DAVID  l22351
# 1073029  QueerAsFolk          DAVID  l22351
# 1073030  QueerAsFolk          DAVID  l22351
# 1073031  QueerAsFolk          DAVID  l22351
# 1073032  QueerAsFolk          DAVID  l22351
# 1073033  QueerAsFolk          DAVID  l22351
# 1073034  QueerAsFolk          DAVID  l22351
# 1073035  QueerAsFolk          DAVID  l22351
# 1073036  QueerAsFolk          DAVID  l22351
# 1073037  QueerAsFolk          DAVID  l22351
# 1073038  QueerAsFolk          DAVID  l22351
# 1073039  QueerAsFolk          DAVID  l22351
# 1073040  QueerAsFolk          DAVID  l22351
# 1073041  QueerAsFolk          DAVID  l22351
# 1073042  QueerAsFolk          DAVID  l22351
# 1073043  QueerAsFolk          DAVID  l22351
#
#                                                       dia1  \
# 0        Get me the medical officer. Lieutenant Sulliva...
# 1          It's something that happened when we first met.
# 2                                   This the patient, sir?
# 3        There you are. Now come along, Doctor, you're ...
# 4        No, I do not mean the infirmary. I mean the si...
# 5        No, Doctor, I'm the doctor and I say that you'...
# 6                        Look here, Doctor. You're not fit
# 7                  I say, I don't think that can be right.
# 8                                                  Well, I
# 9                               Well, I really don't know.
# 10       There is absolutely no question of you leaving...
# 11                                                 Doctor!
# 12                           No, no, Doctor. You can't go.
# 13             What? Oh, yes, of course. Depending on you.
# 14       And I mean, you are still UNIT's scientific ad...
# 15                                              Thank you.
# 16                                                   What?
# 17                                   Very well, thank you.
# 18                                        He promised he'd
# 19                                         You've changed.
# 20       No, I didn't mean your face, I meant your clot...
# 21         UNIT is supposed to be a security organisation.
# 22                                     It's just possible.
# 23       Much better, Doctor. Now, if you've quite fini...
# 24          No, let's settle for that, please. Now, Doctor
# 25                                                    Off?
# 26             The thing is, there's been another robbery.
# 27       Millions of volts running through the wretched...
# 28       Doctor, I have every respect for your concern ...
# 29                      Well, I suppose it was stepped on.
# ...                                                    ...
# 1073014  You didn't tell me the moving men were comingt...
# 1073015                 I better finishedpackin' my stuff.
# 1073016  But I don't know...I don't know what's an"S" a...
# 1073017                Whendid we-when did we get a place?
# 1073018                            Why didn't you tell me?
# 1073019  Sounds great. Um...look, I'm gonna go pick upt...
# 1073020  Oh. Oh. Well, okay. Well, then, I'm gonna call...
# 1073021                        Is there anything I can do?
# 1073022                                      David! David!
# 1073023  Where's my plaid flannel? It used to be righth...
# 1073024  What am I supposed towear to Emmett's party? Y...
# 1073025                                            Thanks.
# 1073026        WhatI need is...somebody who listens to me.
# 1073027  Well, to think about... what I'm gonna do when...
# 1073028  W-well, I...I thought that, um...you know, may...
# 1073029                                   Oh, I can do it.
# 1073030  Well, I used to help my mom put on the screend...
# 1073031  It's supposed to be the Great Northwest, Ma.Ma...
# 1073032                                  David! Uncle Vic!
# 1073033                                              What?
# 1073034                            Why didn't you tell me?
# 1073035                                     Obviously not.
# 1073036                 You have to doeverything yourself!
# 1073037                        You think it's a good idea.
# 1073038  you'll behappy to know this time it's not abou...
# 1073039                     I can take you to the airport.
# 1073040                      Okay, fine, have it your way.
# 1073041        That's not what I was gonna say. I'm sorry.
# 1073042                             I know I don't, but...
# 1073043  Well, I appreciate that, but that's...that's n...
#
#                                                       dia2
# 0                                           Human history.
# 1        I tell you, Brigadier, there's nothing to worr...
# 2        And stupid. If the square on the hypotenuse eq...
# 3                      Am I? Don't you mean the infirmary?
# 4                                 Not fit? I'm the Doctor.
# 5        You may be a doctor, but I'm the Doctor. The d...
# 6        Not fit? Not fit? Of course I'm fit. All syste...
# 7                               Both a bit fast, are they?
# 8        Still, must be patient. A new body's like a ne...
# 9        Well, of course you don't. Why should you? You...
# 10                               How can I prove my point?
# 11       Hello. Come to see me off, have you? Well, I h...
# 12            Can't? Can't? There's no such word as can't.
# 13                                               What for?
# 14                                       Can't I? Goodbye.
# 15                                              Excuse me.
# 16       Haven't me met somewhere before? No, don't tel...
# 17       And Sarah Jane. Well now, isn't this nice? Wha...
# 18                                          Ah, Brigadier.
# 19                                      Oh, no, not again.
# 20                                    Don't you like them?
# 21                 Do you think I might attract attention?
# 22                                             One moment.
# 23                             I'll try again if you like.
# 24                                       Time we were off.
# 25                        To visit the scene of the crime.
# 26       Tell me on the way, Brigadier. Tell me on the ...
# 27                       Oh, but I am, I assure you. Look.
# 28        Not just squashed, flattened. Almost pulverised.
# 29       Exactly. And according to my estimation of the...
# ...                                                    ...
# 1073014                               Oh, I thought I did.
# 1073015                           No, it's okay. I did it.
# 1073016  Captain Astro, robots, comic books are a"P." C...
# 1073017                 I rented a house. On the internet.
# 1073018  Well, there just wasn't time. I mean, we would...
# 1073019                               Nope, don't have to.
# 1073020                            No need. Ibooked a car.
# 1073021  Uh, yeah, you can...stand there and lookgorgeous.
# 1073022                                        What is it?
# 1073023                               Oh, oh, I packed it.
# 1073024                                              Here.
# 1073025  You'll look good in that. That's too small on ...
# 1073026                                              What?
# 1073027                            Okay, let's discuss it.
# 1073028  Oh, I just remembered I told the people who ar...
# 1073029             No, that's okay. I'll take care of it.
# 1073030       It's okay. I'm good with my hands, remember?
# 1073031    All we need now is a bear to sh1t in the woods.
# 1073032                           Oh, okay. Just a second.
# 1073033      I said I changed the reservation until tomo--
# 1073034                              Well, does it matter?
# 1073035  Well, Michael, it's just a little change of pl...
# 1073036                                   I just thought--
# 1073037  For Christ sakes, Michael, what do you want me...
# 1073038                     The car'll be here any minute.
# 1073039         I know you can, but I'd rather you didn't.
# 1073040                               The way I always do?
# 1073041  How many times have I told you you don't have ...
# 1073042  Aside from that...I'm the one that should beap...
# 1073043  Well, I hope you'll decide to change your mind...
#
# [1073044 rows x 5 columns]

# %%
PRE_PRINT = 100000
WORKLOAD = 1073044

def write_all_syntactic(df_dialogs, output_file, rm_sent_file, clip_sent=True):
    assert not os.path.exists(output_file)
    assert not os.path.exists(rm_sent_file)
    with open(output_file, 'a+') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow('sent_id,show_id,char_name,char_id,head_info,head_pos,token,token_par,position,is_stop'.split(','))
    with open(rm_sent_file, 'a+') as csvfile2:
        writer = csv.writer(csvfile2)
        writer.writerow('show_id,char_name,char_id,dia1,dia2'.split(','))
    _time = time()
    _last_ind = 1
    for row in df_dialogs.itertuples():
        if ((row.Index < 10000) and (row.Index % 1000 == 0)) or (row.Index % PRE_PRINT) == 0:
            print(row.Index, '{:.2f} hours left.'.format((time()-_time)/(row.Index-_last_ind)*(WORKLOAD-row.Index)/60/60))
            _time = time()
            _last_ind = row.Index
        if type(row.dia1) != str or len(row.dia1) == 0:
            continue
        with open(output_file, 'a+') as csvfile:
            writer = csv.writer(csvfile)
            if clip_sent:
                heads = parse(row.dia1)
            else:
                heads = parse_all(row.dia1)
            if len(heads) == 0:
                 with open(rm_sent_file, 'a+') as csvfile2:
                    writer2 = csv.writer(csvfile2)
                    writer2.writerow([row.show_id, row.char_name, row.char_id, row.dia1, row.dia2])
            for head in heads:
                writer.writerow([row.Index, row.show_id, row.char_name, row.char_id, head[0], head[1], head[2], head[3], head[4], head[5]])

# %%
raise Exception('write all (with best guess sentence), this ops costs about 5 hours on an decent CPU machine.')

# %%
# write all sentence with filtering to most important sentence.
write_all_syntactic(dialogs, 'all_dialogs_heads.csv', 'all_dialogs_removed.csv')
# Out:
# 0 -1.59 hours left.
# 1000 5.40 hours left.
# 2000 5.00 hours left.
# 3000 5.01 hours left.
# 4000 5.08 hours left.
# 5000 4.78 hours left.
# 6000 4.91 hours left.
# 7000 4.82 hours left.
# 8000 4.65 hours left.
# 9000 4.78 hours left.
# 100000 4.77 hours left.
# 200000 4.60 hours left.
# 300000 3.86 hours left.
# 400000 3.35 hours left.
# 500000 2.90 hours left.
# 600000 2.45 hours left.
# 700000 1.88 hours left.
# 800000 1.28 hours left.
# 900000 0.86 hours left.
# 1000000 0.36 hours left.

# %%
raise Exception('write all, this ops costs about 5 hours on an decent CPU machine.')

# %%
# write all sentence without sub-sentence filtering
# write_all_syntactic(dialogs, 'all_dialogs_heads_nolimit.csv', 'all_dialogs_removed_nolimit.csv', clip_sent=False)

# %%
dialog_heads = pd.read_csv('all_dialogs_heads.csv')
dialog_heads
# Out:
#           sent_id      show_id      char_name char_id head_info head_pos  \
# 0               0    DoctorWho  FOURTH DOCTOR   l8653       POS       VB
# 1               0    DoctorWho  FOURTH DOCTOR   l8653       DEP     ROOT
# 2               0    DoctorWho  FOURTH DOCTOR   l8653       POS       IN
# 3               0    DoctorWho  FOURTH DOCTOR   l8653       DEP     prep
# 4               0    DoctorWho  FOURTH DOCTOR   l8653       POS       DT
# 5               0    DoctorWho  FOURTH DOCTOR   l8653       DEP      det
# 6               0    DoctorWho  FOURTH DOCTOR   l8653       POS       NN
# 7               0    DoctorWho  FOURTH DOCTOR   l8653       DEP     pobj
# 8               0    DoctorWho  FOURTH DOCTOR   l8653       POS       IN
# 9               0    DoctorWho  FOURTH DOCTOR   l8653       DEP     prep
# 10              0    DoctorWho  FOURTH DOCTOR   l8653       POS       RB
# 11              0    DoctorWho  FOURTH DOCTOR   l8653       DEP    pcomp
# 12              0    DoctorWho  FOURTH DOCTOR   l8653       POS        ,
# 13              0    DoctorWho  FOURTH DOCTOR   l8653       DEP    punct
# 14              0    DoctorWho  FOURTH DOCTOR   l8653       POS       UH
# 15              0    DoctorWho  FOURTH DOCTOR   l8653       DEP     intj
# 16              0    DoctorWho  FOURTH DOCTOR   l8653       POS        .
# 17              0    DoctorWho  FOURTH DOCTOR   l8653       DEP    punct
# 18              1    DoctorWho  FOURTH DOCTOR   l8653       POS      PRP
# 19              1    DoctorWho  FOURTH DOCTOR   l8653       DEP    nsubj
# 20              1    DoctorWho  FOURTH DOCTOR   l8653       POS      VBZ
# 21              1    DoctorWho  FOURTH DOCTOR   l8653       DEP     ROOT
# 22              1    DoctorWho  FOURTH DOCTOR   l8653       POS       NN
# 23              1    DoctorWho  FOURTH DOCTOR   l8653       DEP     attr
# 24              1    DoctorWho  FOURTH DOCTOR   l8653       POS      WDT
# 25              1    DoctorWho  FOURTH DOCTOR   l8653       DEP    nsubj
# 26              1    DoctorWho  FOURTH DOCTOR   l8653       POS      VBD
# 27              1    DoctorWho  FOURTH DOCTOR   l8653       DEP    relcl
# 28              1    DoctorWho  FOURTH DOCTOR   l8653       POS      WRB
# 29              1    DoctorWho  FOURTH DOCTOR   l8653       DEP   advmod
# ...           ...          ...            ...     ...       ...      ...
# 17160348  1073041  QueerAsFolk          DAVID  l22351       POS       JJ
# 17160349  1073041  QueerAsFolk          DAVID  l22351       DEP    acomp
# 17160350  1073041  QueerAsFolk          DAVID  l22351       POS        .
# 17160351  1073041  QueerAsFolk          DAVID  l22351       DEP    punct
# 17160352  1073042  QueerAsFolk          DAVID  l22351       POS      PRP
# 17160353  1073042  QueerAsFolk          DAVID  l22351       DEP    nsubj
# 17160354  1073042  QueerAsFolk          DAVID  l22351       POS      VBP
# 17160355  1073042  QueerAsFolk          DAVID  l22351       DEP     ROOT
# 17160356  1073042  QueerAsFolk          DAVID  l22351       POS      PRP
# 17160357  1073042  QueerAsFolk          DAVID  l22351       DEP    nsubj
# 17160358  1073042  QueerAsFolk          DAVID  l22351       POS      VBP
# 17160359  1073042  QueerAsFolk          DAVID  l22351       DEP    ccomp
# 17160360  1073042  QueerAsFolk          DAVID  l22351       POS       RB
# 17160361  1073042  QueerAsFolk          DAVID  l22351       DEP      neg
# 17160362  1073042  QueerAsFolk          DAVID  l22351       POS        ,
# 17160363  1073042  QueerAsFolk          DAVID  l22351       DEP    punct
# 17160364  1073042  QueerAsFolk          DAVID  l22351       POS       CC
# 17160365  1073042  QueerAsFolk          DAVID  l22351       DEP       cc
# 17160366  1073042  QueerAsFolk          DAVID  l22351       POS        .
# 17160367  1073042  QueerAsFolk          DAVID  l22351       DEP    punct
# 17160368  1073043  QueerAsFolk          DAVID  l22351       POS      PRP
# 17160369  1073043  QueerAsFolk          DAVID  l22351       DEP    nsubj
# 17160370  1073043  QueerAsFolk          DAVID  l22351       POS      VBP
# 17160371  1073043  QueerAsFolk          DAVID  l22351       DEP     ROOT
# 17160372  1073043  QueerAsFolk          DAVID  l22351       POS      NFP
# 17160373  1073043  QueerAsFolk          DAVID  l22351       DEP    punct
# 17160374  1073043  QueerAsFolk          DAVID  l22351       POS       UH
# 17160375  1073043  QueerAsFolk          DAVID  l22351       DEP     intj
# 17160376  1073043  QueerAsFolk          DAVID  l22351       POS        .
# 17160377  1073043  QueerAsFolk          DAVID  l22351       DEP    punct
#
#               token  token_par  position  is_stop
# 0              come       come        60    False
# 1              come       come         0    False
# 2                to         to        65     True
# 3                to       come        -5     True
# 4               the        the        68     True
# 5               the        lab         4     True
# 6               lab        lab        72    False
# 7               lab         to        -7    False
# 8                at         at        76     True
# 9                at       come       -16     True
# 10             once       once        79     True
# 11             once         at        -3     True
# 12                ,          ,        83    False
# 13                ,       come       -23    False
# 14           please     please        85     True
# 15           please       come       -25     True
# 16                .          .        91    False
# 17                .       come       -31    False
# 18               it         it         0     True
# 19               it         be         2     True
# 20               be         be         2     True
# 21               be         be         0     True
# 22        something  something         5     True
# 23        something         be        -3     True
# 24             that       that        15     True
# 25             that     happen         5     True
# 26           happen     happen        20    False
# 27           happen  something       -15    False
# 28             when       when        29     True
# 29             when       meet        14     True
# ...             ...        ...       ...      ...
# 17160348      sorry      sorry        37    False
# 17160349      sorry         be        -3    False
# 17160350          .          .        42    False
# 17160351          .         be        -8    False
# 17160352          i          i         0     True
# 17160353          i       know         2     True
# 17160354       know       know         2    False
# 17160355       know       know         0    False
# 17160356          i          i         7     True
# 17160357          i         do         2     True
# 17160358         do         do         9     True
# 17160359         do       know        -7     True
# 17160360        not        not        11     True
# 17160361        not         do        -2     True
# 17160362          ,          ,        14    False
# 17160363          ,       know       -12    False
# 17160364        but        but        16     True
# 17160365        but       know       -14     True
# 17160366        ...        ...        19    False
# 17160367        ...       know       -17    False
# 17160368          i          i       275     True
# 17160369          i        say         2     True
# 17160370        say        say       277     True
# 17160371        say        say         0     True
# 17160372        ...        ...       280    False
# 17160373        ...        say        -3    False
# 17160374        yes        yes       283    False
# 17160375        yes        say        -6    False
# 17160376          .          .       286    False
# 17160377          .        say        -9    False
#
# [17160378 rows x 10 columns]

# %%
# -- direct inspection for sentence neighbourhoood (exact match of sentence head) --
def _head_string(row):
    return '{}|{}|{}'.format(row.head_pos, row.token, row.token_par)

dialog_heads['head_text'] = dialog_heads.apply(_head_string, axis=1)
dialog_heads
# Out:
#           sent_id      show_id      char_name char_id head_info head_pos  \
# 0               0    DoctorWho  FOURTH DOCTOR   l8653       POS       VB
# 1               0    DoctorWho  FOURTH DOCTOR   l8653       DEP     ROOT
# 2               0    DoctorWho  FOURTH DOCTOR   l8653       POS       IN
# 3               0    DoctorWho  FOURTH DOCTOR   l8653       DEP     prep
# 4               0    DoctorWho  FOURTH DOCTOR   l8653       POS       DT
# 5               0    DoctorWho  FOURTH DOCTOR   l8653       DEP      det
# 6               0    DoctorWho  FOURTH DOCTOR   l8653       POS       NN
# 7               0    DoctorWho  FOURTH DOCTOR   l8653       DEP     pobj
# 8               0    DoctorWho  FOURTH DOCTOR   l8653       POS       IN
# 9               0    DoctorWho  FOURTH DOCTOR   l8653       DEP     prep
# 10              0    DoctorWho  FOURTH DOCTOR   l8653       POS       RB
# 11              0    DoctorWho  FOURTH DOCTOR   l8653       DEP    pcomp
# 12              0    DoctorWho  FOURTH DOCTOR   l8653       POS        ,
# 13              0    DoctorWho  FOURTH DOCTOR   l8653       DEP    punct
# 14              0    DoctorWho  FOURTH DOCTOR   l8653       POS       UH
# 15              0    DoctorWho  FOURTH DOCTOR   l8653       DEP     intj
# 16              0    DoctorWho  FOURTH DOCTOR   l8653       POS        .
# 17              0    DoctorWho  FOURTH DOCTOR   l8653       DEP    punct
# 18              1    DoctorWho  FOURTH DOCTOR   l8653       POS      PRP
# 19              1    DoctorWho  FOURTH DOCTOR   l8653       DEP    nsubj
# 20              1    DoctorWho  FOURTH DOCTOR   l8653       POS      VBZ
# 21              1    DoctorWho  FOURTH DOCTOR   l8653       DEP     ROOT
# 22              1    DoctorWho  FOURTH DOCTOR   l8653       POS       NN
# 23              1    DoctorWho  FOURTH DOCTOR   l8653       DEP     attr
# 24              1    DoctorWho  FOURTH DOCTOR   l8653       POS      WDT
# 25              1    DoctorWho  FOURTH DOCTOR   l8653       DEP    nsubj
# 26              1    DoctorWho  FOURTH DOCTOR   l8653       POS      VBD
# 27              1    DoctorWho  FOURTH DOCTOR   l8653       DEP    relcl
# 28              1    DoctorWho  FOURTH DOCTOR   l8653       POS      WRB
# 29              1    DoctorWho  FOURTH DOCTOR   l8653       DEP   advmod
# ...           ...          ...            ...     ...       ...      ...
# 17160348  1073041  QueerAsFolk          DAVID  l22351       POS       JJ
# 17160349  1073041  QueerAsFolk          DAVID  l22351       DEP    acomp
# 17160350  1073041  QueerAsFolk          DAVID  l22351       POS        .
# 17160351  1073041  QueerAsFolk          DAVID  l22351       DEP    punct
# 17160352  1073042  QueerAsFolk          DAVID  l22351       POS      PRP
# 17160353  1073042  QueerAsFolk          DAVID  l22351       DEP    nsubj
# 17160354  1073042  QueerAsFolk          DAVID  l22351       POS      VBP
# 17160355  1073042  QueerAsFolk          DAVID  l22351       DEP     ROOT
# 17160356  1073042  QueerAsFolk          DAVID  l22351       POS      PRP
# 17160357  1073042  QueerAsFolk          DAVID  l22351       DEP    nsubj
# 17160358  1073042  QueerAsFolk          DAVID  l22351       POS      VBP
# 17160359  1073042  QueerAsFolk          DAVID  l22351       DEP    ccomp
# 17160360  1073042  QueerAsFolk          DAVID  l22351       POS       RB
# 17160361  1073042  QueerAsFolk          DAVID  l22351       DEP      neg
# 17160362  1073042  QueerAsFolk          DAVID  l22351       POS        ,
# 17160363  1073042  QueerAsFolk          DAVID  l22351       DEP    punct
# 17160364  1073042  QueerAsFolk          DAVID  l22351       POS       CC
# 17160365  1073042  QueerAsFolk          DAVID  l22351       DEP       cc
# 17160366  1073042  QueerAsFolk          DAVID  l22351       POS        .
# 17160367  1073042  QueerAsFolk          DAVID  l22351       DEP    punct
# 17160368  1073043  QueerAsFolk          DAVID  l22351       POS      PRP
# 17160369  1073043  QueerAsFolk          DAVID  l22351       DEP    nsubj
# 17160370  1073043  QueerAsFolk          DAVID  l22351       POS      VBP
# 17160371  1073043  QueerAsFolk          DAVID  l22351       DEP     ROOT
# 17160372  1073043  QueerAsFolk          DAVID  l22351       POS      NFP
# 17160373  1073043  QueerAsFolk          DAVID  l22351       DEP    punct
# 17160374  1073043  QueerAsFolk          DAVID  l22351       POS       UH
# 17160375  1073043  QueerAsFolk          DAVID  l22351       DEP     intj
# 17160376  1073043  QueerAsFolk          DAVID  l22351       POS        .
# 17160377  1073043  QueerAsFolk          DAVID  l22351       DEP    punct
#
#               token  token_par  position  is_stop               head_text
# 0              come       come        60    False            VB|come|come
# 1              come       come         0    False          ROOT|come|come
# 2                to         to        65     True                IN|to|to
# 3                to       come        -5     True            prep|to|come
# 4               the        the        68     True              DT|the|the
# 5               the        lab         4     True             det|the|lab
# 6               lab        lab        72    False              NN|lab|lab
# 7               lab         to        -7    False             pobj|lab|to
# 8                at         at        76     True                IN|at|at
# 9                at       come       -16     True            prep|at|come
# 10             once       once        79     True            RB|once|once
# 11             once         at        -3     True           pcomp|once|at
# 12                ,          ,        83    False                   ,|,|,
# 13                ,       come       -23    False            punct|,|come
# 14           please     please        85     True        UH|please|please
# 15           please       come       -25     True        intj|please|come
# 16                .          .        91    False                   .|.|.
# 17                .       come       -31    False            punct|.|come
# 18               it         it         0     True               PRP|it|it
# 19               it         be         2     True             nsubj|it|be
# 20               be         be         2     True               VBZ|be|be
# 21               be         be         0     True              ROOT|be|be
# 22        something  something         5     True  NN|something|something
# 23        something         be        -3     True       attr|something|be
# 24             that       that        15     True           WDT|that|that
# 25             that     happen         5     True       nsubj|that|happen
# 26           happen     happen        20    False       VBD|happen|happen
# 27           happen  something       -15    False  relcl|happen|something
# 28             when       when        29     True           WRB|when|when
# 29             when       meet        14     True        advmod|when|meet
# ...             ...        ...       ...      ...                     ...
# 17160348      sorry      sorry        37    False          JJ|sorry|sorry
# 17160349      sorry         be        -3    False          acomp|sorry|be
# 17160350          .          .        42    False                   .|.|.
# 17160351          .         be        -8    False              punct|.|be
# 17160352          i          i         0     True                 PRP|i|i
# 17160353          i       know         2     True            nsubj|i|know
# 17160354       know       know         2    False           VBP|know|know
# 17160355       know       know         0    False          ROOT|know|know
# 17160356          i          i         7     True                 PRP|i|i
# 17160357          i         do         2     True              nsubj|i|do
# 17160358         do         do         9     True               VBP|do|do
# 17160359         do       know        -7     True           ccomp|do|know
# 17160360        not        not        11     True              RB|not|not
# 17160361        not         do        -2     True              neg|not|do
# 17160362          ,          ,        14    False                   ,|,|,
# 17160363          ,       know       -12    False            punct|,|know
# 17160364        but        but        16     True              CC|but|but
# 17160365        but       know       -14     True             cc|but|know
# 17160366        ...        ...        19    False               .|...|...
# 17160367        ...       know       -17    False          punct|...|know
# 17160368          i          i       275     True                 PRP|i|i
# 17160369          i        say         2     True             nsubj|i|say
# 17160370        say        say       277     True             VBP|say|say
# 17160371        say        say         0     True            ROOT|say|say
# 17160372        ...        ...       280    False             NFP|...|...
# 17160373        ...        say        -3    False           punct|...|say
# 17160374        yes        yes       283    False              UH|yes|yes
# 17160375        yes        say        -6    False            intj|yes|say
# 17160376          .          .       286    False                   .|.|.
# 17160377          .        say        -9    False             punct|.|say
#
# [17160378 rows x 11 columns]

# %%
dialog_heads.head_text.value_counts()
# Out:
# .|.|.                        576174
# ,|,|,                        428302
# PRP|you|you                  310320
# PRP|i|i                      265113
# .|?|?                        252663
# ROOT|be|be                   219064
# DT|the|the                   205609
# VBZ|be|be                    180086
# NNP|PERSON|PERSON            146516
# TO|to|to                     146201
# VBP|be|be                    145453
# RB|not|not                   141320
# punct|.|be                   136676
# DT|a|a                       135013
# PRP|it|it                    132420
# CC|and|and                    92985
# punct|,|be                    85277
# WP|what|what                  79302
# IN|of|of                      78788
# PRP|we|we                     77222
# DT|that|that                  74381
# punct|?|be                    61287
# VBD|be|be                     60514
# IN|in|in                      57542
# PRP|me|me                     56727
# VBP|do|do                     53599
# nsubj|it|be                   53510
# DT|this|this                  52876
# IN|to|to                      52822
# .|!|!                         51969
#                               ...
# det|these|recreation              1
# appos|medicine|birthday           1
# ccomp|become|dare                 1
# advmod|upstairs|table             1
# relcl|live|friend                 1
# attr|sandalwood|be                1
# dobj|1|say                        1
# poss|my|park                      1
# nsubj|batch|come                  1
# conj|personal|business            1
# .|ah--|ah--                       1
# case|'s|Thomsen                   1
# attr|sublet|be                    1
# npadvmod|bit|happy                1
# advmod|far|bite                   1
# compound|Smallville|Lanes         1
# advcl|lock|want                   1
# xcomp|chase|care                  1
# punct|—|eeeee                     1
# poss|asteroid|surface             1
# VBP|string|string                 1
# nsubjpass|maggot|hammer           1
# attr|keychain|be                  1
# NN|betamax|betamax                1
# amod|own|computer                 1
# dobj|other|trick                  1
# advmod|kinda|base                 1
# cc|of|scream                      1
# conj|wind|’                       1
# compound|isotope|rate             1
# Name: head_text, Length: 1155675, dtype: int64

# %%
# write them back with the extra column
dialog_heads.to_csv('all_dialogs_heads.csv', index=False)

# %% [markdown]
# ## Clean Data for Matrix Multiplication of Sentence Neighbourhood
#
# Let us play around to get some sentence neighourhood grouping.
#
# The Matrix Multiplication is in next pipeline (pipe3). This section only clean and write data.

# %%
# Filter the sentence head features that has low frequency.
# we keep at >4 freqency features.

_count = 0
_len = dialog_heads.shape[0]
for text, freq in dialog_heads.head_text.value_counts().iteritems():
    if 5 < freq:
        _count += freq

print(_count/_len)  # precentage of data still got left after filtering.
# Out:
# 0.9127074590081874

# %%
# remove all low frequency features and save to file
filtered_heads = dialog_heads[dialog_heads.groupby('head_text')['head_text'].transform('count').ge(5)]
filtered_heads

# %%
# write to file for next pipeline
assert not os.path.exists('all_dialogs_heads_filtered.csv')
filtered_heads.to_csv('all_dialogs_heads_filtered.csv', index=False)

# %%
filtered_heads.loc[filtered_heads.sent_id==617921]

# %%
filtered_heads.loc[filtered_heads.sent_id==562875]

# %%
dialogs.iloc[508079].dia1

# %%
dialogs.iloc[159581].dia1

# %%
parse(dialogs.iloc[159581].dia1)
