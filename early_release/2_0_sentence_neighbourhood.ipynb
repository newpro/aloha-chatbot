# %% [markdown]
# ## Matrix Multiplication for Dialog Heads
#
# This file perform matrix multiplication learning for dialog heads.
#
# Content:
#
# * Clean data a bit, remove low frequency count.
# * Build Coo Matrix.
# * Parameter search.

# %%
# DATA LOAD
import os
import itertools
import pandas as pd
import numpy as np

import sys
# sys.path.insert(0, '/home/kits-adm/Workspace/play/dodgson_play/implicit_local/implicit') # local compile that has gpu support
import implicit
import numpy as np

from copy import deepcopy
from sklearn import metrics
from scipy.sparse import coo_matrix
from implicit.evaluation import train_test_split, precision_at_k, mean_average_precision_at_k

os.environ["MKL_NUM_THREADS"] = "1"

BASE = '/home/kits-adm/Datasets/dodgsons/dodgson/outputs/no_split/'
RANDOM_STATE = 28145037

def seed(value=RANDOM_STATE):
    np.random.seed(value)

# %%
data = pd.read_csv('all_dialogs_heads.csv')
data = data.sample(frac=1, random_state=RANDOM_STATE).reset_index(drop=True)
data
# Out:
#           sent_id                        show_id            char_name char_id  \
# 0         1063785                    QueerAsFolk              MICHAEL  l22346
# 1          233952                    TheSimpsons         Lisa Simpson  a15823
# 2          926937                  SonsOfAnarchy                 CLAY  l24811
# 3          504583                  OnceUponATime        MARY MARGARET  l19393
# 4          508646                  OnceUponATime           CINDERELLA  l19407
# 5           78453                      DoctorWho              BARBARA   l8667
# 6          146223                   VeronicaMars             VERONICA  l30591
# 7           19636                      DoctorWho      ELEVENTH DOCTOR   l8661
# 8          717221                   GilmoreGirls                 RORY  l11613
# 9          161951                     Smallville                CLARK  l24611
# 10        1059921                    Charmed1998                 ANDY   l6497
# 11         504657                  OnceUponATime        MARY MARGARET  l19393
# 12         672740                          Alias                 JACK   l1275
# 13         144292                   VeronicaMars             VERONICA  l30591
# 14         537460                       StarTrek              JANEWAY  l25466
# 15         923983                  SonsOfAnarchy                  JAX  l24810
# 16         894784               TheBigBangTheory              SHELDON   l4390
# 17         597351                       StarTrek             CHAKOTAY  l25467
# 18         662463                       StarTrek                PHLOX  l25490
# 19         642832                       StarTrek               HARPER   l1893
# 20         375325                   TheMentalist                  CHO  l17675
# 21         238693                    TheSimpsons  C. Montgomery Burns  a15869
# 22         606411                       StarTrek                 WORF  l25435
# 23         526675                   GreysAnatomy                DEREK  l12263
# 24         751240                   GilmoreGirls              RICHARD  l11615
# 25         220001                    TheSimpsons         Bart Simpson  a15822
# 26         518382                  AdventureTime   Princess Bubblegum   a3409
# 27          66679                      DoctorWho                 GWEN   l9078
# 28         130438                           NCIS                 KATE  l18800
# 29         437089  MyLittlePonyFriendshipIsMagic                Spike  a13105
# ...           ...                            ...                  ...     ...
# 17160348  1063421                    QueerAsFolk              MICHAEL  l22346
# 17160349   709703                   GilmoreGirls                 RORY  l11613
# 17160350   174190                     Smallville                 LANA  l24615
# 17160351   274814                   Supernatural                  SAM  l25967
# 17160352   548045                       StarTrek              JANEWAY  l25466
# 17160353   314500                          Bones               SWEETS   l5163
# 17160354   192729                    TheSimpsons        Homer Simpson  a15835
# 17160355   329079                        Friends                 ROSS  l10696
# 17160356   509057                  AdventureTime                 Finn   a3415
# 17160357   465269                    OneTreeHill               NATHAN  l19594
# 17160358   240124                    TheSimpsons          Moe Szyslak  a15875
# 17160359    25432                      DoctorWho        SECOND DOCTOR   l8651
# 17160360   493526                  OnceUponATime                 EMMA  l19391
# 17160361   309814                          Bones               ANGELA   l5149
# 17160362   793175                    TheOfficeUS              MICHAEL  l19352
# 17160363  1006647                       Seinfeld               GEORGE  l23594
# 17160364   610713                       StarTrek                SPOCK  l25411
# 17160365   723387                   GilmoreGirls                 RORY  l11613
# 17160366   125325                           NCIS                 ABBY  l18806
# 17160367   732232                   GilmoreGirls                 LUKE  l11617
# 17160368   774869                        Roswell                  MAX  l23046
# 17160369   967551                   DawsonsCreek                 JOEY   l7947
# 17160370   860557              HowIMetYourMother               BARNEY  l13774
# 17160371   126524                           NCIS                 ABBY  l18806
# 17160372   387420                       Futurama                Leela   a8871
# 17160373   537886                       StarTrek              JANEWAY  l25466
# 17160374   182960                     Smallville                JIMMY  l24654
# 17160375   568148                       StarTrek                 HUNT   l1890
# 17160376   652290                       StarTrek                MCCOY  l25412
# 17160377   295962                          Bones              BRENNAN   l5146
#
#          head_info   head_pos      token  token_par  position  is_stop  \
# 0              POS        VBZ         be         be         2     True
# 1              DEP        det          a       girl         8     True
# 2              DEP   compound       club    problem         5    False
# 3              DEP      punct          .    Nothing       -25    False
# 4              POS         JJ     entire     entire        77    False
# 5              DEP      advcl         be       hold        34     True
# 6              DEP   compound       drug    testing         5    False
# 7              POS          .          .          .        66    False
# 8              DEP       ROOT        buy        buy         0    False
# 9              DEP      punct          ,    believe         4    False
# 10             DEP      ccomp         be      think       -18     True
# 11             POS       PRP$        her        her        45     True
# 12             POS         UH         um         um         9    False
# 13             POS        VBZ         do         do         0     True
# 14             POS         NN  deflector  deflector        61    False
# 15             POS        VBZ         be         be        26     True
# 16             DEP       nmod      click      thunk        12    False
# 17             DEP  nsubjpass       body      leave        33    False
# 18             DEP      nsubj  condition         be       -16    False
# 19             DEP       prep     beyond         be        24     True
# 20             DEP      punct          .      shoot       -15    False
# 21             POS         NN      blood      blood        63    False
# 22             POS          ,          ,          ,        72    False
# 23             DEP       mark         if         be         5     True
# 24             POS         JJ      ready      ready        19    False
# 25             DEP      punct          :       make        60    False
# 26             POS         IN         on         on        20     True
# 27             DEP        det         no     weapon         9     True
# 28             POS         UH         no         no         0     True
# 29             POS        PRP          i          i        20     True
# ...            ...        ...        ...        ...       ...      ...
# 17160348       DEP        det          a      sauce        19     True
# 17160349       DEP       pobj      honey        for        -4    False
# 17160350       DEP        aux         to         go         3     True
# 17160351       POS          .          .          .        16    False
# 17160352       DEP        aux      could       wait        27     True
# 17160353       DEP      punct          ,         be         4    False
# 17160354       POS        PRP         me         me        76     True
# 17160355       POS         VB       wait       wait       110    False
# 17160356       POS          .          ?          ?        34    False
# 17160357       POS        PRP        you        you         7     True
# 17160358       DEP      punct          !      cause       -19    False
# 17160359       POS         NN     report     report        62    False
# 17160360       DEP      punct          ?      think       -30    False
# 17160361       DEP      punct          .      dream       -17    False
# 17160362       POS        NNP        GPE        GPE        72    False
# 17160363       DEP       mark       that        ask        14     True
# 17160364       POS         MD       will       will       113     True
# 17160365       POS        VBD         be         be         8     True
# 17160366       POS        NNP        ORG        ORG       114    False
# 17160367       POS          .          .          .       162    False
# 17160368       DEP       intj         no     PERSON         4     True
# 17160369       POS         TO         to         to       261     True
# 17160370       DEP       intj       okay         be        14    False
# 17160371       DEP      nsubj       that         be         4     True
# 17160372       POS          .          .          .        86    False
# 17160373       POS         NN      price      price       109    False
# 17160374       POS         RB       sort       sort        79    False
# 17160375       POS          .          .          .        32    False
# 17160376       POS        NNP        FAC        FAC        66    False
# 17160377       DEP       case         's     PERSON        -7     True
#
#                        head_text
# 0                      VBZ|be|be
# 1                     det|a|girl
# 2          compound|club|problem
# 3                punct|.|Nothing
# 4               JJ|entire|entire
# 5                  advcl|be|hold
# 6          compound|drug|testing
# 7                          .|.|.
# 8                   ROOT|buy|buy
# 9                punct|,|believe
# 10                ccomp|be|think
# 11                  PRP$|her|her
# 12                      UH|um|um
# 13                     VBZ|do|do
# 14        NN|deflector|deflector
# 15                     VBZ|be|be
# 16              nmod|click|thunk
# 17          nsubjpass|body|leave
# 18            nsubj|condition|be
# 19                prep|beyond|be
# 20                 punct|.|shoot
# 21                NN|blood|blood
# 22                         ,|,|,
# 23                    mark|if|be
# 24                JJ|ready|ready
# 25                  punct|:|make
# 26                      IN|on|on
# 27                 det|no|weapon
# 28                      UH|no|no
# 29                       PRP|i|i
# ...                          ...
# 17160348             det|a|sauce
# 17160349          pobj|honey|for
# 17160350               aux|to|go
# 17160351                   .|.|.
# 17160352          aux|could|wait
# 17160353              punct|,|be
# 17160354               PRP|me|me
# 17160355            VB|wait|wait
# 17160356                   .|?|?
# 17160357             PRP|you|you
# 17160358           punct|!|cause
# 17160359        NN|report|report
# 17160360           punct|?|think
# 17160361           punct|.|dream
# 17160362             NNP|GPE|GPE
# 17160363           mark|that|ask
# 17160364            MD|will|will
# 17160365               VBD|be|be
# 17160366             NNP|ORG|ORG
# 17160367                   .|.|.
# 17160368          intj|no|PERSON
# 17160369                TO|to|to
# 17160370            intj|okay|be
# 17160371           nsubj|that|be
# 17160372                   .|.|.
# 17160373          NN|price|price
# 17160374            RB|sort|sort
# 17160375                   .|.|.
# 17160376             NNP|FAC|FAC
# 17160377          case|'s|PERSON
#
# [17160378 rows x 11 columns]

# %% [markdown]
# ## Basic cleaning
#
# Basic filtering of all data except the following:
#
#
# * All punct except "?"
# * No ROOT.
#
# In addition, remove all sentence feature that have freq less than 5.

# %%
data = data.loc[(data.head_pos!='ROOT') & (data.head_pos!='punct')]
data
# Out:
#           sent_id                        show_id            char_name char_id  \
# 0         1063785                    QueerAsFolk              MICHAEL  l22346
# 1          233952                    TheSimpsons         Lisa Simpson  a15823
# 2          926937                  SonsOfAnarchy                 CLAY  l24811
# 4          508646                  OnceUponATime           CINDERELLA  l19407
# 5           78453                      DoctorWho              BARBARA   l8667
# 6          146223                   VeronicaMars             VERONICA  l30591
# 7           19636                      DoctorWho      ELEVENTH DOCTOR   l8661
# 10        1059921                    Charmed1998                 ANDY   l6497
# 11         504657                  OnceUponATime        MARY MARGARET  l19393
# 12         672740                          Alias                 JACK   l1275
# 13         144292                   VeronicaMars             VERONICA  l30591
# 14         537460                       StarTrek              JANEWAY  l25466
# 15         923983                  SonsOfAnarchy                  JAX  l24810
# 16         894784               TheBigBangTheory              SHELDON   l4390
# 17         597351                       StarTrek             CHAKOTAY  l25467
# 18         662463                       StarTrek                PHLOX  l25490
# 19         642832                       StarTrek               HARPER   l1893
# 21         238693                    TheSimpsons  C. Montgomery Burns  a15869
# 22         606411                       StarTrek                 WORF  l25435
# 23         526675                   GreysAnatomy                DEREK  l12263
# 24         751240                   GilmoreGirls              RICHARD  l11615
# 26         518382                  AdventureTime   Princess Bubblegum   a3409
# 27          66679                      DoctorWho                 GWEN   l9078
# 28         130438                           NCIS                 KATE  l18800
# 29         437089  MyLittlePonyFriendshipIsMagic                Spike  a13105
# 31         580866                       StarTrek               ARCHER  l25486
# 32         971419                   DawsonsCreek               DAWSON   l7946
# 33         866034              HowIMetYourMother                ROBIN  l13772
# 34        1055655                    Charmed1998                 COLE   l6502
# 35        1000771                       Seinfeld                JERRY  l23593
# ...           ...                            ...                  ...     ...
# 17160343   603811                       StarTrek                 WORF  l25435
# 17160344   749073                   GilmoreGirls               SOOKIE  l11619
# 17160346   373719                   TheMentalist               LISBON  l17674
# 17160347   656813                       StarTrek               TRANCE   l1896
# 17160348  1063421                    QueerAsFolk              MICHAEL  l22346
# 17160349   709703                   GilmoreGirls                 RORY  l11613
# 17160350   174190                     Smallville                 LANA  l24615
# 17160351   274814                   Supernatural                  SAM  l25967
# 17160352   548045                       StarTrek              JANEWAY  l25466
# 17160354   192729                    TheSimpsons        Homer Simpson  a15835
# 17160355   329079                        Friends                 ROSS  l10696
# 17160356   509057                  AdventureTime                 Finn   a3415
# 17160357   465269                    OneTreeHill               NATHAN  l19594
# 17160359    25432                      DoctorWho        SECOND DOCTOR   l8651
# 17160362   793175                    TheOfficeUS              MICHAEL  l19352
# 17160363  1006647                       Seinfeld               GEORGE  l23594
# 17160364   610713                       StarTrek                SPOCK  l25411
# 17160365   723387                   GilmoreGirls                 RORY  l11613
# 17160366   125325                           NCIS                 ABBY  l18806
# 17160367   732232                   GilmoreGirls                 LUKE  l11617
# 17160368   774869                        Roswell                  MAX  l23046
# 17160369   967551                   DawsonsCreek                 JOEY   l7947
# 17160370   860557              HowIMetYourMother               BARNEY  l13774
# 17160371   126524                           NCIS                 ABBY  l18806
# 17160372   387420                       Futurama                Leela   a8871
# 17160373   537886                       StarTrek              JANEWAY  l25466
# 17160374   182960                     Smallville                JIMMY  l24654
# 17160375   568148                       StarTrek                 HUNT   l1890
# 17160376   652290                       StarTrek                MCCOY  l25412
# 17160377   295962                          Bones              BRENNAN   l5146
#
#          head_info   head_pos      token  token_par  position  is_stop  \
# 0              POS        VBZ         be         be         2     True
# 1              DEP        det          a       girl         8     True
# 2              DEP   compound       club    problem         5    False
# 4              POS         JJ     entire     entire        77    False
# 5              DEP      advcl         be       hold        34     True
# 6              DEP   compound       drug    testing         5    False
# 7              POS          .          .          .        66    False
# 10             DEP      ccomp         be      think       -18     True
# 11             POS       PRP$        her        her        45     True
# 12             POS         UH         um         um         9    False
# 13             POS        VBZ         do         do         0     True
# 14             POS         NN  deflector  deflector        61    False
# 15             POS        VBZ         be         be        26     True
# 16             DEP       nmod      click      thunk        12    False
# 17             DEP  nsubjpass       body      leave        33    False
# 18             DEP      nsubj  condition         be       -16    False
# 19             DEP       prep     beyond         be        24     True
# 21             POS         NN      blood      blood        63    False
# 22             POS          ,          ,          ,        72    False
# 23             DEP       mark         if         be         5     True
# 24             POS         JJ      ready      ready        19    False
# 26             POS         IN         on         on        20     True
# 27             DEP        det         no     weapon         9     True
# 28             POS         UH         no         no         0     True
# 29             POS        PRP          i          i        20     True
# 31             DEP       mark         if      agree         5     True
# 32             DEP   npadvmod     PERSON       know        15    False
# 33             POS         NN       info       info        63    False
# 34             POS          ,          ,          ,        12    False
# 35             POS        PRP        you        you         5     True
# ...            ...        ...        ...        ...       ...      ...
# 17160343       POS         CD   CARDINAL   CARDINAL        61     True
# 17160344       POS         NN     budget     budget        20    False
# 17160346       DEP     advmod       once      bring       -27     True
# 17160347       POS        PRP         it         it        74     True
# 17160348       DEP        det          a      sauce        19     True
# 17160349       DEP       pobj      honey        for        -4    False
# 17160350       DEP        aux         to         go         3     True
# 17160351       POS          .          .          .        16    False
# 17160352       DEP        aux      could       wait        27     True
# 17160354       POS        PRP         me         me        76     True
# 17160355       POS         VB       wait       wait       110    False
# 17160356       POS          .          ?          ?        34    False
# 17160357       POS        PRP        you        you         7     True
# 17160359       POS         NN     report     report        62    False
# 17160362       POS        NNP        GPE        GPE        72    False
# 17160363       DEP       mark       that        ask        14     True
# 17160364       POS         MD       will       will       113     True
# 17160365       POS        VBD         be         be         8     True
# 17160366       POS        NNP        ORG        ORG       114    False
# 17160367       POS          .          .          .       162    False
# 17160368       DEP       intj         no     PERSON         4     True
# 17160369       POS         TO         to         to       261     True
# 17160370       DEP       intj       okay         be        14    False
# 17160371       DEP      nsubj       that         be         4     True
# 17160372       POS          .          .          .        86    False
# 17160373       POS         NN      price      price       109    False
# 17160374       POS         RB       sort       sort        79    False
# 17160375       POS          .          .          .        32    False
# 17160376       POS        NNP        FAC        FAC        66    False
# 17160377       DEP       case         's     PERSON        -7     True
#
#                        head_text
# 0                      VBZ|be|be
# 1                     det|a|girl
# 2          compound|club|problem
# 4               JJ|entire|entire
# 5                  advcl|be|hold
# 6          compound|drug|testing
# 7                          .|.|.
# 10                ccomp|be|think
# 11                  PRP$|her|her
# 12                      UH|um|um
# 13                     VBZ|do|do
# 14        NN|deflector|deflector
# 15                     VBZ|be|be
# 16              nmod|click|thunk
# 17          nsubjpass|body|leave
# 18            nsubj|condition|be
# 19                prep|beyond|be
# 21                NN|blood|blood
# 22                         ,|,|,
# 23                    mark|if|be
# 24                JJ|ready|ready
# 26                      IN|on|on
# 27                 det|no|weapon
# 28                      UH|no|no
# 29                       PRP|i|i
# 31                 mark|if|agree
# 32          npadvmod|PERSON|know
# 33                  NN|info|info
# 34                         ,|,|,
# 35                   PRP|you|you
# ...                          ...
# 17160343    CD|CARDINAL|CARDINAL
# 17160344        NN|budget|budget
# 17160346       advmod|once|bring
# 17160347               PRP|it|it
# 17160348             det|a|sauce
# 17160349          pobj|honey|for
# 17160350               aux|to|go
# 17160351                   .|.|.
# 17160352          aux|could|wait
# 17160354               PRP|me|me
# 17160355            VB|wait|wait
# 17160356                   .|?|?
# 17160357             PRP|you|you
# 17160359        NN|report|report
# 17160362             NNP|GPE|GPE
# 17160363           mark|that|ask
# 17160364            MD|will|will
# 17160365               VBD|be|be
# 17160366             NNP|ORG|ORG
# 17160367                   .|.|.
# 17160368          intj|no|PERSON
# 17160369                TO|to|to
# 17160370            intj|okay|be
# 17160371           nsubj|that|be
# 17160372                   .|.|.
# 17160373          NN|price|price
# 17160374            RB|sort|sort
# 17160375                   .|.|.
# 17160376             NNP|FAC|FAC
# 17160377          case|'s|PERSON
#
# [14823075 rows x 11 columns]

# %%
head_count = data.head_text.value_counts()
print(len(head_count))
head_count
# Out:
# 1084813
# .|.|.                           576174
# ,|,|,                           428302
# PRP|you|you                     310320
# PRP|i|i                         265113
# .|?|?                           252663
# DT|the|the                      205609
# VBZ|be|be                       180086
# NNP|PERSON|PERSON               146516
# TO|to|to                        146201
# VBP|be|be                       145453
# RB|not|not                      141320
# DT|a|a                          135013
# PRP|it|it                       132420
# CC|and|and                       92985
# WP|what|what                     79302
# IN|of|of                         78788
# PRP|we|we                        77222
# DT|that|that                     74381
# VBD|be|be                        60514
# IN|in|in                         57542
# PRP|me|me                        56727
# VBP|do|do                        53599
# nsubj|it|be                      53510
# DT|this|this                     52876
# IN|to|to                         52822
# .|!|!                            51969
# IN|for|for                       48300
# PRP|he|he                        47695
# PRP$|your|your                   45517
# VB|have|have                     45041
#                                  ...
# prep|in|airbag                       1
# dobj|film|suppose                    1
# dobj|DA|see                          1
# prep|of|persistence                  1
# dobj|boy|execute                     1
# prep|from|possible                   1
# dep|vow|be                           1
# conj|replace|draw                    1
# amod|ultrasonic|lithotryptor         1
# parataxis|mean|mob                   1
# dobj|yourself|murder                 1
# amod|entire|pack                     1
# advmod|considerably|improve          1
# conj|fly|miss                        1
# nsubj|me|undo                        1
# advmod|ok|drink                      1
# compound|dissolver|thing             1
# amod|light|preparation               1
# npadvmod|Witter|hey                  1
# dobj|fryer|work                      1
# amod|approve|architect               1
# acl|jam|signal                       1
# appos|coat|bloodstain                1
# dobj|effect|resist                   1
# nsubj|Anyone|mess                    1
# appos|exposure|strength              1
# JJ|domineering|domineering           1
# pobj|dominatrix|with                 1
# appos|card|content                   1
# pobj|slag|with                       1
# Name: head_text, Length: 1084813, dtype: int64

# %%
sent_count = data.sent_id.value_counts()
print(len(sent_count))
sent_count
# Out:
# 929614
# 831222     170
# 763046     163
# 467363     154
# 831028     150
# 719532     147
# 965936     143
# 241286     135
# 831108     132
# 398397     132
# 715491     132
# 704331     130
# 909670     128
# 731202     128
# 745303     127
# 952114     127
# 967251     127
# 575390     126
# 974959     126
# 900148     125
# 979734     125
# 716739     124
# 974554     123
# 325812     122
# 426906     122
# 663693     121
# 845686     121
# 427592     121
# 840637     121
# 306281     119
# 734729     119
#           ...
# 774933       4
# 269051       4
# 340097       4
# 438969       4
# 694480       4
# 641063       4
# 364214       4
# 1001061      4
# 873415       4
# 741229       4
# 482523       4
# 323765       4
# 350072       4
# 144686       4
# 733401       4
# 683566       4
# 339627       4
# 510044       4
# 319894       4
# 222081       4
# 880332       4
# 718774       4
# 357302       4
# 735303       4
# 683565       4
# 342747       4
# 1005511      4
# 224865       4
# 761605       4
# 515802       4
# Name: sent_id, Length: 929614, dtype: int64

# %%
# -- Filter Inspection --
# BEFORE WE FILTER: inspect percentage of data left after filtering, we do not want to remove too much lol
# we keep at >5 freqency features.

_count = 0
_len = data.shape[0]
for text, freq in data.head_text.value_counts().iteritems():
    if 5 < freq:
        _count += freq

print(_count/_len)  # precentage of data still got left after filtering, got 90% left, pretty good!
# Out:
# 0.9053410982539049

# %%
# remove all low frequency features and save to file
data = data[data.groupby('head_text')['head_text'].transform('count').ge(5)]
data
# Out:
#           sent_id                        show_id            char_name char_id  \
# 0         1063785                    QueerAsFolk              MICHAEL  l22346
# 1          233952                    TheSimpsons         Lisa Simpson  a15823
# 4          508646                  OnceUponATime           CINDERELLA  l19407
# 5           78453                      DoctorWho              BARBARA   l8667
# 6          146223                   VeronicaMars             VERONICA  l30591
# 7           19636                      DoctorWho      ELEVENTH DOCTOR   l8661
# 10        1059921                    Charmed1998                 ANDY   l6497
# 11         504657                  OnceUponATime        MARY MARGARET  l19393
# 12         672740                          Alias                 JACK   l1275
# 13         144292                   VeronicaMars             VERONICA  l30591
# 14         537460                       StarTrek              JANEWAY  l25466
# 15         923983                  SonsOfAnarchy                  JAX  l24810
# 18         662463                       StarTrek                PHLOX  l25490
# 19         642832                       StarTrek               HARPER   l1893
# 21         238693                    TheSimpsons  C. Montgomery Burns  a15869
# 22         606411                       StarTrek                 WORF  l25435
# 23         526675                   GreysAnatomy                DEREK  l12263
# 24         751240                   GilmoreGirls              RICHARD  l11615
# 26         518382                  AdventureTime   Princess Bubblegum   a3409
# 27          66679                      DoctorWho                 GWEN   l9078
# 28         130438                           NCIS                 KATE  l18800
# 29         437089  MyLittlePonyFriendshipIsMagic                Spike  a13105
# 31         580866                       StarTrek               ARCHER  l25486
# 32         971419                   DawsonsCreek               DAWSON   l7946
# 33         866034              HowIMetYourMother                ROBIN  l13772
# 34        1055655                    Charmed1998                 COLE   l6502
# 35        1000771                       Seinfeld                JERRY  l23593
# 36         642447                       StarTrek               HARPER   l1893
# 38         110457                           NCIS                GIBBS  l18791
# 40         403957                       CSIVerse                 NICK   l7486
# ...           ...                            ...                  ...     ...
# 17160343   603811                       StarTrek                 WORF  l25435
# 17160344   749073                   GilmoreGirls               SOOKIE  l11619
# 17160346   373719                   TheMentalist               LISBON  l17674
# 17160347   656813                       StarTrek               TRANCE   l1896
# 17160348  1063421                    QueerAsFolk              MICHAEL  l22346
# 17160349   709703                   GilmoreGirls                 RORY  l11613
# 17160350   174190                     Smallville                 LANA  l24615
# 17160351   274814                   Supernatural                  SAM  l25967
# 17160352   548045                       StarTrek              JANEWAY  l25466
# 17160354   192729                    TheSimpsons        Homer Simpson  a15835
# 17160355   329079                        Friends                 ROSS  l10696
# 17160356   509057                  AdventureTime                 Finn   a3415
# 17160357   465269                    OneTreeHill               NATHAN  l19594
# 17160359    25432                      DoctorWho        SECOND DOCTOR   l8651
# 17160362   793175                    TheOfficeUS              MICHAEL  l19352
# 17160363  1006647                       Seinfeld               GEORGE  l23594
# 17160364   610713                       StarTrek                SPOCK  l25411
# 17160365   723387                   GilmoreGirls                 RORY  l11613
# 17160366   125325                           NCIS                 ABBY  l18806
# 17160367   732232                   GilmoreGirls                 LUKE  l11617
# 17160368   774869                        Roswell                  MAX  l23046
# 17160369   967551                   DawsonsCreek                 JOEY   l7947
# 17160370   860557              HowIMetYourMother               BARNEY  l13774
# 17160371   126524                           NCIS                 ABBY  l18806
# 17160372   387420                       Futurama                Leela   a8871
# 17160373   537886                       StarTrek              JANEWAY  l25466
# 17160374   182960                     Smallville                JIMMY  l24654
# 17160375   568148                       StarTrek                 HUNT   l1890
# 17160376   652290                       StarTrek                MCCOY  l25412
# 17160377   295962                          Bones              BRENNAN   l5146
#
#          head_info  head_pos      token  token_par  position  is_stop  \
# 0              POS       VBZ         be         be         2     True
# 1              DEP       det          a       girl         8     True
# 4              POS        JJ     entire     entire        77    False
# 5              DEP     advcl         be       hold        34     True
# 6              DEP  compound       drug    testing         5    False
# 7              POS         .          .          .        66    False
# 10             DEP     ccomp         be      think       -18     True
# 11             POS      PRP$        her        her        45     True
# 12             POS        UH         um         um         9    False
# 13             POS       VBZ         do         do         0     True
# 14             POS        NN  deflector  deflector        61    False
# 15             POS       VBZ         be         be        26     True
# 18             DEP     nsubj  condition         be       -16    False
# 19             DEP      prep     beyond         be        24     True
# 21             POS        NN      blood      blood        63    False
# 22             POS         ,          ,          ,        72    False
# 23             DEP      mark         if         be         5     True
# 24             POS        JJ      ready      ready        19    False
# 26             POS        IN         on         on        20     True
# 27             DEP       det         no     weapon         9     True
# 28             POS        UH         no         no         0     True
# 29             POS       PRP          i          i        20     True
# 31             DEP      mark         if      agree         5     True
# 32             DEP  npadvmod     PERSON       know        15    False
# 33             POS        NN       info       info        63    False
# 34             POS         ,          ,          ,        12    False
# 35             POS       PRP        you        you         5     True
# 36             DEP  npadvmod     PERSON         be       -19    False
# 38             DEP      dobj         me       tell        -8     True
# 40             DEP      dobj         it       help        -5     True
# ...            ...       ...        ...        ...       ...      ...
# 17160343       POS        CD   CARDINAL   CARDINAL        61     True
# 17160344       POS        NN     budget     budget        20    False
# 17160346       DEP    advmod       once      bring       -27     True
# 17160347       POS       PRP         it         it        74     True
# 17160348       DEP       det          a      sauce        19     True
# 17160349       DEP      pobj      honey        for        -4    False
# 17160350       DEP       aux         to         go         3     True
# 17160351       POS         .          .          .        16    False
# 17160352       DEP       aux      could       wait        27     True
# 17160354       POS       PRP         me         me        76     True
# 17160355       POS        VB       wait       wait       110    False
# 17160356       POS         .          ?          ?        34    False
# 17160357       POS       PRP        you        you         7     True
# 17160359       POS        NN     report     report        62    False
# 17160362       POS       NNP        GPE        GPE        72    False
# 17160363       DEP      mark       that        ask        14     True
# 17160364       POS        MD       will       will       113     True
# 17160365       POS       VBD         be         be         8     True
# 17160366       POS       NNP        ORG        ORG       114    False
# 17160367       POS         .          .          .       162    False
# 17160368       DEP      intj         no     PERSON         4     True
# 17160369       POS        TO         to         to       261     True
# 17160370       DEP      intj       okay         be        14    False
# 17160371       DEP     nsubj       that         be         4     True
# 17160372       POS         .          .          .        86    False
# 17160373       POS        NN      price      price       109    False
# 17160374       POS        RB       sort       sort        79    False
# 17160375       POS         .          .          .        32    False
# 17160376       POS       NNP        FAC        FAC        66    False
# 17160377       DEP      case         's     PERSON        -7     True
#
#                        head_text
# 0                      VBZ|be|be
# 1                     det|a|girl
# 4               JJ|entire|entire
# 5                  advcl|be|hold
# 6          compound|drug|testing
# 7                          .|.|.
# 10                ccomp|be|think
# 11                  PRP$|her|her
# 12                      UH|um|um
# 13                     VBZ|do|do
# 14        NN|deflector|deflector
# 15                     VBZ|be|be
# 18            nsubj|condition|be
# 19                prep|beyond|be
# 21                NN|blood|blood
# 22                         ,|,|,
# 23                    mark|if|be
# 24                JJ|ready|ready
# 26                      IN|on|on
# 27                 det|no|weapon
# 28                      UH|no|no
# 29                       PRP|i|i
# 31                 mark|if|agree
# 32          npadvmod|PERSON|know
# 33                  NN|info|info
# 34                         ,|,|,
# 35                   PRP|you|you
# 36            npadvmod|PERSON|be
# 38                  dobj|me|tell
# 40                  dobj|it|help
# ...                          ...
# 17160343    CD|CARDINAL|CARDINAL
# 17160344        NN|budget|budget
# 17160346       advmod|once|bring
# 17160347               PRP|it|it
# 17160348             det|a|sauce
# 17160349          pobj|honey|for
# 17160350               aux|to|go
# 17160351                   .|.|.
# 17160352          aux|could|wait
# 17160354               PRP|me|me
# 17160355            VB|wait|wait
# 17160356                   .|?|?
# 17160357             PRP|you|you
# 17160359        NN|report|report
# 17160362             NNP|GPE|GPE
# 17160363           mark|that|ask
# 17160364            MD|will|will
# 17160365               VBD|be|be
# 17160366             NNP|ORG|ORG
# 17160367                   .|.|.
# 17160368          intj|no|PERSON
# 17160369                TO|to|to
# 17160370            intj|okay|be
# 17160371           nsubj|that|be
# 17160372                   .|.|.
# 17160373          NN|price|price
# 17160374            RB|sort|sort
# 17160375                   .|.|.
# 17160376             NNP|FAC|FAC
# 17160377          case|'s|PERSON
#
# [13530074 rows x 11 columns]

# %%
# -- VALIDATE --
# validate the last step (freq filtering) is successful.

head_count = data.head_text.value_counts()
print(len(head_count))
head_count
# Out:
# 142447
# .|.|.                           576174
# ,|,|,                           428302
# PRP|you|you                     310320
# PRP|i|i                         265113
# .|?|?                           252663
# DT|the|the                      205609
# VBZ|be|be                       180086
# NNP|PERSON|PERSON               146516
# TO|to|to                        146201
# VBP|be|be                       145453
# RB|not|not                      141320
# DT|a|a                          135013
# PRP|it|it                       132420
# CC|and|and                       92985
# WP|what|what                     79302
# IN|of|of                         78788
# PRP|we|we                        77222
# DT|that|that                     74381
# VBD|be|be                        60514
# IN|in|in                         57542
# PRP|me|me                        56727
# VBP|do|do                        53599
# nsubj|it|be                      53510
# DT|this|this                     52876
# IN|to|to                         52822
# .|!|!                            51969
# IN|for|for                       48300
# PRP|he|he                        47695
# PRP$|your|your                   45517
# VB|have|have                     45041
#                                  ...
# amod|exciting|time                   5
# pobj|knowledge|in                    5
# amod|new|furniture                   5
# dobj|relationship|pursue             5
# nsubj|you|stress                     5
# VBN|disgrace|disgrace                5
# conj|be|consider                     5
# intj|hey|lookin                      5
# pobj|cancer|for                      5
# advcl|come|complain                  5
# advmod|where|reach                   5
# det|all|mine                         5
# det|the|virgin                       5
# neg|not|sustain                      5
# intj|hey|hate                        5
# xcomp|help|will                      5
# compound|knock|off                   5
# advcl|happen|let                     5
# pobj|star|about                      5
# det|the|zodiac                       5
# NNS|aggressor|aggressor              5
# aux|come|run                         5
# VBZ|hunt|hunt                        5
# compound|tomb|vampire                5
# det|the|rebellion                    5
# NNP|Beer|Beer                        5
# JJ|whitelighter|whitelighter         5
# advcl|refuse|what                    5
# dobj|thee|take                       5
# dobj|concentration|have              5
# Name: head_text, Length: 142447, dtype: int64

# %% [markdown]
# ## Utilities for Matrix Multiplication
#
# This section defines common functions of MM.
#
# ### Note: Approximate Good Params
#
# The following params works well in general, regardless of variations:
#
# conf=20, factors=30, regularization=0.1, iterations=200
#
# We choose to not push too much on accuracy, and use same params for all variations. You can push quiet a lot on accuarcy by perform a grid search. We provide grid search code here.
#
# Acc record for each variations are recorded here (% on top 1 sentence retrival):
#
# * v1 (keep all): 28.975672759668893

# %%
# -- UTILITY BLOCK --

# -- process to coo matrix --
def to_coo(df, _obj_col, _feature_col):
    obj_cat = data[_obj_col].astype('category')
    feature_cat = data[_feature_col].astype('category')
#     df[_obj_col] = sent_cat
#     df[_feature_col] = feature_cat

    # create a sparse matrix of all the users/repos
    return (
        coo_matrix((np.ones(df.shape[0]), (feature_cat.cat.codes.copy(), obj_cat.cat.codes.copy()))),
        obj_cat, feature_cat,
    )

# Perform training and optional testing.
# optimal: {'factors': 27, 'regularization': 0.1, 'iterations': 200, 'model': als, 'confidence': 30}
def get_train(df, top_n=1, random_state = 28145037, report_test_acc=False,
              conf=30, factors=27, regularization=0.1, iterations=200):
    _obj_col='sent_id'
    _feature_col='head_text'
    
    obj_cat = df[_obj_col].astype('category')
    feature_cat = df[_feature_col].astype('category')
#     data[_obj_col] = sent_cat
#     data[_feature_col] = feature_cat

    # build coo matrix
    coo = coo_matrix((np.ones(df.shape[0]), (feature_cat.cat.codes.copy(), obj_cat.cat.codes.copy())))
    print(repr(coo))  # for manual sanity check

    # sanity check for accuracy
    if report_test_acc:
        print('--SANITY: Validate accuracy --')
        np.random.seed(random_state)
        train_csr, test_csr = train_test_split(coo, train_percentage=0.7)
        train_csr, test_csr

        _als = implicit.als.AlternatingLeastSquares(factors=factors,
                                                    regularization=regularization, iterations=iterations)
        _als.fit(train_csr * conf)
        prec = precision_at_k(_als, train_csr.T, test_csr.T, K=top_n)
        print('Sent prec: {}', prec*100)
    
    # train include all data, return the model and categories
    print('--TRAIN: train on complete matrix --')
    _als = implicit.als.AlternatingLeastSquares(factors=factors,
                                                regularization=regularization, iterations=iterations)
    _als.fit(coo * conf)
    return _als, obj_cat, feature_cat


# Build refer maps for sentences.
def build_maps(df):
    sent_map = dict(enumerate(df['sent_id'].astype('category').cat.categories))
    # key: sentence id. value: category id of sentence(what the MM model indexing).
    inv_sent_map = {r: i for i, r in sent_map.items()}
    print(len(inv_sent_map), len(sent_map))
    return sent_map, inv_sent_map

# %%
# -- PARAMETER SEARCH --
# NOTE: we did not perform a full scale parameter search due to our hardwares.
# We only found the params that are about right. You can play around to get more accurate model.

# this is for link to GPU. GPU build has to perform locally. Check on implicit repo for details.
# NOTE: we did not made this work due to hardware condition.
# GPU version is not validated by us, use by your own risk.
# sys.path.insert(0, '/home/kits-adm/Workspace/play/dodgson_play/implicit_local') 

# -- perform an approximately grid search --
# Warning: this this a pretty complete search, cost a lot of times (several days on dencent GPU) 
# _searches = {'factors': [10, 20, 30, 40, 50, 80, 120],
#              'regularization': [0.0, 1e-5, 1e-3, 1e-1, 1e1, 1e2],
#              'iterations': [1, 10, 15, 50, 100, 500, 1000, 3000],
#              'model': [implicit.als.AlternatingLeastSquares, implicit.bpr.BayesianPersonalizedRanking],
#              'confidence': [1, 2, 3, 4, 5, 10, 20],
#             }

# best guess
# this paramters are in general works well for implicit, regardless of dataset
# We recommand to use it if you running out of patience for the last one.
_searches = {'factors': [27, 30, 33, 36],
             'regularization': [0.0, 1e-3, 1e-1],
             'iterations': [200, 500,],
             'model': [implicit.als.AlternatingLeastSquares],
             'confidence': [10, 20, 30],
            }

# best guess with gpu (factor by 32)
# however we did not made this work due to py37 is not compatable with GPU version LoL, you can try it, should be fast)
# also a note here: The testing may actually takes longer than training due to on CPU, so...this may not be useful after all 
# _searches = {'factors': [32, 64, 96],
#              'regularization': [0.0, 1e-5, 1e-3, 1e-1, 1e1, 1e2],
#              'iterations': [500,],
#              'model': [implicit.als.AlternatingLeastSquares],
#              'confidence': [10, 20, 30],
#              'use_gpu': [True,],
#             }

# fixed to a specific value
# _searches = {'factors': [24,],
#              'regularization': [0.01,],
#              'iterations': [500,],
#              'model': [implicit.als.AlternatingLeastSquares],
#              'confidence': [20,],
#             }

def grid_search(train_csr, test_csr, param_grid, top_k=10):
    best = {
        'prec': None, 'mprec': None, 'params': None, 'model': None,
    }  # mprec, param, model

    keys, values = zip(*param_grid.items())
    for v in itertools.product(*values):
        params = dict(zip(keys, v))
        print('--------')
        print(params)

        # setup model
        _base_model = params.pop('model')
        _model_init = deepcopy(_base_model)
        _conf_magnify = params.pop('confidence')
        _model = _model_init(**params)
        print(_model)

        # train
        seed()
        _model.fit(train_csr * _conf_magnify)
        prec = precision_at_k(_model, train_csr.T, test_csr.T, K=top_k)
#         mprec = mean_average_precision_at_k(_model, train_csr.T, test_csr.T, K=top_k)

        print(prec)
#         print(mprec)
        if (best['prec'] is None) or prec > best['prec']:
            best['prec'] = prec
#             best['mprec'] = mprec
            best['params'] = params
            best['model'] = _model
            print('...New Best...')
    print('--COMPLETE--')
    return best

# def 
# best_models = {}
# for top_k in [1]: #, 10, 100, 1000]:
#     print('-- start {} --'.format(top_k))
#     best = grid_search(train_csr, test_csr,
#                        _searches, top_k=top_k,)
#     best_models[top_k] = best

# usage:
def search_all(df, random_state=3262832):
    _obj_col='sent_id'
    _feature_col='head_text'
    
    obj_cat = df[_obj_col].astype('category')
    feature_cat = df[_feature_col].astype('category')

    # build coo matrix
    coo = coo_matrix((np.ones(df.shape[0]), (feature_cat.cat.codes.copy(), obj_cat.cat.codes.copy())))
    print(repr(coo))  # for manual sanity check

    # sanity check for accuracy
    print('--SANITY: Validate accuracy --')
    np.random.seed(random_state)
    train_csr, test_csr = train_test_split(coo, train_percentage=0.7)
    best = grid_search(train_csr, test_csr, _searches, top_k=100,)

# search_all(data)

# %% [markdown]
# ## Utilities for model inspection
#
# ### Why
#
# The model requires to be manually inspected. This is due to in semi-supervised setting, accuracy may not be an good indicator of learning, due to:
#
# * model accuracy depends on how data setup. Due to it indicate roughly: "how well the model is guessing the data correctly".
# * How data should be setup is exactly what we want to investigate. Therefore based on the last point, the question is circular and can not be solved. Only thing we can do is to manually inspect it.
#
# In addition, the inspection want to answer all of the following question:
#
# * How good is each variations of the model learning? In details, what exactly does it learn? To take apart this question, in details, we want to ask:
#     * What exactly does the variations of the model care about? Is it sentence structure (syntactic), content (sematic), or something else?
#     * If it is learning something useful, how does it help us normalize data?
#     * How well is the variation of the model learning, for whatever it is learning?
# * In terms of clustering, what is the optimal sum of determine if it should be centrality?
#     * Can median / avg be an good indicator for centrality?
# * In terms of the sentence characteristic (simple vs complex sentence, special structure or meanings...) what does sum / avg be good at indicate them?
# * What exactly determine a good ranking, or a good confidence value? E.g., if sentence 1 against sentence 2 has confidence of 0.8, and rank 90, what does it mean?
#
#
# ### What
#
# The inspection code follows procedure:
#
# * random draw n=40 (called sample_n) sentences from dataset.
# * for each drawed sentences, retrive t=10,000 (called top_n) top ranked result against the sentence. Keep confidence and rank value.
# * manual inspect (program print out) some samples of the ranked sentences:
#     * Sentence will be sampled by rank ranges, for each range random draw 2 samples from them:
#         * [R1] 1-10
#         * [R2] 10-20
#         * [R3] 20-30
#         * [R4] 30-60
#         * [R5] 60-120
#         * [R6] 120-300
#         * [R7] 300-600
#         * [R8] 600-1000
#         * [R9] 1000-4000
# * In addition, all drawed sentence will be print out by its average and sum of top 10,000 value, this value is changeable, we call the value accepable_rank. (Note: the value can not be bigger than 10,000 due to it is based on the last calcuated result).

# %%
# --dialogs data need to be loaded --

dialogs = pd.read_csv('all_dialogs.csv')
dialogs
# Out:
#              show_id      char_name char_id  \
# 0          DoctorWho  FOURTH DOCTOR   l8653
# 1          DoctorWho  FOURTH DOCTOR   l8653
# 2          DoctorWho  FOURTH DOCTOR   l8653
# 3          DoctorWho  FOURTH DOCTOR   l8653
# 4          DoctorWho  FOURTH DOCTOR   l8653
# 5          DoctorWho  FOURTH DOCTOR   l8653
# 6          DoctorWho  FOURTH DOCTOR   l8653
# 7          DoctorWho  FOURTH DOCTOR   l8653
# 8          DoctorWho  FOURTH DOCTOR   l8653
# 9          DoctorWho  FOURTH DOCTOR   l8653
# 10         DoctorWho  FOURTH DOCTOR   l8653
# 11         DoctorWho  FOURTH DOCTOR   l8653
# 12         DoctorWho  FOURTH DOCTOR   l8653
# 13         DoctorWho  FOURTH DOCTOR   l8653
# 14         DoctorWho  FOURTH DOCTOR   l8653
# 15         DoctorWho  FOURTH DOCTOR   l8653
# 16         DoctorWho  FOURTH DOCTOR   l8653
# 17         DoctorWho  FOURTH DOCTOR   l8653
# 18         DoctorWho  FOURTH DOCTOR   l8653
# 19         DoctorWho  FOURTH DOCTOR   l8653
# 20         DoctorWho  FOURTH DOCTOR   l8653
# 21         DoctorWho  FOURTH DOCTOR   l8653
# 22         DoctorWho  FOURTH DOCTOR   l8653
# 23         DoctorWho  FOURTH DOCTOR   l8653
# 24         DoctorWho  FOURTH DOCTOR   l8653
# 25         DoctorWho  FOURTH DOCTOR   l8653
# 26         DoctorWho  FOURTH DOCTOR   l8653
# 27         DoctorWho  FOURTH DOCTOR   l8653
# 28         DoctorWho  FOURTH DOCTOR   l8653
# 29         DoctorWho  FOURTH DOCTOR   l8653
# ...              ...            ...     ...
# 1073014  QueerAsFolk          DAVID  l22351
# 1073015  QueerAsFolk          DAVID  l22351
# 1073016  QueerAsFolk          DAVID  l22351
# 1073017  QueerAsFolk          DAVID  l22351
# 1073018  QueerAsFolk          DAVID  l22351
# 1073019  QueerAsFolk          DAVID  l22351
# 1073020  QueerAsFolk          DAVID  l22351
# 1073021  QueerAsFolk          DAVID  l22351
# 1073022  QueerAsFolk          DAVID  l22351
# 1073023  QueerAsFolk          DAVID  l22351
# 1073024  QueerAsFolk          DAVID  l22351
# 1073025  QueerAsFolk          DAVID  l22351
# 1073026  QueerAsFolk          DAVID  l22351
# 1073027  QueerAsFolk          DAVID  l22351
# 1073028  QueerAsFolk          DAVID  l22351
# 1073029  QueerAsFolk          DAVID  l22351
# 1073030  QueerAsFolk          DAVID  l22351
# 1073031  QueerAsFolk          DAVID  l22351
# 1073032  QueerAsFolk          DAVID  l22351
# 1073033  QueerAsFolk          DAVID  l22351
# 1073034  QueerAsFolk          DAVID  l22351
# 1073035  QueerAsFolk          DAVID  l22351
# 1073036  QueerAsFolk          DAVID  l22351
# 1073037  QueerAsFolk          DAVID  l22351
# 1073038  QueerAsFolk          DAVID  l22351
# 1073039  QueerAsFolk          DAVID  l22351
# 1073040  QueerAsFolk          DAVID  l22351
# 1073041  QueerAsFolk          DAVID  l22351
# 1073042  QueerAsFolk          DAVID  l22351
# 1073043  QueerAsFolk          DAVID  l22351
#
#                                                       dia1  \
# 0        Get me the medical officer. Lieutenant Sulliva...
# 1          It's something that happened when we first met.
# 2                                   This the patient, sir?
# 3        There you are. Now come along, Doctor, you're ...
# 4        No, I do not mean the infirmary. I mean the si...
# 5        No, Doctor, I'm the doctor and I say that you'...
# 6                        Look here, Doctor. You're not fit
# 7                  I say, I don't think that can be right.
# 8                                                  Well, I
# 9                               Well, I really don't know.
# 10       There is absolutely no question of you leaving...
# 11                                                 Doctor!
# 12                           No, no, Doctor. You can't go.
# 13             What? Oh, yes, of course. Depending on you.
# 14       And I mean, you are still UNIT's scientific ad...
# 15                                              Thank you.
# 16                                                   What?
# 17                                   Very well, thank you.
# 18                                        He promised he'd
# 19                                         You've changed.
# 20       No, I didn't mean your face, I meant your clot...
# 21         UNIT is supposed to be a security organisation.
# 22                                     It's just possible.
# 23       Much better, Doctor. Now, if you've quite fini...
# 24          No, let's settle for that, please. Now, Doctor
# 25                                                    Off?
# 26             The thing is, there's been another robbery.
# 27       Millions of volts running through the wretched...
# 28       Doctor, I have every respect for your concern ...
# 29                      Well, I suppose it was stepped on.
# ...                                                    ...
# 1073014  You didn't tell me the moving men were comingt...
# 1073015                 I better finishedpackin' my stuff.
# 1073016  But I don't know...I don't know what's an"S" a...
# 1073017                Whendid we-when did we get a place?
# 1073018                            Why didn't you tell me?
# 1073019  Sounds great. Um...look, I'm gonna go pick upt...
# 1073020  Oh. Oh. Well, okay. Well, then, I'm gonna call...
# 1073021                        Is there anything I can do?
# 1073022                                      David! David!
# 1073023  Where's my plaid flannel? It used to be righth...
# 1073024  What am I supposed towear to Emmett's party? Y...
# 1073025                                            Thanks.
# 1073026        WhatI need is...somebody who listens to me.
# 1073027  Well, to think about... what I'm gonna do when...
# 1073028  W-well, I...I thought that, um...you know, may...
# 1073029                                   Oh, I can do it.
# 1073030  Well, I used to help my mom put on the screend...
# 1073031  It's supposed to be the Great Northwest, Ma.Ma...
# 1073032                                  David! Uncle Vic!
# 1073033                                              What?
# 1073034                            Why didn't you tell me?
# 1073035                                     Obviously not.
# 1073036                 You have to doeverything yourself!
# 1073037                        You think it's a good idea.
# 1073038  you'll behappy to know this time it's not abou...
# 1073039                     I can take you to the airport.
# 1073040                      Okay, fine, have it your way.
# 1073041        That's not what I was gonna say. I'm sorry.
# 1073042                             I know I don't, but...
# 1073043  Well, I appreciate that, but that's...that's n...
#
#                                                       dia2
# 0                                           Human history.
# 1        I tell you, Brigadier, there's nothing to worr...
# 2        And stupid. If the square on the hypotenuse eq...
# 3                      Am I? Don't you mean the infirmary?
# 4                                 Not fit? I'm the Doctor.
# 5        You may be a doctor, but I'm the Doctor. The d...
# 6        Not fit? Not fit? Of course I'm fit. All syste...
# 7                               Both a bit fast, are they?
# 8        Still, must be patient. A new body's like a ne...
# 9        Well, of course you don't. Why should you? You...
# 10                               How can I prove my point?
# 11       Hello. Come to see me off, have you? Well, I h...
# 12            Can't? Can't? There's no such word as can't.
# 13                                               What for?
# 14                                       Can't I? Goodbye.
# 15                                              Excuse me.
# 16       Haven't me met somewhere before? No, don't tel...
# 17       And Sarah Jane. Well now, isn't this nice? Wha...
# 18                                          Ah, Brigadier.
# 19                                      Oh, no, not again.
# 20                                    Don't you like them?
# 21                 Do you think I might attract attention?
# 22                                             One moment.
# 23                             I'll try again if you like.
# 24                                       Time we were off.
# 25                        To visit the scene of the crime.
# 26       Tell me on the way, Brigadier. Tell me on the ...
# 27                       Oh, but I am, I assure you. Look.
# 28        Not just squashed, flattened. Almost pulverised.
# 29       Exactly. And according to my estimation of the...
# ...                                                    ...
# 1073014                               Oh, I thought I did.
# 1073015                           No, it's okay. I did it.
# 1073016  Captain Astro, robots, comic books are a"P." C...
# 1073017                 I rented a house. On the internet.
# 1073018  Well, there just wasn't time. I mean, we would...
# 1073019                               Nope, don't have to.
# 1073020                            No need. Ibooked a car.
# 1073021  Uh, yeah, you can...stand there and lookgorgeous.
# 1073022                                        What is it?
# 1073023                               Oh, oh, I packed it.
# 1073024                                              Here.
# 1073025  You'll look good in that. That's too small on ...
# 1073026                                              What?
# 1073027                            Okay, let's discuss it.
# 1073028  Oh, I just remembered I told the people who ar...
# 1073029             No, that's okay. I'll take care of it.
# 1073030       It's okay. I'm good with my hands, remember?
# 1073031    All we need now is a bear to sh1t in the woods.
# 1073032                           Oh, okay. Just a second.
# 1073033      I said I changed the reservation until tomo--
# 1073034                              Well, does it matter?
# 1073035  Well, Michael, it's just a little change of pl...
# 1073036                                   I just thought--
# 1073037  For Christ sakes, Michael, what do you want me...
# 1073038                     The car'll be here any minute.
# 1073039         I know you can, but I'd rather you didn't.
# 1073040                               The way I always do?
# 1073041  How many times have I told you you don't have ...
# 1073042  Aside from that...I'm the one that should beap...
# 1073043  Well, I hope you'll decide to change your mind...
#
# [1073044 rows x 5 columns]

# %%
import random

class ModelInspection:
    RANKS = [1, 10, 20, 30, 60, 120, 300, 600, 1000, 4000, 10000]
    CONFS = np.flip(np.arange(-2.0, 2.0, 0.3))
#     ALLOW_SORTING = {'mean', 'median', 'sum'}

    def __init__(self, model, sent_map, invert_sent_map, dialog_df, top_n=100):
        self.model = model
        self.sent_map = sent_map  # key: sent cat, value: sent id
        self.inv_map = invert_sent_map  # invert key value for sent_map.
        assert len(self.sent_map) == len(self.inv_map)  # should equal due to sent cat are unique
        # can not be smaller than max range, otherwise range can not be fetched.
        assert top_n <= self.RANKS[-1]
        self.top_n = top_n
        self.dialog_df = dialog_df
        # store computed results before ranking.
        self._res = {}  # key: sentence id; value: array of ranks, confs, sents. 

    def compute(self, sample_n=40, random_state=19374, overwrite=False):
        """Draw n samples and compute top_n ranking data, save to class before ranking.
        """
        if not overwrite:  # not allow to overwrite last results
            assert not self._res
        self._res = {}
        # cost some memory to store, maybe not a good idea to be bigger than that
        assert sample_n < 1000
        # draw n samples
        random.seed(random_state)
        for s_cat in random.sample(self.sent_map.keys(), sample_n):
            self._res[self.sent_map[s_cat]] = self._query_sent(s_cat)
        print('FINISH COMPUTE...')

    def _query_sent(self, sent_cat):
        """Query most simular sentences to the sentence category by learned matrix multiplication model.

        Params:
            sent_cat: sent cateogry id.
            model: learned implicit MM model.
            top: limites to n top rank of each sentence (more than the rank will be ignored).
            bounds: list of sentence id, boudary of candidates to be considered (other sentences will be ignored).

        Return:
            Array consists of three elements:
                numpy array of sentence ids in acending ranking order (or conf order, the same).
                numpy array of ranks (to sent ids).
                numpy array of confidence value (to sent ids).
        """
        _sims = self.model.similar_users(sent_cat, N=self.top_n)
#         _scale = None
        _rank = 0
        ranks = []
        confs = []
        sents = []
        for scat, conf in _sims:
            _rank += 1
            if scat == sent_cat:  # itself
                continue
            ranks.append(_rank)
            confs.append(conf)
            sents.append(self.sent_map[scat])
#             if fid in bounds:
#                 res.append(sent_cat, conf, bounds[fid], _rank,))
        return [np.array(sents), np.array(ranks), np.array(confs)]

    def _retrive_dialog(self, sid):
#         print(type(self.dialog_df.iloc[sid].dia1))
#         print(sid)
        return [self.dialog_df.loc[sid].dia1, self.dialog_df.loc[sid].dia2]

    def inspect_by_rank(self, smaller=None, random_state=82628):
#         # NOTE: sort_on in this case has SAME order of results for mean and sum, due to fixed size on rank.
#         assert sort_on in ALLOW_SORTING
        if smaller is None:
            smaller = self.top_n  # by default using biggest range.
        assert smaller >= self.top_n
        # -- first compute sorting order --
        _sort_res = {}  # key: sent id. Value: sum.
        _order = []  # list of sorted
        for sent_id, payload in self._res.items():
            _sort_res[sent_id] = payload[2][:smaller].mean()
        for sid in sorted(_sort_res, key=_sort_res.get, reverse=True):
            _order.append(sid)
        # -- report sentence on ranges --
        random.seed(random_state)
        for o, sid in enumerate(_order):
            # summary
            print()
            print('----------SENT {} @{}---------'.format(sid, o))
            print('TEXT: |{}|'.format(self._retrive_dialog(sid)))
            print('MEAN CONF TOP{}: {}'.format(self.top_n, _sort_res[sid]))
            # ranges
            _last_range = 0
            payload = self._res[sid]
            _confs = payload[2]
            _ranks = payload[1]
            _sents = payload[0]
            for ir, r in enumerate(self.RANKS):
                if r > self.top_n:
                    break
                range_confs = _confs[_last_range:r]
                print()
                if not len(range_confs):
                    print('-- {} range D{} {}-{} is empty'.format(sid, ir, _last_range, r))
                    continue
                print('-- {} range D{} {}-{}, mean conf: {}--'.format(sid, ir, _last_range, r, range_confs.mean()))
                # random sample one and print out.
                sampled_index = random.sample(list(range(_last_range, r)), 1)[0]
                print('rank {}, conf: {}'.format(_ranks[sampled_index], _confs[sampled_index]))
                print('sent {}: |{}|'.format(_sents[sampled_index], self._retrive_dialog(_sents[sampled_index])))
                _last_range = r

# %% [markdown]
# ## Variation V1: Keep ALL
#
# For all above data. keep all variation.
#
# Full filtering manifest:
#
# For DEP (syntactic dependency):
# * No punct dependency.
# * No ROOT.
#
# For POS (senmatic token): Keep All.
#
# Conclusions:
# * If accepatable: Yes but not ideal.
# * top 30 is accepable, and more than 0.6 conf.
#
# Hypothesis of conclusions:
# * either too much (complex grammer struct) or too little (low frequency head got removed) sythatic head would not lead to accurate prediction of likelyness.

# %%
my_model, SENT_CATS, FEATURE_CATS = get_train(data, report_test_acc=False)
# Out:
# <142447x929612 sparse matrix of type '<class 'numpy.float64'>'
# 	with 13530074 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [06:46<00:00,  2.23s/it]

# %%
SENT_MAP, INV_SENT_MAP = build_maps(data)
# Out:
# 929612 929612

# %%
mi = ModelInspection(my_model, SENT_MAP, INV_SENT_MAP, dialog_df=dialogs, top_n=1000)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 291092 @0---------
# TEXT: |["Agent Booth? I'm, uh, Jimmy Walpert. I'm sorry that I wasn't here, but I-I got a bit sick.", "Well, that's no surprise there."]|
# MEAN CONF TOP1000: 1.3065152168273926
#
# -- 291092 range D0 0-1, mean conf: 1.5529706478118896--
# rank 2, conf: 1.5529706478118896
# sent 332133: |["No, no, it's just that it's getting late...", "Hey, hey, it's fine. It's totally fine. We've got plenty of margaritas. It's all good."]|
#
# -- 291092 range D1 1-10, mean conf: 1.4870613813400269--
# rank 5, conf: 1.4965108633041382
# sent 519378: |['Well, why are you surprised? ... now that we got ourselves a vampire.', "Just because he's a vampire doesn't mean he's a murderer!"]|
#
# -- 291092 range D2 10-20, mean conf: 1.4501526355743408--
# rank 21, conf: 1.4402787685394287
# sent 980941: |["Ohh. No, it's just that I'm really tired and\x97", "Yeah, cool. That's\x97tired."]|
#
# -- 291092 range D3 20-30, mean conf: 1.4315941333770752--
# rank 31, conf: 1.4233970642089844
# sent 851722: |["Oh, that's very sweet, but I'm actually getting married on Saturday.", 'Friday night?']|
#
# -- 291092 range D4 30-60, mean conf: 1.4081472158432007--
# rank 37, conf: 1.4164111614227295
# sent 15411: |["I can do that. I'm not just a mum here, you know.", "Thank you, Nancy. Jo, make up the paste from that fungus powder and apply it to the green stain on Cliff's neck."]|
#
# -- 291092 range D5 60-120, mean conf: 1.3796836137771606--
# rank 70, conf: 1.3895446062088013
# sent 784402: |['Oh yea, I did. I was uh, just a little....', 'Shaken up.']|
#
# -- 291092 range D6 120-300, mean conf: 1.3430434465408325--
# rank 174, conf: 1.352192759513855
# sent 1004359: |['But we just got married.', "Well obviously that was a mistake. You need to forget about Arnie. The important thing is you're moving on."]|
#
# -- 291092 range D7 300-600, mean conf: 1.299696683883667--
# rank 335, conf: 1.314713716506958
# sent 204474: |["Actually, I'm still alive, so technically it's vivisection.", 'No one likes a know-it-all.']|
#
# -- 291092 range D8 600-1000, mean conf: 1.2650939226150513--
# rank 935, conf: 1.254542350769043
# sent 810477: |["Ok fine, three hints. One! When you are getting colder, you're really getting warmer.", 'The fridge.']|
#
# ----------SENT 928397 @1---------
# TEXT: |["You know, I'm with you on Marks, Jax. But I don't know how much longer I'm gonna be able to keep playing double agent.", 'Niners are the only ones that can get us close to Marks so we can get Bobby back.']|
# MEAN CONF TOP1000: 1.2687034606933594
#
# -- 928397 range D0 0-1, mean conf: 1.8470147848129272--
# rank 2, conf: 1.8470147848129272
# sent 924606: |["For every 24 hours August has to wait, he's gonna cut off another part of your guy. I mean, I'm with you, but I don't know how much longer I'm gonna be able to keep playing double agent.", 'Jesus.']|
#
# -- 928397 range D1 1-10, mean conf: 1.50613272190094--
# rank 5, conf: 1.5076359510421753
# sent 194072: |["Dad, I know you think you're happy now, but it's not gonna last forever.", 'Everything lasts forever.']|
#
# -- 928397 range D2 10-20, mean conf: 1.4542404413223267--
# rank 14, conf: 1.458958387374878
# sent 621199: |["You know, I'm really trying not to be disappointed.", 'Join the club.']|
#
# -- 928397 range D3 20-30, mean conf: 1.4302419424057007--
# rank 26, conf: 1.42994225025177
# sent 974531: |["My fault for the coagulation. I just didn't know that everybody was gonna be here and--", 'Or that pacey was cooking. Right. Who could have guessed?']|
#
# -- 928397 range D4 30-60, mean conf: 1.4033347368240356--
# rank 46, conf: 1.4057962894439697
# sent 493626: |["Emma, I know you're still angry, but avoiding us is not going to help.", "I'm not avoiding you. With Henry's life on the line, I need to be around people I trust, and right now, that's not you."]|
#
# -- 928397 range D5 60-120, mean conf: 1.366943120956421--
# rank 109, conf: 1.3562928438186646
# sent 1045908: |["I don't even know if this is gonna work.", 'Concentrate... because it has to.']|
#
# -- 928397 range D6 120-300, mean conf: 1.313915491104126--
# rank 124, conf: 1.3491367101669312
# sent 159328: |["I think there was a grain of truth in all of it. Every time you've been affected by red Kryptonite, it hasn't changed who you are. It's just stripped away your inhibitions. I think you need to start being more honest about how you feel.", "So ... you're saying that I want to kiss Lois and keep Chloe in my back pocket while the whole time I'm still in love with Lana?"]|
#
# -- 928397 range D7 300-600, mean conf: 1.2593649625778198--
# rank 317, conf: 1.284674882888794
# sent 952720: |["You don't know how to sail boats.", 'This would be more like, you know, peeling potatoes, washing dishes.']|
#
# -- 928397 range D8 600-1000, mean conf: 1.214929461479187--
# rank 841, conf: 1.2110741138458252
# sent 25782: |['Oh aye. I can be useful too, you know.', "Jamie, I hadn't thought about you."]|
#
# ----------SENT 364188 @2---------
# TEXT: |['How-how I like to melt stuff, and how I dislike stuff that doesn’t melt.', 'Right, okay, um-mm.']|
# MEAN CONF TOP1000: 1.1498936414718628
#
# -- 364188 range D0 0-1, mean conf: 1.3887825012207031--
# rank 2, conf: 1.3887825012207031
# sent 962442: |["But you don't like scary stuff.", 'I have a contradicting personality. Please continue.']|
#
# -- 364188 range D1 1-10, mean conf: 1.3311561346054077--
# rank 4, conf: 1.3476420640945435
# sent 996254: |[": I don't know, but I don't like it.", "Look at this guy, he's like a cat burglar. He thinks if he goes through real slow the machine won't detect him."]|
#
# -- 364188 range D2 10-20, mean conf: 1.288466215133667--
# rank 21, conf: 1.2780203819274902
# sent 646017: |["No offense, but I don't want you touching me in any way. It's no secret that I don't like people much, and I like doctors even less.", "That's funny, I thought most doctors were people."]|
#
# -- 364188 range D3 20-30, mean conf: 1.2672092914581299--
# rank 31, conf: 1.2611218690872192
# sent 145799: |["Yeah, but you don't like people.", "I love people. I'm a people person. I'm just a normal teenage girl going on a normal school field trip."]|
#
# -- 364188 range D4 30-60, mean conf: 1.2468878030776978--
# rank 43, conf: 1.2493205070495605
# sent 1052981: |["No, I'm sick and tired of focusing on everything but us. I feel like I'm going through this whole pregnancy thing by myself and I do not like it.", 'Well, what am I supposed to do? I have a job.']|
#
# -- 364188 range D5 60-120, mean conf: 1.2170387506484985--
# rank 119, conf: 1.2053618431091309
# sent 993106: |["Well... now I know this sounds touristy, but I'd just love to go on one of those five-hour boat rides around Manhattan.", 'Yeah, we could do that...why not, why not.']|
#
# -- 364188 range D6 120-300, mean conf: 1.179103970527649--
# rank 282, conf: 1.1650371551513672
# sent 718959: |["With everything that's going on, finals and all your personal stuff, I didn't want you worrying.", "But Grandpa's money -"]|
#
# -- 364188 range D7 300-600, mean conf: 1.1455192565917969--
# rank 496, conf: 1.1393884420394897
# sent 760217: |['I do like guacamole.', "And it's only 35 miles south of San Francisco -- just a straight shot up the 101."]|
#
# -- 364188 range D8 600-1000, mean conf: 1.1115148067474365--
# rank 722, conf: 1.117303729057312
# sent 663105: |['Thanks. I really mean that.', 'You wanted to see me?']|
#
# ----------SENT 43012 @3---------
# TEXT: |['You are welcome, welcome indeed. Though we know you only as a record in our charts of space and time, yet you seem to us like an old friend.', "Well, that's very kind of you to make me feel so welcome."]|
# MEAN CONF TOP1000: 1.0995197296142578
#
# -- 43012 range D0 0-1, mean conf: 1.325918197631836--
# rank 2, conf: 1.325918197631836
# sent 291122: |['When someone lies with this sort of ease in their professional relationships, chances are they lie at least as much in their personal relationships.', 'Well, maybe she just lied to the wrong person.']|
#
# -- 43012 range D1 1-10, mean conf: 1.2916444540023804--
# rank 5, conf: 1.2962154150009155
# sent 576834: |["I know that. But I've never known Spock to act like a pal under any circumstances, least of all toward Klingons.", "That's true."]|
#
# -- 43012 range D2 10-20, mean conf: 1.246870994567871--
# rank 15, conf: 1.2532082796096802
# sent 953591: |['look Jimmy an I view the lighthouse as a chance ta restore the restaurant to its former glory you know its-its jus somethin from Newport for Newport', 'we think it can be a bit of both, an icon of the past...a beacon for the future']|
#
# -- 43012 range D3 20-30, mean conf: 1.2297343015670776--
# rank 30, conf: 1.2253293991088867
# sent 654359: |["Relax. I'm not going to offer the Perseids anything. If I did, I'd be making the opposition's case for them. They say that we're no better than the Nietzscheans, and they'd be right. We have to make the Perseids see that not all humans are consumed by greed for money, power, and control.", 'And how do we do that?']|
#
# -- 43012 range D4 30-60, mean conf: 1.20659339427948--
# rank 43, conf: 1.2090895175933838
# sent 287574: |["I know, I just don't agree with the social convention which requires us to attend a day long grieving ritual simply because the deceased worked at the Jeffersonian.", 'Try not to say "the deceased."']|
#
# -- 43012 range D5 60-120, mean conf: 1.1791824102401733--
# rank 86, conf: 1.1823313236236572
# sent 605972: |["Look, I know how much you miss the Enterprise, but I'm sure they'll be building a new one soon.", 'It will not be the same. The Enterprise I knew is gone. Those were good years, but now it is time for me to move on.']|
#
# -- 43012 range D6 120-300, mean conf: 1.1330418586730957--
# rank 203, conf: 1.1336290836334229
# sent 61230: |["Might not be connected, but we've noticed a surge of unusual injuries being reported at the A&E unit.", "Chunks taken out of legs and arms. Deep wounds to backs and stomachs. So we have a wave of Weevil attacks to add to our problems. Oh, and by the way, that spray we've used on them previously, looks like they're becoming immune to it."]|
#
# -- 43012 range D7 300-600, mean conf: 1.0904213190078735--
# rank 359, conf: 1.1017402410507202
# sent 166788: |['You know, I asked her out ... not on a date ... before I knew our bomber was an innocent man.', "Toyman's back."]|
#
# -- 43012 range D8 600-1000, mean conf: 1.0593498945236206--
# rank 830, conf: 1.057164192199707
# sent 1042556: |['Yeah, you almost exposed our magic to a room full of people.', "No, listen. I studied the I-ching, tarot cards, runes and tea leaves and they're all giving me the same reading."]|
#
# ----------SENT 589603 @4---------
# TEXT: |["My superintendent was a Betazoid, a full telepath. When he sent for you to his office, he didn't have to ask what you'd done.", "You got called into the superintendent's office? That's a story I'd like to hear."]|
# MEAN CONF TOP1000: 1.094872236251831
#
# -- 589603 range D0 0-1, mean conf: 1.3188846111297607--
# rank 2, conf: 1.3188846111297607
# sent 896615: |['Howard, I’ve asked you not to do that.', 'Lesley and I do research together at the University.']|
#
# -- 589603 range D1 1-10, mean conf: 1.2726399898529053--
# rank 3, conf: 1.313138723373413
# sent 930674: |["An eager prosecutor could sell that she conspired to meet with him, then brought the cross with knowledge of what he'd do.", 'sh1t.']|
#
# -- 589603 range D2 10-20, mean conf: 1.232649564743042--
# rank 15, conf: 1.2352194786071777
# sent 1053592: |["He's so innocent. If only he had any idea what mummy and Aunty Paige did today.", 'They turned a very bad man into a very big tree.']|
#
# -- 589603 range D3 20-30, mean conf: 1.2150112390518188--
# rank 27, conf: 1.2123647928237915
# sent 987141: |["He asked you to talk to me, didn't he?", 'no, n-no, he\x97']|
#
# -- 589603 range D4 30-60, mean conf: 1.195320963859558--
# rank 41, conf: 1.2008978128433228
# sent 486360: |['No! If I did, would I ask you to model full time? We want to do a whole line based on "zero is not a size." I mentioned the idea to Victoria, and she jumped on it so fast, you\'d think it was Julian\'s dad.', "I'm not a model."]|
#
# -- 589603 range D5 60-120, mean conf: 1.1670278310775757--
# rank 90, conf: 1.1659414768218994
# sent 657447: |['We did what had to be done.', "It's what didn't happen that's important. No one should have the capability of destroying a sun."]|
#
# -- 589603 range D6 120-300, mean conf: 1.1308528184890747--
# rank 227, conf: 1.127819299697876
# sent 1037472: |['Well, you have to do what you have to do.', "My god, Leo, can't you think of anything but yourself?"]|
#
# -- 589603 range D7 300-600, mean conf: 1.0889267921447754--
# rank 330, conf: 1.1049306392669678
# sent 1036336: |['Does this have anything to do with you asking Sheila to watch Wyatt? She just called.', "Yes, actually. But we don't have a lot of time. It's about Leo."]|
#
# -- 589603 range D8 600-1000, mean conf: 1.0536726713180542--
# rank 845, conf: 1.0495442152023315
# sent 641959: |['If Archer fails, his crew will have to answer for his crimes.', "We'll be executed. There's an old tradition. If someone saves the Emperor's life, it's said there's no request he can refuse them. Consider the possibilities. A medical facility of your own with unlimited resources. You could conduct experiments as you see fit."]|
#
# ----------SENT 957166 @5---------
# TEXT: |['Bang! Am I good or am I good?', "What do you think you're doing?"]|
# MEAN CONF TOP1000: 1.086531639099121
#
# -- 957166 range D0 0-1, mean conf: 1.2908843755722046--
# rank 2, conf: 1.2908843755722046
# sent 1049234: |["Either I'm that transparent or you're that good.", "Well, I don't think I'll comment since you do have hot liquid over my head."]|
#
# -- 957166 range D1 1-10, mean conf: 1.227843165397644--
# rank 5, conf: 1.229245901107788
# sent 1055153: |["Aren't you happy you became a mortal?", 'At least now we can grow old together like every other couple.']|
#
# -- 957166 range D2 10-20, mean conf: 1.1983791589736938--
# rank 21, conf: 1.1877723932266235
# sent 650611: |["Neelix, is it? You wouldn't be a fellow trader, would you?", 'What makes you say that.']|
#
# -- 957166 range D3 20-30, mean conf: 1.1806458234786987--
# rank 31, conf: 1.1780312061309814
# sent 530456: |["Well I'm not a nice person.", 'If you knew what she did you would understand.']|
#
# -- 957166 range D4 30-60, mean conf: 1.1631594896316528--
# rank 51, conf: 1.1589044332504272
# sent 642423: |["You are a stubborn lad, aren't you?", "Yeah. It's one of my more, say, charming qualities. Mind if I ask you a question?"]|
#
# -- 957166 range D5 60-120, mean conf: 1.1419177055358887--
# rank 91, conf: 1.1421862840652466
# sent 31998: |["I don't want this. I was doing my art. I was good at it, wasn't I?", 'Oh, you are sweet. Stupid, but sweet.']|
#
# -- 957166 range D6 120-300, mean conf: 1.1108909845352173--
# rank 123, conf: 1.1289308071136475
# sent 134875: |["You're... you're not mad?", "Work cannot stop, Mister Palmer, because my mother's nurse elects to abandon us on a Saturday morning. I applaud your initiative."]|
#
# -- 957166 range D7 300-600, mean conf: 1.0813955068588257--
# rank 408, conf: 1.0847573280334473
# sent 982930: |["Jennifer, Tyson has expressed an interest in helping out with the picture. Aren't you a little short-staffed?", 'Yeah, yeah, um, do you have any experience working on a film set before?']|
#
# -- 957166 range D8 600-1000, mean conf: 1.0564522743225098--
# rank 982, conf: 1.045446515083313
# sent 213401: |["Why won't you be art?!", 'Here he is. This is where the... "magic" happens.']|
#
# ----------SENT 149928 @6---------
# TEXT: |['And he bought it for eight hundred cash a couple weeks ago. Right. Bye.', "It's always business with you."]|
# MEAN CONF TOP1000: 1.071974754333496
#
# -- 149928 range D0 0-1, mean conf: 1.2173328399658203--
# rank 2, conf: 1.2173328399658203
# sent 607172: |["I don't know about that. Quark's on a roll. In the last month, he's won two hundred and six straight games.", 'Would you care to make a wager on the outcome?']|
#
# -- 149928 range D1 1-10, mean conf: 1.195109248161316--
# rank 5, conf: 1.202624797821045
# sent 623916: |["Captain, there's a spatial distortion heading towards us. Whatever it is, it's huge. Five light years across and it's expanding.", "Tracking it's origin. A vessel near the Zahl homeworld."]|
#
# -- 149928 range D2 10-20, mean conf: 1.1723897457122803--
# rank 13, conf: 1.17796790599823
# sent 409770: |['At least you got yourself a match for the chimney prints -- a Jonathan Wax, from Henderson, served four years for attempted rape and he was released six months ago.', 'Thank you.']|
#
# -- 149928 range D3 20-30, mean conf: 1.1583753824234009--
# rank 23, conf: 1.1598711013793945
# sent 404071: |['A license is 24 bucks. Hunting without one is a $1,000 fine and up to six months in jail.', "Whoa. Well, that's not worth the risk. Maybe he wasn't up here to hunt?"]|
#
# -- 149928 range D4 30-60, mean conf: 1.149436116218567--
# rank 36, conf: 1.152556300163269
# sent 646630: |["That's the problem. Two to three weeks.", "In two or three weeks, nanites may be all that's left of the Federation."]|
#
# -- 149928 range D5 60-120, mean conf: 1.130284070968628--
# rank 74, conf: 1.1370199918746948
# sent 35253: |['Six months ago.', 'Bit quick to get married.']|
#
# -- 149928 range D6 120-300, mean conf: 1.1052684783935547--
# rank 174, conf: 1.1121671199798584
# sent 569786: |['Thank you, Doctor McCoy. Moving on schedule into quadrant nine oh four. Beta Six is eight days distant.', 'Something, Mister Spock?']|
#
# -- 149928 range D7 300-600, mean conf: 1.0736536979675293--
# rank 304, conf: 1.0908501148223877
# sent 108710: |['Twenty four, twenty five.', 'Which was it? Twenty four or twenty five?']|
#
# -- 149928 range D8 600-1000, mean conf: 1.0332765579223633--
# rank 707, conf: 1.042031168937683
# sent 722318: |['He died two weeks ago in Oxford.', "Oh. Paris, I'm sorry. How?"]|
#
# ----------SENT 865307 @7---------
# TEXT: |["No, this is new. This trumps that. Freeways have exits. So do relationships. The first exit, my personal favorite, is six hours in. You meet, you talk, you have s*x, you exit when she's in the shower.", 'So every girl you have s*x with feels the immediate need to shower? Actually, yeah, I get that.']|
# MEAN CONF TOP1000: 1.0703680515289307
#
# -- 865307 range D0 0-1, mean conf: 1.311629056930542--
# rank 2, conf: 1.311629056930542
# sent 666096: |["Agent Vaughn has trouble sleeping when you're in the field.", 'I doubt he told you that.']|
#
# -- 865307 range D1 1-10, mean conf: 1.2541803121566772--
# rank 8, conf: 1.2511622905731201
# sent 170141: |["I wouldn't be here if it wasn't for you, Lex. Since you've been with her, she has a funny habit of getting hurt.", 'And how many times did she wind up in the hospital when she was dating you? Save yourself a trip next time, Clark. Just send flowers.']|
#
# -- 865307 range D2 10-20, mean conf: 1.2251685857772827--
# rank 18, conf: 1.2237939834594727
# sent 361359: |['Yeah, he’s really great though. He has this incredible zest for life, and he treats me like a queen, except at night when he treats me like the naughty girl I am.', 'Oh, by the way. Would it be okay if I gave the toast to mom and dad this year?']|
#
# -- 865307 range D3 20-30, mean conf: 1.2104523181915283--
# rank 26, conf: 1.211287021636963
# sent 1057510: |['Chris, protecting charges is what we do. Besides, when I was a Whitelighter I had other charges.', "Leo, I didn't come all the way from the future to protect and oversee other charges. I came for one reason and one reason only."]|
#
# -- 865307 range D4 30-60, mean conf: 1.179851770401001--
# rank 61, conf: 1.1662265062332153
# sent 85405: |["No chance. He's a liability, I'm not having him on board.", "We'd be dead without him."]|
#
# -- 865307 range D5 60-120, mean conf: 1.1487185955047607--
# rank 89, conf: 1.1518924236297607
# sent 207379: |['While you were out there daydreaming, this rain has ruined the house.', 'Marge, in a crisis like this, I need time for quiet contemplation.']|
#
# -- 865307 range D6 120-300, mean conf: 1.1027201414108276--
# rank 235, conf: 1.0934878587722778
# sent 632690: |['Commander, I understand that you had a parent who was in Starfleet.', 'Two of them, as a matter of fact. My father was an exozoologist, my mother a Command officer.']|
#
# -- 865307 range D7 300-600, mean conf: 1.0620148181915283--
# rank 411, conf: 1.0656296014785767
# sent 327431: |['I bet he sensed that I was ready to have s*x with another guy.', 'Well, umm, why don’t you give him a call?']|
#
# -- 865307 range D8 600-1000, mean conf: 1.0298985242843628--
# rank 877, conf: 1.0238286256790161
# sent 816037: |["I bet he's wishing he had a hybrid, right? Sixty miles to the gallon in the city.", "No! I bet he's wishing he was strangling someone!"]|
#
# ----------SENT 633043 @8---------
# TEXT: |['Geordi, active scanner output has increased by twenty six percent.', 'Inform Astrophysics that the new La Forge sensor array is online and awaiting major scientific discoveries.']|
# MEAN CONF TOP1000: 1.0132943391799927
#
# -- 633043 range D0 0-1, mean conf: 1.2942403554916382--
# rank 2, conf: 1.2942403554916382
# sent 555719: |['Scanning intensity has increased by fifteen hundred percent.', 'Shields up.']|
#
# -- 633043 range D1 1-10, mean conf: 1.271309494972229--
# rank 7, conf: 1.267788290977478
# sent 552131: |['Under two hours, Captain. And the radiation field has increased by seventeen percent.', 'So what impact will that have on fatal exposure?']|
#
# -- 633043 range D2 10-20, mean conf: 1.2135746479034424--
# rank 17, conf: 1.2124038934707642
# sent 658630: |["Seefra Nine is gone, vaporised. The sun's momentum has slowed by six percent.", 'And no one died.']|
#
# -- 633043 range D3 20-30, mean conf: 1.1856224536895752--
# rank 26, conf: 1.1852498054504395
# sent 603574: |['Increasing power by twenty percent', 'No effect']|
#
# -- 633043 range D4 30-60, mean conf: 1.158677577972412--
# rank 50, conf: 1.155167818069458
# sent 34525: |['Ion storm. Eighty two percent systems failure.', "That ship hasn't moved in over a year. What's taken you so long?"]|
#
# -- 633043 range D5 60-120, mean conf: 1.1308073997497559--
# rank 79, conf: 1.1369969844818115
# sent 633902: |["Confinement beam's at one hundred nine percent of normal.", 'Transporter room, you should be able to get a lock now.']|
#
# -- 633043 range D6 120-300, mean conf: 1.0714139938354492--
# rank 161, conf: 1.0979642868041992
# sent 557836: |['Scan complete. Terikon profile positive. Ninety eight percent probability of match.', "Well, whatever it is we're looking for, it seems we've found it."]|
#
# -- 633043 range D7 300-600, mean conf: 0.9980456829071045--
# rank 496, conf: 0.9878851175308228
# sent 593692: |['Reroute systems to primary hull power sources.', 'The plasma flow to the nacelles is uneven due to injector lock. An emergency saucer separation could rupture the warp field.']|
#
# -- 633043 range D8 600-1000, mean conf: 0.9540753364562988--
# rank 724, conf: 0.9596617221832275
# sent 573087: |['Captain, I have Starbase Six readable now. Switching to audio, sir.', 'Kirk here. Go ahead.']|
#
# ----------SENT 584937 @9---------
# TEXT: |["You're leaving me very little choice.", "Shran left six hours ago. You're too late."]|
# MEAN CONF TOP1000: 1.00254487991333
#
# -- 584937 range D0 0-1, mean conf: 1.2360191345214844--
# rank 2, conf: 1.2360191345214844
# sent 1004716: |["I'm leaving too.", "No body said you're fat. He's a loving character, like the Kool-ade guy."]|
#
# -- 584937 range D1 1-10, mean conf: 1.1562693119049072--
# rank 11, conf: 1.1265324354171753
# sent 444174: |["I'm sorry I didn't leave you a note.", "'Kay."]|
#
# -- 584937 range D2 10-20, mean conf: 1.1227935552597046--
# rank 19, conf: 1.121049404144287
# sent 961352: |["you're really leaving", 'yeah']|
#
# -- 584937 range D3 20-30, mean conf: 1.1075974702835083--
# rank 29, conf: 1.1039037704467773
# sent 253160: |["You're leaving me, aren't you?", 'I... I am.']|
#
# -- 584937 range D4 30-60, mean conf: 1.0890828371047974--
# rank 35, conf: 1.0977234840393066
# sent 303758: |["Be happy they're leaving you alone.", "Yeah. I'm happy. Don't worry, I'm happy."]|
#
# -- 584937 range D5 60-120, mean conf: 1.0675698518753052--
# rank 106, conf: 1.0635242462158203
# sent 505480: |['I’m not leaving you.', 'It’s the only way. You’ll go in there, and you’ll be safe from the curse.']|
#
# -- 584937 range D6 120-300, mean conf: 1.036963701248169--
# rank 192, conf: 1.0388641357421875
# sent 849704: |['"Dear Nadia, sorry I had to kill your boyfriend, but it was the motherly thing to do. Suicide, however, not very motherly of me."', "Great. So, um, Stefan obviously gave you my suicide note. What's your point?"]|
#
# -- 584937 range D7 300-600, mean conf: 0.9947938323020935--
# rank 448, conf: 0.9948635101318359
# sent 642250: |["Unavoidable, I'm afraid.", "Don't tell me you're considering this! We may as well poke out our own eyes with knitting needles, or just ram our heads"]|
#
# -- 584937 range D8 600-1000, mean conf: 0.9668611288070679--
# rank 652, conf: 0.974676251411438
# sent 850712: |["I didn't forget. All the centuries we've spent together and yet I can count on one hand the number of times that our family has been truly happy. I hated leaving here", 'As did I']|
#
# ----------SENT 505042 @10---------
# TEXT: |['Maleficent happened. And that is her idea of a good time.', 'Regina... Are you okay? What happened last night?']|
# MEAN CONF TOP1000: 1.0021792650222778
#
# -- 505042 range D0 0-1, mean conf: 1.2198761701583862--
# rank 2, conf: 1.2198761701583862
# sent 412980: |['Comes from deep within the parenchyma. The first wife had a stroke and it was fatal.', 'What about the scalp lacerations?']|
#
# -- 505042 range D1 1-10, mean conf: 1.1580464839935303--
# rank 10, conf: 1.131125569343567
# sent 890824: |['Yeah, my point is it’s a waste of time.', 'If you’re looking for an example of a waste of time, I would refer you to the conversation we’re having right now.']|
#
# -- 505042 range D2 10-20, mean conf: 1.1163856983184814--
# rank 17, conf: 1.1126736402511597
# sent 265291: |['Dean, it was your idea, and it was the best one either of us had.', 'I said it as a joke.']|
#
# -- 505042 range D3 20-30, mean conf: 1.1029670238494873--
# rank 28, conf: 1.1008645296096802
# sent 783019: |['Yeah, but skewering my navel is not exactly my idea of fun.', "Yeah, relax, honey. You think I'd let anyone get near me with a needle?"]|
#
# -- 505042 range D4 30-60, mean conf: 1.0843331813812256--
# rank 40, conf: 1.0896706581115723
# sent 643951: |["And that's the good news.", "All right, let me guess. We're going to open a can of cosmic whoop ass, huh?"]|
#
# -- 505042 range D5 60-120, mean conf: 1.0573182106018066--
# rank 97, conf: 1.0540692806243896
# sent 216488: |["This is the most fun I've ever had giving you wood.", "Homie, this sculpting has made me feel so fulfilled. I'm as hopeful and full of life as I was in the years before I met you."]|
#
# -- 505042 range D6 120-300, mean conf: 1.02886962890625--
# rank 150, conf: 1.0385537147521973
# sent 429548: |['Honestly, the game was a little scary at first, but once I got the hang of it, I had a pretty good time.', "Let's get this party started!"]|
#
# -- 505042 range D7 300-600, mean conf: 0.9973936080932617--
# rank 483, conf: 0.9928668737411499
# sent 1068417: |['Turns out she had eat my shorts. Caused her tummy great distress.', 'You know that same thing happens to me.']|
#
# -- 505042 range D8 600-1000, mean conf: 0.969818651676178--
# rank 785, conf: 0.9704426527023315
# sent 205730: |["One month? That's a heavy workload for a fourth grader.", 'I say this boy needs more homework.']|
#
# ----------SENT 245501 @11---------
# TEXT: |['When are Mom and Dad coming back?', 'Bored, are ya? Lisa, go cut me a switch.']|
# MEAN CONF TOP1000: 0.9903558492660522
#
# -- 245501 range D0 0-1, mean conf: 1.2189710140228271--
# rank 2, conf: 1.2189710140228271
# sent 870786: |['What are you gonna tell Marshall, huh? And when are you coming back?', "I honestly haven't thought it all the way through, and I don't intend to. All I know is that I'm a ticking time bomb, and if I don't do something for me right away, I swear I'm gonna explode!"]|
#
# -- 245501 range D1 1-10, mean conf: 1.1892621517181396--
# rank 11, conf: 1.156415581703186
# sent 805255: |['"When you coming home Dad?', 'You know, can I call you back?']|
#
# -- 245501 range D2 10-20, mean conf: 1.1479963064193726--
# rank 12, conf: 1.1549098491668701
# sent 993697: |["Hey, don't forget Sunday, okay? You and George are coming, right? Hotel Westbury, eight o'clock.", "I guess I'm coming. I mean..."]|
#
# -- 245501 range D3 20-30, mean conf: 1.1244022846221924--
# rank 29, conf: 1.1206904649734497
# sent 332914: |['When are you coming home?', "What? Guys, I'm not."]|
#
# -- 245501 range D4 30-60, mean conf: 1.1006752252578735--
# rank 39, conf: 1.1090543270111084
# sent 718836: |['When are you coming over? I need to discuss what to wear to your graduation. I thought about a suit.', 'A suit seems nice.']|
#
# -- 245501 range D5 60-120, mean conf: 1.0688133239746094--
# rank 110, conf: 1.0613573789596558
# sent 792076: |['Yeah, are you coming out now?', 'Uh-huh.']|
#
# -- 245501 range D6 120-300, mean conf: 1.0270962715148926--
# rank 130, conf: 1.0517545938491821
# sent 12653: |["Look, I'm on my way back to my spaceship. How about you coming back with me?", "Well, I'd like to, but I haven't really got the time. In any case, I ought to get back and tell the colonists that you've arrived."]|
#
# -- 245501 range D7 300-600, mean conf: 0.9848782420158386--
# rank 346, conf: 1.0028175115585327
# sent 1007353: |["I don't know . I have no idea . I was just listening and she came on.", "This is like a Penthouse letter...Why can't I meet women like this?"]|
#
# -- 245501 range D8 600-1000, mean conf: 0.9454368352890015--
# rank 901, conf: 0.9366328716278076
# sent 225421: |['Woo hoo! I rule this pseudo sport! Come back to me, boy!', "Dad, you don't understand. This was never about being cool. It was about you not caring how I felt."]|
#
# ----------SENT 1072756 @12---------
# TEXT: |["Doc, you're always welcome in my place.", 'Thanks, but no thanks.']|
# MEAN CONF TOP1000: 0.9853835701942444
#
# -- 1072756 range D0 0-1, mean conf: 1.1361948251724243--
# rank 2, conf: 1.1361948251724243
# sent 858785: |["We'll have to go elsewhere. In this bar, I will always be the guy left at the altar. It sucks!", 'Good times.']|
#
# -- 1072756 range D1 1-10, mean conf: 1.1037758588790894--
# rank 3, conf: 1.1227391958236694
# sent 215550: |["And Marge, you'll always be the best chef in our house.", "B.F.D. I've had your scrambled eggs, Homer. The secret ingredient is whiskey."]|
#
# -- 1072756 range D2 10-20, mean conf: 1.0792948007583618--
# rank 12, conf: 1.086746096611023
# sent 194403: |["Homer, there's no reason for you to feel threatened. You'll always be the man of this house.", 'Aw, thanks, honey.']|
#
# -- 1072756 range D3 20-30, mean conf: 1.0663396120071411--
# rank 28, conf: 1.0643800497055054
# sent 127612: |["You're most welcome, your highness.", 'We have a lot of desks to get to.']|
#
# -- 1072756 range D4 30-60, mean conf: 1.0519205331802368--
# rank 48, conf: 1.0516611337661743
# sent 809068: |['Honestly, Pam, the bagels in New York are the only good bagels in the world, I swear to God.', 'Okay.']|
#
# -- 1072756 range D5 60-120, mean conf: 1.0331218242645264--
# rank 96, conf: 1.0319762229919434
# sent 54479: |["Really? You're in wonderful condition.", 'Oh, thank you. What, what competition?']|
#
# -- 1072756 range D6 120-300, mean conf: 1.0094619989395142--
# rank 146, conf: 1.022853970527649
# sent 571813: |["I'm in command here, Jim.", 'What happened to Spock?']|
#
# -- 1072756 range D7 300-600, mean conf: 0.9811117649078369--
# rank 356, conf: 0.9898368120193481
# sent 724264: |["Oh, come on. We're in the same situation, except you're in denial.", "I'm not in denial!"]|
#
# -- 1072756 range D8 600-1000, mean conf: 0.9581206440925598--
# rank 602, conf: 0.9683986902236938
# sent 332651: |['Well, I guess having Rachel back wouldn’t be the worst thing in the world.', 'Yeah! Yes! Thank you! This is great. Thank you so much. And I swear, your kid is going to have the time of his life.']|
#
# ----------SENT 493880 @13---------
# TEXT: |["I'm sorry, Mom. Whatever happened in Camelot, I'm sorry we failed you.", "I know what I said last night, but, Henry, you didn't fail me. Everyone else did."]|
# MEAN CONF TOP1000: 0.9718124866485596
#
# -- 493880 range D0 0-1, mean conf: 1.160290002822876--
# rank 2, conf: 1.160290002822876
# sent 954594: |["hi I'm Charlotte Morgan, I'm so sorry about interrupting you in group", "oooh no no that's ok"]|
#
# -- 493880 range D1 1-10, mean conf: 1.113970160484314--
# rank 6, conf: 1.119394302368164
# sent 666091: |["Sydney, I'm sorry.", "You said you didn't tell us the truth because you were trying to protect me, because you didn't want to risk Sark finding out that I was a double agent. The thing is, someone now has the ability to detonate six nuclear weapons and I am responsible. So I am going to be part of the team that finds and disarms those warheds no matter what you do. But if you were telling the truth when you said you wanted to protect me, then, Mom... I need your help."]|
#
# -- 493880 range D2 10-20, mean conf: 1.0834565162658691--
# rank 17, conf: 1.0834019184112549
# sent 977858: |["Except for ones of utter embarrassment. No. I'm sorry about what happened.", "Sorry? There's no need for you to apologize to me. I know this may be hard for you to believe, but it's actually not every day that a beautiful woman throws herself at me."]|
#
# -- 493880 range D3 20-30, mean conf: 1.0737814903259277--
# rank 22, conf: 1.0775649547576904
# sent 1023404: |["I'm lukewarm about the Drakette.", "That's a nice triangle..."]|
#
# -- 493880 range D4 30-60, mean conf: 1.0417091846466064--
# rank 39, conf: 1.0444141626358032
# sent 194699: |['Why, we could revive the lost arts of conversation... and scrimshaw. Thus, I submit to you: we abolish television. Permanently.', 'Go back to Massachusetts, pinko!']|
#
# -- 493880 range D5 60-120, mean conf: 1.0181242227554321--
# rank 91, conf: 1.0169421434402466
# sent 695135: |['I can assure you, Emily, that there are no belly shots in our future.', "Although doing one off Dad's belly is okay. You're married."]|
#
# -- 493880 range D6 120-300, mean conf: 0.9895725846290588--
# rank 229, conf: 0.9856189489364624
# sent 825841: |["Um, I just wanted to apologize for taking that tone with you earlier that was... uncalled for, I'm sorry.", 'Um, yeah, ah, ah, that means a lot. Thank you for saying it.']|
#
# -- 493880 range D7 300-600, mean conf: 0.9660369753837585--
# rank 407, conf: 0.9673027396202087
# sent 565651: |["A fourth courier ship. This man must be stopped. He lives and fights by his own rules with total disregard for the higher designs of this Commonwealth. The infidelity. The disregard. The horror. It has to end here. Damn you, Hunt. You are in the way. You are in the way of a glorious Commonwealth. We, the Collectors, are trying to save it, but you are blocking us at every turn. Damn you! You're not the Commonwealth. I, we are.", 'Well then, stop the universe, because I want to get off.']|
#
# -- 493880 range D8 600-1000, mean conf: 0.9468907117843628--
# rank 629, conf: 0.9557696580886841
# sent 807859: |["I'm sorry, everybody.", 'I think the tree looks nice.']|
#
# ----------SENT 373427 @14---------
# TEXT: |["She didn't do it.", 'How do you know?']|
# MEAN CONF TOP1000: 0.9704095125198364
#
# -- 373427 range D0 0-1, mean conf: 1.1481242179870605--
# rank 1, conf: 1.1481242179870605
# sent 853046: |["She didn't do it.", "Hey, that's great! You got through to her."]|
#
# -- 373427 range D1 1-10, mean conf: 1.1406657695770264--
# rank 7, conf: 1.1436123847961426
# sent 119633: |["He didn't do it.", "Okay, you're not getting this. You can't just say he didn't do."]|
#
# -- 373427 range D2 10-20, mean conf: 1.132298469543457--
# rank 14, conf: 1.1332687139511108
# sent 85023: |['He did it.', "Right. They're free."]|
#
# -- 373427 range D3 20-30, mean conf: 1.103279709815979--
# rank 22, conf: 1.119655966758728
# sent 823596: |['He did it himself.', 'Is that ladle stainless or...']|
#
# -- 373427 range D4 30-60, mean conf: 1.0904542207717896--
# rank 57, conf: 1.0823582410812378
# sent 735736: |["She didn't.", "I don't understand."]|
#
# -- 373427 range D5 60-120, mean conf: 1.0588141679763794--
# rank 105, conf: 1.0516095161437988
# sent 94833: |["Gaius is loyal and very stubborn. He won't do that willingly.", 'Who said he had to be willing?']|
#
# -- 373427 range D6 120-300, mean conf: 1.009843111038208--
# rank 179, conf: 1.019666314125061
# sent 1009063: |["No she didn't.", "What am I going to do now? I can't live without Susan. I gotta get her back. How? How, am I gonna get her back?"]|
#
# -- 373427 range D7 300-600, mean conf: 0.9667897820472717--
# rank 338, conf: 0.9828313589096069
# sent 693186: |["Don't do that.", "Don't do what?"]|
#
# -- 373427 range D8 600-1000, mean conf: 0.9213483929634094--
# rank 794, conf: 0.9216356873512268
# sent 982370: |["Yes ma'am, she does.", 'Goodbye Grams.']|
#
# ----------SENT 788093 @15---------
# TEXT: |["Attention everyone. Drug testers are coming in a couple of hours to test everyone's urine.", 'Waa... what? What are you talking about?']|
# MEAN CONF TOP1000: 0.9680704474449158
#
# -- 788093 range D0 0-1, mean conf: 1.181787371635437--
# rank 2, conf: 1.181787371635437
# sent 533759: |["CT's are down this morning.", 'Then an MRI. She needs an enema, an ERCP for a stent and brush biopsy this afternoon.']|
#
# -- 788093 range D1 1-10, mean conf: 1.14469575881958--
# rank 3, conf: 1.1606742143630981
# sent 31968: |["Here's to Luke's last night on Bannerman Road.", 'Cheers.']|
#
# -- 788093 range D2 10-20, mean conf: 1.1068063974380493--
# rank 21, conf: 1.0944980382919312
# sent 340794: |["Emma's down for the night.", 'Oh, good.']|
#
# -- 788093 range D3 20-30, mean conf: 1.0859739780426025--
# rank 22, conf: 1.0944525003433228
# sent 556939: |['Our systems came back online a few minutes ago.', 'And the planetary collision?']|
#
# -- 788093 range D4 30-60, mean conf: 1.0613770484924316--
# rank 43, conf: 1.0653692483901978
# sent 630435: |['Conn, are we still on schedule to arrive at Mordan in thirty eight hours?', "Aye, sir. We're at warp four."]|
#
# -- 788093 range D5 60-120, mean conf: 1.0328940153121948--
# rank 64, conf: 1.0493290424346924
# sent 725471: |["I told you I'm meeting my father at 7:30 in the morning in New York.", 'I loved the dinner tonight.']|
#
# -- 788093 range D6 120-300, mean conf: 0.9981732964515686--
# rank 149, conf: 1.012101411819458
# sent 382425: |["Ugh! Great. We're two days from Earth with no food.", 'Problem solved']|
#
# -- 788093 range D7 300-600, mean conf: 0.961327314376831--
# rank 503, conf: 0.9550336003303528
# sent 677364: |['Dolzhenko is typically a few minutes late.', 'Half an hour is more than a few minutes –']|
#
# -- 788093 range D8 600-1000, mean conf: 0.9318451285362244--
# rank 806, conf: 0.9311516284942627
# sent 690052: |['Hey, nobody wants vibing on the holidays.', "Rory, please? I'm gonna be seriously late if I have to go all the way home."]|
#
# ----------SENT 878052 @16---------
# TEXT: |['Can I get you ladies something? I was just about to mix up some Country Time.', "We're looking for Spike, actually."]|
# MEAN CONF TOP1000: 0.9402344822883606
#
# -- 878052 range D0 0-1, mean conf: 1.1381635665893555--
# rank 2, conf: 1.1381635665893555
# sent 589303: |['Can I get you something? A beverage?', 'No, thank you.']|
#
# -- 878052 range D1 1-10, mean conf: 1.1381635665893555--
# rank 4, conf: 1.1381635665893555
# sent 884227: |["Can I get you something? I don't have any coffee.", "Oh, no thank you, I, uh... You don't drink? Beverages, I mean?"]|
#
# -- 878052 range D2 10-20, mean conf: 1.111742377281189--
# rank 20, conf: 1.107922911643982
# sent 519490: |["Can I get you somethin' to drink?", 'Uh, please.']|
#
# -- 878052 range D3 20-30, mean conf: 1.0860095024108887--
# rank 25, conf: 1.0856202840805054
# sent 215737: |['Welcome to Sprawl*Mart! Can I get you a cart or a basket?', "Grampa, you're a greet grater! I mean a great greeter! Now look who's senile!"]|
#
# -- 878052 range D4 30-60, mean conf: 1.0801489353179932--
# rank 36, conf: 1.0809382200241089
# sent 1014733: |['Can I get you anything?', 'What do we have in the fruit department?']|
#
# -- 878052 range D5 60-120, mean conf: 1.0613210201263428--
# rank 114, conf: 1.0401521921157837
# sent 1011576: |['Can I just get it opened first?', "I can't believe you're hoarding sex moves. I'm out there rubbing two sticks together. You walk around with a zippo."]|
#
# -- 878052 range D6 120-300, mean conf: 0.9836044311523438--
# rank 281, conf: 0.9654054045677185
# sent 1036043: |['Have I got something in my teeth?', "Okay, look, um, I got a little swimmer's ear going on. Yeah, fell asleep in the tub last night. So I'm not really getting a lot of this but I did get the part about your teeth, and they're very nice. White."]|
#
# -- 878052 range D7 300-600, mean conf: 0.9304571747779846--
# rank 575, conf: 0.9119141101837158
# sent 75409: |['Have you got a better theory©', "Well, no. It just doesn't fit them. They seem more like a bunch of thugs to me."]|
#
# -- 878052 range D8 600-1000, mean conf: 0.886379599571228--
# rank 715, conf: 0.8954352140426636
# sent 676619: |["You've got to hurry!", "They put an adhesive on the incision, it must have bled through! It's stuck!"]|
#
# ----------SENT 578338 @17---------
# TEXT: |["You humans obviously have emotions. I find it curious that you'd select a Vulcan as your science officer.", "Believe me, she wasn't my first choice."]|
# MEAN CONF TOP1000: 0.9401341080665588
#
# -- 578338 range D0 0-1, mean conf: 1.1407506465911865--
# rank 2, conf: 1.1407506465911865
# sent 299872: |['You might as well picked my name from a hat.', "Normally, I'd agree but your disapproval of Dr. Sidman's work makes me wonder if you're a religious fanatic."]|
#
# -- 578338 range D1 1-10, mean conf: 1.0887278318405151--
# rank 3, conf: 1.1169307231903076
# sent 601433: |["Improbable as it may sound, I've found compelling evidence to support my theory.", 'What kind of evidence?']|
#
# -- 578338 range D2 10-20, mean conf: 1.0589354038238525--
# rank 19, conf: 1.0535904169082642
# sent 566750: |['That a way could be found to harness that energy, and perhaps someday power my entire fleet.', 'At least.']|
#
# -- 578338 range D3 20-30, mean conf: 1.044190526008606--
# rank 23, conf: 1.0491398572921753
# sent 652269: |['Probably. However, that Jim Kirk will find a few changes, if I read my Spocks correctly.', 'Jim, I think I liked him with a beard better. It gave him character. Of course almost any change would be a distinct improvement.']|
#
# -- 578338 range D4 30-60, mean conf: 1.0242583751678467--
# rank 59, conf: 1.0122780799865723
# sent 729625: |['I find Stars Hollow fascinating.', "You're out of your gourd."]|
#
# -- 578338 range D5 60-120, mean conf: 0.9977989196777344--
# rank 79, conf: 1.003136396408081
# sent 72066: |['I too find it repugnant to witness, my lady, but the Doctor has a well-known predilection for violence.', 'That is a foul slur!']|
#
# -- 578338 range D6 120-300, mean conf: 0.9645789861679077--
# rank 221, conf: 0.9620352983474731
# sent 1071612: |["Still I have this dream of perfection. But I'mkeep on lookin'. Hoping against hope that I'll find it.", "Well it's a adorabel dream. But I got to tell youEmmett. In most cases that come along in the movies. Andeven then only to Audrey Hudburn. Real love when it comesdoesn't look anything like what you expect."]|
#
# -- 578338 range D7 300-600, mean conf: 0.932773232460022--
# rank 534, conf: 0.9258641004562378
# sent 653463: |['Unfortunately, I must violate a direct order from Starfleet.', "That's the best possible decision you could make, Spock. I'm with you."]|
#
# -- 578338 range D8 600-1000, mean conf: 0.9102043509483337--
# rank 742, conf: 0.9129008650779724
# sent 750656: |['When do you plan to use it in the dark corner by the staircase, Richard?', 'Well, you never know.']|
#
# ----------SENT 408486 @18---------
# TEXT: |['Maybe this has nothing to do with the case. Maybe it was just a piece of debris left at the scene.', "No, no. I-I'm not quitting. No. I am in too deep."]|
# MEAN CONF TOP1000: 0.9281722903251648
#
# -- 408486 range D0 0-1, mean conf: 1.1569278240203857--
# rank 2, conf: 1.1569278240203857
# sent 595732: |['Maybe it was just a malfunction in the transporter.', 'Then I saw you working the PADD with your left hand. Commander La Forge is right handed, sir. A similar malfunction occurred in the Sherlock Holmes programme I was running before Moriarty first appeared.']|
#
# -- 408486 range D1 1-10, mean conf: 1.1031248569488525--
# rank 9, conf: 1.0859551429748535
# sent 124240: |['Yes, Abby said the signal dropped out. It probably puts him at the outside edge of the reception area of that tower.', "That's pretty clever, Boss. How did you figure that out?"]|
#
# -- 408486 range D2 10-20, mean conf: 1.0761511325836182--
# rank 18, conf: 1.074465036392212
# sent 769132: |['Maybe it was the parasite.', 'What do you mean?']|
#
# -- 408486 range D3 20-30, mean conf: 1.0573502779006958--
# rank 27, conf: 1.0554471015930176
# sent 400256: |['Maybe this is only the dump site.', "His body's also coated. Makes me think whoever did this didn't even stop the car."]|
#
# -- 408486 range D4 30-60, mean conf: 1.0338608026504517--
# rank 58, conf: 1.0262014865875244
# sent 1008047: |["Maybe it's a shortcut.", "We're on the Grand Central, there's no traffic."]|
#
# -- 408486 range D5 60-120, mean conf: 1.0045299530029297--
# rank 102, conf: 0.9968530535697937
# sent 169627: |["Look, I know this guy. And if you're not trying to set him up somebody is. Maybe it's somebody at this club.", "Clark, there's a reason that club's so underground. All right, the city doesn't exactly give licenses for some of the things that go on there. Are you sure you wanna get involved in this?"]|
#
# -- 408486 range D6 120-300, mean conf: 0.9604237675666809--
# rank 181, conf: 0.9699729681015015
# sent 490113: |['Yeah my dad’s the total opposite. He’s totally like 3 minutes before the flight kind of guy.', 'Okay so look, I wrote everything down. When she eats, when she sleeps, what toys she likes. And I put all my numbers down. My cell, my pager. I’ve got my moms, my dads, my cousin who’s getting married, I put his number down. If you need anything at all I’m just going to be less than an hour away so just call anybody…']|
#
# -- 408486 range D7 300-600, mean conf: 0.921546220779419--
# rank 474, conf: 0.9195933938026428
# sent 551131: |['A bizarre incident just took place.', 'The shoot-out between the bellboy and Mickey D.']|
#
# -- 408486 range D8 600-1000, mean conf: 0.8877098560333252--
# rank 847, conf: 0.883510410785675
# sent 202882: |["Maybe we could shop somewhere else. There's a farm stand next door.", "Interesting. It's like a corndog without the dog."]|
#
# ----------SENT 556622 @19---------
# TEXT: |["You're going to have to destroy it in order to escape.", 'How much longer before we reach them?']|
# MEAN CONF TOP1000: 0.9227425456047058
#
# -- 556622 range D0 0-1, mean conf: 1.103016972541809--
# rank 2, conf: 1.103016972541809
# sent 317604: |['“You must be going through a canyon.”', '“Cordelia, can you hear me?”']|
#
# -- 556622 range D1 1-10, mean conf: 1.064356803894043--
# rank 11, conf: 1.0449588298797607
# sent 630639: |["I'm going to have to do a complete internal scan.", "Keep me posted, Doctor, I'll be on the Bridge."]|
#
# -- 556622 range D2 10-20, mean conf: 1.0295493602752686--
# rank 15, conf: 1.028247594833374
# sent 392378: |["I've been going over it.", 'The Collins case is my shift. You are completely off base.']|
#
# -- 556622 range D3 20-30, mean conf: 1.0198079347610474--
# rank 23, conf: 1.0246658325195312
# sent 531542: |["I'm gonna have to put you in the clinic if you miss rounds.", 'Oh, the clinic!']|
#
# -- 556622 range D4 30-60, mean conf: 1.0033118724822998--
# rank 42, conf: 1.0083297491073608
# sent 631399: |["If you can't stabilise the life support, we're going to have to evacuate the ship.", "I think we can do it. I'll have to get to Engineering though. La Forge to damage control team alpha. Meet me on Engineering level three."]|
#
# -- 556622 range D5 60-120, mean conf: 0.9779519438743591--
# rank 96, conf: 0.9758606553077698
# sent 749548: |["I'm going to answer it.", 'Emily, we are in the middle of a discussion.']|
#
# -- 556622 range D6 120-300, mean conf: 0.94999098777771--
# rank 209, conf: 0.9492994546890259
# sent 428671: |['No. I am gonna be attacked by a timberwolf!', 'Can I still wear the mustache?']|
#
# -- 556622 range D7 300-600, mean conf: 0.9170845746994019--
# ...
#
# -- 452076 range D7 300-600, mean conf: 0.8053534030914307--
# rank 482, conf: 0.8012477159500122
# sent 250320: |['I held your hair when you barfed in the simulator.', 'Shut up! Commander.']|
#
# -- 452076 range D8 600-1000, mean conf: 0.7748858332633972--
# rank 706, conf: 0.7806154489517212
# sent 478032: |['I am. In fact, I got everything ready. I made your lunch, and I packed your backpack. Yummy.', 'You cut my pb&j sideways. Carrie cuts it in half. I like it cut in half.']|
#
# ----------SENT 80500 @33---------
# TEXT: |['The information can be extracted by means of your suffering.', "Are you trying to scare me? Well, cos I'm already bloody terrified of dying. And I'll endure a lot of pain for a very long time before I give up the information that's keeping me alive. How long have you got?"]|
# MEAN CONF TOP1000: 0.8011157512664795
#
# -- 80500 range D0 0-1, mean conf: 1.0614655017852783--
# rank 2, conf: 1.0614655017852783
# sent 80550: |['The information can be extracted by means of your suffering.', "Are you trying to scare me? Well, cos I'm already bloody terrified of dying. And I'll endure a lot of pain for a very long time before I give up the information that's keeping me alive. How long have you got?"]|
#
# -- 80500 range D1 1-10, mean conf: 0.9337548017501831--
# rank 5, conf: 0.9499009251594543
# sent 617241: |['Your commanding officer will be notified of your infraction.', 'Piloting lessons?']|
#
# -- 80500 range D2 10-20, mean conf: 0.9008882641792297--
# rank 17, conf: 0.8986355662345886
# sent 32256: |['The laws of hyper-dimensional physics cannot be changed.', "Then use them, Mister Dread. The transmat equipment. That's how you put all the ships in there, isn't it?"]|
#
# -- 80500 range D3 20-30, mean conf: 0.8919903039932251--
# rank 29, conf: 0.8912327289581299
# sent 187851: |['Ah, well. I grow fonder of this child by the second.', "Sophie, look, I promised Elijah that I would protect the Mikaelson miracle baby whilst he tries to win your witch Davina's loyalty. Why don't you tell me just how extreme this faction is?"]|
#
# -- 80500 range D4 30-60, mean conf: 0.8786471486091614--
# rank 37, conf: 0.8857511281967163
# sent 598978: |['Your vessel will be used to defend Nyrian acquisitions.', 'Is this the way you operate, gradually changing places with the crew of a ship?']|
#
# -- 80500 range D5 60-120, mean conf: 0.857721209526062--
# rank 75, conf: 0.8650887608528137
# sent 574554: |['Our log tapes will indicate our innocence in the present situation.', "Unfortunately, there's no guarantee that they will be believed."]|
#
# -- 80500 range D6 120-300, mean conf: 0.8250111937522888--
# rank 246, conf: 0.8173490166664124
# sent 537258: |['The crew will not benefit from the leadership of an exhausted captain.', "You're right as usual. I've missed your counsel, Tuvok."]|
#
# -- 80500 range D7 300-600, mean conf: 0.7952161431312561--
# rank 310, conf: 0.8104465007781982
# sent 33179: |['Soon it will drain you completely, and then my adventure begins. I will feast on this world.', 'Where, Where are we?']|
#
# -- 80500 range D8 600-1000, mean conf: 0.7720077633857727--
# rank 960, conf: 0.7643674612045288
# sent 586101: |["We can't do that either. It will go into a spore and remain until it comes in contact with a planet or another ship. The results would be disastrous.", "Commander, your attitude tells me that however bad I think it is, it's actually worse."]|
#
# ----------SENT 518662 @34---------
# TEXT: |["It's running backwards. There's serious witchery afoot here.", "Come on, Princess. We don't got all night."]|
# MEAN CONF TOP1000: 0.7677862644195557
#
# -- 518662 range D0 0-1, mean conf: 0.8839796185493469--
# rank 2, conf: 0.8839796185493469
# sent 757422: |["Sorry, Paris. There's noise here.", "So, I'm returning your call."]|
#
# -- 518662 range D1 1-10, mean conf: 0.8743042349815369--
# rank 7, conf: 0.8721401691436768
# sent 254346: |["Hey, something's different about Moe's. There's no chicks here.", "There's never any chicks here."]|
#
# -- 518662 range D2 10-20, mean conf: 0.8616870045661926--
# rank 13, conf: 0.8704456686973572
# sent 77316: |["Yes. Barbara, look! There's a passageway here.", "Well, that won't be easy."]|
#
# -- 518662 range D3 20-30, mean conf: 0.8407623171806335--
# rank 24, conf: 0.8478252291679382
# sent 802752: |["There's a KISS cover band in here.", "Let's do it."]|
#
# -- 518662 range D4 30-60, mean conf: 0.8229874968528748--
# rank 44, conf: 0.8244907855987549
# sent 316323: |['There are indentations here.', 'Alpha-numeric. Z and S?']|
#
# -- 518662 range D5 60-120, mean conf: 0.8090773820877075--
# rank 68, conf: 0.8125522136688232
# sent 202420: |["Here's fifty.", 'Woo hoo!']|
#
# -- 518662 range D6 120-300, mean conf: 0.7928221225738525--
# rank 212, conf: 0.7923479676246643
# sent 599259: |['There is no alternative.', "Look, I'll honour the original agreement, but I'm not turning this ship around. It's too dangerous."]|
#
# -- 518662 range D7 300-600, mean conf: 0.770018994808197--
# rank 454, conf: 0.7679236531257629
# sent 911660: |['There are no Jewish hobbits.', 'Clearly, you’ve never been to my house for dinner on Rosh Hashanah.']|
#
# -- 518662 range D8 600-1000, mean conf: 0.7375772595405579--
# rank 886, conf: 0.7314609289169312
# sent 120560: |["So there's no call log.", 'Thanks to our bomb disposal expert, we still have plenty to work with.']|
#
# ----------SENT 607345 @35---------
# TEXT: |['On my way.', 'We have been unable to establish two way communication so far, but we have determined that the signal is coming from somewhere in the Rutharian sector.']|
# MEAN CONF TOP1000: 0.7286088466644287
#
# -- 607345 range D0 0-1, mean conf: 0.9466015696525574--
# rank 1, conf: 0.9466015696525574
# sent 652740: |['On my way. Scotty. Bones?', "I don't know yet, Jim."]|
#
# -- 607345 range D1 1-10, mean conf: 0.9466015696525574--
# rank 7, conf: 0.9466015100479126
# sent 376043: |['On my way.', "If you get an address, go straight to judge Hildred and get a search warrant. We'll take down Sylvan today."]|
#
# -- 607345 range D2 10-20, mean conf: 0.9466015696525574--
# rank 12, conf: 0.9466015100479126
# sent 632585: |['On my way.', "At first I thought the catwalk was spinning. As it turns out, it was me. I was lucky Ensign Fletcher was there to grab me. It's a long way down to the bottom of the warp core."]|
#
# -- 607345 range D3 20-30, mean conf: 0.9466015100479126--
# rank 30, conf: 0.9466014504432678
# sent 545592: |['On my way.', "I'm glad we got that settled."]|
#
# -- 607345 range D4 30-60, mean conf: 0.9059665203094482--
# rank 32, conf: 0.9466014504432678
# sent 628797: |['On my way.', 'It may not be home, but it checks out. Thermionic radiation, surface temperatures in excess of five hundred Kelvins.']|
#
# -- 607345 range D5 60-120, mean conf: 0.8318519592285156--
# rank 102, conf: 0.8106677532196045
# sent 988894: |["Andie, it's fine. Your house is on my way.", "Well, maybe we shouldn't do this."]|
#
# -- 607345 range D6 120-300, mean conf: 0.7571907639503479--
# rank 297, conf: 0.7282128930091858
# sent 41353: |['Doctor, I�d just come face to face with myself. I wasn�t counting the buttons on my jacket.', 'Yes, I quite understand that. Well, I think we should leave the Museum, try and find the Tardis, and make sure that it doesn�t end up in here. Are you all agreeable?']|
#
# -- 607345 range D7 300-600, mean conf: 0.7093185186386108--
# rank 576, conf: 0.6984303593635559
# sent 974593: |["Ok, there's a chair. Ok, sit down in the chair. Sit down in the chair. Ok. All right. Open your eyes.", 'Ok, you realize for the "hands over the eyes" game to work the present has to be on the table, right?']|
#
# -- 607345 range D8 600-1000, mean conf: 0.6849678158760071--
# rank 954, conf: 0.6763699650764465
# sent 571425: |['The unit touched my screens.', 'That unit was my Chief Engineer. (silence) Lieutenant. Lieutenant, are you all right?']|
#
# ----------SENT 623255 @36---------
# TEXT: |["The evening's young, Lieutenant. Let's mingle.", 'Vulcans do not. Curious.']|
# MEAN CONF TOP1000: 0.7204592227935791
#
# -- 623255 range D0 0-1, mean conf: 0.79104083776474--
# rank 2, conf: 0.79104083776474
# sent 100733: |["How strong? All right, boys. Let's rumble.", "It's still here!"]|
#
# -- 623255 range D1 1-10, mean conf: 0.7909930348396301--
# rank 11, conf: 0.7909592986106873
# sent 451440: |["Let's jet.", "You can't do that! That's stealing! There is a security camera in here."]|
#
# -- 623255 range D2 10-20, mean conf: 0.7907751798629761--
# rank 20, conf: 0.7906837463378906
# sent 566653: |["Sun's gone out. Let's roll.", "Sun's gone out? I'll need an explanation for that one, too."]|
#
# -- 623255 range D3 20-30, mean conf: 0.7906837463378906--
# rank 24, conf: 0.7906837463378906
# sent 923940: |["Let's roll.", 'We got a call from one of the guys who press our bullets.']|
#
# -- 623255 range D4 30-60, mean conf: 0.7802141904830933--
# rank 39, conf: 0.7879856824874878
# sent 231768: |["All right, all right, I lied! I'm sorry. Let's kiss.", "No. You don't understand, Nelson. A kiss doesn't mean anything if it's dishonest."]|
#
# -- 623255 range D5 60-120, mean conf: 0.744409441947937--
# rank 63, conf: 0.7541061639785767
# sent 595189: |["Let's test the emitter.", 'Particle accelerators at full power.']|
#
# -- 623255 range D6 120-300, mean conf: 0.7428367733955383--
# rank 214, conf: 0.7428367137908936
# sent 922843: |["Let's go.", 'Hey, back up Clay.']|
#
# -- 623255 range D7 300-600, mean conf: 0.7334666848182678--
# rank 486, conf: 0.7369080781936646
# sent 889681: |['Let’s go.', 'Interesting. s*x works even better than chocolate to modify behaviour. I wonder if anyone else has stumbled on to that.']|
#
# -- 623255 range D8 600-1000, mean conf: 0.6871994137763977--
# rank 967, conf: 0.6720697283744812
# sent 895512: |["Next game, let's switch helmets.", "No, I'd look silly in that helmet."]|
#
# ----------SENT 746926 @37---------
# TEXT: |['Yeah, first row. Right in front of the kid with the humongous. . .uh, the really cute kid.', "Darn, I wanted to get a picture of her walking in. I'll get some of her in her seat."]|
# MEAN CONF TOP1000: 0.7099781632423401
#
# -- 746926 range D0 0-1, mean conf: 0.8375022411346436--
# rank 2, conf: 0.8375022411346436
# sent 114722: |["I'd say we played that one nicely, Boss. The whole good guy, bad guy technique.", 'Dinozzo.']|
#
# -- 746926 range D1 1-10, mean conf: 0.8205328583717346--
# rank 11, conf: 0.8090616464614868
# sent 100197: |['The pregnant girl, Jessica.', "Yeah. Since Matt had to kill her himself, somebody from the hospital could've seen him."]|
#
# -- 746926 range D2 10-20, mean conf: 0.8029680252075195--
# rank 12, conf: 0.8089250922203064
# sent 740177: |["Hey, how dare you walk away from me when I'm being a world class jerk to you. The painting's great Mom, really.", 'Thank you.']|
#
# -- 746926 range D3 20-30, mean conf: 0.7947232723236084--
# rank 24, conf: 0.7979431748390198
# sent 329138: |['Oh, Janine, the really hot dancer girl?', 'Some would say she’s attractive, yes.']|
#
# -- 746926 range D4 30-60, mean conf: 0.7737901210784912--
# rank 59, conf: 0.7632611989974976
# sent 251094: |['Aw, thanks big guy.', 'Now dance, rummy!']|
#
# -- 746926 range D5 60-120, mean conf: 0.754306972026825--
# rank 65, conf: 0.7608816027641296
# sent 300732: |['Really, this man murdered Jenny.', 'And then buried her in a mass unmarked grave.']|
#
# -- 746926 range D6 120-300, mean conf: 0.7310614585876465--
# rank 198, conf: 0.7330610156059265
# sent 983311: |['Whatever for? Besides the obvious, that is.', 'Well, the truth is that I intended to shock you tonight, but something unexpected happened. For the first time, I was able to see past the cliché, and I actually enjoyed being a homecoming queen.']|
#
# -- 746926 range D7 300-600, mean conf: 0.7055677771568298--
# rank 483, conf: 0.7029306292533875
# sent 798524: |['Good work, kid.', 'Thanks old man.']|
#
# -- 746926 range D8 600-1000, mean conf: 0.6850512623786926--
# rank 881, conf: 0.6814810037612915
# sent 74815: |['The bad cat killed it. The bad cat the man brought.', 'What man? Which way did he go? Show me!']|
#
# ----------SENT 307923 @38---------
# TEXT: |['How did it taste?', "Eh, it's way worse coming up. I can tell you that."]|
# MEAN CONF TOP1000: 0.6533960700035095
#
# -- 307923 range D0 0-1, mean conf: 0.815858781337738--
# rank 2, conf: 0.815858781337738
# sent 542216: |['Stupido! Foolish Florentines! A bird is a mechanical instrument that  \t\tworks according to mathematical laws. An instrument that surely I can recreate.  \t\tHow did it fail?', 'Maybe you underestimated the wingspan?']|
#
# -- 307923 range D1 1-10, mean conf: 0.7677942514419556--
# rank 7, conf: 0.7575483322143555
# sent 723141: |['Why did it suck?', 'Just a ton of schoolwork and Ramadan.']|
#
# -- 307923 range D2 10-20, mean conf: 0.739109456539154--
# rank 16, conf: 0.7393673658370972
# sent 28462: |['How can it?', "I don't know. The Doctor will, and he's on his way back. Yes, that surprises you, doesn't it, even more than the Krynoid. But it's true. Have a little faith, Scorby."]|
#
# -- 307923 range D3 20-30, mean conf: 0.7284725904464722--
# rank 22, conf: 0.7300121784210205
# sent 473098: |['How bout that?', 'Good, it’s good.']|
#
# -- 307923 range D4 30-60, mean conf: 0.7153249382972717--
# rank 43, conf: 0.7154927849769592
# sent 623248: |['How does it end?', 'Either in conversion to a more balanced, stable relationship, or in tragic circumstances.']|
#
# -- 307923 range D5 60-120, mean conf: 0.6966657638549805--
# rank 67, conf: 0.7057323455810547
# sent 914647: |['Oh. How do you drink it?', 'Oh, just put it in your mouth and pop it like a zit.']|
#
# -- 307923 range D6 120-300, mean conf: 0.6751151084899902--
# rank 136, conf: 0.6864432096481323
# sent 752191: |['Very sweet mum, but you know what -- it\'s totally unnecessary. Look you already gave us "wolf girl," which, I mean, ah? How do you top that?', 'We insist.']|
#
# -- 307923 range D7 300-600, mean conf: 0.6525231003761292--
# rank 334, conf: 0.6628308296203613
# sent 319166: |['How she do that?"', '"She\'s Fred. She does that, too."']|
#
# -- 307923 range D8 600-1000, mean conf: 0.6260740160942078--
# rank 955, conf: 0.6200328469276428
# sent 595617: |["That's what I call them. Let's say you had an anti-matter flow converter that was fluctuating. How would you repair it?", 'The correct procedure would be to adjust the converter.']|
#
# ----------SENT 964068 @39---------
# TEXT: |['What? No en suite commode?', 'Excuse me?']|
# MEAN CONF TOP1000: 0.6102358102798462
#
# -- 964068 range D0 0-1, mean conf: 0.713284432888031--
# rank 2, conf: 0.713284432888031
# sent 657211: |['No! Trance?', "Beka, it's all right. I'll be"]|
#
# -- 964068 range D1 1-10, mean conf: 0.6955726146697998--
# rank 9, conf: 0.6882790327072144
# sent 704828: |["Yeah, well, now he's in the canned-peas aisle. Apparently he doesn't like peas, but he does like pea soup. Interesting, no? No!", 'All right, give me that. Um, okay.']|
#
# -- 964068 range D2 10-20, mean conf: 0.6770169138908386--
# rank 18, conf: 0.6731129884719849
# sent 1019837: |['No!!!', 'Yeeeahh!!!']|
#
# -- 964068 range D3 20-30, mean conf: 0.6677316427230835--
# rank 23, conf: 0.6720771193504333
# sent 223172: |['Mista Sparkaru -- Un no yoi besto washu!!', 'Bor-ing.']|
#
# -- 964068 range D4 30-60, mean conf: 0.6600018739700317--
# rank 60, conf: 0.6600018739700317
# sent 725880: |['No. No, why?', 'Just wondering.']|
#
# -- 964068 range D5 60-120, mean conf: 0.6496660113334656--
# rank 72, conf: 0.6511105298995972
# sent 686430: |['No, what?', 'That it always falls on the day after trash day. Therefore, all the stuff that you forgot to throw out that you would normally be stuck with for another whole week, you can instead put in a pretty basket and auction off for charity.']|
#
# -- 964068 range D6 120-300, mean conf: 0.6283683180809021--
# rank 145, conf: 0.6392545104026794
# sent 511276: |["No, c'mon!", 'Ooh! Ooh!']|
#
# -- 964068 range D7 300-600, mean conf: 0.6058496236801147--
# rank 408, conf: 0.6063693761825562
# sent 517757: |['WHOA!!!', 'You blew it, Finn! With this!']|
#
# -- 964068 range D8 600-1000, mean conf: 0.5903844833374023--
# rank 814, conf: 0.5900639295578003
# sent 704273: |["Sure, why not? Let's start planning it.", "You don't plan an elopement. You just do it."]|

# %%
# Continue from here only if you want to see other variations.
# Depend on your data distribution, other variations may be more benefitial.

# raise Exception('End of research model.')

# %% [markdown]
# ## Variation V2: Remove Stop words
#
# Same as V1 except remove stop words, including tokens and heads.
#
# Full manifest:
#
# For DEP (syntactic dependency):
# * No punct dependency.
# * No ROOT.
# * No stop words.
#
# For POS (senmatic token):
# * No stop words.
#
# Conclusion:
# Not accepable.

# %%
data_v2 = data.loc[data.is_stop==False]
data_v2
# Out:
#           sent_id            show_id            char_name char_id head_info  \
# 4          508646      OnceUponATime           CINDERELLA  l19407       POS
# 6          146223       VeronicaMars             VERONICA  l30591       DEP
# 7           19636          DoctorWho      ELEVENTH DOCTOR   l8661       POS
# 12         672740              Alias                 JACK   l1275       POS
# 14         537460           StarTrek              JANEWAY  l25466       POS
# 18         662463           StarTrek                PHLOX  l25490       DEP
# 21         238693        TheSimpsons  C. Montgomery Burns  a15869       POS
# 22         606411           StarTrek                 WORF  l25435       POS
# 24         751240       GilmoreGirls              RICHARD  l11615       POS
# 32         971419       DawsonsCreek               DAWSON   l7946       DEP
# 33         866034  HowIMetYourMother                ROBIN  l13772       POS
# 34        1055655        Charmed1998                 COLE   l6502       POS
# 36         642447           StarTrek               HARPER   l1893       DEP
# 45         189666        TheSimpsons        Homer Simpson  a15835       POS
# 56         813633        TheOfficeUS                 ANDY  l19350       POS
# 58         460395        OneTreeHill                LUCAS  l19593       POS
# 59         357634            Friends               MONICA  l10692       POS
# 64         309155              Bones               ANGELA   l5149       POS
# 68         529936       GreysAnatomy               GEORGE  l12266       POS
# 69          81062          DoctorWho                CLARA   l8711       POS
# 72         578352           StarTrek               ARCHER  l25486       POS
# 73         343955            Friends                 JOEY  l10694       POS
# 76        1050595        Charmed1998                 PRUE   l6494       DEP
# 80         545131           StarTrek              JANEWAY  l25466       POS
# 81         313849              Bones               SWEETS   l5163       POS
# 93         110435               NCIS                GIBBS  l18791       POS
# 107        752836       GilmoreGirls                 LANE  l11622       POS
# 108        752214       GilmoreGirls              RICHARD  l11615       POS
# 109        449728        OneTreeHill               BROOKE  l19597       POS
# 110        242714        TheSimpsons      Seymour Skinner  a15836       POS
# ...           ...                ...                  ...     ...       ...
# 17160285   474465        OneTreeHill                MOUTH  l19603       POS
# 17160288   873111         Buffyverse                BUFFY   l5648       POS
# 17160293   480044        OneTreeHill                KAREN  l19601       POS
# 17160296   406135           CSIVerse                 NICK   l7486       DEP
# 17160300   359751            Friends               MONICA  l10692       POS
# 17160310   600643           StarTrek             CHAKOTAY  l25467       DEP
# 17160311   538371           StarTrek              JANEWAY  l25466       DEP
# 17160318    66392          DoctorWho                 GWEN   l9078       POS
# 17160323   859388  HowIMetYourMother               BARNEY  l13774       POS
# 17160327   649350           StarTrek               NEELIX  l25473       POS
# 17160328   885589              Salem                 MARY  l23233       DEP
# 17160329   688919       GilmoreGirls              LORELAI  l11612       POS
# 17160332   218173        TheSimpsons        Marge Simpson  a15821       POS
# 17160334   180556         Smallville               MARTHA  l24613       POS
# 17160341   464413        OneTreeHill               NATHAN  l19594       POS
# 17160344   749073       GilmoreGirls               SOOKIE  l11619       POS
# 17160349   709703       GilmoreGirls                 RORY  l11613       DEP
# 17160351   274814       Supernatural                  SAM  l25967       POS
# 17160355   329079            Friends                 ROSS  l10696       POS
# 17160356   509057      AdventureTime                 Finn   a3415       POS
# 17160359    25432          DoctorWho        SECOND DOCTOR   l8651       POS
# 17160362   793175        TheOfficeUS              MICHAEL  l19352       POS
# 17160366   125325               NCIS                 ABBY  l18806       POS
# 17160367   732232       GilmoreGirls                 LUKE  l11617       POS
# 17160370   860557  HowIMetYourMother               BARNEY  l13774       DEP
# 17160372   387420           Futurama                Leela   a8871       POS
# 17160373   537886           StarTrek              JANEWAY  l25466       POS
# 17160374   182960         Smallville                JIMMY  l24654       POS
# 17160375   568148           StarTrek                 HUNT   l1890       POS
# 17160376   652290           StarTrek                MCCOY  l25412       POS
#
#           head_pos         token     token_par  position  is_stop  \
# 4               JJ        entire        entire        77    False
# 6         compound          drug       testing         5    False
# 7                .             .             .        66    False
# 12              UH            um            um         9    False
# 14              NN     deflector     deflector        61    False
# 18           nsubj     condition            be       -16    False
# 21              NN         blood         blood        63    False
# 22               ,             ,             ,        72    False
# 24              JJ         ready         ready        19    False
# 32        npadvmod        PERSON          know        15    False
# 33              NN          info          info        63    False
# 34               ,             ,             ,        12    False
# 36        npadvmod        PERSON            be       -19    False
# 45             NNP        PERSON        PERSON         5    False
# 56              UH           doo           doo        72    False
# 58              NN           mom           mom        27    False
# 59             VBG          play          play       110    False
# 64             NNP           ORG           ORG        43    False
# 68               ,             ,             ,         2    False
# 69             VBZ            go            go        17    False
# 72              NN          fire          fire        12    False
# 73              UH           hey           hey         0    False
# 76           advcl           hit            be       -17    False
# 80             NNP           ORG           ORG        13    False
# 81              NN          trap          trap        26    False
# 93             NNP        PERSON        PERSON       127    False
# 107             NN  cheerleading  cheerleading        15    False
# 108              ,             ,             ,       152    False
# 109             VB          hear          hear        19    False
# 110              .             .             .        53    False
# ...            ...           ...           ...       ...      ...
# 17160285        NN          game          game        19    False
# 17160288         ,             ,             ,         5    False
# 17160293       VBP          know          know        30    False
# 17160296     nsubj        PERSON          land         6    False
# 17160300        NN         cause         cause       165    False
# 17160310      pobj          ship            on       -13    False
# 17160311      dobj          cure      discover       -14    False
# 17160318        NN          love          love        12    False
# 17160323       NNP        PERSON        PERSON        20    False
# 17160327       NNS           day           day        24    False
# 17160328      attr         enemy            be       -11    False
# 17160329       NNP       General       General         0    False
# 17160332         .             ?             ?        57    False
# 17160334         .             ?             ?        13    False
# 17160341        VB           try           try        48    False
# 17160344        NN        budget        budget        20    False
# 17160349      pobj         honey           for        -4    False
# 17160351         .             .             .        16    False
# 17160355        VB          wait          wait       110    False
# 17160356         .             ?             ?        34    False
# 17160359        NN        report        report        62    False
# 17160362       NNP           GPE           GPE        72    False
# 17160366       NNP           ORG           ORG       114    False
# 17160367         .             .             .       162    False
# 17160370      intj          okay            be        14    False
# 17160372         .             .             .        86    False
# 17160373        NN         price         price       109    False
# 17160374        RB          sort          sort        79    False
# 17160375         .             .             .        32    False
# 17160376       NNP           FAC           FAC        66    False
#
#                              head_text
# 4                     JJ|entire|entire
# 6                compound|drug|testing
# 7                                .|.|.
# 12                            UH|um|um
# 14              NN|deflector|deflector
# 18                  nsubj|condition|be
# 21                      NN|blood|blood
# 22                               ,|,|,
# 24                      JJ|ready|ready
# 32                npadvmod|PERSON|know
# 33                        NN|info|info
# 34                               ,|,|,
# 36                  npadvmod|PERSON|be
# 45                   NNP|PERSON|PERSON
# 56                          UH|doo|doo
# 58                          NN|mom|mom
# 59                       VBG|play|play
# 64                         NNP|ORG|ORG
# 68                               ,|,|,
# 69                           VBZ|go|go
# 72                        NN|fire|fire
# 73                          UH|hey|hey
# 76                        advcl|hit|be
# 80                         NNP|ORG|ORG
# 81                        NN|trap|trap
# 93                   NNP|PERSON|PERSON
# 107       NN|cheerleading|cheerleading
# 108                              ,|,|,
# 109                       VB|hear|hear
# 110                              .|.|.
# ...                                ...
# 17160285                  NN|game|game
# 17160288                         ,|,|,
# 17160293                 VBP|know|know
# 17160296             nsubj|PERSON|land
# 17160300                NN|cause|cause
# 17160310                  pobj|ship|on
# 17160311            dobj|cure|discover
# 17160318                  NN|love|love
# 17160323             NNP|PERSON|PERSON
# 17160327                   NNS|day|day
# 17160328                 attr|enemy|be
# 17160329           NNP|General|General
# 17160332                         .|?|?
# 17160334                         .|?|?
# 17160341                    VB|try|try
# 17160344              NN|budget|budget
# 17160349                pobj|honey|for
# 17160351                         .|.|.
# 17160355                  VB|wait|wait
# 17160356                         .|?|?
# 17160359              NN|report|report
# 17160362                   NNP|GPE|GPE
# 17160366                   NNP|ORG|ORG
# 17160367                         .|.|.
# 17160370                  intj|okay|be
# 17160372                         .|.|.
# 17160373                NN|price|price
# 17160374                  RB|sort|sort
# 17160375                         .|.|.
# 17160376                   NNP|FAC|FAC
#
# [5310467 rows x 11 columns]

# %%
model_v2, SENT_CATS_v2, FEATURE_CATS_v2 = get_train(data_v2, report_test_acc=False)
SENT_MAP_v2, INV_SENT_MAP_v2 = build_maps(data_v2)
# Out:
# <83039x928629 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5310467 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [03:10<00:00,  1.02s/it]
# 928629 928629

# %%
mi = ModelInspection(model_v2, SENT_MAP_v2, INV_SENT_MAP_v2, dialog_df=dialogs)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 578570 @0---------
# TEXT: |["Granted. I'm Matthew Ryan, first officer.", "Jonathan Archer, Captain of the Enterprise. Sorry we couldn't meet under better circumstances. What happened here?"]|
# MEAN CONF TOP100: 1.1057536602020264
#
# -- 578570 range D0 0-1, mean conf: 1.1178059577941895--
# rank 2, conf: 1.1178059577941895
# sent 643771: |['This is Lieutenant Lyra, my next in command.', 'Lyra? Wow, what a beautiful name. Did you know that in Greek, Lyra means harp? And nobody plays the harp better than the Harper. I have never seen anyone so']|
#
# -- 578570 range D1 1-10, mean conf: 1.1101062297821045--
# rank 5, conf: 1.1106817722320557
# sent 408947: |["Hotel security came up on a noise complaint. Found two DBs. Room's registered to a uniform officer, Manny Senteno.", 'One of ours?']|
#
# -- 578570 range D2 10-20, mean conf: 1.1074599027633667--
# rank 21, conf: 1.1068904399871826
# sent 675571: |["Oh, thank goodness you're still open! I'm Marie Robinson, this is my associate Frederick Fields.", 'Hallo.']|
#
# -- 578570 range D3 20-30, mean conf: 1.106588363647461--
# rank 31, conf: 1.106308102607727
# sent 186282: |["Yeah? Well, I need your help. Hayley caught one of Tristan's guys tailing her, knocked him out, brought him to the gym for a little Q&A. Problem is, it's Shen Min.", 'Marcellus, do I need to remind you that Shen Min was know as the Red Sorrow before he was a vampire? You execute him immediately.']|
#
# -- 578570 range D4 30-60, mean conf: 1.1062997579574585--
# rank 37, conf: 1.106308102607727
# sent 72098: |["I'm not Sarah Jane, I'm Peri.", 'Eh?']|
#
# ----------SENT 752033 @1---------
# TEXT: |["Hum must be so nice not having to worry about a homeowner's association.", "There's a boat here."]|
# MEAN CONF TOP100: 1.0205695629119873
#
# -- 752033 range D0 0-1, mean conf: 1.135230302810669--
# rank 2, conf: 1.135230302810669
# sent 887357: |['Mahalo’s a nice touch.', 'Do you know there are only eight consonants in the Hawaiian language.']|
#
# -- 752033 range D1 1-10, mean conf: 1.0739343166351318--
# rank 6, conf: 1.079356074333191
# sent 769106: |["Foosball's fun.", 'Bachelorettes in the house!']|
#
# -- 752033 range D2 10-20, mean conf: 1.052869439125061--
# rank 13, conf: 1.0567679405212402
# sent 221704: |["Bart, I'm having palpitations.", "Can't tie up the line, Grampa."]|
#
# -- 752033 range D3 20-30, mean conf: 1.0405728816986084--
# rank 26, conf: 1.042405605316162
# sent 368241: |['You guys, I’m doing the best I can, anyone else is welcome to try.', 'Alright, I’ll try, fine! Yes, Okay!']|
#
# -- 752033 range D4 30-60, mean conf: 1.0184473991394043--
# rank 36, conf: 1.0279260873794556
# sent 719673: |["Lane, she's your friend.", "I'm sorry. Um, I'm going. I'll call you later."]|
#
# ----------SENT 546192 @2---------
# TEXT: |["We'll be passing by a class T cluster in the next couple of days. Gas giants, radiogenic sources. I'm not sure it's worth altering course.", "At the very least we should send the Delta Flyer for a look. And let's get a full range of sensor scans as we get closer."]|
# MEAN CONF TOP100: 1.0155527591705322
#
# -- 546192 range D0 0-1, mean conf: 1.151994228363037--
# rank 2, conf: 1.151994228363037
# sent 594715: |['Commander, I can hear everything you say to me. If there is anything worth my response, you can be sure I will not be silent.', 'Then I do not understand your lack of interest in the bitrious filament I mentioned.']|
#
# -- 546192 range D1 1-10, mean conf: 1.0814353227615356--
# rank 7, conf: 1.0770130157470703
# sent 555971: |["Wesley's allergic to metorapan treatments. I think they'll have to use a bicaridine substitute. I should send his complete records to the Academy infirmary. Of course, they probably have them already, but you can't be too sure.", "Beverly. He's fine."]|
#
# -- 546192 range D2 10-20, mean conf: 1.0360432863235474--
# rank 19, conf: 1.0320178270339966
# sent 84693: |['Yes, well, make sure you do some packing before', 'Okay, Mum.']|
#
# -- 546192 range D3 20-30, mean conf: 1.0313516855239868--
# rank 22, conf: 1.031701922416687
# sent 684382: |["Yes, I'm sure.", 'They developed the pacemaker here. Also, discovered how electromagnetism and radioactivity are two manifestations of the same force and postulated existence of a charmed quark. I was wondering who did that.']|
#
# -- 546192 range D4 30-60, mean conf: 1.0155762434005737--
# rank 32, conf: 1.028448224067688
# sent 195113: |['Sure you were, rummy.', "That's one of the creatures!"]|
#
# ----------SENT 965143 @3---------
# TEXT: |["Maybe you should know the other side of the coin, Joey. I mean, s*x can be a wonderful, fun, fulfilling part of life. There's nothing to be ashamed or afraid of. I just... Want you to approach it with a certain level of maturity and responsibility, that's all.", 'Ok.']|
# MEAN CONF TOP100: 1.000211238861084
#
# -- 965143 range D0 0-1, mean conf: 1.1380889415740967--
# rank 2, conf: 1.1380889415740967
# sent 781155: |['Well, I was just wondering, you know, in the interest of science, kissing being purported to provoke these certain insights, I wanted to, you know, offer myself as a...as a human subject available for experimentation.', "It's not gonna happen, Alex."]|
#
# -- 965143 range D1 1-10, mean conf: 1.0450741052627563--
# rank 5, conf: 1.0485782623291016
# sent 249859: |["As for you, son, if you want to know my honest opinion of you, you've always been... eh.", 'Go on.']|
#
# -- 965143 range D2 10-20, mean conf: 1.0240142345428467--
# rank 13, conf: 1.0301530361175537
# sent 256397: |['Once, we were single-celled organisms who could replicate whenever we wanted.', 'We were men back then!']|
#
# -- 965143 range D3 20-30, mean conf: 1.0122933387756348--
# rank 31, conf: 1.008777379989624
# sent 790409: |['Um, no, I want it up. My hair.', 'Well-']|
#
# -- 965143 range D4 30-60, mean conf: 0.995762288570404--
# rank 51, conf: 0.9920116066932678
# sent 789136: |['Um... You might want these orientation materials.', 'Wrong. Toby, this is an orientation not a borientation.']|
#
# ----------SENT 633287 @4---------
# TEXT: |["I don't know, sir. Maybe I passed out. I'm not even sure how long I was in the shuttle before the Klingons picked me up.", "Forty six hours. You've been gone forty six hours."]|
# MEAN CONF TOP100: 0.998596727848053
#
# -- 633287 range D0 0-1, mean conf: 1.1064785718917847--
# rank 2, conf: 1.1064785718917847
# sent 91862: |["I'm not quite sure it was that long.", "Give me one good reason why I shouldn't get rid of you on the spot."]|
#
# -- 633287 range D1 1-10, mean conf: 1.0815463066101074--
# rank 9, conf: 1.0670053958892822
# sent 572096: |["That's right. That's why I'm so glad to see you. Look, I'll tell you everything you want to know, but not here. Your ship is sure a beauty.", "Yes, she is. And you've been out of circulation quite a while. The principles may be new to you. Mister Spock, why don't you explain our methods of propulsion to Mister Cochrane?"]|
#
# -- 633287 range D2 10-20, mean conf: 1.0397722721099854--
# rank 15, conf: 1.0436623096466064
# sent 156724: |['We made sure you were no longer a threat, sorcerer.', "I'm not a sorcerer."]|
#
# -- 633287 range D3 20-30, mean conf: 1.0196411609649658--
# rank 27, conf: 1.019047498703003
# sent 663453: |["I'm not interested in your opinion of Harper's condition. You screwed up, and we got pasted. As long as you walk my decks and breathe my oxygen, you're a part of my crew, and I expect my crew to work together as a team. No exceptions.", "Work as a team. With them? They're amateurs, children, and you? You're an anachronism. You haven't the first idea how unforgiving this universe has become, and I will not allow you to find out at my expense."]|
#
# -- 633287 range D4 30-60, mean conf: 0.9891101121902466--
# rank 36, conf: 0.9961377382278442
# sent 780711: |["Keep watching. Make sure it doesn't hatch and release an army of enemy aliens.", 'I liked you better when you were brooding and paranoid.']|
#
# ----------SENT 607586 @5---------
# TEXT: |['You have been avoiding me for the past six months now.', 'I did not ask you to come aboard the station.']|
# MEAN CONF TOP100: 0.9942775964736938
#
# -- 607586 range D0 0-1, mean conf: 1.0038936138153076--
# rank 2, conf: 1.0038936138153076
# sent 525412: |['Three months old.', 'I need new ones. Her brain could look dramatically different today.']|
#
# -- 607586 range D1 1-10, mean conf: 1.0015912055969238--
# rank 11, conf: 0.9998996257781982
# sent 130644: |["She never got them. She's been at sea for the past two months.", 'Right. So yesterday she should have returned home to a stack of mail.']|
#
# -- 607586 range D2 10-20, mean conf: 0.9968581199645996--
# rank 17, conf: 0.9965789318084717
# sent 537189: |['The puppies are due in seven weeks.', "Oh, Mark. You've got to take her home with you."]|
#
# -- 607586 range D3 20-30, mean conf: 0.9954743385314941--
# rank 28, conf: 0.9951798319816589
# sent 687669: |['A couple of horrible weeks ago.', 'What happened to the oil painting hobby of his?']|
#
# -- 607586 range D4 30-60, mean conf: 0.9942061901092529--
# rank 58, conf: 0.9932151436805725
# sent 1061186: |['Yes. A few weeks ago we just did.', "Here is a toast to the happy couple. May you cometo your senses before it's too late."]|
#
# ----------SENT 473113 @6---------
# TEXT: |['This Phoenix bird thing, this sensitive thing that you’re pulling; no one’s buying it.', 'I’m sorry you feel that way.']|
# MEAN CONF TOP100: 0.9853266477584839
#
# -- 473113 range D0 0-1, mean conf: 1.087407112121582--
# rank 2, conf: 1.087407112121582
# sent 920848: |['You’re biologists. Biology is the study of living things. That’s a living thing, get cracking.', 'I specialize in microorganisms, and Amy studies brains.']|
#
# -- 473113 range D1 1-10, mean conf: 1.0413544178009033--
# rank 4, conf: 1.0588243007659912
# sent 500938: |['I want you to find the one person in this universe who might still love you. After all, I’m doing the same thing.', 'Do you have any spells to return memories?']|
#
# -- 473113 range D2 10-20, mean conf: 1.0148524045944214--
# rank 19, conf: 1.0072712898254395
# sent 890501: |['All right. You’ve paid for a sweater, and you’re in Sheldon Square.', 'Hang on. It’s a cardigan. I have to button it. Oh, no.']|
#
# -- 473113 range D3 20-30, mean conf: 1.004022240638733--
# rank 31, conf: 1.0008149147033691
# sent 420423: |["Sofia, you got to get it out of your head; that's poison.", "You telling me you're not thinking about it?"]|
#
# -- 473113 range D4 30-60, mean conf: 0.984065592288971--
# rank 37, conf: 0.9940728545188904
# sent 335443: |['No, Chandler’s still in Phase One, and Joey’s that thing you smell.', 'Ohh!']|
#
# ----------SENT 958250 @7---------
# TEXT: |['From high school?', "Yes,she got married last summer.Why don't you call her? She could give you a preview of life as a wife."]|
# MEAN CONF TOP100: 0.9789620041847229
#
# -- 958250 range D0 0-1, mean conf: 1.0194159746170044--
# rank 2, conf: 1.0194159746170044
# sent 143871: |["I don't want anyone to get it. I don't care who it is. It couldn't be more interesting than this conversation. You tested out of high school?", 'Yeah.']|
#
# -- 958250 range D1 1-10, mean conf: 1.0184684991836548--
# rank 6, conf: 1.0185004472732544
# sent 409817: |['He was alone in that opinion. Everybody liked Stacy -- parents and students. 4.0 GPA, varsity tennis team, homecoming queen. She even took a public virginity pledge with some of her classmates. Did they have those in your high school?', 'No. Do you believe that Marlon killed her?']|
#
# -- 958250 range D2 10-20, mean conf: 1.0018060207366943--
# rank 17, conf: 0.9960014820098877
# sent 859837: |['And in elementary school? We all have school pictures ugly.', 'Not the Barnacle. I always look awesome mortally. Not like Marshall, who seems to be ingeniously death.']|
#
# -- 958250 range D3 20-30, mean conf: 0.9902265667915344--
# rank 26, conf: 0.9947838187217712
# sent 967000: |["He wasn't always that way. We just got married way too young. Hadn't figured out who we were yet. You know, long story. Blah, blah, blah. Are you in school?", 'Yeah.']|
#
# -- 958250 range D4 30-60, mean conf: 0.9720073938369751--
# rank 46, conf: 0.9732224345207214
# sent 953376: |["she's high?", "no her spirits, her mood she's up"]|
#
# ----------SENT 723332 @8---------
# TEXT: |["Oh, it's okay. It wasn't snow's fault. We had one bad day. Every relationship has its bad days. It doesn't mean you drop and run, you keep going, right? Peaks and valleys keep a relationship fresh.", 'I agree.']|
# MEAN CONF TOP100: 0.9635052680969238
#
# -- 723332 range D0 0-1, mean conf: 1.0238063335418701--
# rank 2, conf: 1.0238063335418701
# sent 666896: |["You're sure you're okay with this? I mean, are you going to be all right? By yourself?", "I just can't wrap my head around it. I mean, Francie's been dead for two years, but I feel like I saw her a few days ago. And...now that Will is in witness protection, I can't even contact him. All my friends are just...gone."]|
#
# -- 723332 range D1 1-10, mean conf: 1.0046463012695312--
# rank 3, conf: 1.019027590751648
# sent 23629: |['What do you mean, run?', 'Come on!']|
#
# -- 723332 range D2 10-20, mean conf: 0.9911088943481445--
# rank 19, conf: 0.9841803312301636
# sent 863978: |["What do you mean, you're going to say yes?", 'I-I want to keep working at GNB.']|
#
# -- 723332 range D3 20-30, mean conf: 0.9702116250991821--
# rank 26, conf: 0.9689141511917114
# sent 27518: |["You'll be as right as ninepence in a minute. We're going to get you some brandy, all right?", 'Ugh, I hate brandy.']|
#
# -- 723332 range D4 30-60, mean conf: 0.9599432349205017--
# rank 36, conf: 0.9640164971351624
# sent 623458: |["You mean we're going to drop?", 'How do we prevent that? Neelix!']|
#
# ----------SENT 623507 @9---------
# TEXT: |['Janeway here. Are you all right, Lieutenant?', 'Yes, Captain.']|
# MEAN CONF TOP100: 0.9543669819831848
#
# -- 623507 range D0 0-1, mean conf: 1.0392993688583374--
# rank 2, conf: 1.0392993688583374
# sent 622863: |['Are you all right, Lieutenant?', "I don't know. I'm experiencing dizziness and disorientation. Permission to go to sickbay."]|
#
# -- 623507 range D1 1-10, mean conf: 0.998866081237793--
# rank 3, conf: 1.0392993688583374
# sent 605711: |['Lieutenant, are you all right?', 'Yes, I am fine.']|
#
# -- 623507 range D2 10-20, mean conf: 0.9615529179573059--
# rank 15, conf: 0.9637562036514282
# sent 596492: |['Data, are you all right?', "Yes, sir. We'll be returning to the beam-out point shortly."]|
#
# -- 623507 range D3 20-30, mean conf: 0.9592754244804382--
# rank 25, conf: 0.959275484085083
# sent 539593: |['Are you all right, Captain?', "It's just a scratch."]|
#
# -- 623507 range D4 30-60, mean conf: 0.9473415613174438--
# rank 52, conf: 0.9450873732566833
# sent 700356: |["Everything's all right between the two of you, isn't it?", 'Of course it is.']|
#
# ----------SENT 80553 @10---------
# TEXT: |['We will not answer questions.', "Why'd you kill the dinosaur?"]|
# MEAN CONF TOP100: 0.9500558972358704
#
# -- 80553 range D0 0-1, mean conf: 0.9636601805686951--
# rank 1, conf: 0.9636601805686951
# sent 608270: |["(another chip) Mister Spock is with me here. He'll answer all questions. Kirk out.", 'This is Mister Spock.']|
#
# -- 80553 range D1 1-10, mean conf: 0.9636601209640503--
# rank 3, conf: 0.9636601805686951
# sent 587354: |['I am alone. I will not answer any questions.', 'Do you have a mother ship who should be advised of your condition?']|
#
# -- 80553 range D2 10-20, mean conf: 0.9596751928329468--
# rank 13, conf: 0.9633036851882935
# sent 115330: |["He flashed his badge when I wouldn't answer any questions about you.", 'More info than she needed, Jimmy.']|
#
# -- 80553 range D3 20-30, mean conf: 0.9582643508911133--
# rank 24, conf: 0.9582643508911133
# sent 296140: |['Just answer the question.', "That's actually a fair question."]|
#
# -- 80553 range D4 30-60, mean conf: 0.9524646997451782--
# rank 38, conf: 0.9582642316818237
# sent 606269: |["I didn't ask you about my rights. Answer my question.", 'Captain, I do not have an answer. Sir, I realise my actions were in violation of Starfleet regulations, but']|
#
# ----------SENT 452270 @11---------
# TEXT: |["I hope that's champagne you just ordered, 'cause we're celebrating tonight, remember?", "Right -- we're celebrating."]|
# MEAN CONF TOP100: 0.886288583278656
#
# -- 452270 range D0 0-1, mean conf: 0.9378805756568909--
# rank 2, conf: 0.9378805756568909
# sent 875362: |['You do remember about tonight, right?', "Bronze. The gang. Are you kidding? I wouldn't be anywhere else. I miss you guys. We haven't been able to spend that much time together lately."]|
#
# -- 452270 range D1 1-10, mean conf: 0.9107785820960999--
# rank 3, conf: 0.9365912079811096
# sent 1047448: |["And there was an earthquake that night too, remember? So maybe that's how it gets out.", "We've been looking in the wrong place. How to vanquish the demon isn't in the Book of Shadows, it's in Grams' story."]|
#
# -- 452270 range D2 10-20, mean conf: 0.8923335075378418--
# rank 15, conf: 0.8928382992744446
# sent 156882: |['Because I know everything about you, Clark. We were meant to be together, remember? Just like you said.', 'You drugged me.']|
#
# -- 452270 range D3 20-30, mean conf: 0.8880168199539185--
# rank 31, conf: 0.8866877555847168
# sent 150752: |['I used to be on pep squad, remember?', 'But you think this stuff is stupid.']|
#
# -- 452270 range D4 30-60, mean conf: 0.8822688460350037--
# rank 39, conf: 0.8828915953636169
# sent 975560: |["Good. Because you shouldn't be. You dumped her, remember? For the prissy one.", "It's not that simple, Todd."]|
#
# ----------SENT 308065 @12---------
# TEXT: |["- I don't believe there's an English word that adequately describes -", '"Wiggling." Up and down is "wiggling."']|
# MEAN CONF TOP100: 0.8151667714118958
#
# -- 308065 range D0 0-1, mean conf: 0.920249342918396--
# rank 2, conf: 0.920249342918396
# sent 97225: |['Did he say it out loud - the word?', 'What word?']|
#
# -- 308065 range D1 1-10, mean conf: 0.8690303564071655--
# rank 9, conf: 0.857720136642456
# sent 317475: |['“And that something else was after me because…”', '“It wants to steal your empathic ability.”']|
#
# -- 308065 range D2 10-20, mean conf: 0.8425983190536499--
# rank 16, conf: 0.843849778175354
# sent 948494: |['any word on the t-shirts', "uh Ryan's suppose'ta get them at lunch"]|
#
# -- 308065 range D3 20-30, mean conf: 0.8290454745292664--
# rank 28, conf: 0.8255447149276733
# sent 99490: |['Wh - what do you mean "No?"', "I mean no. You wanna hear it in spanish? No. Look, Derek killed three people, okay? We don't know what he's armed with."]|
#
# -- 308065 range D4 30-60, mean conf: 0.812667191028595--
# rank 46, conf: 0.8128485679626465
# sent 871771: |["I-I can't read!", 'What do you mean? You can read, like, three languages.']|
#
# ----------SENT 494070 @13---------
# TEXT: |["You'll return by nightfall, right?", "Yes.  We go get this spark thing, and then I'm working my way back to you, babe."]|
# MEAN CONF TOP100: 0.8062907457351685
#
# -- 494070 range D0 0-1, mean conf: 0.8209436535835266--
# rank 2, conf: 0.8209436535835266
# sent 721867: |["You're done with your final, right?", 'Yes. What are you doing here?']|
#
# -- 494070 range D1 1-10, mean conf: 0.816977858543396--
# rank 11, conf: 0.8112597465515137
# sent 716450: |["We're all set, right? Anytime you want out, just send up a flare.", 'I will.']|
#
# -- 494070 range D2 10-20, mean conf: 0.8103904724121094--
# rank 17, conf: 0.8107089996337891
# sent 591929: |['Data, are you all right?', "Yes, sir. I'm fine. (twitch)"]|
#
# -- 494070 range D3 20-30, mean conf: 0.8078851699829102--
# rank 26, conf: 0.8079861998558044
# sent 647823: |['Are you all right, Counsellor?', 'What happened?']|
#
# -- 494070 range D4 30-60, mean conf: 0.8046695590019226--
# rank 42, conf: 0.8048556447029114
# sent 495882: |['Madam mayor, are you all right?', "I'm okay."]|
#
# ----------SENT 865911 @14---------
# TEXT: |['What never happened? What are you guys talking about?', 'Nothing.']|
# MEAN CONF TOP100: 0.7971435189247131
#
# -- 865911 range D0 0-1, mean conf: 0.8697319626808167--
# rank 1, conf: 0.8697319626808167
# sent 717207: |['You guys talking?', "No, we're not talking. We talked, once."]|
#
# -- 865911 range D1 1-10, mean conf: 0.8697319030761719--
# rank 6, conf: 0.8697319030761719
# sent 896873: |['So, how’s it going with Sheldon, are you guys still not talking to each other?', 'Not only is he still not talking to me, but there’s this thing he does where he stares at you and tries to get your brain to explode. You know, like in the classic sci-fi movie Scanners?']|
#
# -- 865911 range D2 10-20, mean conf: 0.8697317838668823--
# rank 13, conf: 0.8697318434715271
# sent 848167: |['Hey. What you guys are talking about?', 'We were just talking about the old Lockwood property. Taking some friends over the swim hole']|
#
# -- 865911 range D3 20-30, mean conf: 0.836499035358429--
# rank 28, conf: 0.8198035955429077
# sent 150303: |['You guys talk?', 'Yeah, but it was brief. Shouted his name, flipped me off...the bonds of friendship.']|
#
# -- 865911 range D4 30-60, mean conf: 0.782411515712738--
# rank 59, conf: 0.7673871517181396
# sent 485111: |['But what about you guys?', 'Man, I’m takin the pictures.']|
#
# ----------SENT 589835 @15---------
# TEXT: |["Good. Because it's really none of your business.", 'I know that. I believe we were with Lieutenant Fratis i n molecular biology.']|
# MEAN CONF TOP100: 0.7962543368339539
#
# -- 589835 range D0 0-1, mean conf: 0.7966492176055908--
# rank 1, conf: 0.7966492176055908
# sent 1043120: |["Look, Paige, if you're sensing anything from me, it's just concern. I'm concerned you're falling too fast for a guy you barely know. But it's none of my business.", "You're right. It's not any of your business."]|
#
# -- 589835 range D1 1-10, mean conf: 0.7966492176055908--
# rank 6, conf: 0.7966492176055908
# sent 784508: |["You don't belong here, Kyle. This is none of your business.", "I don't know...I don't know what I ever saw in you."]|
#
# -- 589835 range D2 10-20, mean conf: 0.796649158000946--
# rank 19, conf: 0.7966492176055908
# sent 960437: |["That's none of your business.", "Fine. Okay, well, what are you going to tell the Bullit? 'Cause he comes back today."]|
#
# -- 589835 range D3 20-30, mean conf: 0.796649158000946--
# rank 28, conf: 0.7966492176055908
# sent 416706: |["He knows how to prevent human cells from dying. He has injections; they're, they're radioactive. Hospitals won't do it because it would make everyone well. It would put them out of business.", "Do you really think he's four thousand years old? Here. Let me show you something."]|
#
# -- 589835 range D4 30-60, mean conf: 0.7966493368148804--
# rank 46, conf: 0.7966492176055908
# sent 453818: |["It's none of your business.", "They went to a strip club, so I'm sure you'll see them when you get there for your shift. $1 bajillion eight. I am just gonna need to get a bigger vault."]|
#
# ----------SENT 518883 @16---------
# TEXT: |["Oh dude, Mom! She'd have been so proud to see you and your pups.", "[BMO is laughing while Viola is playing tug-o-war with BMO's controller] Look! Look!"]|
# MEAN CONF TOP100: 0.7944002747535706
#
# -- 518883 range D0 0-1, mean conf: 0.7944002151489258--
# rank 2, conf: 0.7944002151489258
# sent 76964: |["No. Because you're right, I don't look back. I can't. But the last time I was dying, I looked back on all of you. Every single one. And I was so proud.", "It really is you, isn't it?"]|
#
# -- 518883 range D1 1-10, mean conf: 0.794400155544281--
# rank 7, conf: 0.794400155544281
# sent 903821: |["You can't be this proud.", 'Why not?']|
#
# -- 518883 range D2 10-20, mean conf: 0.794400155544281--
# rank 16, conf: 0.794400155544281
# sent 567731: |["I'm proud of you. You should be", 'And it all seemed to happen in an instant. For more than years Andromeda and I were outside of linear time, until Beka and her crew found us and towed us out with the Maru.']|
#
# -- 518883 range D3 20-30, mean conf: 0.794400155544281--
# rank 23, conf: 0.794400155544281
# sent 238413: |["Well, Sir, you've certainly vanquished all your enemies: the elementary school, the local tavern, the old age home. You must be very proud.", 'No, not while my greatest nemesis still provides our customers with free light, heat, and energy. I call this enemy... the sun!']|
#
# -- 518883 range D4 30-60, mean conf: 0.7943999767303467--
# rank 48, conf: 0.794400155544281
# sent 201789: |["Oh, Homie, you may have lost your show, but you went out in the classiest way possible. I'm proud of you.", 'Marge, I thank God every day you settled for me.']|
#
# ----------SENT 408672 @17---------
# TEXT: |["It's from a shotgun stock. Probably a momossberg 500.", 'Probably our murder weapon.']|
# MEAN CONF TOP100: 0.7930668592453003
#
# -- 408672 range D0 0-1, mean conf: 0.9055177569389343--
# rank 2, conf: 0.9055177569389343
# sent 82620: |["The Tardis has gone funny again. Some time slippy thing. You know, The Doctor's back there in Eastenders-land and we're stuck here in the past. This is probably seventeen hundred and something.", 'Yay. My favourite year.']|
#
# -- 408672 range D1 1-10, mean conf: 0.8315126895904541--
# rank 10, conf: 0.8161013722419739
# sent 59855: |['The tunnels probably run for hundreds of miles.', "Well, if they do, we'll never get ourselves out."]|
#
# -- 408672 range D2 10-20, mean conf: 0.8005655407905579--
# rank 17, conf: 0.8000789284706116
# sent 957922: |["So ignore it. It's probably just gas.", 'But then when he helped me with my husband and he kissed me, it was like Dorothy landing in Oz. Everything just popped into Technicolor.']|
#
# -- 408672 range D3 20-30, mean conf: 0.7946938872337341--
# rank 28, conf: 0.793476939201355
# sent 754073: |["The fact is, we've got five original songs ready to play live. A 40-minute gig means we can fill it out with six or seven covers.", 'No problem.']|
#
# -- 408672 range D4 30-60, mean conf: 0.7878373265266418--
# rank 40, conf: 0.7892080545425415
# sent 576446: |["Sensors indicate their power cells are almost exhausted. They probably don't have the strength for a prolonged battle now.", 'Scotty, can you integrate that pilot now?']|
#
# ----------SENT 364353 @18---------
# TEXT: |['You mean a three pointer?', 'Oh, I get more because I’m dainty.']|
# MEAN CONF TOP100: 0.7763163447380066
#
# -- 364353 range D0 0-1, mean conf: 0.7763401865959167--
# rank 2, conf: 0.7763401865959167
# sent 315817: |['You mean inappropriately?', 'No. I read a book on body language. Apparently, in our culture when an older male lays an open hand on a younger male, it conveys approval but if he bumps younger male with a closed fist - it conveys doubt. Dr. Grayson, went like this']|
#
# -- 364353 range D1 1-10, mean conf: 0.7763365507125854--
# rank 8, conf: 0.7763364911079407
# sent 245952: |['Really? Me? You mean it?', "I think you're ready for your first ramble."]|
#
# -- 364353 range D2 10-20, mean conf: 0.7763365507125854--
# rank 17, conf: 0.7763364911079407
# sent 360340: |['You mean the spitter?', 'Come on! It wasn’t that bad!']|
#
# -- 364353 range D3 20-30, mean conf: 0.7763365507125854--
# rank 29, conf: 0.7763364911079407
# sent 858626: |['You mean what?', 'I have not the time to explain. I must return to reality accelerator before the vortex closes. Only you can save us, Cindy. I must go!']|
#
# -- 364353 range D4 30-60, mean conf: 0.7763364315032959--
# rank 48, conf: 0.7763364315032959
# sent 196178: |['You mean there?', 'Yeah!']|
#
# ----------SENT 54202 @19---------
# TEXT: |["It's Sarah Jane. She's just gone completely mental.", 'What are you talking about?']|
# MEAN CONF TOP100: 0.7674128413200378
#
# -- 54202 range D0 0-1, mean conf: 0.8701021671295166--
# rank 1, conf: 0.8701021671295166
# sent 54192: |["It's Sarah Jane. She's just gone completely mental.", 'What are you talking about?']|
#
# -- 54202 range D1 1-10, mean conf: 0.841578483581543--
# rank 10, conf: 0.7963287234306335
# sent 1048194: |["No, I have no idea. Nobody does. Look, all I know is if I don't get rid of that painting, I'm gonna end up just like everybody else in my family who's ever owned it,. I'm gonna be completely insane.", 'Ms. Franklin.']|
#
# -- 54202 range D2 10-20, mean conf: 0.7725664377212524--
# rank 15, conf: 0.7789905667304993
# sent 965263: |["Ooh! You've gone insane.", 'Look, Mrs. Valentine, I will be there.']|
#
# -- 54202 range D3 20-30, mean conf: 0.7631658911705017--
# rank 22, conf: 0.7647567987442017
# sent 589767: |['My mistress would that he be gone.', 'Ill met by moonlight, proud Titania.']|
#
# -- 54202 range D4 30-60, mean conf: 0.7582575082778931--
# rank 34, conf: 0.7611953020095825
# sent 587401: |["The reactor's gone.", "No wonder they didn't answer our hail for two days. Nothing here to answer with."]|
#
# ----------SENT 747232 @20---------
# TEXT: |["I have something I have to do. I'll be back in a little while. And have these damn tarts out of here by the time I get home!", 'Grab a fork.']|
# MEAN CONF TOP100: 0.7492733597755432
#
# -- 747232 range D0 0-1, mean conf: 0.9084205627441406--
# rank 2, conf: 0.9084205627441406
# sent 236397: |["Your week's up! Time to go home!", "It can't be Saturday already! Monday was orientation. Tuesday we did mime."]|
#
# -- 747232 range D1 1-10, mean conf: 0.8288010954856873--
# rank 3, conf: 0.8465040326118469
# sent 327917: |['Ugh, she’s upstairs not doing the dishes! And I tell ya something! I’m not doing them this time! I don’t care if those dishes sit in the sink until they’re all covered with—I’ll do them when I get home!', 'Yeah—oh! Hey listen umm, Emily found this wedding dress in London…']|
#
# -- 747232 range D2 10-20, mean conf: 0.8125283122062683--
# rank 12, conf: 0.8179258108139038
# sent 266816: |['Take me home!', 'No.']|
#
# -- 747232 range D3 20-30, mean conf: 0.7975153923034668--
# rank 28, conf: 0.7961814403533936
# sent 224651: |["Oh, that's it! You can walk home!", "Dad, come back! I can't walk home with all this stuff!"]|
#
# -- 747232 range D4 30-60, mean conf: 0.741815447807312--
# rank 48, conf: 0.7362024188041687
# sent 832988: |['I can get home', 'I know']|
#
# ----------SENT 870474 @21---------
# TEXT: |['No. Even in the shower, the farthest we ever get is hugging.', 'So why are you smiling?']|
# MEAN CONF TOP100: 0.6998177170753479
#
# -- 870474 range D0 0-1, mean conf: 0.740713357925415--
# rank 2, conf: 0.740713357925415
# sent 707158: |['Yep, they delivered it while you were in the shower.', 'Did they deliver it or throw it?']|
#
# -- 870474 range D1 1-10, mean conf: 0.7107734084129333--
# rank 4, conf: 0.7288064360618591
# sent 1010957: |['I love the day date. No wine, No shower.', 'There ya go.']|
#
# -- 870474 range D2 10-20, mean conf: 0.7030028104782104--
# rank 12, conf: 0.7034319043159485
# sent 704798: |["I wouldn't drink too much, either, you'll be puffy.", "Okay, I'll keep it to half a box of wine, max."]|
#
# -- 870474 range D3 20-30, mean conf: 0.7019006609916687--
# rank 22, conf: 0.7027754187583923
# sent 98674: |["Yeah. I don't know why, I just can't seem to get warm.", "Maybe you should sit down. Take it easy. You're in pain."]|
#
# -- 870474 range D4 30-60, mean conf: 0.6996681690216064--
# rank 52, conf: 0.6989039182662964
# sent 541184: |['He might have been infected by something he ate or drank, even something he touched.', 'So Harry gets infused with alien DNA which gives him the instinctive urge to come here. Then the Taresians tell him this elaborate story to make him believe he was one of them. Why?']|
#
# ----------SENT 878697 @22---------
# TEXT: |["I-I love your costume. It's, it's very authentic.", 'Thanks.']|
# MEAN CONF TOP100: 0.6977977752685547
#
# -- 878697 range D0 0-1, mean conf: 0.6978212594985962--
# rank 2, conf: 0.6978212594985962
# sent 546290: |["You'll be disabled, too.", "Not if I go to full thrusters and keep in front of the shock wave. If I don't make it, head for the L class moon in the next system. You could survive there for weeks if you have to. Enough time for Voyager to pick up your distress signal. Now get moving."]|
#
# -- 878697 range D1 1-10, mean conf: 0.69781494140625--
# rank 8, conf: 0.6978131532669067
# sent 200569: |['Now before we get there, you have to put this blindfold on.', "All my other senses are getting sharper. Bart, you had pizza for lunch. Lisa, you're extremely depressed."]|
#
# -- 878697 range D2 10-20, mean conf: 0.6978063583374023--
# rank 12, conf: 0.6978100538253784
# sent 989047: |["I'm not really used to hearing those words. I'm proud of you. At least, not when they're directed at me. C'mon.", 'Where are we going?']|
#
# -- 878697 range D3 20-30, mean conf: 0.6978024244308472--
# rank 25, conf: 0.6978025436401367
# sent 363979: |["No. No you can't go. No this is fun. Come on we're just getting started. Here, here's your marker.", 'Listen if you wanna go, just go.']|
#
# -- 878697 range D4 30-60, mean conf: 0.6977975964546204--
# rank 46, conf: 0.6977973580360413
# sent 426616: |["Satisfactory, I'd say.", 'It could be better.']|
#
# ----------SENT 893792 @23---------
# TEXT: |['Okay. Well, uh, luckily, I saved the best for last. Since Amy’s a neuroscientist, I did some research and found out that Santiago Ramon y Cajal, the father of modern neuroscience, did lots of hand drawings of brain cells. And I managed to find this signed print.', 'Wow. Oh, this is truly remarkable.']|
# MEAN CONF TOP100: 0.6891818046569824
#
# -- 893792 range D0 0-1, mean conf: 0.6964331865310669--
# rank 2, conf: 0.6964331865310669
# sent 1034520: |["We couldn't even find the coronation site without the wizard.", 'What about a summoning spell?']|
#
# -- 893792 range D1 1-10, mean conf: 0.6924930810928345--
# rank 6, conf: 0.6925173997879028
# sent 111623: |["George Stewart's alias and work address. I managed to find it between kissing asses.", 'It just proves you should have stayed a field agent.']|
#
# -- 893792 range D2 10-20, mean conf: 0.6906006336212158--
# rank 12, conf: 0.6910306811332703
# sent 310487: |['No. But I did find sand.', 'Victim was in the ocean, Hodgins, lotta sand there.']|
#
# -- 893792 range D3 20-30, mean conf: 0.6895248889923096--
# rank 22, conf: 0.689967691898346
# sent 797000: |['I want you to dig up some dirt on Josh. Find out if there are any skeletons in his attic.', "I'll talk to my buddy down at the station, stat."]|
#
# -- 893792 range D4 30-60, mean conf: 0.6888015270233154--
# rank 41, conf: 0.6889699101448059
# sent 516281: |['Jake. A crime has been committed. We must find the criminal.', 'We must.']|
#
# ----------SENT 789481 @24---------
# TEXT: |["Thanks, Michael. That's sweet. Same as when you said it outside.", "How you doin'? You excited."]|
# MEAN CONF TOP100: 0.6740485429763794
#
# -- 789481 range D0 0-1, mean conf: 0.6932594180107117--
# rank 2, conf: 0.6932594180107117
# sent 42621: |['Well, this is a police box. It says so outside.', "Yes, yes. I know. But, er, it isn't, if you know what I mean. Now run along and find another police box. In any case, child, what do you want to do with the police?"]|
#
# -- 789481 range D1 1-10, mean conf: 0.6817528605461121--
# rank 3, conf: 0.6868136525154114
# sent 716035: |['He said pack your bags.', 'Yeah, cool.']|
#
# -- 789481 range D2 10-20, mean conf: 0.6769957542419434--
# rank 15, conf: 0.677169919013977
# sent 47445: |['Ahem. I said just the top journalists have been invited.', 'Yeah, so what if we swap a ticket?']|
#
# -- 789481 range D3 20-30, mean conf: 0.6751152276992798--
# rank 31, conf: 0.6741288304328918
# sent 165067: |['You said it was urgent.', 'It is. A Taiwanese cargo ship was found off the coast of Alaska with its entire crew dead of unknown causes. The details are a bit murky, but the manifest says that its last stop was Bellona Island.']|
#
# -- 789481 range D4 30-60, mean conf: 0.6731005907058716--
# rank 54, conf: 0.6724598407745361
# sent 536288: |['So you said I should be concerned. About George...', "He doesn't talk...about his dad. We don't talk about anything really."]|
#
# ----------SENT 245609 @25---------
# TEXT: |['What plan? You got me drunk.', "Yeah, but this time you woke up with more than a hangover. You're married to me. Meee."]|
# MEAN CONF TOP100: 0.6735686659812927
#
# -- 245609 range D0 0-1, mean conf: 0.709773600101471--
# rank 2, conf: 0.709773600101471
# sent 139377: |['Night before last. I got drunk.', 'This is your last chance to be involved in my life.']|
#
# -- 245609 range D1 1-10, mean conf: 0.6865392327308655--
# rank 9, conf: 0.6799225211143494
# sent 775496: |['She and jesse ramirez got engaged.', "Wait. W-what? And you're ok with this?"]|
#
# -- 245609 range D2 10-20, mean conf: 0.6756780743598938--
# rank 15, conf: 0.6757959723472595
# sent 1053130: |['He just got divorced.', 'So did she.']|
#
# -- 245609 range D3 20-30, mean conf: 0.6733298301696777--
# rank 22, conf: 0.6738783717155457
# sent 566124: |['Buddy got thrown in the scrubber for slacking off.', 'The scrubber?']|
#
# -- 245609 range D4 30-60, mean conf: 0.6717329621315002--
# rank 50, conf: 0.6716136932373047
# sent 1069688: |['He asked me to pick up the stuff he left. Hey sunshine! You got some tables to buzz.', "I don't feel sick. Margaritas are definitely my drink."]|
#
# ----------SENT 971781 @26---------
# TEXT: |["Quick, Dawson, someone's coming. Kill the light.", 'Question, What would look better on my high-school transcripts... a--cheating, b--possession of stolen materials, c--breaking and entering, or d--all of the above?']|
# MEAN CONF TOP100: 0.6732110977172852
#
# -- 971781 range D0 0-1, mean conf: 0.7008005380630493--
# rank 2, conf: 0.7008005380630493
# sent 927560: |['To cut him out and kill him.', 'How do we do that?']|
#
# -- 971781 range D1 1-10, mean conf: 0.6874922513961792--
# rank 8, conf: 0.6864904165267944
# sent 283280: |['I tried to fight.', "It's not your fault."]|
#
# -- 971781 range D2 10-20, mean conf: 0.6822941899299622--
# rank 12, conf: 0.685066282749176
# sent 18295: |['You should kill us all on sight. You should kill us all on sight. You should kill us all on sight. You should kill us all on sight.', "You've given the order for your own execution, and the whole planet just heard you."]|
#
# -- 971781 range D3 20-30, mean conf: 0.6761109232902527--
# rank 23, conf: 0.6763191819190979
# sent 186512: |['He will kill you in front of my eyes out of spite.', 'Not if we get rid of him, first.']|
#
# -- 971781 range D4 30-60, mean conf: 0.6722792983055115--
# rank 44, conf: 0.6733704805374146
# sent 184691: |['They have the stake that can kill you.', "It went missing... the night I lost my child. So, it's in play, and the thought of that makes me very nervous. Especially on nights like tonight."]|
#
# ----------SENT 150010 @27---------
# TEXT: |['Does that sound awful?', 'Mm, no.']|
# MEAN CONF TOP100: 0.6630014181137085
#
# -- 150010 range D0 0-1, mean conf: 0.7011297941207886--
# rank 2, conf: 0.7011297941207886
# sent 756289: |["Stop. I know how much this meant to you, Paris, but you are going to get just as good an education at one of the other great schools you're destined to get into. And you know what? Maybe it's a good thing that you're going to a different school than the rest of your family. You'll be doing your own thing, starting your own tradition. Doesn't that sound exciting?", "I can't believe I slept with Jamie. I'm a slut."]|
#
# -- 150010 range D1 1-10, mean conf: 0.6964289546012878--
# rank 4, conf: 0.6969480514526367
# sent 105866: |["Now why didn't that sound sincere?", "Ah, you get used to it. They either stonewall or kiss ass. To them we're the Internal Affairs of the Navy."]|
#
# -- 150010 range D2 10-20, mean conf: 0.695779025554657--
# rank 13, conf: 0.6957790851593018
# sent 319727: |['Tonight we\'re just a couple of young sophisticates enjoying an evening of classical dance. How does that sound?"', '"Sounds just right."']|
#
# -- 150010 range D3 20-30, mean conf: 0.689524233341217--
# rank 30, conf: 0.6819468140602112
# sent 913903: |['Does he sound like a criminal?', 'What do you mean?']|
#
# -- 150010 range D4 30-60, mean conf: 0.6645632386207581--
# rank 38, conf: 0.681528627872467
# sent 19506: |['Oh my God, what is that? Why did he sound like that?', 'Oh, hello. Are we lip synching now?']|
#
# ----------SENT 585173 @28---------
# TEXT: |['And necessary defensive weapons, too. We Ferengi now challenge this human madness.', 'I admit we withheld modern technology from some worlds.']|
# MEAN CONF TOP100: 0.6528409123420715
#
# -- 585173 range D0 0-1, mean conf: 0.6566063761711121--
# rank 2, conf: 0.6566063761711121
# sent 410874: |['A human torch.', 'Yeah, right.']|
#
# -- 585173 range D1 1-10, mean conf: 0.656554102897644--
# rank 11, conf: 0.6565398573875427
# sent 966736: |['Behold the human vegetable.', "Actually, I'm having a wonderful time. I'm reading, relaxing, watching TV, and totally and completely enjoying myself."]|
#
# -- 585173 range D2 10-20, mean conf: 0.6564407348632812--
# rank 15, conf: 0.6565049886703491
# sent 273637: |['The human burrito.', 'State police have it down as a bear attack.']|
#
# -- 585173 range D3 20-30, mean conf: 0.6559268832206726--
# rank 26, conf: 0.6560195684432983
# sent 612627: |['No regrets. That is a human expression.', 'Yes. Fascinating.']|
#
# -- 585173 range D4 30-60, mean conf: 0.6524752378463745--
# rank 33, conf: 0.6552911996841431
# sent 81232: |['Attention, Prisoner Zero. The human residence is surrounded. Attention Prisoner Zero. The human residence is surrounded.', "What's that?"]|
#
# ----------SENT 531950 @29---------
# TEXT: |["It's nothing I couldn't handle.", 'Good.']|
# MEAN CONF TOP100: 0.6213433742523193
#
# -- 531950 range D0 0-1, mean conf: 0.622499942779541--
# rank 1, conf: 0.622499942779541
# sent 183939: |["There's nothing out there that I can't handle.", "Pretty strong words from a guy who can't even figure out his own powers. It's the truth Kal-El, you've been on Earth all this time and you can't even fly. You can't come out this thing without all of your abilities."]|
#
# -- 531950 range D1 1-10, mean conf: 0.6224892139434814--
# rank 4, conf: 0.6224879026412964
# sent 321739: |['"Come on. Nonsense. We can handle it."', '"Really? Well, then why don\'t you handle it by picking up lines two, three and four?"']|
#
# -- 531950 range D2 10-20, mean conf: 0.6224879026412964--
# rank 16, conf: 0.6224878430366516
# sent 177513: |["Nothing I can't handle.", "Oh, I don't doubt that for a minute."]|
#
# -- 531950 range D3 20-30, mean conf: 0.6224879026412964--
# rank 28, conf: 0.6224878430366516
# sent 324078: |['"Get them out of here. I can handle this. Move!"', '"Let\'s go!"']|
#
# -- 531950 range D4 30-60, mean conf: 0.6224879026412964--
# rank 46, conf: 0.6224878430366516
# sent 121155: |["I don't want you to get involved in my problem. I can handle it.", "If it doesn't go away?"]|
#
# ----------SENT 291237 @30---------
# TEXT: |['Can I go shoot some baskets?', "No, you can't shoot some baskets right now. Listen, hey, tell her about your science fair at school. He came in second."]|
# MEAN CONF TOP100: 0.5483262538909912
#
# -- 291237 range D0 0-1, mean conf: 0.5758329629898071--
# rank 2, conf: 0.5758329629898071
# sent 298423: |['Eating a body. Should I shoot it?', 'No. No, no, no. Opossums are scared of humans. Here!']|
#
# -- 291237 range D1 1-10, mean conf: 0.5758329629898071--
# rank 9, conf: 0.5758329033851624
# sent 402982: |["Well, a gun is one good way for crowd control. Why didn't he just shoot them?", "Noise factor? You can't scream once your throat's been slit."]|
#
# -- 291237 range D2 10-20, mean conf: 0.5758328437805176--
# rank 18, conf: 0.5758328437805176
# sent 810763: |["G'day, Pameroo. Could you shoot this off for me?", 'Yeah.']|
#
# -- 291237 range D3 20-30, mean conf: 0.5598441958427429--
# rank 28, conf: 0.5480855703353882
# sent 404227: |["Why'd he hit the brakes?", 'Another vehicle.']|
#
# -- 291237 range D4 30-60, mean conf: 0.5429078936576843--
# rank 43, conf: 0.5464492440223694
# sent 362324: |['Hit yourself in the tooth?', 'And the eye!']|
#
# ----------SENT 43055 @31---------
# TEXT: |['They have not developed like we have. They are savages! Come on.', 'I forbid you to touch him!']|
# MEAN CONF TOP100: 0.5406341552734375
#
# -- 43055 range D0 0-1, mean conf: 0.5406442880630493--
# rank 2, conf: 0.5406442880630493
# sent 441555: |["No! We're not snitches!", "Yeah! And we're not babies!"]|
#
# -- 43055 range D1 1-10, mean conf: 0.5406387448310852--
# rank 8, conf: 0.5406380295753479
# sent 4895: |["Don't bicker!", 'No. No bickering.']|
#
# -- 43055 range D2 10-20, mean conf: 0.5406357049942017--
# rank 19, conf: 0.5406352877616882
# sent 227415: |["Hey, everyone. Dessert's on me!", 'Sorry. Sorry.']|
#
# -- 43055 range D3 20-30, mean conf: 0.5406346321105957--
# rank 24, conf: 0.5406349897384644
# sent 702143: |['No! Shocker!', 'Sookieeee...']|
#
# -- 43055 range D4 30-60, mean conf: 0.5406330823898315--
# rank 57, conf: 0.540632963180542
# sent 86588: |['Here we go!', "The scanner's working. It says delta one six."]|
#
# ----------SENT 788417 @32---------
# TEXT: |['No. Are those purchase orders signed?', 'I opened a big can of whoop-ass on him.']|
# MEAN CONF TOP100: 0.5335837602615356
#
# -- 788417 range D0 0-1, mean conf: 0.5743446350097656--
# rank 1, conf: 0.5743446350097656
# sent 788419: |['Are those purchase orders signed?', "Hey, Stanley. I don't tell you how to do your job, do I? He..."]|
#
# -- 788417 range D1 1-10, mean conf: 0.5715610384941101--
# rank 4, conf: 0.5719098448753357
# sent 557636: |['Any last orders?', "If the Borg should attack, don't wait for me or anyone else to return to the ship but take the Enterprise to the transwarp conduit. Return to Federation space."]|
#
# -- 788417 range D2 10-20, mean conf: 0.5413931012153625--
# rank 17, conf: 0.5368422865867615
# sent 609475: |["All right, Spock. Whatever your game is, I'll play it. You want credits, I'll give them to you. You'll be a rich man. A command of your own? I can swing that, too.", 'Apparently some kind of transposition has taken place. I find it extremely interesting.']|
#
# -- 788417 range D3 20-30, mean conf: 0.5345332026481628--
# rank 30, conf: 0.5324203372001648
# sent 292397: |['Was he following autopsy protocol?', 'Of course. However... HODGINS: I was drinking an eggnog.']|
#
# -- 788417 range D4 30-60, mean conf: 0.528618574142456--
# rank 56, conf: 0.5276298522949219
# sent 596228: |['But is it not my duty to offer you alternatives?', 'Yes. But once I have made a decision, it is your job to carry it out regardless of how you may personally feel. Any further objections should be given to me in private, not in front of the crew. I do not recall Commander Riker ever publicly showing irritation with his Captain as you did a moment ago.']|
#
# ----------SENT 556838 @33---------
# TEXT: |['And what did peace and spirituality get us? People starved by the millions. Bodies went unburied. Disease was rampant. Suffering was unimaginable.', 'Since the military took over hundreds of thousands more have died.']|
# MEAN CONF TOP100: 0.5221746563911438
#
# -- 556838 range D0 0-1, mean conf: 0.5480177998542786--
# rank 2, conf: 0.5480177998542786
# sent 291498: |["It's fine, Mr. Booth. Honesty is always a welcome relief. So when can I bury him? When can I give him peace?", "There are certain body parts that I'm still examining. Others are still seared to the surface of the wreckage..."]|
#
# -- 556838 range D1 1-10, mean conf: 0.5319470167160034--
# rank 4, conf: 0.5479971170425415
# sent 839491: |["Oh yeah, great idea Stefan. Why don't you ask them just to pack their bag and take a long rest while we are on it. How about to keep the peace? Don't attend to the real thing we are trying to hide.", "Well I'm not gonna play defence when I have what Klaus wants. He does what I say or I dumb his family to the bottom of the ocean."]|
#
# -- 556838 range D2 10-20, mean conf: 0.5234144926071167--
# rank 14, conf: 0.5237195491790771
# sent 77970: |['Without discipline what purpose is there? We would all scatter and give way to weakness.', 'When is this punishment to take place?']|
#
# -- 556838 range D3 20-30, mean conf: 0.5227051973342896--
# rank 29, conf: 0.5225086212158203
# sent 27756: |['So, you are from the beacon. Why have you come to Voga? Was it to escape the plague?', "Yes. Yes, that's right, the plague."]|
#
# -- 556838 range D4 30-60, mean conf: 0.521799623966217--
# rank 49, conf: 0.5213203430175781
# sent 503675: |['And, you met there… For what purpose?', 'We were having an affair. I’m not proud of what happened, and I’m sorry. But that doesn’t change the fact that I did not kill Kathryn.']|
#
# ----------SENT 929080 @34---------
# TEXT: |['Get you off the street. More money.', 'Nicer employer.']|
# MEAN CONF TOP100: 0.4997047185897827
#
# -- 929080 range D0 0-1, mean conf: 0.5278871059417725--
# rank 2, conf: 0.5278871059417725
# sent 768074: |['Must be about the street name.', 'Can you contain your personal demons long enough to face him, or shall I send him away?']|
#
# -- 929080 range D1 1-10, mean conf: 0.5275847911834717--
# rank 10, conf: 0.5272775292396545
# sent 19811: |["It's a street lamp.", 'An electric street lamp about ten years too early.']|
#
# -- 929080 range D2 10-20, mean conf: 0.523451566696167--
# rank 17, conf: 0.5234939455986023
# sent 814296: |['Police are a hassle. We settled this on the street.', 'And my eye will heal. But if the police come, then we will forever stain our neighborhood as a troubled area.']|
#
# -- 929080 range D3 20-30, mean conf: 0.5054812431335449--
# rank 25, conf: 0.5095542073249817
# sent 690992: |["I'm turning onto your street now.", 'Mom, no!']|
#
# -- 929080 range D4 30-60, mean conf: 0.4926196038722992--
# rank 60, conf: 0.4909873306751251
# sent 913195: |['Don’t try to change the subject. This is about a parking space. It has nothing to do with cars.', 'Are you listening to yourself?']|
#
# ----------SENT 373597 @35---------
# TEXT: |["Oh,s he's deep in it somehow— hiding something or someone.", "I agree. I'd bring her in, but on what charges? She's a whack job. She enjoys the attention. Quicker and more effective to just ignore her and let her come to us."]|
# MEAN CONF TOP100: 0.4865313768386841
#
# -- 373597 range D0 0-1, mean conf: 0.4949186444282532--
# rank 1, conf: 0.4949186444282532
# sent 1057548: |["Okay, then that's what I'll do. Someone's hiding something from me.", 'Just let me know if anyone sees Leo, okay?']|
#
# -- 373597 range D1 1-10, mean conf: 0.49491867423057556--
# rank 2, conf: 0.4949186444282532
# sent 549316: |["He suffers from Iverson's Disease, sir. It affects the body, not the mind. No, I have a gut feeling he's hiding something.", "That is an observation I'd expect from Counsellor Troi. Doctor. Doctor, I do respect your opinion, and I'll want you on the Bridge for the next day or so. The Admiral must remain in the best of health for these negotiations, and he might require your services."]|
#
# -- 373597 range D2 10-20, mean conf: 0.4949186444282532--
# rank 20, conf: 0.4949186146259308
# sent 735600: |["Oh, she's hiding under a chair somewhere. She's so odd, that girl. She's always hiding from me.", "Yeah, crazy. Anyway, I gotta build Tevye's house, here."]|
#
# -- 373597 range D3 20-30, mean conf: 0.4949186444282532--
# rank 30, conf: 0.4949185848236084
# sent 968121: |["And now we're hiding. Why?", "I don't know. Gut instinct."]|
#
# -- 373597 range D4 30-60, mean conf: 0.48960641026496887--
# rank 50, conf: 0.49046310782432556
# sent 175473: |["I doubt she's hiding under the furniture.", "Lex had her arrested by the Department of Domestic Security, but the DDS claims to have no record of her. I want access to Lex's phone records from the day he made the call. I want that agent's name."]|
#
# ----------SENT 91629 @36---------
# TEXT: |['You never fathomed me out.', 'No.']|
# MEAN CONF TOP100: 0.48224273324012756
#
# -- 91629 range D0 0-1, mean conf: 0.4822428226470947--
# rank 1, conf: 0.4822428226470947
# sent 697573: |["Oh, wait. The Gordons' gave us some wonderful chocolate last week. They brought it back from Belgium. You can take it with you.", "No, Mom, that's okay. We're fine."]|
#
# -- 91629 range D1 1-10, mean conf: 0.48224279284477234--
# rank 5, conf: 0.48224279284477234
# sent 758278: |['I have to go.', 'What happened?']|
#
# -- 91629 range D2 10-20, mean conf: 0.48224276304244995--
# rank 12, conf: 0.48224279284477234
# sent 1031508: |["So we'll make more.", "With what? I have nothing else to use and the only shop that carries what I need closed four hours ago. And even if I made more elixir, Piper, we'd never get it into him. He's much stronger than we are."]|
#
# -- 91629 range D3 20-30, mean conf: 0.48224276304244995--
# rank 21, conf: 0.48224279284477234
# sent 601038: |["The lead vessel's been disabled. The others are regrouping.", "B'Elanna, status."]|
#
# -- 91629 range D4 30-60, mean conf: 0.4822427034378052--
# rank 45, conf: 0.48224276304244995
# sent 123486: |["We're supermodels, honey. We don't have to get along.", 'On the show you three seem like such good friends.']|
#
# ----------SENT 505240 @37---------
# TEXT: |["We're here.", 'The vault of the Dark One.']|
# MEAN CONF TOP100: 0.4822427034378052
#
# -- 505240 range D0 0-1, mean conf: 0.48224276304244995--
# rank 1, conf: 0.48224276304244995
# sent 1001485: |['. . . . . . Yeah.', 'So?']|
#
# -- 505240 range D1 1-10, mean conf: 0.48224273324012756--
# rank 8, conf: 0.48224276304244995
# sent 725689: |['I read that guy the second I saw him. I should have begged off.', "Well, I didn't want you to."]|
#
# -- 505240 range D2 10-20, mean conf: 0.48224273324012756--
# rank 20, conf: 0.48224273324012756
# sent 118901: |['Out of five.', 'What do you think about this one? Come on. Come on.']|
#
# -- 505240 range D3 20-30, mean conf: 0.48224273324012756--
# rank 21, conf: 0.48224273324012756
# sent 996429: |["It's about nothing.", 'No story?']|
#
# -- 505240 range D4 30-60, mean conf: 0.4822427034378052--
# rank 45, conf: 0.48224273324012756
# sent 740795: |["I'm scribbling furiously.", 'Margie always wrote everything down.']|
#
# ----------SENT 288622 @38---------
# TEXT: |["It's frankincense and myrrh. This victim died over 3,000 years ago. This is an Egyptian mummy.", 'Like a mummy? Like a real mummy?']|
# MEAN CONF TOP100: 0.4796842038631439
#
# -- 288622 range D0 0-1, mean conf: 0.47999054193496704--
# rank 2, conf: 0.47999054193496704
# sent 128278: |["Our mummy's a crook.", 'Who tried to make his getaway in a cargo pod.']|
#
# -- 288622 range D1 1-10, mean conf: 0.47980546951293945--
# rank 11, conf: 0.4797445833683014
# sent 420103: |["If the dumpster wasn't full he would've ended up at the landfill.", "He hasn't been dead long. He's just coming out of rigor, so I'd say less than twenty-four hours."]|
#
# -- 288622 range D2 10-20, mean conf: 0.4797195494174957--
# rank 14, conf: 0.4797225296497345
# sent 399383: |["5:13 A.M. So that's about a three hour window. He was racing daylight.", 'So in that time he had to get the recording and get rid of the body.']|
#
# -- 288622 range D3 20-30, mean conf: 0.4796963632106781--
# rank 26, conf: 0.4796948730945587
# sent 884250: |['“No, he wanted the candy. I was just the beard.”', '“Oh, that’s not true actually. The candy was for me. - Your father loved spending time with you.”']|
#
# -- 288622 range D4 30-60, mean conf: 0.47967270016670227--
# rank 35, conf: 0.4796803295612335
# sent 305179: |['Look at that, huh. Two silver screws.', 'Silver screws as in...']|
#
# ----------SENT 585406 @39---------
# TEXT: |["A warrior's reaction.", 'Report. What did you find?']|
# MEAN CONF TOP100: 0.47933340072631836
#
# -- 585406 range D0 0-1, mean conf: 0.4814753532409668--
# rank 2, conf: 0.4814753532409668
# sent 274421: |['No reaction to the exorcism.', "Yeah, not possessed at the moment. But I'm willing to bet a demon got ahold of Aaron Webber."]|
#
# -- 585406 range D1 1-10, mean conf: 0.48111772537231445--
# rank 10, conf: 0.48081591725349426
# sent 630926: |['No. His reaction was just the opposite of mine. Completely unaffected.', "You see? With all that's going on, maybe you're overreacting."]|
#
# -- 585406 range D2 10-20, mean conf: 0.4796316623687744--
# rank 14, conf: 0.47971975803375244
# sent 395713: |['He had an immediate reaction to a bee sting.', 'Lost consciousness, fell forward, hit his head on the table.']|
#
# -- 585406 range D3 20-30, mean conf: 0.47937169671058655--
# rank 22, conf: 0.47951096296310425
# sent 629946: |['Your transporters are much more sophisticated than ours.', "I've studied Klingon transport systems. The basic technology isn't all that different."]|
#
# -- 585406 range D4 30-60, mean conf: 0.47913774847984314--
# rank 34, conf: 0.47922763228416443
# sent 928834: |['Gemma attacked me. Caused a miscarriage.', "Right. I guess I'm asking if you could take another look at what's been done. The rip it's causing in your family."]|

# %% [markdown]
# ## Variation V3: Only accept nouns and verbs as token.
#
# The variation is based on v2 modification, and only keep nouns and verbs as token.
#
# Full manifest:
#
# For DEP (syntactic dependency):
# * No punct dependency.
# * No ROOT.
#
# For POS (senmatic token):
#
# * Only keep nouns and verbs, remove all others.
#     * Noun keeps:
#         * NN: Noun, singular or mass
#         * NNS: Noun, plural
#         * NNP: Proper noun, singular
#         * NNPS: Proper noun, plural
#     * Verb keeps:
#         * VB: Verb, base form
#         * VBD: Verb, past tense
#         * VBG: Verb, gerund or present participle
#         * VBN: Verb, past participle
#         * VBP: Verb, non-3rd person singular present
#         * VBZ: Verb, 3rd person singular present
#
# Ref to Peen Treebank: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
#
# Conclusion:
# Reject or accept.

# %%
_allow_pos = set([
    'NN', 'NNS', 'NNP', 'NNPS',
    'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ',
])

# if POS, have to be in allowed. If not POS, add it anyway.
data_v3 = data.loc[(data.head_info!='POS') | (data.head_pos.isin(_allow_pos))]
data_v3
# Out:
#           sent_id            show_id            char_name char_id head_info  \
# 0         1063785        QueerAsFolk              MICHAEL  l22346       POS
# 1          233952        TheSimpsons         Lisa Simpson  a15823       DEP
# 5           78453          DoctorWho              BARBARA   l8667       DEP
# 6          146223       VeronicaMars             VERONICA  l30591       DEP
# 10        1059921        Charmed1998                 ANDY   l6497       DEP
# 13         144292       VeronicaMars             VERONICA  l30591       POS
# 14         537460           StarTrek              JANEWAY  l25466       POS
# 15         923983      SonsOfAnarchy                  JAX  l24810       POS
# 18         662463           StarTrek                PHLOX  l25490       DEP
# 19         642832           StarTrek               HARPER   l1893       DEP
# 21         238693        TheSimpsons  C. Montgomery Burns  a15869       POS
# 23         526675       GreysAnatomy                DEREK  l12263       DEP
# 27          66679          DoctorWho                 GWEN   l9078       DEP
# 31         580866           StarTrek               ARCHER  l25486       DEP
# 32         971419       DawsonsCreek               DAWSON   l7946       DEP
# 33         866034  HowIMetYourMother                ROBIN  l13772       POS
# 36         642447           StarTrek               HARPER   l1893       DEP
# 38         110457               NCIS                GIBBS  l18791       DEP
# 40         403957           CSIVerse                 NICK   l7486       DEP
# 42         788696        TheOfficeUS              MICHAEL  l19352       DEP
# 44         790267        TheOfficeUS              MICHAEL  l19352       DEP
# 45         189666        TheSimpsons        Homer Simpson  a15835       POS
# 46         608478           StarTrek                SPOCK  l25411       POS
# 48         511955      AdventureTime                 Finn   a3415       DEP
# 49         805801        TheOfficeUS                  JIM  l19347       DEP
# 52         730165       GilmoreGirls                 RORY  l11613       DEP
# 53         585682           StarTrek                RIKER  l25432       DEP
# 55         908523   TheBigBangTheory                PENNY   l4391       DEP
# 57         393226           CSIVerse              GRISSOM   l7484       DEP
# 58         460395        OneTreeHill                LUCAS  l19593       POS
# ...           ...                ...                  ...     ...       ...
# 17160323   859388  HowIMetYourMother               BARNEY  l13774       POS
# 17160327   649350           StarTrek               NEELIX  l25473       POS
# 17160328   885589              Salem                 MARY  l23233       DEP
# 17160329   688919       GilmoreGirls              LORELAI  l11612       POS
# 17160330   660454           StarTrek                 REED  l25489       DEP
# 17160331   183094         Smallville                 TESS  l24621       DEP
# 17160333   597311           StarTrek             CHAKOTAY  l25467       DEP
# 17160335  1007369           Seinfeld               GEORGE  l23594       DEP
# 17160336   443968           TheLWord                ALICE  l15690       DEP
# 17160337   875528         Buffyverse                BUFFY   l5648       DEP
# 17160341   464413        OneTreeHill               NATHAN  l19594       POS
# 17160342   676588              Alias                DIXON   l1277       POS
# 17160344   749073       GilmoreGirls               SOOKIE  l11619       POS
# 17160346   373719       TheMentalist               LISBON  l17674       DEP
# 17160348  1063421        QueerAsFolk              MICHAEL  l22346       DEP
# 17160349   709703       GilmoreGirls                 RORY  l11613       DEP
# 17160350   174190         Smallville                 LANA  l24615       DEP
# 17160352   548045           StarTrek              JANEWAY  l25466       DEP
# 17160355   329079            Friends                 ROSS  l10696       POS
# 17160359    25432          DoctorWho        SECOND DOCTOR   l8651       POS
# 17160362   793175        TheOfficeUS              MICHAEL  l19352       POS
# 17160363  1006647           Seinfeld               GEORGE  l23594       DEP
# 17160365   723387       GilmoreGirls                 RORY  l11613       POS
# 17160366   125325               NCIS                 ABBY  l18806       POS
# 17160368   774869            Roswell                  MAX  l23046       DEP
# 17160370   860557  HowIMetYourMother               BARNEY  l13774       DEP
# 17160371   126524               NCIS                 ABBY  l18806       DEP
# 17160373   537886           StarTrek              JANEWAY  l25466       POS
# 17160376   652290           StarTrek                MCCOY  l25412       POS
# 17160377   295962              Bones              BRENNAN   l5146       DEP
#
#            head_pos      token  token_par  position  is_stop  \
# 0               VBZ         be         be         2     True
# 1               det          a       girl         8     True
# 5             advcl         be       hold        34     True
# 6          compound       drug    testing         5    False
# 10            ccomp         be      think       -18     True
# 13              VBZ         do         do         0     True
# 14               NN  deflector  deflector        61    False
# 15              VBZ         be         be        26     True
# 18            nsubj  condition         be       -16    False
# 19             prep     beyond         be        24     True
# 21               NN      blood      blood        63    False
# 23             mark         if         be         5     True
# 27              det         no     weapon         9     True
# 31             mark         if      agree         5     True
# 32         npadvmod     PERSON       know        15    False
# 33               NN       info       info        63    False
# 36         npadvmod     PERSON         be       -19    False
# 38             dobj         me       tell        -8     True
# 40             dobj         it       help        -5     True
# 42        nsubjpass         he      dress         9     True
# 44              neg        not       need         4     True
# 45              NNP     PERSON     PERSON         5    False
# 46               VB        get        get        30     True
# 48           advmod      still         be        -3     True
# 49             prep      about  complaint       -11     True
# 52           advmod       just       feel         5     True
# 53             pobj       that       with        -5     True
# 55          auxpass         be    excited         3     True
# 57             prep         of     murder        -7     True
# 58               NN        mom        mom        27    False
# ...             ...        ...        ...       ...      ...
# 17160323        NNP     PERSON     PERSON        20    False
# 17160327        NNS        day        day        24    False
# 17160328       attr      enemy         be       -11    False
# 17160329        NNP    General    General         0    False
# 17160330       prep         on      paint       -21     True
# 17160331     advmod        now         be         9     True
# 17160333        det          a    society        20     True
# 17160335        det       this      thing        10     True
# 17160336      nsubj       that         go        11     True
# 17160337       dobj        her   remember        -9     True
# 17160341         VB        try        try        48    False
# 17160342        VBZ         be         be        28     True
# 17160344         NN     budget     budget        20    False
# 17160346     advmod       once      bring       -27     True
# 17160348        det          a      sauce        19     True
# 17160349       pobj      honey        for        -4    False
# 17160350        aux         to         go         3     True
# 17160352        aux      could       wait        27     True
# 17160355         VB       wait       wait       110    False
# 17160359         NN     report     report        62    False
# 17160362        NNP        GPE        GPE        72    False
# 17160363       mark       that        ask        14     True
# 17160365        VBD         be         be         8     True
# 17160366        NNP        ORG        ORG       114    False
# 17160368       intj         no     PERSON         4     True
# 17160370       intj       okay         be        14    False
# 17160371      nsubj       that         be         4     True
# 17160373         NN      price      price       109    False
# 17160376        NNP        FAC        FAC        66    False
# 17160377       case         's     PERSON        -7     True
#
#                        head_text
# 0                      VBZ|be|be
# 1                     det|a|girl
# 5                  advcl|be|hold
# 6          compound|drug|testing
# 10                ccomp|be|think
# 13                     VBZ|do|do
# 14        NN|deflector|deflector
# 15                     VBZ|be|be
# 18            nsubj|condition|be
# 19                prep|beyond|be
# 21                NN|blood|blood
# 23                    mark|if|be
# 27                 det|no|weapon
# 31                 mark|if|agree
# 32          npadvmod|PERSON|know
# 33                  NN|info|info
# 36            npadvmod|PERSON|be
# 38                  dobj|me|tell
# 40                  dobj|it|help
# 42            nsubjpass|he|dress
# 44                  neg|not|need
# 45             NNP|PERSON|PERSON
# 46                    VB|get|get
# 48               advmod|still|be
# 49          prep|about|complaint
# 52              advmod|just|feel
# 53                pobj|that|with
# 55            auxpass|be|excited
# 57                prep|of|murder
# 58                    NN|mom|mom
# ...                          ...
# 17160323       NNP|PERSON|PERSON
# 17160327             NNS|day|day
# 17160328           attr|enemy|be
# 17160329     NNP|General|General
# 17160330           prep|on|paint
# 17160331           advmod|now|be
# 17160333           det|a|society
# 17160335          det|this|thing
# 17160336           nsubj|that|go
# 17160337       dobj|her|remember
# 17160341              VB|try|try
# 17160342               VBZ|be|be
# 17160344        NN|budget|budget
# 17160346       advmod|once|bring
# 17160348             det|a|sauce
# 17160349          pobj|honey|for
# 17160350               aux|to|go
# 17160352          aux|could|wait
# 17160355            VB|wait|wait
# 17160359        NN|report|report
# 17160362             NNP|GPE|GPE
# 17160363           mark|that|ask
# 17160365               VBD|be|be
# 17160366             NNP|ORG|ORG
# 17160368          intj|no|PERSON
# 17160370            intj|okay|be
# 17160371           nsubj|that|be
# 17160373          NN|price|price
# 17160376             NNP|FAC|FAC
# 17160377          case|'s|PERSON
#
# [7917166 rows x 11 columns]

# %%
model_v3, SENT_CATS_v3, FEATURE_CATS_v3 = get_train(data_v3, report_test_acc=False)
SENT_MAP_v3, INV_SENT_MAP_v3 = build_maps(data_v3)
# Out:
# <137129x924111 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7917166 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [03:34<00:00,  1.14s/it]
# 924111 924111

# %%
mi = ModelInspection(model_v3, SENT_MAP_v3, INV_SENT_MAP_v3, dialog_df=dialogs)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 475992 @0---------
# TEXT: |["Don't be a dork! It's what you love to do. If you don't want to, then we'll work together every day, and I'll love it, but if you do, as much as I'll miss spending my days with you, I'll love spending my nights with you.", 'I love you, Millicent Huxtable.']|
# MEAN CONF TOP100: 1.352049708366394
#
# -- 475992 range D0 0-1, mean conf: 1.4974424839019775--
# rank 2, conf: 1.4974424839019775
# sent 216537: |["Marge, I hate to interrupt the ol' solilo-diddly-iloquy, but I just want to thank you for your early Christmas card.", "Christmas card? I haven't even taken the photo yet!"]|
#
# -- 475992 range D1 1-10, mean conf: 1.4503693580627441--
# rank 5, conf: 1.4632606506347656
# sent 949769: |['I love you, Julie, and I want tobe there for you, and our son.', "She's pregnant with Frank's baby?"]|
#
# -- 475992 range D2 10-20, mean conf: 1.4009217023849487--
# rank 21, conf: 1.3864495754241943
# sent 975386: |['I suspected as much.', "And he doesn't trust his production designer."]|
#
# -- 475992 range D3 20-30, mean conf: 1.3772058486938477--
# rank 31, conf: 1.368213176727295
# sent 570024: |["Well, you people certainly have interesting problems. I'd love to stay around to see how your girlfriend works out, but", "I'm afraid you'll have to. We can't send you back."]|
#
# -- 475992 range D4 30-60, mean conf: 1.348555088043213--
# rank 37, conf: 1.3583067655563354
# sent 959868: |['but I put everything I had inta this marriage...I wanted it to work just as much as you did', 'oh I doubt that...no one hates to fail more then I do...but here we are']|
#
# ----------SENT 80930 @1---------
# TEXT: |["You can miss me for five minutes a day. And you'd better do it properly. You'd better be sad. I expect my five. But all the rest of the time, Clara, all the rest of the time, every single second, you just get the hell on with it. Clear?", "Don't you soldier me."]|
# MEAN CONF TOP100: 1.258829116821289
#
# -- 80930 range D0 0-1, mean conf: 1.4159077405929565--
# rank 2, conf: 1.4159077405929565
# sent 671516: |['Time for me to get the hell out of here.', 'Just look at your watch and tell me what time it is.']|
#
# -- 80930 range D1 1-10, mean conf: 1.3733370304107666--
# rank 6, conf: 1.3824867010116577
# sent 1002201: |['Now, because of that stupid rye bread, I gotta keep them all separated for the rest of my life.', 'Bad situation.']|
#
# -- 80930 range D2 10-20, mean conf: 1.3139984607696533--
# rank 13, conf: 1.3220804929733276
# sent 321421: |['"There is nothing else you can do here. Just - get some rest, okay?"', '"No..."']|
#
# -- 80930 range D3 20-30, mean conf: 1.2886854410171509--
# rank 26, conf: 1.2843838930130005
# sent 163051: |['You should get some rest.', 'Clark, um, would you mind sticking around for a little while? Whoever did this is still out there.']|
#
# -- 80930 range D4 30-60, mean conf: 1.259380578994751--
# rank 36, conf: 1.2776331901550293
# sent 637013: |["It sounds like you've got a big day ahead of you. You should probably get some rest.", "All right, all right, let's call it a night."]|
#
# ----------SENT 290147 @2---------
# TEXT: |["Well, yeah. This is The Stock Yard we're talking about.", 'How did Dalton feel about that?']|
# MEAN CONF TOP100: 0.9994047284126282
#
# -- 290147 range D0 0-1, mean conf: 1.2609587907791138--
# rank 2, conf: 1.2609587907791138
# sent 253961: |["She's talking about the Bible.", "So? She's good-looking. Shut up."]|
#
# -- 290147 range D1 1-10, mean conf: 1.1055690050125122--
# rank 7, conf: 1.091921091079712
# sent 144655: |['Nope. It\'s like listening to "The Brady Bunch" with a reggae soundtrack.', 'What about your background check on Josh? Anything shady, out of line?']|
#
# -- 290147 range D2 10-20, mean conf: 1.0428860187530518--
# rank 19, conf: 1.0307706594467163
# sent 683226: |["Lorelai, this is Rory we're talking about.", 'I know.']|
#
# -- 290147 range D3 20-30, mean conf: 1.0070602893829346--
# rank 22, conf: 1.0159928798675537
# sent 45236: |["I reckon that's what Sarah Jane was talking about.", "Well, at least it's polite."]|
#
# -- 290147 range D4 30-60, mean conf: 0.9867384433746338--
# rank 32, conf: 0.9972491264343262
# sent 813670: |["That's pretty good. What about uh, for a thousand points?", "I'll run naked through the parking lot with a donut on my ding-dong."]|
#
# ----------SENT 411062 @3---------
# TEXT: |["Well, iron is a conductive mineral. I want to know if there was enough iron in Valenti's blood to conduct electricity.", "That's far out."]|
# MEAN CONF TOP100: 0.9978355765342712
#
# -- 411062 range D0 0-1, mean conf: 1.1093276739120483--
# rank 2, conf: 1.1093276739120483
# sent 705144: |["We thought it was time to clear the air. After all, Christopher is Rory's father, and we wanted him to know there were no hard feelings.", 'Really?']|
#
# -- 411062 range D1 1-10, mean conf: 1.0730165243148804--
# rank 5, conf: 1.079229712486267
# sent 177060: |['Mr. Luthor, I know Lex pretty well, and if he wanted you to know where he was, you probably would.', 'Lex is seriously ill. He needs help.']|
#
# -- 411062 range D2 10-20, mean conf: 1.040006399154663--
# rank 13, conf: 1.046898365020752
# sent 271193: |['Oh... You want to know if I know about the demon blood.', "You didn't tell Dean."]|
#
# -- 411062 range D3 20-30, mean conf: 1.0215634107589722--
# rank 31, conf: 1.0165497064590454
# sent 849851: |['Fine. And, uh, ticktock. I managed to restrain him, but you know how persistent Damon can be when he wants something', "We'll be there soon"]|
#
# -- 411062 range D4 30-60, mean conf: 0.994033694267273--
# rank 51, conf: 0.9875094890594482
# sent 119604: |["Well, Ziva, I think she didn't just float out of that campsite. We need to find out who she is.", 'Right. I talked to the guys Riley worked with at the Navy Yard. Only one of them... a Seaman Brad Phillips, knew he was going camping. Riley mentioned taking a girl he met a couple weeks ago. Phillips never caught a name.']|
#
# ----------SENT 455153 @4---------
# TEXT: |['23? That how many tequila shots it took you to do it?', 'Stop it']|
# MEAN CONF TOP100: 0.9625215530395508
#
# -- 455153 range D0 0-1, mean conf: 1.0264949798583984--
# rank 2, conf: 1.0264949798583984
# sent 536406: |["Hi. So, if you could just take these two then that'll free me up to do...", "Oh, no, no, no. No, I'm not here to work. I'm um, I'm um, I'm um, I'm sorry. I haven't slept in like two days and I'm actually looking for George. We're supposed to meet up for coffee."]|
#
# -- 455153 range D1 1-10, mean conf: 1.0115013122558594--
# rank 9, conf: 1.0091781616210938
# sent 496310: |['We’ll do whatever it takes.', 'Heartwarming. He’s trapped in his own castle.']|
#
# -- 455153 range D2 10-20, mean conf: 0.9938843846321106--
# rank 15, conf: 0.9954265356063843
# sent 45188: |["All right. But don't take any unnecessary risks.", "Hey, there's nothing to worry about, we all know Luke is the loose cannon in the gang."]|
#
# -- 455153 range D3 20-30, mean conf: 0.9899238348007202--
# rank 27, conf: 0.989782452583313
# sent 617422: |["She's like that. Don't take it personally.", "Believe me, you're the last person I want to ask for help. I have no choice."]|
#
# -- 455153 range D4 30-60, mean conf: 0.9806776642799377--
# rank 36, conf: 0.988650381565094
# sent 1058692: |["No, no, no, no. Please don't take him.", 'Please, baby. Please.']|
#
# ----------SENT 626996 @5---------
# TEXT: |["Then why don't they get themselves out?", "I don't know."]|
# MEAN CONF TOP100: 0.9520584344863892
#
# -- 626996 range D0 0-1, mean conf: 0.9559424519538879--
# rank 2, conf: 0.9559424519538879
# sent 885921: |['So where do they get them?', "Isaac, if you'd be so kind as to explain to the captain your duties."]|
#
# -- 626996 range D1 1-10, mean conf: 0.9545918703079224--
# rank 11, conf: 0.9539548754692078
# sent 845575: |['Yeah, but how do you get through?', 'Jeremy, I will be fine. Look. I got to go, OK? Be careful.']|
#
# -- 626996 range D2 10-20, mean conf: 0.9535855054855347--
# rank 17, conf: 0.9534534215927124
# sent 823180: |["I just don't get it.", "What don't you get?"]|
#
# -- 626996 range D3 20-30, mean conf: 0.952933669090271--
# rank 28, conf: 0.9528302550315857
# sent 529000: |["What if they don't get him out from there before he...", "I don't know. I don't know, ok? I don't know."]|
#
# -- 626996 range D4 30-60, mean conf: 0.9520788788795471--
# rank 58, conf: 0.9515278935432434
# sent 272284: |["Okay, I don't get it.", 'Nobody']|
#
# ----------SENT 751543 @6---------
# TEXT: |['I know what something to do means, Richard.', 'My apologies, Emily.']|
# MEAN CONF TOP100: 0.9209492802619934
#
# -- 751543 range D0 0-1, mean conf: 1.0140111446380615--
# rank 2, conf: 1.0140111446380615
# sent 609700: |["I know when something doesn't strike me right, and he doesn't.", 'Specifics, Doctor. Labels do not make arguments.']|
#
# -- 751543 range D1 1-10, mean conf: 0.9661267399787903--
# rank 4, conf: 0.9990840554237366
# sent 335495: |['I know that switch does something, okay? So-so I went down to city hall and got these. All I had to do was pay $25 and wait in line for three hours.', 'Wow! If only more people knew.']|
#
# -- 751543 range D2 10-20, mean conf: 0.935893177986145--
# rank 19, conf: 0.9308431148529053
# sent 1049255: |["Not unless you know something I don't. Do you?", 'Well, maybe not about this.']|
#
# -- 751543 range D3 20-30, mean conf: 0.9265789985656738--
# rank 31, conf: 0.9238216876983643
# sent 326706: |['They found rust. You know what rust does to a boat?', 'It gives it a nice antiquey look.']|
#
# -- 751543 range D4 30-60, mean conf: 0.9183099865913391--
# rank 37, conf: 0.9222787618637085
# sent 838022: |["Bonnie knows, doesn't she?", 'Yes.']|
#
# ----------SENT 375779 @7---------
# TEXT: |["Listen, her actual pitching skills—bush league. You put a bag on her, Liselle couldn't sell squat.", 'Ever ask her out?']|
# MEAN CONF TOP100: 0.8809974789619446
#
# -- 375779 range D0 0-1, mean conf: 0.9077476859092712--
# rank 2, conf: 0.9077476859092712
# sent 607903: |['Gravitation on automatic. (consoles blow up) Emergency stations. All decks on fire alert. Neutralise controls. Kelso, put it on manual. Any radiation? Anything?', 'Negative!']|
#
# -- 375779 range D1 1-10, mean conf: 0.9051496982574463--
# rank 6, conf: 0.9053256511688232
# sent 365504: |['I put it on to scare Chandler!', "Oh my God! Monica's gonna totally freak out!"]|
#
# -- 375779 range D2 10-20, mean conf: 0.9015032052993774--
# rank 17, conf: 0.9014362096786499
# sent 128175: |['Put it on the plasma, Kate.', 'It started at Eastlake, Ohio, at fourteen hundred, and by the time it reached Indian Point in Buchanon, New York, all the Northeast and most of Canada was dark.']|
#
# -- 375779 range D3 20-30, mean conf: 0.8981321454048157--
# rank 26, conf: 0.8986508846282959
# sent 322098: |['“Cordelia, just put down the very sharp knife.”', '“Well, they don’t smell right.”']|
#
# -- 375779 range D4 30-60, mean conf: 0.8839305639266968--
# rank 46, conf: 0.8836829662322998
# sent 136609: |['Put Director Shepard on.', "You're wasting..."]|
#
# ----------SENT 794312 @8---------
# TEXT: |["So... here's the thing about infidelity.", 'Mm, no, when are you people going to stop casting the first stone? I am not in the wrong here. I am the good guy.']|
# MEAN CONF TOP100: 0.8809418082237244
#
# -- 794312 range D0 0-1, mean conf: 0.9890033602714539--
# rank 2, conf: 0.9890033602714539
# sent 365888: |["Here's the thing.", 'Yeah?']|
#
# -- 794312 range D1 1-10, mean conf: 0.9530514478683472--
# rank 3, conf: 0.9890033602714539
# sent 138266: |["Here's the thing.", 'Oh, no.']|
#
# -- 794312 range D2 10-20, mean conf: 0.909134566783905--
# rank 19, conf: 0.9062854647636414
# sent 1019250: |['Uh, well, uh the thing is that . . .', "It's cold out, and I didn't bring my own. Jerry! God forbid I should borrow one from Holly. It might have belonged to grandma Memma. Thanks for mutton."]|
#
# -- 794312 range D3 20-30, mean conf: 0.8937843441963196--
# rank 26, conf: 0.8941540718078613
# sent 785461: |["And then there's this whole thing about the granilith.", 'Why did you lie to Lonnie and Rath about the granilith, anyway?']|
#
# -- 794312 range D4 30-60, mean conf: 0.8762747049331665--
# rank 36, conf: 0.8857530355453491
# sent 663447: |['Why is it that the most beautiful things are always the most dangerous?', 'They do it on purpose.']|
#
# ----------SENT 934522 @9---------
# TEXT: |["so now you think it's an act", "I think it's a crutch?"]|
# MEAN CONF TOP100: 0.8645159006118774
#
# -- 934522 range D0 0-1, mean conf: 0.8693488240242004--
# rank 2, conf: 0.8693488240242004
# sent 62006: |["So you think it's near?", "She's a shapeshifter, Rhys. She could be out there making small talk with your mom and dad."]|
#
# -- 934522 range D1 1-10, mean conf: 0.8681350946426392--
# rank 3, conf: 0.8692432641983032
# sent 412303: |["So you think it's a serial?", "I don't know, but I'm keeping my eyes peeled. Maybe they came back to take a look."]|
#
# -- 934522 range D2 10-20, mean conf: 0.8669177889823914--
# rank 15, conf: 0.867005467414856
# sent 397837: |["So far, all the prints come back to her. Player piano, whiskey bottle, shot glass. There was some lipstick around the rim. I haven't had a chance to test it. You think it's her shade?", "Heather's not supposed to drink because of her diabetes, which could explain the hypoglycemia and shock."]|
#
# -- 934522 range D3 20-30, mean conf: 0.866157054901123--
# rank 25, conf: 0.8662952780723572
# sent 55461: |["Well, I think it's marvellous.", "So do I. Though it's not quite as you described it."]|
#
# -- 934522 range D4 30-60, mean conf: 0.8640949726104736--
# rank 52, conf: 0.863311767578125
# sent 714423: |["I think it's wise.", 'Hello?']|
#
# ----------SENT 535353 @10---------
# TEXT: |['Addison! Thank you for meeting us.', "You wanna tell me what's so important I'm keeping it secret from my Chief of Surgery?"]|
# MEAN CONF TOP100: 0.8468173742294312
#
# -- 535353 range D0 0-1, mean conf: 0.8509982824325562--
# rank 2, conf: 0.8509982824325562
# sent 249160: |['Thank you, Krusty for inviting me.', 'Well, all the good Presidents turned us down.']|
#
# -- 535353 range D1 1-10, mean conf: 0.848993182182312--
# rank 4, conf: 0.8505437970161438
# sent 685784: |['Thank you. Hello Lorelai, thank you for inviting us.', 'Our pleasure. Do you need help bringing in the rest of your stuff?']|
#
# -- 535353 range D2 10-20, mean conf: 0.8478857278823853--
# rank 13, conf: 0.8479918837547302
# sent 866901: |['Thank you for last, Robin.', 'That night, great show on poisons.']|
#
# -- 535353 range D3 20-30, mean conf: 0.8476133346557617--
# rank 24, conf: 0.8477241396903992
# sent 133482: |['Thank you for pointing that out... Officer David.', 'David!']|
#
# -- 535353 range D4 30-60, mean conf: 0.8470093607902527--
# rank 38, conf: 0.8471677899360657
# sent 450385: |['Great. Thank you for the tip.', 'You having fun, tutor girl?']|
#
# ----------SENT 150618 @11---------
# TEXT: |['OK, that was the pile you just got finished alphabetizing, was not it?', 'Actually, it was two batteries.']|
# MEAN CONF TOP100: 0.8445242047309875
#
# -- 150618 range D0 0-1, mean conf: 0.8951091170310974--
# rank 2, conf: 0.8951091170310974
# sent 952917: |['oh it was a fixer upper that we never got to fix up', 'I know']|
#
# -- 150618 range D1 1-10, mean conf: 0.8791525959968567--
# rank 3, conf: 0.8855778574943542
# sent 92782: |["His fever's getting worse, isn't it?", "The poison's setting in."]|
#
# -- 150618 range D2 10-20, mean conf: 0.8706591725349426--
# rank 15, conf: 0.8724966645240784
# sent 894448: |['Is it really worth getting upset about?', 'Yeah, they say don’t meet your heroes. Don’t peek behind that curtain of fame and celebrity, because if you do, you’ll see them as they really are, degenerate carnival folk.']|
#
# -- 150618 range D3 20-30, mean conf: 0.8608481287956238--
# rank 31, conf: 0.8551403880119324
# sent 863182: |['It was the worst trip ever, but then it got worse.', "Well, don't worry, the next exit's the hotel. We can go there."]|
#
# -- 150618 range D4 30-60, mean conf: 0.8434876799583435--
# rank 39, conf: 0.847309947013855
# sent 848259: |['Look, Tyler… I think that you misunderstood me at the party. I get it, it was very dramatic', "You're lying"]|
#
# ----------SENT 43219 @12---------
# TEXT: |["All right. If you consider it's necessary I'll have a word with the Commissioner of Police.", 'No, Sir Charles. I think the police might find it too big for them to handle at the moment.']|
# MEAN CONF TOP100: 0.8275033831596375
#
# -- 43219 range D0 0-1, mean conf: 0.8763706088066101--
# rank 2, conf: 0.8763706088066101
# sent 71791: |["That's a bit remiss. I'd have a word with the manufacturers, if. Sorry.", 'Impact fifteen seconds.']|
#
# -- 43219 range D1 1-10, mean conf: 0.8740265965461731--
# rank 9, conf: 0.8737495541572571
# sent 675217: |['You have my word.', 'Thank you.']|
#
# -- 43219 range D2 10-20, mean conf: 0.8737495541572571--
# rank 16, conf: 0.8737495541572571
# sent 591902: |["I won't mention it to anyone. You have my word.", 'If you had an off switch Doctor, would you not keep it secret?']|
#
# -- 43219 range D3 20-30, mean conf: 0.8732903599739075--
# rank 28, conf: 0.8730329871177673
# sent 32301: |['Miss Smith, my name is Colonel Tia Karim, representing the Unified Intelligence Task Force. If I could have a word in private?', "No, no, no. You're not getting any closer. Just tell me, what do you want?"]|
#
# -- 43219 range D4 30-60, mean conf: 0.8366934061050415--
# rank 46, conf: 0.8392017483711243
# sent 803590: |["Oh... My... God, that's why people are leaving. I- I have no words.", 'We just passed the exit for Corcroan.']|
#
# ----------SENT 969785 @13---------
# TEXT: |['Give it to me.', "I don't want to watch it."]|
# MEAN CONF TOP100: 0.8068779706954956
#
# -- 969785 range D0 0-1, mean conf: 0.8084156513214111--
# rank 1, conf: 0.8084156513214111
# sent 571930: |["I've never played games. Give it to me.", "I wasn't sure before, but I am now. This is the source of your power, isn't it. The transmuter."]|
#
# -- 969785 range D1 1-10, mean conf: 0.8084156513214111--
# rank 10, conf: 0.8084155917167664
# sent 368685: |['Give it to me!', 'No']|
#
# -- 969785 range D2 10-20, mean conf: 0.8084155321121216--
# rank 16, conf: 0.8084155321121216
# sent 958168: |['Give it to me.', 'Oh, my God.']|
#
# -- 969785 range D3 20-30, mean conf: 0.8084155321121216--
# rank 25, conf: 0.8084155321121216
# sent 16362: |['Give it to me.', "Sarah, what's the matter with you?"]|
#
# -- 969785 range D4 30-60, mean conf: 0.8082481026649475--
# rank 42, conf: 0.8084154725074768
# sent 16388: |['Give it to me.', 'No. I shall return the crystal only to the Great One herself.']|
#
# ----------SENT 875054 @14---------
# TEXT: |['Well, do you have one at home?', "I don't know. What's a ricer?"]|
# MEAN CONF TOP100: 0.7785553336143494
#
# -- 875054 range D0 0-1, mean conf: 0.8956459164619446--
# rank 2, conf: 0.8956459164619446
# sent 853096: |["But I don't have a home.", "Not lost on me at all. But I don't understand, why don't you just go to a hotel? You could be sleeping on a mattress instead of... what appears to be torn-up drawings of my building."]|
#
# -- 875054 range D1 1-10, mean conf: 0.8500781655311584--
# rank 7, conf: 0.8294220566749573
# sent 751575: |["Dad, I don't have a home fax.", "I don't see how you can do business on this level and not have a home fax."]|
#
# -- 875054 range D2 10-20, mean conf: 0.7972690463066101--
# rank 14, conf: 0.8006942272186279
# sent 688053: |['Uh, I have a really crappy mattress at home.', 'Chris.']|
#
# -- 875054 range D3 20-30, mean conf: 0.7793225049972534--
# rank 28, conf: 0.7779133319854736
# sent 475214: |["Well I'm thrilled to have you back. So do you have your new tree hill catchphrase yet?", "I don't think I'm gonna need one"]|
#
# -- 875054 range D4 30-60, mean conf: 0.7692417502403259--
# rank 59, conf: 0.7644895315170288
# sent 445037: |["Oh, well, it differs every night. We don't really have her on a schedule.", 'Yeah.']|
#
# ----------SENT 560010 @15---------
# TEXT: |["Kae-Lee. Kae-Lee. Oh. She's my sister.", 'I know.']|
# MEAN CONF TOP100: 0.748408854007721
#
# -- 560010 range D0 0-1, mean conf: 0.7943731546401978--
# rank 1, conf: 0.7943731546401978
# sent 845355: |["Bonnie… She's my sister", "Jeremy Gilbert, do you not know me at all? Is there a part of you that thinks for one minute that I'd let one of my friends die just so I could come back to life? I'm dead, jer, and as much as I want to come back maybe I'm just supposed to accept it"]|
#
# -- 560010 range D1 1-10, mean conf: 0.7837788462638855--
# rank 7, conf: 0.7861050963401794
# sent 663738: |["She's the Leper's sister? We definitely can't trust her.", "If you'd informed us of this earlier, we would have strongly advised you against it."]|
#
# -- 560010 range D2 10-20, mean conf: 0.7727214097976685--
# rank 20, conf: 0.7717316746711731
# sent 218213: |["S'okay... she's my wife.", 'Ned and Edna married?']|
#
# -- 560010 range D3 20-30, mean conf: 0.7636682391166687--
# rank 29, conf: 0.7606567740440369
# sent 812927: |["He's my foster brother.", "Well, any brother of Erin's is a friend of mine. Nice to meet you. Andy Bernard."]|
#
# -- 560010 range D4 30-60, mean conf: 0.748314619064331--
# rank 46, conf: 0.7471063137054443
# sent 810861: |["Look at the numbers. Every single time, it's come up 150 over 100. Your husband is a pathological liar.", 'Jim, you have high blood pressure.']|
#
# ----------SENT 246843 @16---------
# TEXT: |['Yeah, keep away from him, Milhouse.', "You too, Ralphie. You're out of that day care center."]|
# MEAN CONF TOP100: 0.7110300064086914
#
# -- 246843 range D0 0-1, mean conf: 0.778436541557312--
# rank 2, conf: 0.778436541557312
# sent 861586: |['Just keep Brad away from the bouquet.', 'It gets worse.']|
#
# -- 246843 range D1 1-10, mean conf: 0.7478081583976746--
# rank 7, conf: 0.7361748218536377
# sent 505889: |['Keep him safe, Ruby.', 'Don’t push it, Snow.']|
#
# -- 246843 range D2 10-20, mean conf: 0.7291141152381897--
# rank 16, conf: 0.7295658588409424
# sent 38452: |['The other grey alien back at Dreamland. Keep up, Jimmy.', "But she wasn't on your ship, was she. Night Eagle and his men\nwould have saved her, too."]|
#
# -- 246843 range D3 20-30, mean conf: 0.7237586379051208--
# rank 23, conf: 0.7260372042655945
# sent 75549: |['Jo, keep back!', 'Get back! Go on, back!']|
#
# -- 246843 range D4 30-60, mean conf: 0.7108951807022095--
# rank 48, conf: 0.7103645205497742
# sent 1060256: |["Emmett, you can't keep loosin' your key!", 'Hey, Sonny Boy.']|
#
# ----------SENT 92040 @17---------
# TEXT: |['Have a little patience. Think of something pleasant.', 'You in the stocks?']|
# MEAN CONF TOP100: 0.7103793025016785
#
# -- 92040 range D0 0-1, mean conf: 0.7603347897529602--
# rank 2, conf: 0.7603347897529602
# sent 739361: |["Mom, she's a young girl. Think of something young.", 'A Mont Blanc pen?']|
#
# -- 92040 range D1 1-10, mean conf: 0.7596756219863892--
# rank 10, conf: 0.7595406174659729
# sent 1065685: |["I'll think of something.", 'I bet you will.']|
#
# -- 92040 range D2 10-20, mean conf: 0.7560278177261353--
# rank 17, conf: 0.7552489638328552
# sent 505519: |['I’ll think of something else.', 'Thank you.']|
#
# -- 92040 range D3 20-30, mean conf: 0.7419577836990356--
# rank 28, conf: 0.7399519085884094
# sent 469630: |['I thought I smelled something.', 'Oh that’s skank. And I think it’s coming from you.']|
#
# -- 92040 range D4 30-60, mean conf: 0.7110267877578735--
# rank 40, conf: 0.7306630611419678
# sent 872026: |["There's a rumor going around that, uh, Mr. Cox is the most boring teacher in the entire world. Like, I think he won a belt or something.", 'Like, yes.']|
#
# ----------SENT 522085 @18---------
# TEXT: |["You're funny. And cold. Well, you're not...", 'I am vampire. Yes.']|
# MEAN CONF TOP100: 0.7084341049194336
#
# -- 522085 range D0 0-1, mean conf: 0.7170114517211914--
# rank 2, conf: 0.7170114517211914
# sent 929591: |["Well, aren't you resourceful?", '- No, no, Venus! BAROSKY: - What the hell?']|
#
# -- 522085 range D1 1-10, mean conf: 0.7170071005821228--
# rank 8, conf: 0.7170112729072571
# sent 769440: |["Well you aren't.", "You're just being selfish, Luke."]|
#
# -- 522085 range D2 10-20, mean conf: 0.7160102128982544--
# rank 17, conf: 0.7155524492263794
# sent 1071386: |["Well, I'm not!", "What do you care? You're moving in with David."]|
#
# -- 522085 range D3 20-30, mean conf: 0.7145823836326599--
# rank 29, conf: 0.7143329977989197
# sent 888749: |['Well, aren’t you sweet?', 'Anyway, should you have any interaction with her, it would be most helpful that she not see you as a sexual rival.']|
#
# -- 522085 range D4 30-60, mean conf: 0.7080692648887634--
# rank 48, conf: 0.7069824934005737
# sent 1066197: |["Well, my, aren't you two raising him well.", "Oh, want anyone see that new Matt Damon movie. Iread in a chat room last night that there's a dick shotin it. It's brief, but nothing the less dick."]|
#
# ----------SENT 898584 @19---------
# TEXT: |['Yes. In fact, he was quite enthusiastic. He said, “Frankly, if I could send you tonight, I would.”', 'Okay, well, do you want to go?']|
# MEAN CONF TOP100: 0.6956923604011536
#
# -- 898584 range D0 0-1, mean conf: 0.7908563613891602--
# rank 2, conf: 0.7908563613891602
# sent 702685: |['She said she sent you an invitation.', "I didn't know it was from her."]|
#
# -- 898584 range D1 1-10, mean conf: 0.7527773380279541--
# rank 10, conf: 0.7300711870193481
# sent 154702: |['Rumors from his old school. He went to junior high in Grandville, and he told some kids there that he was extraterrestrial. Needless to say, they sent him to a distant corner in the social galaxy.', "He didn't do anything... super, did he?"]|
#
# -- 898584 range D2 10-20, mean conf: 0.7095412015914917--
# rank 15, conf: 0.7091824412345886
# sent 244483: |['But you said a stork brought me.', 'Um, that was God disguised as a stork.']|
#
# -- 898584 range D3 20-30, mean conf: 0.7040510177612305--
# rank 22, conf: 0.7058379650115967
# sent 33015: |['You said bring this.', "What good's that? It's not even charged."]|
#
# -- 898584 range D4 30-60, mean conf: 0.6920192837715149--
# rank 34, conf: 0.6996616721153259
# sent 90522: |['Anhora said you would be tested. And last night, in the grain store, you let that villager go. And he said it would bring its own reward.', 'He was merely grateful, and so he should have been.']|
#
# ----------SENT 508204 @20---------
# TEXT: |[". That's not yours.", 'Story of my life.']|
# MEAN CONF TOP100: 0.6551253199577332
#
# -- 508204 range D0 0-1, mean conf: 0.6557726860046387--
# rank 1, conf: 0.6557726860046387
# sent 682108: |['That is not yours.', 'No, I found it in the bags of stuff for the sale.']|
#
# -- 508204 range D1 1-10, mean conf: 0.6553409099578857--
# rank 3, conf: 0.6554363965988159
# sent 780646: |["That's not mine.", "How'd it get in your breifcase?"]|
#
# -- 508204 range D2 10-20, mean conf: 0.6551836133003235--
# rank 12, conf: 0.6551955342292786
# sent 599957: |["That's not advisable.", "We don't have a choice."]|
#
# -- 508204 range D3 20-30, mean conf: 0.6551424264907837--
# rank 28, conf: 0.6551406383514404
# sent 40327: |["That's not thunder, surely?", 'Sounded more like an ancient cannon.']|
#
# -- 508204 range D4 30-60, mean conf: 0.6550920605659485--
# rank 48, conf: 0.6550827622413635
# sent 766034: |["Isn't that confusing?", 'Not when you think about it.']|
#
# ----------SENT 496948 @21---------
# TEXT: |["No, I mean it. I've no reason to escape.", "And with that cuff, you won't have the magic to do it either. Oh, look. Home."]|
# MEAN CONF TOP100: 0.6471038460731506
#
# -- 496948 range D0 0-1, mean conf: 0.7402406930923462--
# rank 2, conf: 0.7402406930923462
# sent 137140: |['Do you? I have no reason to back out.', 'Neither do I.']|
#
# -- 496948 range D1 1-10, mean conf: 0.727330207824707--
# rank 4, conf: 0.7342167496681213
# sent 369391: |['There’s a part in a TV movie that I would be perfect for and I didn’t even be put up for it! She’d better have a good reason.', 'I’m guessing she does.']|
#
# -- 496948 range D2 10-20, mean conf: 0.7033787965774536--
# rank 12, conf: 0.7156921625137329
# sent 422870: |['I was! But I had a very good reason.', "We're listening."]|
#
# -- 496948 range D3 20-30, mean conf: 0.6718235611915588--
# rank 22, conf: 0.6802378296852112
# sent 30709: |['They must have had a reason.', 'To leave a three month old baby on its own?']|
#
# -- 496948 range D4 30-60, mean conf: 0.6402092576026917--
# rank 52, conf: 0.6374550461769104
# sent 137291: |['Why did she do it? Did she have a reason?', "She says that she doesn't have friends to invite to the shower, so she's going to invite her enemies. And those are her enemies, girls who slept with Ricky."]|
#
# ----------SENT 309678 @22---------
# TEXT: |['Look at this.', 'Let me see that one. Let me see if I can, uh, scan this.']|
# MEAN CONF TOP100: 0.6463879942893982
#
# -- 309678 range D0 0-1, mean conf: 0.6468210816383362--
# rank 1, conf: 0.6468210816383362
# sent 297256: |['Look at this!', 'Booth.']|
#
# -- 309678 range D1 1-10, mean conf: 0.6468210816383362--
# rank 7, conf: 0.6468210816383362
# sent 270484: |['Dude. Look at this.', 'I just talked to Bobby.']|
#
# -- 309678 range D2 10-20, mean conf: 0.6468210816383362--
# rank 11, conf: 0.6468210816383362
# sent 65499: |['Never mind that. Look at this.', 'What? What is it?']|
#
# -- 309678 range D3 20-30, mean conf: 0.6468210220336914--
# rank 24, conf: 0.6468210816383362
# sent 279428: |['Look at this.', "Yeah, it's a penny."]|
#
# -- 309678 range D4 30-60, mean conf: 0.6468178033828735--
# rank 46, conf: 0.6468210220336914
# sent 60149: |['At the moment, we have other things to worry about. Look at this!', 'What?']|
#
# ----------SENT 870429 @23---------
# TEXT: |['How can you speak of such things?', 'You\'re kidding. Barney, every time I mention a woman you don\'t know, the first thing you say is, "Boobs?" Not the complete sentence, "Does she have big boobs?" Which also would not be great. Just: "Boobs?"']|
# MEAN CONF TOP100: 0.6404199004173279
#
# -- 870429 range D0 0-1, mean conf: 0.8093811273574829--
# rank 2, conf: 0.8093811273574829
# sent 867274: |['How can you speak of such things?', 'Girls talk about everything.']|
#
# -- 870429 range D1 1-10, mean conf: 0.6957548260688782--
# rank 6, conf: 0.6700150966644287
# sent 1007369: |['Oh! That was nothing. So listen, what about this bald thing?', "Ah! Some bald thing, a bald thing I dunno. It's nothing"]|
#
# -- 870429 range D2 10-20, mean conf: 0.6514887809753418--
# rank 12, conf: 0.6606064438819885
# sent 966743: |['Really? You seem pretty carefree about the whole thing, Jo.', "Well, that's me. When it comes to grades, I'm all about the carefree."]|
#
# -- 870429 range D3 20-30, mean conf: 0.6456567645072937--
# rank 22, conf: 0.6471703052520752
# sent 365464: |['Pheebs, what are you doing with the coat? How about the whole animal rights thing?', "Well, I've been reading up and for your information, minks are not very nice. Okay, I admit it! I love this coat! Okay, I—it's the best thing I've ever had wrapped around me, including Phil Huntley!"]|
#
# -- 870429 range D4 30-60, mean conf: 0.6357103586196899--
# rank 41, conf: 0.6379500031471252
# sent 950588: |["hey that's spose'ta be my line ok your spose'ta say how I could never understand and how Ryan's the most important thing in the world and without him", "we're just friends...or at least we're tryin'a be"]|
#
# ----------SENT 883449 @24---------
# TEXT: |['Remember Halloween, I got turned into a soldier?', 'Yeah.']|
# MEAN CONF TOP100: 0.6316864490509033
#
# -- 883449 range D0 0-1, mean conf: 0.724993884563446--
# rank 2, conf: 0.724993884563446
# sent 738577: |['Hey remember the year you got me the unicorn marionette with the purple horn?', "You didn't like the unicorn marionette?"]|
#
# -- 883449 range D1 1-10, mean conf: 0.6821054816246033--
# rank 3, conf: 0.713407039642334
# sent 819512: |['Uh, Charles Schultz did. I thought it was relevant cause I got you all those birds for Christmas, remember?', 'Uh, yeah I do remember.']|
#
# -- 883449 range D2 10-20, mean conf: 0.6525173187255859--
# rank 15, conf: 0.6540048718452454
# sent 297371: |['Bones, hey! Good news. Turns out I got Parker for Christmas after all.', 'Christmas magic, right?']|
#
# -- 883449 range D3 20-30, mean conf: 0.6433621048927307--
# rank 31, conf: 0.6402339339256287
# sent 989565: |['I just remembered I got some French vocab to study for.', "You don't take French."]|
#
# -- 883449 range D4 30-60, mean conf: 0.6289723515510559--
# rank 54, conf: 0.6229907870292664
# sent 106843: |['Probably gets her roof shingled and driveway tarred every year.', 'Does Dorn even have a sister?']|
#
# ----------SENT 636676 @25---------
# TEXT: |['Your plan could work.', 'Now that we have your blessing.']|
# MEAN CONF TOP100: 0.625066339969635
#
# -- 636676 range D0 0-1, mean conf: 0.7055621147155762--
# rank 2, conf: 0.7055621147155762
# sent 65085: |['If the plan works.', "Ah, there's only one way to find out, isn't there?"]|
#
# -- 636676 range D1 1-10, mean conf: 0.6977267265319824--
# rank 9, conf: 0.6950390338897705
# sent 196511: |['Yeah, congratulations, Homer. The plan worked perfectly.', "But I'm in jail."]|
#
# -- 636676 range D2 10-20, mean conf: 0.6636355519294739--
# rank 15, conf: 0.6722081899642944
# sent 890868: |['Whatcha doin’ there? Working on a new plan to catch the roadrunner?', 'The humorous implication being that I am Wile E. Coyote?']|
#
# -- 636676 range D3 20-30, mean conf: 0.6221084594726562--
# rank 22, conf: 0.6284789443016052
# sent 559831: |["Not soon enough. The Restors are in range. They're targeting us. I hope your plan works.", 'Me too, Rev. Me too.']|
#
# -- 636676 range D4 30-60, mean conf: 0.6124867796897888--
# rank 50, conf: 0.6112411618232727
# sent 1005901: |['What? A health plan?', 'I was going to say, "Being a good host."']|
#
# ----------SENT 610960 @26---------
# TEXT: |['An entire human colony, a whole settlement. One hundred men, women and children. Who did it? And why? (communicator beep) Kirk here.', 'Spock here, Captain.']|
# MEAN CONF TOP100: 0.6020067930221558
#
# -- 610960 range D0 0-1, mean conf: 0.6074376702308655--
# rank 1, conf: 0.6074376702308655
# sent 922883: |['Hm. Who did it?', "I'm not sure."]|
#
# -- 610960 range D1 1-10, mean conf: 0.6067410111427307--
# rank 8, conf: 0.6061028838157654
# sent 522201: |['Hum, vampire-hating church annihilated. Wonder who did it? F****** brilliant.', 'I doubt the King of Texas would approve the destruction of our international political agenda.']|
#
# -- 610960 range D2 10-20, mean conf: 0.6042858362197876--
# rank 12, conf: 0.6057927012443542
# sent 87431: |['Who did that?', 'What?']|
#
# -- 610960 range D3 20-30, mean conf: 0.6025493741035461--
# rank 23, conf: 0.6036400198936462
# sent 810538: |['Oh my God, where did this come from?! Who did this?!', "I got Erin a new computer, because the one at reception sucked. I should know. And I don't wanna say the other one was old, but its I.P. number is one!"]|
#
# -- 610960 range D4 30-60, mean conf: 0.6018582582473755--
# rank 44, conf: 0.6019446849822998
# sent 898258: |['Why do we have to tell him I did it?', 'Well, we’re not gonna tell him I did it.']|
#
# ----------SENT 549387 @27---------
# TEXT: |['Our shield has confused outsiders for millennia, Captain.', "That's a very long time to have such technology. Why do you reveal yourselves to us now?"]|
# MEAN CONF TOP100: 0.5964654088020325
#
# -- 549387 range D0 0-1, mean conf: 0.6784501075744629--
# rank 2, conf: 0.6784501075744629
# sent 224355: |['Good Lord! What has become of the Sport of Kings?', 'Get bent.']|
#
# -- 549387 range D1 1-10, mean conf: 0.655661404132843--
# rank 4, conf: 0.6687230467796326
# sent 31543: |['I am picking up news reports from the International Gallery. The Mona Lisa has been stolen.', "The Mona Lisa? I don't believe it. The security at the International Gallery was supposed to be massive."]|
#
# -- 549387 range D2 10-20, mean conf: 0.6239206790924072--
# rank 13, conf: 0.6298072338104248
# sent 1036775: |["Distrust is expected but don't let it blind you. If I haven't taught Piper how to master the sword before the Dark Knight returns, your survival depends on that potion.", 'Okay, so where are we supposed to get the ingredients?']|
#
# -- 549387 range D3 20-30, mean conf: 0.608055055141449--
# rank 30, conf: 0.6046801209449768
# sent 493085: |["There has to be a better strategy. While we're reading files, my sister is out there somewhere. We have to confront this Snow Queen.", "Believe me, if I could, we would. We have to find her first. And, Elsa, we have to be careful. This woman is tricky. She seems to know both of us, and we don't remember anything about her. And something tells me that that is not an accident."]|
#
# -- 549387 range D4 30-60, mean conf: 0.5891602635383606--
# rank 38, conf: 0.5952556133270264
# sent 434849: |['It seems the dark places Star Swirl indicated on the map have changed.', "I bet the Pony of Shadows would've loved the Ghastly Caverns before a thousand years of erosion turned it into the Ghastly Gorge."]|
#
# ----------SENT 588700 @28---------
# TEXT: |['I have completed modifications, Commander.', 'Excellent. Doctor Crusher, meet us in Transporter room six immediately.']|
# MEAN CONF TOP100: 0.5866827368736267
#
# -- 588700 range D0 0-1, mean conf: 0.6245068907737732--
# rank 2, conf: 0.6245068907737732
# sent 16144: |["That's impossible. The Commander and his troops have only just\narrived.", 'No, Sarah is absolutely right. Those two were in the refinery\nall the time.']|
#
# -- 588700 range D1 1-10, mean conf: 0.6093549728393555--
# rank 11, conf: 0.6040685176849365
# sent 587203: |["But I haven't finished fixing your tea, Commander.", "I'm sorry, but we're finished here. Now, I can allow time for you and Kevin to pack."]|
#
# -- 588700 range D2 10-20, mean conf: 0.6008213758468628--
# rank 15, conf: 0.6010165810585022
# sent 550420: |['(a red shirt who has suddenly replaced Wesley) Captain, I have a star fix.', 'On screen.']|
#
# -- 588700 range D3 20-30, mean conf: 0.5950500965118408--
# rank 26, conf: 0.595268726348877
# sent 537736: |['Repair crews have degaussed the hull, Captain.', "Good. Let's plan an oh seven hundred departure. What's this?"]|
#
# -- 588700 range D4 30-60, mean conf: 0.586547315120697--
# rank 33, conf: 0.5922430753707886
# sent 537358: |['We have some excellent suggestions, Captain.', "Very well. You're welcome to join us, this time."]|
#
# ----------SENT 793281 @29---------
# TEXT: |['Yeah. Every single day.', 'You never said anything.']|
# MEAN CONF TOP100: 0.586290180683136
#
# -- 793281 range D0 0-1, mean conf: 0.5868488550186157--
# rank 2, conf: 0.5868488550186157
# sent 769489: |['Every damn year.', "It was Lenny's responsibility."]|
#
# -- 793281 range D1 1-10, mean conf: 0.5867648720741272--
# rank 4, conf: 0.5867587924003601
# sent 228810: |['I signed you up for the Ten-And-Below Talent Show next week!', "You know, I'm almost eleven, it's not really fair."]|
#
# -- 793281 range D2 10-20, mean conf: 0.5867449641227722--
# rank 16, conf: 0.5867457389831543
# sent 449632: |['What, bad day?', 'I just really needed my boyfriend.']|
#
# -- 793281 range D3 20-30, mean conf: 0.5866809487342834--
# rank 28, conf: 0.5866769552230835
# sent 1032013: |["The 17th century hottie? Wow, it's hard to forget.", 'Okay, enough about the past, tell her about the present.']|
#
# -- 793281 range D4 30-60, mean conf: 0.5863353610038757--
# rank 46, conf: 0.5862706303596497
# sent 270444: |['A whole year?', "I should have told you. I'm sorry."]|
#
# ----------SENT 963218 @30---------
# TEXT: |['Yeah...come in.', "I just wanted to say I'm sorry about yesterday."]|
# MEAN CONF TOP100: 0.5816051363945007
#
# -- 963218 range D0 0-1, mean conf: 0.5822163224220276--
# rank 2, conf: 0.5822163224220276
# sent 599176: |['Yes. come in.', "We've just completed the latest sensor sweep. So far, so good. The Northwest Passage is still clear of Borg activity."]|
#
# -- 963218 range D1 1-10, mean conf: 0.5821949243545532--
# rank 9, conf: 0.5821908712387085
# sent 1013549: |['Yes, yes, come in.', 'Sir, I just got a call from the terrorist. I told him to call back here.']|
#
# -- 963218 range D2 10-20, mean conf: 0.5821047425270081--
# rank 18, conf: 0.582064688205719
# sent 695260: |['Come in, come in.', "Ooh, you look tenser than usual. What's wrong?"]|
#
# -- 963218 range D3 20-30, mean conf: 0.5820324420928955--
# rank 28, conf: 0.582028865814209
# sent 69346: |['Greyhound Two. Come in, please. Over.', "Is that you, Yates? Now look, we're going to blast our way in. I'm calling up the artillery and RAF strike command. You lot had better evacuate to the cellars."]|
#
# -- 963218 range D4 30-60, mean conf: 0.5818142294883728--
# rank 43, conf: 0.5820288062095642
# sent 321717: |['"Oh! Please, come in."', '"Oh, thanks."']|
#
# ----------SENT 588469 @31---------
# TEXT: |['Aye, sir.', "Mister La Forge, prepare to launch the construction module. I'd like to get this over with as fast as possible."]|
# MEAN CONF TOP100: 0.5536529421806335
#
# -- 588469 range D0 0-1, mean conf: 0.5536530017852783--
# rank 1, conf: 0.5536530017852783
# sent 572764: |['Aye, sir.', "Mister Lurry, there's a Klingon warship hanging one hundred kilometres off your station."]|
#
# -- 588469 range D1 1-10, mean conf: 0.5536529421806335--
# rank 7, conf: 0.5536529421806335
# sent 575193: |['Aye, sir.', 'Mister Chekov, give him a full spread of photon torpedoes.']|
#
# -- 588469 range D2 10-20, mean conf: 0.5536528825759888--
# rank 18, conf: 0.5536529421806335
# sent 596566: |['Aye, sir.', 'Captain, we are approaching the Devolin system.']|
#
# -- 588469 range D3 20-30, mean conf: 0.5536528825759888--
# rank 23, conf: 0.5536529421806335
# sent 604055: |['Aye, sir.', 'It is turning with us, sir.']|
#
# -- 588469 range D4 30-60, mean conf: 0.5536529421806335--
# rank 56, conf: 0.5536529421806335
# sent 571805: |['Aye, sir. (leaves)', 'Scotty, push it right to the edge. This ship has got to manoeuver.']|
#
# ----------SENT 581853 @32---------
# TEXT: |['We should have worn EV suits.', 'The Doctor said it was safe for short periods.']|
# MEAN CONF TOP100: 0.5368182063102722
#
# -- 581853 range D0 0-1, mean conf: 0.5673020482063293--
# rank 2, conf: 0.5673020482063293
# sent 926749: |['JT would have never touched drugs.', 'JT was a good businessman.']|
#
# -- 581853 range D1 1-10, mean conf: 0.5657650232315063--
# rank 4, conf: 0.5666066408157349
# sent 122114: |["No. No this is major. They've already burned through the NCIS public firewall.", 'Well, isolate the node and dump it on the other side of the router.']|
#
# -- 581853 range D2 10-20, mean conf: 0.559018075466156--
# rank 17, conf: 0.558912992477417
# sent 69726: |["Well, they've completed the post mortem on Hughes.", 'And?']|
#
# -- 581853 range D3 20-30, mean conf: 0.5479936599731445--
# rank 30, conf: 0.542324960231781
# sent 55902: |["But you've dismantled the CET.", "Oh, we've got far more sophisticated stuff in the Tardis. Do it in no time."]|
#
# -- 581853 range D4 30-60, mean conf: 0.5352516770362854--
# rank 56, conf: 0.5319011807441711
# sent 246060: |["Bart, you haven't touched your mashed potatoes.", 'More breast?']|
#
# ----------SENT 54408 @33---------
# TEXT: |["Can I just check that for you? That's lovely, thank you.", 'Right, just in time. Now, where is he? Where is Harrison?']|
# MEAN CONF TOP100: 0.5364655256271362
#
# -- 54408 range D0 0-1, mean conf: 0.6938842535018921--
# rank 2, conf: 0.6938842535018921
# sent 27415: |["Wait here, Miss. I'll check for you.", 'Great.']|
#
# -- 54408 range D1 1-10, mean conf: 0.6115452647209167--
# rank 4, conf: 0.6796897649765015
# sent 578817: |["It'll be online by the end of the day tomorrow, guaranteed. Could you check the dilithium alignment for me?", "Sure. Point oh six microns. At least we'll be flying home under our own power."]|
#
# -- 54408 range D2 10-20, mean conf: 0.5401725769042969--
# rank 14, conf: 0.5428271293640137
# sent 254941: |['So, can I deliver that to the office for you?', "Ha! I wasn't born yesterday."]|
#
# -- 54408 range D3 20-30, mean conf: 0.5323641896247864--
# rank 29, conf: 0.5310957431793213
# sent 711024: |['Well I would like you to pick something out and let my buy it for you.', "Dad you don't have to buy me anything."]|
#
# -- 54408 range D4 30-60, mean conf: 0.5266230702400208--
# rank 49, conf: 0.526381254196167
# sent 900997: |['Be sure to check the mail.', 'How many times are you gonna tell me? What’s with you?']|
#
# ----------SENT 593167 @34---------
# TEXT: |['But nothing more?', 'I do not understand.']|
# MEAN CONF TOP100: 0.503589928150177
#
# -- 593167 range D0 0-1, mean conf: 0.5038153529167175--
# rank 2, conf: 0.5038153529167175
# sent 418398: |['No. Just lap dances-- nothing more.', "I think the dance might have been a bit more intimate. Penile swab's back from the lab."]|
#
# -- 593167 range D1 1-10, mean conf: 0.5036159157752991--
# rank 10, conf: 0.5036030411720276
# sent 830123: |['No. No, nothing new', "Then today was a bust. She's all yours"]|
#
# -- 593167 range D2 10-20, mean conf: 0.5036020278930664--
# rank 17, conf: 0.5036020278930664
# sent 751489: |['Uh, nothing?', 'You have to talk to her!']|
#
# -- 593167 range D3 20-30, mean conf: 0.5035927891731262--
# rank 25, conf: 0.5035932064056396
# sent 760724: |['Its nothing personal.', "I know, I'm sure once she gets to know me she'll. . ."]|
#
# -- 593167 range D4 30-60, mean conf: 0.5035854578018188--
# rank 60, conf: 0.503581702709198
# sent 824986: |['Uhhh... nothing.', 'Nothing?']|
#
# ----------SENT 727394 @35---------
# TEXT: |["Reading it again, you're just torturing yourself.", '"Ben Cochran at Harvard, he helped me out with my Boston paper, as did Frank Williams. And Rory Gilmore, I gave her her first internship at my Stamford paper, and now she\'s the editor of the Yale Daily News." Arc!']|
# MEAN CONF TOP100: 0.49523162841796875
#
# -- 727394 range D0 0-1, mean conf: 0.5185110569000244--
# rank 2, conf: 0.5185110569000244
# sent 263443: |["Oh, no, no, no. They're reading an instruction manual.", 'What?']|
#
# -- 727394 range D1 1-10, mean conf: 0.5037363171577454--
# rank 3, conf: 0.5098292231559753
# sent 595551: |["This is where it gets a little wild, Captain. Behind that panel is a junction we were using to transfer warp power to the sensor array. We're reading a subspace particle stream emanating from that junction.", 'It appears to be composed of spatially inverted tetryon particles. We believe they are emanating from a tertiary subspace manifold.']|
#
# -- 727394 range D2 10-20, mean conf: 0.5020283460617065--
# rank 21, conf: 0.5017085075378418
# sent 547092: |["There's a ship approaching at high warp. I'm reading holographic signatures.", 'Red alert.']|
#
# -- 727394 range D3 20-30, mean conf: 0.5008080005645752--
# rank 30, conf: 0.5006234049797058
# sent 637057: |['What are you reading?', "The paq'batlh. It's a sacred Klingon scroll."]|
#
# -- 727394 range D4 30-60, mean conf: 0.4992915093898773--
# rank 50, conf: 0.4991360604763031
# sent 613428: |["I'm reading a electrical storms forming all around us.", 'Adjusting flight path.']|
#
# ----------SENT 976360 @36---------
# TEXT: |['The one where you apologize to me and tend to my wounded heart. All the while explaining why your not to blame for opening up your big mouth.', "I'm not..I only told Dawson. I didn't know Kenny Leaverton was in the bathroom."]|
# MEAN CONF TOP100: 0.37983232736587524
#
# -- 976360 range D0 0-1, mean conf: 0.4354529082775116--
# rank 2, conf: 0.4354529082775116
# sent 212599: |['Had some laughs / Killed some time... "Drank lots of vodka and lime / Faked some warmth / Forced a smile / One eye on the clock the whole while..."', "Apu, you're a bachelor. Get up there!"]|
#
# -- 976360 range D1 1-10, mean conf: 0.42180779576301575--
# rank 6, conf: 0.42626214027404785
# sent 666567: |["They'll probably keep me in debrief for a while.", "You'll be okay."]|
#
# -- 976360 range D2 10-20, mean conf: 0.3920662999153137--
# rank 13, conf: 0.39378485083580017
# sent 528839: |["I don't want to get in the middle of it. Derek and I are happy. Can we just keep it that way for a while?", 'You know, you could always just swallow your pride and ask him yourself.']|
#
# -- 976360 range D3 20-30, mean conf: 0.3838748335838318--
# rank 22, conf: 0.38796108961105347
# sent 920515: |['Yeah, that’ll hold me for a while.', 'Howard, you did have a real woman. I was right there in the next room while you were clicking that troll’s brains out.']|
#
# -- 976360 range D4 30-60, mean conf: 0.37448009848594666--
# rank 46, conf: 0.37443098425865173
# sent 1039795: |["Well, this just might be worth all those years of waiting. The Charmed Ones…under my rule. Imagine the possibilities. Maybe I'll keep you around for awhile, after you complete the task at hand.", 'Kill Dog?']|
#
# ----------SENT 756633 @37---------
# TEXT: |['Can you blame him?', "No. I know I let it go too long. I just wasn't sure what Asher was thinking at first. I wasn't sure if it was just a fling for him. But over the past couple of weeks, he's been mentioning stuff about the future. He's spending a month teaching a couple of courses at Oxford over the summer and then he asked me what I was planning to do over the summer. I mean there is a definite implication that he was wondering if I was available during the summer. I think he might ask me to go with him to Oxford. I mean, why else would he ask?"]|
# MEAN CONF TOP100: 0.06889782845973969
#
# -- 756633 range D0 0-1, mean conf: 0.08076904714107513--
# rank 1, conf: 0.08076904714107513
# sent 68719: |['Can you blame him? It is possible he has gone up to a rendezvous with a flying coffin.', "Do you think they're dead?"]|
#
# -- 756633 range D1 1-10, mean conf: 0.08072009682655334--
# rank 9, conf: 0.08069536834955215
# sent 861315: |['Can you blame her? You called her a hooker.', "I'm sorry, dude, it was funny."]|
#
# -- 756633 range D2 10-20, mean conf: 0.08023836463689804--
# rank 21, conf: 0.08007585257291794
# sent 743303: |["Well, you can't blame him.", 'He had a very tortured relationship with that man, but none of that matters at the end.']|
#
# -- 756633 range D3 20-30, mean conf: 0.07978232204914093--
# rank 22, conf: 0.0800708755850792
# sent 171729: |["Well, can you blame me? I mean, I enjoyed being with the two smartest, prettiest girls in school. Together, you're almost my equal.", "I don't believe this. Clark tried to warn us about you."]|
#
# -- 756633 range D4 30-60, mean conf: 0.07386601716279984--
# rank 46, conf: 0.0774124413728714
# sent 506420: |['How can we even blame her?  If you died, I would not be able to move on.', 'You must.']|
#
# ----------SENT 292754 @38---------
# TEXT: |['Hypercellularity with total effacemenbt of the marrow space. Osteoblasts at 26%.', 'Okay. Good work, Zack. Keep working on the weapon I.D.']|
# MEAN CONF TOP100: 0.02499370649456978
#
# -- 292754 range D0 0-1, mean conf: 0.033764079213142395--
# rank 1, conf: 0.033764079213142395
# sent 509404: |['The wedding? Back on—100%!', 'Phew!']|
#
# -- 292754 range D1 1-10, mean conf: 0.03240444138646126--
# rank 11, conf: 0.030179275199770927
# sent 221135: |["If you want suspense...romance...you'll find it in the Itchy & Scratchy Movie. Coming soon to a theater near you. 53% new footage.", 'Wow.']|
#
# -- 292754 range D2 10-20, mean conf: 0.026256129145622253--
# rank 14, conf: 0.026835525408387184
# sent 862311: |['A 20% tip, really, for that waiter?', "I don't know, Barney, he worked a triple, it just..."]|
#
# -- 292754 range D3 20-30, mean conf: 0.024816351011395454--
# rank 26, conf: 0.024885648861527443
# sent 166168: |["Um, I'm gonna have to take the credit for this one. And for the record, it was a lot less creepy yesterday.", "You know, I don't think I'd still be alive if I was sitting across anyone else in that room."]|
#
# -- 292754 range D4 30-60, mean conf: 0.024183819070458412--
# rank 35, conf: 0.024543551728129387
# sent 191762: |['Here you go, Homer. A hundred and thirty-five dollars.', "I used to hate the smell of your sweaty feet. Now it's the smell of victory."]|
#
# ----------SENT 366708 @39---------
# TEXT: |['Hey-hey Pheebs!', 'What?']|
# MEAN CONF TOP100: 0.008424301631748676
#
# -- 366708 range D0 0-1, mean conf: 0.009127841331064701--
# rank 2, conf: 0.009127841331064701
# sent 343413: |['All right, let’s go! Bye, Pheebs!', 'Bye, Pheebs!']|
#
# -- 366708 range D1 1-10, mean conf: 0.009127537719905376--
# rank 10, conf: 0.009127293713390827
# sent 358336: |['Hey, Pheebs!', 'We got out pictures back from London.']|
#
# -- 366708 range D2 10-20, mean conf: 0.00871172733604908--
# rank 14, conf: 0.009127293713390827
# sent 336096: |['Hey, Pheebs!', 'What are you reading?']|
#
# -- 366708 range D3 20-30, mean conf: 0.008373533375561237--
# rank 22, conf: 0.008414008654654026
# sent 448072: |['So, how’s your Lucas quest going?', 'Fine. Ow! Hand.']|
#
# -- 366708 range D4 30-60, mean conf: 0.00831190962344408--
# rank 34, conf: 0.008341725915670395
# sent 911445: |['People could call me Angie. Yo, Angie, how’s it goin’?', 'To this day, I can’t look at pickled herring without being aroused and ashamed. Oh, cousin Jeanie.']|

# %% [markdown]
# ## Variation V4: Dep only
#
# Same as all versions except only keep dep.
#
# Full manifest:
#
# For DEP (syntactic dependency):
# * No punct dependency.
# * No ROOT.
#
# For POS (senmatic token): NO POS.
#
# Decision: reject.

# %%
data_v4 = data.loc[data.head_info!='POS']
data_v4
# Out:
#           sent_id                        show_id       char_name char_id  \
# 1          233952                    TheSimpsons    Lisa Simpson  a15823
# 5           78453                      DoctorWho         BARBARA   l8667
# 6          146223                   VeronicaMars        VERONICA  l30591
# 10        1059921                    Charmed1998            ANDY   l6497
# 18         662463                       StarTrek           PHLOX  l25490
# 19         642832                       StarTrek          HARPER   l1893
# 23         526675                   GreysAnatomy           DEREK  l12263
# 27          66679                      DoctorWho            GWEN   l9078
# 31         580866                       StarTrek          ARCHER  l25486
# 32         971419                   DawsonsCreek          DAWSON   l7946
# 36         642447                       StarTrek          HARPER   l1893
# 38         110457                           NCIS           GIBBS  l18791
# 40         403957                       CSIVerse            NICK   l7486
# 42         788696                    TheOfficeUS         MICHAEL  l19352
# 44         790267                    TheOfficeUS         MICHAEL  l19352
# 48         511955                  AdventureTime            Finn   a3415
# 49         805801                    TheOfficeUS             JIM  l19347
# 52         730165                   GilmoreGirls            RORY  l11613
# 53         585682                       StarTrek           RIKER  l25432
# 55         908523               TheBigBangTheory           PENNY   l4391
# 57         393226                       CSIVerse         GRISSOM   l7484
# 62         162342                     Smallville           CLARK  l24611
# 63         464165                    OneTreeHill          NATHAN  l19594
# 66         431264  MyLittlePonyFriendshipIsMagic          Rarity  a13095
# 76        1050595                    Charmed1998            PRUE   l6494
# 83          22777                      DoctorWho   SECOND DOCTOR   l8651
# 84         711898                   GilmoreGirls            RORY  l11613
# 85         465951                    OneTreeHill          NATHAN  l19594
# 88        1013468                       Seinfeld          GEORGE  l23594
# 99          72905                      DoctorWho  SEVENTH DOCTOR   l8656
# ...           ...                            ...             ...     ...
# 17160276   293610                          Bones         BRENNAN   l5146
# 17160277   565667                       StarTrek            HUNT   l1890
# 17160280   566363                       StarTrek            HUNT   l1890
# 17160287   614239                       StarTrek           PARIS  l25469
# 17160296   406135                       CSIVerse            NICK   l7486
# 17160298   620790                       StarTrek            BEKA   l1892
# 17160304   815378                    TheOfficeUS           KEVIN  l19354
# 17160306   384416                       Futurama          Bender   a8872
# 17160307    52154                      DoctorWho            RANI   l9061
# 17160308   482160                    OneTreeHill            CLAY  l19609
# 17160310   600643                       StarTrek        CHAKOTAY  l25467
# 17160311   538371                       StarTrek         JANEWAY  l25466
# 17160317   497238                  OnceUponATime          REGINA  l19395
# 17160328   885589                          Salem            MARY  l23233
# 17160330   660454                       StarTrek            REED  l25489
# 17160331   183094                     Smallville            TESS  l24621
# 17160333   597311                       StarTrek        CHAKOTAY  l25467
# 17160335  1007369                       Seinfeld          GEORGE  l23594
# 17160336   443968                       TheLWord           ALICE  l15690
# 17160337   875528                     Buffyverse           BUFFY   l5648
# 17160346   373719                   TheMentalist          LISBON  l17674
# 17160348  1063421                    QueerAsFolk         MICHAEL  l22346
# 17160349   709703                   GilmoreGirls            RORY  l11613
# 17160350   174190                     Smallville            LANA  l24615
# 17160352   548045                       StarTrek         JANEWAY  l25466
# 17160363  1006647                       Seinfeld          GEORGE  l23594
# 17160368   774869                        Roswell             MAX  l23046
# 17160370   860557              HowIMetYourMother          BARNEY  l13774
# 17160371   126524                           NCIS            ABBY  l18806
# 17160377   295962                          Bones         BRENNAN   l5146
#
#          head_info   head_pos      token  token_par  position  is_stop  \
# 1              DEP        det          a       girl         8     True
# 5              DEP      advcl         be       hold        34     True
# 6              DEP   compound       drug    testing         5    False
# 10             DEP      ccomp         be      think       -18     True
# 18             DEP      nsubj  condition         be       -16    False
# 19             DEP       prep     beyond         be        24     True
# 23             DEP       mark         if         be         5     True
# 27             DEP        det         no     weapon         9     True
# 31             DEP       mark         if      agree         5     True
# 32             DEP   npadvmod     PERSON       know        15    False
# 36             DEP   npadvmod     PERSON         be       -19    False
# 38             DEP       dobj         me       tell        -8     True
# 40             DEP       dobj         it       help        -5     True
# 42             DEP  nsubjpass         he      dress         9     True
# 44             DEP        neg        not       need         4     True
# 48             DEP     advmod      still         be        -3     True
# 49             DEP       prep      about  complaint       -11     True
# 52             DEP     advmod       just       feel         5     True
# 53             DEP       pobj       that       with        -5     True
# 55             DEP    auxpass         be    excited         3     True
# 57             DEP       prep         of     murder        -7     True
# 62             DEP        det        the        ORG         4     True
# 63             DEP        aux         do        get         8     True
# 66             DEP        aux        can        get         6     True
# 76             DEP      advcl        hit         be       -17    False
# 83             DEP         cc         or       turn         3     True
# 84             DEP       poss         my       life         3     True
# 85             DEP       dobj         me       tell        -5     True
# 88             DEP        aux         do       have         8     True
# 99             DEP       prep         of       cost        -5     True
# ...            ...        ...        ...        ...       ...      ...
# 17160276       DEP       pobj      sense         on        -3    False
# 17160277       DEP      nsubj       time       come         9    False
# 17160280       DEP         cc        but      right        -7     True
# 17160287       DEP        det         an   engineer         3     True
# 17160296       DEP      nsubj     PERSON       land         6    False
# 17160298       DEP     nummod   CARDINAL   CARDINAL         5     True
# 17160304       DEP        aux         to        run         3     True
# 17160306       DEP      nsubj          i      agree         2     True
# 17160307       DEP        det          a       link         2     True
# 17160308       DEP       prep       into     change        -7     True
# 17160310       DEP       pobj       ship         on       -13    False
# 17160311       DEP       dobj       cure   discover       -14    False
# 17160317       DEP       prep         of        out        -4     True
# 17160328       DEP       attr      enemy         be       -11    False
# 17160330       DEP       prep         on      paint       -21     True
# 17160331       DEP     advmod        now         be         9     True
# 17160333       DEP        det          a    society        20     True
# 17160335       DEP        det       this      thing        10     True
# 17160336       DEP      nsubj       that         go        11     True
# 17160337       DEP       dobj        her   remember        -9     True
# 17160346       DEP     advmod       once      bring       -27     True
# 17160348       DEP        det          a      sauce        19     True
# 17160349       DEP       pobj      honey        for        -4    False
# 17160350       DEP        aux         to         go         3     True
# 17160352       DEP        aux      could       wait        27     True
# 17160363       DEP       mark       that        ask        14     True
# 17160368       DEP       intj         no     PERSON         4     True
# 17160370       DEP       intj       okay         be        14    False
# 17160371       DEP      nsubj       that         be         4     True
# 17160377       DEP       case         's     PERSON        -7     True
#
#                          head_text
# 1                       det|a|girl
# 5                    advcl|be|hold
# 6            compound|drug|testing
# 10                  ccomp|be|think
# 18              nsubj|condition|be
# 19                  prep|beyond|be
# 23                      mark|if|be
# 27                   det|no|weapon
# 31                   mark|if|agree
# 32            npadvmod|PERSON|know
# 36              npadvmod|PERSON|be
# 38                    dobj|me|tell
# 40                    dobj|it|help
# 42              nsubjpass|he|dress
# 44                    neg|not|need
# 48                 advmod|still|be
# 49            prep|about|complaint
# 52                advmod|just|feel
# 53                  pobj|that|with
# 55              auxpass|be|excited
# 57                  prep|of|murder
# 62                     det|the|ORG
# 63                      aux|do|get
# 66                     aux|can|get
# 76                    advcl|hit|be
# 83                      cc|or|turn
# 84                    poss|my|life
# 85                    dobj|me|tell
# 88                     aux|do|have
# 99                    prep|of|cost
# ...                            ...
# 17160276             pobj|sense|on
# 17160277           nsubj|time|come
# 17160280              cc|but|right
# 17160287           det|an|engineer
# 17160296         nsubj|PERSON|land
# 17160298  nummod|CARDINAL|CARDINAL
# 17160304                aux|to|run
# 17160306             nsubj|i|agree
# 17160307                det|a|link
# 17160308          prep|into|change
# 17160310              pobj|ship|on
# 17160311        dobj|cure|discover
# 17160317               prep|of|out
# 17160328             attr|enemy|be
# 17160330             prep|on|paint
# 17160331             advmod|now|be
# 17160333             det|a|society
# 17160335            det|this|thing
# 17160336             nsubj|that|go
# 17160337         dobj|her|remember
# 17160346         advmod|once|bring
# 17160348               det|a|sauce
# 17160349            pobj|honey|for
# 17160350                 aux|to|go
# 17160352            aux|could|wait
# 17160363             mark|that|ask
# 17160368            intj|no|PERSON
# 17160370              intj|okay|be
# 17160371             nsubj|that|be
# 17160377            case|'s|PERSON
#
# [5039860 rows x 11 columns]

# %%
model_v4, SENT_CATS_v4, FEATURE_CATS_v4 = get_train(data_v4, report_test_acc=False)
SENT_MAP_v4, INV_SENT_MAP_v4 = build_maps(data_v4)
# Out:
# <116443x906631 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5039860 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [02:01<00:00,  1.58it/s]
# 906631 906631

# %%
mi = ModelInspection(model_v4, SENT_MAP_v4, INV_SENT_MAP_v4, dialog_df=dialogs)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 773306 @0---------
# TEXT: |["And with government agents after us, we had better get our asses in gear, don't you think?", 'Agents?']|
# MEAN CONF TOP100: 1.1626336574554443
#
# -- 773306 range D0 0-1, mean conf: 1.1730817556381226--
# rank 2, conf: 1.1730817556381226
# sent 220583: |["I deserved that. Look, I know we let you down, but me and the boys, we still think you've got a big future in racketeering and extortion.", "Sorry Fat Tony. I used to think your gang was cool, but now I learned that crime doesn't pay."]|
#
# -- 773306 range D1 1-10, mean conf: 1.170893669128418--
# rank 5, conf: 1.1716468334197998
# sent 957615: |['you got great taste in movies, I think your smart, I think your interesting', 'really']|
#
# -- 773306 range D2 10-20, mean conf: 1.1670458316802979--
# rank 21, conf: 1.166184663772583
# sent 38894: |["All right, carry on, fine. How far do you think you'll get without\nthis? (the fluid link)", 'Give that to me.']|
#
# -- 773306 range D3 20-30, mean conf: 1.1655062437057495--
# rank 31, conf: 1.164972186088562
# sent 130467: |['I think you got him, boss.', 'Well, what are we going to do with this thing? No way, Gibbs.']|
#
# -- 773306 range D4 30-60, mean conf: 1.1623308658599854--
# rank 37, conf: 1.1636496782302856
# sent 521613: |['Well, you think they still got him down at the jail?', 'I think so, yeah.']|
#
# ----------SENT 916460 @1---------
# TEXT: |['The question you should be asking is what is their problem with me? My first memory, a hummingbird dive-bombing my stroller to get at the apple juice in my sippy cup.', 'Hummingbirds are pretty.']|
# MEAN CONF TOP100: 1.1236767768859863
#
# -- 916460 range D0 0-1, mean conf: 1.2134889364242554--
# rank 2, conf: 1.2134889364242554
# sent 718969: |['So, was that a trick question?', 'We both need to cut weight from our packs.']|
#
# -- 916460 range D1 1-10, mean conf: 1.1783584356307983--
# rank 6, conf: 1.1758939027786255
# sent 26812: |['May I ask what are your sources?', 'His colleagues at Oxford, the science correspondent of The Times\nand the editor of Nature.']|
#
# -- 916460 range D2 10-20, mean conf: 1.1410000324249268--
# rank 13, conf: 1.1503350734710693
# sent 294959: |['At the very least. Very smart, Bones. What was the other reason?', 'Come on. I have winnings to collect.']|
#
# -- 916460 range D3 20-30, mean conf: 1.1262775659561157--
# rank 26, conf: 1.1257377862930298
# sent 32625: |['That is the question.', "Oh, I'm sorry, Mister Smalley. Or Co?"]|
#
# -- 916460 range D4 30-60, mean conf: 1.1167080402374268--
# rank 36, conf: 1.1194359064102173
# sent 787233: |['How is that a business question?', "Well, you're wearing it at the office. And"]|
#
# ----------SENT 954530 @2---------
# TEXT: |["is it so crazy, you have a close relationship with this man when we're goin through a hard time an when he leaves you go on a bender", 'well nothing happened, the same way nothing happened between you an Rebecca']|
# MEAN CONF TOP100: 1.0404465198516846
#
# -- 954530 range D0 0-1, mean conf: 1.151698350906372--
# rank 2, conf: 1.151698350906372
# sent 233729: |["Oh yeah, if I didn't have inner peace, I'd completely go psycho on all you guys all the time.", "Well, I'm looking for a new faith. One that isn't so materialistic."]|
#
# -- 954530 range D1 1-10, mean conf: 1.1090515851974487--
# rank 7, conf: 1.1042741537094116
# sent 680023: |["Of course it's about me. If Rory goes and has a good time without you, then I win.", 'OK, Bob Barker. Listen, Rory knocks herself out all week at Chilton. Weekends are the only time she has to unwind and have fun.']|
#
# -- 954530 range D2 10-20, mean conf: 1.0746495723724365--
# rank 19, conf: 1.068455457687378
# sent 920758: |['First of all, they’re not tricks, they’re illusions. And, secondly, when we get married, they’re all going up in the attic so you can have that closet for clothes.', 'Why would I keep clothes at your mother’s house?']|
#
# -- 954530 range D3 20-30, mean conf: 1.0541404485702515--
# rank 22, conf: 1.0646641254425049
# sent 776945: |["Not really. I've just never seen him so upset. I have this weird feeling that...he's just gonna leave without even saying goodbye.", "You know, maybe, because if he did...he wouldn't be able to go through with it."]|
#
# -- 954530 range D4 30-60, mean conf: 1.0332671403884888--
# rank 32, conf: 1.047074556350708
# sent 920652: |['What? It’s fun. If I have no cavities, afterwards, we go out for a treat.', 'All right, Howard, let’s get something straight right now. I’m not going to be your mother.']|
#
# ----------SENT 519698 @3---------
# TEXT: |['Sure, but is that really the best idea, you going home by yourself?', "I'm not. I'm going to stay at Bill's. No one'll come looking for me there."]|
# MEAN CONF TOP100: 1.0125696659088135
#
# -- 519698 range D0 0-1, mean conf: 1.1537821292877197--
# rank 2, conf: 1.1537821292877197
# sent 696700: |["It's really not appropriate to go out in.", 'Well, I did not foresee your burning loin.']|
#
# -- 519698 range D1 1-10, mean conf: 1.0994752645492554--
# rank 5, conf: 1.1060221195220947
# sent 230905: |["That's right, dead serious about going to Itchy and Scratchy Land.", "You know, Itchy and Scratchy Land isn't just for kids. They have a place called Parents Island."]|
#
# -- 519698 range D2 10-20, mean conf: 1.056672215461731--
# rank 13, conf: 1.0629717111587524
# sent 474066: |['Cut! That was good, but I think you can go bigger.', "You don't think it's already too big?"]|
#
# -- 519698 range D3 20-30, mean conf: 1.0287797451019287--
# rank 31, conf: 1.0205552577972412
# sent 948188: |["an it's not like id go without him", 'well you have to']|
#
# -- 519698 range D4 30-60, mean conf: 1.0059808492660522--
# rank 51, conf: 1.0012307167053223
# sent 946754: |["oh that's good because I think lit mags gonna go a little bit late today", 'ah huh yeah maybe next time']|
#
# ----------SENT 419890 @4---------
# TEXT: |["For something that's not a game, it sure does have a lot of rules.", 'You want to do this or not?']|
# MEAN CONF TOP100: 0.9699573516845703
#
# -- 419890 range D0 0-1, mean conf: 1.135579228401184--
# rank 2, conf: 1.135579228401184
# sent 656172: |["It's not like we have lot of time.", 'Twelve hours fifteen minutes, to be precise.']|
#
# -- 419890 range D1 1-10, mean conf: 1.054418921470642--
# rank 9, conf: 1.0279362201690674
# sent 156874: |["It's just, well, we don't have any kind of commitment or anything.", 'Oh, baby, no one is more committed to making this happen than me.']|
#
# -- 419890 range D2 10-20, mean conf: 1.0040000677108765--
# rank 15, conf: 1.0056389570236206
# sent 436681: |['Their stories were different, but they also had a lot in common.', "I guess... They were all on a ship that sank, and... that's about it."]|
#
# -- 419890 range D3 20-30, mean conf: 0.981651782989502--
# rank 27, conf: 0.9801843762397766
# sent 750856: |['Well, when you have my money to bail you out, taking risks is not much of a problem, is it?', "You're making me sound like an incompetent child."]|
#
# -- 419890 range D4 30-60, mean conf: 0.9592677354812622--
# rank 36, conf: 0.9681282639503479
# sent 864956: |["It's not like I have a list.", 'Oh, yes, you do.']|
#
# ----------SENT 768307 @5---------
# TEXT: |["That sounds great. Um we didn't need a song that necessarily had dogs in the lyrics, right, Michel?", 'Whatever. David bowie sounds like a hoot.']|
# MEAN CONF TOP100: 0.9166578054428101
#
# -- 768307 range D0 0-1, mean conf: 0.9615477323532104--
# rank 2, conf: 0.9615477323532104
# sent 1025679: |["You can have ,I don't need it anymore.", 'Ooh Mama...']|
#
# -- 768307 range D1 1-10, mean conf: 0.9511909484863281--
# rank 11, conf: 0.9465126395225525
# sent 1032974: |["Saving me? I had it under control, I didn't need your help.", 'Right.']|
#
# -- 768307 range D2 10-20, mean conf: 0.9426496624946594--
# rank 17, conf: 0.9424577355384827
# sent 683202: |["If Rory has that money she won't need you anymore.", "I don't know Mom, she's 16. There's still a couple of ways I might come in handy, you know buying the beer that kind of stuff."]|
#
# -- 768307 range D3 20-30, mean conf: 0.9329222440719604--
# rank 28, conf: 0.931263267993927
# sent 9492: |['Salyavin. I have you here at last. We have everything we need.', 'K9, the sphere! Shoot the sphere!']|
#
# -- 768307 range D4 30-60, mean conf: 0.925632119178772--
# rank 58, conf: 0.9150936007499695
# sent 751279: |["So, she has a boyfriend, which means she doesn't need another one!", "She's twenty years old, Lorelai. She's not going to be with that boy forever."]|
#
# ----------SENT 252152 @6---------
# TEXT: |['"But Greg, my Dad will kill me. And you have that scholarship to Ivy League State."', '"Loosen up, baby. Tomorrow I\'m shipping off to Vietnam." I... I thought I was going to Ivy League State.']|
# MEAN CONF TOP100: 0.8934981822967529
#
# -- 252152 range D0 0-1, mean conf: 0.922200620174408--
# rank 2, conf: 0.922200620174408
# sent 156837: |["What for? Don't you already have a scholarship to Met U?", "Yes, for football. But they're still gonna be looking at my final GPA."]|
#
# -- 252152 range D1 1-10, mean conf: 0.9113447666168213--
# rank 4, conf: 0.9125087857246399
# sent 1005188: |["I'll have the Clams Casino.", 'Get outta here.']|
#
# -- 252152 range D2 10-20, mean conf: 0.9053579568862915--
# rank 19, conf: 0.9033610820770264
# sent 216464: |['Whoa, even the Army has Humvees now!', "Homie, don't do this -- you have a wife and three young children at home."]|
#
# -- 252152 range D3 20-30, mean conf: 0.9016833305358887--
# rank 31, conf: 0.9005604386329651
# sent 586094: |['Number One, you have the Bridge.', 'Aye, sir.']|
#
# -- 252152 range D4 30-60, mean conf: 0.8941797614097595--
# rank 37, conf: 0.896289050579071
# sent 537318: |['And I have no intention of letting anyone with your technological knowledge board the Array.', 'Jabin, can we discuss this like two civilised']|
#
# ----------SENT 383604 @7---------
# TEXT: |['Quite frankly, Robot 1-X will put all my previous models to shame. Incidentally, would one of my previous models mind coming up here?', "Right here! I'm comin'! C'mon, baby! I'll do it! C'mon, Mom!"]|
# MEAN CONF TOP100: 0.8920584917068481
#
# -- 383604 range D0 0-1, mean conf: 0.9398596882820129--
# rank 2, conf: 0.9398596882820129
# sent 559439: |['Oh, but some of them were coming around, like Mapes.', "We're leaving. That's final. Now go shut the airlocks and prepare to depart."]|
#
# -- 383604 range D1 1-10, mean conf: 0.9281050562858582--
# rank 6, conf: 0.929541826248169
# sent 186271: |['And after all of this civil discourse, what understanding did you come to?', 'That we expose and destroy our first sired.']|
#
# -- 383604 range D2 10-20, mean conf: 0.9185301661491394--
# rank 17, conf: 0.9182063937187195
# sent 573863: |['Neither one of you can come in here.', "Where's Mister Seven?"]|
#
# -- 383604 range D3 20-30, mean conf: 0.9104491472244263--
# rank 26, conf: 0.9119246006011963
# sent 690582: |["Uh, no thanks. See, I already have food here. We sell it to the other customers who don't come quite as prepared as the two of you.", 'Mm, be nice and get us some salsa.']|
#
# -- 383604 range D4 30-60, mean conf: 0.8922178745269775--
# rank 46, conf: 0.8926539421081543
# sent 904379: |['Oh, sure, cut the foreigner in half, there’s a billion more where he came from.', 'Hey, if you guys need a fourth, I’ll play.']|
#
# ----------SENT 533329 @8---------
# TEXT: |["I don't like you.", 'Mm-hmm.']|
# MEAN CONF TOP100: 0.8364468216896057
#
# -- 533329 range D0 0-1, mean conf: 0.8368344306945801--
# rank 1, conf: 0.8368344306945801
# sent 1022691: |["*I* don't like you!", "If they like me, why don't they ask me to go? Oh yeah."]|
#
# -- 533329 range D1 1-10, mean conf: 0.8368337154388428--
# rank 2, conf: 0.8368344306945801
# sent 874225: |["I don't like you.", "Will, I'm sorry about today. You know how my foot likes to live in my mouth."]|
#
# -- 533329 range D2 10-20, mean conf: 0.8366646766662598--
# rank 19, conf: 0.8365920782089233
# sent 292333: |["But juries don't like you.", 'Excuse me?']|
#
# -- 533329 range D3 20-30, mean conf: 0.8364689946174622--
# rank 26, conf: 0.8364694118499756
# sent 1010067: |['"I don\'t like him."', 'Uh-Huh']|
#
# -- 533329 range D4 30-60, mean conf: 0.8363884687423706--
# rank 36, conf: 0.8364399671554565
# sent 519132: |["Meh, no, I-I don't like her.", 'This is all your fault, Finn!']|
#
# ----------SENT 465111 @9---------
# TEXT: |['That’s it. Stay with Dan,… Keith and Jules get to be happy.', 'Yeah, till she sings a duet… and goes on tour.']|
# MEAN CONF TOP100: 0.8255130648612976
#
# -- 465111 range D0 0-1, mean conf: 0.9221973419189453--
# rank 2, conf: 0.9221973419189453
# sent 231572: |["Lisa? This isn't working. I've got to courier something to Springfield. And it's gotta be big enough to fit Milhouse, Martin, and Nelson inside.", "But Bart, that'll cost a fortune."]|
#
# -- 465111 range D1 1-10, mean conf: 0.8790890574455261--
# rank 3, conf: 0.9071826338768005
# sent 291989: |['To get Shawn and David back with Margaret Sanders.', 'Maybe I was lying. To catch the bad guy. I learned that trick from you. The end justifies the means.']|
#
# -- 465111 range D2 10-20, mean conf: 0.8579257726669312--
# rank 15, conf: 0.8592289686203003
# sent 724131: |['I need to get a new getting-back-together-with-Luke dress for my back-together-with-Luke date.', 'Oh, where do you want to go?']|
#
# -- 465111 range D3 20-30, mean conf: 0.8462573885917664--
# rank 25, conf: 0.8481212854385376
# sent 20741: |["No, ma'am. We're not escaping. We've got to help the Doctor with Clara.", 'Long story.']|
#
# -- 465111 range D4 30-60, mean conf: 0.8214858174324036--
# rank 52, conf: 0.8177701234817505
# sent 256129: |["Every afternoon at Moe's, Chief Wiggum, Principal Skinner, Apu and I would get together and sing... and the crowds went wild.", 'Yoo hoo!']|
#
# ----------SENT 600802 @10---------
# TEXT: |["I promised the crew I'd get them home.", "Home isn't Earth."]|
# MEAN CONF TOP100: 0.8048335313796997
#
# -- 600802 range D0 0-1, mean conf: 0.8423586487770081--
# rank 2, conf: 0.8423586487770081
# sent 1044088: |["I promised him I'd get him home safely.", 'I know, but you can still save his future, and you can still save Wyatt. We just have to hurry, and you have to focus. Okay? Look, you were saying something about the underworld, about looking for something there. What?']|
#
# -- 600802 range D1 1-10, mean conf: 0.8347854614257812--
# rank 4, conf: 0.8418278694152832
# sent 169463: |['Well, I promised his parents I would get him home.', 'Well, I think I can manage that.']|
#
# -- 600802 range D2 10-20, mean conf: 0.8144972920417786--
# rank 13, conf: 0.8193792104721069
# sent 295929: |["I - I will if it doesn't get any better. Ow! Man.", 'Are you afraid of the dentist?']|
#
# -- 600802 range D3 20-30, mean conf: 0.806766152381897--
# rank 24, conf: 0.80754554271698
# sent 542539: |['As soon as he can get people together.', 'Leave it to Neelix to come up with the right idea at the right time.']|
#
# -- 600802 range D4 30-60, mean conf: 0.8013082146644592--
# rank 38, conf: 0.8028775453567505
# sent 131207: |["I told you he hated the Navy. Every morning he'd put on his uniform and go to the office. As soon as he got home, couldn't get out of it fast enough.", "You didn't know Jerry long before you married, did you?"]|
#
# ----------SENT 82516 @11---------
# TEXT: |["Hey, what's wrong?", "She doesn't like the Tardis noise. I asked him to turn something off, but it was all, but I don't want to punch a hole in the space-time continuum. Shush."]|
# MEAN CONF TOP100: 0.7408246397972107
#
# -- 82516 range D0 0-1, mean conf: 0.7535101771354675--
# rank 1, conf: 0.7535101771354675
# sent 471185: |["Peyton? Hey, what's wrong?", 'I went to see him.']|
#
# -- 82516 range D1 1-10, mean conf: 0.7535101175308228--
# rank 3, conf: 0.7535101175308228
# sent 945646: |["hey, what's wrong", 'Seth is gone']|
#
# -- 82516 range D2 10-20, mean conf: 0.7493805289268494--
# rank 15, conf: 0.753510057926178
# sent 784086: |["Hey, what's wrong?", 'I invite you into my house and you go through my stuff?']|
#
# -- 82516 range D3 20-30, mean conf: 0.7422881126403809--
# rank 31, conf: 0.7411607503890991
# sent 155076: |["What's up, Kal?", "Hey, what's up."]|
#
# -- 82516 range D4 30-60, mean conf: 0.7411608099937439--
# rank 39, conf: 0.7411607503890991
# sent 807942: |["What's up, Pam?", "I just wanted to let you that Dwight's gonna be ok. The doctor said there's a really simple treatment for a concussion, so he'll probably even be back at work tomorrow."]|
#
# ----------SENT 901598 @12---------
# TEXT: |['Hey, uh, Leonard, things are a little tight at the comic book store. I might need some help covering my share of the check.', 'Oh, yeah, no worries.']|
# MEAN CONF TOP100: 0.708825409412384
#
# -- 901598 range D0 0-1, mean conf: 0.7100346088409424--
# rank 2, conf: 0.7100346088409424
# sent 125770: |['I think I have a more constructive way for you to spend your time. I need some help.', 'Okay.']|
#
# -- 901598 range D1 1-10, mean conf: 0.7099373936653137--
# rank 9, conf: 0.7097761631011963
# sent 537894: |["I'll need some help.", "You have my authorisation to use any of the ships personnel you need. This has top priority. And don't worry about secrecy. I doubt you'd be able to keep this quiet for very long."]|
#
# -- 901598 range D2 10-20, mean conf: 0.7093005180358887--
# rank 16, conf: 0.7092815637588501
# sent 639019: |['Do you need some help?', 'I need to contact my ship.']|
#
# -- 901598 range D3 20-30, mean conf: 0.7091377973556519--
# rank 28, conf: 0.7091399431228638
# sent 675387: |['You need some help?', 'No.']|
#
# -- 901598 range D4 30-60, mean conf: 0.7087221145629883--
# rank 46, conf: 0.708754301071167
# sent 689404: |['I need help.', 'With what?']|
#
# ----------SENT 743100 @13---------
# TEXT: |["Uh, yeah, I guess. Although, it depends on what you'd call recently.", "In the last year, you've been divorced in the last year, that would be recent."]|
# MEAN CONF TOP100: 0.7051652073860168
#
# -- 743100 range D0 0-1, mean conf: 0.7064558267593384--
# rank 2, conf: 0.7064558267593384
# sent 239239: |['Hindu. What do you call the moisture on your Hin?', 'Classic. Now, tell them how to run a nuclear plant!']|
#
# -- 743100 range D1 1-10, mean conf: 0.7058830261230469--
# rank 11, conf: 0.7055294513702393
# sent 1070122: |['What do you call this?', "I'll promised you can blow me tomorrow night."]|
#
# -- 743100 range D2 10-20, mean conf: 0.7054721713066101--
# rank 17, conf: 0.7054513096809387
# sent 857598: |["See, that's just it. I'm not the boyfriend, I'm the mistress. No, not the mistress. The mastress. Master. What do you call it?", "I'm pretty sure we're gonna call is mistress."]|
#
# -- 743100 range D3 20-30, mean conf: 0.7053623795509338--
# rank 26, conf: 0.7053855061531067
# sent 819874: |['Here we go... ok... what do African Americans call...', 'Deangelo, did you order a barber?']|
#
# -- 743100 range D4 30-60, mean conf: 0.7051197290420532--
# rank 42, conf: 0.7051366567611694
# sent 191522: |['Hey, hey, this drink is delicious! And my phlegm feels looser. What do you call it?', 'Well, it\'s called a "Flaming...']|
#
# ----------SENT 888209 @14---------
# TEXT: |['How is that not a braniac?', 'Well, for one thing, she was French. For another, it was literature.']|
# MEAN CONF TOP100: 0.6723079681396484
#
# -- 888209 range D0 0-1, mean conf: 0.7275750041007996--
# rank 2, conf: 0.7275750041007996
# sent 1058123: |["I don't believe this. Someone is killing witches, possibly as we speak. How is that not your only priority?", "Because we're running out of time, that's why."]|
#
# -- 888209 range D1 1-10, mean conf: 0.7083733081817627--
# rank 7, conf: 0.7088351249694824
# sent 187766: |["Marcel has a way to tell whenever there's magic done in the Quarter. The 'how' isn't relevant.", "I'll tell you what's not bloody relevant – a coven of witches who can't do magic. Here's an idea: move away."]|
#
# -- 888209 range D2 10-20, mean conf: 0.6875282526016235--
# rank 14, conf: 0.6866233348846436
# sent 1031664: |["How can it not be? Dan is aging because I wished for him to move on with his life. He would be fine if it wasn't for me. It's not fair, he doesn't deserve this. It's bad enough the wishes are biting us in the ass but not him. This shouldn't be happening to him.", "We have to find the genie. It's the only way to save Dan... and Prue."]|
#
# -- 888209 range D3 20-30, mean conf: 0.6860837936401367--
# rank 28, conf: 0.6865468621253967
# sent 607487: |['How can that be?', 'The lead ship is using some kind of long range tachyon scanner to penetrate our cloaks.']|
#
# -- 888209 range D4 30-60, mean conf: 0.6691519021987915--
# rank 59, conf: 0.6624097228050232
# sent 342159: |["Oh my God! That is so not the opposite of taking somebody's underwear!!", "Look at me! I'm Chandler! Could I be wearing any more clothes? Maybe if I wasn't going commando..."]|
#
# ----------SENT 995528 @15---------
# TEXT: |['What did you do?', 'What do you think? I gave him my Pez dispenser.']|
# MEAN CONF TOP100: 0.6716222167015076
#
# -- 995528 range D0 0-1, mean conf: 0.6716222167015076--
# rank 1, conf: 0.6716222167015076
# sent 855569: |['What did you do?', 'Honestly, I thought to marry him just out of sheer embarrassment. But I did the right thing. I did what anyone who has someone should hook her. I would have broken my heart.']|
#
# -- 995528 range D1 1-10, mean conf: 0.6716221570968628--
# rank 6, conf: 0.6716221570968628
# sent 136886: |['So do you. Why do you look so happy? What did you do?', 'Nothing. Have a good first day of school. Bye.']|
#
# -- 995528 range D2 10-20, mean conf: 0.6716221570968628--
# rank 19, conf: 0.6716221570968628
# sent 73119: |['Oh, thanks, Doctor. We ran into this piece of space junk. What did you do?', 'Well, I simply applied the Tardis vortex drive to generate an antigravity spiral to halt your descent. Sorry about the bumpy landing. A miscalculation.']|
#
# -- 995528 range D3 20-30, mean conf: 0.6716221570968628--
# rank 28, conf: 0.6716221570968628
# sent 53910: |["Then suddenly I've got Clyde leaving me a message. I rush down here and you tell me Mum's gone. What did you do? I trusted you.", "Oh, so it's my fault again."]|
#
# -- 995528 range D4 30-60, mean conf: 0.6716219782829285--
# rank 45, conf: 0.6716221570968628
# sent 733924: |['My bedroom window is on the second floor. What did you do?', "Well, I promised to fix your window, so I'm here to fix your window."]|
#
# ----------SENT 982035 @16---------
# TEXT: |['Do you do these things to upset me Jennifer?', 'It was only a kiss Grams.']|
# MEAN CONF TOP100: 0.6686371564865112
#
# -- 982035 range D0 0-1, mean conf: 0.6811184287071228--
# rank 2, conf: 0.6811184287071228
# sent 117346: |['Why are you doing these things?', 'Sharpening my investigative skills.']|
#
# -- 982035 range D1 1-10, mean conf: 0.6763187646865845--
# rank 7, conf: 0.676209568977356
# sent 398814: |["I got a ton of people out interviewing every two-bit stiff that ever had a beef against Flynn. They're all doing the smart thing -- keeping their mouth shut.", 'So we have no statements or physical evidence indicating it was a hit on Flynn.']|
#
# -- 982035 range D2 10-20, mean conf: 0.6730148196220398--
# rank 16, conf: 0.672819197177887
# sent 444956: |["You're doing the right thing, Bette.", 'After this week, I should be able to get back to some... semblance of a normal schedule.']|
#
# -- 982035 range D3 20-30, mean conf: 0.6710763573646545--
# rank 23, conf: 0.6716722846031189
# sent 686648: |["And she's doing that no-hose thing.", "Yeah. She's a chic, good hair, wrinkle-free, no-hose-wearing witch."]|
#
# -- 982035 range D4 30-60, mean conf: 0.6686074733734131--
# rank 48, conf: 0.6685302257537842
# sent 135212: |['How could someone do the things this man did, Doctor?', "Oh, in some cases, there's a physiological defect in the hard-wiring of their brains. Yeah, a mechanism that precludes the ability to feel genuine emotion."]|
#
# ----------SENT 546358 @17---------
# TEXT: |["Just that they're a more gullible species than most.", 'Tell her about your research, Mister Tuvok.']|
# MEAN CONF TOP100: 0.6674723029136658
#
# -- 546358 range D0 0-1, mean conf: 0.7309304475784302--
# rank 2, conf: 0.7309304475784302
# sent 909809: |['"It\'s just so perfect that we\'re both Libras."', "Wow, this is hard. I'm gonna say Cinnamon."]|
#
# -- 546358 range D1 1-10, mean conf: 0.7094032168388367--
# rank 10, conf: 0.6969541311264038
# sent 1040893: |["We should all just be thankful that we're alive.", "And visible. Although I'm not sure how that happened."]|
#
# -- 546358 range D2 10-20, mean conf: 0.6879643201828003--
# rank 17, conf: 0.6846141815185547
# sent 824080: |["Like that people are stupid, and that they're idiots, and that they're sluts.", 'Why would he say that?']|
#
# -- 546358 range D3 20-30, mean conf: 0.6770455837249756--
# rank 28, conf: 0.6754804849624634
# sent 41561: |['Yes. Just as though it were alive.', 'Alive! Yes.']|
#
# -- 546358 range D4 30-60, mean conf: 0.6630507707595825--
# rank 40, conf: 0.6661136746406555
# sent 374064: |["Well, my friend says to stay away from them. That they're bad news.", "Good, sound lawyerly advice. I'll take that under advisement."]|
#
# ----------SENT 593646 @18---------
# TEXT: |["Mister Data, you are our resident honour student in exobiology. I'm assigning you to head up the Life Sciences on this mission.", 'Aye, sir.']|
# MEAN CONF TOP100: 0.6574786901473999
#
# -- 593646 range D0 0-1, mean conf: 0.6581141948699951--
# rank 2, conf: 0.6581141948699951
# sent 696683: |['So send me a Honeybaked Ham.', 'But this is wrong. This is not how you do these things.']|
#
# -- 593646 range D1 1-10, mean conf: 0.657892107963562--
# rank 8, conf: 0.6578149199485779
# sent 628346: |["Captain's log, supplemental. We've weathered the ion storm and tracked the Delta Flyer to an M-class planetoid.", "I'm detecting a residual impulse signature in the upper atmosphere."]|
#
# -- 593646 range D2 10-20, mean conf: 0.6576279401779175--
# rank 17, conf: 0.657633364200592
# sent 230644: |['Oh, no. I must have joined the Junior Campers!', 'The few, the proud, the geeky.']|
#
# -- 593646 range D3 20-30, mean conf: 0.6575072407722473--
# rank 29, conf: 0.6574974656105042
# sent 749570: |['The Hartford Zoological Silent Auction, the Mark Twain House Restoration Fund luncheon, the Harriet Beecher Stowe Literacy Auction.', 'I can read those myself, you know.']|
#
# -- 593646 range D4 30-60, mean conf: 0.657446026802063--
# rank 48, conf: 0.6574334502220154
# sent 393429: |['The Ground Fault Circuit Interrupter.', "Big words meaning you won't get electrocuted."]|
#
# ----------SENT 810922 @19---------
# TEXT: |['Kevin!? Kelly!? Kathy!? Andy just gave me a chain with three weak links. Have you ever tried to use a chain with three weak links? I have. And now I no longer own an arctic wolf.', "Well, let's hear it."]|
# MEAN CONF TOP100: 0.6514099836349487
#
# -- 810922 range D0 0-1, mean conf: 0.6955344676971436--
# rank 2, conf: 0.6955344676971436
# sent 621175: |["If you land the Maru, you die. I've put explosives on your ship. If you try to communicate with anyone, you die. It will detonate if you try to use your comm.", 'What are you talking about?']|
#
# -- 810922 range D1 1-10, mean conf: 0.67061847448349--
# rank 10, conf: 0.6605677008628845
# sent 3118: |["Well, that for a start. It hasn't been fired for fifty years. If you try to use it, it'll probably explode in your face.", 'Explode? Unthinkable. It was made in Birmingham. Tie up over there, skipper.']|
#
# -- 810922 range D2 10-20, mean conf: 0.6565738916397095--
# rank 15, conf: 0.6578097939491272
# sent 580922: |["Someone's trying to open Launch bay two.", 'Lock them out.']|
#
# -- 810922 range D3 20-30, mean conf: 0.6522492170333862--
# rank 22, conf: 0.6542249321937561
# sent 2343: |['Alien intruders and unidentified Kastrian have reached regeneration chamber. Should they try to enter, they will be eliminated.', "I never met a door that couldn't be opened somehow."]|
#
# -- 810922 range D4 30-60, mean conf: 0.6489192843437195--
# rank 34, conf: 0.6508687138557434
# sent 601762: |["They're trying to lock on us with a tractor beam.", 'Reverse thrusters. Full power.']|
#
# ----------SENT 811973 @20---------
# TEXT: |['Oh my God.', 'I had no idea.']|
# MEAN CONF TOP100: 0.6319160461425781
#
# -- 811973 range D0 0-1, mean conf: 0.6319161057472229--
# rank 1, conf: 0.6319161057472229
# sent 825837: |['Oh my God.', 'Hey, Jim.']|
#
# -- 811973 range D1 1-10, mean conf: 0.6319160461425781--
# rank 2, conf: 0.6319161057472229
# sent 157957: |['Oh my God.', 'Merry Christmas, Lana.']|
#
# -- 811973 range D2 10-20, mean conf: 0.6319160461425781--
# rank 11, conf: 0.6319160461425781
# sent 801932: |['No no, yes there is. Behind the shelves. Oh my God.', 'What? What?']|
#
# -- 811973 range D3 20-30, mean conf: 0.6319160461425781--
# rank 27, conf: 0.6319160461425781
# sent 1064640: |['Oh! Oh, my God!', "I've warned you."]|
#
# -- 811973 range D4 30-60, mean conf: 0.6319160461425781--
# rank 47, conf: 0.6319160461425781
# sent 537137: |["That's it! This is pain! That's what causes the pain! Oh, my God!", 'anterior ethmoid neurovascular complex. A simple turbinectomy fix it. Unless you still want to take out his little brain.']|
#
# ----------SENT 893140 @21---------
# TEXT: |['I’m all for it.', 'Attaboy!']|
# MEAN CONF TOP100: 0.6209990382194519
#
# -- 893140 range D0 0-1, mean conf: 0.7078397274017334--
# rank 2, conf: 0.7078397274017334
# sent 484416: |['I guess you could take comfort in the fact that he’s being safe, but you know mistakes happen. I’m a walking poster child for it.', 'Oh boy. Karen’s calling tonight, what am I going to tell her? You know besides the fact that I want what’s best for Lucas, I just, I don’t wanna let her down.']|
#
# -- 893140 range D1 1-10, mean conf: 0.6806440353393555--
# rank 4, conf: 0.6893847584724426
# sent 1069675: |["Why not? Since I'm payin' for it.", "New York's amazing. I went clubbing last night until six in the morning. And the guys, whoo, the guys are --"]|
#
# -- 893140 range D2 10-20, mean conf: 0.6525007486343384--
# rank 12, conf: 0.6558734178543091
# sent 432098: |["Oh, there's no emergency! I'm just waitin' for an apology.", 'An apology?!']|
#
# -- 893140 range D3 20-30, mean conf: 0.643237829208374--
# rank 22, conf: 0.6502084136009216
# sent 519575: |["I was lookin' for ya.", 'Well...you found me.']|
#
# -- 893140 range D4 30-60, mean conf: 0.6185837984085083--
# rank 52, conf: 0.6111043691635132
# sent 937152: |["I'm here for you.", 'Fig?']|
#
# ----------SENT 623564 @22---------
# TEXT: |["Ready weapons. We're going to disperse it.", 'Phasers online.']|
# MEAN CONF TOP100: 0.6099626421928406
#
# -- 623564 range D0 0-1, mean conf: 0.6101874709129333--
# rank 1, conf: 0.6101874709129333
# sent 96500: |["That's the best part. They only found half. We're going.", "We're seriously doing this?"]|
#
# -- 623564 range D1 1-10, mean conf: 0.6101874709129333--
# rank 8, conf: 0.6101874709129333
# sent 664047: |['Like I said, no weapons. We are going native.', "As loathe as I am to agree with him, I'll have to concur. It is highly imprudent not to carry something"]|
#
# -- 623564 range D2 10-20, mean conf: 0.6101874709129333--
# rank 12, conf: 0.6101874709129333
# sent 270317: |["Sam. We're going!", 'No!']|
#
# -- 623564 range D3 20-30, mean conf: 0.6101866960525513--
# rank 25, conf: 0.6101874113082886
# sent 795803: |["Let's go to the zone! We're going to zone!", 'De-fense!']|
#
# -- 623564 range D4 30-60, mean conf: 0.6101300120353699--
# rank 46, conf: 0.6101446747779846
# sent 867390: |['Who are we gonna...', '"Dear Wang Guy...Can enemies ever be friends? Just wondering."']|
#
# ----------SENT 316350 @23---------
# TEXT: |["You're not screwing with me, are you? You're just like this.", 'Yes. This is exactly how I am.']|
# MEAN CONF TOP100: 0.5726361274719238
#
# -- 316350 range D0 0-1, mean conf: 0.6172220706939697--
# rank 2, conf: 0.6172220706939697
# sent 451300: |["Yeah! Of course I promise. You're stuck with me.", "I'm really sorry that I've been distant. I'm trying to get back. It's just gonna take a little while."]|
#
# -- 316350 range D1 1-10, mean conf: 0.609851598739624--
# rank 6, conf: 0.6152356266975403
# sent 312968: |['Are you angry with me?', 'Yes, I am angry, Dr Brennan. We had a great thing going and you just... You let it fall apart.']|
#
# -- 316350 range D2 10-20, mean conf: 0.6047470569610596--
# rank 12, conf: 0.6047618389129639
# sent 634013: |["I'll take that as a yes. You're with me.", "There. I've aligned the field coils."]|
#
# -- 316350 range D3 20-30, mean conf: 0.5998339653015137--
# rank 22, conf: 0.604538083076477
# sent 919486: |['Yes. You’re either with me or against me.', 'You want to take the bus to work?']|
#
# -- 316350 range D4 30-60, mean conf: 0.5699109435081482--
# rank 41, conf: 0.567826509475708
# sent 670472: |['Apparently not. He wants Sydney, too. Are you with her?', "Uh, no, I haven't seen her."]|
#
# ----------SENT 600541 @24---------
# TEXT: |['Shields down to sixty two percent.', 'Return fire.']|
# MEAN CONF TOP100: 0.5635455846786499
#
# -- 600541 range D0 0-1, mean conf: 0.5654047727584839--
# rank 1, conf: 0.5654047727584839
# sent 597804: |['Powering up lateral phaser arrays. Shields down to eighty three percent.', 'Return fire.']|
#
# -- 600541 range D1 1-10, mean conf: 0.5654046535491943--
# rank 2, conf: 0.5654047727584839
# sent 540929: |['Shields down to eighty four percent.', 'Returning fire.']|
#
# -- 600541 range D2 10-20, mean conf: 0.565403163433075--
# rank 15, conf: 0.5654029250144958
# sent 541131: |['Shields down to eighty five percent.', 'Return fire.']|
#
# -- 600541 range D3 20-30, mean conf: 0.5651341676712036--
# rank 31, conf: 0.5638650059700012
# sent 546111: |["Shield's down to forty eight percent.", "Target the lead ship's weapons array."]|
#
# -- 600541 range D4 30-60, mean conf: 0.5631222128868103--
# rank 54, conf: 0.5628572106361389
# sent 552102: |['Captain, energy loss increasing to five percent.', 'Yellow Alert.']|
#
# ----------SENT 299005 @25---------
# TEXT: |['You’re bored. Hm. Spark is gone.', 'I’m a scientist first.']|
# MEAN CONF TOP100: 0.4616038501262665
#
# -- 299005 range D0 0-1, mean conf: 0.46170419454574585--
# rank 1, conf: 0.46170419454574585
# sent 6059: |["Quite sure. Something's gone astray.", "No, no, no, just a minute. There may have been a time shift.\nLet's take another reading."]|
#
# -- 299005 range D1 1-10, mean conf: 0.46170419454574585--
# rank 8, conf: 0.46170416474342346
# sent 183411: |['If I pull these tanks, then the mainframe melts. All my work. Watchtower is gone.', "If you don't, we die."]|
#
# -- 299005 range D2 10-20, mean conf: 0.46170416474342346--
# rank 15, conf: 0.46170416474342346
# sent 503863: |['Because there’s nothing to go back to. That land is gone.', 'We should get to Gold.']|
#
# -- 299005 range D3 20-30, mean conf: 0.4617013931274414--
# rank 22, conf: 0.4617041349411011
# sent 514617: |['The piglets are gone!', 'And so are the fairy wands.']|
#
# -- 299005 range D4 30-60, mean conf: 0.4616338014602661--
# rank 50, conf: 0.4616115689277649
# sent 543559: |['They are fading. They are gone.', "All right. Let's see what we can do to keep them from coming back. What's the last thing you remember?"]|
#
# ----------SENT 153235 @26---------
# TEXT: |['You remember this?', "It's my first fishing rod."]|
# MEAN CONF TOP100: 0.45097431540489197
#
# -- 153235 range D0 0-1, mean conf: 0.45115751028060913--
# rank 2, conf: 0.45115751028060913
# sent 481127: |['Not fair. True. Oh, my gosh. Oh, my god. You remember this?', 'This is horrible. Oh, mom, look at my hair. You gave me the most awful haircut.']|
#
# -- 153235 range D1 1-10, mean conf: 0.45112425088882446--
# rank 8, conf: 0.4511242210865021
# sent 402106: |['You remember your geology.', 'Yes!']|
#
# -- 153235 range D2 10-20, mean conf: 0.4511198401451111--
# rank 12, conf: 0.4511241912841797
# sent 572429: |['Yes. Yes, indeed, Captain. Doctor, you remember', 'He was scared! He saw the dead body and he ran out of the building and he was scared to death.']|
#
# -- 153235 range D3 20-30, mean conf: 0.4510940909385681--
# rank 23, conf: 0.45110681653022766
# sent 128626: |['You remember who buried you?', "She may always block that memory. Isn't that right, Doctor?"]|
#
# -- 153235 range D4 30-60, mean conf: 0.4509850740432739--
# rank 44, conf: 0.4510244131088257
# sent 42808: |["You remember the agreement? They must find your Tardis before you finish your game. If they don't, then you will have to stay here and you'll be in my power forever. Look, they've already reached their next test.", 'That game? I might have known.']|
#
# ----------SENT 649884 @27---------
# TEXT: |['Thirty three, thirty four, thirty five. And that fluidic converter needs to be purged.', 'Right.']|
# MEAN CONF TOP100: 0.4439272880554199
#
# -- 649884 range D0 0-1, mean conf: 0.44528380036354065--
# rank 2, conf: 0.44528380036354065
# sent 543800: |["No, for that you'll need my guidance and some luck.", "I'll have to take this up with the Brenari. See what they think of their new benefactor. I'll let you know what they decide. I'll have to insist you remain under guard. No hard feelings."]|
#
# -- 649884 range D1 1-10, mean conf: 0.4448340833187103--
# rank 4, conf: 0.4452653229236603
# sent 1069461: |['And you may need an employment insurance.', 'What?']|
#
# -- 649884 range D2 10-20, mean conf: 0.4442530572414398--
# rank 13, conf: 0.4444107115268707
# sent 1050706: |["Is that what you think? That we don't need you anymore?", "Well, I mean, it's just that ever since Piper got married and you moved up with Cole, I feel like I don't really have to watch out for you guys as much anymore."]|
#
# -- 649884 range D3 20-30, mean conf: 0.4440454840660095--
# rank 30, conf: 0.4439837336540222
# sent 464002: |['Well, maybe you need to rethink your approach.', 'Well, you’re his friend. How do I handle this?']|
#
# -- 649884 range D4 30-60, mean conf: 0.44385161995887756--
# rank 38, conf: 0.4438978433609009
# sent 29904: |["I don't care. I'll deal with the Xylok later. We don't need him to avenge our family.", "If you kill us, you'll never stop Mister Smith, and you'll never get off this planet alive."]|
#
# ----------SENT 55505 @28---------
# TEXT: |['It is very a pretty painting.', "It's a very sophisticated device for a level five civilisation."]|
# MEAN CONF TOP100: 0.4347207844257355
#
# -- 55505 range D0 0-1, mean conf: 0.4348032772541046--
# rank 1, conf: 0.4348032772541046
# sent 595006: |["It's just a painting.", 'Timothy, you understand that you may speak with me about anything you wish? Any subject?']|
#
# -- 55505 range D1 1-10, mean conf: 0.4347389042377472--
# rank 11, conf: 0.4347304701805115
# sent 247243: |["It's an armed robbery, dammit!", 'I guess we should go.']|
#
# -- 55505 range D2 10-20, mean conf: 0.43472710251808167--
# rank 15, conf: 0.4347280263900757
# sent 737713: |["It's an abstract painting.", 'But what is it supposed to be?']|
#
# -- 55505 range D3 20-30, mean conf: 0.43472152948379517--
# rank 26, conf: 0.43472158908843994
# sent 394245: |['Yes ... only it was ...', '... from above.']|
#
# -- 55505 range D4 30-60, mean conf: 0.4347184896469116--
# rank 33, conf: 0.4347206950187683
# sent 979232: |["It's an ashtray.", "Yeah. Thank you, I've been meaning to take up smoking."]|
#
# ----------SENT 560249 @29---------
# TEXT: |['Andromeda the ship, not the persona, but wearing a big, pointy hat.', 'So, this is the disturbing part.']|
# MEAN CONF TOP100: 0.4312300980091095
#
# -- 560249 range D0 0-1, mean conf: 0.4323272109031677--
# rank 2, conf: 0.4323272109031677
# sent 588558: |['Lay in an intercept course for the Romulan ship.', 'Shields up. Load all torpedo bays. Stand by phasers.']|
#
# -- 560249 range D1 1-10, mean conf: 0.4317237436771393--
# rank 4, conf: 0.4318667948246002
# sent 387741: |["Now, Leela, couldn't we just fire you and have Fry or Bender fly the ship?", 'Not if you stand on their air hose much longer.']|
#
# -- 560249 range D2 10-20, mean conf: 0.4314762055873871--
# rank 16, conf: 0.43148860335350037
# sent 547393: |['The Vaadwaur ship is retreating.', 'Hail the second ship.']|
#
# -- 560249 range D3 20-30, mean conf: 0.4313594698905945--
# rank 28, conf: 0.43133699893951416
# sent 661985: |['Outside the ship, crawling on the hull.', 'What about what I saw in Engineering?']|
#
# -- 560249 range D4 30-60, mean conf: 0.43121713399887085--
# rank 46, conf: 0.43123549222946167
# sent 560447: |["It's not repelling the objects. They're migrating along the ship's surface.", 'Where to?']|
#
# ----------SENT 605404 @30---------
# TEXT: |["Ah. We've received new directives from the Federation Council on this matter. Until we can find a way to counteract the warp field effect, the Council feels our best course is to slow the damage as much as possible. Therefore, areas of space found susceptible to warp fields will be restricted to essential travel only, and effective immediately all Federation vessels will be limited to a speed of warp five, except in cases of extreme emergency.", 'The Klingons will observe these restrictions, but the Romulans will not.']|
# MEAN CONF TOP100: 0.42221805453300476
#
# -- 605404 range D0 0-1, mean conf: 0.4365661144256592--
# rank 2, conf: 0.4365661144256592
# sent 585133: |['Who in this case sail the galaxy in search of mercantile and territorial opportunity.', 'And are those scholars saying the Ferengi may not unlike us?']|
#
# -- 605404 range D1 1-10, mean conf: 0.43257635831832886--
# rank 9, conf: 0.4313976764678955
# sent 1040709: |["No, it's completely forbidden, except in cases of dire emergencies.", "What's forbidden?"]|
#
# -- 605404 range D2 10-20, mean conf: 0.42776060104370117--
# rank 18, conf: 0.42708414793014526
# sent 427396: |['Or in the sky, in this case.', 'Come on, come on, come on!']|
#
# -- 605404 range D3 20-30, mean conf: 0.42523717880249023--
# rank 28, conf: 0.4251950681209564
# sent 535560: |["Well he's separated from his wife. That usually doesn't make a person giddy. Except in my case.", 'I think he needs someone to talk to.']|
#
# -- 605404 range D4 30-60, mean conf: 0.4218398928642273--
# rank 43, conf: 0.42180919647216797
# sent 317385: |['"What happens to all mortal beings. Albeit sooner in her case."', '"She\'ll die? - Then I\'m here to beg for her life."']|
#
# ----------SENT 507013 @31---------
# TEXT: |["Let's cut around the harbor, it'll be faster.  David...  David?", "Hang on.  I think there's a way we can put a stop to all this.  I think...  I think we should... destroy the page."]|
# MEAN CONF TOP100: 0.39804762601852417
#
# -- 507013 range D0 0-1, mean conf: 0.39881619811058044--
# rank 2, conf: 0.39881619811058044
# sent 130199: |['Agents Todd, DiNozzo. NCIS.', 'Do you always work on your own planes, Mister McAllister?']|
#
# -- 507013 range D1 1-10, mean conf: 0.39881616830825806--
# rank 8, conf: 0.39881616830825806
# sent 192333: |['Jin-gle Bells, Jin-gle Bells...', 'Bart! Why are you doing that?']|
#
# -- 507013 range D2 10-20, mean conf: 0.39881613850593567--
# rank 19, conf: 0.39881613850593567
# sent 194298: |['Making out the jury list for the film festival. Mayor Quimby -- Krusty -- Jay --', 'Marge, do you respect my intelligence?']|
#
# -- 507013 range D3 20-30, mean conf: 0.3987430930137634--
# rank 24, conf: 0.3988161087036133
# sent 1004238: |['Mandelbaum, Mandelbaum, Mandelbaum...', 'Fellas, fellas, look, I gotta go.']|
#
# -- 507013 range D4 30-60, mean conf: 0.39819687604904175--
# rank 57, conf: 0.39798280596733093
# sent 367899: |['Not Chandler, just Joey.', 'Sure.']|
#
# ----------SENT 640026 @32---------
# TEXT: |['Archer to Enterprise.', 'Go ahead.']|
# MEAN CONF TOP100: 0.35872185230255127
#
# -- 640026 range D0 0-1, mean conf: 0.35886403918266296--
# rank 2, conf: 0.35886403918266296
# sent 640468: |['Archer to Enterprise.', 'Go ahead.']|
#
# -- 640026 range D1 1-10, mean conf: 0.3588640093803406--
# rank 4, conf: 0.3588640093803406
# sent 640265: |['Archer to Enterprise.', 'Go ahead.']|
#
# -- 640026 range D2 10-20, mean conf: 0.3588559627532959--
# rank 17, conf: 0.3588491380214691
# sent 621216: |["Come on. Everybody knows about this. It's a legend. The curse of the TCPA. Training Centre for Protectors of Avatars, right?", "It's a legend. Suddenly, it's crystal clear."]|
#
# -- 640026 range D3 20-30, mean conf: 0.3588489890098572--
# rank 30, conf: 0.3588489890098572
# sent 615567: |['Arachnia to Proton.', "I'm reading you."]|
#
# -- 640026 range D4 30-60, mean conf: 0.3588132858276367--
# rank 56, conf: 0.35880041122436523
# sent 632398: |['Bridge to Engineering.', "Adjusting shield frequencies now, Commander. We'll have this smoothed out in just a second."]|
#
# ----------SENT 486298 @33---------
# TEXT: |['Go away, you witch.', '"Witch"? "Witch"?! Look, missy, my ass is on the line here!']|
# MEAN CONF TOP100: 0.20607268810272217
#
# -- 486298 range D0 0-1, mean conf: 0.21556010842323303--
# rank 1, conf: 0.21556010842323303
# sent 641761: |['A good engineer can see the differences. You coming to the mess hall later? My going away party?', "I don't understand the logic behind this transfer. You're not being promoted"]|
#
# -- 486298 range D1 1-10, mean conf: 0.21547731757164001--
# rank 3, conf: 0.21556009352207184
# sent 901097: |['Go away, bird.', 'Sheldon, just ignore him.']|
#
# -- 486298 range D2 10-20, mean conf: 0.21433469653129578--
# rank 14, conf: 0.21485520899295807
# sent 389800: |["Jimmy cracked corn and I don't care,Cause the master's gone away.", "It's toe-tapping-ly tragic."]|
#
# -- 486298 range D3 20-30, mean conf: 0.2117348462343216--
# rank 29, conf: 0.20968547463417053
# sent 279666: |['No go away!', 'Okay. Donovan paladin. Okay?']|
#
# -- 486298 range D4 30-60, mean conf: 0.20469792187213898--
# rank 49, conf: 0.20404545962810516
# sent 829520: |["We're done. Can't you just go away?", 'Not until you tell me why you saved me. You owe me that']|
#
# ----------SENT 374750 @34---------
# TEXT: |["Oops. Sorry. Uh, she's a little cranky. New boss coming in.", 'Enough with that.']|
# MEAN CONF TOP100: 0.14308254420757294
#
# -- 374750 range D0 0-1, mean conf: 0.14391902089118958--
# rank 2, conf: 0.14391902089118958
# sent 622314: |['Two more coming in.', 'Captain.']|
#
# -- 374750 range D1 1-10, mean conf: 0.14363400638103485--
# rank 10, conf: 0.14332827925682068
# sent 935214: |['hey guys, come in', 'hey']|
#
# -- 374750 range D2 10-20, mean conf: 0.14314620196819305--
# rank 17, conf: 0.14314410090446472
# sent 605544: |['Worf Come in.', 'What are you doing here?']|
#
# -- 374750 range D3 20-30, mean conf: 0.14306418597698212--
# rank 25, conf: 0.14306329190731049
# sent 515557: |["Don't be a wiener dog. Jake, you coming?", 'Whoo! Yeah, baby!']|
#
# -- 374750 range D4 30-60, mean conf: 0.1430222988128662--
# rank 60, conf: 0.14299052953720093
# sent 998698: |["Oh, you've come for the haircut.", 'No, actually I was just gonna...']|
#
# ----------SENT 44051 @35---------
# TEXT: |["It's stone cold. It's as if something happened out of the blue. They left suddenly. Just dropped everything and went.", "Lottery win. I'm just trying to be positive."]|
# MEAN CONF TOP100: 0.041253089904785156
#
# -- 44051 range D0 0-1, mean conf: 0.047242671251297--
# rank 1, conf: 0.047242671251297
# sent 44043: |["It's stone cold. It's as if something happened out of the blue. They left suddenly. Just dropped everything and went.", "Lottery win. I'm just trying to be positive."]|
#
# -- 44051 range D1 1-10, mean conf: 0.04586201161146164--
# rank 3, conf: 0.0467982143163681
# sent 441912: |["Gabby? You just missed her. She was in such a hurry, she didn't even come in. Just dropped this letter and zoomed away!", '"Dear Crusaders, I\'ll never forget you. You really are every bit as awesome as I\'d heard. I\'m heading home to tell all the griffons how you did the impossible by getting me my cutie mark. Toodles."']|
#
# -- 44051 range D2 10-20, mean conf: 0.04414801672101021--
# rank 21, conf: 0.04365779459476471
# sent 213215: |['The first episode was just a pilot, Dad. Producers fiddle with shows all the time. They change characters, drop others, and push some into the background.', 'Your character provides the comic relief. Like... Ohhh... Marlon Brando in "Apocalypse Now."']|
#
# -- 44051 range D3 20-30, mean conf: 0.04294246807694435--
# rank 30, conf: 0.04257887974381447
# sent 967586: |["Relax, would you? I can't just drop by?", "No. Look, Bess, I'm sorry if I seem short with you this afternoon. It's just...this place, being back."]|
#
# -- 44051 range D4 30-60, mean conf: 0.04097123444080353--
# rank 50, conf: 0.04070878028869629
# sent 924291: |["They can't drop here.", "I know. We'll get rid of them."]|
#
# ----------SENT 571359 @36---------
# TEXT: |['Shields still holding, sir.', 'Good.']|
# MEAN CONF TOP100: 0.021250871941447258
#
# -- 571359 range D0 0-1, mean conf: 0.021986570209264755--
# rank 2, conf: 0.021986570209264755
# sent 826872: |['Hold still, woman!', 'Get off me! Get it off! Ahhhh!']|
#
# -- 571359 range D1 1-10, mean conf: 0.02177378162741661--
# rank 6, conf: 0.02191350981593132
# sent 378410: |['Whoa, mama! Hold still, sexy lady.', "What's wrong?"]|
#
# -- 571359 range D2 10-20, mean conf: 0.021276269108057022--
# rank 13, conf: 0.021299714222550392
# sent 170451: |["It's nothing to worry about. Everything's still holding within operational parameters.", 'Make sure it stays that way.']|
#
# -- 571359 range D3 20-30, mean conf: 0.021222524344921112--
# rank 22, conf: 0.021236076951026917
# sent 553326: |['I am Commander Sunad of Zalkon. You are trespassing into our space and you are holding a Zalkonian citizen.', "I'm Captain Jean-Luc Picard of the United Federation of Planets. We do not intend transgression of"]|
#
# -- 571359 range D4 30-60, mean conf: 0.021198540925979614--
# rank 46, conf: 0.02120501734316349
# sent 9079: |["Yes, Doctor, I'm holding on.", 'Come over here and hold on to this, then.']|
#
# ----------SENT 93728 @37---------
# TEXT: |["I don't need looking after. I can fend for myself.", "Ah. Well, in that case, you won't be wanting any of this, then."]|
# MEAN CONF TOP100: 0.01902173087000847
#
# -- 93728 range D0 0-1, mean conf: 0.027094801887869835--
# rank 1, conf: 0.027094801887869835
# sent 677468: |['I can fend for myself.', "But you're not just fending for yourself. You're fending for two. And let's be honest - right now, you waddle."]|
#
# -- 93728 range D1 1-10, mean conf: 0.02048664540052414--
# rank 9, conf: 0.020081276074051857
# sent 656320: |['Speak for yourself.', "I wasn't."]|
#
# -- 93728 range D2 10-20, mean conf: 0.019927997142076492--
# rank 21, conf: 0.019836487248539925
# sent 196282: |['Hey, speak for yourself.', "Marge, kids, let's go buy some happiness!"]|
#
# -- 93728 range D3 20-30, mean conf: 0.019587960094213486--
# rank 22, conf: 0.019819624722003937
# sent 954244: |['yeah thanks um...enjoy yourselves', 'oh, looks like everyone�s a little nervous']|
#
# -- 93728 range D4 30-60, mean conf: 0.018938571214675903--
# rank 46, conf: 0.018798422068357468
# sent 201807: |['You wasted our money on something extravagant for yourself!', "There's a trickle-down theory here. If I'm happy, I'm less abusive to the rest of you."]|
#
# ----------SENT 296304 @38---------
# TEXT: |['Yes to relieve pressure.', 'these are accurate.']|
# MEAN CONF TOP100: 0.004408600274473429
#
# -- 296304 range D0 0-1, mean conf: 0.0066453395411372185--
# rank 2, conf: 0.0066453395411372185
# sent 321908: |['"A soothing brew to relieve tension."', '"Ah. Kind of looks like muddy water."']|
#
# -- 296304 range D1 1-10, mean conf: 0.004765523597598076--
# rank 11, conf: 0.00458341371268034
# sent 277992: |["I'm sure you did everything you could, Sir, but it appears he had a massive cerebral hemorrhage.", 'Oh.']|
#
# -- 296304 range D2 10-20, mean conf: 0.004529914818704128--
# rank 14, conf: 0.004554136656224728
# sent 658267: |["They're trying to decipher the Methus diagram from the crystal. I have to help them while", 'No, he wants you to rest while you still can.']|
#
# -- 296304 range D3 20-30, mean conf: 0.004457239061594009--
# rank 26, conf: 0.004460702650249004
# sent 514804: |['Jake, wait. We have to help them.', "They're partying! They're fine."]|
#
# -- 296304 range D4 30-60, mean conf: 0.004365153610706329--
# rank 35, conf: 0.004404629115015268
# sent 499583: |['No, I don’t. I have to help you.', 'But you’re a hero – you can’t run. You have to help everybody.']|
#
# ----------SENT 988702 @39---------
# TEXT: |['Hi, sweetheart.', "God, it's good to see you."]|
# MEAN CONF TOP100: 1.7174677478803968e-12
#
# -- 988702 range D0 0-1, mean conf: 2.339126505337963e-12--
# rank 1, conf: 2.339126505337963e-12
# sent 138527: |['Hi, sweetheart.', "She's having some breakfast. She just got up. Come on in."]|
#
# -- 988702 range D1 1-10, mean conf: 2.09263682771077e-12--
# rank 10, conf: 1.7793486952952242e-12
# sent 474050: |['Oh. Hi, baby.', "Hi. What's going on?"]|
#
# -- 988702 range D2 10-20, mean conf: 1.7781172584677152e-12--
# rank 14, conf: 1.7793470689919655e-12
# sent 489879: |['Hi, baby.', "Well, how's Chris Keller's lady doing? Mmm."]|
#
# -- 988702 range D3 20-30, mean conf: 1.7353500364122865e-12--
# rank 22, conf: 1.76772799957009e-12
# sent 628765: |['However, if an explosion occurs while both ships are inside the field, neither vessel will survive.', 'We can do it, Captain.']|
#
# -- 988702 range D4 30-60, mean conf: 1.6768281641682536e-12--
# rank 34, conf: 1.694867770435371e-12
# sent 908569: |['The dungeon master’s supposed to roll.', 'Yeah, well I’m supposed to be in Vegas throwing up on a shrimp buffet. Now give it. All right, what do I need?']|

# %% [markdown]
# ## Variation V5: Keep and only keep all tokens.
#
# Similar to V4 except for POS.
#
# Full manifest:
#
# For DEP (syntactic dependency): NO DEP.
#
# For POS (senmatic token).
#
# Conclusion: Reject

# %%
data_v5 = data.loc[data.head_info=='POS']
data_v5
# Out:
#           sent_id                             show_id            char_name  \
# 0         1063785                         QueerAsFolk              MICHAEL
# 4          508646                       OnceUponATime           CINDERELLA
# 7           19636                           DoctorWho      ELEVENTH DOCTOR
# 11         504657                       OnceUponATime        MARY MARGARET
# 12         672740                               Alias                 JACK
# 13         144292                        VeronicaMars             VERONICA
# 14         537460                            StarTrek              JANEWAY
# 15         923983                       SonsOfAnarchy                  JAX
# 21         238693                         TheSimpsons  C. Montgomery Burns
# 22         606411                            StarTrek                 WORF
# 24         751240                        GilmoreGirls              RICHARD
# 26         518382                       AdventureTime   Princess Bubblegum
# 28         130438                                NCIS                 KATE
# 29         437089       MyLittlePonyFriendshipIsMagic                Spike
# 33         866034                   HowIMetYourMother                ROBIN
# 34        1055655                         Charmed1998                 COLE
# 35        1000771                            Seinfeld                JERRY
# 41         582768                            StarTrek               ARCHER
# 45         189666                         TheSimpsons        Homer Simpson
# 46         608478                            StarTrek                SPOCK
# 47         137218  TheSecretLifeOfTheAmericanTeenager                  AMY
# 54         495646                       OnceUponATime               REGINA
# 56         813633                         TheOfficeUS                 ANDY
# 58         460395                         OneTreeHill                LUCAS
# 59         357634                             Friends               MONICA
# 60           1463                           DoctorWho        FOURTH DOCTOR
# 64         309155                               Bones               ANGELA
# 68         529936                        GreysAnatomy               GEORGE
# 69          81062                           DoctorWho                CLARA
# 71         312182                               Bones                  CAM
# ...           ...                                 ...                  ...
# 17160322   712716                        GilmoreGirls                 RORY
# 17160323   859388                   HowIMetYourMother               BARNEY
# 17160327   649350                            StarTrek               NEELIX
# 17160329   688919                        GilmoreGirls              LORELAI
# 17160332   218173                         TheSimpsons        Marge Simpson
# 17160334   180556                          Smallville               MARTHA
# 17160339   510565                       AdventureTime                 Finn
# 17160340    91047                          Merlin2008               ARTHUR
# 17160341   464413                         OneTreeHill               NATHAN
# 17160342   676588                               Alias                DIXON
# 17160343   603811                            StarTrek                 WORF
# 17160344   749073                        GilmoreGirls               SOOKIE
# 17160347   656813                            StarTrek               TRANCE
# 17160351   274814                        Supernatural                  SAM
# 17160354   192729                         TheSimpsons        Homer Simpson
# 17160355   329079                             Friends                 ROSS
# 17160356   509057                       AdventureTime                 Finn
# 17160357   465269                         OneTreeHill               NATHAN
# 17160359    25432                           DoctorWho        SECOND DOCTOR
# 17160362   793175                         TheOfficeUS              MICHAEL
# 17160364   610713                            StarTrek                SPOCK
# 17160365   723387                        GilmoreGirls                 RORY
# 17160366   125325                                NCIS                 ABBY
# 17160367   732232                        GilmoreGirls                 LUKE
# 17160369   967551                        DawsonsCreek                 JOEY
# 17160372   387420                            Futurama                Leela
# 17160373   537886                            StarTrek              JANEWAY
# 17160374   182960                          Smallville                JIMMY
# 17160375   568148                            StarTrek                 HUNT
# 17160376   652290                            StarTrek                MCCOY
#
#          char_id head_info head_pos      token  token_par  position  is_stop  \
# 0         l22346       POS      VBZ         be         be         2     True
# 4         l19407       POS       JJ     entire     entire        77    False
# 7          l8661       POS        .          .          .        66    False
# 11        l19393       POS     PRP$        her        her        45     True
# 12         l1275       POS       UH         um         um         9    False
# 13        l30591       POS      VBZ         do         do         0     True
# 14        l25466       POS       NN  deflector  deflector        61    False
# 15        l24810       POS      VBZ         be         be        26     True
# 21        a15869       POS       NN      blood      blood        63    False
# 22        l25435       POS        ,          ,          ,        72    False
# 24        l11615       POS       JJ      ready      ready        19    False
# 26         a3409       POS       IN         on         on        20     True
# 28        l18800       POS       UH         no         no         0     True
# 29        a13105       POS      PRP          i          i        20     True
# 33        l13772       POS       NN       info       info        63    False
# 34         l6502       POS        ,          ,          ,        12    False
# 35        l23593       POS      PRP        you        you         5     True
# 41        l25486       POS      WDT       that       that        54     True
# 45        a15835       POS      NNP     PERSON     PERSON         5    False
# 46        l25411       POS       VB        get        get        30     True
# 47        l23561       POS       CC        and        and        16     True
# 54        l19395       POS       RB       else       else        53     True
# 56        l19350       POS       UH        doo        doo        72    False
# 58        l19593       POS       NN        mom        mom        27    False
# 59        l10692       POS      VBG       play       play       110    False
# 60         l8653       POS       DT         an         an        64     True
# 64         l5149       POS      NNP        ORG        ORG        43    False
# 68        l12266       POS        ,          ,          ,         2    False
# 69         l8711       POS      VBZ         go         go        17    False
# 71         l5150       POS       DT       that       that        59     True
# ...          ...       ...      ...        ...        ...       ...      ...
# 17160322  l11613       POS      VBZ       have       have        80     True
# 17160323  l13774       POS      NNP     PERSON     PERSON        20    False
# 17160327  l25473       POS      NNS        day        day        24    False
# 17160329  l11612       POS      NNP    General    General         0    False
# 17160332  a15821       POS        .          ?          ?        57    False
# 17160334  l24613       POS        .          ?          ?        13    False
# 17160339   a3415       POS       RB        now        now         0     True
# 17160340  l17712       POS       WP       what       what         0     True
# 17160341  l19594       POS       VB        try        try        48    False
# 17160342   l1277       POS      VBZ         be         be        28     True
# 17160343  l25435       POS       CD   CARDINAL   CARDINAL        61     True
# 17160344  l11619       POS       NN     budget     budget        20    False
# 17160347   l1896       POS      PRP         it         it        74     True
# 17160351  l25967       POS        .          .          .        16    False
# 17160354  a15835       POS      PRP         me         me        76     True
# 17160355  l10696       POS       VB       wait       wait       110    False
# 17160356   a3415       POS        .          ?          ?        34    False
# 17160357  l19594       POS      PRP        you        you         7     True
# 17160359   l8651       POS       NN     report     report        62    False
# 17160362  l19352       POS      NNP        GPE        GPE        72    False
# 17160364  l25411       POS       MD       will       will       113     True
# 17160365  l11613       POS      VBD         be         be         8     True
# 17160366  l18806       POS      NNP        ORG        ORG       114    False
# 17160367  l11617       POS        .          .          .       162    False
# 17160369   l7947       POS       TO         to         to       261     True
# 17160372   a8871       POS        .          .          .        86    False
# 17160373  l25466       POS       NN      price      price       109    False
# 17160374  l24654       POS       RB       sort       sort        79    False
# 17160375   l1890       POS        .          .          .        32    False
# 17160376  l25412       POS      NNP        FAC        FAC        66    False
#
#                        head_text
# 0                      VBZ|be|be
# 4               JJ|entire|entire
# 7                          .|.|.
# 11                  PRP$|her|her
# 12                      UH|um|um
# 13                     VBZ|do|do
# 14        NN|deflector|deflector
# 15                     VBZ|be|be
# 21                NN|blood|blood
# 22                         ,|,|,
# 24                JJ|ready|ready
# 26                      IN|on|on
# 28                      UH|no|no
# 29                       PRP|i|i
# 33                  NN|info|info
# 34                         ,|,|,
# 35                   PRP|you|you
# 41                 WDT|that|that
# 45             NNP|PERSON|PERSON
# 46                    VB|get|get
# 47                    CC|and|and
# 54                  RB|else|else
# 56                    UH|doo|doo
# 58                    NN|mom|mom
# 59                 VBG|play|play
# 60                      DT|an|an
# 64                   NNP|ORG|ORG
# 68                         ,|,|,
# 69                     VBZ|go|go
# 71                  DT|that|that
# ...                          ...
# 17160322           VBZ|have|have
# 17160323       NNP|PERSON|PERSON
# 17160327             NNS|day|day
# 17160329     NNP|General|General
# 17160332                   .|?|?
# 17160334                   .|?|?
# 17160339              RB|now|now
# 17160340            WP|what|what
# 17160341              VB|try|try
# 17160342               VBZ|be|be
# 17160343    CD|CARDINAL|CARDINAL
# 17160344        NN|budget|budget
# 17160347               PRP|it|it
# 17160351                   .|.|.
# 17160354               PRP|me|me
# 17160355            VB|wait|wait
# 17160356                   .|?|?
# 17160357             PRP|you|you
# 17160359        NN|report|report
# 17160362             NNP|GPE|GPE
# 17160364            MD|will|will
# 17160365               VBD|be|be
# 17160366             NNP|ORG|ORG
# 17160367                   .|.|.
# 17160369                TO|to|to
# 17160372                   .|.|.
# 17160373          NN|price|price
# 17160374            RB|sort|sort
# 17160375                   .|.|.
# 17160376             NNP|FAC|FAC
#
# [8490214 rows x 11 columns]

# %%
model_v5, SENT_CATS_v5, FEATURE_CATS_v5 = get_train(data_v5, report_test_acc=False)
SENT_MAP_v5, INV_SENT_MAP_v5 = build_maps(data_v5)
# Out:
# <26004x929612 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8490214 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [05:23<00:00,  1.81s/it]
# 929612 929612

# %%
mi = ModelInspection(model_v5, SENT_MAP_v5, INV_SENT_MAP_v5, dialog_df=dialogs)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 43012 @0---------
# TEXT: |['You are welcome, welcome indeed. Though we know you only as a record in our charts of space and time, yet you seem to us like an old friend.', "Well, that's very kind of you to make me feel so welcome."]|
# MEAN CONF TOP100: 2.520731210708618
#
# -- 43012 range D0 0-1, mean conf: 2.6744749546051025--
# rank 2, conf: 2.6744749546051025
# sent 633894: |['I predict that when these findings are made public, they will become a new model for warp field operation.', 'Sounds interesting.']|
#
# -- 43012 range D1 1-10, mean conf: 2.6253905296325684--
# rank 5, conf: 2.631696939468384
# sent 769941: |["Taylor, everyone, there will be millions of questions, some of them even legitimate, but the bottom line is, you know me. I've been apart of this town for. . .well, look how big my daughter is - for that long. And opening this inn has been a dream of mine and of Sookie's for most of that time. Along with Michel, we plan to make this community as proud of the historic Dragonfly Inn as you were when the same team was running the Independence Inn.", 'You mean the place that burned down on your watch?']|
#
# -- 43012 range D2 10-20, mean conf: 2.570065975189209--
# rank 21, conf: 2.554349422454834
# sent 597481: |['I must point out that if you take the liberty of changing a time-honoured recipe you are hardly presenting a taste of home.', 'Senior officers please report to the bridge.']|
#
# -- 43012 range D3 20-30, mean conf: 2.5420053005218506--
# rank 31, conf: 2.533785581588745
# sent 637383: |['Two words exactly. We collided in the corridor during a Borg attack. I said, excuse me. Since we were at Red alert and about to be destroyed, I think it was very considerate of me.', "Well, Mister Considerate, why don't you go over there right now and offer him some encouragement. His first away mission, I'm sure he could use it."]|
#
# -- 43012 range D4 30-60, mean conf: 2.5094316005706787--
# rank 37, conf: 2.524320363998413
# sent 44029: |["It's our history project for the weekend. On Monday, Clyde and I have to demonstrate the different battle strategies of Bonaparte and Wellington at Waterloo.", "I wanted to do the Battle of Hoth, But Mrs Pittman reckons that Star Wars isn't historically accurate, or something like that."]|
#
# ----------SENT 589603 @1---------
# TEXT: |["My superintendent was a Betazoid, a full telepath. When he sent for you to his office, he didn't have to ask what you'd done.", "You got called into the superintendent's office? That's a story I'd like to hear."]|
# MEAN CONF TOP100: 2.203319787979126
#
# -- 589603 range D0 0-1, mean conf: 2.315885543823242--
# rank 2, conf: 2.315885543823242
# sent 1016630: |["He didn't come within two feet of the thing. He's wavin at it... So, I told him if he picks us up at the airport, he wouldn't have to pay me anything.", "Hey, how we doin' on time?"]|
#
# -- 589603 range D1 1-10, mean conf: 2.272660970687866--
# rank 6, conf: 2.2715859413146973
# sent 675540: |['Edward Poole was a friend, a visitor to this office, a former operative with MI-6. Recently, I was shocked to learn he has become an ally of Khasinau. So, I asked Marshall to examine his scanning room profile to see if he can come up with any leads. Marshall?', 'Thanks. Now, this is really good.']|
#
# -- 589603 range D2 10-20, mean conf: 2.2483644485473633--
# rank 13, conf: 2.2558135986328125
# sent 159546: |["Well, don't look to me for encouragement. After what he did to my mom, I don't mind the idea of him cohabitating with the rats for all of eternity.", "Trust me, Chloe. Lately I've had moments where I thought the world would be a better place without him, but ..."]|
#
# -- 589603 range D3 20-30, mean conf: 2.2268309593200684--
# rank 26, conf: 2.229041814804077
# sent 120054: |["If Galib had intel on Abu's plans, did he have time to tell Gibbs?", 'Maybe. They were together when the bomb went off.']|
#
# -- 589603 range D4 30-60, mean conf: 2.1971371173858643--
# rank 36, conf: 2.210467576980591
# sent 1062161: |["Darren refused to identify his attackers. They're gonna get off. When I told him to be brave, stand up for himself, he said to me, what did you do? I was a coward. I should have done something and I didn't.", "Well, you wanna get even? I'll tell you how to get even Become the biggest f*cking success you can possibly be."]|
#
# ----------SENT 364188 @2---------
# TEXT: |['How-how I like to melt stuff, and how I dislike stuff that doesn’t melt.', 'Right, okay, um-mm.']|
# MEAN CONF TOP100: 2.198901653289795
#
# -- 364188 range D0 0-1, mean conf: 2.3695034980773926--
# rank 2, conf: 2.3695034980773926
# sent 353708: |['Anyway, I picked up this outfit that I want to wear and the, and the boots don’t really go with it.', 'You said that you paid all that money because those boots go with skirts, dresses, and pants!']|
#
# -- 364188 range D1 1-10, mean conf: 2.280310869216919--
# rank 7, conf: 2.277247190475464
# sent 718959: |["With everything that's going on, finals and all your personal stuff, I didn't want you worrying.", "But Grandpa's money -"]|
#
# -- 364188 range D2 10-20, mean conf: 2.240819215774536--
# rank 19, conf: 2.2316033840179443
# sent 952359: |['you know Marissa, honey its not to late to change your mind, fresh air all the baked clams you can eat', 'yeah that sounds...tempting but, I think I just need to be alone']|
#
# -- 364188 range D3 20-30, mean conf: 2.214855670928955--
# rank 22, conf: 2.221912384033203
# sent 835093: |["I just don't get it, your thing with them", "I know it doesn't make sense. But at the beginning, after my parents died, there was something about being with Stefan that just... Felt safe"]|
#
# -- 364188 range D4 30-60, mean conf: 2.1911542415618896--
# rank 32, conf: 2.2076809406280518
# sent 356526: |["Don't, I like it dirty.", "That's your call."]|
#
# ----------SENT 865307 @3---------
# TEXT: |["No, this is new. This trumps that. Freeways have exits. So do relationships. The first exit, my personal favorite, is six hours in. You meet, you talk, you have s*x, you exit when she's in the shower.", 'So every girl you have s*x with feels the immediate need to shower? Actually, yeah, I get that.']|
# MEAN CONF TOP100: 1.9501712322235107
#
# -- 865307 range D0 0-1, mean conf: 2.048065423965454--
# rank 2, conf: 2.048065423965454
# sent 391232: |['Ah, Hermes! Crew, meet Hermes Conrad. He manages my delivery business, pays the bills, notifies next of kin, what have you.', 'Someone come and dropped this package through the slot last night. Now which one of you is the captain?']|
#
# -- 865307 range D1 1-10, mean conf: 2.0175397396087646--
# rank 5, conf: 2.0307443141937256
# sent 146153: |["That's my little brother Rodney. He's had a birthday, hence the thank you cards.", 'Hey, Rodney.']|
#
# -- 865307 range D2 10-20, mean conf: 1.9884065389633179--
# rank 13, conf: 1.9974172115325928
# sent 525923: |["I don't doubt that but you have a wife to go home to and I'm guessing she has no idea where you are right now.", "No, she doesn't."]|
#
# -- 865307 range D3 20-30, mean conf: 1.9697694778442383--
# rank 31, conf: 1.968265175819397
# sent 997011: |["Aver Martone. I've heard of her, who's she playing?", "She's playing, Pagliacci?s wife, Nedda."]|
#
# -- 865307 range D4 30-60, mean conf: 1.949072241783142--
# rank 51, conf: 1.9451717138290405
# sent 496228: |['So, you’re gonna tell me what’s in that letter you’ve been starring at?', 'What letter?']|
#
# ----------SENT 291092 @4---------
# TEXT: |["Agent Booth? I'm, uh, Jimmy Walpert. I'm sorry that I wasn't here, but I-I got a bit sick.", "Well, that's no surprise there."]|
# MEAN CONF TOP100: 1.9465420246124268
#
# -- 291092 range D0 0-1, mean conf: 2.0988924503326416--
# rank 2, conf: 2.0988924503326416
# sent 333725: |["Uh, actually, we're getting a cat.", 'Together?']|
#
# -- 291092 range D1 1-10, mean conf: 2.035443067550659--
# rank 9, conf: 2.030517578125
# sent 144026: |["I'm sorry, w-was that too dirty, 'cause", 'Not to me dork. To him']|
#
# -- 291092 range D2 10-20, mean conf: 2.001401662826538--
# rank 15, conf: 2.0122008323669434
# sent 166298: |["No problem. You know, it's one week until we rendezvous at the altar, and we're, uh, still getting RSVPs.", 'I bet you anything these slow responders have never had to tackle the challenge of a seating chart.']|
#
# -- 291092 range D3 20-30, mean conf: 1.968947172164917--
# rank 27, conf: 1.9691864252090454
# sent 533723: |['I was just, actually -', 'I did. Could you excuse us for a second?']|
#
# -- 291092 range D4 30-60, mean conf: 1.9395241737365723--
# rank 36, conf: 1.9469622373580933
# sent 278712: |["Uh, I'm not a sociopath.", "You're bad with people, okay. No use being offended by the fact."]|
#
# ----------SENT 493880 @5---------
# TEXT: |["I'm sorry, Mom. Whatever happened in Camelot, I'm sorry we failed you.", "I know what I said last night, but, Henry, you didn't fail me. Everyone else did."]|
# MEAN CONF TOP100: 1.940148115158081
#
# -- 493880 range D0 0-1, mean conf: 2.0686557292938232--
# rank 2, conf: 2.0686557292938232
# sent 343052: |["Listen, I'm really really sorry about what happened today in the cafeteria.", "It's no big deal you know. You do what you gotta do, right?"]|
#
# -- 493880 range D1 1-10, mean conf: 2.0239617824554443--
# rank 11, conf: 1.9977728128433228
# sent 295739: |['You know, we talked about you in therapy.', 'You did?']|
#
# -- 493880 range D2 10-20, mean conf: 1.9767529964447021--
# rank 17, conf: 1.9718494415283203
# sent 400439: |["I'm thinking Lori packed the diamonds.", 'After she fed the horse, evidently.']|
#
# -- 493880 range D3 20-30, mean conf: 1.9517920017242432--
# rank 28, conf: 1.9517155885696411
# sent 306652: |['No. No, I mean about- about staying in the States.', "Mind? Angie, I only love Paris because you love Paris, but... catching bad guys, that's what I'm made for. You're not... doing this for me?"]|
#
# -- 493880 range D4 30-60, mean conf: 1.9323533773422241--
# rank 58, conf: 1.924842357635498
# sent 294164: |['You accept that plea bargain, the investigation stops.', 'Indict him. Give us time to give you what we need.']|
#
# ----------SENT 578338 @6---------
# TEXT: |["You humans obviously have emotions. I find it curious that you'd select a Vulcan as your science officer.", "Believe me, she wasn't my first choice."]|
# MEAN CONF TOP100: 1.8881442546844482
#
# -- 578338 range D0 0-1, mean conf: 2.051804542541504--
# rank 2, conf: 2.051804542541504
# sent 27148: |["I am not sure what to make of you, Doctor. I think perhaps it\nwould be safer to accept Ortron's theory and execute you as a spy.", "You can't do that. We're not under your authority."]|
#
# -- 578338 range D1 1-10, mean conf: 1.95656156539917--
# rank 4, conf: 1.9701685905456543
# sent 585116: |["Ship's log, Commander William Riker reporting. Continuing our appraisal of Ligonian technology. The Captain has made it clear he wants Lieutenant Yar beamed immediately to safety if her life should become endangered, and I fervently hope the rules of that contest make it possible.", 'Riker to Transporter Chief. Do we have our people on sensors yet?']|
#
# -- 578338 range D2 10-20, mean conf: 1.912696123123169--
# rank 19, conf: 1.908601999282837
# sent 197324: |['These melons represent your pro-tectees. Throughout this course, you will pro-tect your personal melon as if it was paying your salary.', 'Wha?']|
#
# -- 578338 range D3 20-30, mean conf: 1.9033243656158447--
# rank 31, conf: 1.899223804473877
# sent 615173: |["And you think it'll be able to withstand the gas giant's atmosphere.", 'The probe did.']|
#
# -- 578338 range D4 30-60, mean conf: 1.884605050086975--
# rank 37, conf: 1.8925089836120605
# sent 457436: |["And I'd be happy to end your suspension, as long as you agree to print an apology for your actions in the next edition of the school paper. I've prepared it for you. I'll also be taking over the paper's publishing responsibilities going forward. In addition, you'll address your literature class and explain that you were wrong and that you showed a serious error in judgment.", "And if I don't?"]|
#
# ----------SENT 928397 @7---------
# TEXT: |["You know, I'm with you on Marks, Jax. But I don't know how much longer I'm gonna be able to keep playing double agent.", 'Niners are the only ones that can get us close to Marks so we can get Bobby back.']|
# MEAN CONF TOP100: 1.8573204278945923
#
# -- 928397 range D0 0-1, mean conf: 2.229616403579712--
# rank 2, conf: 2.229616403579712
# sent 924606: |["For every 24 hours August has to wait, he's gonna cut off another part of your guy. I mean, I'm with you, but I don't know how much longer I'm gonna be able to keep playing double agent.", 'Jesus.']|
#
# -- 928397 range D1 1-10, mean conf: 1.9486310482025146--
# rank 6, conf: 1.938782811164856
# sent 260791: |["I'm going as fast as I can.", "Good, 'cause you know I got a dislocated shoulder over here."]|
#
# -- 928397 range D2 10-20, mean conf: 1.9026914834976196--
# rank 17, conf: 1.900537371635437
# sent 208473: |["I know, Homie. I know you well enough to know you're not ready to forgive me yet. But I also know you well enough to know that this will work.", "Where'd you get that dress?"]|
#
# -- 928397 range D3 20-30, mean conf: 1.8806079626083374--
# rank 26, conf: 1.8814209699630737
# sent 102697: |["But not as much as I'm going to ask.", "What? What's that supposed to mean?"]|
#
# -- 928397 range D4 30-60, mean conf: 1.8481462001800537--
# rank 46, conf: 1.8460073471069336
# sent 346798: |["I'm sorry buddy, but I don't think I'm gonna be able to make it.", 'We were gonna go see the Jets!']|
#
# ----------SENT 633043 @8---------
# TEXT: |['Geordi, active scanner output has increased by twenty six percent.', 'Inform Astrophysics that the new La Forge sensor array is online and awaiting major scientific discoveries.']|
# MEAN CONF TOP100: 1.7486257553100586
#
# -- 633043 range D0 0-1, mean conf: 1.9619110822677612--
# rank 2, conf: 1.9619110822677612
# sent 659839: |["The vessel's mass has increased by three percent.", "They've improved their defences since we last saw them."]|
#
# -- 633043 range D1 1-10, mean conf: 1.908642053604126--
# rank 3, conf: 1.9462811946868896
# sent 654619: |['Makrai fever has a ninety five percent mortality rate.', 'Which translates into thirty one million dead on Rodina.']|
#
# -- 633043 range D2 10-20, mean conf: 1.8286317586898804--
# rank 19, conf: 1.8150469064712524
# sent 555560: |['The wave has closed to one kilometre, Captain.', 'Picard to Commander Riker. Bridge to Lieutenant Worf, acknowledge.']|
#
# -- 633043 range D3 20-30, mean conf: 1.7796014547348022--
# rank 26, conf: 1.7782258987426758
# sent 566031: |["Hmm. Beka's brain seems to be one hundred percent healthy, physically.", "Looks like we're at a dead end."]|
#
# -- 633043 range D4 30-60, mean conf: 1.7306787967681885--
# rank 36, conf: 1.7470406293869019
# sent 577629: |['Helm, close to within transporter range.', 'And second, ...turn that damned thing off.']|
#
# ----------SENT 54159 @9---------
# TEXT: |['Sarah Jane, you may be interested to know that the Museum of Culture is currently staging an exhibition of totem poles. Among them is what has become known as the Totem of the Lost Tribe.', 'Oh, my dad wants to see that. Said they found in a cave, like it had been hidden.']|
# MEAN CONF TOP100: 1.7355011701583862
#
# -- 54159 range D0 0-1, mean conf: 2.124026298522949--
# rank 1, conf: 2.124026298522949
# sent 54162: |['Sarah Jane, you may be interested to know that the Museum of Culture is currently staging an exhibition of totem poles. Among them is what has become known as the Totem of the Lost Tribe.', 'Oh, my dad wants to see that. Said they found in a cave, like it had been hidden.']|
#
# -- 54159 range D1 1-10, mean conf: 1.8820852041244507--
# rank 3, conf: 2.124026298522949
# sent 54156: |['Sarah Jane, you may be interested to know that the Museum of Culture is currently staging an exhibition of totem poles. Among them is what has become known as the Totem of the Lost Tribe.', 'Oh, my dad wants to see that. Said they found in a cave, like it had been hidden.']|
#
# -- 54159 range D2 10-20, mean conf: 1.7697988748550415--
# rank 15, conf: 1.7743844985961914
# sent 5611: |['It has the powers of transmutation, transformation and the establishing of hyperspatial and temporal coordinates.', 'Ha. Exactly as I thought.']|
#
# -- 54159 range D3 20-30, mean conf: 1.7491216659545898--
# rank 25, conf: 1.749725580215454
# sent 576638: |["No, unless they have scanners. See, there. It's like a cloud of some kind. It's been between us and the planet since you vanished.", 'If Lucien put it there']|
#
# -- 54159 range D4 30-60, mean conf: 1.7195180654525757--
# rank 52, conf: 1.7168277502059937
# sent 588223: |['Then it appears, for reasons unknown, someone has gone to great pains to erase all traces of this man.', 'Who was on transporter duty when he came aboard?']|
#
# ----------SENT 556622 @10---------
# TEXT: |["You're going to have to destroy it in order to escape.", 'How much longer before we reach them?']|
# MEAN CONF TOP100: 1.729442834854126
#
# -- 556622 range D0 0-1, mean conf: 1.8800475597381592--
# rank 2, conf: 1.8800475597381592
# sent 798598: |["I'm in it to win.", 'Game on!']|
#
# -- 556622 range D1 1-10, mean conf: 1.8149983882904053--
# rank 4, conf: 1.8714337348937988
# sent 156934: |["There's gonna be millions of eyes on you. You're gonna be under a magnifying glass.", 'I have pulled it off before.']|
#
# -- 556622 range D2 10-20, mean conf: 1.7572036981582642--
# rank 13, conf: 1.7624942064285278
# sent 77593: |['And I was going to paddle in it.', "It's all right, Susan. It's all right. Look, you've got some more shoes back at the ship, haven't you? Well, go and put them on. We'll wait here for you."]|
#
# -- 556622 range D3 20-30, mean conf: 1.7428184747695923--
# rank 24, conf: 1.7465646266937256
# sent 772895: |["We're gonna have to rewrite that.", 'What?']|
#
# -- 556622 range D4 30-60, mean conf: 1.7251299619674683--
# rank 38, conf: 1.7335351705551147
# sent 833505: |['You have to feed in order to complete the transition.', 'I know that.']|
#
# ----------SENT 585182 @11---------
# TEXT: |['A most interesting conclusion. But what if they will never learn, Riker?', 'Is this a test also?']|
# MEAN CONF TOP100: 1.6990987062454224
#
# -- 585182 range D0 0-1, mean conf: 1.8329066038131714--
# rank 2, conf: 1.8329066038131714
# sent 863362: |['What will Lily say when you learn that you smoked?', 'Lily did not discover. I have a system.']|
#
# -- 585182 range D1 1-10, mean conf: 1.7599446773529053--
# rank 3, conf: 1.7920646667480469
# sent 873003: |['This is all so weird. I mean, how are we supposed to act when we see him?', "Well, it's gotta be weird for him, too. Now that we know so much."]|
#
# -- 585182 range D2 10-20, mean conf: 1.7300045490264893--
# rank 15, conf: 1.7300127744674683
# sent 353860: |['Rach, you know that birthing tape you wanted to see? It’s here.', 'Oh, and we should warn you, before you watch it: don’t watch it.']|
#
# -- 585182 range D3 20-30, mean conf: 1.7157318592071533--
# rank 31, conf: 1.7122982740402222
# sent 651172: |['If we say yes, will you feed us?', 'One of those species is the Benkarans. They occupy just ten percent of Nygean space, but take up nearly eighty percent of the space in Nygean prisons.']|
#
# -- 585182 range D4 30-60, mean conf: 1.6973801851272583--
# rank 39, conf: 1.7038284540176392
# sent 41340: |['Well, how will we know when we have? Arrived, I mean.', 'The cases will disappear and we shall all become visible.']|
#
# ----------SENT 723047 @12---------
# TEXT: |['Wow. A room full of guys and still extremely slim pickings.', "Well, I don't know. It's a tough choice, maybe I should let my boyfriend help me choose."]|
# MEAN CONF TOP100: 1.6926723718643188
#
# -- 723047 range D0 0-1, mean conf: 1.8021422624588013--
# rank 2, conf: 1.8021422624588013
# sent 79776: |["Gadget. Health and safety. Classified, I'm afraid. You know, while the back room boffins work out a few kinks.", "What's it telling you?"]|
#
# -- 723047 range D1 1-10, mean conf: 1.7533011436462402--
# rank 9, conf: 1.7454209327697754
# sent 74717: |["It's Sunday. Some of the gang always comes up here on a Sunday.", 'What for?']|
#
# -- 723047 range D2 10-20, mean conf: 1.7234935760498047--
# rank 16, conf: 1.721673607826233
# sent 326081: |['Word on the street - well, when I say street, I mean those little pretend streets they have here at the zoo.', 'Of course.']|
#
# -- 723047 range D3 20-30, mean conf: 1.712174415588379--
# rank 28, conf: 1.7102789878845215
# sent 630883: |["Captain's log, supplemental. We remain in orbit around Theta Eight, still out of contact with the away team.", "We're almost there, Captain. We'll be able to attempt contact in a few minutes."]|
#
# -- 723047 range D4 30-60, mean conf: 1.6904022693634033--
# rank 46, conf: 1.691402792930603
# sent 715695: |["Ah! That's it, I'm standing up in the middle of your speech and demanding a recount.", 'Shall we seat you?']|
#
# ----------SENT 408486 @13---------
# TEXT: |['Maybe this has nothing to do with the case. Maybe it was just a piece of debris left at the scene.', "No, no. I-I'm not quitting. No. I am in too deep."]|
# MEAN CONF TOP100: 1.6842645406723022
#
# -- 408486 range D0 0-1, mean conf: 1.8537670373916626--
# rank 2, conf: 1.8537670373916626
# sent 595732: |['Maybe it was just a malfunction in the transporter.', 'Then I saw you working the PADD with your left hand. Commander La Forge is right handed, sir. A similar malfunction occurred in the Sherlock Holmes programme I was running before Moriarty first appeared.']|
#
# -- 408486 range D1 1-10, mean conf: 1.7621310949325562--
# rank 11, conf: 1.7350690364837646
# sent 769132: |['Maybe it was the parasite.', 'What do you mean?']|
#
# -- 408486 range D2 10-20, mean conf: 1.7165855169296265--
# rank 17, conf: 1.7116916179656982
# sent 59855: |['The tunnels probably run for hundreds of miles.', "Well, if they do, we'll never get ourselves out."]|
#
# -- 408486 range D3 20-30, mean conf: 1.6990044116973877--
# rank 26, conf: 1.7000298500061035
# sent 315370: |["It's from a long bone. Probably the deltoid process of a humerus.", 'Arm bone?']|
#
# -- 408486 range D4 30-60, mean conf: 1.6788954734802246--
# rank 42, conf: 1.6823835372924805
# sent 165576: |["Lois' imagination has finally kicked into overdrive. It was probably just some sort of styrofoam prop for a school play.", 'Right. That makes sense, actually.']|
#
# ----------SENT 245501 @14---------
# TEXT: |['When are Mom and Dad coming back?', 'Bored, are ya? Lisa, go cut me a switch.']|
# MEAN CONF TOP100: 1.680127739906311
#
# -- 245501 range D0 0-1, mean conf: 1.8035939931869507--
# rank 2, conf: 1.8035939931869507
# sent 358021: |['Ohh, gosh. You guys, come on, this is—I have to meet Joshua! This is my one chance for him to see the fun Rachel. Y’know the "Wouldn’t it be great if she was my wife" Rachel. Ohh, all right! Are Joey and Chandler back?', 'No, Chandler’s still in Phase One, and Joey’s that thing you smell.']|
#
# -- 245501 range D1 1-10, mean conf: 1.7610371112823486--
# rank 7, conf: 1.7626538276672363
# sent 691465: |['Mom, are you home?', "Shh, she'll hear you."]|
#
# -- 245501 range D2 10-20, mean conf: 1.7312486171722412--
# rank 14, conf: 1.7432124614715576
# sent 1022186: |['Kramer, are you coming back to bed?', "Yeah, yeah, I'll be right there baby."]|
#
# -- 245501 range D3 20-30, mean conf: 1.6976006031036377--
# rank 28, conf: 1.6938691139221191
# sent 722437: |["For my headphones. When's Dean getting here?", "Calm down Paris. We're just gonna watch a movie, and you're welcome to join us."]|
#
# -- 245501 range D4 30-60, mean conf: 1.6732022762298584--
# rank 59, conf: 1.6609619855880737
# sent 1008290: |['I know, I know, but man! I never felt so alive! Now, are you coming with me?', "Uh, no, I'm not."]|
#
# ----------SENT 452076 @15---------
# TEXT: |['Quinn. You made out in my bed.', 'Hey!']|
# MEAN CONF TOP100: 1.6720874309539795
#
# -- 452076 range D0 0-1, mean conf: 1.8006881475448608--
# rank 2, conf: 1.8006881475448608
# sent 728731: |['No egg, no nog. I sat in the dark with the lights off and ate gruel.', 'Okay, mom.']|
#
# -- 452076 range D1 1-10, mean conf: 1.7504950761795044--
# rank 7, conf: 1.749178171157837
# sent 514192: |["I'm Jake the Dog and I put my nose in poop.", "There's a lot of interesting smells in poop."]|
#
# -- 452076 range D2 10-20, mean conf: 1.7186568975448608--
# rank 20, conf: 1.7107646465301514
# sent 1012148: |["Why? He's a 31. I saw the tag on the back.", 'The tag, huh?']|
#
# -- 452076 range D3 20-30, mean conf: 1.693821907043457--
# rank 29, conf: 1.6856751441955566
# sent 133106: |['Please. I saw you undressing him with your bedroom eyes.', "At least I'm not the one asking him if he waxed his eyebrows."]|
#
# -- 452076 range D4 30-60, mean conf: 1.6673318147659302--
# rank 46, conf: 1.6701914072036743
# sent 801613: |['You invited me. You threw the red dirt in my face.', 'Oh, yeah.']|
#
# ----------SENT 149928 @16---------
# TEXT: |['And he bought it for eight hundred cash a couple weeks ago. Right. Bye.', "It's always business with you."]|
# MEAN CONF TOP100: 1.6687668561935425
#
# -- 149928 range D0 0-1, mean conf: 1.75736665725708--
# rank 2, conf: 1.75736665725708
# sent 105991: |['Uh, March four, nineteen ninety four. He was declared a deserter thirty days later and he received a dishonorable discharge.', 'Dishonorable?']|
#
# -- 149928 range D1 1-10, mean conf: 1.7404435873031616--
# rank 7, conf: 1.7407504320144653
# sent 409770: |['At least you got yourself a match for the chimney prints -- a Jonathan Wax, from Henderson, served four years for attempted rape and he was released six months ago.', 'Thank you.']|
#
# -- 149928 range D2 10-20, mean conf: 1.7084815502166748--
# rank 16, conf: 1.7085105180740356
# sent 1033888: |["Two weeks of jury duty and suddenly she's lawyery.", 'Now, normally I would have a way to come back for that but I am too tired.']|
#
# -- 149928 range D3 20-30, mean conf: 1.6808710098266602--
# rank 23, conf: 1.6876327991485596
# sent 584906: |['I made some poor choices. Picked the wrong friends. People involved in questionable business ventures. They think I took something that belonged to them. With the help of some old colleagues from the Guard, I managed to make myself disappear. It worked for nearly three years.', 'Your friends found you?']|
#
# -- 149928 range D4 30-60, mean conf: 1.6627291440963745--
# rank 48, conf: 1.6608630418777466
# sent 875206: |["Ta'hoffren. He made me a demon 1120 years ago.", 'Why would he attack Willow?']|
#
# ----------SENT 1072756 @17---------
# TEXT: |["Doc, you're always welcome in my place.", 'Thanks, but no thanks.']|
# MEAN CONF TOP100: 1.6605799198150635
#
# -- 1072756 range D0 0-1, mean conf: 1.7356889247894287--
# rank 2, conf: 1.7356889247894287
# sent 269397: |["Boys, uh... I can't thank you enough for this. I know it was asking a lot but you still came through. Your daddy raised you right.", 'Well, we owed you.']|
#
# -- 1072756 range D1 1-10, mean conf: 1.7153575420379639--
# rank 10, conf: 1.705541729927063
# sent 540834: |["Yes, ma'am. I'm at your command, as always.", 'Will there be any planets where we can take on supplies?']|
#
# -- 1072756 range D2 10-20, mean conf: 1.6905262470245361--
# rank 17, conf: 1.6884759664535522
# sent 687962: |['Asaad Kelada, sorry. In my soul I know I am Asaad Kelada.', 'What do you need from me, Kirk?']|
#
# -- 1072756 range D3 20-30, mean conf: 1.6767971515655518--
# rank 28, conf: 1.6751199960708618
# sent 492305: |['Your parents are in great danger, Emma.', 'You really have no idea what you’re talking about.']|
#
# -- 1072756 range D4 30-60, mean conf: 1.657752513885498--
# rank 40, conf: 1.6607074737548828
# sent 984924: |["Of course I'm right. I'm always right.", 'Hmm. Gonna let that one slide, but only because you have whipped cream on your crotch.']|
#
# ----------SENT 505042 @18---------
# TEXT: |['Maleficent happened. And that is her idea of a good time.', 'Regina... Are you okay? What happened last night?']|
# MEAN CONF TOP100: 1.616306185722351
#
# -- 505042 range D0 0-1, mean conf: 1.7337201833724976--
# rank 2, conf: 1.7337201833724976
# sent 889706: |['Anime. You know, I knew a girl in high school named Anna May. Anna May Fletcher. She was born with one nostril. Then she had this bad nose job and basically wound up with three.', 'You’re here a lot now.']|
#
# -- 505042 range D1 1-10, mean conf: 1.694602131843567--
# rank 8, conf: 1.6881147623062134
# sent 74857: |['Ask Captain Yates. He had the job of clearing up the mess last time.', 'Well, what is a Nestene©']|
#
# -- 505042 range D2 10-20, mean conf: 1.6424171924591064--
# rank 17, conf: 1.6406152248382568
# sent 560155: |["Trance has been busting her purple tail updating Andromeda's xenobiology program. So she took a little unauthorised vacation time.", "It's called going AWOL. In the old days, that would mean two weeks in the brig."]|
#
# -- 505042 range D3 20-30, mean conf: 1.62796151638031--
# rank 29, conf: 1.6254080533981323
# sent 312563: |["I'll send the coat to Hodgins, see what he can discern from it. Her skeletal robusticity and large areas of muscle attachment suggest extremely good health.", 'A couple weeks in the desert and no critters got at these remains?']|
#
# -- 505042 range D4 30-60, mean conf: 1.6096503734588623--
# rank 48, conf: 1.6077121496200562
# sent 70989: |["Earth's safe. So is history and the web of time.", "I meant on a personal level. I don't think I've ever misjudged anybody quite as badly as I did Lytton."]|
#
# ----------SENT 788093 @19---------
# TEXT: |["Attention everyone. Drug testers are coming in a couple of hours to test everyone's urine.", 'Waa... what? What are you talking about?']|
# MEAN CONF TOP100: 1.611495018005371
#
# -- 788093 range D0 0-1, mean conf: 1.8032054901123047--
# rank 2, conf: 1.8032054901123047
# sent 183409: |["They broke through the final firewall. Checkmate's gonna be here any minute.", "As long as they torture us with the A.C. on, I'll die happy."]|
#
# -- 788093 range D1 1-10, mean conf: 1.7094727754592896--
# rank 10, conf: 1.6793580055236816
# sent 256815: |['Here you go. Arrest records going back to 1851.', 'Thanks.']|
#
# -- 788093 range D2 10-20, mean conf: 1.654741883277893--
# rank 15, conf: 1.656945824623108
# sent 180631: |["Excuse me. Senator, it's time to go. Your plane to Washington is waiting.", "I'll be right there."]|
#
# -- 788093 range D3 20-30, mean conf: 1.6302039623260498--
# rank 22, conf: 1.6371872425079346
# sent 650105: |['American Fourth Infantry to invade Sainte Claire Tuesday dawn.', "That's two days from now."]|
#
# -- 788093 range D4 30-60, mean conf: 1.6042283773422241--
# rank 34, conf: 1.617550253868103
# sent 615868: |['Days? The Captain will be back in the morning.', 'Maybe he needs a cold shower.']|
#
# ----------SENT 91570 @20---------
# TEXT: |["No, don't really fancy it.", "You don't have a choice, Merlin."]|
# MEAN CONF TOP100: 1.6098747253417969
#
# -- 91570 range D0 0-1, mean conf: 1.6996376514434814--
# rank 2, conf: 1.6996376514434814
# sent 67966: |["Gwen, this is Allen Shapiro. Don't. Really, don't.", "Well, he's not scaring me. Hello."]|
#
# -- 91570 range D1 1-10, mean conf: 1.640225887298584--
# rank 3, conf: 1.652724027633667
# sent 1016111: |["No, don't cancel it.", "Huh. Well this is a little awkward, isn't it/"]|
#
# -- 91570 range D2 10-20, mean conf: 1.6152395009994507--
# rank 12, conf: 1.619826078414917
# sent 1051956: |["It's fine, dad. Really, don't worry about it.", 'Here, let me take care of that.']|
#
# -- 91570 range D3 20-30, mean conf: 1.614729881286621--
# rank 28, conf: 1.614729881286621
# sent 15140: |['No, not really.', "But Jo, that's only one little world. There's so many hundreds of others to see."]|
#
# -- 91570 range D4 30-60, mean conf: 1.6139236688613892--
# rank 48, conf: 1.6147297620773315
# sent 402468: |['No, not really.', 'Pool?']|
#
# ----------SENT 80500 @21---------
# TEXT: |['The information can be extracted by means of your suffering.', "Are you trying to scare me? Well, cos I'm already bloody terrified of dying. And I'll endure a lot of pain for a very long time before I give up the information that's keeping me alive. How long have you got?"]|
# MEAN CONF TOP100: 1.5488454103469849
#
# -- 80500 range D0 0-1, mean conf: 1.8450264930725098--
# rank 2, conf: 1.8450264930725098
# sent 80550: |['The information can be extracted by means of your suffering.', "Are you trying to scare me? Well, cos I'm already bloody terrified of dying. And I'll endure a lot of pain for a very long time before I give up the information that's keeping me alive. How long have you got?"]|
#
# -- 80500 range D1 1-10, mean conf: 1.628236174583435--
# rank 4, conf: 1.6491910219192505
# sent 524661: |['Your signature requires two witnesses. But the witness cannot be the beneficiary of your estate.', 'Yvetta !']|
#
# -- 80500 range D2 10-20, mean conf: 1.5876903533935547--
# rank 12, conf: 1.5955179929733276
# sent 574948: |["There won't be any others. You'll warn them. Your federation will quarantine the entire area.", 'Yes, I suppose it would.']|
#
# -- 80500 range D3 20-30, mean conf: 1.5693385601043701--
# rank 22, conf: 1.5801573991775513
# sent 388146: |['I got it covered.  In the event of an emergency, my ass can be used as a floatation device.', 'Ooh, that reminds me']|
#
# -- 80500 range D4 30-60, mean conf: 1.5399452447891235--
# rank 52, conf: 1.53408944606781
# sent 25941: |['Earth will still die. The fungus will take the oxygen from your atmosphere.', "No, I'm afraid that you've failed there too. We can destroy the fungus."]|
#
# ----------SENT 584937 @22---------
# TEXT: |["You're leaving me very little choice.", "Shran left six hours ago. You're too late."]|
# MEAN CONF TOP100: 1.5377579927444458
#
# -- 584937 range D0 0-1, mean conf: 1.5931204557418823--
# rank 2, conf: 1.5931204557418823
# sent 543346: |['You are making a serious error.', 'End transmission. Why would people in the business of toxic waste disposal be so anxious to get hold of a probe?']|
#
# -- 584937 range D1 1-10, mean conf: 1.579695224761963--
# rank 8, conf: 1.5779811143875122
# sent 29674: |["You're being a bit calm.", "Oh, there's no need to worry. When it's in range,"]|
#
# -- 584937 range D2 10-20, mean conf: 1.5579760074615479--
# rank 12, conf: 1.5686931610107422
# sent 654824: |["You're making yourself a target.", 'Understood. But Dylan']|
#
# -- 584937 range D3 20-30, mean conf: 1.549391508102417--
# rank 25, conf: 1.5496121644973755
# sent 453754: |['This is kind of weird...you getting me a latte.', 'Coffee is the new latte.']|
#
# -- 584937 range D4 30-60, mean conf: 1.5375863313674927--
# rank 46, conf: 1.540174126625061
# sent 999261: |["Don't fill up on the bread. I'm making you a very special dinner. Very special.", "The pies. I'm going to the bathroom. You know."]|
#
# ----------SENT 893145 @23---------
# TEXT: |['Sheldon, this place is so romantic.', 'Oh, I’m glad you like it. Raj picked it out.']|
# MEAN CONF TOP100: 1.5365893840789795
#
# -- 893145 range D0 0-1, mean conf: 1.6417722702026367--
# rank 2, conf: 1.6417722702026367
# sent 771681: |['Thank you. So, this is your place.', 'This is it.']|
#
# -- 893145 range D1 1-10, mean conf: 1.5796164274215698--
# rank 6, conf: 1.5958714485168457
# sent 781832: |['So, this is the college.', "Yeah. Yeah. As a freshman, my housing choices are pretty limited, but this is the dorm I want. It's close to everything good."]|
#
# -- 893145 range D2 10-20, mean conf: 1.546573281288147--
# rank 12, conf: 1.551866054534912
# sent 87685: |['This is lovely, Cedric.', 'Is there anything else that you need doing, Sire?']|
#
# -- 893145 range D3 20-30, mean conf: 1.5323371887207031--
# rank 22, conf: 1.5341877937316895
# sent 167799: |['This is very generous, Lex.', "Actually, it isn't. It reflects the exact value of the herd and grazing land you lost. I wouldn't insult you by putting you in my debt. All I want is to leave the doubt between us in the past."]|
#
# -- 893145 range D4 30-60, mean conf: 1.529608964920044--
# rank 41, conf: 1.5296188592910767
# sent 803579: |['Dunder Mifflin, this is Pam.', 'Good morning.']|
#
# ----------SENT 746926 @24---------
# TEXT: |['Yeah, first row. Right in front of the kid with the humongous. . .uh, the really cute kid.', "Darn, I wanted to get a picture of her walking in. I'll get some of her in her seat."]|
# MEAN CONF TOP100: 1.5211764574050903
#
# -- 746926 range D0 0-1, mean conf: 1.610357642173767--
# rank 2, conf: 1.610357642173767
# sent 778841: |["Well, clearly there's that, but putting that aside, underneath that, um, weird, poorly bathed exterior, there's, like, this whole...deeply wounded, vulnerable guy.", "Listen, all right, in terms of what happened yesterday between us, that was just we were on the road. All right, we talked. That's all over."]|
#
# -- 746926 range D1 1-10, mean conf: 1.5836485624313354--
# rank 3, conf: 1.602515459060669
# sent 278899: |['Yeah, the overnight guy.', 'Yeah, I know who he is.']|
#
# -- 746926 range D2 10-20, mean conf: 1.5589641332626343--
# rank 15, conf: 1.5631078481674194
# sent 754067: |['Oh, poor guy.', 'I made it extra strong. It should blacken your teeth and rot your stomach.']|
#
# -- 746926 range D3 20-30, mean conf: 1.539955735206604--
# rank 31, conf: 1.535392165184021
# sent 374904: |['Xander was a good guy.', 'Did any of you hear about the layoffs that were coming up soon?']|
#
# -- 746926 range D4 30-60, mean conf: 1.516856074333191--
# rank 54, conf: 1.5099384784698486
# sent 1005588: |['Yeah, flirted with the menu guy. Here.', 'Oh, thanks.']|
#
# ----------SENT 878052 @25---------
# TEXT: |['Can I get you ladies something? I was just about to mix up some Country Time.', "We're looking for Spike, actually."]|
# MEAN CONF TOP100: 1.5210076570510864
#
# -- 878052 range D0 0-1, mean conf: 1.6343680620193481--
# rank 2, conf: 1.6343680620193481
# sent 884227: |["Can I get you something? I don't have any coffee.", "Oh, no thank you, I, uh... You don't drink? Beverages, I mean?"]|
#
# -- 878052 range D1 1-10, mean conf: 1.6343679428100586--
# rank 9, conf: 1.6343679428100586
# sent 636505: |['Are you kidding? Yeah. Can I get you something? Name your poison.', 'Oh. Er.']|
#
# -- 878052 range D2 10-20, mean conf: 1.6048895120620728--
# rank 15, conf: 1.6102404594421387
# sent 898680: |['Can I… Can I get you something to drink?', 'Uh, no, thank you.']|
#
# -- 878052 range D3 20-30, mean conf: 1.5409910678863525--
# rank 22, conf: 1.5594712495803833
# sent 561550: |['Can I offer you something to drink?', 'Er, I thought I was the one playing host here.']|
#
# -- 878052 range D4 30-60, mean conf: 1.5012362003326416--
# rank 50, conf: 1.494653344154358
# sent 975600: |['Can I get you anything?', "Uh, no, thanks. I can't stay that long."]|
#
# ----------SENT 957166 @26---------
# TEXT: |['Bang! Am I good or am I good?', "What do you think you're doing?"]|
# MEAN CONF TOP100: 1.4932819604873657
#
# -- 957166 range D0 0-1, mean conf: 1.5820392370224--
# rank 2, conf: 1.5820392370224
# sent 504963: |["My, my. Aren't you a good a sleeper?", 'You think this spell has made me angry? Do not wake my baby!']|
#
# -- 957166 range D1 1-10, mean conf: 1.5608184337615967--
# rank 8, conf: 1.5581738948822021
# sent 118016: |['Then bring your partner in? Get me blabbering? Are you the good cop or the bad cop?', 'Sit.']|
#
# -- 957166 range D2 10-20, mean conf: 1.5239559412002563--
# rank 12, conf: 1.5351345539093018
# sent 690861: |['Phil is a riot. Am I crying or laughing?', 'Laughing.']|
#
# -- 957166 range D3 20-30, mean conf: 1.5046234130859375--
# rank 23, conf: 1.5117003917694092
# sent 359811: |['Yes! Yes! I’m good! Are you good? Are you good? Is everything—are you—are you perrr-perfect?!', 'Yeah. I’m okay. I’m actually—I’m a little cold, can I have your jacket?']|
#
# -- 957166 range D4 30-60, mean conf: 1.4885636568069458--
# rank 44, conf: 1.491839051246643
# sent 189373: |["Well, aren't you a handsome one?", 'Looks like dessert to me.']|
#
# ----------SENT 869878 @27---------
# TEXT: |['I think we can change them.', 'Come here, you two.']|
# MEAN CONF TOP100: 1.477889060974121
#
# -- 869878 range D0 0-1, mean conf: 1.6279581785202026--
# rank 2, conf: 1.6279581785202026
# sent 541939: |["I'm getting pretty good with the Borg language. I think I can translate them.", 'Get on it.']|
#
# -- 869878 range D1 1-10, mean conf: 1.5432947874069214--
# rank 4, conf: 1.5589115619659424
# sent 656899: |['And you think you can change their minds.', "Don't you?"]|
#
# -- 869878 range D2 10-20, mean conf: 1.5055711269378662--
# rank 13, conf: 1.5117058753967285
# sent 44945: |['I think we lost them.', 'For now.']|
#
# -- 869878 range D3 20-30, mean conf: 1.4891602993011475--
# rank 30, conf: 1.4877830743789673
# sent 224650: |['I told you! I find them boring.', 'Well, I showed up for all your stupid interventions.']|
#
# -- 869878 range D4 30-60, mean conf: 1.4738291501998901--
# rank 38, conf: 1.4764920473098755
# sent 911203: |['Uh, yeah, I think we’ll pass.', 'Oh, is the missus speaking for the couple now?']|
#
# ----------SENT 472923 @28---------
# TEXT: |['You want me to work for you?', 'Nope, no, no, you’ll still be your own boss I’ll just be the guy behind the curtain. And once this place returns to profitability, I’ll even let you buy it back.']|
# MEAN CONF TOP100: 1.4666823148727417
#
# -- 472923 range D0 0-1, mean conf: 1.6436352729797363--
# rank 2, conf: 1.6436352729797363
# sent 889749: |['You want me to work with you?', 'For me. You’re going to have to listen more carefully when you’re on the job.']|
#
# -- 472923 range D1 1-10, mean conf: 1.5236320495605469--
# rank 11, conf: 1.5047094821929932
# sent 645148: |['Somebody want to help me up?', "Boss! You're okay."]|
#
# -- 472923 range D2 10-20, mean conf: 1.4985476732254028--
# rank 15, conf: 1.5012011528015137
# sent 674476: |['You want me to help you? You let my family go. That is the only way!', 'No. That is not the only way.']|
#
# -- 472923 range D3 20-30, mean conf: 1.4824187755584717--
# rank 26, conf: 1.4802531003952026
# sent 845671: |["Right. Anyhoo, I have no idea how you managed to shatter the ascendant into a billion pieces, but we need to put it together before the eclipse at 12:28. You want to help? I know you're a puzzle person.", "I don't want to help. You're a psychopath. This place is your prison. I'm not letting you out. Besides, you'll just kill me the minute we get out."]|
#
# -- 472923 range D4 30-60, mean conf: 1.4641057252883911--
# rank 33, conf: 1.4732592105865479
# sent 106195: |["You want to search me? Go ahead. But I'm telling you the only pick me up I use is a cup of coffee before I go on duty and a couple of these when I'm on deck!", 'Mind if I hang onto these?']|
#
# ----------SENT 751740 @29---------
# TEXT: |['Is she back at Yale?', 'Lorelai...']|
# MEAN CONF TOP100: 1.4584693908691406
#
# -- 751740 range D0 0-1, mean conf: 1.6049814224243164--
# rank 2, conf: 1.6049814224243164
# sent 930218: |['Is he back at the apartment?', 'Um, I guess so. Where else would he go?']|
#
# -- 751740 range D1 1-10, mean conf: 1.5656366348266602--
# rank 4, conf: 1.5837403535842896
# sent 734461: |["I'm gonna go see. She's at Miss Patty's?", "Don't leave me alone."]|
#
# -- 751740 range D2 10-20, mean conf: 1.5002959966659546--
# rank 16, conf: 1.5043253898620605
# sent 942576: |['Wait.Ja Pense is coming to Newport?', 'What is Ja Pense?']|
#
# -- 751740 range D3 20-30, mean conf: 1.4778673648834229--
# rank 28, conf: 1.4792490005493164
# sent 32933: |["Is Luke back? Rani didn't say.", "What? No, no, he's not back. Sorry, excuse me."]|
#
# -- 751740 range D4 30-60, mean conf: 1.4494415521621704--
# rank 46, conf: 1.4494132995605469
# sent 937005: |["Ryan's taking me to Vegas?", "And I'm taking you, Mrs. What-Are-Our- Plans-For-New Year's. Now, why don't you to get packed so we can get on the road."]|
#
# ----------SENT 373427 @30---------
# TEXT: |["She didn't do it.", 'How do you know?']|
# MEAN CONF TOP100: 1.4335644245147705
#
# -- 373427 range D0 0-1, mean conf: 1.5672626495361328--
# rank 1, conf: 1.5672626495361328
# sent 135916: |["She didn't do it.", "You think I don't know that? I'm just telling you what they're saying all over the Beltway. I give it twenty-four hours before they ask for my resignation."]|
#
# -- 373427 range D1 1-10, mean conf: 1.5360509157180786--
# rank 9, conf: 1.4927864074707031
# sent 796953: |["We asked her. She said she didn't do it.", "Which is exactly what you'd say if you did do it. Oh, man! I should've been handling this investigation from the beginning."]|
#
# -- 373427 range D2 10-20, mean conf: 1.4686100482940674--
# rank 18, conf: 1.4663949012756348
# sent 159005: |["He didn't do anything.", "If you're in trouble, Lana, I can help."]|
#
# -- 373427 range D3 20-30, mean conf: 1.45061194896698--
# rank 28, conf: 1.445512294769287
# sent 414806: |["You're not putting this murder rap on me. It was that freak Jason. He did it.", "We're placing you at the scene."]|
#
# -- 373427 range D4 30-60, mean conf: 1.4346805810928345--
# rank 43, conf: 1.44106924533844
# sent 494961: |['These accusations against Mary Margaret – they’ve been gnawing away at me. She didn’t do this.', 'I understand what you’re going through. It’s painful when someone we care about betrays us.']|
#
# ----------SENT 531719 @31---------
# TEXT: |["It's not her husband?", 'No!']|
# MEAN CONF TOP100: 1.4080156087875366
#
# -- 531719 range D0 0-1, mean conf: 1.5518767833709717--
# rank 2, conf: 1.5518767833709717
# sent 712547: |["Isn't he your Lit teacher?", 'Yeah, but I do have really tall people sitting in front of me.']|
#
# -- 531719 range D1 1-10, mean conf: 1.5125758647918701--
# rank 8, conf: 1.5187900066375732
# sent 830753: |["Stefan? Isn't she your girlfriend?", "Who knows? I know she was sired to me. I know her emotions were off. I know she's so full of rage she wants to rip Katherine's head off..."]|
#
# -- 531719 range D2 10-20, mean conf: 1.4477452039718628--
# rank 19, conf: 1.4442400932312012
# sent 904099: |["So you're never getting married? It's his whining, isn't it?", "Sheldon, I'm not a whiner."]|
#
# -- 531719 range D3 20-30, mean conf: 1.4266157150268555--
# rank 24, conf: 1.4301918745040894
# sent 607474: |['Did he revoke my commission?', "No. You will serve aboard the Ch'Tang as Third Officer."]|
#
# -- 531719 range D4 30-60, mean conf: 1.4064172506332397--
# rank 57, conf: 1.3958879709243774
# sent 522043: |['Well, who is she? Is she your girlfriend?', 'Yes.']|
#
# ----------SENT 789149 @32---------
# TEXT: |["I don't know who these new people think they are. I've sat downwind of Phyllis' stinky perfumes for years. Never said a word.", "People hate people that are different from them. That's natural. But you know what makes people forget their differences? A great show. That is why I created the 'Integration Celebration'. This is the moment when Scranton and Stamford come together as one. United in applause."]|
# MEAN CONF TOP100: 1.3987449407577515
#
# -- 789149 range D0 0-1, mean conf: 1.6219425201416016--
# rank 2, conf: 1.6219425201416016
# sent 39871: |['I never said a word.', "Telepathy. You know, telepathy isn't only a prerequisite of the\nSensorites. I know sometimes what you're thinking."]|
#
# -- 789149 range D1 1-10, mean conf: 1.5063163042068481--
# rank 4, conf: 1.5237351655960083
# sent 620566: |['I never said I had a map.', "Well, you're definitely taking us in circles."]|
#
# -- 789149 range D2 10-20, mean conf: 1.448731780052185--
# rank 17, conf: 1.4469573497772217
# sent 815787: |["Sure, last year you guys were riding me really hard for the website and I just peeled out my Z3 and I knocked the mirror off somebody's car. I never said a thing.", 'Wait, what?']|
#
# -- 789149 range D3 20-30, mean conf: 1.4186956882476807--
# rank 30, conf: 1.4121456146240234
# sent 700846: |['I never got a message.', 'I left it on your cell phone.']|
#
# -- 789149 range D4 30-60, mean conf: 1.3868515491485596--
# rank 56, conf: 1.3761669397354126
# sent 487757: |['I said "secretly."', 'No girls crushed on me. I was a clean teen.']|
#
# ----------SENT 607345 @33---------
# TEXT: |['On my way.', 'We have been unable to establish two way communication so far, but we have determined that the signal is coming from somewhere in the Rutharian sector.']|
# MEAN CONF TOP100: 1.3510119915008545
#
# -- 607345 range D0 0-1, mean conf: 1.4231489896774292--
# rank 1, conf: 1.4231489896774292
# sent 573120: |['On my way. McCoy out.', 'Kirk to Engineering. Scotty, there was a power loss. How come?']|
#
# -- 607345 range D1 1-10, mean conf: 1.4231488704681396--
# rank 3, conf: 1.4231489896774292
# sent 639862: |['On my way.', 'Acknowledged.']|
#
# -- 607345 range D2 10-20, mean conf: 1.4231488704681396--
# rank 13, conf: 1.4231488704681396
# sent 603932: |['On my way.', 'Duras.']|
#
# -- 607345 range D3 20-30, mean conf: 1.4231488704681396--
# rank 28, conf: 1.4231488704681396
# sent 601747: |['On my way.', 'Last chance to take the long way around.']|
#
# -- 607345 range D4 30-60, mean conf: 1.365004301071167--
# rank 49, conf: 1.3563952445983887
# sent 511525: |["Ugh, yeah. It's not working. My way sucks.", "Cool, now we've gotta do damage control. Healing the negs energy at the source."]|
#
# ----------SENT 970705 @34---------
# TEXT: |['Jack and Jen?', 'Mm-hm. Andie and I played matchmaker tonight.']|
# MEAN CONF TOP100: 1.3208054304122925
#
# -- 970705 range D0 0-1, mean conf: 1.3441585302352905--
# rank 1, conf: 1.3441585302352905
# sent 754866: |["And, already, you are way ahead of a lot of people as far as parenting skills go, like Britney. Britney Spears does not know which end of a baby goes up. And Courtney Love? She's no June Cleaver.", 'Yeah I bet I could be a better mother than Courtney Love.']|
#
# -- 970705 range D1 1-10, mean conf: 1.344158411026001--
# rank 9, conf: 1.344158411026001
# sent 235738: |['Smithers and Burns?', 'No, us!']|
#
# -- 970705 range D2 10-20, mean conf: 1.3441582918167114--
# rank 16, conf: 1.3441582918167114
# sent 809997: |["Pam and Jim? Hey, I'm Jerry.", 'Hi Jerry.']|
#
# -- 970705 range D3 20-30, mean conf: 1.3441582918167114--
# rank 25, conf: 1.3441582918167114
# sent 103288: |['Peter and Malia?', 'Father and daughter.']|
#
# -- 970705 range D4 30-60, mean conf: 1.3440608978271484--
# rank 60, conf: 1.343682885169983
# sent 673973: |["And Marshall and Rachel? You know he won't hesitate to kill them once he gets what he needs.", "I know. You were right about him. After Irina was extracted, I was taken into custody. I had to designate a guardian for Sydney. I chose Sloane. In spite of everything he's done, I believed that some part of him was still the friend I once trusted with my daughter. Clearly, I was wrong."]|
#
# ----------SENT 623255 @35---------
# TEXT: |["The evening's young, Lieutenant. Let's mingle.", 'Vulcans do not. Curious.']|
# MEAN CONF TOP100: 1.2961820363998413
#
# -- 623255 range D0 0-1, mean conf: 1.3097411394119263--
# rank 2, conf: 1.3097411394119263
# sent 211955: |["That reminds me -- Troy said something interesting last night at the bar. Apparently he doesn't really love Selma and the marriage is just a sham to help his career. Well, enough talk. Let's snuggle.", 'What?!! Oh, my God!']|
#
# -- 623255 range D1 1-10, mean conf: 1.309541940689087--
# rank 3, conf: 1.3097373247146606
# sent 100733: |["How strong? All right, boys. Let's rumble.", "It's still here!"]|
#
# -- 623255 range D2 10-20, mean conf: 1.3090547323226929--
# rank 21, conf: 1.308886170387268
# sent 30548: |["Right. Let's roll.", "Clyde, you don't have to do this. I can find another way in."]|
#
# -- 623255 range D3 20-30, mean conf: 1.308885931968689--
# rank 30, conf: 1.3088860511779785
# sent 240409: |["Let's roll.", "Uh, Homer, you're drivin'."]|
#
# -- 623255 range D4 30-60, mean conf: 1.295518398284912--
# rank 50, conf: 1.2919468879699707
# sent 890990: |['Oh, God bless you, dear. Sheldon, sit down. Let’s talk.', 'All right, but you’re not fooling me. Whenever you say we have to talk, it means you want me to listen.']|
#
# ----------SENT 288485 @36---------
# TEXT: |["Let's go see the cooked person!", 'Geez, you know our deal.']|
# MEAN CONF TOP100: 1.2244501113891602
#
# -- 288485 range D0 0-1, mean conf: 1.3636349439620972--
# rank 2, conf: 1.3636349439620972
# sent 385524: |["Cool! Let's see this one!", "Nah. I'm not in the mood for a historical documentary. I've heard good things about Quizblorg, Quizblorg."]|
#
# -- 288485 range D1 1-10, mean conf: 1.2973676919937134--
# rank 6, conf: 1.29133141040802
# sent 433030: |["Oh, my bad, Sweetie Belle. Let's sing the chorus again!", "Well, gosh. Sure wasn't expectin' that."]|
#
# -- 288485 range D2 10-20, mean conf: 1.2622264623641968--
# rank 13, conf: 1.2689718008041382
# sent 245562: |["Let's play bingo!", "Yeah, let's play bingo!"]|
#
# -- 288485 range D3 20-30, mean conf: 1.2231600284576416--
# rank 22, conf: 1.2401673793792725
# sent 437041: |["You're doing great, Spike. Now let's see the big finish!", 'Whoa-oa-oa-oa!']|
#
# -- 288485 range D4 30-60, mean conf: 1.2087199687957764--
# rank 46, conf: 1.206799030303955
# sent 205780: |["The Old City. Where B.C. turned into A.D.! Let's go!", "Flanders, that stuff's been here for thousands of years. But the breakfast buffet at this hotel, which is included in our package, closes in ten minutes!"]|
#
# ----------SENT 307923 @37---------
# TEXT: |['How did it taste?', "Eh, it's way worse coming up. I can tell you that."]|
# MEAN CONF TOP100: 1.2241803407669067
#
# -- 307923 range D0 0-1, mean conf: 1.3396859169006348--
# rank 2, conf: 1.3396859169006348
# sent 542216: |['Stupido! Foolish Florentines! A bird is a mechanical instrument that  \t\tworks according to mathematical laws. An instrument that surely I can recreate.  \t\tHow did it fail?', 'Maybe you underestimated the wingspan?']|
#
# -- 307923 range D1 1-10, mean conf: 1.2781662940979004--
# rank 9, conf: 1.2571601867675781
# sent 765168: |["It sounded great, guys. All of it. Didn't it?", 'Not too shabby.']|
#
# -- 307923 range D2 10-20, mean conf: 1.240084171295166--
# rank 21, conf: 1.2260503768920898
# sent 27347: |['How did you manage that?', 'The Queen taught me. Nothing to it, really.']|
#
# -- 307923 range D3 20-30, mean conf: 1.2240965366363525--
# rank 22, conf: 1.2260503768920898
# sent 5918: |['How did you manage that?', 'Well. Shush.']|
#
# -- 307923 range D4 30-60, mean conf: 1.216873049736023--
# rank 46, conf: 1.2174556255340576
# sent 407997: |["Yet the grommet's fully intact. How did it survive the blast?", "I don't know, but they always do."]|
#
# ----------SENT 964068 @38---------
# TEXT: |['What? No en suite commode?', 'Excuse me?']|
# MEAN CONF TOP100: 1.1935938596725464
#
# -- 964068 range D0 0-1, mean conf: 1.303304672241211--
# rank 2, conf: 1.303304672241211
# sent 657211: |['No! Trance?', "Beka, it's all right. I'll be"]|
#
# -- 964068 range D1 1-10, mean conf: 1.2862894535064697--
# rank 11, conf: 1.271848201751709
# sent 768343: |["Oh, no? I'm sorry.", 'Trains are dirty.']|
#
# -- 964068 range D2 10-20, mean conf: 1.2413461208343506--
# rank 14, conf: 1.2718479633331299
# sent 447097: |['Oh, no?', "I'm exhausted! I am up half the night with Angelica!"]|
#
# -- 964068 range D3 20-30, mean conf: 1.1879253387451172--
# rank 26, conf: 1.1866812705993652
# sent 352743: |['No, y’know what? It’s gonna be okay. I mean you don’t have to have this rustic Italian feast. Y’know? And-and you don’t need, you don’t need this custom-made, empire-waisted, duchess, satin gown; you can wear off the rack.', 'Look, it really is gonna be okay. The important thing is that we love each other and that we’re gonna get married.']|
#
# -- 964068 range D4 30-60, mean conf: 1.1791867017745972--
# rank 35, conf: 1.1828559637069702
# sent 712462: |['No, what?', "They don't sell giant foam fingers."]|
#
# ----------SENT 518662 @39---------
# TEXT: |["It's running backwards. There's serious witchery afoot here.", "Come on, Princess. We don't got all night."]|
# MEAN CONF TOP100: 1.1899452209472656
#
# -- 518662 range D0 0-1, mean conf: 1.2764973640441895--
# rank 2, conf: 1.2764973640441895
# sent 27302: |['Wait! There is a stranger here. Guards!', "She saw me. They're coming. The guards are coming!"]|
#
# -- 518662 range D1 1-10, mean conf: 1.2587380409240723--
# rank 10, conf: 1.252881407737732
# sent 722430: |["There's a danger here.", 'The roommate thing.']|
#
# -- 518662 range D2 10-20, mean conf: 1.2104487419128418--
# rank 14, conf: 1.2152678966522217
# sent 368276: |["There isn't a piano here.", "That wouldn't stand in the way of a true pianist."]|
#
# -- 518662 range D3 20-30, mean conf: 1.1991562843322754--
# rank 22, conf: 1.2029564380645752
# sent 531114: |["O'Malley...there's no blame here. Your father's body is diseased and has undergone tremendous trauma. Now his organs are shutting down. There's no blame here.", 'Do people come back from this? His BUN and creatine are high. I get that. I was just wondering, in your experience, can people come back from this?']|
#
# -- 518662 range D4 30-60, mean conf: 1.1867421865463257--
# rank 34, conf: 1.1949899196624756
# sent 566505: |['We believe you can. There is no evil here.', "Oh yes, there is. You just haven't seen it yet."]|

# %% [markdown]
# ## Variation V6: Keep and only keep tokens on nouns and verbs.
#
# Full manifest:
#
# For DEP (syntactic dependency): NO DEP.
#
# For POS (senmatic token):
# * Only keep nouns and verbs, remove all others.
#
# REJECT.

# %%
data_v6 = data.loc[(data.head_info=='POS') & (data.head_pos.isin(_allow_pos))]
data_v6
# Out:
#           sent_id            show_id            char_name char_id head_info  \
# 0         1063785        QueerAsFolk              MICHAEL  l22346       POS
# 13         144292       VeronicaMars             VERONICA  l30591       POS
# 14         537460           StarTrek              JANEWAY  l25466       POS
# 15         923983      SonsOfAnarchy                  JAX  l24810       POS
# 21         238693        TheSimpsons  C. Montgomery Burns  a15869       POS
# 33         866034  HowIMetYourMother                ROBIN  l13772       POS
# 45         189666        TheSimpsons        Homer Simpson  a15835       POS
# 46         608478           StarTrek                SPOCK  l25411       POS
# 58         460395        OneTreeHill                LUCAS  l19593       POS
# 59         357634            Friends               MONICA  l10692       POS
# 64         309155              Bones               ANGELA   l5149       POS
# 69          81062          DoctorWho                CLARA   l8711       POS
# 72         578352           StarTrek               ARCHER  l25486       POS
# 75         579201           StarTrek               ARCHER  l25486       POS
# 80         545131           StarTrek              JANEWAY  l25466       POS
# 81         313849              Bones               SWEETS   l5163       POS
# 93         110435               NCIS                GIBBS  l18791       POS
# 107        752836       GilmoreGirls                 LANE  l11622       POS
# 109        449728        OneTreeHill               BROOKE  l19597       POS
# 116        335435            Friends               RACHEL  l10691       POS
# 118        613283           StarTrek                PARIS  l25469       POS
# 120         73421          DoctorWho       SEVENTH DOCTOR   l8656       POS
# 123        174606         Smallville                 LOIS  l24649       POS
# 134        923856      SonsOfAnarchy                  JAX  l24810       POS
# 136         41401          DoctorWho         FIRST DOCTOR   l8650       POS
# 143        900751   TheBigBangTheory              LEONARD   l4385       POS
# 145        416219           CSIVerse                BRASS   l7504       POS
# 154        714918       GilmoreGirls                 RORY  l11613       POS
# 169        192601        TheSimpsons        Homer Simpson  a15835       POS
# 174        590601           StarTrek                RIKER  l25432       POS
# ...           ...                ...                  ...     ...       ...
# 17160204   870557  HowIMetYourMother                 LILY  l13773       POS
# 17160217   203859        TheSimpsons        Homer Simpson  a15835       POS
# 17160221   686728       GilmoreGirls              LORELAI  l11612       POS
# 17160226   248187        TheSimpsons  Milhouse Van Houten  a15849       POS
# 17160242   747265       GilmoreGirls               SOOKIE  l11619       POS
# 17160248   201553        TheSimpsons        Homer Simpson  a15835       POS
# 17160267   319814         Buffyverse                ANGEL   l5650       POS
# 17160285   474465        OneTreeHill                MOUTH  l19603       POS
# 17160293   480044        OneTreeHill                KAREN  l19601       POS
# 17160300   359751            Friends               MONICA  l10692       POS
# 17160301   643572           StarTrek               HARPER   l1893       POS
# 17160302   215366        TheSimpsons        Marge Simpson  a15821       POS
# 17160303   123540               NCIS                MCGEE  l18792       POS
# 17160315   105766               NCIS                GIBBS  l18791       POS
# 17160318    66392          DoctorWho                 GWEN   l9078       POS
# 17160321   148708       VeronicaMars                KEITH  l30592       POS
# 17160322   712716       GilmoreGirls                 RORY  l11613       POS
# 17160323   859388  HowIMetYourMother               BARNEY  l13774       POS
# 17160327   649350           StarTrek               NEELIX  l25473       POS
# 17160329   688919       GilmoreGirls              LORELAI  l11612       POS
# 17160341   464413        OneTreeHill               NATHAN  l19594       POS
# 17160342   676588              Alias                DIXON   l1277       POS
# 17160344   749073       GilmoreGirls               SOOKIE  l11619       POS
# 17160355   329079            Friends                 ROSS  l10696       POS
# 17160359    25432          DoctorWho        SECOND DOCTOR   l8651       POS
# 17160362   793175        TheOfficeUS              MICHAEL  l19352       POS
# 17160365   723387       GilmoreGirls                 RORY  l11613       POS
# 17160366   125325               NCIS                 ABBY  l18806       POS
# 17160373   537886           StarTrek              JANEWAY  l25466       POS
# 17160376   652290           StarTrek                MCCOY  l25412       POS
#
#          head_pos         token     token_par  position  is_stop  \
# 0             VBZ            be            be         2     True
# 13            VBZ            do            do         0     True
# 14             NN     deflector     deflector        61    False
# 15            VBZ            be            be        26     True
# 21             NN         blood         blood        63    False
# 33             NN          info          info        63    False
# 45            NNP        PERSON        PERSON         5    False
# 46             VB           get           get        30     True
# 58             NN           mom           mom        27    False
# 59            VBG          play          play       110    False
# 64            NNP           ORG           ORG        43    False
# 69            VBZ            go            go        17    False
# 72             NN          fire          fire        12    False
# 75            VBZ            be            be        31     True
# 80            NNP           ORG           ORG        13    False
# 81             NN          trap          trap        26    False
# 93            NNP        PERSON        PERSON       127    False
# 107            NN  cheerleading  cheerleading        15    False
# 109            VB          hear          hear        19    False
# 116           VBP         think         think         2    False
# 118           NNS         datum         datum        44    False
# 120           NNP        Doctor        Doctor        15    False
# 123           VBD         leave         leave       101    False
# 134           VBP          want          want         4    False
# 136           NNS         thank         thank        10    False
# 143            NN       brother       brother         8    False
# 145            NN        street        street        19    False
# 154           VBZ            be            be         0     True
# 169            NN          DATE          DATE        40    False
# 174           NNS     situation     situation        32    False
# ...           ...           ...           ...       ...      ...
# 17160204      VBZ         spend         spend        74    False
# 17160217      VBP            do            do        25     True
# 17160221       NN      bachelor      bachelor        59    False
# 17160226       NN           kid           kid        27    False
# 17160242      VBN           rid           rid        39    False
# 17160248      VBG            go            go        85    False
# 17160267      VBG          kill          kill        29    False
# 17160285       NN          game          game        19    False
# 17160293      VBP          know          know        30    False
# 17160300       NN         cause         cause       165    False
# 17160301       VB            be            be        21     True
# 17160302       VB          give          give        27     True
# 17160303      VBD            do            do         0     True
# 17160315      VBZ            be            be         3     True
# 17160318       NN          love          love        12    False
# 17160321      VBN            be            be        42     True
# 17160322      VBZ          have          have        80     True
# 17160323      NNP        PERSON        PERSON        20    False
# 17160327      NNS           day           day        24    False
# 17160329      NNP       General       General         0    False
# 17160341       VB           try           try        48    False
# 17160342      VBZ            be            be        28     True
# 17160344       NN        budget        budget        20    False
# 17160355       VB          wait          wait       110    False
# 17160359       NN        report        report        62    False
# 17160362      NNP           GPE           GPE        72    False
# 17160365      VBD            be            be         8     True
# 17160366      NNP           ORG           ORG       114    False
# 17160373       NN         price         price       109    False
# 17160376      NNP           FAC           FAC        66    False
#
#                              head_text
# 0                            VBZ|be|be
# 13                           VBZ|do|do
# 14              NN|deflector|deflector
# 15                           VBZ|be|be
# 21                      NN|blood|blood
# 33                        NN|info|info
# 45                   NNP|PERSON|PERSON
# 46                          VB|get|get
# 58                          NN|mom|mom
# 59                       VBG|play|play
# 64                         NNP|ORG|ORG
# 69                           VBZ|go|go
# 72                        NN|fire|fire
# 75                           VBZ|be|be
# 80                         NNP|ORG|ORG
# 81                        NN|trap|trap
# 93                   NNP|PERSON|PERSON
# 107       NN|cheerleading|cheerleading
# 109                       VB|hear|hear
# 116                    VBP|think|think
# 118                    NNS|datum|datum
# 120                  NNP|Doctor|Doctor
# 123                    VBD|leave|leave
# 134                      VBP|want|want
# 136                    NNS|thank|thank
# 143                 NN|brother|brother
# 145                   NN|street|street
# 154                          VBZ|be|be
# 169                       NN|DATE|DATE
# 174            NNS|situation|situation
# ...                                ...
# 17160204               VBZ|spend|spend
# 17160217                     VBP|do|do
# 17160221          NN|bachelor|bachelor
# 17160226                    NN|kid|kid
# 17160242                   VBN|rid|rid
# 17160248                     VBG|go|go
# 17160267                 VBG|kill|kill
# 17160285                  NN|game|game
# 17160293                 VBP|know|know
# 17160300                NN|cause|cause
# 17160301                      VB|be|be
# 17160302                  VB|give|give
# 17160303                     VBD|do|do
# 17160315                     VBZ|be|be
# 17160318                  NN|love|love
# 17160321                     VBN|be|be
# 17160322                 VBZ|have|have
# 17160323             NNP|PERSON|PERSON
# 17160327                   NNS|day|day
# 17160329           NNP|General|General
# 17160341                    VB|try|try
# 17160342                     VBZ|be|be
# 17160344              NN|budget|budget
# 17160355                  VB|wait|wait
# 17160359              NN|report|report
# 17160362                   NNP|GPE|GPE
# 17160365                     VBD|be|be
# 17160366                   NNP|ORG|ORG
# 17160373                NN|price|price
# 17160376                   NNP|FAC|FAC
#
# [2877306 rows x 11 columns]

# %%
model_v6, SENT_CATS_v6, FEATURE_CATS_v6 = get_train(data_v6, report_test_acc=False)
SENT_MAP_v6, INV_SENT_MAP_v6 = build_maps(data_v6)
# Out:
# <20686x904907 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2877306 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [01:37<00:00,  1.99it/s]
# 904907 904907

# %%
mi = ModelInspection(model_v6, SENT_MAP_v6, INV_SENT_MAP_v6, dialog_df=dialogs)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 519664 @0---------
# TEXT: |["Sookie. All of the things that you need to be protected from, all of the trouble you're in, you're in because of me. So you needing to be protected has nothing to de with you or who you are. All of it is my fault. So why don't you just go to sleep and let me be the one to worry about it?", "Bill, all the trouble I'm in, it's mine. I chose it. I chose it when I chose you."]|
# MEAN CONF TOP100: 1.3187565803527832
#
# -- 519664 range D0 0-1, mean conf: 1.3921537399291992--
# rank 2, conf: 1.3921537399291992
# sent 803056: |['Ah. Well, please think about it. And call me. We will do whatever we can to get you to stay.', 'Okay.']|
#
# -- 519664 range D1 1-10, mean conf: 1.3719496726989746--
# rank 5, conf: 1.3747535943984985
# sent 878413: |["Let's not worry about her anymore.", "I have to sign off. I'll talk to you later."]|
#
# -- 519664 range D2 10-20, mean conf: 1.350116491317749--
# rank 21, conf: 1.3364603519439697
# sent 52599: |["Don't go to sleep. Please.", "I'm not. I'm just tired."]|
#
# -- 519664 range D3 20-30, mean conf: 1.3333680629730225--
# rank 31, conf: 1.3279845714569092
# sent 950907: |["everything's gonna be fine, I don't want you to worry sweetie", "i'm not"]|
#
# -- 519664 range D4 30-60, mean conf: 1.3149757385253906--
# rank 37, conf: 1.3208562135696411
# sent 31602: |["Don't worry about us, where did it go?", 'If Slitheen are back on Earth it means mayhem on a global scale.']|
#
# ----------SENT 742296 @1---------
# TEXT: |['You brought up Toblerone. I just said it was better than that because I think it is.', 'Marzipan is candy. You like candy.']|
# MEAN CONF TOP100: 1.3100883960723877
#
# -- 742296 range D0 0-1, mean conf: 1.4580312967300415--
# rank 2, conf: 1.4580312967300415
# sent 630828: |["Just because I said that I think she's interesting", "You said she was perfect. Come on down. You're no use around here for now. Come on down. Go talk to her. Use the ladder."]|
#
# -- 742296 range D1 1-10, mean conf: 1.3768246173858643--
# rank 6, conf: 1.3606183528900146
# sent 796634: |['No, uh, no. That was a test. I was testing you, and you all failed. Miserably. When I said that Dwight was a narc, how many of you defended him? How many of you said, "Hey, you know what, he\'s right? What he\'s doing is protecting this office from the evils of drugs."', 'Thank you, Michael.']|
#
# -- 742296 range D2 10-20, mean conf: 1.351905107498169--
# rank 13, conf: 1.3549888134002686
# sent 870576: |['Wait. No. It had to be more than just, "Nah." Oh, I think she said...', "You're a big... stupid octopus head!"]|
#
# -- 742296 range D3 20-30, mean conf: 1.3294963836669922--
# rank 26, conf: 1.3300445079803467
# sent 715019: |['Maybe Dean is even more terrific than we thought he was.', "It's not covering the whole cast."]|
#
# -- 742296 range D4 30-60, mean conf: 1.3073177337646484--
# rank 36, conf: 1.320939302444458
# sent 67317: |["Thing is, I was thinking though, right? Those kids went off at eight forty, when everyone's on their way to school, then at ten thirty, that's break time. It's like it was timed, you know? So you'd get maximum kids out in the open, visible to everyone.", 'I suppose.']|
#
# ----------SENT 44090 @2---------
# TEXT: |['Some sort of neural control implant, I imagine. I always thought the Sontarans used hypnosis to control their drones.', 'What, is he dangerous?']|
# MEAN CONF TOP100: 1.235913634300232
#
# -- 44090 range D0 0-1, mean conf: 1.5027680397033691--
# rank 2, conf: 1.5027680397033691
# sent 44089: |['Some sort of neural control implant, I imagine. I always thought the Sontarans used hypnosis to control their drones.', 'What, is he dangerous?']|
#
# -- 44090 range D1 1-10, mean conf: 1.347191333770752--
# rank 7, conf: 1.3600714206695557
# sent 577773: |['I thought you said the Vulcans were opposed to this.', 'They are. but we agreed to make a few compromises.']|
#
# -- 44090 range D2 10-20, mean conf: 1.286086082458496--
# rank 19, conf: 1.2804358005523682
# sent 50770: |['I thought if I learnt how to manipulate it, I could control the volcano.', "Not from here, you won't."]|
#
# -- 44090 range D3 20-30, mean conf: 1.2446444034576416--
# rank 22, conf: 1.2624496221542358
# sent 132861: |['I thought Marines looked after their own?', 'How does a homeless man get past the security agents, local cops, hotel staff, into a locked-down building?']|
#
# -- 44090 range D4 30-60, mean conf: 1.2166517972946167--
# rank 32, conf: 1.2274665832519531
# sent 801372: |['Sons used to idolize their fathers.', 'Us old timers need to stick together. And how better than by signing a contract?']|
#
# ----------SENT 955438 @3---------
# TEXT: |['Well, I know that. And I know this is important to Ryan.', 'So important.']|
# MEAN CONF TOP100: 1.1993223428726196
#
# -- 955438 range D0 0-1, mean conf: 1.1996408700942993--
# rank 1, conf: 1.1996408700942993
# sent 313758: |['Artie. All I know is Artie.', 'Artie. Okay, well let’s talk about ELIZABETH and Artie. Now,']|
#
# -- 955438 range D1 1-10, mean conf: 1.1996407508850098--
# rank 4, conf: 1.1996408700942993
# sent 296890: |["Look, I know that we can't say anything until you do the tissue markers and we go through channels, but, I'm telling you, I know this is Kristen.", 'Poor Ted.']|
#
# -- 955438 range D2 10-20, mean conf: 1.1996406316757202--
# rank 12, conf: 1.1996407508850098
# sent 180297: |["Martha, you know it's not the same.", "I know nothing is black or white, especially in politics. If you win this election, you'll be able to help so many people who desperately need it. Please don't let your pride get in the way."]|
#
# -- 955438 range D3 20-30, mean conf: 1.1996406316757202--
# rank 30, conf: 1.1996407508850098
# sent 355816: |["I think she took it pretty well. You know Paolo's over there right now, so...", "We should get over there and see if she's okay."]|
#
# -- 955438 range D4 30-60, mean conf: 1.1996408700942993--
# rank 50, conf: 1.1996407508850098
# sent 970950: |["I know, Dawson...it's just..", "I was taking your advice. You know, you don't think...do. Just something really spontaneous."]|
#
# ----------SENT 593096 @4---------
# TEXT: |['I am the one responsible for the deaths in the computer core.', 'We know who you are.']|
# MEAN CONF TOP100: 1.0939476490020752
#
# -- 593096 range D0 0-1, mean conf: 1.1888492107391357--
# rank 2, conf: 1.1888492107391357
# sent 635017: |["Acknowledged. I'm downloading the logs into the Engineering computer core.", "This data describes literally every cubic centimetre in this sector. It's over five billion gigaquads of information."]|
#
# -- 593096 range D1 1-10, mean conf: 1.152723789215088--
# rank 9, conf: 1.14252507686615
# sent 560506: |["HG reprogrammed your nanobots. They're manufacturing more parts of him. They're flooding your systems, Rommie.", "We need to contact HG and find out why he's doing this. There's only one way to do that."]|
#
# -- 593096 range D2 10-20, mean conf: 1.125153660774231--
# rank 15, conf: 1.1276888847351074
# sent 376617: |["The lock on the door— looks new Someone cut it open. Well, if they haven't started work on the house yet... All the power tools are missing.", "What's there?"]|
#
# -- 593096 range D3 20-30, mean conf: 1.108487844467163--
# rank 27, conf: 1.1076147556304932
# sent 43113: |["Ah, Doctor! I understand from Major Green you're a specialist in computer development.", "Well, hardly a specialist, sir, but I dabble, yes, I dabble. Oh, so that's what it is."]|
#
# -- 593096 range D4 30-60, mean conf: 1.0896680355072021--
# rank 36, conf: 1.1007717847824097
# sent 643232: |['Harper, where are those engines?', "I'm working on it, you big"]|
#
# ----------SENT 560116 @5---------
# TEXT: |["Excuse me. After the number of scrapes we've been through, it's a wonder she's working at all.", "Don't worry, Rommie. As soon as we dock at El Dorado Drift, we'll pick up parts and you'll be as good as new."]|
# MEAN CONF TOP100: 1.0681811571121216
#
# -- 560116 range D0 0-1, mean conf: 1.0681813955307007--
# rank 1, conf: 1.0681813955307007
# sent 309015: |["Nothing, nothing. As long as it's working for you.", 'Oh, it is. Definitely.']|
#
# -- 560116 range D1 1-10, mean conf: 1.0681813955307007--
# rank 10, conf: 1.0681813955307007
# sent 768966: |["It's your wireless mic, dude. It's not working.", 'Well, did somebody touch it? Because it was working before.']|
#
# -- 560116 range D2 10-20, mean conf: 1.0681812763214111--
# rank 16, conf: 1.0681812763214111
# sent 33470: |["It's not working.", "Sky, don't let them use you."]|
#
# -- 560116 range D3 20-30, mean conf: 1.0681812763214111--
# rank 27, conf: 1.0681812763214111
# sent 62530: |["It's working?", 'Yes.']|
#
# -- 560116 range D4 30-60, mean conf: 1.0681813955307007--
# rank 57, conf: 1.0681812763214111
# sent 155966: |["It's not working? You lied to me, Clark.", "No, I didn't."]|
#
# ----------SENT 917115 @6---------
# TEXT: |['Oh, look how cute your little doggy is.', 'Yeah, well, I wouldn’t get too close. If I give the right command in German, she’ll rip your face off.']|
# MEAN CONF TOP100: 1.055978775024414
#
# -- 917115 range D0 0-1, mean conf: 1.055978775024414--
# rank 1, conf: 1.055978775024414
# sent 986781: |["Hmm, sounds hot. What's he look like?", "Ah, come on, that's not important."]|
#
# -- 917115 range D1 1-10, mean conf: 1.055978775024414--
# rank 3, conf: 1.055978775024414
# sent 1002066: |["What's he look like?", "I really didn't pay much attention, I'd just come from buying a speedboat."]|
#
# -- 917115 range D2 10-20, mean conf: 1.055978775024414--
# rank 19, conf: 1.055978775024414
# sent 972623: |["Look, it's not like that.", "Then how was it? 'Cause Jen was short on details."]|
#
# -- 917115 range D3 20-30, mean conf: 1.055978775024414--
# rank 31, conf: 1.055978775024414
# sent 1022384: |["Ah, look who's here.", "I'm sorry."]|
#
# -- 917115 range D4 30-60, mean conf: 1.055978775024414--
# rank 37, conf: 1.055978775024414
# sent 345522: |['I can’t believe she’s really gone. Look around you, all of this is ours.', 'I don’t think so.']|
#
# ----------SENT 571095 @7---------
# TEXT: |["I'm sorry, Jim. The boy's unconscious, but he's still alive.", 'Peter?']|
# MEAN CONF TOP100: 1.054368495941162
#
# -- 571095 range D0 0-1, mean conf: 1.0544922351837158--
# rank 1, conf: 1.0544922351837158
# sent 77043: |["Did you indeed? And what's the old boy like?", "Well, that's just it. I got her address from the secretary, 76 Totter's Lane, and I went along there one evening. Oh Ian, do pay attention."]|
#
# -- 571095 range D1 1-10, mean conf: 1.0544922351837158--
# rank 5, conf: 1.0544922351837158
# sent 94299: |["He's just a boy.", 'Have you seen your son recently? You have to let him make his own mind up.']|
#
# -- 571095 range D2 10-20, mean conf: 1.0544922351837158--
# rank 16, conf: 1.0544922351837158
# sent 1013023: |["Okay, where's my boy?", 'Oh my God.']|
#
# -- 571095 range D3 20-30, mean conf: 1.0544922351837158--
# rank 26, conf: 1.0544922351837158
# sent 1027541: |["That's your big boy.", 'Can I have a bite?']|
#
# -- 571095 range D4 30-60, mean conf: 1.0544923543930054--
# rank 46, conf: 1.0544921159744263
# sent 129244: |["Where's the boy?", 'In his room.']|
#
# ----------SENT 486204 @8---------
# TEXT: |["Millie, he's amused by her.", "So, I don't want a guy who's amused by someone like that."]|
# MEAN CONF TOP100: 1.0426549911499023
#
# -- 486204 range D0 0-1, mean conf: 1.042678952217102--
# rank 2, conf: 1.042678952217102
# sent 697322: |["He's a Rhodes scholar.", 'Ask him where the anvils went. …Or not.']|
#
# -- 486204 range D1 1-10, mean conf: 1.0426609516143799--
# rank 3, conf: 1.042664885520935
# sent 691135: |["Don't listen to him. Alex is an incredible businessman.", 'Ah.']|
#
# -- 486204 range D2 10-20, mean conf: 1.0426548719406128--
# rank 19, conf: 1.042654037475586
# sent 348138: |["Hey. Where's Joey?", 'Joey ate my last stick of gum, so I killed him. Do you think that was wrong?']|
#
# -- 486204 range D3 20-30, mean conf: 1.0426539182662964--
# rank 26, conf: 1.0426539182662964
# sent 662977: |["This guy is brilliant. He's nearly doubled the size of the Drago-Kasov fleet in less than two years. Dylan, he's dangerous.", "And after my little excursion to Enga's Redoubt, it's best if Cuchulain never learns of my presence here. I advise extreme caution."]|
#
# -- 486204 range D4 30-60, mean conf: 1.0426539182662964--
# rank 36, conf: 1.0426539182662964
# sent 127352: |["It's over, Abby.", "Not until he finds another loophole to crawl out of. He will. You don't know him."]|
#
# ----------SENT 996921 @9---------
# TEXT: |['I\'m writin\' it. "How\'s it going?"', 'Okay..']|
# MEAN CONF TOP100: 1.0280719995498657
#
# -- 996921 range D0 0-1, mean conf: 1.0280721187591553--
# rank 1, conf: 1.0280721187591553
# sent 776769: |["Nothing. How's it going?", 'Fine. Are you all right?']|
#
# -- 996921 range D1 1-10, mean conf: 1.0280719995498657--
# rank 2, conf: 1.0280719995498657
# sent 1021324: |["Elaine, you should get out of there. I sabotaged the bagel machine last night. It's going down.", 'What did you do?']|
#
# -- 996921 range D2 10-20, mean conf: 1.0280721187591553--
# rank 14, conf: 1.0280719995498657
# sent 817128: |["Yo. I got the Nard-puppy for ya. What's going on here?", "It's a baby game where you guess whose picture is whose."]|
#
# -- 996921 range D3 20-30, mean conf: 1.0280721187591553--
# rank 24, conf: 1.0280719995498657
# sent 833259: |["Was there a problem?Did you find her? What's going on?", 'Isobel?']|
#
# -- 996921 range D4 30-60, mean conf: 1.0280721187591553--
# rank 51, conf: 1.0280719995498657
# sent 761209: |["Hey, how's it going?", "Uh, just washing Rory's car."]|
#
# ----------SENT 374722 @10---------
# TEXT: |['Mm. She turned me into a real artist. Before I met her, I was taking snapshots.', "Mr. Banks, we're gonna need to talk to your daughter."]|
# MEAN CONF TOP100: 1.0264352560043335
#
# -- 374722 range D0 0-1, mean conf: 1.094208002090454--
# rank 2, conf: 1.094208002090454
# sent 840921: |["I'm Sloan, and you met some of the Travelers when they were taking a bucket of your blood", 'Oh, yeah. How could I forget? So, you have the antidote to this ripper virus, correct?']|
#
# -- 374722 range D1 1-10, mean conf: 1.0723493099212646--
# rank 4, conf: 1.0766575336456299
# sent 190439: |['She sounded like she was taking that awful seriously.', 'Oh, the truth!']|
#
# -- 374722 range D2 10-20, mean conf: 1.0628116130828857--
# rank 13, conf: 1.0633840560913086
# sent 577857: |['Why were you taking Klaang home?', 'You know, under different circumstances, I might be flattered by this, but.']|
#
# -- 374722 range D3 20-30, mean conf: 1.0537805557250977--
# rank 24, conf: 1.0563313961029053
# sent 335963: |["Okay, I'm sorry! I'm sorry! I-I-I was um, I was taking a nap.", 'Since when do take naps in that position. Oh God Monica, tell me you were waiting for a guy! Please tell me you were waiting for a guy!']|
#
# -- 374722 range D4 30-60, mean conf: 1.0267997980117798--
# rank 38, conf: 1.0400488376617432
# sent 402265: |["I-I ... that's a ... I am not the one that should be here. You should be talking to the man that took Jesse.", 'Did Jesse get sick? Was there an accident?']|
#
# ----------SENT 902085 @11---------
# TEXT: |['I say we begin with a classic Star Trek fight scene.', 'I’ll set the timer.']|
# MEAN CONF TOP100: 1.0205528736114502
#
# -- 902085 range D0 0-1, mean conf: 1.1428050994873047--
# rank 2, conf: 1.1428050994873047
# sent 226688: |['Actually, I just got "Death Kill City Two: Death Kill Stories".', 'Whoa! You\'ve got "D.K.C.2.D.K.S."? That one\'s rated "Bad For Everyone"!']|
#
# -- 902085 range D1 1-10, mean conf: 1.0936942100524902--
# rank 3, conf: 1.1137943267822266
# sent 515509: |["First we visit Tree Trunks for apple pie, and then we go to Bubblegum's science music thing!", 'Wait, what about the movie at the drive-in?']|
#
# -- 902085 range D2 10-20, mean conf: 1.0729737281799316--
# rank 15, conf: 1.0761529207229614
# sent 394877: |['We call it a "fight bite."', 'Human mouths are full of bacteria. A wound from a human bite is a tremendous source of infection, unfortunately.']|
#
# -- 902085 range D3 20-30, mean conf: 1.0423164367675781--
# rank 31, conf: 1.0322580337524414
# sent 917703: |['Okay, here we go. Episode I: The Phantom Menace.', 'Ugh, let’s get this over with.']|
#
# -- 902085 range D4 30-60, mean conf: 1.0133488178253174--
# rank 39, conf: 1.0223596096038818
# sent 270952: |['Ahh. Sounds like Ozzie and Harriet.', 'More like The Shining.']|
#
# ----------SENT 888560 @12---------
# TEXT: |['Excuse me. Sheldon, we both agreed to do this.', 'It’s a waste of time. I might as well explain the laws of thermodynamics to a bunch of labradoodles.']|
# MEAN CONF TOP100: 1.0053536891937256
#
# -- 888560 range D0 0-1, mean conf: 1.013192892074585--
# rank 2, conf: 1.013192892074585
# sent 350775: |['Oh yeah, Emily convinced me to do it.', 'You do know that Wham broke up?']|
#
# -- 888560 range D1 1-10, mean conf: 1.0075526237487793--
# rank 9, conf: 1.0070892572402954
# sent 56190: |["That's funny. Skagra threatened to do that to me too.", 'Skagra?']|
#
# -- 888560 range D2 10-20, mean conf: 1.0054280757904053--
# rank 16, conf: 1.0053186416625977
# sent 1006480: |['George, do me a solid? Two minutes.', "Well, I'm going with him. I'd like to... I've never done a 'solid' before."]|
#
# -- 888560 range D3 20-30, mean conf: 1.004994511604309--
# rank 28, conf: 1.004994511604309
# sent 1058065: |["Chris, don't!", "You don't know me."]|
#
# -- 888560 range D4 30-60, mean conf: 1.0049941539764404--
# rank 46, conf: 1.0049943923950195
# sent 836791: |["Elena, don't.", 'Because you decided to stop the spell that could bring him back. My friend that owes me.']|
#
# ----------SENT 298190 @13---------
# TEXT: |["What do you mean, you don't believe in luck? Okay, well, how do you explain when good things happen out of nowhere?", 'Define "good things."']|
# MEAN CONF TOP100: 0.9973718523979187
#
# -- 298190 range D0 0-1, mean conf: 1.0751430988311768--
# rank 2, conf: 1.0751430988311768
# sent 630781: |["Yes, but you do know better. Androids don't feel such things.", "I don't know. Sometimes I think he's becoming more human than any of us realise."]|
#
# -- 298190 range D1 1-10, mean conf: 1.0330746173858643--
# rank 11, conf: 1.0212647914886475
# sent 48264: |['How do you know all these things?', 'Ah. That would be rather difficult to explain.']|
#
# -- 298190 range D2 10-20, mean conf: 1.020306944847107--
# rank 17, conf: 1.0203273296356201
# sent 445096: |['The things you do in the dark? They have consequences.', "But, no one's saying that what happened was OK, T. I think, maybe you, you might be a little overjudgmental."]|
#
# -- 298190 range D3 20-30, mean conf: 1.017561912536621--
# rank 26, conf: 1.017669439315796
# sent 981748: |['Things never change here, do they?', 'No... because these are the roles we were destined to play.']|
#
# -- 298190 range D4 30-60, mean conf: 0.9991129040718079--
# rank 42, conf: 1.0042524337768555
# sent 1070351: |['I feel for you, kiddie, really do.', 'Gary.']|
#
# ----------SENT 315381 @14---------
# TEXT: |['She may have been conscious for some time after the assault.', "But there's no sign of bone remodeling. She died soon after the assault."]|
# MEAN CONF TOP100: 0.9924794435501099
#
# -- 315381 range D0 0-1, mean conf: 1.0326124429702759--
# rank 2, conf: 1.0326124429702759
# sent 878884: |["The test was irrelevant. We've been tracking you for some time.", 'Is that a good thing?']|
#
# -- 315381 range D1 1-10, mean conf: 1.0315738916397095--
# rank 7, conf: 1.0315264463424683
# sent 136660: |["And you've been in there all this time?", 'I have a ... a gastrointestinal challenge.']|
#
# -- 315381 range D2 10-20, mean conf: 1.0308153629302979--
# rank 14, conf: 1.0315263271331787
# sent 520123: |["Yeah, we're ready for him. We've been ready for a long time.", "You're gonna get yourself killed. That's not a threat, it's a fact."]|
#
# -- 315381 range D3 20-30, mean conf: 1.0257277488708496--
# rank 28, conf: 1.0267515182495117
# sent 750889: |["She'd been ill for some time, but still...", 'The family is pretty overwhelmed.']|
#
# -- 315381 range D4 30-60, mean conf: 0.9981195330619812--
# rank 59, conf: 0.9719884991645813
# sent 646414: |["Reconciliation with the Gatherers is impossible. It's been tried. Every time we've offered amnesty, they've rejected it.", 'When was the last attempt made?']|
#
# ----------SENT 648832 @15---------
# TEXT: |['On Talax, fighting with the defence forces.', "I was on Talax, but I wasn't fighting with the defence forces. I was hiding from them. I wasn't a hero at the battle of the Pyrithian Gorge. I've never even been there."]|
# MEAN CONF TOP100: 0.9310899376869202
#
# -- 648832 range D0 0-1, mean conf: 0.9979891777038574--
# rank 2, conf: 0.9979891777038574
# sent 470282: |['You and Haley fighting?', 'My problem is with anybody who just vanishes and then waltzes back in and expects to be instantly forgiven']|
#
# -- 648832 range D1 1-10, mean conf: 0.9857184886932373--
# rank 7, conf: 0.9804026484489441
# sent 736867: |['Lorelai and Luke are fighting.', "We're not fighting."]|
#
# -- 648832 range D2 10-20, mean conf: 0.9606830477714539--
# rank 20, conf: 0.9561901688575745
# sent 976273: |["I'm not quite following you here Pacey.", 'I got the girl this time, Dawson.']|
#
# -- 648832 range D3 20-30, mean conf: 0.933659553527832--
# rank 29, conf: 0.929075300693512
# sent 936567: |["Cohen, you're acting really weird.", "I feel weird, you know? Maybe whatever my mom has is contagious, and I'd hate for you to catch it and feel weird, too. You know?"]|
#
# -- 648832 range D4 30-60, mean conf: 0.9227522611618042--
# rank 46, conf: 0.9218693971633911
# sent 682774: |['So Lorelai, are you a member of the DAR?', "No, I'm not. D-A-R-N."]|
#
# ----------SENT 93878 @16---------
# TEXT: |['With great skill. Can I ask you something?', 'Yes, of course. Anything.']|
# MEAN CONF TOP100: 0.9153657555580139
#
# -- 93878 range D0 0-1, mean conf: 0.9725698828697205--
# rank 2, conf: 0.9725698828697205
# sent 716017: |["That's great. Can I ask you something?", 'Of course you can.']|
#
# -- 93878 range D1 1-10, mean conf: 0.9725698828697205--
# rank 7, conf: 0.9725698828697205
# sent 985199: |['Hi. Can I ask you something?', 'Yeah. Sure. But, um... I should lay the ground rules here, I will not, under any circumstances, play Limp Bizkit. Just so you know. Ok?']|
#
# -- 93878 range D2 10-20, mean conf: 0.9725697636604309--
# rank 16, conf: 0.9725698232650757
# sent 703242: |['So can I ask you something?', 'Sure.']|
#
# -- 93878 range D3 20-30, mean conf: 0.9725697636604309--
# rank 23, conf: 0.9725698232650757
# sent 773460: |['Can I ask you something?', "Sure, but I have to be honest with you, Liz. At this point, I don't think I have any secrets left."]|
#
# -- 93878 range D4 30-60, mean conf: 0.9236739277839661--
# rank 48, conf: 0.9203864932060242
# sent 273569: |["Shouldn't she ask for my permission or something?", 'Y-you want her to ask for my hand?']|
#
# ----------SENT 810840 @17---------
# TEXT: |["I mean, I guess he'd be okay with hair. Okay, you should see if he'll get hair plugs.", "I don't think Jim cares about his hair."]|
# MEAN CONF TOP100: 0.9070791602134705
#
# -- 810840 range D0 0-1, mean conf: 0.9953010082244873--
# rank 2, conf: 0.9953010082244873
# sent 790627: |["How'd you get gum in your hair?", "I was walking in and I noticed something shinny under Stanley's car and I got under to see what it was and I messed up my hair, all for a stupid piece of tinfoil."]|
#
# -- 810840 range D1 1-10, mean conf: 0.9798052906990051--
# rank 10, conf: 0.9556530714035034
# sent 710060: |['Go get me the hair spray.', 'OK.']|
#
# -- 810840 range D2 10-20, mean conf: 0.9360268712043762--
# rank 17, conf: 0.928813636302948
# sent 194235: |["Now don't worry. You'll get to see it just as soon as we unveil our new ad campaign.", 'Let me see! Let me see! Out of the way!']|
#
# -- 810840 range D3 20-30, mean conf: 0.9250099062919617--
# rank 28, conf: 0.9217067956924438
# sent 17567: |["You could get torn into pieces by a monster you can't see.", "Oh right, yes, that. Don't worry. I'll be back before you can say where's he got to now? Not that fast! But pretty fast. See you around."]|
#
# -- 810840 range D4 30-60, mean conf: 0.896124541759491--
# rank 40, conf: 0.8949610590934753
# sent 292841: |["Our gang unit's gonna bring in the leader of Mara Muerte, see if we can identify the gangbanger that got away.", 'Why would a gang leader cooperate?']|
#
# ----------SENT 811893 @18---------
# TEXT: |['I knew it.', 'Oh, doggie.']|
# MEAN CONF TOP100: 0.9008305668830872
#
# -- 811893 range D0 0-1, mean conf: 0.9008306264877319--
# rank 1, conf: 0.9008306264877319
# sent 923346: |['He hardly knew them.', 'Let us hear that from him.']|
#
# -- 811893 range D1 1-10, mean conf: 0.9008305668830872--
# rank 7, conf: 0.9008306264877319
# sent 647908: |["I think you'd be better at something like that. Or Beverly. She knew him the longest.", "I know it's not going to be easy, but I think it's important that we face up to what's happened. You're in command now. The crew's looking to you for guidance."]|
#
# -- 811893 range D2 10-20, mean conf: 0.9008305668830872--
# rank 16, conf: 0.9008305668830872
# sent 244086: |['I knew he would.', "I'll be right back, boys. I'm going to go help that lady."]|
#
# -- 811893 range D3 20-30, mean conf: 0.9008305668830872--
# rank 28, conf: 0.9008305668830872
# sent 392209: |['But you already knew that.', 'I know what happened to Wendy.']|
#
# -- 811893 range D4 30-60, mean conf: 0.9008306860923767--
# rank 48, conf: 0.9008305668830872
# sent 480736: |['I knew it.', "Too much sugar? Ok, I've seen you eat 5 balls of Count Chocula in one sitting."]|
#
# ----------SENT 604747 @19---------
# TEXT: |["Get rid of the android. We'll have some fun.", 'Is there a problem here?']|
# MEAN CONF TOP100: 0.8771592974662781
#
# -- 604747 range D0 0-1, mean conf: 0.9429536461830139--
# rank 1, conf: 0.9429536461830139
# sent 267853: |["I didn't mind. I liked that you were watching me. Come on, Sammy. You and I can still have a little dirty fun.", "You wanna have fun? Go ahead then. I'm a little tied up right now."]|
#
# -- 604747 range D1 1-10, mean conf: 0.9429535269737244--
# rank 9, conf: 0.9429535865783691
# sent 250474: |['Maybe you can have fun with just me.', 'Okay, why not?']|
#
# -- 604747 range D2 10-20, mean conf: 0.9416016340255737--
# rank 14, conf: 0.9429535269737244
# sent 717050: |['We can have our own fun.', "I can't miss the winter carnival."]|
#
# -- 604747 range D3 20-30, mean conf: 0.8915945291519165--
# rank 22, conf: 0.9299564957618713
# sent 636804: |["Well, the galaxy doesn't stand a chance. Now, promise me that you're going to be careful over there. No stopping to have fun.", 'Fun? On a Malon freighter?']|
#
# -- 604747 range D4 30-60, mean conf: 0.8638500571250916--
# rank 34, conf: 0.8652682900428772
# sent 259606: |["Well, I'm actually going to find the ship and put an end to this. But you have fun.", "Hey, Bela, how'd you get like this, huh? What, did daddy not give you enough hugs or something?"]|
#
# ----------SENT 383524 @20---------
# TEXT: |['Wh-What? You went without me?', 'You were looking up curse words in the dictionary. It seemed like a better use of your time.']|
# MEAN CONF TOP100: 0.8694323301315308
#
# -- 383524 range D0 0-1, mean conf: 0.869432270526886--
# rank 1, conf: 0.869432270526886
# sent 329211: |['I know, I know. I went a little crazy.', 'A little? Your place looks like page 72 of the catalogue. Oh look at that! The ornamental bird cage! Large!']|
#
# -- 383524 range D1 1-10, mean conf: 0.8694322109222412--
# rank 2, conf: 0.869432270526886
# sent 706569: |["Good. It's good you went over.", 'But then I went to see Rory.']|
#
# -- 383524 range D2 10-20, mean conf: 0.869432270526886--
# rank 11, conf: 0.8694322109222412
# sent 941962: |['Hey. Your mom left, huh? It went well?', 'Yeah, really well.']|
#
# -- 383524 range D3 20-30, mean conf: 0.869432270526886--
# rank 27, conf: 0.8694322109222412
# sent 684634: |['No, he just went out.', "You didn't ask him where he was going?"]|
#
# -- 383524 range D4 30-60, mean conf: 0.869432270526886--
# rank 47, conf: 0.8694322109222412
# sent 1070818: |['You went on!', 'Right. So will you.']|
#
# ----------SENT 599916 @21---------
# TEXT: |['We were hit by some kind of shockwave.', 'Source?']|
# MEAN CONF TOP100: 0.8651376366615295
#
# -- 599916 range D0 0-1, mean conf: 0.9498580098152161--
# rank 2, conf: 0.9498580098152161
# sent 98648: |["I don't know. But there was definitely some kind of struggle.", 'With who?']|
#
# -- 599916 range D1 1-10, mean conf: 0.9474303722381592--
# rank 4, conf: 0.9477509260177612
# sent 233997: |['Of course. It was, uh... some kind of a... light rail.', "There's no light rail in Springfield."]|
#
# -- 599916 range D2 10-20, mean conf: 0.9429959058761597--
# rank 12, conf: 0.9467089176177979
# sent 119880: |['Actually, an off-base Navy lodging facility. Used mostly by TDY personnel and visiting family. Apparently there was some kind of bloodbath.', "Mondays. What's the body count?"]|
#
# -- 599916 range D3 20-30, mean conf: 0.926627516746521--
# rank 22, conf: 0.9377840161323547
# sent 615452: |["I understand your passion, but passion alone doesn't give you the right to take matters into your own hands. Four years ago, I released you from prison and gave you a fresh start. Until now, you've been a fine officer. Your service on this ship has been exemplary. I really believed you were past this kind of conduct.", "I've never been very good at playing by the rules. That doesn't mean that serving under your command hasn't changed me, for the better. At least this time, I broke the rules for a reason. For something I believed in."]|
#
# -- 599916 range D4 30-60, mean conf: 0.8533384799957275--
# rank 52, conf: 0.8412352204322815
# sent 393043: |['Picked up a hint of some kind of booze.', 'Call me when you get the results.']|
#
# ----------SENT 893529 @22---------
# TEXT: |['You, you want to rub something on my chest?', 'Yes. All over it.']|
# MEAN CONF TOP100: 0.8589304685592651
#
# -- 893529 range D0 0-1, mean conf: 0.92291659116745--
# rank 2, conf: 0.92291659116745
# sent 1013257: |['So, you want a protein shake, or something?', "Nah, I guess I should really get moving on this, huh? I'm gonna go."]|
#
# -- 893529 range D1 1-10, mean conf: 0.9184948801994324--
# rank 8, conf: 0.9175359010696411
# sent 187208: |['Because you want something from me. Everyone does.', "Do I want something from you...? Yeah, Davina, actually I do. Thanks to your friend Marcel, most of my family is cursed. They're stuck in their wolf form, except on a full moon. Now, I'm smart enough to know that every curse has a loophole. And, well, you're the strongest witch I've ever heard of. But I wouldn't lie to you to get what I want. I'd ask you. I guess that's the difference between Marcel and me."]|
#
# -- 893529 range D2 10-20, mean conf: 0.9168489575386047--
# rank 12, conf: 0.9175359010696411
# sent 430151: |['You want something? You gotta give something!', 'Well, how about a big warm hug from a grateful pony friend?']|
#
# -- 893529 range D3 20-30, mean conf: 0.8891156911849976--
# rank 25, conf: 0.9041972756385803
# sent 850195: |['I know how this game works. You want something in return.', 'Just your support.']|
#
# -- 893529 range D4 30-60, mean conf: 0.8545766472816467--
# rank 46, conf: 0.8523905873298645
# sent 1016367: |['Is that something you want to do?', "I don't know. Those writers make a lot of money."]|
#
# ----------SENT 989946 @23---------
# TEXT: |['He told you?', 'Yeah.']|
# MEAN CONF TOP100: 0.8568706512451172
#
# -- 989946 range D0 0-1, mean conf: 0.8568705916404724--
# rank 1, conf: 0.8568705916404724
# sent 701007: |['I told you.', 'And, um, how was your, uh, date with Robert?']|
#
# -- 989946 range D1 1-10, mean conf: 0.8568705916404724--
# rank 5, conf: 0.8568705916404724
# sent 1030957: |['No. She told us not to.', "So, let her be pissed at us, at least she'll be alive."]|
#
# -- 989946 range D2 10-20, mean conf: 0.8568705320358276--
# rank 11, conf: 0.8568705320358276
# sent 542666: |["I was aware she'd been a Borg. She told me herself.", 'Did you ever express curiosity in that technology, or try to examine it more closely?']|
#
# -- 989946 range D3 20-30, mean conf: 0.8568705320358276--
# rank 21, conf: 0.8568705320358276
# sent 52081: |[']So lonely. I saw this. I saw this future. My future. And I told myself', "I Won't let that happen."]|
#
# -- 989946 range D4 30-60, mean conf: 0.8568705320358276--
# rank 40, conf: 0.8568705320358276
# sent 254163: |['Who told you about those?', 'A talking tree in a commercial.']|
#
# ----------SENT 622734 @24---------
# TEXT: |["He was a very wise man. More than anyone, he shaped the person I am. If it hadn't been for him I would have never questioned my people's beliefs. I would have never left our city. I would never have met all of you.", 'Then we owe him a debt. It is difficult to imagine this journey without you.']|
# MEAN CONF TOP100: 0.8471084237098694
#
# -- 622734 range D0 0-1, mean conf: 0.8706649541854858--
# rank 1, conf: 0.8706649541854858
# sent 167143: |["We've already met.", "I seriously doubt I'd forget meeting you."]|
#
# -- 622734 range D1 1-10, mean conf: 0.8706649541854858--
# rank 2, conf: 0.8706649541854858
# sent 969291: |["I'm Joey. I live down the creek and we've never met...ever.", 'So, Jen are you just visiting?']|
#
# -- 622734 range D2 10-20, mean conf: 0.8706647753715515--
# rank 15, conf: 0.8706648945808411
# sent 429982: |["Technically, we've already met.", 'You?!']|
#
# -- 622734 range D3 20-30, mean conf: 0.8706647753715515--
# rank 31, conf: 0.8706648349761963
# sent 47741: |["We've met.", 'Are you an Earthling?']|
#
# -- 622734 range D4 30-60, mean conf: 0.8485998511314392--
# rank 54, conf: 0.8323850035667419
# sent 32621: |["If we'd never met you, we would have been stuffed.", "If you'd never met me, and got grounded by the Judoon, you wouldn't have been in danger in the first place."]|
#
# ----------SENT 767731 @25---------
# TEXT: |['Micehel, good! Listen, emergency, can you --', 'You are not going to believe this.']|
# MEAN CONF TOP100: 0.8215112686157227
#
# -- 767731 range D0 0-1, mean conf: 0.8308170437812805--
# rank 2, conf: 0.8308170437812805
# sent 108395: |['Listen to the live feed? I want to help my mommy, Agent Gibbs. I can take it.', 'Here.']|
#
# -- 767731 range D1 1-10, mean conf: 0.8258911967277527--
# rank 9, conf: 0.8235765695571899
# sent 423542: |["What?! No! They'd sooner launch their dinners at us than listen to us.", "Well, they'll listen to me. I'm an impartial third party."]|
#
# -- 767731 range D2 10-20, mean conf: 0.8212213516235352--
# rank 15, conf: 0.821147084236145
# sent 823192: |['Listen, she ignored my ultimatum. Now what?', 'Now you move on.']|
#
# -- 767731 range D3 20-30, mean conf: 0.8209311366081238--
# rank 22, conf: 0.8209311366081238
# sent 575081: |["But if she won't listen to me", 'Then make her listen, Ambassador. Use a different approach. Stop being so diplomatic. She respects strength. Go in strong.']|
#
# -- 767731 range D4 30-60, mean conf: 0.8209310173988342--
# rank 50, conf: 0.820931077003479
# sent 777886: |['Would you just listen to yourself?', "I don't even know where-- to, like, another country or another planet."]|
#
# ----------SENT 153449 @26---------
# TEXT: |["I just spoke to Justin's parents.", "How's he doing?"]|
# MEAN CONF TOP100: 0.8103676438331604
#
# -- 153449 range D0 0-1, mean conf: 1.0486862659454346--
# rank 2, conf: 1.0486862659454346
# sent 735430: |["First Al's Pancake World, and now my parents vow renewal?", "I'm serious. I'm not really their favorite person. They don't really want me there."]|
#
# -- 153449 range D1 1-10, mean conf: 0.9576445817947388--
# rank 8, conf: 0.9440585374832153
# sent 1003944: |['So, were your parents shocked to see the Cadillac?', "Actually, I haven't heard from 'em yet."]|
#
# -- 153449 range D2 10-20, mean conf: 0.8431993722915649--
# rank 12, conf: 0.8613253831863403
# sent 177990: |["LuthorCorp didn't kill Lana's parents.", "Neither did you, son. You can't blame yourself for something you had no control over."]|
#
# -- 153449 range D3 20-30, mean conf: 0.8194842338562012--
# rank 23, conf: 0.8262750506401062
# sent 753347: |['Young Chui works for his father who builds Adventist hospitals. Young Chui will go to college at Loma Linda University. Then he will return to work for his father building Adventist hospitals. Now, put your coat on. Young Chui and his parents will drive you to Elks Lodge.', 'Mama!']|
#
# -- 153449 range D4 30-60, mean conf: 0.793875515460968--
# rank 44, conf: 0.7968324422836304
# sent 102630: |['The beast of Gevaudan. Listen. "A quadruped wolf - like monster, prowling the Auvergne and south Dordogne areas of France during the year 1764 to 1767. La Bete killed over a hundred people, becoming so infamous that the King Louie the 15th sent one of his best hunters to try and kill it."', 'Boring.']|
#
# ----------SENT 638997 @27---------
# TEXT: |['Not by anything?', 'No.']|
# MEAN CONF TOP100: 0.7680253386497498
#
# -- 638997 range D0 0-1, mean conf: 0.7689082026481628--
# rank 1, conf: 0.7689082026481628
# sent 417715: |['Yeah, anything interesting?', "Numerous calls from Eiger's house to Sy Magli's office."]|
#
# -- 638997 range D1 1-10, mean conf: 0.7689082026481628--
# rank 3, conf: 0.7689082026481628
# sent 999129: |["Can I get'ca anything else?", 'Oh, no thanks.']|
#
# -- 638997 range D2 10-20, mean conf: 0.7689081430435181--
# rank 12, conf: 0.7689081430435181
# sent 300336: |['Okay, anything else?', "There also appears to be something that catches on the bone as it's pulled back, like a hook near the blade's point."]|
#
# -- 638997 range D3 20-30, mean conf: 0.7689081430435181--
# rank 29, conf: 0.7689081430435181
# sent 708415: |['Hey, anything good?', "Um, here's one that comes loaded with an entertainment pkg."]|
#
# -- 638997 range D4 30-60, mean conf: 0.7688904404640198--
# rank 37, conf: 0.7689081430435181
# sent 1063526: |['No, I got it. Unless youwant anything else.', 'Yeah, I do.']|
#
# ----------SENT 419413 @28---------
# TEXT: |['Like a spear, or a pipe of some kind?', 'Perhaps.']|
# MEAN CONF TOP100: 0.7624743580818176
#
# -- 419413 range D0 0-1, mean conf: 0.7637609243392944--
# rank 2, conf: 0.7637609243392944
# sent 202690: |['I, uh, was never president. I invented some kind of stove.', 'Well, I invented a Popsicle made of Mountain Dew.']|
#
# -- 419413 range D1 1-10, mean conf: 0.7632944583892822--
# rank 11, conf: 0.7630829215049744
# sent 300124: |['What kind of scars?', 'Well, like he’d been whipped.']|
#
# -- 419413 range D2 10-20, mean conf: 0.7629615068435669--
# rank 15, conf: 0.7630066871643066
# sent 99387: |["I'm starting to think this was a really bad idea. Oh, man. Okay, that one - kind of hurt.", "Quiet. Remember, you're supposed to be thinking about your heart rate, all right? About staying calm."]|
#
# -- 419413 range D3 20-30, mean conf: 0.7627016305923462--
# rank 26, conf: 0.7626917958259583
# sent 310969: |["It's dry. This is a good watch. Some kind of residue.", 'Could it help ID the poison?']|
#
# -- 419413 range D4 30-60, mean conf: 0.7623952627182007--
# rank 33, conf: 0.7626450657844543
# sent 391565: |["And for what? Some kind of cheap laugh? That's not what F-A-R-T is all about.", 'No, sir! Not us FARTers.']|
#
# ----------SENT 983202 @29---------
# TEXT: |["Sorry. Tomorrow I'm turnin' in my helmet.", "Jack, you can't."]|
# MEAN CONF TOP100: 0.7538232803344727
#
# -- 983202 range D0 0-1, mean conf: 0.7657544016838074--
# rank 2, conf: 0.7657544016838074
# sent 867519: |["Bev, you look at me. It's not a stupid idea. Tonight, we are queens.", "And we don't care about some stupid, sexist, corporate holiday."]|
#
# -- 983202 range D1 1-10, mean conf: 0.761604905128479--
# rank 4, conf: 0.765727162361145
# sent 536495: |["Later, then. Tonight, when we're alone?", 'Is it serious?']|
#
# -- 983202 range D2 10-20, mean conf: 0.7582696676254272--
# rank 16, conf: 0.75823974609375
# sent 706955: |["I hereby apologize for any accidental Christmas celebrating I may have done. I'm now ready to celebrate Christmas for real.", 'Yeah?']|
#
# -- 983202 range D3 20-30, mean conf: 0.7556388974189758--
# rank 28, conf: 0.7549657225608826
# sent 576728: |['Signals appear random. Perhaps some are beyond our reception capability.', 'Could be a natural radio source newly energised by']|
#
# -- 983202 range D4 30-60, mean conf: 0.7527828216552734--
# rank 46, conf: 0.752265214920044
# sent 946102: |["Yeah, Kirsten warned me about that. You're limited to two a week.", 'Oh! I knew I should have divorced that dame.']|
#
# ----------SENT 772780 @30---------
# TEXT: |["She's bipolar.", "Really? But you're so young."]|
# MEAN CONF TOP100: 0.7463986277580261
#
# -- 772780 range D0 0-1, mean conf: 0.7463986873626709--
# rank 1, conf: 0.7463986873626709
# sent 829384: |["It's pretty messed up though, isn't it?", 'Yep']|
#
# -- 772780 range D1 1-10, mean conf: 0.7463986277580261--
# rank 8, conf: 0.7463986277580261
# sent 246840: |["It's almost like she's alive again.", "What's that, floating mask? Y-You want me to shoot everyone?"]|
#
# -- 772780 range D2 10-20, mean conf: 0.7463985681533813--
# rank 17, conf: 0.7463986277580261
# sent 941431: |['well how is he, is he ok', "I don't know, figured he's outta my life...why get back into it"]|
#
# -- 772780 range D3 20-30, mean conf: 0.7463985681533813--
# rank 27, conf: 0.7463986277580261
# sent 854202: |["Everybody says it's good to change, right? But it's what's good?", 'Who wants to go to the same old bar, sit at the same place and drink the same thing? The same thing! My favorite!']|
#
# -- 772780 range D4 30-60, mean conf: 0.7463986873626709--
# rank 42, conf: 0.7463986277580261
# sent 1016480: |["Right after we get off the phone, then you go and tell her that?! Well, of course she knows it was me who complained! Now I'm responsible for this woman's quitting. Oh, this is unbelievable!", "I know! I screwed up. It's all my fault. Would you call her?"]|
#
# ----------SENT 82629 @31---------
# TEXT: |['This is weird.', "Yeah, says the time travelling nurse. Yeah, er, let's just leave that for now. Come on."]|
# MEAN CONF TOP100: 0.7463986277580261
#
# -- 82629 range D0 0-1, mean conf: 0.7463986277580261--
# rank 1, conf: 0.7463986277580261
# sent 336168: |['What-what is it, what is it?', "Oh my God, it's so huge, but you just have to promise me that you cannot tell anyone."]|
#
# -- 82629 range D1 1-10, mean conf: 0.7463986277580261--
# rank 7, conf: 0.7463986277580261
# sent 1017615: |["well it's too much, it's embarrassing", 'why does she have to chew so many?']|
#
# -- 82629 range D2 10-20, mean conf: 0.7463985681533813--
# rank 18, conf: 0.7463986277580261
# sent 447384: |["I'm nesting, you guys. I wish I could describe what it feels like. It's... it's...", "It's okay, we can use our imaginations, really."]|
#
# -- 82629 range D3 20-30, mean conf: 0.7463985681533813--
# rank 23, conf: 0.7463986277580261
# sent 69595: |["Yes, it is, isn't it.", "All right, now we're in here, what do we do?"]|
#
# -- 82629 range D4 30-60, mean conf: 0.7463986873626709--
# rank 56, conf: 0.7463985681533813
# sent 86837: |['There is no right or wrong. Only what is and what isn’t.', 'I’m serious ... If anyone wants to kill him they can go ahead. In fact, I’ll give them a hand.']|
#
# ----------SENT 546366 @32---------
# TEXT: |['Improvisation is not foremost among my talents.', 'Considering I caught you off guard, I thought your performance was exemplary.']|
# MEAN CONF TOP100: 0.7446541786193848
#
# -- 546366 range D0 0-1, mean conf: 0.7448219656944275--
# rank 2, conf: 0.7448219656944275
# sent 64144: |["Yes, that's what I suspect.", 'Where did you get hold of this?']|
#
# -- 546366 range D1 1-10, mean conf: 0.7447474002838135--
# rank 4, conf: 0.7447636723518372
# sent 300626: |['That is one of out theories, yes.', 'Could the Gravedigger have sent Worstenbach?']|
#
# -- 546366 range D2 10-20, mean conf: 0.7447046637535095--
# rank 17, conf: 0.7446980476379395
# sent 111203: |["There are three wheels, numbered zero through nine each. That's a thousand possibilities.", 'Then your fingers better get busy.']|
#
# -- 546366 range D3 20-30, mean conf: 0.7446858882904053--
# rank 30, conf: 0.7446786165237427
# sent 918437: |['Isn’t that their burden? I’m the one with something interesting to say.', 'Fair enough, but in its essence, teaching is a performance art. In the classroom paradigm, the teacher has the responsibility to communicate, as well as entertain and engage.']|
#
# -- 546366 range D4 30-60, mean conf: 0.7446498870849609--
# rank 56, conf: 0.7446338534355164
# sent 296531: |["This is his case. He's invested.", "He's irrational. Probably male menopause."]|
#
# ----------SENT 251298 @33---------
# TEXT: |["Lisa, you made me realize the importance of free and independent media. So I printed my own paper. Although it's mostly culled from wire services.", 'Hey, who wants a copy of "The Lenny Saver?"']|
# MEAN CONF TOP100: 0.7428545951843262
#
# -- 251298 range D0 0-1, mean conf: 0.74387127161026--
# rank 2, conf: 0.74387127161026
# sent 286627: |['It\'s written right there on the side of the truck. Which "high wire" is not.', 'It\'s just sometimes you get irritated and you say "Booth" without thinking.']|
#
# -- 251298 range D1 1-10, mean conf: 0.7433795928955078--
# rank 4, conf: 0.7434361577033997
# sent 404830: |["You almost finished with that? What's your count?", 'Yeah. 109 rods.']|
#
# -- 251298 range D2 10-20, mean conf: 0.7430903911590576--
# rank 14, conf: 0.7431043982505798
# sent 308518: |["That's - that's not up to me. That's not up to you. That's up to a jury.", "That's not the point."]|
#
# -- 251298 range D3 20-30, mean conf: 0.7430042028427124--
# rank 29, conf: 0.7429855465888977
# sent 10278: |["It's no better than tossing a coin.", "What's so improbable about tossing a coin? Never heard of the I-Ching?"]|
#
# -- 251298 range D4 30-60, mean conf: 0.742810845375061--
# rank 49, conf: 0.7427747249603271
# sent 879381: |["Special. That's why I spared no expense on the tux.", 'The tux? I thought you, uh, borrowed it from your cousin Rigby.']|
#
# ----------SENT 55528 @34---------
# TEXT: |["Well, when you've been around as long as I have. How old are you, anyway?", 'Hundred and twenty five.']|
# MEAN CONF TOP100: 0.7369993329048157
#
# -- 55528 range D0 0-1, mean conf: 0.7369992733001709--
# rank 1, conf: 0.7369992733001709
# sent 515536: |["Maybe this is where they put all the dummy demons. [cuddles a caterpillar demon and talks to it in a baby-like voice] Right, big guy? You're not so smart, right? Yeah... [to Jake; normal voice] Let's go out that hole, man.", 'Okay, get on.']|
#
# -- 55528 range D1 1-10, mean conf: 0.7369992733001709--
# rank 9, conf: 0.7369992733001709
# sent 874524: |['"It\'s okay. - I\'m ready."', '"Angel listen to me." Takes a hold of his shoulders. "Sit up." Angel scoots up a little higher, but he is weak and moving clearly hurts a great deal.']|
#
# -- 55528 range D2 10-20, mean conf: 0.7369993329048157--
# rank 16, conf: 0.7369992733001709
# sent 20886: |['Where are we?', 'Catacombs.']|
#
# -- 55528 range D3 20-30, mean conf: 0.7369993329048157--
# rank 24, conf: 0.7369992733001709
# sent 183420: |["You're predictable.", "You may be really good at staying one step ahead of Checkmate, but you don't know the first thing about me."]|
#
# -- 55528 range D4 30-60, mean conf: 0.7369993329048157--
# rank 59, conf: 0.7369992733001709
# sent 193133: |["I'm not sure.", 'Where you going?']|
#
# ----------SENT 507107 @35---------
# TEXT: |["You don't have to do this alone. I'm with you.", 'Me, too!']|
# MEAN CONF TOP100: 0.7369993329048157
#
# -- 507107 range D0 0-1, mean conf: 0.7369992733001709--
# rank 1, conf: 0.7369992733001709
# sent 535948: |["You're ugly and old.", "I'll miss you, too. Okay."]|
#
# -- 507107 range D1 1-10, mean conf: 0.7369992733001709--
# rank 2, conf: 0.7369992733001709
# sent 719267: |["I'm not happy.", 'Why?']|
#
# -- 507107 range D2 10-20, mean conf: 0.7369993329048157--
# rank 20, conf: 0.7369992733001709
# sent 121370: |["When you're ready.", 'Huh. Okay.']|
#
# -- 507107 range D3 20-30, mean conf: 0.7369993329048157--
# rank 29, conf: 0.7369992733001709
# sent 741828: |["I'm sorry I'm a little late.", "Well, you're here now and that's all that matters. Shall we go into the living room?"]|
#
# -- 507107 range D4 30-60, mean conf: 0.7369993329048157--
# rank 49, conf: 0.7369992733001709
# sent 1071833: |["You're drunk.", "Only a couple of glasses wine and I had a very nice time. In case you're interested."]|
#
# ----------SENT 533365 @36---------
# TEXT: |['Give me the Mixmaster.', 'Face it. You have nothing I want.']|
# MEAN CONF TOP100: 0.62017822265625
#
# -- 533365 range D0 0-1, mean conf: 0.62017822265625--
# rank 1, conf: 0.62017822265625
# sent 852090: |['Give it to me, give it, give me...', 'Play the tape, play it, play it!']|
#
# -- 533365 range D1 1-10, mean conf: 0.6201781630516052--
# rank 5, conf: 0.6201781630516052
# sent 84329: |['Give it to me!', 'The nanoforms!']|
#
# -- 533365 range D2 10-20, mean conf: 0.6201781630516052--
# rank 12, conf: 0.6201781630516052
# sent 378621: |['Give me that.  More weight!', "Hey, Dr. Zoidberg, what's that jazz on your head?"]|
#
# -- 533365 range D3 20-30, mean conf: 0.6201781630516052--
# rank 21, conf: 0.6201781630516052
# sent 705980: |['Give me that.', 'No, no, no!']|
#
# -- 533365 range D4 30-60, mean conf: 0.6201781630516052--
# rank 45, conf: 0.6201781630516052
# sent 856805: |["Well I didn't think we'd be on a flying to Philadelphia when I woke up this morning, I'll give you that.", "Let's go talk to those girls."]|
#
# ----------SENT 295508 @37---------
# TEXT: |['I am a mad "sagger". I ... I ... I wear my shorts very, very low.', 'Okay.']|
# MEAN CONF TOP100: 0.12225272506475449
#
# -- 295508 range D0 0-1, mean conf: 0.14368516206741333--
# rank 1, conf: 0.14368516206741333
# sent 509568: |['You are not an outsider. You wear cute little blue shorts!', 'I... am complicated.']|
#
# -- 295508 range D1 1-10, mean conf: 0.1381000429391861--
# rank 9, conf: 0.1378324180841446
# sent 1015233: |["I still have it. The collar's okay. I wear it under sweaters.", "I don't know what I'm gonna do. She asked me to give her a baby shower."]|
#
# -- 295508 range D2 10-20, mean conf: 0.1368718445301056--
# rank 21, conf: 0.1364007145166397
# sent 510252: |["Nah, they're still cool. But Ice King's still lame because he hides his ninja love. We wear our ninja on our sleeves!", 'Jake! Show me how to do that.']|
#
# -- 295508 range D3 20-30, mean conf: 0.1310327649116516--
# rank 22, conf: 0.13585057854652405
# sent 743842: |['I wear it with tights.', "I've planning it for weeks. Everybody's counting on me. But here I am thousands of miles away, stuck in a land of reindeer stew. And I'm loathe to cancel because there's nothing Constance Betterton would like more than for me to slip up so she can destroy my reputation, run me out of the DAR, Then jump in the air like a cheerleader and land doing the splits."]|
#
# -- 295508 range D4 30-60, mean conf: 0.12026187032461166--
# rank 46, conf: 0.12174054235219955
# sent 127460: |["Habits. Yeah, they're called habits. Big white hats.", 'Yep, they called to say that... bowling practice is cancelled.']|
#
# ----------SENT 600159 @38---------
# TEXT: |['I belong here.', "Maybe so. But until we know what's going on, you've got to come back with us to the ship. Harry, no!"]|
# MEAN CONF TOP100: 0.05095039680600166
#
# -- 600159 range D0 0-1, mean conf: 0.06185625493526459--
# rank 1, conf: 0.06185625493526459
# sent 83476: |["I'm back. We're back, all of us. Back where we belong.", 'That felt like a spatio']|
#
# -- 600159 range D1 1-10, mean conf: 0.06185625120997429--
# rank 11, conf: 0.06185624748468399
# sent 505089: |['Where they belong.', 'The baby.  We have to get the baby back!']|
#
# -- 600159 range D2 10-20, mean conf: 0.06137959286570549--
# rank 14, conf: 0.06185624748468399
# sent 517294: |["No... It's... well... These belong to you.", "But it's not even my birthday! This is so exciting!"]|
#
# -- 600159 range D3 20-30, mean conf: 0.051308371126651764--
# rank 26, conf: 0.050576210021972656
# sent 195901: |["Yeah! That's what people do in Russia!", "It's time I told you about a chapter of my life I hoped would be closed forever. I was on my way to the Harrisburg Coat Outlet to buy an irregular coat. But it required a stopover in New York City."]|
#
# -- 600159 range D4 30-60, mean conf: 0.04847829416394234--
# rank 35, conf: 0.049373261630535126
# sent 393577: |["Place is sealed, and they don't spontaneously generate.", "So they're feeding on fresh blood. Could be a rodent, though, or bad garbage."]|
#
# ----------SENT 464804 @39---------
# TEXT: |['Wha-uh.', 'Wait a second.']|
# MEAN CONF TOP100: 0.012754342518746853
#
# -- 464804 range D0 0-1, mean conf: 0.015208098106086254--
# rank 1, conf: 0.015208098106086254
# sent 443391: |['Wha-hah!', 'Garbunkle! Follow my lead!']|
#
# -- 464804 range D1 1-10, mean conf: 0.014280363917350769--
# rank 10, conf: 0.013053538277745247
# sent 40863: |["You don't mean to say we're going on?", 'Oh, goodness me, goodness me, child, how you do talk. Yes, we are.']|
#
# -- 464804 range D2 10-20, mean conf: 0.012852275744080544--
# rank 14, conf: 0.0128629794344306
# sent 724406: |["But how do you know what I'm going to say?", 'Trust me. I know.']|
#
# -- 464804 range D3 20-30, mean conf: 0.012700475752353668--
# rank 22, conf: 0.012750204652547836
# sent 776802: |["Uh, listen, sweetie, about this camping weekend. We should just go and take advantage of the time together. I wouldn't miss that for anything.", 'I was actually gonna say the same thing.']|
#
# -- 464804 range D4 30-60, mean conf: 0.012588176876306534--
# rank 34, conf: 0.01262385118752718
# sent 755838: |["I read slow so I don't miss anything.", "It's not the Bhagavad Gita, Madeline. It's simple instructions for the business fair."]|

# %% [markdown]
# ## V7: V like this.
#
# Manufest:
# * DEP: all.
# * POS: all noun forms only.
#
# Decent but less than V1?
#
# Idea: random draw from top 10 for context correct candidate.
# Reason: to avoid the risk of getting same ranked 1 sentence for various dialog 1s. Protential risk including model give weights too much to centain sentences features which may casuse bias in training set.

# %%
data_v7 = data.loc[(data.head_info=='DEP') | (data.head_pos.isin(set(['NN', 'NNS', 'NNP', 'NNPS',])))]
data_v7
# Out:
#           sent_id                        show_id            char_name char_id  \
# 1          233952                    TheSimpsons         Lisa Simpson  a15823
# 5           78453                      DoctorWho              BARBARA   l8667
# 6          146223                   VeronicaMars             VERONICA  l30591
# 10        1059921                    Charmed1998                 ANDY   l6497
# 14         537460                       StarTrek              JANEWAY  l25466
# 18         662463                       StarTrek                PHLOX  l25490
# 19         642832                       StarTrek               HARPER   l1893
# 21         238693                    TheSimpsons  C. Montgomery Burns  a15869
# 23         526675                   GreysAnatomy                DEREK  l12263
# 27          66679                      DoctorWho                 GWEN   l9078
# 31         580866                       StarTrek               ARCHER  l25486
# 32         971419                   DawsonsCreek               DAWSON   l7946
# 33         866034              HowIMetYourMother                ROBIN  l13772
# 36         642447                       StarTrek               HARPER   l1893
# 38         110457                           NCIS                GIBBS  l18791
# 40         403957                       CSIVerse                 NICK   l7486
# 42         788696                    TheOfficeUS              MICHAEL  l19352
# 44         790267                    TheOfficeUS              MICHAEL  l19352
# 45         189666                    TheSimpsons        Homer Simpson  a15835
# 48         511955                  AdventureTime                 Finn   a3415
# 49         805801                    TheOfficeUS                  JIM  l19347
# 52         730165                   GilmoreGirls                 RORY  l11613
# 53         585682                       StarTrek                RIKER  l25432
# 55         908523               TheBigBangTheory                PENNY   l4391
# 57         393226                       CSIVerse              GRISSOM   l7484
# 58         460395                    OneTreeHill                LUCAS  l19593
# 62         162342                     Smallville                CLARK  l24611
# 63         464165                    OneTreeHill               NATHAN  l19594
# 64         309155                          Bones               ANGELA   l5149
# 66         431264  MyLittlePonyFriendshipIsMagic               Rarity  a13095
# ...           ...                            ...                  ...     ...
# 17160310   600643                       StarTrek             CHAKOTAY  l25467
# 17160311   538371                       StarTrek              JANEWAY  l25466
# 17160317   497238                  OnceUponATime               REGINA  l19395
# 17160318    66392                      DoctorWho                 GWEN   l9078
# 17160323   859388              HowIMetYourMother               BARNEY  l13774
# 17160327   649350                       StarTrek               NEELIX  l25473
# 17160328   885589                          Salem                 MARY  l23233
# 17160329   688919                   GilmoreGirls              LORELAI  l11612
# 17160330   660454                       StarTrek                 REED  l25489
# 17160331   183094                     Smallville                 TESS  l24621
# 17160333   597311                       StarTrek             CHAKOTAY  l25467
# 17160335  1007369                       Seinfeld               GEORGE  l23594
# 17160336   443968                       TheLWord                ALICE  l15690
# 17160337   875528                     Buffyverse                BUFFY   l5648
# 17160344   749073                   GilmoreGirls               SOOKIE  l11619
# 17160346   373719                   TheMentalist               LISBON  l17674
# 17160348  1063421                    QueerAsFolk              MICHAEL  l22346
# 17160349   709703                   GilmoreGirls                 RORY  l11613
# 17160350   174190                     Smallville                 LANA  l24615
# 17160352   548045                       StarTrek              JANEWAY  l25466
# 17160359    25432                      DoctorWho        SECOND DOCTOR   l8651
# 17160362   793175                    TheOfficeUS              MICHAEL  l19352
# 17160363  1006647                       Seinfeld               GEORGE  l23594
# 17160366   125325                           NCIS                 ABBY  l18806
# 17160368   774869                        Roswell                  MAX  l23046
# 17160370   860557              HowIMetYourMother               BARNEY  l13774
# 17160371   126524                           NCIS                 ABBY  l18806
# 17160373   537886                       StarTrek              JANEWAY  l25466
# 17160376   652290                       StarTrek                MCCOY  l25412
# 17160377   295962                          Bones              BRENNAN   l5146
#
#          head_info   head_pos      token  token_par  position  is_stop  \
# 1              DEP        det          a       girl         8     True
# 5              DEP      advcl         be       hold        34     True
# 6              DEP   compound       drug    testing         5    False
# 10             DEP      ccomp         be      think       -18     True
# 14             POS         NN  deflector  deflector        61    False
# 18             DEP      nsubj  condition         be       -16    False
# 19             DEP       prep     beyond         be        24     True
# 21             POS         NN      blood      blood        63    False
# 23             DEP       mark         if         be         5     True
# 27             DEP        det         no     weapon         9     True
# 31             DEP       mark         if      agree         5     True
# 32             DEP   npadvmod     PERSON       know        15    False
# 33             POS         NN       info       info        63    False
# 36             DEP   npadvmod     PERSON         be       -19    False
# 38             DEP       dobj         me       tell        -8     True
# 40             DEP       dobj         it       help        -5     True
# 42             DEP  nsubjpass         he      dress         9     True
# 44             DEP        neg        not       need         4     True
# 45             POS        NNP     PERSON     PERSON         5    False
# 48             DEP     advmod      still         be        -3     True
# 49             DEP       prep      about  complaint       -11     True
# 52             DEP     advmod       just       feel         5     True
# 53             DEP       pobj       that       with        -5     True
# 55             DEP    auxpass         be    excited         3     True
# 57             DEP       prep         of     murder        -7     True
# 58             POS         NN        mom        mom        27    False
# 62             DEP        det        the        ORG         4     True
# 63             DEP        aux         do        get         8     True
# 64             POS        NNP        ORG        ORG        43    False
# 66             DEP        aux        can        get         6     True
# ...            ...        ...        ...        ...       ...      ...
# 17160310       DEP       pobj       ship         on       -13    False
# 17160311       DEP       dobj       cure   discover       -14    False
# 17160317       DEP       prep         of        out        -4     True
# 17160318       POS         NN       love       love        12    False
# 17160323       POS        NNP     PERSON     PERSON        20    False
# 17160327       POS        NNS        day        day        24    False
# 17160328       DEP       attr      enemy         be       -11    False
# 17160329       POS        NNP    General    General         0    False
# 17160330       DEP       prep         on      paint       -21     True
# 17160331       DEP     advmod        now         be         9     True
# 17160333       DEP        det          a    society        20     True
# 17160335       DEP        det       this      thing        10     True
# 17160336       DEP      nsubj       that         go        11     True
# 17160337       DEP       dobj        her   remember        -9     True
# 17160344       POS         NN     budget     budget        20    False
# 17160346       DEP     advmod       once      bring       -27     True
# 17160348       DEP        det          a      sauce        19     True
# 17160349       DEP       pobj      honey        for        -4    False
# 17160350       DEP        aux         to         go         3     True
# 17160352       DEP        aux      could       wait        27     True
# 17160359       POS         NN     report     report        62    False
# 17160362       POS        NNP        GPE        GPE        72    False
# 17160363       DEP       mark       that        ask        14     True
# 17160366       POS        NNP        ORG        ORG       114    False
# 17160368       DEP       intj         no     PERSON         4     True
# 17160370       DEP       intj       okay         be        14    False
# 17160371       DEP      nsubj       that         be         4     True
# 17160373       POS         NN      price      price       109    False
# 17160376       POS        NNP        FAC        FAC        66    False
# 17160377       DEP       case         's     PERSON        -7     True
#
#                        head_text
# 1                     det|a|girl
# 5                  advcl|be|hold
# 6          compound|drug|testing
# 10                ccomp|be|think
# 14        NN|deflector|deflector
# 18            nsubj|condition|be
# 19                prep|beyond|be
# 21                NN|blood|blood
# 23                    mark|if|be
# 27                 det|no|weapon
# 31                 mark|if|agree
# 32          npadvmod|PERSON|know
# 33                  NN|info|info
# 36            npadvmod|PERSON|be
# 38                  dobj|me|tell
# 40                  dobj|it|help
# 42            nsubjpass|he|dress
# 44                  neg|not|need
# 45             NNP|PERSON|PERSON
# 48               advmod|still|be
# 49          prep|about|complaint
# 52              advmod|just|feel
# 53                pobj|that|with
# 55            auxpass|be|excited
# 57                prep|of|murder
# 58                    NN|mom|mom
# 62                   det|the|ORG
# 63                    aux|do|get
# 64                   NNP|ORG|ORG
# 66                   aux|can|get
# ...                          ...
# 17160310            pobj|ship|on
# 17160311      dobj|cure|discover
# 17160317             prep|of|out
# 17160318            NN|love|love
# 17160323       NNP|PERSON|PERSON
# 17160327             NNS|day|day
# 17160328           attr|enemy|be
# 17160329     NNP|General|General
# 17160330           prep|on|paint
# 17160331           advmod|now|be
# 17160333           det|a|society
# 17160335          det|this|thing
# 17160336           nsubj|that|go
# 17160337       dobj|her|remember
# 17160344        NN|budget|budget
# 17160346       advmod|once|bring
# 17160348             det|a|sauce
# 17160349          pobj|honey|for
# 17160350               aux|to|go
# 17160352          aux|could|wait
# 17160359        NN|report|report
# 17160362             NNP|GPE|GPE
# 17160363           mark|that|ask
# 17160366             NNP|ORG|ORG
# 17160368          intj|no|PERSON
# 17160370            intj|okay|be
# 17160371           nsubj|that|be
# 17160373          NN|price|price
# 17160376             NNP|FAC|FAC
# 17160377          case|'s|PERSON
#
# [6259648 rows x 11 columns]

# %%
model_v7, SENT_CATS_v7, FEATURE_CATS_v7 = get_train(data_v7, report_test_acc=False)
SENT_MAP_v7, INV_SENT_MAP_v7 = build_maps(data_v7)
# Out:
# <129816x921574 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6259648 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [02:24<00:00,  1.29it/s]
# 921574 921574

# %%
mi = ModelInspection(model_v7, SENT_MAP_v7, INV_SENT_MAP_v7, dialog_df=dialogs)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 885975 @0---------
# TEXT: |['And it had nothing to do with feeling?', "Not beyond the feeling I possess for any of God's needy creatures... a hungry child..."]|
# MEAN CONF TOP100: 1.0700825452804565
#
# -- 885975 range D0 0-1, mean conf: 1.1104716062545776--
# rank 2, conf: 1.1104716062545776
# sent 2132: |['Yes, but it has nothing to do with clinical pathology.', 'Does that crystalline lattice remind you of anything?']|
#
# -- 885975 range D1 1-10, mean conf: 1.099260687828064--
# rank 5, conf: 1.1025006771087646
# sent 769898: |['But this has nothing to do with -', "You've always been the head pilgrim girl at the food drive table."]|
#
# -- 885975 range D2 10-20, mean conf: 1.08853018283844--
# rank 21, conf: 1.0861375331878662
# sent 576130: |['I know nothing of this. Send for someone learned in witchcraft and let him examine him. I will have nothing to do with it.', 'My lord, at least arrange for me to meet Mister Atoz.']|
#
# -- 885975 range D3 20-30, mean conf: 1.0791008472442627--
# rank 31, conf: 1.0764031410217285
# sent 341733: |["Look, that has nothing to do with this, ok? She's my ex-wife. If she were marrying a guy, none of you'd expect me to be there.", "Hey, if she were marrying a guy, she'd be like the worst lesbian ever."]|
#
# -- 885975 range D4 30-60, mean conf: 1.067521333694458--
# rank 37, conf: 1.0756841897964478
# sent 972628: |['This has nothing to do with s*x.', "Oh, what, are you in love? Is that what this is? Oh, god, don't look. Don't look at her, all right? Don't. I-- you know what, Pacey? I feel sorry for you. Because when all this is over, you're really gonna need your friends, and you're not gonna have any. You are not gonna have a single one."]|
#
# ----------SENT 456451 @1---------
# TEXT: |["Yeah. Yeah, as his editor, I'm thrilled, obviously, but as his girlfriend, I can't help but notice the timing.", "Oh, you're talking about Peyton coming back?"]|
# MEAN CONF TOP100: 0.9638590812683105
#
# -- 456451 range D0 0-1, mean conf: 1.0746314525604248--
# rank 2, conf: 1.0746314525604248
# sent 444122: |["Look, I am a wreck about this cruise and you're not helping.", 'How would you feel, Dana, if I - if I came down and I just interrupted one of your matches, or - or... corrected one of your shots?']|
#
# -- 456451 range D1 1-10, mean conf: 1.0318323373794556--
# rank 6, conf: 1.0313255786895752
# sent 899084: |['It was a full turtleneck. Why aren’t you helping me?', 'I don’t know. Maybe because I’m crazy?']|
#
# -- 456451 range D2 10-20, mean conf: 1.0031949281692505--
# rank 13, conf: 1.0138438940048218
# sent 240206: |["Don't be afraid, Moe. I'm here to help you with your romantic problems.", "Hey, I don't need no advice from no pinball machine. I'll have you know I wrote the book on love."]|
#
# -- 456451 range D3 20-30, mean conf: 0.9817792177200317--
# rank 26, conf: 0.9811969995498657
# sent 78278: |["Right. Better than following him, we can plan a reception committee. If I can discover the results of this meeting, I'm ready to return to England and I'm free to help you.", 'Have you any idea who Barrass is meeting?']|
#
# -- 456451 range D4 30-60, mean conf: 0.9582741856575012--
# rank 36, conf: 0.9700945615768433
# sent 358809: |["Yeah, it's weird. I can't help it though he's so sweet, he's like this little puppy dog, y'know? But like a really tough one that shots bad guys. Ohh, I just love beginning parts of relationships, y'know?! You just like can't keep your hands off each other.", 'I know it is the best.']|
#
# ----------SENT 590254 @2---------
# TEXT: |['That was a perimeter warning from the Remmler Array. A small ship is approaching. I believe Mister Orton has dropped his defence shields.', 'This must be the sign they were waiting for. Mister Data, you will be the only one unaffected by the hypersonic burst. As soon as every else is unconscious, I need you to get to the computer panel and stop that ship somehow.']|
# MEAN CONF TOP100: 0.9036273956298828
#
# -- 590254 range D0 0-1, mean conf: 0.9362640976905823--
# rank 2, conf: 0.9362640976905823
# sent 631111: |['Mister La Forge, I believe we will postpone.', 'Yes, sir.']|
#
# -- 590254 range D1 1-10, mean conf: 0.913462221622467--
# rank 7, conf: 0.9125263094902039
# sent 623915: |["They're firing on us, Captain.", "It's a small vessel, fifteen lifeforms aboard. Low warp capacity, limited armaments. They pose no threat."]|
#
# -- 590254 range D2 10-20, mean conf: 0.9082323908805847--
# rank 19, conf: 0.9074051976203918
# sent 573403: |['Captain, why should I aim at such a structure?', 'Never mind, Spock. Just get on with the job.']|
#
# -- 590254 range D3 20-30, mean conf: 0.9058676958084106--
# rank 22, conf: 0.9064499735832214
# sent 375376: |['Sir, do you got any soda?', 'What kind do you want?']|
#
# -- 590254 range D4 30-60, mean conf: 0.9027546048164368--
# rank 32, conf: 0.9053481221199036
# sent 611481: |['Doctor Sanchez has ruled that possibility out, sir.', 'Please keep me fully advised. Spock out. He was in the transporter room. Someone may have entered after Captain Kirk and his party left. Mister Scott, since the Enterprise is obviously functional, I suggest we return to our starting place at top warp speed.']|
#
# ----------SENT 412235 @3---------
# TEXT: |['Now how did you know that receipt was in there?', 'Well, I used to read point spreads. Now I read books.']|
# MEAN CONF TOP100: 0.8778584003448486
#
# -- 412235 range D0 0-1, mean conf: 0.9686601161956787--
# rank 2, conf: 0.9686601161956787
# sent 642474: |['How are you able to access them? How did you even know that they were in there?', 'I just had a vision. I get a lot of them lately.']|
#
# -- 412235 range D1 1-10, mean conf: 0.9169676899909973--
# rank 5, conf: 0.91704261302948
# sent 347706: |["We know you're out there.", 'Who do you think its from?']|
#
# -- 412235 range D2 10-20, mean conf: 0.9084026217460632--
# rank 13, conf: 0.9107053279876709
# sent 162087: |["I know you're out there somewhere.", "I've been keeping an eye on you."]|
#
# -- 412235 range D3 20-30, mean conf: 0.8977487683296204--
# rank 31, conf: 0.889240562915802
# sent 997914: |["Kramer! Kramer! Kramer, open up, I know you're in there!", 'Susan!']|
#
# -- 412235 range D4 30-60, mean conf: 0.8756968379020691--
# rank 51, conf: 0.8716540932655334
# sent 165590: |["We are talking about an alien invasion. Two men are dead. You know, if you were there, you'd be clacking away on the keyboard as we speak.", 'Not now. The Daily Planet just hired a new editor wonder boy from the Star City Post. And spaceships are not the stuff of good first impressions.']|
#
# ----------SENT 612580 @4---------
# TEXT: |["And I will not return without a full explanation. Ambassador, with great respect for all that you've achieved on behalf of the Federation, this sort of cowboy diplomacy will not easily be tolerated any more.", 'Cowboy diplomacy?']|
# MEAN CONF TOP100: 0.840373158454895
#
# -- 612580 range D0 0-1, mean conf: 0.9568911790847778--
# rank 2, conf: 0.9568911790847778
# sent 603: |['A sort of Think Tank.', 'Yes. But over the years the Elite has become more and more powerful, and now they can demand whatever they like.']|
#
# -- 612580 range D1 1-10, mean conf: 0.9025487899780273--
# rank 9, conf: 0.8796385526657104
# sent 977852: |['Pacey, our arrangement precludes any sort of emotional foreplay.', 'Yes, it does, which by extension also precludes the idea of angry s*x. Now you want to tell me what just happened with your mom?']|
#
# -- 612580 range D2 10-20, mean conf: 0.8650789260864258--
# rank 15, conf: 0.8658483028411865
# sent 675880: |['Project Blackhole does not share its toys as often as the NSC would like, governmental turf-war, that kind of thing.', 'Of course.']|
#
# -- 612580 range D3 20-30, mean conf: 0.8455570936203003--
# rank 27, conf: 0.8437944054603577
# sent 85408: |["Don't know. Some kind of signal drawing the Tardis off course.", 'Where are we?']|
#
# -- 612580 range D4 30-60, mean conf: 0.8339322209358215--
# rank 36, conf: 0.8374159336090088
# sent 242047: |['In science: dead last.', "I'm telling you people the earth revolves around the sun."]|
#
# ----------SENT 796632 @5---------
# TEXT: |["I'm not taking Rogaine.", 'Angela, what about you?']|
# MEAN CONF TOP100: 0.8382633924484253
#
# -- 796632 range D0 0-1, mean conf: 0.8743184804916382--
# rank 2, conf: 0.8743184804916382
# sent 121055: |["Don't take it personal, Goliath.", 'Yeah, can I ask you about that? Every arms dealer I meet, they have the cheesiest code names? I mean, Goliath? Did you choose that?']|
#
# -- 796632 range D1 1-10, mean conf: 0.8722432851791382--
# rank 11, conf: 0.8708749413490295
# sent 9784: |["Tigella won't take long, then.", 'No, no, no. A quick flight, a quick service.']|
#
# -- 796632 range D2 10-20, mean conf: 0.8677541017532349--
# rank 17, conf: 0.8678240776062012
# sent 502221: |['Hook sacrificed himself, and you took that from him!', 'Do you honestly think that you can hurt me? I now have the combined power of every Dark One who ever lived... including you.']|
#
# -- 796632 range D3 20-30, mean conf: 0.8603779673576355--
# rank 28, conf: 0.8597917556762695
# sent 641387: |["That's not entirely accurate. I chose to retire rather than face dismissal. I was under investigation by the Security Ministry. They claimed I had taken restricted data from the Academy archives.", 'Did you?']|
#
# -- 796632 range D4 30-60, mean conf: 0.8424656987190247--
# rank 58, conf: 0.8353119492530823
# sent 462179: |["I'm aware of that, Slick. We'll take the Armani.", "You're buying me a tuxedo?"]|
#
# ----------SENT 367842 @6---------
# TEXT: |['Really?! So this has happened to you?', 'Oh absolutely yeah! Oh and keep in mind, now, I was carrying triplets so in, y’know, medical terms I was-I was thrice as randy.']|
# MEAN CONF TOP100: 0.8311267495155334
#
# -- 367842 range D0 0-1, mean conf: 0.8363127708435059--
# rank 2, conf: 0.8363127708435059
# sent 531417: |["Except housing a human for nine long months is all that I can think about. It...it...the thoughts are invading the surgeries that I love, and it's...it's...it's...it's hormonal. It's...and horrible. But it is happening...to me.", 'You want to have a baby?']|
#
# -- 367842 range D1 1-10, mean conf: 0.8354852199554443--
# rank 4, conf: 0.8358880877494812
# sent 859260: |['It has happened to you what?', 'There... a girl in the gym. Pauline. She runs after me for a while.']|
#
# -- 367842 range D2 10-20, mean conf: 0.8348695635795593--
# rank 19, conf: 0.8346893787384033
# sent 356179: |["Ok, ok, ok. How did this happen to me? How did this happen to me? A week ago, two weeks ago, I was fine. Ross was just Ross, just this guy. Now he's Rrrooossss, oh, this really great guy that I can't have.", 'Sweetie, I wanted you to have him too.']|
#
# -- 367842 range D3 20-30, mean conf: 0.8333166837692261--
# rank 31, conf: 0.832290768623352
# sent 153160: |["What if I don't have a home? What if you found out I did bad things? What would happen to me then?", "Ryan, everything's gonna work out. I know it. You like comics?"]|
#
# -- 367842 range D4 30-60, mean conf: 0.8312889337539673--
# rank 37, conf: 0.8312719464302063
# sent 576555: |['What will happen to me now?', "You'll have to stand trial. But you did save the Enterprise from the Romulans, and I will recommend that be taken into consideration."]|
#
# ----------SENT 972384 @7---------
# TEXT: |["My son. It's been quite a year for ya.", 'What do you mean?']|
# MEAN CONF TOP100: 0.8202141523361206
#
# -- 972384 range D0 0-1, mean conf: 0.8420163989067078--
# rank 2, conf: 0.8420163989067078
# sent 928448: |["Tell me about Chris Dun. Juice and Gemma ID'd him as the guy they saw leaving Jax's house the night of Tara's murder. He's been M.I.A. for weeks.", "That's probably why. 'Cause Lin knew he was sloppy. Got him out of the country. When did Gemma ID him?"]|
#
# -- 972384 range D1 1-10, mean conf: 0.8335769176483154--
# rank 6, conf: 0.8340218663215637
# sent 1059326: |["It's only been a couple of days.", 'Yeah, well, what if I never get through to her?']|
#
# -- 972384 range D2 10-20, mean conf: 0.825451672077179--
# rank 17, conf: 0.8249332904815674
# sent 268222: |["It's been a year.", 'Shh, just take it easy.']|
#
# -- 972384 range D3 20-30, mean conf: 0.8232498168945312--
# rank 26, conf: 0.8232210278511047
# sent 828049: |["It's been a few days", "Give then, I don't know. What's the big deal?"]|
#
# -- 972384 range D4 30-60, mean conf: 0.8204478621482849--
# rank 46, conf: 0.8202028274536133
# sent 320829: |['I\'m going to bed. - It\'s been a long day."', '"You\'ve been up for three hours."']|
#
# ----------SENT 523501 @8---------
# TEXT: |['I told her she can listen to my thoughts whenever she wanted to.', "No, see, she doesn't wanna listen to any body's thoughts. She wants to not hear 'em. But that requires constant work on her part. And now she's met somebody and she can drop all that effort and just relax... Oh, man, you don't stand a chance. I'm really sorry, but you don't."]|
# MEAN CONF TOP100: 0.8126465082168579
#
# -- 523501 range D0 0-1, mean conf: 0.8614422082901001--
# rank 2, conf: 0.8614422082901001
# sent 851071: |["I told you I don't want to talk", "I heard. You're keeping all that rage bottled up inside. Caroline's worried sick about you"]|
#
# -- 523501 range D1 1-10, mean conf: 0.8426482677459717--
# rank 3, conf: 0.8500851392745972
# sent 122575: |['Um... do you want the truth, or do you want me to lie to you to ease the burden of your own self-loathing.', "I'd prefer the lie."]|
#
# -- 523501 range D2 10-20, mean conf: 0.826827883720398--
# rank 19, conf: 0.8228272795677185
# sent 931934: |['You want to tell me what happened to Piney?', 'You should know.']|
#
# -- 523501 range D3 20-30, mean conf: 0.8184982538223267--
# rank 26, conf: 0.8188390731811523
# sent 258386: |['So. You uh, you want to tell me about this last hunt of yours?', "No. Not really. No offense, it's just kind of a family thing."]|
#
# -- 523501 range D4 30-60, mean conf: 0.810002326965332--
# rank 36, conf: 0.8125929832458496
# sent 1030584: |['Do you want us to tell him?', "No, it's something I have to do."]|
#
# ----------SENT 729431 @9---------
# TEXT: |['Worked for Brenda Starr. Worked for Lois Lane.', 'Ah so if I get a job as a journalist in a comic strip, this is the one.']|
# MEAN CONF TOP100: 0.7615432143211365
#
# -- 729431 range D0 0-1, mean conf: 0.795468270778656--
# rank 2, conf: 0.795468270778656
# sent 664881: |["While those men were accessing the registers, these two men hacked into the bank's mainframe and rerouted funds. They work for Anini Hassan.", "I don't understand. Why would Hassan be robbing a bank in the States?"]|
#
# -- 729431 range D1 1-10, mean conf: 0.7837972640991211--
# rank 3, conf: 0.7954573631286621
# sent 169453: |["I know that name. I've come across it several times in my research. She works for Virgil Swann, the billionaire.", "Look, this doesn't concern you."]|
#
# -- 729431 range D2 10-20, mean conf: 0.7671182751655579--
# rank 15, conf: 0.7681682109832764
# sent 799437: |['Oh, hi. You work for Michael.', 'I work with Michael.']|
#
# -- 729431 range D3 20-30, mean conf: 0.7623975276947021--
# rank 25, conf: 0.76285719871521
# sent 235891: |['Delivery for Lisa Simpson.', "It's a gift from Mapple!"]|
#
# -- 729431 range D4 30-60, mean conf: 0.7590686678886414--
# rank 52, conf: 0.7583355903625488
# sent 662923: |['For Beka, who showed me how to fly. For Tyr', 'I want no souvenirs from a suicide.']|
#
# ----------SENT 638428 @10---------
# TEXT: |["That's something Mister Velik used to say. Tenth grade biology class. He was a Vulcan scientist (who came to teach us about life on other worlds. I'd never seen a Vulcan before, not up close. He scared the hell out of me.", "Perhaps it's not too late to follow his advice."]|
# MEAN CONF TOP100: 0.7487571239471436
#
# -- 638428 range D0 0-1, mean conf: 0.8450218439102173--
# rank 2, conf: 0.8450218439102173
# sent 126589: |['Thank god. Anthrax scares the hell out of me. May I?', 'Yeah.']|
#
# -- 638428 range D1 1-10, mean conf: 0.8448460102081299--
# rank 4, conf: 0.8448675274848938
# sent 1033490: |['Beats the hell out of me.', 'Piper?']|
#
# -- 638428 range D2 10-20, mean conf: 0.8186511993408203--
# rank 13, conf: 0.8446778655052185
# sent 102114: |['Oh, you just scared the hell out of me.', 'Sorry, I wa - I was just, um, I was - nothing.']|
#
# -- 638428 range D3 20-30, mean conf: 0.7858941555023193--
# rank 24, conf: 0.7937166690826416
# sent 924487: |['Get the hell out of there! Denny!', 'Put it down.']|
#
# -- 638428 range D4 30-60, mean conf: 0.7372521162033081--
# rank 38, conf: 0.7602428197860718
# sent 1045389: |['Beats the hell out of video games.', "This isn't a game, okay? This is real. Deadly real."]|
#
# ----------SENT 872824 @11---------
# TEXT: |['I think so. What do you mean?', "I like seeing you. The part at the end of the night where we say good-bye... It's getting harder."]|
# MEAN CONF TOP100: 0.7335238456726074
#
# -- 872824 range D0 0-1, mean conf: 0.7335240840911865--
# rank 1, conf: 0.7335240840911865
# sent 84358: |['What do you mean?', 'She was really upset when you started ignoring her.']|
#
# -- 872824 range D1 1-10, mean conf: 0.7335240244865417--
# rank 2, conf: 0.7335240244865417
# sent 485130: |['What do you mean?', 'First half of the summer you play like straight trash. Then bam you back to the old Luc. I mean what’s going on?']|
#
# -- 872824 range D2 10-20, mean conf: 0.733523964881897--
# rank 14, conf: 0.7335240244865417
# sent 86297: |['What do you mean? The Coronation.', "It's the Queen's. Queen Elizabeth."]|
#
# -- 872824 range D3 20-30, mean conf: 0.733523964881897--
# rank 30, conf: 0.7335240244865417
# sent 344650: |['What do you mean? Yesterday you said I was too pretty to pay for stuff!', 'It’s just I can’t because my manager said I…']|
#
# -- 872824 range D4 30-60, mean conf: 0.7335240840911865--
# rank 38, conf: 0.7335240244865417
# sent 746959: |['What do you mean?', "Well, the day he got back, Jackson and I went into the diner and I asked him how his trip went. He couldn't get away from me fast enough."]|
#
# ----------SENT 247554 @12---------
# TEXT: |["Hey, what's with the skirt?", "I've brought friends to this treehouse before."]|
# MEAN CONF TOP100: 0.7297527194023132
#
# -- 247554 range D0 0-1, mean conf: 0.7666223645210266--
# rank 2, conf: 0.7666223645210266
# sent 993709: |["That's more you than you've ever been. Hey, what is with the pink lining?", "I don't know. It's got a pink lining."]|
#
# -- 247554 range D1 1-10, mean conf: 0.7532913684844971--
# rank 9, conf: 0.7438880205154419
# sent 846755: |["So what's up with those two?", "Cliff notes… Liv goes to Whitmore, she's a new witch,and Bonnie's teaching her magic"]|
#
# -- 247554 range D2 10-20, mean conf: 0.737755298614502--
# rank 16, conf: 0.7377347946166992
# sent 83463: |["So what's with the sponsored silence?", "I've been thinking about something else. You said anything I wanted to know, just ask, all right?"]|
#
# -- 247554 range D3 20-30, mean conf: 0.7372013926506042--
# rank 28, conf: 0.7372013926506042
# sent 518761: |["So it's up to the four of us to stop him. Are you ready, Marceline? Marceline? Hey, what's wrong?", 'Me, I guess.']|
#
# -- 247554 range D4 30-60, mean conf: 0.7326662540435791--
# rank 46, conf: 0.7343037724494934
# sent 1024392: |["Hey, what's happenin.'", "Well, you know, Poppie's over at my place. Tonight's the big night. I'm gonna make the first test pizza at the restaurant."]|
#
# ----------SENT 376843 @13---------
# TEXT: |["Not with staff. Cleaning crew? I don't know. You'd have to ask them.", 'And where could we find them?']|
# MEAN CONF TOP100: 0.7256340384483337
#
# -- 376843 range D0 0-1, mean conf: 0.758938729763031--
# rank 2, conf: 0.758938729763031
# sent 258048: |["You'd have to ask him that.", 'So why exactly do we need your help?']|
#
# -- 376843 range D1 1-10, mean conf: 0.753885805606842--
# rank 11, conf: 0.7522892355918884
# sent 326387: |['You had to ask.', 'Yeah.']|
#
# -- 376843 range D2 10-20, mean conf: 0.7513989210128784--
# rank 17, conf: 0.751102089881897
# sent 1060375: |['Do you have to ask?', "Woody's, after work."]|
#
# -- 376843 range D3 20-30, mean conf: 0.746981680393219--
# rank 26, conf: 0.746734619140625
# sent 960439: |['Now, I have to ask: have you been drinking?', 'Not a drop.']|
#
# -- 376843 range D4 30-60, mean conf: 0.7281943559646606--
# rank 42, conf: 0.7310247421264648
# sent 572917: |['Yes. You have made me feel strangely. If it were allowed, I would ask that you have another drill thrall.', "I wouldn't like that, Shahna. I wouldn't like that at all."]|
#
# ----------SENT 877477 @14---------
# TEXT: |["I'm sorry, did you say-", 'Crib!']|
# MEAN CONF TOP100: 0.7246384024620056
#
# -- 877477 range D0 0-1, mean conf: 0.7786228656768799--
# rank 2, conf: 0.7786228656768799
# sent 1056907: |["I'm sorry, I didn't...", "I get it, Phoebe, better than anyone, I know what you're going through. It'll rip you apart if you let it."]|
#
# -- 877477 range D1 1-10, mean conf: 0.773388147354126--
# rank 7, conf: 0.7743738889694214
# sent 516405: |["Okay. I'm sorry I did that.", "It's alright. It's only, like, the fifth room you've train-wrecked this month."]|
#
# -- 877477 range D2 10-20, mean conf: 0.7469924688339233--
# rank 14, conf: 0.7559919953346252
# sent 39881: |["I'm sorry, Grandfather, I can't do it.", 'This instant!']|
#
# -- 877477 range D3 20-30, mean conf: 0.7288764715194702--
# rank 28, conf: 0.7250326871871948
# sent 379929: |["I'm afraid I can't do that, Leela.", "What's happening? Space cow?"]|
#
# -- 877477 range D4 30-60, mean conf: 0.7200039625167847--
# rank 59, conf: 0.7162865996360779
# sent 279889: |["Neither do I, I'm afraid.", 'How about you, Hector?']|
#
# ----------SENT 477328 @15---------
# TEXT: |["Oh, I don't know. Maybe because it's my home?", 'Oh, well, my home was in Los Angeles, a home I gave up to be closer to you, because your work was here.']|
# MEAN CONF TOP100: 0.7127518057823181
#
# -- 477328 range D0 0-1, mean conf: 0.7658951282501221--
# rank 2, conf: 0.7658951282501221
# sent 76132: |['Because that was the proper place for us.', 'What was all that business about the flute?']|
#
# -- 477328 range D1 1-10, mean conf: 0.7464157342910767--
# rank 7, conf: 0.7420673370361328
# sent 37505: |["Well, maybe everyone's really, really quiet.", "Yeah, maybe. But they'd still show up on the system."]|
#
# -- 477328 range D2 10-20, mean conf: 0.7270784974098206--
# rank 20, conf: 0.7210904955863953
# sent 1072540: |["Boy, this place isn't quite the same around here since you're left.", "Boy, so I've noticed."]|
#
# -- 477328 range D3 20-30, mean conf: 0.7165733575820923--
# rank 29, conf: 0.713590145111084
# sent 739573: |["That's because this is a right comfy couch.", 'Maybe I should stay.']|
#
# -- 477328 range D4 30-60, mean conf: 0.710655152797699--
# rank 46, conf: 0.7112426161766052
# sent 855833: |['Because it is past the fifth most profitable films.', "I do not care. I will take it to my grave. It's a silly movie anyway!"]|
#
# ----------SENT 937394 @16---------
# TEXT: |['Me, too. We should call your dad.', "Sure, nobody can change somebody's mind like my dad, but he's not going to leave my mom, and the airlines won't let women fly in their ninth month of pregnancy."]|
# MEAN CONF TOP100: 0.6657986640930176
#
# -- 937394 range D0 0-1, mean conf: 0.7434118390083313--
# rank 2, conf: 0.7434118390083313
# sent 459418: |["Yeah, that's what I want. Listen, have your dad call me with an estimate.", 'My uncle?']|
#
# -- 937394 range D1 1-10, mean conf: 0.7328072786331177--
# rank 7, conf: 0.7345095276832581
# sent 977427: |['Well, for starters, call my dad.', "Jack, think about what you're saying..."]|
#
# -- 937394 range D2 10-20, mean conf: 0.7035844326019287--
# rank 16, conf: 0.705020546913147
# sent 486026: |["It's my company. And please do me a favor... call her Victoria. Don't call her my mom.", 'Okay.']|
#
# -- 937394 range D3 20-30, mean conf: 0.6691402196884155--
# rank 23, conf: 0.684511661529541
# sent 937771: |["I can't dean Kim would call my dad, or worse my mom", 'ok, how about after school?']|
#
# -- 937394 range D4 30-60, mean conf: 0.6513406038284302--
# rank 48, conf: 0.650433361530304
# sent 279667: |['Is my dad crying?', "I think your dad's crying because he's happy. He's happy he got you back."]|
#
# ----------SENT 310581 @17---------
# TEXT: |['Two years later he kills Conc- Cement Head.', "She hoodwinked you 'cause she was hot."]|
# MEAN CONF TOP100: 0.6486203074455261
#
# -- 310581 range D0 0-1, mean conf: 0.6616238951683044--
# rank 2, conf: 0.6616238951683044
# sent 365621: |["Wow! Didn't she die like five years ago?", "No, she just died today! Okay, umm, we're having a memorial service tomorrow."]|
#
# -- 310581 range D1 1-10, mean conf: 0.6538304686546326--
# rank 10, conf: 0.650765061378479
# sent 861956: |['That grandpa died three years ago.', 'His favorite grandson is getting married, Ted. I think he can take a day off from haunting the barn to make an appearance.']|
#
# -- 310581 range D2 10-20, mean conf: 0.6494791507720947--
# rank 17, conf: 0.6492776274681091
# sent 255532: |['Thirty-four years old.', 'Time enough to start over with a new man.']|
#
# -- 310581 range D3 20-30, mean conf: 0.6489425897598267--
# rank 28, conf: 0.6488852500915527
# sent 1049151: |["That's it. It's the only way. It's the only way to save the one's I love. I should've done it before. Eight years ago.", "I didn't want to."]|
#
# -- 310581 range D4 30-60, mean conf: 0.6481685042381287--
# rank 40, conf: 0.648469865322113
# sent 602137: |['Seventeen years ago.', "The Captain and I haven't risen from the grave. The ship's been fractured into different timeframes."]|
#
# ----------SENT 753792 @18---------
# TEXT: |['Maybe she wanted a chance to cool off.', "No, that's your mother. My mother's the kicker and the douser. No, Mrs. Kim is sending a message."]|
# MEAN CONF TOP100: 0.6460883021354675
#
# -- 753792 range D0 0-1, mean conf: 0.7540154457092285--
# rank 2, conf: 0.7540154457092285
# sent 287449: |['I just wanted a chance.', "Really, and you thought she'd overlook the fake photo that you put in there, too, huh?"]|
#
# -- 753792 range D1 1-10, mean conf: 0.7098754644393921--
# rank 8, conf: 0.7024357318878174
# sent 508546: |['You can call me whatever you want, as long as you let me buy you a drink after your shift. I already know Ruby. I want the chance to meet Red.', 'Um, tonight’s actually not great. Because-']|
#
# -- 753792 range D2 10-20, mean conf: 0.6639928221702576--
# rank 17, conf: 0.6588030457496643
# sent 471744: |['If you had the chance to get to know your real father, would you want to?', "Oh, wow. I mean, you know what? Before Ellie, I probably would have said no, but she was awesome. And, so, yeah, it does make me kind of wonder about my real dad sometimes. But... You know, then again, what if I meet him and I don't like him? So, sometimes I think it's just easier not to know and go with my own idealized version of him."]|
#
# -- 753792 range D3 20-30, mean conf: 0.6437662839889526--
# rank 29, conf: 0.6409100890159607
# sent 935100: |["he's offering us a second chance", 'I promised']|
#
# -- 753792 range D4 30-60, mean conf: 0.635543167591095--
# rank 48, conf: 0.6350687146186829
# sent 620562: |['Nietzschean beta is potent. Given the chance, we would drain you dry.', "You're a user. You must know Saguro. We need to find her."]|
#
# ----------SENT 965826 @19---------
# TEXT: |["We'll see.", 'Jen, the train leaves at 11:00. Make it. I mean, we need you back there.']|
# MEAN CONF TOP100: 0.6303102374076843
#
# -- 965826 range D0 0-1, mean conf: 0.6308761239051819--
# rank 1, conf: 0.6308761239051819
# sent 460350: |['We’ll see.', 'Why didn’t you tell me?']|
#
# -- 965826 range D1 1-10, mean conf: 0.6308761239051819--
# rank 9, conf: 0.6308761239051819
# sent 495639: |["We'll see.", "I've already seen, Gold. I've seen your dark heart and it always wins out. You always choose darkness."]|
#
# -- 965826 range D2 10-20, mean conf: 0.6308760643005371--
# rank 14, conf: 0.6308760643005371
# sent 148558: |["Start writing. We'll see.", 'Don, can I talk to you a sec?']|
#
# -- 965826 range D3 20-30, mean conf: 0.6308760643005371--
# rank 21, conf: 0.6308760643005371
# sent 669461: |["Yeah. We'll see.", 'I have an instinct.']|
#
# -- 965826 range D4 30-60, mean conf: 0.630771279335022--
# rank 33, conf: 0.6308760046958923
# sent 34849: |["We'll see.", "I promised Jackie I'd always take you back home."]|
#
# ----------SENT 290976 @20---------
# TEXT: |["Synovial gas, that's what the cracking is.", "Synovial gas, what's that mean?"]|
# MEAN CONF TOP100: 0.620566725730896
#
# -- 290976 range D0 0-1, mean conf: 0.6393014788627625--
# rank 2, conf: 0.6393014788627625
# sent 667644: |["Technically, that's what a demotion is.", "I don't know exactly what you have against me, but my record"]|
#
# -- 290976 range D1 1-10, mean conf: 0.6389865875244141--
# rank 3, conf: 0.6391538977622986
# sent 807978: |['There is stink in there, my God! What is... what is that?', "Oh... I don't know."]|
#
# -- 290976 range D2 10-20, mean conf: 0.6388558149337769--
# rank 12, conf: 0.638862133026123
# sent 585377: |["The Battle of Maxia, sir. That's what it is.", 'The Picard Manoeuvre. What is the defence against that, Data?']|
#
# -- 290976 range D3 20-30, mean conf: 0.633285641670227--
# rank 28, conf: 0.6310362219810486
# sent 702094: |["That's what this is.", 'System already hardened you?']|
#
# -- 290976 range D4 30-60, mean conf: 0.6201183795928955--
# rank 48, conf: 0.6182757616043091
# sent 649829: |["That's exactly what it was.", "Ah. So, tell me more about what's happening to you. What does it all mean?"]|
#
# ----------SENT 293587 @21---------
# TEXT: |['You invited me to dinner.', 'Why?']|
# MEAN CONF TOP100: 0.5948398113250732
#
# -- 293587 range D0 0-1, mean conf: 0.606468677520752--
# rank 2, conf: 0.606468677520752
# sent 841242: |['My husband will get to kick out you. We should you invite to dinner sometime.', 'Damon? What did you do to Gail?']|
#
# -- 293587 range D1 1-10, mean conf: 0.6020616292953491--
# rank 4, conf: 0.6055027842521667
# sent 178979: |["You didn't seriously invite him to dinner.", 'Clark, Mr. Lane is a three-star general. I think he deserves a little respect.']|
#
# -- 293587 range D2 10-20, mean conf: 0.5960953831672668--
# rank 12, conf: 0.598345160484314
# sent 425104: |['Allow us to treat you to dinner.', 'What a great way to apologize.']|
#
# -- 293587 range D3 20-30, mean conf: 0.5947445034980774--
# rank 22, conf: 0.5948657989501953
# sent 212595: |["Oh, so now you're quitting dinner, too.", 'Homer, please.']|
#
# -- 293587 range D4 30-60, mean conf: 0.594147264957428--
# rank 52, conf: 0.5939858555793762
# sent 1001696: |['When we were little girls Grandma Memma would take us to a matinee and then dinner here.', 'Grandma Memma?']|
#
# ----------SENT 590009 @22---------
# TEXT: |['You got it, partner.', 'This is a result of the experimental interface?']|
# MEAN CONF TOP100: 0.5880370736122131
#
# -- 590009 range D0 0-1, mean conf: 0.5888823866844177--
# rank 2, conf: 0.5888823866844177
# sent 405253: |['Uh, couple of weak partials. What you got, partner?', 'Newspapers. I found them in the carport.']|
#
# -- 590009 range D1 1-10, mean conf: 0.5884928107261658--
# rank 8, conf: 0.5884757041931152
# sent 191947: |['Go get it, pal.', 'My quarter!!!']|
#
# -- 590009 range D2 10-20, mean conf: 0.5881310701370239--
# rank 12, conf: 0.5881815552711487
# sent 80477: |['Have you got it?', 'I can only just about reach it.']|
#
# -- 590009 range D3 20-30, mean conf: 0.5880300998687744--
# rank 25, conf: 0.588043749332428
# sent 752099: |['Okay you got it.', 'Check in with me later.']|
#
# -- 590009 range D4 30-60, mean conf: 0.5879534482955933--
# rank 46, conf: 0.5879521369934082
# sent 930490: |['You got it.', 'Talked to Oswald.']|
#
# ----------SENT 795617 @23---------
# TEXT: |["I'm on a sale!", "Listen to me. It's two p.m. From now until four, your priority is knitting. Knit like the wind."]|
# MEAN CONF TOP100: 0.5841270089149475
#
# -- 795617 range D0 0-1, mean conf: 0.6034845113754272--
# rank 2, conf: 0.6034845113754272
# sent 273884: |["I'm on the nanny.", 'I thought you said no hot chicks.']|
#
# -- 795617 range D1 1-10, mean conf: 0.6031924486160278--
# rank 6, conf: 0.6031923294067383
# sent 391150: |["Working on a real TV show is so exciting! I'm on a mostly natural high!", 'These costumes are gonna make it hard to go to the bathroom.']|
#
# -- 795617 range D2 10-20, mean conf: 0.6026361584663391--
# rank 12, conf: 0.6029455065727234
# sent 60751: |['I was on the beat.', "Carry it. I'll make sure you don't need to use it."]|
#
# -- 795617 range D3 20-30, mean conf: 0.6008425951004028--
# rank 22, conf: 0.6015906929969788
# sent 911424: |['I can’t! I’m on the toilet!', 'For God’s sake, I don’t need to hear that! Can’t you just say, I’m busy?']|
#
# -- 795617 range D4 30-60, mean conf: 0.5810974836349487--
# rank 41, conf: 0.5816873908042908
# sent 1002545: |["I'm on no sleep, bro.", 'Problem in the bedroom?']|
#
# ----------SENT 561519 @24---------
# TEXT: |["If the information your AI uncovered is true, she's been planning this for months.", 'She knew that her scouts would locate me eventually and bring me to Terazed, knew that there would be a referendum.']|
# MEAN CONF TOP100: 0.5820360779762268
#
# -- 561519 range D0 0-1, mean conf: 0.6625779271125793--
# rank 2, conf: 0.6625779271125793
# sent 561075: |['And if this were the old days, I would note this in my permanent files.', 'So you want to lodge an official protest against inviting Doge Miskich on board.']|
#
# -- 561519 range D1 1-10, mean conf: 0.6283185482025146--
# rank 3, conf: 0.6470769643783569
# sent 139910: |["They don't walk the first year. And she won't know for a few years. You have a few years to decide, if that's your concern.", "A few years? We started at one year, and now we're at a few years. Dad, we're moving in the wrong direction."]|
#
# -- 561519 range D2 10-20, mean conf: 0.6051037907600403--
# rank 15, conf: 0.6091565489768982
# sent 580911: |["There aren't any ships or inhabited systems for several light years.", 'I wonder if this could be Zephram Cochrane. They say he was piloting a one-man vessel when he disappeared.']|
#
# -- 561519 range D3 20-30, mean conf: 0.5929771661758423--
# rank 31, conf: 0.5895714163780212
# sent 553172: |["Is it true that he'll be retiring after this mission?", "Unofficially, that's what I hear. What a crowning achievement for his career. The benefits of relations with the Legarans are incalculable."]|
#
# -- 561519 range D4 30-60, mean conf: 0.5789661407470703--
# rank 54, conf: 0.5749917030334473
# sent 649912: |['She was careless with her thoughts. The result was violence.', "B'Elanna's not used to being around telepaths. That doesn't make her guilty."]|
#
# ----------SENT 151003 @25---------
# TEXT: |["Fantastic. So good, in fact, they took him off suicide watch yesterday. Banner freakin' day in the Cook household, let me tell ya.", "Is he gettin' better?"]|
# MEAN CONF TOP100: 0.5713487863540649
#
# -- 151003 range D0 0-1, mean conf: 0.5978930592536926--
# rank 2, conf: 0.5978930592536926
# sent 184441: |['You encourage him, Elijah, but he grows more pathetic every day.', "I'm not pathetic."]|
#
# -- 151003 range D1 1-10, mean conf: 0.5945138335227966--
# rank 9, conf: 0.5943753719329834
# sent 367958: |['Hi! Hey, Happy Valentine’s Day!', 'Oh, you, too.']|
#
# -- 151003 range D2 10-20, mean conf: 0.5824052095413208--
# rank 15, conf: 0.583748996257782
# sent 175246: |['Busy day, Ms. Lane?', 'Does breaking and entering not mean anything to rich people?']|
#
# -- 151003 range D3 20-30, mean conf: 0.5757876634597778--
# rank 22, conf: 0.5766927003860474
# sent 614502: |['Not today, Vorik.', "Good morning. Here's the helm control evaluation you wanted."]|
#
# -- 151003 range D4 30-60, mean conf: 0.5713658928871155--
# rank 50, conf: 0.570542573928833
# sent 252539: |['Mmmm, delicious. Smithers, every year you outstrip yourself in succulence.', 'Thank you, sir. Oh, would you like some candied yams?']|
#
# ----------SENT 92290 @26---------
# TEXT: |['Your whole life, I tried to prepare you for the day you would become King. Did you learn nothing?', 'I watched you rule, and I learnt that if you trust no-one, you will always live in fear. Your hatred came from fear, not strength.']|
# MEAN CONF TOP100: 0.49936172366142273
#
# -- 92290 range D0 0-1, mean conf: 0.5066688060760498--
# rank 2, conf: 0.5066688060760498
# sent 884806: |['Have you learned nothing? As long as you are alive...', "Then I'll die."]|
#
# -- 92290 range D1 1-10, mean conf: 0.50136399269104--
# rank 8, conf: 0.5003036856651306
# sent 442466: |["We tried everything, from papier-m<e2>ch<e9> to making birds' nests, and nothing worked.", "What's so funny?"]|
#
# -- 92290 range D2 10-20, mean conf: 0.49963751435279846--
# rank 12, conf: 0.49999698996543884
# sent 87386: |["Well, nothing's changed there, then.", 'But, in time, I came to respect him for what he stands for, what he does.']|
#
# -- 92290 range D3 20-30, mean conf: 0.4994029402732849--
# rank 23, conf: 0.49946603178977966
# sent 236053: |["It's all my fault: Homer wanted to serve those little cocktail hot dogs. But no. I had to have spring rolls! They taste like nothing!", "I don't understand. Dad would never miss an open bar with chicken wings. Plus he loves Mom, and us, yada, yada, yada."]|
#
# -- 92290 range D4 30-60, mean conf: 0.49904102087020874--
# rank 44, conf: 0.49901095032691956
# sent 10527: |['No movement, nothing.', "Good. Let's get back to the Tardis. Off you go. Come on. Off you go."]|
#
# ----------SENT 498301 @27---------
# TEXT: |['If that’s true, then that means-', 'We’re from the future, mate.']|
# MEAN CONF TOP100: 0.49914801120758057
#
# -- 498301 range D0 0-1, mean conf: 0.4992739260196686--
# rank 2, conf: 0.4992739260196686
# sent 342769: |['Wow! That’s ah, that’s pretty nice!', 'Pretty nice?']|
#
# -- 498301 range D1 1-10, mean conf: 0.49923861026763916--
# rank 4, conf: 0.4992561936378479
# sent 342384: |['That’s okay.', 'Can I talk to you for a second?!']|
#
# -- 498301 range D2 10-20, mean conf: 0.4991726279258728--
# rank 13, conf: 0.49918946623802185
# sent 364384: |['Wow, that’s great.', 'Oh, yeah!']|
#
# -- 498301 range D3 20-30, mean conf: 0.49916166067123413--
# rank 30, conf: 0.49916166067123413
# sent 916714: |['That’s great. Get out.', 'What? Why?']|
#
# -- 498301 range D4 30-60, mean conf: 0.49914318323135376--
# rank 38, conf: 0.49916163086891174
# sent 342620: |['You’re kidding?! That’s great!', 'Oh, it was so amazing. After the']|
#
# ----------SENT 594805 @28---------
# TEXT: |['Thanks, Worf.', 'Wesley, was our attempt to make you uncomfortable effective?']|
# MEAN CONF TOP100: 0.4758656322956085
#
# -- 594805 range D0 0-1, mean conf: 0.4758657217025757--
# rank 1, conf: 0.4758657217025757
# sent 930725: |['Thanks, Rat.', "How's Tara doing?"]|
#
# -- 594805 range D1 1-10, mean conf: 0.4758657217025757--
# rank 10, conf: 0.4758656919002533
# sent 237126: |['Ooh, Thanks, Dad.', "What's that stone around your neck?"]|
#
# -- 594805 range D2 10-20, mean conf: 0.4758656919002533--
# rank 14, conf: 0.4758656919002533
# sent 478083: |['Thanks, Jamie.', 'Hey, daddy, when you married mama, was it your best day ever?']|
#
# -- 594805 range D3 20-30, mean conf: 0.4758656919002533--
# rank 25, conf: 0.4758656919002533
# sent 305431: |['Thanks, Hodgins.', '...Angela.']|
#
# -- 594805 range D4 30-60, mean conf: 0.4758656322956085--
# rank 32, conf: 0.4758656620979309
# sent 220654: |['Thanks, Bart.', 'Less talk, more sleep.']|
#
# ----------SENT 628760 @29---------
# TEXT: |["You're willing to risk your rank, your career, over this?", 'Have you ever been in love, Captain?']|
# MEAN CONF TOP100: 0.4624847173690796
#
# -- 628760 range D0 0-1, mean conf: 0.4991769790649414--
# rank 2, conf: 0.4991769790649414
# sent 541486: |["We'd need approximately fifty trillion nanoprobes to arm this mine. It would take the Doctor several weeks to replicate that amount. You are losing this conflict. Are you willing to risk further delay?", 'Right now your enemy believes it is invulnerable. If we create smaller weapons using our torpedoes and destroy a few of their bioships, it may deter them, convince them to give up this war.']|
#
# -- 628760 range D1 1-10, mean conf: 0.4898642897605896--
# rank 4, conf: 0.4990581274032593
# sent 890793: |['Are you willing to risk it?', 'Curse you.']|
#
# -- 628760 range D2 10-20, mean conf: 0.46618276834487915--
# rank 16, conf: 0.4667879045009613
# sent 934474: |["you don't realise how lucky you are", 'that my dad showed up an humiliated me...?']|
#
# -- 628760 range D3 20-30, mean conf: 0.46161746978759766--
# rank 28, conf: 0.46122512221336365
# sent 193397: |['All right, all right, all right. Would you be willing to wear a hidden camera and microphone?', "Oh, that I'll wear."]|
#
# -- 628760 range D4 30-60, mean conf: 0.459194540977478--
# rank 46, conf: 0.4592074751853943
# sent 686119: |["No, you can pay it out in installments if you want. Monthly, bimonthly, whatever - whatever you're comfortable with.", "So, let me get this straight. Uh, you and some guys who actually know what they're doing are gonna come over and fix my house, and I can pay them back whenever I want?"]|
#
# ----------SENT 979025 @30---------
# TEXT: |['Hey, news flash, Pacey. You hate Drue.', "Yes, I do, but it's only a ride home. And I'm trying to be a better person, just like you. Besides, it's a karma thing."]|
# MEAN CONF TOP100: 0.45945292711257935
#
# -- 979025 range D0 0-1, mean conf: 0.4644050896167755--
# rank 1, conf: 0.4644050896167755
# sent 481805: |['You hated Chairy.', 'Hey! "Hate" is a strong word. I just thought Chairy\'s best days were behind him.']|
#
# -- 979025 range D1 1-10, mean conf: 0.4630180895328522--
# rank 9, conf: 0.4619477689266205
# sent 970619: |['Andie hates me.', "When a girl hates you the way Andie hates you, it really means that she likes you. That's basic kindergarten psychology."]|
#
# -- 979025 range D2 10-20, mean conf: 0.4604736864566803--
# rank 18, conf: 0.4602908492088318
# sent 895816: |['Just dandy, Mr I-Wish-I-Was-Better-At-Improv.', 'Read another one.']|
#
# -- 979025 range D3 20-30, mean conf: 0.45989546179771423--
# rank 28, conf: 0.4598616659641266
# sent 374728: |['I made lemonade. James loves my lemonade.', 'Who else was home?']|
#
# -- 979025 range D4 30-60, mean conf: 0.45908594131469727--
# rank 43, conf: 0.4591851234436035
# sent 164272: |["Then, why have you been avoiding me, Chloe? It's been weeks since I brought you back from that hospital in the Yukon where I found you.", "I've been busy, Lex."]|
#
# ----------SENT 536975 @31---------
# TEXT: |['It was last-minute. I needed some warm bodies.', "Which would explain why I'm here."]|
# MEAN CONF TOP100: 0.45339149236679077
#
# -- 536975 range D0 0-1, mean conf: 0.46087056398391724--
# rank 2, conf: 0.46087056398391724
# sent 303911: |['She thinks the work deserves our full concentration. I need the skull now.', "Well, I'm still finding particulates. And since you're only Dr. Brennan's assistant without her, you don't carry all that much weight around here."]|
#
# -- 536975 range D1 1-10, mean conf: 0.45810064673423767--
# rank 8, conf: 0.4579067528247833
# sent 403084: |['Why do you need my DNA?', 'To prove that you also attacked Heather Kessler.']|
#
# -- 536975 range D2 10-20, mean conf: 0.45538783073425293--
# rank 19, conf: 0.45480868220329285
# sent 522108: |["No. But this poison is similar but way more efficient. I think I've seen it before but it's hard to tell without testing, and we don't have that kind of time. Give us some privacy. I need to remove her clothing.", 'I will be just outside. I am so sorry.']|
#
# -- 536975 range D3 20-30, mean conf: 0.45409947633743286--
# rank 24, conf: 0.4542446732521057
# sent 831736: |["It doesn't feel right. Maybe I need a bigger map.", 'Maybe you started practising, you suck at magic now.']|
#
# -- 536975 range D4 30-60, mean conf: 0.4528960883617401--
# rank 57, conf: 0.4525604248046875
# sent 38237: |['Not a dickie bird. So let me get this right. You need that crystal? Then consider it done.', 'Why, what do you mean? Christina? Christina!']|
#
# ----------SENT 81159 @32---------
# TEXT: |["I can't change what's already happened. There are rules.", "So break them. And anyway, you owe me. You've made yourself essential to me. You've given me something else to, to be. And you can't do that and then die. It's not fair."]|
# MEAN CONF TOP100: 0.4524010121822357
#
# -- 81159 range D0 0-1, mean conf: 0.4774226248264313--
# rank 1, conf: 0.4774226248264313
# sent 81140: |["I can't change what's already happened. There are rules.", "So break them. And anyway, you owe me. You've made yourself essential to me. You've given me something else to, to be. And you can't do that and then die. It's not fair."]|
#
# -- 81159 range D1 1-10, mean conf: 0.47389882802963257--
# rank 3, conf: 0.4774225950241089
# sent 694638: |["There's rules?", 'Oh, yeah, especially for a true classic like "Casablanca." It\'s not like we\'re watching a there\'s-nothing-else-on movie or a guilty pleasure like "Hardbodies." Oh, my God. Have you seen "Hardbodies"?']|
#
# -- 81159 range D2 10-20, mean conf: 0.4551600515842438--
# rank 17, conf: 0.4553726315498352
# sent 410926: |["It's like a household cleanser. There's a pine smell.", 'Probably used to clean that diaper pail.']|
#
# -- 81159 range D3 20-30, mean conf: 0.4515228271484375--
# rank 30, conf: 0.450580358505249
# sent 1017846: |['There was no mistaking it?', 'Jerry.']|
#
# -- 81159 range D4 30-60, mean conf: 0.4495874345302582--
# rank 56, conf: 0.4489800035953522
# sent 199511: |["I'm a little disappointed. There were too many aprons.", 'It was great, all right. But all I wanna do right now is hit the adjustable sack with a good juice box. Because when all is said and done... Prison rodeo!?']|
#
# ----------SENT 54569 @33---------
# TEXT: |["That's strange.", 'Well?']|
# MEAN CONF TOP100: 0.4461475610733032
#
# -- 54569 range D0 0-1, mean conf: 0.44640377163887024--
# rank 1, conf: 0.44640377163887024
# sent 578776: |["That's strange.", "It made me think. We don't know that much about Malcolm, do we? (weird noise)"]|
#
# -- 54569 range D1 1-10, mean conf: 0.44640371203422546--
# rank 3, conf: 0.44640377163887024
# sent 612344: |["That's strange.", 'By observation alone, it appears they hit an invisible force field.']|
#
# -- 54569 range D2 10-20, mean conf: 0.4462992250919342--
# rank 13, conf: 0.44640374183654785
# sent 125609: |["That's strange.", "Yeah. I can't go down to autopsy."]|
#
# -- 54569 range D3 20-30, mean conf: 0.4461478292942047--
# rank 29, conf: 0.44614705443382263
# sent 179704: |["That's harsh.", "He was a corporate lawyer. That's the way he dealt with people."]|
#
# -- 54569 range D4 30-60, mean conf: 0.4461299777030945--
# rank 49, conf: 0.44613757729530334
# sent 174949: |["That's odd.", "That's Clark Kent. Can I ask why you're playing daddy Warbucks with the guy? 'Cause in my world, friends don't give friends $20,000 toys."]|
#
# ----------SENT 901050 @34---------
# TEXT: |['Oh, sounds serious. What’s up?', 'Okay, uh, here it is. I met this girl and I kissed her, and I feel terrible about it. But it’s done, it’s never gonna happen again. And I am so, so sorry.']|
# MEAN CONF TOP100: 0.43450626730918884
#
# -- 901050 range D0 0-1, mean conf: 0.4345068633556366--
# rank 1, conf: 0.4345068633556366
# sent 366408: |['What’s up?!', 'Umm, I think there’s something you should maybe know.']|
#
# -- 901050 range D1 1-10, mean conf: 0.4345068335533142--
# rank 9, conf: 0.4345068335533142
# sent 449868: |['Come on. Nobody loves a wedding more than Brooke Davis. What’s up?', 'I’d just appreciate if you wouldn’t talk to Peyton today.']|
#
# -- 901050 range D2 10-20, mean conf: 0.4345068335533142--
# rank 16, conf: 0.4345068335533142
# sent 339174: |['What’s up?', 'Well, I haven’t seen him since that night that he told me how he y’know… I don’t know, I think he’s avoiding me. Why is that bagel on the floor?']|
#
# -- 901050 range D3 20-30, mean conf: 0.4345068335533142--
# rank 24, conf: 0.4345068335533142
# sent 351782: |['Sure! What’s up?', 'Monica and I almost got married last night.']|
#
# -- 901050 range D4 30-60, mean conf: 0.43450674414634705--
# rank 60, conf: 0.4345068037509918
# sent 506729: |['She’s uh resting. What’s up?', 'Has either one of you seen Snow? She went to the stream but she hasn’t-']|
#
# ----------SENT 509612 @35---------
# TEXT: |['Ugh! Enough talking! Dinner is served!', 'No! [Pulls Eberhardt away before Marceline could bite him; Marceline attacks again.] No!']|
# MEAN CONF TOP100: 0.41602468490600586
#
# -- 509612 range D0 0-1, mean conf: 0.4168578088283539--
# rank 1, conf: 0.4168578088283539
# sent 199959: |['Dinner is served.', 'Mm, various eggs.']|
#
# -- 509612 range D1 1-10, mean conf: 0.41677606105804443--
# rank 3, conf: 0.416795015335083
# sent 593273: |['Dinner at eight?', "The data from the Barzan's probe of the wormhole are quite impressive, Captain. The wormhole delivered the probe beyond the Denkiri Arm, in the Gamma Quadrant."]|
#
# -- 509612 range D2 10-20, mean conf: 0.41674500703811646--
# rank 21, conf: 0.4167272746562958
# sent 140558: |['Enjoy your dinner.', 'Wait. Bill. Is that who Adrian is seeing?']|
#
# -- 509612 range D3 20-30, mean conf: 0.416715145111084--
# rank 30, conf: 0.416703462600708
# sent 695729: |['Dinner, et cetera.', 'Sounds good, et cetera.']|
#
# -- 509612 range D4 30-60, mean conf: 0.4165363311767578--
# rank 50, conf: 0.41651397943496704
# sent 693598: |["I can't skip dinner.", "Come on, we're gonna go to dinner next week and every week after that for the rest of our lives. And I do mean the rest of our lives because my parents will outlive us. The damned can do that."]|
#
# ----------SENT 43335 @36---------
# TEXT: |['Well, come quietly then.', 'And where are you taking me?']|
# MEAN CONF TOP100: 0.3631799519062042
#
# -- 43335 range D0 0-1, mean conf: 0.3637538254261017--
# rank 2, conf: 0.3637538254261017
# sent 681326: |["Well then don't come.", 'What?']|
#
# -- 43335 range D1 1-10, mean conf: 0.36343592405319214--
# rank 6, conf: 0.36345720291137695
# sent 369234: |["So he can't come?", "No, and so there's no one to walk me down the aisle and... well, I would just really love it if you would do it."]|
#
# -- 43335 range D2 10-20, mean conf: 0.3633551597595215--
# rank 13, conf: 0.36336082220077515
# sent 32335: |["Then you'll come?", "Oh, yes. Nothing's going to make me miss this. I'll be there."]|
#
# -- 43335 range D3 20-30, mean conf: 0.3632468581199646--
# rank 22, conf: 0.3633241057395935
# sent 3903: |['Why did you come here, then?', 'Because my new little chum here seemed unhappy about something.']|
#
# -- 43335 range D4 30-60, mean conf: 0.3631592094898224--
# rank 46, conf: 0.36316126585006714
# sent 1065257: |['I almost didn’t come back.', 'We would have missed you.']|
#
# ----------SENT 583428 @37---------
# TEXT: |['Have you manufactured more data to support this claim?', 'A few weeks ago we came across an alien. He was adrift in what we believe was a transdimensional disturbance. The alien was inside a pod which was constructed of the same combination of alloys that make up the outer shell of the Spheres. He was a Sphere Builder.']|
# MEAN CONF TOP100: 0.14695850014686584
#
# -- 583428 range D0 0-1, mean conf: 0.1516706347465515--
# rank 2, conf: 0.1516706347465515
# sent 544520: |['I am intrigued. They are an unusual Collective with a compelling mission. But I require more data.', "That's why I want you to talk to Kurros yourself. See if he can answer your questions."]|
#
# -- 583428 range D1 1-10, mean conf: 0.1514315903186798--
# rank 9, conf: 0.15136811137199402
# sent 57289: |['Query imprecise. Additional data required.', "What's the matter with your warp drive?"]|
#
# -- 583428 range D2 10-20, mean conf: 0.15133196115493774--
# rank 21, conf: 0.15130479633808136
# sent 654938: |['Mine too. Rommie, contact Dylan. Transmit our data.', 'Transmitting. But Dylan is forty four light minutes out.']|
#
# -- 583428 range D3 20-30, mean conf: 0.15100353956222534--
# rank 22, conf: 0.15128138661384583
# sent 309478: |['Did you have any luck? Was the data damaged?', 'Uh, a bit. There might be still a few corrupted frames.']|
#
# -- 583428 range D4 30-60, mean conf: 0.1475767344236374--
# rank 46, conf: 0.14761245250701904
# sent 588600: |['Data launched that probe.', 'If he rigged it, could you prove it?']|
#
# ----------SENT 758879 @38---------
# TEXT: |['Oh, yeah.', 'Make it four.']|
# MEAN CONF TOP100: 0.024440724402666092
#
# -- 758879 range D0 0-1, mean conf: 0.02444072626531124--
# rank 1, conf: 0.02444072626531124
# sent 219320: |['Oh, yeah? Well, I dare you to yank his beard off.', 'Ah, touché!']|
#
# -- 758879 range D1 1-10, mean conf: 0.024440724402666092--
# rank 10, conf: 0.024440724402666092
# sent 136965: |["Oh, yeah? Well, Lauren's at home crying her eyes out because Jesse just broke up with her.", 'What? Why?']|
#
# -- 758879 range D2 10-20, mean conf: 0.024440724402666092--
# rank 13, conf: 0.024440724402666092
# sent 438557: |['Oh, yeah! Weird!', 'But, um, why were we so terrible before?']|
#
# -- 758879 range D3 20-30, mean conf: 0.024440724402666092--
# rank 25, conf: 0.024440724402666092
# sent 100993: |['Oh, yeah.', "Okay, this one will get you into all of the perimeter doors, this one into the evidence room, and this one's for my father's office."]|
#
# -- 758879 range D4 30-60, mean conf: 0.024440722540020943--
# rank 34, conf: 0.024440724402666092
# sent 985869: |['Oh, yeah.', "Yeah. So you're drinking?"]|
#
# ----------SENT 550852 @39---------
# TEXT: |['They forced me out.', 'No. That was your own damn stubborn pride.']|
# MEAN CONF TOP100: 0.012658209539949894
#
# -- 550852 range D0 0-1, mean conf: 0.015786761417984962--
# rank 2, conf: 0.015786761417984962
# sent 357985: |['That is not true. She did! She forced me!', 'Hey, we would still be living here if hadn’t gotten the question wrong!']|
#
# -- 550852 range D1 1-10, mean conf: 0.01457834430038929--
# rank 10, conf: 0.0133530767634511
# sent 30510: |['Trueman is the Chosen One and I will follow him forever. And he ordered me to destroy you.', "Clyde. You know me. I am never going to submit. I am going to fight this thing, and send it back. If I have to, I'll destroy it."]|
#
# -- 550852 range D2 10-20, mean conf: 0.013115888461470604--
# rank 14, conf: 0.013178988359868526
# sent 28298: |['Yes, she did! You she-devils want to destroy me!', 'No!']|
#
# -- 550852 range D3 20-30, mean conf: 0.012855115346610546--
# rank 22, conf: 0.012939941138029099
# sent 391987: |["You can't force me to operate.", 'Maybe not, but perhaps I can encourage you with my encouragement drill.']|
#
# -- 550852 range D4 30-60, mean conf: 0.012501141987740993--
# rank 34, conf: 0.012728996574878693
# sent 664030: |['All you have to do, Tyr, is give us the bones. They will become a banner around which we rally to destroy the Drago-Kazov, and build a great Nietzschean empire that our grandfathers could only imagine.', "Because you're just so superior. So superior you've become prisoner aboard a Commonwealth vessel."]|

# %% [markdown]
# ## V8:
#
# Manifest:
# * DEP: everything except det.
# * POS: all nouns.

# %%
data_v8 = data.loc[((data.head_info=='DEP') & (data.head_pos!='det')) | (data.head_pos.isin(set(['NN', 'NNS', 'NNP', 'NNPS',])))]
data_v8
# Out:
#           sent_id                        show_id            char_name char_id  \
# 5           78453                      DoctorWho              BARBARA   l8667
# 6          146223                   VeronicaMars             VERONICA  l30591
# 10        1059921                    Charmed1998                 ANDY   l6497
# 14         537460                       StarTrek              JANEWAY  l25466
# 18         662463                       StarTrek                PHLOX  l25490
# 19         642832                       StarTrek               HARPER   l1893
# 21         238693                    TheSimpsons  C. Montgomery Burns  a15869
# 23         526675                   GreysAnatomy                DEREK  l12263
# 31         580866                       StarTrek               ARCHER  l25486
# 32         971419                   DawsonsCreek               DAWSON   l7946
# 33         866034              HowIMetYourMother                ROBIN  l13772
# 36         642447                       StarTrek               HARPER   l1893
# 38         110457                           NCIS                GIBBS  l18791
# 40         403957                       CSIVerse                 NICK   l7486
# 42         788696                    TheOfficeUS              MICHAEL  l19352
# 44         790267                    TheOfficeUS              MICHAEL  l19352
# 45         189666                    TheSimpsons        Homer Simpson  a15835
# 48         511955                  AdventureTime                 Finn   a3415
# 49         805801                    TheOfficeUS                  JIM  l19347
# 52         730165                   GilmoreGirls                 RORY  l11613
# 53         585682                       StarTrek                RIKER  l25432
# 55         908523               TheBigBangTheory                PENNY   l4391
# 57         393226                       CSIVerse              GRISSOM   l7484
# 58         460395                    OneTreeHill                LUCAS  l19593
# 63         464165                    OneTreeHill               NATHAN  l19594
# 64         309155                          Bones               ANGELA   l5149
# 66         431264  MyLittlePonyFriendshipIsMagic               Rarity  a13095
# 72         578352                       StarTrek               ARCHER  l25486
# 76        1050595                    Charmed1998                 PRUE   l6494
# 80         545131                       StarTrek              JANEWAY  l25466
# ...           ...                            ...                  ...     ...
# 17160304   815378                    TheOfficeUS                KEVIN  l19354
# 17160306   384416                       Futurama               Bender   a8872
# 17160308   482160                    OneTreeHill                 CLAY  l19609
# 17160310   600643                       StarTrek             CHAKOTAY  l25467
# 17160311   538371                       StarTrek              JANEWAY  l25466
# 17160317   497238                  OnceUponATime               REGINA  l19395
# 17160318    66392                      DoctorWho                 GWEN   l9078
# 17160323   859388              HowIMetYourMother               BARNEY  l13774
# 17160327   649350                       StarTrek               NEELIX  l25473
# 17160328   885589                          Salem                 MARY  l23233
# 17160329   688919                   GilmoreGirls              LORELAI  l11612
# 17160330   660454                       StarTrek                 REED  l25489
# 17160331   183094                     Smallville                 TESS  l24621
# 17160336   443968                       TheLWord                ALICE  l15690
# 17160337   875528                     Buffyverse                BUFFY   l5648
# 17160344   749073                   GilmoreGirls               SOOKIE  l11619
# 17160346   373719                   TheMentalist               LISBON  l17674
# 17160349   709703                   GilmoreGirls                 RORY  l11613
# 17160350   174190                     Smallville                 LANA  l24615
# 17160352   548045                       StarTrek              JANEWAY  l25466
# 17160359    25432                      DoctorWho        SECOND DOCTOR   l8651
# 17160362   793175                    TheOfficeUS              MICHAEL  l19352
# 17160363  1006647                       Seinfeld               GEORGE  l23594
# 17160366   125325                           NCIS                 ABBY  l18806
# 17160368   774869                        Roswell                  MAX  l23046
# 17160370   860557              HowIMetYourMother               BARNEY  l13774
# 17160371   126524                           NCIS                 ABBY  l18806
# 17160373   537886                       StarTrek              JANEWAY  l25466
# 17160376   652290                       StarTrek                MCCOY  l25412
# 17160377   295962                          Bones              BRENNAN   l5146
#
#          head_info   head_pos      token  token_par  position  is_stop  \
# 5              DEP      advcl         be       hold        34     True
# 6              DEP   compound       drug    testing         5    False
# 10             DEP      ccomp         be      think       -18     True
# 14             POS         NN  deflector  deflector        61    False
# 18             DEP      nsubj  condition         be       -16    False
# 19             DEP       prep     beyond         be        24     True
# 21             POS         NN      blood      blood        63    False
# 23             DEP       mark         if         be         5     True
# 31             DEP       mark         if      agree         5     True
# 32             DEP   npadvmod     PERSON       know        15    False
# 33             POS         NN       info       info        63    False
# 36             DEP   npadvmod     PERSON         be       -19    False
# 38             DEP       dobj         me       tell        -8     True
# 40             DEP       dobj         it       help        -5     True
# 42             DEP  nsubjpass         he      dress         9     True
# 44             DEP        neg        not       need         4     True
# 45             POS        NNP     PERSON     PERSON         5    False
# 48             DEP     advmod      still         be        -3     True
# 49             DEP       prep      about  complaint       -11     True
# 52             DEP     advmod       just       feel         5     True
# 53             DEP       pobj       that       with        -5     True
# 55             DEP    auxpass         be    excited         3     True
# 57             DEP       prep         of     murder        -7     True
# 58             POS         NN        mom        mom        27    False
# 63             DEP        aux         do        get         8     True
# 64             POS        NNP        ORG        ORG        43    False
# 66             DEP        aux        can        get         6     True
# 72             POS         NN       fire       fire        12    False
# 76             DEP      advcl        hit         be       -17    False
# 80             POS        NNP        ORG        ORG        13    False
# ...            ...        ...        ...        ...       ...      ...
# 17160304       DEP        aux         to        run         3     True
# 17160306       DEP      nsubj          i      agree         2     True
# 17160308       DEP       prep       into     change        -7     True
# 17160310       DEP       pobj       ship         on       -13    False
# 17160311       DEP       dobj       cure   discover       -14    False
# 17160317       DEP       prep         of        out        -4     True
# 17160318       POS         NN       love       love        12    False
# 17160323       POS        NNP     PERSON     PERSON        20    False
# 17160327       POS        NNS        day        day        24    False
# 17160328       DEP       attr      enemy         be       -11    False
# 17160329       POS        NNP    General    General         0    False
# 17160330       DEP       prep         on      paint       -21     True
# 17160331       DEP     advmod        now         be         9     True
# 17160336       DEP      nsubj       that         go        11     True
# 17160337       DEP       dobj        her   remember        -9     True
# 17160344       POS         NN     budget     budget        20    False
# 17160346       DEP     advmod       once      bring       -27     True
# 17160349       DEP       pobj      honey        for        -4    False
# 17160350       DEP        aux         to         go         3     True
# 17160352       DEP        aux      could       wait        27     True
# 17160359       POS         NN     report     report        62    False
# 17160362       POS        NNP        GPE        GPE        72    False
# 17160363       DEP       mark       that        ask        14     True
# 17160366       POS        NNP        ORG        ORG       114    False
# 17160368       DEP       intj         no     PERSON         4     True
# 17160370       DEP       intj       okay         be        14    False
# 17160371       DEP      nsubj       that         be         4     True
# 17160373       POS         NN      price      price       109    False
# 17160376       POS        NNP        FAC        FAC        66    False
# 17160377       DEP       case         's     PERSON        -7     True
#
#                        head_text
# 5                  advcl|be|hold
# 6          compound|drug|testing
# 10                ccomp|be|think
# 14        NN|deflector|deflector
# 18            nsubj|condition|be
# 19                prep|beyond|be
# 21                NN|blood|blood
# 23                    mark|if|be
# 31                 mark|if|agree
# 32          npadvmod|PERSON|know
# 33                  NN|info|info
# 36            npadvmod|PERSON|be
# 38                  dobj|me|tell
# 40                  dobj|it|help
# 42            nsubjpass|he|dress
# 44                  neg|not|need
# 45             NNP|PERSON|PERSON
# 48               advmod|still|be
# 49          prep|about|complaint
# 52              advmod|just|feel
# 53                pobj|that|with
# 55            auxpass|be|excited
# 57                prep|of|murder
# 58                    NN|mom|mom
# 63                    aux|do|get
# 64                   NNP|ORG|ORG
# 66                   aux|can|get
# 72                  NN|fire|fire
# 76                  advcl|hit|be
# 80                   NNP|ORG|ORG
# ...                          ...
# 17160304              aux|to|run
# 17160306           nsubj|i|agree
# 17160308        prep|into|change
# 17160310            pobj|ship|on
# 17160311      dobj|cure|discover
# 17160317             prep|of|out
# 17160318            NN|love|love
# 17160323       NNP|PERSON|PERSON
# 17160327             NNS|day|day
# 17160328           attr|enemy|be
# 17160329     NNP|General|General
# 17160330           prep|on|paint
# 17160331           advmod|now|be
# 17160336           nsubj|that|go
# 17160337       dobj|her|remember
# 17160344        NN|budget|budget
# 17160346       advmod|once|bring
# 17160349          pobj|honey|for
# 17160350               aux|to|go
# 17160352          aux|could|wait
# 17160359        NN|report|report
# 17160362             NNP|GPE|GPE
# 17160363           mark|that|ask
# 17160366             NNP|ORG|ORG
# 17160368          intj|no|PERSON
# 17160370            intj|okay|be
# 17160371           nsubj|that|be
# 17160373          NN|price|price
# 17160376             NNP|FAC|FAC
# 17160377          case|'s|PERSON
#
# [5848314 rows x 11 columns]

# %%
model_v8, SENT_CATS_v8, FEATURE_CATS_v8 = get_train(data_v8, report_test_acc=False)
SENT_MAP_v8, INV_SENT_MAP_v8 = build_maps(data_v8)
# Out:
# <118938x921300 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5848314 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [02:25<00:00,  1.34it/s]
# 921300 921300

# %%
mi = ModelInspection(model_v8, SENT_MAP_v8, INV_SENT_MAP_v8, dialog_df=dialogs)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 754017 @0---------
# TEXT: |['I guess. You know, when I was with Dean, I always knew that no matter what happened, he would be there.', 'Dean was very dependable.']|
# MEAN CONF TOP100: 1.0681836605072021
#
# -- 754017 range D0 0-1, mean conf: 1.1625285148620605--
# rank 2, conf: 1.1625285148620605
# sent 395604: |["Not one word since high school. Listen, when we found that torso in the hole, on the crest of that hill ... I recognized the kid's shirt, and I knew he'd been with Leland, so ...", 'So you assumed your brother was capable of murder.']|
#
# -- 754017 range D1 1-10, mean conf: 1.1162421703338623--
# rank 5, conf: 1.1247273683547974
# sent 996615: |["parents had two constant arguments, while ah, they were driving, over either how fast my father was going, or how much gas was left in the tank.\xa0 My father had a standard defense for either one of these, it was always, that's because you're looking at it from an angle.\xa0 If you were over here -- it looks from where you're sitting, it looks like I'm doing 90 on empty... but that's because you're over there.\xa0 If you were over here you'd know I'm in the driveway with a full tank.?", "So George and I went up to NBC and we told them the idea for a series now we're just waiting to sign the contract."]|
#
# -- 754017 range D2 10-20, mean conf: 1.0956772565841675--
# rank 21, conf: 1.0903825759887695
# sent 468815: |["No. No, she's not doing that 5:00 a.M. Thing anymore, which her daddy would know if he was ever here.", 'All right, you know what? This is all just a bad dream, Haley James.']|
#
# -- 754017 range D3 20-30, mean conf: 1.0836856365203857--
# rank 31, conf: 1.0779842138290405
# sent 788215: |["You know that I'm very serious here.", 'Jan, listen, I promise that I will kick it up a notch. Bam!']|
#
# -- 754017 range D4 30-60, mean conf: 1.066813588142395--
# rank 37, conf: 1.073580265045166
# sent 570071: |["They know you've been here.", 'All they have is a mystery and no answers. Mister Sulu, signal the Transporter Chief. Four to beam up.']|
#
# ----------SENT 291068 @1---------
# TEXT: |["Okay, how could I put him in a locker I don't even have the key to?", 'Who has the key?']|
# MEAN CONF TOP100: 1.0392537117004395
#
# -- 291068 range D0 0-1, mean conf: 1.1141611337661743--
# rank 2, conf: 1.1141611337661743
# sent 247339: |["Wait, wait, wait. He's just a boy! Do you have to put him in jail?", "Well, we've gotta teach him a lesson somehow."]|
#
# -- 291068 range D1 1-10, mean conf: 1.104299783706665--
# rank 6, conf: 1.1051424741744995
# sent 686375: |['And I will not have my granddaughter driving around in some contraption you put together in auto shop.', 'Okay, can I just say something here?']|
#
# -- 291068 range D2 10-20, mean conf: 1.083975911140442--
# rank 13, conf: 1.093315601348877
# sent 422045: |['Good? Try awesomely amazing. That book is undeniably, unquestionably, un-put-down-able! But then I had to put it down; I was sent home before I could finish it.', "Well, I'm glad that's all this is about."]|
#
# -- 291068 range D3 20-30, mean conf: 1.0612828731536865--
# rank 26, conf: 1.0610610246658325
# sent 553863: |['Negative. Switching to manual. Fifty million kilometres to Pentarus Five. We may have to put down somewhere else.', 'Mister Crusher, scan for a class-M environment.']|
#
# -- 291068 range D4 30-60, mean conf: 1.03458571434021--
# rank 36, conf: 1.043027400970459
# sent 437029: |["Sorry, Rarity, but I had to put out the ragin' inferno.", 'Inferno? Where?']|
#
# ----------SENT 523652 @2---------
# TEXT: |["Do you have any idea what I've been through today? A friend would ask!", "Don't tell me how to be your friend. I'm the only one you got, <snip> damn it!"]|
# MEAN CONF TOP100: 0.9600251317024231
#
# -- 523652 range D0 0-1, mean conf: 1.1289122104644775--
# rank 2, conf: 1.1289122104644775
# sent 791127: |["OK, you don't have any idea what I've been through, so, let's...", "No, I don't!"]|
#
# -- 523652 range D1 1-10, mean conf: 1.035084843635559--
# rank 7, conf: 1.030766487121582
# sent 694849: |["Would have been pathetic if you hadn't.", "I can't do this."]|
#
# -- 523652 range D2 10-20, mean conf: 1.0051065683364868--
# rank 19, conf: 0.9958283305168152
# sent 25096: |["You've been in the year two thousand, haven't you?", 'Yes, but I hardly had time to follow the strip cartoons.']|
#
# -- 523652 range D3 20-30, mean conf: 0.9789897799491882--
# rank 22, conf: 0.9881346821784973
# sent 354065: |['Yeah, I’ve had them picked out since I was fourteen.', 'Oh no, it’s gonna be named after some snack or baked good isn’t it?']|
#
# -- 523652 range D4 30-60, mean conf: 0.9511268138885498--
# rank 32, conf: 0.9689158201217651
# sent 952179: |["yeah sorry um...I've jus ben really busy", 'course, packin an stuff']|
#
# ----------SENT 412349 @3---------
# TEXT: |["If you're going to drive all the way out here to dump a body, why not take another ten minutes and bury her?", "Guess it wasn't worth the killer's time."]|
# MEAN CONF TOP100: 0.9414557218551636
#
# -- 412349 range D0 0-1, mean conf: 1.0861737728118896--
# rank 2, conf: 1.0861737728118896
# sent 361254: |['How long it took to go back in the water?', 'Chandler, we can’t let this tape wreck Valentine’s Day!']|
#
# -- 412349 range D1 1-10, mean conf: 1.0121524333953857--
# rank 5, conf: 1.005828857421875
# sent 546331: |['It was going to take a while to replicate the supplies they needed, so we invited them back to the Flyer.', "That's when they must have gotten access to our systems."]|
#
# -- 412349 range D2 10-20, mean conf: 0.9763199687004089--
# rank 13, conf: 0.9841752648353577
# sent 688954: |['You waited until I left, you went into my room, and you took my pillow.', "Well, you weren't using it."]|
#
# -- 412349 range D3 20-30, mean conf: 0.9576505422592163--
# rank 31, conf: 0.9527960419654846
# sent 406313: |["I'll take a ride with you, but I'm going to pass on the Mexican food at 10:00 in the morning.", "No, I'd like to see Greg. I'm definitely in, yeah."]|
#
# -- 412349 range D4 30-60, mean conf: 0.9359292984008789--
# rank 51, conf: 0.9320498704910278
# sent 76837: |["Not exactly, but. No, it's funny, all of this today, because it got me thinking. Because the Doctor, he showed me such a remarkable life, and when he went, it just took me a long while to get over it.", "Me, too. You know, sometimes I think I've never stopped running."]|
#
# ----------SENT 594965 @4---------
# TEXT: |['Damage report, Mister Data.', 'Outer and inner hulls have been breached. Decks seven through twelve are exposed to space.']|
# MEAN CONF TOP100: 0.9041886925697327
#
# -- 594965 range D0 0-1, mean conf: 0.9259858131408691--
# rank 2, conf: 0.9259858131408691
# sent 649689: |['The damage report, Mister Neelix.', 'Aye, sir.']|
#
# -- 594965 range D1 1-10, mean conf: 0.9108149409294128--
# rank 9, conf: 0.9102823734283447
# sent 596879: |['Mister Data, report.', 'The ship has moved into warp, sir.']|
#
# -- 594965 range D2 10-20, mean conf: 0.9096945524215698--
# rank 15, conf: 0.9097450375556946
# sent 628064: |['Report, Mister Kim.', "8472 and the Hirogen, they've been beamed to one of the attacking ships."]|
#
# -- 594965 range D3 20-30, mean conf: 0.9059286117553711--
# rank 27, conf: 0.905645489692688
# sent 609410: |['Sensor readings, Mister Spock.', 'Negative, Captain. It has a protective screen. I cannot get through.']|
#
# -- 594965 range D4 30-60, mean conf: 0.9034997820854187--
# rank 36, conf: 0.9046082496643066
# sent 632254: |['Mister Worf, take charge of the Doctor. Mister Data, shut down the transmission.', "Vibration amplitude is increasing. It can't last much longer."]|
#
# ----------SENT 92314 @5---------
# TEXT: |['How long have you known Tyr?', "He's been in my service since he was a boy."]|
# MEAN CONF TOP100: 0.8447532057762146
#
# -- 92314 range D0 0-1, mean conf: 0.9226271510124207--
# rank 1, conf: 0.9226271510124207
# sent 474390: |['How long have you known Lucas?', 'Since 4th grade. I transferred in.']|
#
# -- 92314 range D1 1-10, mean conf: 0.8693233132362366--
# rank 11, conf: 0.8510932922363281
# sent 667658: |['If I had known Sloane was involved? Not a chance.', 'It was a little deceitful, right?']|
#
# -- 92314 range D2 10-20, mean conf: 0.8469575643539429--
# rank 17, conf: 0.8460386395454407
# sent 169795: |['How long have you known this?', '..A few weeks.']|
#
# -- 92314 range D3 20-30, mean conf: 0.8437628746032715--
# rank 28, conf: 0.843173086643219
# sent 868116: |["Nothing. Her name's Victoria, that's all I got. Wait, Claudia, Claudia would know.", "Well, Claudia's on her honeymoon. She'll be back in two weeks. Call her then."]|
#
# -- 92314 range D4 30-60, mean conf: 0.841469407081604--
# rank 58, conf: 0.8402878046035767
# sent 963783: |["Look, you don't know me, Joey, ok? You don't know what I'm capable of when I set my sights on something.", "Andie, you're a stubborn and determined person. There's nothing wrong with that."]|
#
# ----------SENT 873080 @6---------
# TEXT: |['I guess Giles had a big night planned tonight.', "Giles didn't set this up. Angel did."]|
# MEAN CONF TOP100: 0.8418344855308533
#
# -- 873080 range D0 0-1, mean conf: 0.9185304641723633--
# rank 2, conf: 0.9185304641723633
# sent 979972: |['I had a great time tonight, Pacey.', "Yeah, I'll take that."]|
#
# -- 873080 range D1 1-10, mean conf: 0.8904450535774231--
# rank 4, conf: 0.8981409072875977
# sent 31225: |['Yeah, see you, Mum, have a good evening.', 'You too. Bye, K9.']|
#
# -- 873080 range D2 10-20, mean conf: 0.8736006617546082--
# rank 19, conf: 0.8721969723701477
# sent 343777: |['Oh well, since I have that whole history with Rachel, I guess Phoebe.', 'Okay, great!']|
#
# -- 873080 range D3 20-30, mean conf: 0.8525317907333374--
# rank 31, conf: 0.8458954691886902
# sent 336133: |['I had a really nice time tonight.', "So did I. I'm really glad Monica asked us out."]|
#
# -- 873080 range D4 30-60, mean conf: 0.8373232483863831--
# rank 37, conf: 0.8411979675292969
# sent 483533: |['So maybe it’s good that we have a session without Nathan', 'Holding back hasn’t been our problem)']|
#
# ----------SENT 886248 @7---------
# TEXT: |["Well, just because you cannot see the world that lies beyond the horizon does not mean it's invisible. Eventually, we will see it.", 'You would look into the face of God?']|
# MEAN CONF TOP100: 0.8241363763809204
#
# -- 886248 range D0 0-1, mean conf: 0.824904203414917--
# rank 2, conf: 0.824904203414917
# sent 350446: |['Now, we’ll see.', 'Air hole! Air hole!!']|
#
# -- 886248 range D1 1-10, mean conf: 0.8246736526489258--
# rank 6, conf: 0.8246861100196838
# sent 329193: |['Yeah well, we’ll see.', 'You kissed her.']|
#
# -- 886248 range D2 10-20, mean conf: 0.8245164155960083--
# rank 17, conf: 0.8245358467102051
# sent 716021: |['No, but how will we see each other?', "Easy, weekends \x96 that's what they were invented for."]|
#
# -- 886248 range D3 20-30, mean conf: 0.8243598937988281--
# rank 26, conf: 0.8243906497955322
# sent 140754: |['Yeah, we will see.', "Come on. Bunny doesn't need me today and we should celebrate."]|
#
# -- 886248 range D4 30-60, mean conf: 0.8240618109703064--
# rank 46, conf: 0.8240864276885986
# sent 410523: |["You'll see it in your next paycheck.", 'More money, more problems.']|
#
# ----------SENT 966119 @8---------
# TEXT: |['We should probably just say good-bye forever right now.', 'Yeah, might as well.']|
# MEAN CONF TOP100: 0.7916550040245056
#
# -- 966119 range D0 0-1, mean conf: 0.9196997880935669--
# rank 2, conf: 0.9196997880935669
# sent 830458: |['How can you say that right now?', "Because I don't want you to be cured"]|
#
# -- 966119 range D1 1-10, mean conf: 0.8370963931083679--
# rank 3, conf: 0.9027977585792542
# sent 863981: |['What would College You say if he heard what you were saying right now?', 'Honestly? Probably something pretentious, and pseudo-intellectual, like...']|
#
# -- 966119 range D2 10-20, mean conf: 0.8077195882797241--
# rank 19, conf: 0.798451840877533
# sent 903855: |["No. No, they loved it. They, uh, couldn't say enough nice things about it.", "So what's the problem?"]|
#
# -- 966119 range D3 20-30, mean conf: 0.7918183207511902--
# rank 26, conf: 0.7915875315666199
# sent 826814: |["I didn't say it to him. I said it about him.", '...Jim.']|
#
# -- 966119 range D4 30-60, mean conf: 0.7857500910758972--
# rank 36, conf: 0.788364827632904
# sent 531945: |['Would you stop saying that?', 'Ok']|
#
# ----------SENT 477482 @9---------
# TEXT: |["The pizza was a good call. I'm glad you got it wrong. What?", 'I think we should adopt.']|
# MEAN CONF TOP100: 0.7876325845718384
#
# -- 477482 range D0 0-1, mean conf: 0.8606644868850708--
# rank 2, conf: 0.8606644868850708
# sent 727583: |["I'm so glad you got it.", 'Oh, yeah, totally.']|
#
# -- 477482 range D1 1-10, mean conf: 0.8535209894180298--
# rank 3, conf: 0.8584286570549011
# sent 587774: |["Good. I'm glad we've got that straightened out. Resume.", 'The place is called Risa, and believe me, Captain, it is a paradise. Warm tropical breezes, exotic food. Nothing to do but sit around all day and enjoy the quiet. And then']|
#
# -- 477482 range D2 10-20, mean conf: 0.8181986808776855--
# rank 15, conf: 0.8191555738449097
# sent 959542: |["well this is a disaster i'm gonna have'ta call Catherine Zita Jones's people I was tryin'a get her for the opening", 'you Marco how quickly can you get down to the Crab Shack an pick us up some fresh-']|
#
# -- 477482 range D3 20-30, mean conf: 0.8070739507675171--
# rank 25, conf: 0.8076766133308411
# sent 287088: |["Whoa, a little warning, dude, I'm only the Hulk when I get pissed.", "Listen, we'd like to talk to you about Ashley Clark."]|
#
# -- 477482 range D4 30-60, mean conf: 0.7874168157577515--
# rank 52, conf: 0.7820338606834412
# sent 487652: |["Are you sure we won't get in trouble for this?", 'Relax. I do this all the time.']|
#
# ----------SENT 729632 @10---------
# TEXT: |['Hey, we just saw Kwan and Steve. Oh, yeah? Wait, Lane was there, too, right?', 'Yeah.']|
# MEAN CONF TOP100: 0.7854046821594238
#
# -- 729632 range D0 0-1, mean conf: 0.8542582392692566--
# rank 2, conf: 0.8542582392692566
# sent 942714: |['Taylor was right there, right?', "Oh, yeah, oh, yeah; but she wasn't supposed to be talking to me. She would say something and then the therapist would say it again to me. Wow. It's crazy, huh?"]|
#
# -- 729632 range D1 1-10, mean conf: 0.8083561658859253--
# rank 4, conf: 0.8188161253929138
# sent 1024366: |['Uh, is Noreen there?', 'Yes she is...']|
#
# -- 729632 range D2 10-20, mean conf: 0.7956825494766235--
# rank 13, conf: 0.7965568900108337
# sent 961733: |['it sounds it, was uh was Julie there', "ugh yeah, you should'a seen the look she gave me like I was some scheming fortune hunter"]|
#
# -- 729632 range D3 20-30, mean conf: 0.7950933575630188--
# rank 24, conf: 0.795093297958374
# sent 150829: |['Cheerleaders. Was Meg there?', 'I think she was.']|
#
# -- 729632 range D4 30-60, mean conf: 0.7866722941398621--
# rank 38, conf: 0.7943556904792786
# sent 681395: |["Rory's there without you...", 'She is.']|
#
# ----------SENT 456590 @11---------
# TEXT: |["You had a right to be upset. I finally started walking again. I've got no business being in some guy's face.", 'Lucas kissed Peyton.']|
# MEAN CONF TOP100: 0.7803779244422913
#
# -- 456590 range D0 0-1, mean conf: 0.909503698348999--
# rank 2, conf: 0.909503698348999
# sent 966795: |['The other Joey. The carefree girl who knows how to drink and play strip poker and go away on a sailboat for a summer. The girl who can get up in front of a crowd of complete strangers and sing at a beauty pageant.', 'Other Joey?']|
#
# -- 456590 range D1 1-10, mean conf: 0.8418161869049072--
# rank 3, conf: 0.8782278895378113
# sent 909763: |['You got it, you girls are in charge.', 'Thank you.']|
#
# -- 456590 range D2 10-20, mean conf: 0.8041545748710632--
# rank 15, conf: 0.8067095875740051
# sent 299374: |['You get a notice to appear in front of a federal judge, you appear.', 'I assume this has something to do with the Gravedigger.']|
#
# -- 456590 range D3 20-30, mean conf: 0.7898105382919312--
# rank 31, conf: 0.7848894596099854
# sent 421193: |["Oh Twilight. Did those silly fillies finally get in yer head? You know there's no such thing as a curse.", "Apple Bloom, sweetie. You can't just stand there and tell me this isn't a curse."]|
#
# -- 456590 range D4 30-60, mean conf: 0.774407148361206--
# rank 39, conf: 0.779140830039978
# sent 299322: |["Gross? You got your finger in some guy's maxillary orbit.", "I don't think there's anything else to be learned here, so let's get this Popsicle back to the lab."]|
#
# ----------SENT 247623 @12---------
# TEXT: |['Thank you, Bart. Great job.', 'I knew the dog before he came to class.']|
# MEAN CONF TOP100: 0.7691912651062012
#
# -- 247623 range D0 0-1, mean conf: 0.7691915035247803--
# rank 1, conf: 0.7691915035247803
# sent 789888: |['Thank you, Michael.', "You're welcome. You're welcome, you're welcome. OK. So, let's dish."]|
#
# -- 247623 range D1 1-10, mean conf: 0.7691915035247803--
# rank 8, conf: 0.7691914439201355
# sent 921004: |['Thank you, Bernadette.', 'Zip it, pervert!']|
#
# -- 247623 range D2 10-20, mean conf: 0.7691913843154907--
# rank 15, conf: 0.7691914439201355
# sent 723337: |['Thank you, Richard.', 'So how long are you going to keep him?']|
#
# -- 247623 range D3 20-30, mean conf: 0.7691913843154907--
# rank 27, conf: 0.7691914439201355
# sent 867046: |['Thank you, Lil.', "I think Lori's age made him very wise."]|
#
# -- 247623 range D4 30-60, mean conf: 0.7691915035247803--
# rank 45, conf: 0.7691914439201355
# sent 1067472: |['Thank you, Teddy.', "I'm sure you can use it."]|
#
# ----------SENT 151043 @13---------
# TEXT: |["Hey, how's it going?", 'All right.']|
# MEAN CONF TOP100: 0.7664394378662109
#
# -- 151043 range D0 0-1, mean conf: 0.7675526738166809--
# rank 1, conf: 0.7675526738166809
# sent 1060382: |["Hey, how is it goin'?", "I'm not interested."]|
#
# -- 151043 range D1 1-10, mean conf: 0.7675526142120361--
# rank 10, conf: 0.7675526142120361
# sent 295595: |["Hey, How's it going?", 'What? What are you doing here?']|
#
# -- 151043 range D2 10-20, mean conf: 0.7675525546073914--
# rank 17, conf: 0.7675526142120361
# sent 682757: |["Hey, how's it going?", "Oh, now that' s just too easy."]|
#
# -- 151043 range D3 20-30, mean conf: 0.7674024701118469--
# rank 26, conf: 0.7675213813781738
# sent 940764: |['hey, hows it goin', 'great, look I gotta get ta the lock in']|
#
# -- 151043 range D4 30-60, mean conf: 0.7661661505699158--
# rank 42, conf: 0.7660146355628967
# sent 590368: |["Deanna mentioned that you went to bed early because you were feeling a little anxious about the play, but I had no idea. You said that in your dream, we performed the play. How'd it go?", 'It was a smash. We got a standing ovation.']|
#
# ----------SENT 498441 @14---------
# TEXT: |['Maybe she feels the same way about pirates as you do about magic.', "I've worked to change. Though, in fairness, being a pirate is not necessarily a bad thing. Particularly a charming one like meself."]|
# MEAN CONF TOP100: 0.750699520111084
#
# -- 498441 range D0 0-1, mean conf: 0.8007674217224121--
# rank 2, conf: 0.8007674217224121
# sent 599711: |['The same way you did.', 'The others?']|
#
# -- 498441 range D1 1-10, mean conf: 0.7934079766273499--
# rank 7, conf: 0.794445276260376
# sent 635043: |['Probably the same way we did.', 'The last time we saw it, it was heading in the same direction in the Badlands where the Caretaker picked us up.']|
#
# -- 498441 range D2 10-20, mean conf: 0.7816038131713867--
# rank 14, conf: 0.7855761647224426
# sent 811100: |['Webcams make me look the way I do in my fantasies.', 'I know, right? What is it? You always look so good in those things.']|
#
# -- 498441 range D3 20-30, mean conf: 0.7697933912277222--
# rank 28, conf: 0.7689723968505859
# sent 945178: |["Sandy, I'm doing this my own way", 'how...by sneakin around...by lyin to me']|
#
# -- 498441 range D4 30-60, mean conf: 0.7595412135124207--
# rank 59, conf: 0.7487177848815918
# sent 711431: |["It's not done that way.", "It can be though, let's vote."]|
#
# ----------SENT 293676 @15---------
# TEXT: |['Whoa! Did you see that?', 'Very interesting phenomenon. The electrostatic charge of the particles reacted with the bone. Angela was unable to recreate that pattern from the X-rays using the best technology in the world.']|
# MEAN CONF TOP100: 0.7447256445884705
#
# -- 293676 range D0 0-1, mean conf: 0.7448055744171143--
# rank 1, conf: 0.7448055744171143
# sent 100199: |['Oh, hold on, stop! Did you see that? Scroll back.', "That's him! That's Matt!"]|
#
# -- 293676 range D1 1-10, mean conf: 0.7448055744171143--
# rank 6, conf: 0.7448055744171143
# sent 181765: |['Did you see that?', 'Yeah. Unbelievable.']|
#
# -- 293676 range D2 10-20, mean conf: 0.7448054552078247--
# rank 20, conf: 0.7448055148124695
# sent 84935: |['Did you see that?', "Yeah. But that's impossible."]|
#
# -- 293676 range D3 20-30, mean conf: 0.7448054552078247--
# rank 29, conf: 0.7448055148124695
# sent 192904: |['Did you see that?', 'Yeah.']|
#
# -- 293676 range D4 30-60, mean conf: 0.744805634021759--
# rank 46, conf: 0.7448055148124695
# sent 579830: |["Wait a minute. Did you see that? They've got schematics on half a dozen different Klingon ships.", 'The Stealth Cruiser, Lieutenant. Nothing else.']|
#
# ----------SENT 376960 @16---------
# TEXT: |["It's a deterrent. It sends out a message, nobody gets away with killing a cop, a judge or a D.A.", "Cho can get a list of Kelly's cases, see who she put away that held a grudge."]|
# MEAN CONF TOP100: 0.7104907035827637
#
# -- 376960 range D0 0-1, mean conf: 0.7336773872375488--
# rank 2, conf: 0.7336773872375488
# sent 128763: |["She'll get the message!", "You know, I'll bet this is why number two came after you with a nine iron, wasn't it? You just refused to sit down and talk things through."]|
#
# -- 376960 range D1 1-10, mean conf: 0.7318006753921509--
# rank 7, conf: 0.7319531440734863
# sent 974149: |["You didn't get my message?", 'No. You sound a little drunk.']|
#
# -- 376960 range D2 10-20, mean conf: 0.72957843542099--
# rank 16, conf: 0.7300158143043518
# sent 493079: |['Sorry, love. I just got your message. I...', "It's okay. I just need another minute here."]|
#
# -- 376960 range D3 20-30, mean conf: 0.7250198721885681--
# rank 23, conf: 0.7267491221427917
# sent 496818: |["It wasn't luck. You got us that message. Thank you.", 'I need your help with something.']|
#
# -- 376960 range D4 30-60, mean conf: 0.7157775163650513--
# rank 48, conf: 0.7133262753486633
# sent 139676: |['I got your message.', "Oh, yeah, I did leave a message, didn't I."]|
#
# ----------SENT 796885 @17---------
# TEXT: |["Hey Howard. Michael Scott here. Yeah, sorry about that. Dwight is an idiot. I know. No, he's a little... Little dim. He's the janitor's brother, so...", "That's not true."]|
# MEAN CONF TOP100: 0.7082026600837708
#
# -- 796885 range D0 0-1, mean conf: 0.7868050932884216--
# rank 2, conf: 0.7868050932884216
# sent 47534: |['Yes. Yes! You are so my sister.', 'Rani, come on. The launch starts in an hour. Oh, you look great.']|
#
# -- 796885 range D1 1-10, mean conf: 0.7482080459594727--
# rank 10, conf: 0.7353273630142212
# sent 79019: |['Now you are my truly, truly brother.', 'Ian, we must get back to the ship.']|
#
# -- 796885 range D2 10-20, mean conf: 0.7181364297866821--
# rank 17, conf: 0.7166224718093872
# sent 295190: |['Go home. I have a few more questions for Barbara Harper, Okay. You go home and you be with your brother, alright?', 'Okay.']|
#
# -- 796885 range D3 20-30, mean conf: 0.7092135548591614--
# rank 28, conf: 0.708423912525177
# sent 731489: |["You're so my daughter.", 'Aye aye aye.']|
#
# -- 796885 range D4 30-60, mean conf: 0.7027984261512756--
# rank 40, conf: 0.7035217881202698
# sent 636214: |['So is he just a figment of our imagination?', "If he is, we've all been imagining the exact same thing."]|
#
# ----------SENT 43352 @18---------
# TEXT: |['Wine, Cherub, to help the Doctor talk more freely.', 'One thing more, before we go on any further.']|
# MEAN CONF TOP100: 0.7034265398979187
#
# -- 43352 range D0 0-1, mean conf: 0.7871766090393066--
# rank 2, conf: 0.7871766090393066
# sent 308689: |['Doctor Sweets helped me.', 'Oh well then I totally change my mind about Sweets. I now love him.']|
#
# -- 43352 range D1 1-10, mean conf: 0.7532333135604858--
# rank 8, conf: 0.7472071051597595
# sent 622547: |['It was, er, I believe it was called signal correlation traces. Mister Hogan was helping me, and he detected them.', 'When I looked for signal correlation traces, there were none. That means someone placed them in the system after my initial investigation.']|
#
# -- 43352 range D2 10-20, mean conf: 0.7318886518478394--
# rank 17, conf: 0.7307410836219788
# sent 5092: |['Zanak. Just helping you along, Doctor.', 'Yes. So your planet']|
#
# -- 43352 range D3 20-30, mean conf: 0.7229529023170471--
# rank 29, conf: 0.7220093011856079
# sent 50735: |['Help me, Doctor.', "It's all right, Kamelion. Help's on its way."]|
#
# -- 43352 range D4 30-60, mean conf: 0.7024255990982056--
# rank 48, conf: 0.7008236646652222
# sent 599897: |["I'd like to ask you a favour. I need a change of pace. I'd like to help Steth repair his ship.", "This isn't a good time to ask."]|
#
# ----------SENT 310675 @19---------
# TEXT: |['This the guy Bones is checking out to replace Zack?', 'Clark Edison, meet Special Agent Seeley Booth.']|
# MEAN CONF TOP100: 0.6892237067222595
#
# -- 310675 range D0 0-1, mean conf: 0.7417065501213074--
# rank 2, conf: 0.7417065501213074
# sent 149095: |['That guy on Seinfeld, George.', 'Oh? How so?']|
#
# -- 310675 range D1 1-10, mean conf: 0.7224596738815308--
# rank 10, conf: 0.7182369232177734
# sent 856201: |["Oh, yeah. That's who I hate. Guys, we hate Kate Hudson.", "No, we hate Zoey! I'm so furious at you all right now, but it's Thanksgiving, and I have a Turturkeykey to make. And not that I'm The Blitz, but could everyone please come with me into the kitchen?"]|
#
# -- 310675 range D2 10-20, mean conf: 0.7148169279098511--
# rank 15, conf: 0.7172026634216309
# sent 107542: |['And we wanted to meet some new people. Plus we heard this guy Darin Spotnitz threw some awesome parties.', "Hmm. How'd you get there?"]|
#
# -- 310675 range D3 20-30, mean conf: 0.7042832970619202--
# rank 22, conf: 0.7093014717102051
# sent 711010: |["Luke's the diner guy?", 'Yes. We eat there practically every day.']|
#
# -- 310675 range D4 30-60, mean conf: 0.6854972839355469--
# rank 34, conf: 0.6936829090118408
# sent 377538: |["Let's check out the wife— Leslie Sloop.", 'Working.']|
#
# ----------SENT 901316 @20---------
# TEXT: |['Yeah, I was gonna throw it away, but I just couldn’t.', 'That is so sweet. In 25 to 30 minutes I’m gonna show you how much this means to me.']|
# MEAN CONF TOP100: 0.6830689907073975
#
# -- 901316 range D0 0-1, mean conf: 0.6881444454193115--
# rank 2, conf: 0.6881444454193115
# sent 1042011: |["She's not gonna throw it. Are you?", 'Throw the potion.']|
#
# -- 901316 range D1 1-10, mean conf: 0.6858030557632446--
# rank 3, conf: 0.6875280141830444
# sent 768241: |["Not like there's anything to feel guilty about. Jackson sells his vegetables all over town. I'm not just gonna throw these away.", "Just because Lorelai is away does not mean that I'm obligated to listen to your incessant prattling."]|
#
# -- 901316 range D2 10-20, mean conf: 0.6840173006057739--
# rank 12, conf: 0.6841864585876465
# sent 942680: |["But I'm going to treasure this poem forever.", 'I meant it. Just so you know.']|
#
# -- 901316 range D3 20-30, mean conf: 0.6834843754768372--
# rank 28, conf: 0.6834111213684082
# sent 247200: |["I ain't gonna pin no tail on no donkey.", "Look, just come to the party. It's gonna be fun. Batman's gonna be there."]|
#
# -- 901316 range D4 30-60, mean conf: 0.68271404504776--
# rank 48, conf: 0.6825571060180664
# sent 708922: |["I'm not gonna scream.", 'Once a screamer, always a screamer.']|
#
# ----------SENT 612737 @21---------
# TEXT: |["You'll be an observer. When it's over, you're cut loose.", 'The story of my life.']|
# MEAN CONF TOP100: 0.6577930450439453
#
# -- 612737 range D0 0-1, mean conf: 0.7342618703842163--
# rank 2, conf: 0.7342618703842163
# sent 430900: |["Rest when it's over, Big McIntosh! Ride! Ride!", "This is just dreadful. Even at top speed the Apples are only making one barrel to the twins' three!"]|
#
# -- 612737 range D1 1-10, mean conf: 0.7174075841903687--
# rank 4, conf: 0.7168856263160706
# sent 36874: |["To warn everyone. Start the evacuation. What time does Vesuvius erupt? When's it due?", "It's 79AD, twenty third of August, which makes volcano day tomorrow."]|
#
# -- 612737 range D2 10-20, mean conf: 0.696713387966156--
# rank 12, conf: 0.7151849865913391
# sent 740882: |['Oh, how nice. When is it?', 'A week from Sunday.']|
#
# -- 612737 range D3 20-30, mean conf: 0.6630924940109253--
# rank 22, conf: 0.6701720356941223
# sent 974034: |["Well, I will tell you this... and it is the last piece of fatherly advice I dispense before you leave the nest. It ain't over... till it's over.", "That's it? That's your advice, a trite, hackneyed cliché?"]|
#
# -- 612737 range D4 30-60, mean conf: 0.6459453701972961--
# rank 52, conf: 0.6436959505081177
# sent 164130: |['When was this?', 'Right after you left for the lab.']|
#
# ----------SENT 937681 @22---------
# TEXT: |["what're you doing", 'nothin']|
# MEAN CONF TOP100: 0.64887535572052
#
# -- 937681 range D0 0-1, mean conf: 0.6488754153251648--
# rank 1, conf: 0.6488754153251648
# sent 43587: |['I hear talking! What are you doing?', "My pen's run out, I'm getting a new one."]|
#
# -- 937681 range D1 1-10, mean conf: 0.6488754153251648--
# rank 7, conf: 0.6488754153251648
# sent 42435: |['What are you doing?', "Landing, my dear. That's what you wanted, wasn't it?"]|
#
# -- 937681 range D2 10-20, mean conf: 0.64887535572052--
# rank 11, conf: 0.6488754153251648
# sent 33304: |['What? What are you doing?', "There's no baby seat. And the last thing I need is her blowing the car's electrics. And make sure Mister Smith stays out of harm's way."]|
#
# -- 937681 range D3 20-30, mean conf: 0.64887535572052--
# rank 24, conf: 0.6488754153251648
# sent 975334: |['What are you doing?', 'I was gonna ask you to dance.']|
#
# -- 937681 range D4 30-60, mean conf: 0.6488755345344543--
# rank 45, conf: 0.6488754153251648
# sent 57899: |['What do you want? Hmm? What are you up to? Ah! What are you doing?', 'Doctor, where are they taking you?']|
#
# ----------SENT 759110 @23---------
# TEXT: |['Bring my mother?', "Ah. And tell her to bring that guy she's with. What's his name? Luke?"]|
# MEAN CONF TOP100: 0.6252946853637695
#
# -- 759110 range D0 0-1, mean conf: 0.6258032917976379--
# rank 2, conf: 0.6258032917976379
# sent 188669: |["I can't. Only my mother can.", 'I will step in front of a moving truck before I let your mother take over my body.']|
#
# -- 759110 range D1 1-10, mean conf: 0.6257928013801575--
# rank 6, conf: 0.6258014440536499
# sent 910102: |['Oh, my mother.', 'Oh, my God.']|
#
# -- 759110 range D2 10-20, mean conf: 0.6256828308105469--
# rank 12, conf: 0.62575763463974
# sent 129074: |["She finished the story, tucked me in, blew out the candles. My mother thought that candlelight enhanced the trompe l'oieil.", "Canopy beds, trompe l'oieil, flickering candles. No wonder your bete noir was a vampire."]|
#
# -- 759110 range D3 20-30, mean conf: 0.625534176826477--
# rank 22, conf: 0.6256174445152283
# sent 486564: |['I might. How could you do something like that in public?! And better question...What imbecile would mistake me for my mother?!', "Maybe it's not that bad."]|
#
# -- 759110 range D4 30-60, mean conf: 0.6252946853637695--
# rank 41, conf: 0.6253271102905273
# sent 885448: |['When, mother?', 'When all my work is complete.']|
#
# ----------SENT 367989 @24---------
# TEXT: |['You believe that this guy is destined for someone else and you’re still gonna date him?', 'Well, he may not be my soul mate, but a girl’s gotta eat.']|
# MEAN CONF TOP100: 0.6188042163848877
#
# -- 367989 range D0 0-1, mean conf: 0.6242985129356384--
# rank 2, conf: 0.6242985129356384
# sent 470331: |['OK. What’re you going as?', 'An angel.']|
#
# -- 367989 range D1 1-10, mean conf: 0.6224120855331421--
# rank 3, conf: 0.6236868500709534
# sent 346067: |['Oh yeah? You’re going further down! Downtown!', 'Seriously guys, the trash talk is embarrassing.']|
#
# -- 367989 range D2 10-20, mean conf: 0.6203439831733704--
# rank 15, conf: 0.6207777261734009
# sent 330653: |['You’re going down.', 'Oh yeah? You’re going further down! Downtown!']|
#
# -- 367989 range D3 20-30, mean conf: 0.6192821860313416--
# rank 31, conf: 0.6189435720443726
# sent 492393: |['Wait. We’re already going?', 'Yes, I just need one last thing.']|
#
# -- 367989 range D4 30-60, mean conf: 0.618332028388977--
# rank 54, conf: 0.6181015968322754
# sent 989452: |["No way. You're my family. You go, I go.", "But I mean, what about what you want? I mean, you're always so selfless, Jack. Will you promise me that you'll think about yourself this time?"]|
#
# ----------SENT 54589 @25---------
# TEXT: |["We're all murderers! Murderers!", 'It came from over there.']|
# MEAN CONF TOP100: 0.6087090373039246
#
# -- 54589 range D0 0-1, mean conf: 0.6635634899139404--
# rank 2, conf: 0.6635634899139404
# sent 250113: |["Bart, over here! Come on. / Over here! / We're all open! / Over here!", 'Just throw it, doofus!']|
#
# -- 54589 range D1 1-10, mean conf: 0.6433550715446472--
# rank 9, conf: 0.6336202621459961
# sent 976937: |["You're right. I call it foreplay. But then again, we don't owe any explanations to each other, do we? We're just sparring partners right? We don't mean any more to each other than that.", "That's not true. You know that's not true, Andie. I mean, I was having a wonderful time with you tonight. I was. It's just when I ran into Kristy, I just...I got swept up in the moment."]|
#
# -- 54589 range D2 10-20, mean conf: 0.6234948039054871--
# rank 15, conf: 0.6253817677497864
# sent 58275: |['Are you all ready, lad?', "Aye, let's away."]|
#
# -- 54589 range D3 20-30, mean conf: 0.6118592023849487--
# rank 22, conf: 0.6151068806648254
# sent 813489: |["Wait! Why don't we come up with a plan we're all happy about?", 'Pam, how is this thing even any better than my old computer?']|
#
# -- 54589 range D4 30-60, mean conf: 0.6052544116973877--
# rank 50, conf: 0.6033115386962891
# sent 234456: |["You're not gettin' out 'til we're sixteen!", "I'm proud of you, Mom. But just one thing: isn't your book a little hard on Dad?"]|
#
# ----------SENT 972666 @26---------
# TEXT: |["Whoa. Isn't Pacey racing?", 'Yeah.']|
# MEAN CONF TOP100: 0.6070476770401001
#
# -- 972666 range D0 0-1, mean conf: 0.638411819934845--
# rank 2, conf: 0.638411819934845
# sent 724617: |["Oh, I like how the lapels are cut. Aren't those nice lapels, Rory?", 'Uh, sure, Grandpa. His lapels look great.']|
#
# -- 972666 range D1 1-10, mean conf: 0.6301414966583252--
# rank 8, conf: 0.6284338235855103
# sent 167347: |["Whitney's not my enemy.", "Yes he is, Clark, and the sooner you realize that, the sooner you'll find a way to win Lana. Just remember, keep your friends close and the quarterback closer."]|
#
# -- 972666 range D2 10-20, mean conf: 0.6190643906593323--
# rank 12, conf: 0.6197078227996826
# sent 268501: |["Don't be overdramatic, Sam.", "You're lucky this turned out to be a real case. Because if it wasn't you would have just found something else to kill."]|
#
# -- 972666 range D3 20-30, mean conf: 0.6099293828010559--
# rank 23, conf: 0.6142991781234741
# sent 464940: |['The song is not over Nathan.', 'Yeah but… the dance is.']|
#
# -- 972666 range D4 30-60, mean conf: 0.6040696501731873--
# rank 44, conf: 0.6036569476127625
# sent 564365: |["Then you've already decided. The Patriarch is not Admiral Stark.", 'Not now, and never will be.']|
#
# ----------SENT 877739 @27---------
# TEXT: |["What's that?", 'Nothing.']|
# MEAN CONF TOP100: 0.5852536559104919
#
# -- 877739 range D0 0-1, mean conf: 0.5852535963058472--
# rank 1, conf: 0.5852535963058472
# sent 72238: |["What's that?", "Bone. From some animal I don't recognise. Snapped off? Sharp, jagged edges?"]|
#
# -- 877739 range D1 1-10, mean conf: 0.5852535963058472--
# rank 3, conf: 0.5852535963058472
# sent 504080: |['What was that?', 'That… Is a great subject for discussion. When we get home.']|
#
# -- 877739 range D2 10-20, mean conf: 0.5852535963058472--
# rank 12, conf: 0.5852535367012024
# sent 412094: |["What's that?", '"Amelia."']|
#
# -- 877739 range D3 20-30, mean conf: 0.5852535963058472--
# rank 29, conf: 0.5852535367012024
# sent 262519: |["I'm sorry. What was that?", 'Okay, yes. The answer is yes.']|
#
# -- 877739 range D4 30-60, mean conf: 0.5852535367012024--
# rank 37, conf: 0.5852535367012024
# sent 485283: |["What's that?", 'Jimmy. See, Abby had diabetes, so he let her go. Look, I know Jimmy was all distraught and not his self, but... I could never understand how he could just have it in his heart to let Abby go, but with Keith, that was somebody he knew and loved.']|
#
# ----------SENT 628937 @28---------
# TEXT: |["Please, you're going to destroy yourself, and us.", 'Detonation in twenty seconds.']|
# MEAN CONF TOP100: 0.5845504403114319
#
# -- 628937 range D0 0-1, mean conf: 0.5922647714614868--
# rank 2, conf: 0.5922647714614868
# sent 624836: |["No, we're not going to destroy them over a misunderstanding.", 'Either that or retreat.']|
#
# -- 628937 range D1 1-10, mean conf: 0.5893672704696655--
# rank 11, conf: 0.5883322954177856
# sent 534587: |["A scrapper? He's going to destroy him.", "He's tougher than he looks. Silent but deadly."]|
#
# -- 628937 range D2 10-20, mean conf: 0.5868285894393921--
# rank 15, conf: 0.5866501331329346
# sent 886986: |['I... I... I was going to return this...', 'Oh, thank you.']|
#
# -- 628937 range D3 20-30, mean conf: 0.5856354236602783--
# rank 26, conf: 0.5857535004615784
# sent 48671: |['Are we going to stabilise the shield?', 'Yes.']|
#
# -- 628937 range D4 30-60, mean conf: 0.5842851996421814--
# rank 33, conf: 0.5852214097976685
# sent 4181: |['Are we going to follow them?', 'Of course.']|
#
# ----------SENT 509753 @29---------
# TEXT: |["Yep. It's me.", "Man! I'm such a huge nerd for you! Please take us on as hero apprentices!"]|
# MEAN CONF TOP100: 0.5677850246429443
#
# -- 509753 range D0 0-1, mean conf: 0.5677850842475891--
# rank 1, conf: 0.5677850842475891
# sent 782903: |["No, it-it's me. It's me.", 'Liz? Gotta get back to you, babe.']|
#
# -- 509753 range D1 1-10, mean conf: 0.5677850842475891--
# rank 3, conf: 0.5677850842475891
# sent 625013: |["It's me.", 'Activate the grid. What happened?']|
#
# -- 509753 range D2 10-20, mean conf: 0.5677851438522339--
# rank 15, conf: 0.5677850842475891
# sent 999774: |["It's me.", 'Come on up.']|
#
# -- 509753 range D3 20-30, mean conf: 0.5677851438522339--
# rank 27, conf: 0.5677850842475891
# sent 995958: |["It's me!", 'Come on up.']|
#
# -- 509753 range D4 30-60, mean conf: 0.5677850842475891--
# rank 45, conf: 0.5677850246429443
# sent 877746: |["It's me.", "You're here."]|
#
# ----------SENT 638599 @30---------
# TEXT: |['This whole thing sounds illogical.', 'Your advice, Commander.']|
# MEAN CONF TOP100: 0.5638143420219421
#
# -- 638599 range D0 0-1, mean conf: 0.5659863352775574--
# rank 1, conf: 0.5659863352775574
# sent 676350: |['She improvised that whole thing.', 'Yeah, who’d think you could turn a pregnancy into an alias?']|
#
# -- 638599 range D1 1-10, mean conf: 0.5659862756729126--
# rank 9, conf: 0.5659862756729126
# sent 656509: |['What whole thing?', 'Exactly. Bye!']|
#
# -- 638599 range D2 10-20, mean conf: 0.5659793615341187--
# rank 18, conf: 0.5659783482551575
# sent 511643: |["Uh, nope. The bear did it, and I've got proof. I taped the whole thing.", "The bear ate all my cakes, and you just sat there and watched him do it?! What's wrong with you?!"]|
#
# -- 638599 range D3 20-30, mean conf: 0.5658569931983948--
# rank 28, conf: 0.565859854221344
# sent 694706: |["Well, there's nothing much to talk about. It was just bad. I got a little better as the night went on - talked a little more. He was very nice, just not my type. Oh, and the whole draft thing backfired.", 'How so?']|
#
# -- 638599 range D4 30-60, mean conf: 0.5637171268463135--
# rank 43, conf: 0.5640646815299988
# sent 1046461: |['Excuse me, where vision is history, he hit on me. Remember, the whole vision thing.', "Vision thing? Please tell me you didn't use your powers."]|
#
# ----------SENT 551000 @31---------
# TEXT: |["LAFORGE: Okay. In the event of a breach of seal integrity there's an emergency release system which dumps the antimatter. DATA: Apparently such a dump began, was then halted, and the containment seals were dropped. There was still sufficient antimatter present to lead to an explosion.", 'And so there is no evidence that a weapon was used?']|
# MEAN CONF TOP100: 0.5437543988227844
#
# -- 551000 range D0 0-1, mean conf: 0.6111416816711426--
# rank 2, conf: 0.6111416816711426
# sent 591511: |["There's still no indication of why they attacked the station?", 'They practically tore the place apart. Accessed the central computer, turned the cargo bay inside out. Obviously they were looking for something.']|
#
# -- 551000 range D1 1-10, mean conf: 0.595020592212677--
# rank 8, conf: 0.5934252142906189
# sent 53201: |['And animals. There are still animals.', "What's so different about us?"]|
#
# -- 551000 range D2 10-20, mean conf: 0.5885047912597656--
# rank 19, conf: 0.5880708694458008
# sent 32776: |["There's still upstairs.", "Then it's got to be there, otherwise Earth's future is in serious trouble."]|
#
# -- 551000 range D3 20-30, mean conf: 0.5668914914131165--
# rank 24, conf: 0.5772708654403687
# sent 439842: |["Oh, I don't know why I didn't choose to wear something more casual. Why, I knew that juggling routine like the back of my hoof! But never you mind. There is still the race to be run!", 'I really appreciate all the effort, Big Ma<U+0097> cousin Orchard Blossom, but maybe we just skip the whole obstacle course thing and call it a day.']|
#
# -- 551000 range D4 30-60, mean conf: 0.5355533957481384--
# rank 57, conf: 0.5277140736579895
# sent 177745: |['All the vital data is still secure in the mainframe.', 'And how long do you think before that location is compromised? If it ever became public that Luthorcorp is experimenting on people with abilities ...']|
#
# ----------SENT 561669 @32---------
# TEXT: |['Kraylux. Somewhere in the outer system.', 'Status on the rest of the fleet?']|
# MEAN CONF TOP100: 0.5163028240203857
#
# -- 561669 range D0 0-1, mean conf: 0.5184745788574219--
# rank 2, conf: 0.5184745788574219
# sent 656245: |['Naturally. I belong in this system.', 'The transition is ninety nine percent complete. Why do you call me old friend?']|
#
# -- 561669 range D1 1-10, mean conf: 0.5176706314086914--
# rank 4, conf: 0.5183724164962769
# sent 495258: |['Careful, dearie. These are straight up spells. Rough in the system.', 'I don’t care if they turn me green. I’m getting my son back.']|
#
# -- 561669 range D2 10-20, mean conf: 0.5167014002799988--
# rank 17, conf: 0.5166651010513306
# sent 282920: |['What now is proved was once only imagined. The rat, the mouse, the fox, the rabbit, watch the roots; the lion, the tiger, the horse, the elephant, watch the fruits. The system contains, the fountain... overflows.', 'What?']|
#
# -- 561669 range D3 20-30, mean conf: 0.5166326761245728--
# rank 30, conf: 0.5166199207305908
# sent 726937: |['But the system!', 'It will never happen again.']|
#
# -- 561669 range D4 30-60, mean conf: 0.516488254070282--
# rank 56, conf: 0.5163836479187012
# sent 32980: |['Spacecraft approaching the solar system.', 'Get it on the screen.']|
#
# ----------SENT 590165 @33---------
# TEXT: |['You think that she lied?', "Lied, conveniently forgot, I'm not sure. I think it's something we have to consider."]|
# MEAN CONF TOP100: 0.511650025844574
#
# -- 590165 range D0 0-1, mean conf: 0.5143572688102722--
# rank 2, conf: 0.5143572688102722
# sent 1032008: |['You think she stood him up?', "Not deliberately. I just think that since we've been back from pilgrim times, she's been on a demon vender."]|
#
# -- 590165 range D1 1-10, mean conf: 0.5124435424804688--
# rank 4, conf: 0.5124536752700806
# sent 392215: |['So you want to call it? How do you think he died?', 'Fear.']|
#
# -- 590165 range D2 10-20, mean conf: 0.5119050741195679--
# rank 14, conf: 0.5120323896408081
# sent 446572: |["That is ass backward, Shane. You shouldn't meant not to hurt her. You should think before you act.", "You're right. I know. You're right."]|
#
# -- 590165 range D3 20-30, mean conf: 0.5116825699806213--
# rank 29, conf: 0.5116638541221619
# sent 239748: |["Moe, I think I'll have another -- -- Whoops. Moe, I'm a little low on funds. You think could cover me just this once?", 'No, sorry.']|
#
# -- 590165 range D4 30-60, mean conf: 0.5115252137184143--
# rank 49, conf: 0.5114871859550476
# sent 400987: |['Whoa, wait a minute. You think ... ? No way.', 'It was an inside job. You knew the registers were full. Those gunmen had help from an employee.']|
#
# ----------SENT 537135 @34---------
# TEXT: |['He suffers a lot. There is no need for abdominal surgery.', "It's fun. No, Dr. Grey has had an interesting idea. And unlike you, I take seriously the new chief of protocol, and I listen."]|
# MEAN CONF TOP100: 0.4997328519821167
#
# -- 537135 range D0 0-1, mean conf: 0.5654983520507812--
# rank 2, conf: 0.5654983520507812
# sent 4590: |["There's no need for formality, Excellency.", "I know. There's something in there I want rather badly. Let's go. Come on."]|
#
# -- 537135 range D1 1-10, mean conf: 0.5441319942474365--
# rank 10, conf: 0.5373842716217041
# sent 607848: |["And like us, it's an intelligent animal. There's no need to hunt it down.", 'A very interesting hypothesis, Doctor. Briefing room.']|
#
# -- 537135 range D2 10-20, mean conf: 0.5367693305015564--
# rank 17, conf: 0.5368278622627258
# sent 34214: |["That's very kind. There's no need.", "You're the one working."]|
#
# -- 537135 range D3 20-30, mean conf: 0.5171869993209839--
# rank 25, conf: 0.5261162519454956
# sent 961857: |["There's no need to rush fate.", "Don't wait an eternity Dawson, I mean she's from New York where things tend to move faster."]|
#
# -- 537135 range D4 30-60, mean conf: 0.49129718542099--
# rank 60, conf: 0.4844713509082794
# sent 551086: |["Yeah, that's starting to come back to me. There was no proof included.", 'For the eight hundred years people have been trying to solve it.']|
#
# ----------SENT 81184 @35---------
# TEXT: |['You are curious. You have seen the words, too. I can hear them tick inside you. But you are still locked in your history. Still slavishly protecting Time. Willing to die rather than change a word of the future.', '(sotto) Lunn.']|
# MEAN CONF TOP100: 0.47691017389297485
#
# -- 81184 range D0 0-1, mean conf: 0.5359587073326111--
# rank 2, conf: 0.5359587073326111
# sent 1025891: |['You never said you were fighting children.', "Well, it's not the size of the opponent, Elaine, it's, uh, the ferocity."]|
#
# -- 81184 range D1 1-10, mean conf: 0.5073330998420715--
# rank 3, conf: 0.5211699604988098
# sent 252161: |['Aww, now say hello to your other seven children.', 'My... Whaa...?!']|
#
# -- 81184 range D2 10-20, mean conf: 0.48634853959083557--
# rank 21, conf: 0.4836045801639557
# sent 748852: |["See? Who says Stars Hollow's not progressive? Hey.", 'Hey, you guys.']|
#
# -- 81184 range D3 20-30, mean conf: 0.4808291494846344--
# rank 30, conf: 0.4780369699001312
# sent 56134: |['Yes. Pompous lot. All words and no actions.', "Well, that's not true. What about Salyavin?"]|
#
# -- 81184 range D4 30-60, mean conf: 0.47359105944633484--
# rank 50, conf: 0.47314631938934326
# sent 258956: |["Good. Keep it that way. Wandell's buddies are looking for someone or something to string up, and they're not going to slow down to listen to reason. You understand what I'm saying?", "We'd better hit the road. If, uh, you can remember where we parked the car."]|
#
# ----------SENT 590401 @36---------
# TEXT: |['There was a struggle and I', 'You what? What happened?']|
# MEAN CONF TOP100: 0.44659173488616943
#
# -- 590401 range D0 0-1, mean conf: 0.44675353169441223--
# rank 2, conf: 0.44675353169441223
# sent 535898: |["Addison, I'm sorry. I did all the tests. There's no fertility potential here.", 'Okay. Uh... this is good. This is, um... oh, this is just... perfect.']|
#
# -- 590401 range D1 1-10, mean conf: 0.44670799374580383--
# rank 6, conf: 0.44671058654785156
# sent 192768: |["So Homer, please feel free to tell us anything. There's no judgment here.", 'The other day I was so desperate for a beer I snuck into the football stadium and ate the dirt under the bleachers.']|
#
# -- 590401 range D2 10-20, mean conf: 0.44666069746017456--
# rank 13, conf: 0.44667884707450867
# sent 557616: |['There was no authorisation.', 'Picard to shuttlecraft. Identify yourself and return to the ship immediately. Mister Worf, lock on with a tractor beam and return it to the ship.']|
#
# -- 590401 range D3 20-30, mean conf: 0.44662562012672424--
# rank 22, conf: 0.44663766026496887
# sent 165962: |["I know her. She's my cousin. She's not a killer. I just need to find her. Is there any more audio?", "There's a little more noise."]|
#
# -- 590401 range D4 30-60, mean conf: 0.4465879797935486--
# rank 46, conf: 0.44659268856048584
# sent 744279: |["Don't be naive. There are schemers about preying on the naive.", 'John Kendall.']|
#
# ----------SENT 583579 @37---------
# TEXT: |['Shut up, bitch. Do we make you angry?', 'You could say that.']|
# MEAN CONF TOP100: 0.41706258058547974
#
# -- 583579 range D0 0-1, mean conf: 0.41795751452445984--
# rank 2, conf: 0.41795751452445984
# sent 452467: |['Can we make her sexier? I mean, not slutty, just sexy...Er.', "Yeah. We'll tuck this and..."]|
#
# -- 583579 range D1 1-10, mean conf: 0.41785991191864014--
# rank 9, conf: 0.4178289473056793
# sent 1012701: |['We made quite a haul.', "Where'd you go?"]|
#
# -- 583579 range D2 10-20, mean conf: 0.417682945728302--
# rank 21, conf: 0.41754791140556335
# sent 320736: |['We could make a collage - or a mobile."', '"Wesley!']|
#
# -- 583579 range D3 20-30, mean conf: 0.41741305589675903--
# rank 22, conf: 0.4175439774990082
# sent 327119: |['No! We’re gonna have fun. We can make fudge!', "Pity food? Y'know what that’s okay, all right, I don’t need any of you to stay, okay nobody stays."]|
#
# -- 583579 range D4 30-60, mean conf: 0.41695868968963623--
# rank 46, conf: 0.4169515371322632
# sent 564755: |["We'll never make it to slipstream.", "Yes, we will. We're at the same point the courier pilot was when he entered slipstream. Beka, form a slipstream portal around us now."]|
#
# ----------SENT 979329 @38---------
# TEXT: |['You counted to 10 before doing it again just in case I wanted to stop you. You bought me a wall.', "I didn't buy it so much as I\x97"]|
# MEAN CONF TOP100: 0.20986288785934448
#
# -- 979329 range D0 0-1, mean conf: 0.21859422326087952--
# rank 2, conf: 0.21859422326087952
# sent 759378: |['Why would the wall street journal print this? Why?', 'It was an interview with my father. If he said it, they get to print it.']|
#
# -- 979329 range D1 1-10, mean conf: 0.21470771729946136--
# rank 11, conf: 0.21395136415958405
# sent 224743: |['Okay, here\'s Comic Book Guy\'s instructions: "A carton of malted milk balls, one box confectioner\'s sugar, a can of chocolate frosting..."', "That's just his shopping list."]|
#
# -- 979329 range D2 10-20, mean conf: 0.21301808953285217--
# rank 14, conf: 0.21337991952896118
# sent 621221: |['Or the rats that are chewing through this wall.', "What? I'm going to pretend that was your stomach that made that growling noise."]|
#
# -- 979329 range D3 20-30, mean conf: 0.21180181205272675--
# rank 26, conf: 0.21181660890579224
# sent 303631: |['So, uh, he overdosed with his meth behind the wall.', 'Well, the space was too narrow for him to squeeze through. He got stuck, the bag broke, and when he gasped for air he inhaled and died instantaneously.']|
#
# -- 979329 range D4 30-60, mean conf: 0.20995168387889862--
# rank 35, conf: 0.21075455844402313
# sent 652312: |['Bones? (sees another skeleton chained to the wall) Doc?', 'You were saying something about trick or treat.']|
#
# ----------SENT 795848 @39---------
# TEXT: |["Go get 'em.", 'Good.']|
# MEAN CONF TOP100: 0.04587780684232712
#
# -- 795848 range D0 0-1, mean conf: 0.04704391956329346--
# rank 2, conf: 0.04704391956329346
# sent 822754: |["Go get 'em.", 'Oh! Whoa!']|
#
# -- 795848 range D1 1-10, mean conf: 0.04642645642161369--
# rank 10, conf: 0.04604380950331688
# sent 695631: |["Ah, got 'em.", "Oh, it's just like heaven."]|
#
# -- 795848 range D2 10-20, mean conf: 0.04594753310084343--
# rank 14, conf: 0.045970842242240906
# sent 600409: |["You'd better get going.", "Right. I don't want to be late."]|
#
# -- 795848 range D3 20-30, mean conf: 0.04588157683610916--
# rank 22, conf: 0.045885659754276276
# sent 523150: |['Go get him!', 'Follow me!']|
#
# -- 795848 range D4 30-60, mean conf: 0.045818619430065155--
# rank 34, conf: 0.045868027955293655
# sent 464549: |['I better get going.', 'Okay. I guess by rule, I owe you a kiss.']|

# %% [markdown]
# ## V9: Noun, verbs, and clean DEP
#
# DEP: all DEP but det.
# POS: verbs and nouns.

# %%
data_v9 = data.loc[((data.head_info=='DEP') & (data.head_pos!='det')) | (data.head_pos.isin(_allow_pos))]
data_v9
# Out:
#           sent_id            show_id            char_name char_id head_info  \
# 0         1063785        QueerAsFolk              MICHAEL  l22346       POS
# 5           78453          DoctorWho              BARBARA   l8667       DEP
# 6          146223       VeronicaMars             VERONICA  l30591       DEP
# 10        1059921        Charmed1998                 ANDY   l6497       DEP
# 13         144292       VeronicaMars             VERONICA  l30591       POS
# 14         537460           StarTrek              JANEWAY  l25466       POS
# 15         923983      SonsOfAnarchy                  JAX  l24810       POS
# 18         662463           StarTrek                PHLOX  l25490       DEP
# 19         642832           StarTrek               HARPER   l1893       DEP
# 21         238693        TheSimpsons  C. Montgomery Burns  a15869       POS
# 23         526675       GreysAnatomy                DEREK  l12263       DEP
# 31         580866           StarTrek               ARCHER  l25486       DEP
# 32         971419       DawsonsCreek               DAWSON   l7946       DEP
# 33         866034  HowIMetYourMother                ROBIN  l13772       POS
# 36         642447           StarTrek               HARPER   l1893       DEP
# 38         110457               NCIS                GIBBS  l18791       DEP
# 40         403957           CSIVerse                 NICK   l7486       DEP
# 42         788696        TheOfficeUS              MICHAEL  l19352       DEP
# 44         790267        TheOfficeUS              MICHAEL  l19352       DEP
# 45         189666        TheSimpsons        Homer Simpson  a15835       POS
# 46         608478           StarTrek                SPOCK  l25411       POS
# 48         511955      AdventureTime                 Finn   a3415       DEP
# 49         805801        TheOfficeUS                  JIM  l19347       DEP
# 52         730165       GilmoreGirls                 RORY  l11613       DEP
# 53         585682           StarTrek                RIKER  l25432       DEP
# 55         908523   TheBigBangTheory                PENNY   l4391       DEP
# 57         393226           CSIVerse              GRISSOM   l7484       DEP
# 58         460395        OneTreeHill                LUCAS  l19593       POS
# 59         357634            Friends               MONICA  l10692       POS
# 63         464165        OneTreeHill               NATHAN  l19594       DEP
# ...           ...                ...                  ...     ...       ...
# 17160318    66392          DoctorWho                 GWEN   l9078       POS
# 17160321   148708       VeronicaMars                KEITH  l30592       POS
# 17160322   712716       GilmoreGirls                 RORY  l11613       POS
# 17160323   859388  HowIMetYourMother               BARNEY  l13774       POS
# 17160327   649350           StarTrek               NEELIX  l25473       POS
# 17160328   885589              Salem                 MARY  l23233       DEP
# 17160329   688919       GilmoreGirls              LORELAI  l11612       POS
# 17160330   660454           StarTrek                 REED  l25489       DEP
# 17160331   183094         Smallville                 TESS  l24621       DEP
# 17160336   443968           TheLWord                ALICE  l15690       DEP
# 17160337   875528         Buffyverse                BUFFY   l5648       DEP
# 17160341   464413        OneTreeHill               NATHAN  l19594       POS
# 17160342   676588              Alias                DIXON   l1277       POS
# 17160344   749073       GilmoreGirls               SOOKIE  l11619       POS
# 17160346   373719       TheMentalist               LISBON  l17674       DEP
# 17160349   709703       GilmoreGirls                 RORY  l11613       DEP
# 17160350   174190         Smallville                 LANA  l24615       DEP
# 17160352   548045           StarTrek              JANEWAY  l25466       DEP
# 17160355   329079            Friends                 ROSS  l10696       POS
# 17160359    25432          DoctorWho        SECOND DOCTOR   l8651       POS
# 17160362   793175        TheOfficeUS              MICHAEL  l19352       POS
# 17160363  1006647           Seinfeld               GEORGE  l23594       DEP
# 17160365   723387       GilmoreGirls                 RORY  l11613       POS
# 17160366   125325               NCIS                 ABBY  l18806       POS
# 17160368   774869            Roswell                  MAX  l23046       DEP
# 17160370   860557  HowIMetYourMother               BARNEY  l13774       DEP
# 17160371   126524               NCIS                 ABBY  l18806       DEP
# 17160373   537886           StarTrek              JANEWAY  l25466       POS
# 17160376   652290           StarTrek                MCCOY  l25412       POS
# 17160377   295962              Bones              BRENNAN   l5146       DEP
#
#            head_pos      token  token_par  position  is_stop  \
# 0               VBZ         be         be         2     True
# 5             advcl         be       hold        34     True
# 6          compound       drug    testing         5    False
# 10            ccomp         be      think       -18     True
# 13              VBZ         do         do         0     True
# 14               NN  deflector  deflector        61    False
# 15              VBZ         be         be        26     True
# 18            nsubj  condition         be       -16    False
# 19             prep     beyond         be        24     True
# 21               NN      blood      blood        63    False
# 23             mark         if         be         5     True
# 31             mark         if      agree         5     True
# 32         npadvmod     PERSON       know        15    False
# 33               NN       info       info        63    False
# 36         npadvmod     PERSON         be       -19    False
# 38             dobj         me       tell        -8     True
# 40             dobj         it       help        -5     True
# 42        nsubjpass         he      dress         9     True
# 44              neg        not       need         4     True
# 45              NNP     PERSON     PERSON         5    False
# 46               VB        get        get        30     True
# 48           advmod      still         be        -3     True
# 49             prep      about  complaint       -11     True
# 52           advmod       just       feel         5     True
# 53             pobj       that       with        -5     True
# 55          auxpass         be    excited         3     True
# 57             prep         of     murder        -7     True
# 58               NN        mom        mom        27    False
# 59              VBG       play       play       110    False
# 63              aux         do        get         8     True
# ...             ...        ...        ...       ...      ...
# 17160318         NN       love       love        12    False
# 17160321        VBN         be         be        42     True
# 17160322        VBZ       have       have        80     True
# 17160323        NNP     PERSON     PERSON        20    False
# 17160327        NNS        day        day        24    False
# 17160328       attr      enemy         be       -11    False
# 17160329        NNP    General    General         0    False
# 17160330       prep         on      paint       -21     True
# 17160331     advmod        now         be         9     True
# 17160336      nsubj       that         go        11     True
# 17160337       dobj        her   remember        -9     True
# 17160341         VB        try        try        48    False
# 17160342        VBZ         be         be        28     True
# 17160344         NN     budget     budget        20    False
# 17160346     advmod       once      bring       -27     True
# 17160349       pobj      honey        for        -4    False
# 17160350        aux         to         go         3     True
# 17160352        aux      could       wait        27     True
# 17160355         VB       wait       wait       110    False
# 17160359         NN     report     report        62    False
# 17160362        NNP        GPE        GPE        72    False
# 17160363       mark       that        ask        14     True
# 17160365        VBD         be         be         8     True
# 17160366        NNP        ORG        ORG       114    False
# 17160368       intj         no     PERSON         4     True
# 17160370       intj       okay         be        14    False
# 17160371      nsubj       that         be         4     True
# 17160373         NN      price      price       109    False
# 17160376        NNP        FAC        FAC        66    False
# 17160377       case         's     PERSON        -7     True
#
#                        head_text
# 0                      VBZ|be|be
# 5                  advcl|be|hold
# 6          compound|drug|testing
# 10                ccomp|be|think
# 13                     VBZ|do|do
# 14        NN|deflector|deflector
# 15                     VBZ|be|be
# 18            nsubj|condition|be
# 19                prep|beyond|be
# 21                NN|blood|blood
# 23                    mark|if|be
# 31                 mark|if|agree
# 32          npadvmod|PERSON|know
# 33                  NN|info|info
# 36            npadvmod|PERSON|be
# 38                  dobj|me|tell
# 40                  dobj|it|help
# 42            nsubjpass|he|dress
# 44                  neg|not|need
# 45             NNP|PERSON|PERSON
# 46                    VB|get|get
# 48               advmod|still|be
# 49          prep|about|complaint
# 52              advmod|just|feel
# 53                pobj|that|with
# 55            auxpass|be|excited
# 57                prep|of|murder
# 58                    NN|mom|mom
# 59                 VBG|play|play
# 63                    aux|do|get
# ...                          ...
# 17160318            NN|love|love
# 17160321               VBN|be|be
# 17160322           VBZ|have|have
# 17160323       NNP|PERSON|PERSON
# 17160327             NNS|day|day
# 17160328           attr|enemy|be
# 17160329     NNP|General|General
# 17160330           prep|on|paint
# 17160331           advmod|now|be
# 17160336           nsubj|that|go
# 17160337       dobj|her|remember
# 17160341              VB|try|try
# 17160342               VBZ|be|be
# 17160344        NN|budget|budget
# 17160346       advmod|once|bring
# 17160349          pobj|honey|for
# 17160350               aux|to|go
# 17160352          aux|could|wait
# 17160355            VB|wait|wait
# 17160359        NN|report|report
# 17160362             NNP|GPE|GPE
# 17160363           mark|that|ask
# 17160365               VBD|be|be
# 17160366             NNP|ORG|ORG
# 17160368          intj|no|PERSON
# 17160370            intj|okay|be
# 17160371           nsubj|that|be
# 17160373          NN|price|price
# 17160376             NNP|FAC|FAC
# 17160377          case|'s|PERSON
#
# [7505832 rows x 11 columns]

# %%
model_v9, SENT_CATS_v9, FEATURE_CATS_v9 = get_train(data_v9, report_test_acc=False)
SENT_MAP_v9, INV_SENT_MAP_v9 = build_maps(data_v9)
# Out:
# <126251x923918 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7505832 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [03:02<00:00,  1.04it/s]
# 923918 923918

# %%
mi = ModelInspection(model_v9, SENT_MAP_v9, INV_SENT_MAP_v9, dialog_df=dialogs)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 290211 @0---------
# TEXT: |['I want to see if I could find a link between the old witch and the new witch.', "All right, you know what? Go for it. It's all yours."]|
# MEAN CONF TOP100: 1.0366235971450806
#
# -- 290211 range D0 0-1, mean conf: 1.1804099082946777--
# rank 2, conf: 1.1804099082946777
# sent 485533: |["I'm so sorry. I wanted to see you as soon as I found out.", "It's okay. Thank you, though."]|
#
# -- 290211 range D1 1-10, mean conf: 1.0964984893798828--
# rank 5, conf: 1.0976508855819702
# sent 502236: |["Keep looking for as long as you like. But down here, this is my shop. And you won't find anything unless I want you to.", 'Be careful with your threats.']|
#
# -- 290211 range D2 10-20, mean conf: 1.0747586488723755--
# rank 21, conf: 1.0695421695709229
# sent 303049: |['Well, what I want to do is I want to find a doctor to find him and pump him with enough morphine to stun an elephant.', "Physicians can't do that, it's against the Hippocratic Oath. First, do no harm."]|
#
# -- 290211 range D3 20-30, mean conf: 1.0614131689071655--
# rank 31, conf: 1.0525517463684082
# sent 127584: |['Gibbs wanted me to see if you finished the processing the crime scene evidence yet.', "I have, but Gibbs is not going to like this. Exhibit A. These are the bomb fragments that Ducky pulled from Colonel Cooper. It's plastic, but not your usual petroleum-based wreck-the-environment polymer. It's made of... corn. It's biodegradable which explains why it disintegrated so much in the blast. What are you doing?"]|
#
# -- 290211 range D4 30-60, mean conf: 1.0374499559402466--
# rank 37, conf: 1.0462466478347778
# sent 410023: |['I just want to find these boys.', 'Okay. Carl Fisher, apparently ...']|
#
# ----------SENT 150645 @1---------
# TEXT: |["Wait, if I'm Daphne, what does that make you? Fred?", "Oh no. If I gotta be any of those white boys, I gotta be shaggy all the way baby. Shaggy's got mad flavor."]|
# MEAN CONF TOP100: 0.9788039922714233
#
# -- 150645 range D0 0-1, mean conf: 1.1412750482559204--
# rank 2, conf: 1.1412750482559204
# sent 450673: |["No. Hey, listen to me. You were never a failure, okay? I mean, you won three cheerleading competitions, and what did Victoria have to say about that? Oh, wait. Nothing, 'cause she wasn't there. She also wasn't there when you won the miss June Bug title at the county fair or when you were elected student-body president. Brooke, if you're a failure, what does that make me?", 'Pretty lame, I guess.']|
#
# -- 150645 range D1 1-10, mean conf: 1.0368269681930542--
# rank 6, conf: 1.0345631837844849
# sent 554615: |["Well, if he's Little John, that makes you", 'I know. Robin Hood.']|
#
# -- 150645 range D2 10-20, mean conf: 0.9976868629455566--
# rank 13, conf: 1.0075606107711792
# sent 556703: |['The jury is still out on that, Picard, make no mistake.', "Your arrogant pretence at being the moral guardians of the universe strikes me as being hollow, Q. I see no evidence that you are guided by a superior moral code, or any code whatsoever. You may be nearly omnipotent, and I don't deny that your parlour tricks are very impressive, but morality? I don't see it. I don't acknowledge it, Q. I would put human morality against the Q's any day. And perhaps that's the reason that we fascinate you so. Because our puny behaviour shows you a glimmer of the one thing that evades your omnipotence, a moral centre. And if so, I can think of no crueller irony than that you should destroy this young woman, whose only crime is that she's too human."]|
#
# -- 150645 range D3 20-30, mean conf: 0.9845501184463501--
# rank 26, conf: 0.9847529530525208
# sent 1065189: |["I'm not sure she's up for this.", 'That makes two of us.']|
#
# -- 150645 range D4 30-60, mean conf: 0.9736990332603455--
# rank 36, conf: 0.9792352914810181
# sent 623992: |["I'm sure she is.", "And this isn't the first time Lieutenant Torres' violent proclivities have created problems."]|
#
# ----------SENT 588807 @2---------
# TEXT: |['Nothing that you have said is beyond what a school child could learn in a history book.', 'What is not commonly known that during those negotiations, you, Kalin Trose, quelled a plot by a radical from your moon who was attempting to assassinate the Beta delegate.']|
# MEAN CONF TOP100: 0.964625358581543
#
# -- 588807 range D0 0-1, mean conf: 1.0853971242904663--
# rank 2, conf: 1.0853971242904663
# sent 646185: |["I'm going to do the only honourable thing there is to do. And I'd say your Captain has the inside track.", "Mother, don't even think it."]|
#
# -- 588807 range D1 1-10, mean conf: 1.0244450569152832--
# rank 7, conf: 1.0221790075302124
# sent 916179: |['I think it’s like Beetlejuice. We said his name too many times.', 'Come on in.']|
#
# -- 588807 range D2 10-20, mean conf: 0.9987556338310242--
# rank 19, conf: 0.9946177005767822
# sent 437594: |["My letter to Princess Celestia is almost overdue, and I haven't learned anything about friendship!", 'Oh, thank goodness. I thought something really awful had happened.']|
#
# -- 588807 range D3 20-30, mean conf: 0.9820602536201477--
# rank 22, conf: 0.9891396164894104
# sent 376395: |['"Kimball," she says, "you shall kneel before the lord of beasts."', "That's scary."]|
#
# -- 588807 range D4 30-60, mean conf: 0.9621341228485107--
# rank 32, conf: 0.9748328924179077
# sent 730037: |["Thank you. That's really nice of you. And your mother says that you've graduated Yale, editor of the Yale Daily News -- that's not bad.", 'Oh, thank you. I want to pursue a career in journalism.']|
#
# ----------SENT 92058 @3---------
# TEXT: |["Mm. Well, let's just say manners are not your strong point.", 'Really?']|
# MEAN CONF TOP100: 0.9286943078041077
#
# -- 92058 range D0 0-1, mean conf: 1.121347188949585--
# rank 2, conf: 1.121347188949585
# sent 210981: |["Look, Marge, I'm sorry I haven't been a better husband. I'm sorry about the time I tried to make gravy in the bathtub. I'm sorry I used your wedding dress to wax the car... And I'm sorry... Oh well let's just say I'm sorry for the whole marriage up to this point.", "You're right. I am lucky to have him."]|
#
# -- 92058 range D1 1-10, mean conf: 0.9848838448524475--
# rank 5, conf: 1.0055692195892334
# sent 163357: |["Let's just say I'm not from around here.", 'You knew about this?']|
#
# -- 92058 range D2 10-20, mean conf: 0.9514440298080444--
# rank 13, conf: 0.9643440246582031
# sent 578901: |["All I'm saying is that we let nature make the choice.", "The hell with nature. You're a doctor. You have a moral obligation to help people who are suffering."]|
#
# -- 92058 range D3 20-30, mean conf: 0.9329085350036621--
# rank 31, conf: 0.9295640587806702
# sent 284223: |['Pretty sure that Sweets would say a lost baseball game - is not personal or revealing.', "Football, Bones. Okay. It's Football. Oh, okay. I got one. Alright, personally, between two people or revealing like, uh...aha!"]|
#
# -- 92058 range D4 30-60, mean conf: 0.9229020476341248--
# rank 51, conf: 0.9201923608779907
# sent 65455: |['Dead? Not at all, my boy. Not at all. I was merely, let me say, frozen stiff?', 'You mean you knew everything that was happening?']|
#
# ----------SENT 560117 @4---------
# TEXT: |["Please, the Free Trade Alliance never met a monopoly it didn't like.", 'I only have one question. What are we talking about?']|
# MEAN CONF TOP100: 0.925226092338562
#
# -- 560117 range D0 0-1, mean conf: 1.011212706565857--
# rank 2, conf: 1.011212706565857
# sent 339337: |['Did you like me when we first met?', 'Chandler, I’m not gonna lie to ya, but I am gonna run away from you.']|
#
# -- 560117 range D1 1-10, mean conf: 0.9595463275909424--
# rank 9, conf: 0.9512853026390076
# sent 858071: |["But she didn't like Field of Dreams.", "I can't think of anything."]|
#
# -- 560117 range D2 10-20, mean conf: 0.9346149563789368--
# rank 15, conf: 0.936896800994873
# sent 1000580: |['So did you like the movie?', "Yeah, it was OK. Frankenstein didn't seem quite right to me. I missed the sport jacket."]|
#
# -- 560117 range D3 20-30, mean conf: 0.9283981323242188--
# rank 27, conf: 0.9280382394790649
# sent 408543: |['How did you like the show?', 'Alison Carpenter is dead.']|
#
# -- 560117 range D4 30-60, mean conf: 0.9210745692253113--
# rank 36, conf: 0.9234727621078491
# sent 1015565: |['Oh, beautiful did he like them?', "No, ... he didn't! No, ... he didn't!"]|
#
# ----------SENT 627128 @5---------
# TEXT: |['Have you found anything at all that would cast doubt on his story?', 'No.']|
# MEAN CONF TOP100: 0.9097452163696289
#
# -- 627128 range D0 0-1, mean conf: 1.0806828737258911--
# rank 1, conf: 1.0806828737258911
# sent 627092: |['Have you found anything at all that would cast doubt on his story?', 'No.']|
#
# -- 627128 range D1 1-10, mean conf: 0.9818886518478394--
# rank 11, conf: 0.9806569218635559
# sent 626163: |["I'm still picking up dilithium signatures but there are no dilithium formations here. Have you found anything yet?", "I'm running a geo-strato analysis of the rock in this vicinity. So far there's no indication of any dilithium."]|
#
# -- 627128 range D2 10-20, mean conf: 0.9482197761535645--
# rank 17, conf: 0.9398374557495117
# sent 626426: |['Have you found any traces of the bacteria?', "I've checked the transporter logs for the past month. There's no indication that the biofilter picked up anything suspicious."]|
#
# -- 627128 range D3 20-30, mean conf: 0.9316673278808594--
# rank 28, conf: 0.9302862882614136
# sent 469669: |['Peyton. Have they found her?', 'Not yet. God, Jake, I am so, so sorry, okay? We only looked away for like two seconds.']|
#
# -- 627128 range D4 30-60, mean conf: 0.9051821231842041--
# rank 58, conf: 0.891029953956604
# sent 1018540: |['Yes. So have you found anything yet?', 'Uh, no. Not really.']|
#
# ----------SENT 508306 @6---------
# TEXT: |["He'll forgive me. He just needs time.", "Even with all the time in the world, some things can't be forgiven."]|
# MEAN CONF TOP100: 0.8952102065086365
#
# -- 508306 range D0 0-1, mean conf: 0.9255889058113098--
# rank 2, conf: 0.9255889058113098
# sent 919942: |['Well, he’s been having a couple of tough days. I’m sure he’s fine. He probably just needs a little alone time to decompress.', 'You’re probably right. So, what are you guys doing?']|
#
# -- 508306 range D1 1-10, mean conf: 0.9226187467575073--
# rank 4, conf: 0.9251012802124023
# sent 726754: |["She's on the warpath right now. She'll calm down. She just needs some time.", 'You know, maybe I could give her more to do. That piece she just wrote would make a great series. Giving her something like that might help her rebound faster, make her the normal Paris again. What do you think.']|
#
# -- 508306 range D2 10-20, mean conf: 0.9104657173156738--
# rank 19, conf: 0.9084987044334412
# sent 882322: |['If every a whiz there was. I-I just need some time.', "No. I just heard you weren't . . ."]|
#
# -- 508306 range D3 20-30, mean conf: 0.9080914258956909--
# rank 31, conf: 0.9074821472167969
# sent 732620: |["I'm talking about going out for about an hour. What \x96 you need more time?", 'Nicole, will you excuse me for a minute?']|
#
# -- 508306 range D4 30-60, mean conf: 0.9038489460945129--
# rank 37, conf: 0.9051881432533264
# sent 151970: |['You just need more time.', "Irony of all ironies? Frozen from the waist down's new roommate? She's a one woman red light district."]|
#
# ----------SENT 309751 @7---------
# TEXT: |['What we should have done is crashed right into each other.', 'At the speed of light.']|
# MEAN CONF TOP100: 0.8775889873504639
#
# -- 309751 range D0 0-1, mean conf: 0.9252875447273254--
# rank 2, conf: 0.9252875447273254
# sent 301201: |["Not yet, dude. Now we haven't determined is what he would've rolled on that would've done this.", "Oh! What if! What if, the victim wasn't spinning. What if, the weapon was spinning."]|
#
# -- 309751 range D1 1-10, mean conf: 0.8990069627761841--
# rank 6, conf: 0.9030389189720154
# sent 806916: |["That's genius. That's the best prank you've ever done.", "I'll take it."]|
#
# -- 309751 range D2 10-20, mean conf: 0.8832520246505737--
# rank 17, conf: 0.8836320638656616
# sent 324124: |['"Yep. She\'s been doing that."', '"Hormones."']|
#
# -- 309751 range D3 20-30, mean conf: 0.8784306645393372--
# rank 26, conf: 0.8785584568977356
# sent 80235: |["The turkey isn't done yet.", 'Is it still asking the question?']|
#
# -- 309751 range D4 30-60, mean conf: 0.8745477199554443--
# rank 46, conf: 0.8740710616111755
# sent 924424: |["Oh, yeah. Yo, when it's done? I need ten minutes. Diosa stuff.", 'Okay.']|
#
# ----------SENT 751693 @8---------
# TEXT: |['Goodbye Emily. Go to hell Richard.', "I'm not through with you yet!"]|
# MEAN CONF TOP100: 0.8701074719429016
#
# -- 751693 range D0 0-1, mean conf: 0.8804740309715271--
# rank 2, conf: 0.8804740309715271
# sent 218119: |['Marge, go to Hell, Marge!', "I think that's enough birthday fun."]|
#
# -- 751693 range D1 1-10, mean conf: 0.8736547231674194--
# rank 3, conf: 0.8753669261932373
# sent 97569: |['Then go home, Scott.', 'I meant fair for them.']|
#
# -- 751693 range D2 10-20, mean conf: 0.8727335929870605--
# rank 19, conf: 0.8727336525917053
# sent 522666: |['Go home, Sam.', 'Good night.']|
#
# -- 751693 range D3 20-30, mean conf: 0.8708171844482422--
# rank 26, conf: 0.8707472085952759
# sent 101272: |['Stiles, please go.', "It's okay. I hate parties. It's a social anxiety thing. You ever had a panic attack?"]|
#
# -- 751693 range D4 30-60, mean conf: 0.8702327609062195--
# rank 36, conf: 0.8703868389129639
# sent 702720: |['Go away, Lorelai.', "What's wrong, Dad?"]|
#
# ----------SENT 375865 @9---------
# TEXT: |['And you felt responsible because it was your gun.', 'No, I thought he was stupid to have it on him. Never should have done that.']|
# MEAN CONF TOP100: 0.8696892261505127
#
# -- 375865 range D0 0-1, mean conf: 0.9648587107658386--
# rank 2, conf: 0.9648587107658386
# sent 857041: |['Never really clicked. I felt bad though, he was pretty bummed.', "Don't beat yourself up. He'll be fine. I mean, the guy's like a billionaire. He can put his platinum card on a fishing line and reel in 10 chicks hotter than you."]|
#
# -- 375865 range D1 1-10, mean conf: 0.9258483052253723--
# rank 3, conf: 0.9423214197158813
# sent 540183: |['It was their wish, and I felt an obligation to fulfill it.', 'What did you do during those fifty years?']|
#
# -- 375865 range D2 10-20, mean conf: 0.8986265063285828--
# rank 15, conf: 0.9006016254425049
# sent 384431: |['Searing, searing pain that feels as if it were in a vice.', 'Well, that was rude.']|
#
# -- 375865 range D3 20-30, mean conf: 0.885051429271698--
# rank 25, conf: 0.8863873481750488
# sent 621401: |["You feel he's your load?", "Don't even start with that."]|
#
# -- 375865 range D4 30-60, mean conf: 0.8697841167449951--
# rank 52, conf: 0.8651655316352844
# sent 17315: |["It's ten years in the future. Maybe how this ground feels is how it always feels.", "Good thought, but no, it doesn't. Hear that, drill in start-up mode. Afterwaves of a recent seismological shift and blue grass."]|
#
# ----------SENT 497042 @10---------
# TEXT: |["Isaac lied. He couldn't write her out of the story. Where can I find her?", "You can't. Snow White locked her up years ago. No one has set eyes on her since. The prison she's in is impenetrable."]|
# MEAN CONF TOP100: 0.8392484188079834
#
# -- 497042 range D0 0-1, mean conf: 0.8401248455047607--
# rank 2, conf: 0.8401248455047607
# sent 73611: |["I can't find out.", 'What else does he do, this Kandyman?']|
#
# -- 497042 range D1 1-10, mean conf: 0.8397665023803711--
# rank 4, conf: 0.8398326635360718
# sent 846872: |['Well can you find out? We need to know who his next target is.', "If Enzo talks it'll be you guys."]|
#
# -- 497042 range D2 10-20, mean conf: 0.8396442532539368--
# rank 13, conf: 0.8396714925765991
# sent 955259: |["No. I've been to the Bait Shop, the diner. I can't find him anywhere.", 'I just feel strange to be cooking with all this going on. Maybe we should call dinner off.']|
#
# -- 497042 range D3 20-30, mean conf: 0.8394379615783691--
# rank 24, conf: 0.8394800424575806
# sent 761663: |["Yeah, I'm fine. I just - I can't find her.", "Well, maybe she's at Sookie's."]|
#
# -- 497042 range D4 30-60, mean conf: 0.8392525911331177--
# rank 38, conf: 0.8393259048461914
# sent 533446: |["Lost. Literally can't find.", "Shepherd says I'm selfish and competitive. What the hell is wrong with that? I kick ass. I'm an excellent resident."]|
#
# ----------SENT 476102 @11---------
# TEXT: |["I know what I saw. Don't make a liar out of me. Go to bed. I believe you, Peyton.", 'I know you only have eyes for me. Sweet dreams.']|
# MEAN CONF TOP100: 0.8254528641700745
#
# -- 476102 range D0 0-1, mean conf: 0.8576940894126892--
# rank 2, conf: 0.8576940894126892
# sent 193362: |['I believe you, Dad.', 'Well, no matter what the paper says, I still have a job to do.']|
#
# -- 476102 range D1 1-10, mean conf: 0.8569198250770569--
# rank 3, conf: 0.8576940894126892
# sent 154946: |['I believe you, Clark.', 'Then what am I doing here?']|
#
# -- 476102 range D2 10-20, mean conf: 0.8521949052810669--
# rank 15, conf: 0.8524794578552246
# sent 161794: |['We believe in you, Master B.', "Don't believe in me. Believe in the shield and what it represents. Most importantly, believe in yourselves."]|
#
# -- 476102 range D3 20-30, mean conf: 0.8481869697570801--
# rank 31, conf: 0.8469977974891663
# sent 1023979: |["Oh! I can't believe this, Kramer!", 'Yeah.']|
#
# -- 476102 range D4 30-60, mean conf: 0.8266945481300354--
# rank 39, conf: 0.8289472460746765
# sent 126650: |["What don't I believe in, Abby?", "UFOs, mystics, coincidence, saying you're sorry, excuses, I could go on all night."]|
#
# ----------SENT 581959 @12---------
# TEXT: |['That cloaking field is enormous. Whoever built this thing went to a great deal of trouble to conceal it.', 'Judging from those ion trails, the Osaarians spent over eight hours here. I want to find out why. Any luck scanning the interior?']|
# MEAN CONF TOP100: 0.8201322555541992
#
# -- 581959 range D0 0-1, mean conf: 0.9879063367843628--
# rank 2, conf: 0.9879063367843628
# sent 584265: |['Your Chef obviously went to a great deal of trouble.', "I'm told these are authentic Tellarite dishes."]|
#
# -- 581959 range D1 1-10, mean conf: 0.8672482967376709--
# rank 9, conf: 0.8575718998908997
# sent 923975: |['Lot of changes going on with your club.', 'Yeah.']|
#
# -- 581959 range D2 10-20, mean conf: 0.8452499508857727--
# rank 16, conf: 0.8466886878013611
# sent 119885: |['Or a drug deal gone bad.', 'Look at this. How bad does a drug deal have to go for you to leave the drugs behind?']|
#
# -- 581959 range D3 20-30, mean conf: 0.8291144371032715--
# rank 28, conf: 0.826543927192688
# sent 221791: |['Oh, sorry. This bus and I have sort of a "Shining" thing goin\' on.', "Ah! This is what being a kid is all about. Hey, Huck. What's L-I-N-C-O-N doin' here?"]|
#
# -- 581959 range D4 30-60, mean conf: 0.8148109912872314--
# rank 46, conf: 0.8141469359397888
# sent 61371: |['Wow. Some of this stuff must go back centuries.', 'He scavenges antique pieces from the past, brings them here, sells them for a profit. Not a bad business plan.']|
#
# ----------SENT 535474 @13---------
# TEXT: |['Derek says that neither of you brought your assets into the marriage.', 'Well I had my trust fund. And a sparkling personality. And the futon couch.']|
# MEAN CONF TOP100: 0.8185474276542664
#
# -- 535474 range D0 0-1, mean conf: 0.9104529619216919--
# rank 2, conf: 0.9104529619216919
# sent 834870: |['Really? Try me, because your coffins are next to go. Say goodbye to your family Klaus.', 'Stefan slow down!']|
#
# -- 535474 range D1 1-10, mean conf: 0.8603717684745789--
# rank 11, conf: 0.8466776609420776
# sent 1049389: |['All of these files say Halliwell.', 'Yeah, well, look at all these tests that he took. Okay, not just on blood that he took from you but blood that he took from Phoebe and me.']|
#
# -- 535474 range D2 10-20, mean conf: 0.8366772532463074--
# rank 17, conf: 0.8384643793106079
# sent 42042: |['The temple of Zeus, you say? A trifle modest, is it not, for so powerful a god.', "This is my travelling temple. Being small, it's convenient."]|
#
# -- 535474 range D3 20-30, mean conf: 0.826201319694519--
# rank 26, conf: 0.8262321949005127
# sent 111595: |["And now I have all this evidence. Forensics. The thing that I love and I believe in. And it says Tony's a murderer.", "Tony's not a murderer."]|
#
# -- 535474 range D4 30-60, mean conf: 0.8158339858055115--
# rank 42, conf: 0.8176468014717102
# sent 532667: |['Derek says I should apologize until he listens.', 'Derek says?']|
#
# ----------SENT 969988 @14---------
# TEXT: |["You're cutting class to go to a nightclub, you're asking what I'm doing. I'm coming with you,man. I wouldn't miss this for the world.", 'Billy.']|
# MEAN CONF TOP100: 0.8041267991065979
#
# -- 969988 range D0 0-1, mean conf: 0.8860979676246643--
# rank 2, conf: 0.8860979676246643
# sent 969968: |["You're cutting class to go to a nightclub, you're asking what I'm doing. I'm coming with you,man. I wouldn't miss this for the world.", 'Billy.']|
#
# -- 969988 range D1 1-10, mean conf: 0.8519937992095947--
# rank 7, conf: 0.8694984912872314
# sent 502239: |['I miss the world above the tastes, the smells.', "Sorry. You can't go back."]|
#
# -- 969988 range D2 10-20, mean conf: 0.8014626502990723--
# rank 14, conf: 0.8022218942642212
# sent 1066134: |["We couldn't missed that party for the world,sweetheart.", 'And we think our invitations must have gotten lostin the mail.']|
#
# -- 969988 range D3 20-30, mean conf: 0.7998906373977661--
# rank 28, conf: 0.7996289134025574
# sent 686267: |['Mom, I have the Franklin today. I cannot miss it.', "Rory, please. I can't handle the entire day with him. I can't, I can't, I caaaaan't."]|
#
# -- 969988 range D4 30-60, mean conf: 0.7985155582427979--
# rank 59, conf: 0.7979146242141724
# sent 381670: |["Bye Bender. I'll miss you.", 'Go on, get out of here before you get caught.']|
#
# ----------SENT 411153 @15---------
# TEXT: |['I thought you guys were processing the car?', 'Yeah, um... what do you know about silica?']|
# MEAN CONF TOP100: 0.8014324307441711
#
# -- 411153 range D0 0-1, mean conf: 0.9099836349487305--
# rank 2, conf: 0.9099836349487305
# sent 406911: |['Thought you guys checked this house.', 'Twice. Both times, nobody home.']|
#
# -- 411153 range D1 1-10, mean conf: 0.8854734897613525--
# rank 7, conf: 0.8873905539512634
# sent 806838: |['And you thought you guys were millionaires.', 'You heard that one.']|
#
# -- 411153 range D2 10-20, mean conf: 0.8539864420890808--
# rank 20, conf: 0.8433526158332825
# sent 446688: |['Okay, fine. What do you guys think about butt waxing?', 'Who has hair on their butt?']|
#
# -- 411153 range D3 20-30, mean conf: 0.8311616778373718--
# rank 29, conf: 0.8266331553459167
# sent 181842: |["What d'you think about that guy?", 'Er... He seems pretty cool.']|
#
# -- 411153 range D4 30-60, mean conf: 0.7971811294555664--
# rank 46, conf: 0.7962009906768799
# sent 447174: |['But I thought you guys were talking about selling?', "We're staying."]|
#
# ----------SENT 756784 @16---------
# TEXT: |["Oh, my God, I'm starving.", "I can't believe what a great video store that was."]|
# MEAN CONF TOP100: 0.7928236126899719
#
# -- 756784 range D0 0-1, mean conf: 0.8462843894958496--
# rank 2, conf: 0.8462843894958496
# sent 684446: |['God, these classrooms are huge.', 'Better to fit those big Harvard brains.']|
#
# -- 756784 range D1 1-10, mean conf: 0.8419058322906494--
# rank 7, conf: 0.8413364887237549
# sent 716645: |["God, I'm starved.", 'Think about something else.']|
#
# -- 756784 range D2 10-20, mean conf: 0.833716869354248--
# rank 16, conf: 0.8357127904891968
# sent 888369: |['Oh my God, a treasure chest, I’m rich!', 'Level three and she thinks she’s rich! What a noob.']|
#
# -- 756784 range D3 20-30, mean conf: 0.8212888836860657--
# rank 23, conf: 0.8242257833480835
# sent 1063875: |['God, you are so pathetic.', "No. You are! Don't you know that you still haveyour powers? All your powers. And you always will!Whether you're eighteen, or you're thirty, or you'refifty or you're a hundred. You will always be young, andyou will always be beautiful. You're Brian Kinney forfuck's sake!"]|
#
# -- 756784 range D4 30-60, mean conf: 0.7958403825759888--
# rank 48, conf: 0.794416069984436
# sent 894992: |['Oh, my God, you’re jealous.', 'Why would I be jealous?']|
#
# ----------SENT 727540 @17---------
# TEXT: |["Yay! So you're back.", 'Yeah. I just had to get out of there.']|
# MEAN CONF TOP100: 0.7404947280883789
#
# -- 727540 range D0 0-1, mean conf: 0.7797566056251526--
# rank 2, conf: 0.7797566056251526
# sent 320473: |['“So, you’re back.”', '“Very good Mr. I-can’t-trail-the-suspect-during-the-day-because-I’ll-burst-into-flames Private Eye.”']|
#
# -- 727540 range D1 1-10, mean conf: 0.7557837963104248--
# rank 10, conf: 0.7503955364227295
# sent 768401: |["You're back, okay, hi.", "We're gonna be playing a gig next month, and I think you'd really get into it."]|
#
# -- 727540 range D2 10-20, mean conf: 0.750209629535675--
# rank 17, conf: 0.7503703236579895
# sent 389742: |['Rich nephew, come over here and give your uncle a nice, big meal.  So, here we are', 'And a rich, respected doctor with many surviving patients.']|
#
# -- 727540 range D3 20-30, mean conf: 0.7493413686752319--
# rank 28, conf: 0.7493858933448792
# sent 770642: |['So are we.', 'Yeah, but mine are humiliating.']|
#
# -- 727540 range D4 30-60, mean conf: 0.7393086552619934--
# rank 40, conf: 0.739557147026062
# sent 334339: |["So we're a little late.", 'Come on.']|
#
# ----------SENT 636815 @18---------
# TEXT: |["There's something jamming the airlock controls.", "Torres to Chakotay. We've got a problem. The actuators aren't working. Somebody's going to have to go up there and take a look."]|
# MEAN CONF TOP100: 0.7371881008148193
#
# -- 636815 range D0 0-1, mean conf: 0.7448977828025818--
# rank 2, conf: 0.7448977828025818
# sent 6032: |["There's something blocking the firing bay.", "Oh, don't worry about that, Fenner. You won't be needing the firing bay any more. No more Kroll, no more methane, no more orbit shots. Ha ha!"]|
#
# -- 636815 range D1 1-10, mean conf: 0.7445380091667175--
# rank 8, conf: 0.7445353269577026
# sent 976346: |['Yes. There is something.', "Right. So, Ya know what. I think we should start acting like it. Going out in public, together. It'll be great. Like a real couple."]|
#
# -- 636815 range D2 10-20, mean conf: 0.7441520690917969--
# rank 17, conf: 0.7440570592880249
# sent 38196: |["There's something in those clouds. Something shining. Look.", 'Like metal. Why would there be metal in a storm?']|
#
# -- 636815 range D3 20-30, mean conf: 0.7427476048469543--
# rank 29, conf: 0.7424119710922241
# sent 598577: |['Thank you. Is there something else?', 'Have you heard anything more from Q?']|
#
# -- 636815 range D4 30-60, mean conf: 0.7417205572128296--
# rank 48, conf: 0.7421776652336121
# sent 286267: |["Reads that article on the inventor and figures there's something to cash in on.", 'You know, Bones never gets in this late.']|
#
# ----------SENT 455249 @19---------
# TEXT: |['You’re not wearing your ring.', 'I love you.']|
# MEAN CONF TOP100: 0.7256731986999512
#
# -- 455249 range D0 0-1, mean conf: 0.7451518177986145--
# rank 2, conf: 0.7451518177986145
# sent 954297: |['you�re not wearing a ring', 'I-I lost it...I-I mean I-I t- I took it off an I-I can�t find it']|
#
# -- 455249 range D1 1-10, mean conf: 0.7387271523475647--
# rank 10, conf: 0.7370350360870361
# sent 936352: |['your not wearing your sweatshirt', 'uhhh']|
#
# -- 455249 range D2 10-20, mean conf: 0.7336593270301819--
# rank 15, conf: 0.7338078022003174
# sent 1033799: |['A warlock wearing the ring of inspiration.', 'The what?']|
#
# -- 455249 range D3 20-30, mean conf: 0.731540858745575--
# rank 22, conf: 0.7325787544250488
# sent 897470: |['You’re wearing modern underwear?', 'Relatively modern. Why, what are you wearing?']|
#
# -- 455249 range D4 30-60, mean conf: 0.7248143553733826--
# rank 34, conf: 0.7275625467300415
# sent 721079: |['Hi. Oh, you wore a rose!', 'That was the agreement.']|
#
# ----------SENT 80949 @20---------
# TEXT: |['As you were. No saluting. Are you the same people as before?', 'Of course they are.']|
# MEAN CONF TOP100: 0.7138541340827942
#
# -- 80949 range D0 0-1, mean conf: 0.74451744556427--
# rank 2, conf: 0.74451744556427
# sent 382470: |["Nooo!   Are you people satisfied? This gentle visitor is dying! And we'll never even know why he came.", "I'll tell you ... with my final breath.   I came here with a simple dream"]|
#
# -- 80949 range D1 1-10, mean conf: 0.7354152202606201--
# rank 3, conf: 0.7432326078414917
# sent 147947: |['Yeah. Are you the radio people?', 'My name is Miss Crockett. This is my partner, Mr. Tubbs.']|
#
# -- 80949 range D2 10-20, mean conf: 0.7241443395614624--
# rank 12, conf: 0.7273203730583191
# sent 189586: |['These people are obviously freaks.', "Oh, you think so? Well, let's see what's behind Door Number Two."]|
#
# -- 80949 range D3 20-30, mean conf: 0.7208121418952942--
# rank 28, conf: 0.720155656337738
# sent 370534: |['You people are a disgrace! Get out!', "Oh, we're going. We'll give you until four to call us with an offer. After that we're going to make some calls of our own."]|
#
# -- 80949 range D4 30-60, mean conf: 0.7128303647041321--
# rank 48, conf: 0.7116757035255432
# sent 739427: |["They're great people.", 'This Patricia --']|
#
# ----------SENT 54421 @21---------
# TEXT: |["What's this?", "According to my instructions, it's the core to the Key of Time."]|
# MEAN CONF TOP100: 0.6866809725761414
#
# -- 54421 range D0 0-1, mean conf: 0.6866809129714966--
# rank 1, conf: 0.6866809129714966
# sent 493498: |["What's this?", "A.T.M. Security footage. We're trying to figure out if Ursula and Cruella stole something from Gold's shop."]|
#
# -- 54421 range D1 1-10, mean conf: 0.6866809129714966--
# rank 3, conf: 0.6866809129714966
# sent 1022888: |["Don't you know? Look-look at your face! You only shaved the right side of your face! What is this? A joke?", "No, t's a joke.. a joke... a joke... you think this is funny?"]|
#
# -- 54421 range D2 10-20, mean conf: 0.6866808533668518--
# rank 11, conf: 0.6866808533668518
# sent 321442: |['"What\'s this?\'', '"Enemies of Merl list."']|
#
# -- 54421 range D3 20-30, mean conf: 0.6866808533668518--
# rank 21, conf: 0.6866808533668518
# sent 969561: |['I think we found the perfect anniversary gift, Dawson. What is this?', "I don't know, I swear, I didn't shoot it. I must have left the camera running when we ran out of the ruins."]|
#
# -- 54421 range D4 30-60, mean conf: 0.6866810321807861--
# rank 51, conf: 0.6866808533668518
# sent 909586: |['Huh. What is this?', "Well, you know how they gave me the company car? Didn't make sense to have two, so I sold the other one."]|
#
# ----------SENT 793449 @22---------
# TEXT: |["Voodoo Mama Juju, the witch doctor of the Savannah swamps. I'm not comfortable with this.", 'Well how do you think I feel? I mean I have to play Caleb Crawdad, handsome playboy. Every night, a different woman. Being oogled. Having to hug and kiss and spoon, I make them feel beautiful.']|
# MEAN CONF TOP100: 0.6720778942108154
#
# -- 793449 range D0 0-1, mean conf: 0.6952775716781616--
# rank 2, conf: 0.6952775716781616
# sent 690140: |["Yeah, I know, okay? I'm not exactly thrilled with this.", "Okay. I'm sorry. It's your thing. I'll just butt out now."]|
#
# -- 793449 range D1 1-10, mean conf: 0.6744202375411987--
# rank 8, conf: 0.6738049983978271
# sent 200599: |["You're not welcome.", 'I love you, boy.']|
#
# -- 793449 range D2 10-20, mean conf: 0.6722618937492371--
# rank 12, conf: 0.6731892824172974
# sent 882184: |['“No! You’re not a guest.”', '“You want me to tear this place apart, you bloody poof?”']|
#
# -- 793449 range D3 20-30, mean conf: 0.6720690727233887--
# rank 25, conf: 0.6720749139785767
# sent 70546: |["You're not serious.", "I'm always serious."]|
#
# -- 793449 range D4 30-60, mean conf: 0.6718311905860901--
# rank 46, conf: 0.6718756556510925
# sent 962191: |["You're not alone.", 'Yes I am.']|
#
# ----------SENT 522187 @23---------
# TEXT: |["I didn't.", 'My only desire is to keep you safe.']|
# MEAN CONF TOP100: 0.6522531509399414
#
# -- 522187 range D0 0-1, mean conf: 0.6522532105445862--
# rank 1, conf: 0.6522532105445862
# sent 449046: |['I didn’t.', 'Please, Erica, you know a ton of people, I’m sure there’s someone.']|
#
# -- 522187 range D1 1-10, mean conf: 0.6522531509399414--
# rank 5, conf: 0.6522531509399414
# sent 175656: |["I didn't.", 'Good.']|
#
# -- 522187 range D2 10-20, mean conf: 0.6522531509399414--
# rank 11, conf: 0.6522531509399414
# sent 957147: |["I didn't.", "It was just coincidence? That's weird."]|
#
# -- 522187 range D3 20-30, mean conf: 0.6522531509399414--
# rank 21, conf: 0.6522531509399414
# sent 999705: |["I didn't.", "You won't."]|
#
# -- 522187 range D4 30-60, mean conf: 0.6522529721260071--
# rank 40, conf: 0.6522531509399414
# sent 761162: |["I didn't!", "Turn the situation around, Rory! How's it looking?"]|
#
# ----------SENT 794470 @24---------
# TEXT: |["No, no, no, no. It's the other hand. Right hand. Yeah.", "Would have been nice to work with my family. It would have been nice if Luke had been able to stay here. But he couldn't. These things seldom work out. I don't know how Ringling Brothers do it. Night after night, town after town, all across America. You would think they'd be sick of each other by now. But, clearly, they make it work. And my hat's off to them."]|
# MEAN CONF TOP100: 0.6315463185310364
#
# -- 794470 range D0 0-1, mean conf: 0.6906128525733948--
# rank 2, conf: 0.6906128525733948
# sent 393373: |["It's a hand.", "It's your hand."]|
#
# -- 794470 range D1 1-10, mean conf: 0.6806718707084656--
# rank 3, conf: 0.6906128525733948
# sent 609355: |['What is it, Mister Spock? Is it a hand?', 'Negative, Captain. Not living tissue.']|
#
# -- 794470 range D2 10-20, mean conf: 0.6676624417304993--
# rank 15, conf: 0.6711180806159973
# sent 238759: |['Is that the trillion-dollar bill in his hand?', "Well, that would be pretty careless of me, wouldn't it? I keep the real bill right here."]|
#
# -- 794470 range D3 20-30, mean conf: 0.6579057574272156--
# rank 31, conf: 0.6541514992713928
# sent 733103: |['Your hand is near the wax lips.', 'So?']|
#
# -- 794470 range D4 30-60, mean conf: 0.6250501275062561--
# rank 54, conf: 0.6161158680915833
# sent 485560: |["Wow. It's scary guffy for my back!", "Man that can't be good for nobody's back."]|
#
# ----------SENT 43232 @25---------
# TEXT: |['Have you discovered something, Doctor?', "Well, yes, I think I've managed to decode the programme mechanism. And if I'm right, I think there are eleven others in London, perhaps in an area of twenty to thirty miles. And this has it's own timing device, this computer. And I think if my calculations are right, then we conclude that they were intended to attack at twelve o'clock today."]|
# MEAN CONF TOP100: 0.6301108002662659
#
# -- 43232 range D0 0-1, mean conf: 0.708446741104126--
# rank 2, conf: 0.708446741104126
# sent 43241: |["Yeah. Haven't you anything you can suggest, Doctor? This is urgent.", "Somehow we've got to get a hold of that machine."]|
#
# -- 43232 range D1 1-10, mean conf: 0.6821608543395996--
# rank 9, conf: 0.6780745983123779
# sent 584595: |["I'm pleased. You have acquired something of a reputation, Captain.", 'Favourable, I hope.']|
#
# -- 43232 range D2 10-20, mean conf: 0.6503522992134094--
# rank 15, conf: 0.6555212736129761
# sent 570344: |['Do something, Captain.', 'Can we?']|
#
# -- 43232 range D3 20-30, mean conf: 0.6356643438339233--
# rank 22, conf: 0.6411726474761963
# sent 65354: |['Have you noticed something? I mean something very peculiar.', 'Well, everything�s peculiar.']|
#
# -- 43232 range D4 30-60, mean conf: 0.6246117949485779--
# rank 50, conf: 0.6220954060554504
# sent 865833: |['Hello, Marshall. Have you finally finished the ninja report?', "Yeah, I got it. Right here. I think it's gonna blow you away."]|
#
# ----------SENT 246898 @26---------
# TEXT: |["Oh-ho, so it's a good thing she died. From our point of view. Financially.", "Well, I'd like to thank you both for cooperating with our DID YOU DO IT?!"]|
# MEAN CONF TOP100: 0.6197549104690552
#
# -- 246898 range D0 0-1, mean conf: 0.6220648884773254--
# rank 2, conf: 0.6220648884773254
# sent 777735: |['This is as far as I can go. From a legal point of view.', 'What? Are you kidding?']|
#
# -- 246898 range D1 1-10, mean conf: 0.6209061145782471--
# rank 8, conf: 0.6207717657089233
# sent 393627: |['Whoa... whoa. Point of disturbance.', 'Hold up.']|
#
# -- 246898 range D2 10-20, mean conf: 0.6202885508537292--
# rank 12, conf: 0.6203698515892029
# sent 615898: |['Point, server.', "It's all in the wrist."]|
#
# -- 246898 range D3 20-30, mean conf: 0.6202006340026855--
# rank 23, conf: 0.6202114820480347
# sent 522452: |['No point anyway.', 'What?']|
#
# -- 246898 range D4 30-60, mean conf: 0.6200535893440247--
# rank 44, conf: 0.6200124621391296
# sent 663940: |["Dylan, we've got bigger problems than geological instability and a gang of looters. I've discovered the source of the tidal forces on Empyrium. A point singularity.", 'How did a point singularity bomb end up inside the planet?']|
#
# ----------SENT 588574 @27---------
# TEXT: |['Negative, sir. Their phaser banks are not armed.', 'What about the Cardassians?']|
# MEAN CONF TOP100: 0.6134008765220642
#
# -- 588574 range D0 0-1, mean conf: 0.619878351688385--
# rank 2, conf: 0.619878351688385
# sent 57126: |["Computers aren't infallible.", 'Shush.']|
#
# -- 588574 range D1 1-10, mean conf: 0.6184599995613098--
# rank 4, conf: 0.6191692352294922
# sent 565428: |["Don't look normal. That's putting it mildly. She's got more holes in her head than, than Swiss cheese. Her pathways aren't even complete.", "They're complete enough to still function."]|
#
# -- 588574 range D2 10-20, mean conf: 0.617490291595459--
# rank 13, conf: 0.6176889538764954
# sent 410031: |["Unfortunately, these windows aren't tempered.", 'Very dangerous if broken.']|
#
# -- 588574 range D3 20-30, mean conf: 0.6168534159660339--
# rank 30, conf: 0.6165431141853333
# sent 550066: |["I can't get them to materialise. My readings aren't complete.", 'Keep trying.']|
#
# -- 588574 range D4 30-60, mean conf: 0.6141093373298645--
# rank 38, conf: 0.6154511570930481
# sent 644479: |["The rebels aren't your enemies.", 'Who said that?']|
#
# ----------SENT 875236 @28---------
# TEXT: |['"Oh you know grading papers."', '"Ah, that\'ll be fun."']|
# MEAN CONF TOP100: 0.5932340621948242
#
# -- 875236 range D0 0-1, mean conf: 0.59420245885849--
# rank 2, conf: 0.59420245885849
# sent 742231: |['Oh, you know.', 'This is our daughter, Lorelai, and our granddaughter, Rory.']|
#
# -- 875236 range D1 1-10, mean conf: 0.5942020416259766--
# rank 11, conf: 0.5941993594169617
# sent 770994: |['Oh, you know -- the greenhouse.', 'The greenhouse? What about the greenhouse?']|
#
# -- 875236 range D2 10-20, mean conf: 0.5936799049377441--
# rank 15, conf: 0.5939970016479492
# sent 266084: |['Oh, you know… not great.', 'Yeah.']|
#
# -- 875236 range D3 20-30, mean conf: 0.5932471752166748--
# rank 26, conf: 0.5932530760765076
# sent 307781: |["Yeah, you know? 'Cause, uh, this isn't weird enough.", 'Hodgins supplied the types of makeup.']|
#
# -- 875236 range D4 30-60, mean conf: 0.5930696129798889--
# rank 33, conf: 0.5931532979011536
# sent 210736: |['Wow, Dad. You really know your monorails.', "Homer, there's a family of opossums in here!"]|
#
# ----------SENT 963441 @29---------
# TEXT: |["Yeah, it's okay, though! You're a very cute persnickety.", 'I did not get persnickety.']|
# MEAN CONF TOP100: 0.5735454559326172
#
# -- 963441 range D0 0-1, mean conf: 0.5735506415367126--
# rank 2, conf: 0.5735506415367126
# sent 971343: |["No, I'm not! You are incredibly talented.", 'You are incredibly biased.']|
#
# -- 963441 range D1 1-10, mean conf: 0.5735486745834351--
# rank 4, conf: 0.5735496282577515
# sent 642402: |['Are you amused? We have at best eight hours before that storm reduces us to component parts, and Dylan has disappeared.', "I don't know. Ask Rev Bem, maybe he knows."]|
#
# -- 963441 range D2 10-20, mean conf: 0.5735471844673157--
# rank 16, conf: 0.5735473036766052
# sent 951930: |["you're a dweeb", 'will you show me where ta drop my stuff']|
#
# -- 963441 range D3 20-30, mean conf: 0.5735463500022888--
# rank 28, conf: 0.573546290397644
# sent 1070555: |["You're dreamy-eyed schoolboy.", "In ways you can't."]|
#
# -- 963441 range D4 30-60, mean conf: 0.5735448002815247--
# rank 46, conf: 0.5735446214675903
# sent 914124: |['You are a putz.', 'As advertised.']|
#
# ----------SENT 611075 @30---------
# TEXT: |['McCoy to Bridge.', 'Spock here.']|
# MEAN CONF TOP100: 0.5327270030975342
#
# -- 611075 range D0 0-1, mean conf: 0.5363457202911377--
# rank 1, conf: 0.5363457202911377
# sent 584303: |['Tucker to the Bridge.', 'Go ahead.']|
#
# -- 611075 range D1 1-10, mean conf: 0.5363457202911377--
# rank 8, conf: 0.5363457202911377
# sent 568386: |['McCoy to Bridge. Captain there?', "Kirk here. Nothing to report, Doctor. We haven't located Mrs. Crater. What's the matter, can't you sleep?"]|
#
# -- 611075 range D2 10-20, mean conf: 0.5363456010818481--
# rank 18, conf: 0.5363456606864929
# sent 640058: |['Tucker to the Bridge.', 'Go ahead.']|
#
# -- 611075 range D3 20-30, mean conf: 0.5359872579574585--
# rank 28, conf: 0.5358848571777344
# sent 641273: |['Corporal Kelly to the Bridge.', 'Go ahead.']|
#
# -- 611075 range D4 30-60, mean conf: 0.5338454842567444--
# rank 43, conf: 0.5348538756370544
# sent 1014368: |["That irreverence, that wit I'd recognize it anywhere. Some charlatan has stolen a Ziggy and passed it off as his own. I can prove it. Quick Elaine, to my archives.", "You know, you know what's great about our relationship?...It's not about looks."]|
#
# ----------SENT 549490 @31---------
# TEXT: |['You hit him pretty hard, Captain.', 'What do you think, Counsellor?']|
# MEAN CONF TOP100: 0.5135357975959778
#
# -- 549490 range D0 0-1, mean conf: 0.5384383797645569--
# rank 2, conf: 0.5384383797645569
# sent 600578: |['Captain, when the wave hit our communications array received a download.', 'What sort of download?']|
#
# -- 549490 range D1 1-10, mean conf: 0.5199544429779053--
# rank 8, conf: 0.5187309980392456
# sent 571076: |['He burned up, Captain.', 'Reverse course. One hundred and eighty degrees about.']|
#
# -- 549490 range D2 10-20, mean conf: 0.5165585279464722--
# rank 19, conf: 0.5159026980400085
# sent 573385: |['Your uniform, Captain.', "Yes, it's a shame yours isn't as attractive as mine. Gestapo, I believe."]|
#
# -- 549490 range D3 20-30, mean conf: 0.5151494741439819--
# rank 24, conf: 0.5156180262565613
# sent 569889: |['On your knees, Captain!', 'No! Does it still taste as sweet?']|
#
# -- 549490 range D4 30-60, mean conf: 0.5128075480461121--
# rank 57, conf: 0.5120689272880554
# sent 886495: |['No dead animal could threaten a storied soldier such as yourself, Captain.', "It could, if powered by forces we don't understand."]|
#
# ----------SENT 366799 @32---------
# TEXT: |['Uh, Phoebe…', 'Oh Ross, hi.']|
# MEAN CONF TOP100: 0.4846937656402588
#
# -- 366799 range D0 0-1, mean conf: 0.48489120602607727--
# rank 2, conf: 0.48489120602607727
# sent 901542: |['Alright, uh, fine, I’m coming and I’m bringing somebody. Uh, Koothrappali plus one.', 'Who you bringing?']|
#
# -- 366799 range D1 1-10, mean conf: 0.4848366975784302--
# rank 4, conf: 0.4848546087741852
# sent 736085: |['Uh, hello, Luke.', 'You said I had three days, right?']|
#
# -- 366799 range D2 10-20, mean conf: 0.48482194542884827--
# rank 17, conf: 0.48482197523117065
# sent 879656: |['Uh, Willow?', 'Uh, hi.']|
#
# -- 366799 range D3 20-30, mean conf: 0.48482194542884827--
# rank 30, conf: 0.48482194542884827
# sent 406017: |['Nick, uh, ...', "You know what? Forget about it. If this girl's involved, that means she's capable of murder. It's all cued up for you. Her voice is first."]|
#
# -- 366799 range D4 30-60, mean conf: 0.4847716689109802--
# rank 56, conf: 0.4846956133842468
# sent 796199: |['Uh, no, no, no Gould.', 'Did you do her?']|
#
# ----------SENT 976574 @33---------
# TEXT: |['Its not going to happen tonight. No more life imitating movies for me.', 'Wait a minute, what did I just hear?']|
# MEAN CONF TOP100: 0.45352962613105774
#
# -- 976574 range D0 0-1, mean conf: 0.5661181807518005--
# rank 2, conf: 0.5661181807518005
# sent 1011265: |['Wow, she rearranged her whole life for you.', "I guess she did.\xa0 He's gone, now I'm the man."]|
#
# -- 976574 range D1 1-10, mean conf: 0.5113174319267273--
# rank 4, conf: 0.5291217565536499
# sent 653005: |['I cannot allow you to jeopardise your life for me.', "Spock, didn't you hear? I might be able to retain and bring these techniques to the world. Jim, isn't it worth that risk? Wouldn't you insist upon taking such a risk yourself?"]|
#
# -- 976574 range D2 10-20, mean conf: 0.48305946588516235--
# rank 14, conf: 0.4837891161441803
# sent 387857: |['Hey! Save some for me!', "Good news, everyone. Tomorrow you'll be making a delivery to Ebola 9, the virus planet."]|
#
# -- 976574 range D3 20-30, mean conf: 0.4695529341697693--
# rank 29, conf: 0.46544399857521057
# sent 224403: |['Listen to me. Unless you change your deceitful ways, I foresee a life of bitterness and failure for you... Bart Simpson.', "How'd you know my name?"]|
#
# -- 976574 range D4 30-60, mean conf: 0.44937336444854736--
# rank 49, conf: 0.4460565745830536
# sent 95656: |['Yes my Lord, I owe them my life.', 'How did they heal you? You were as good as dead, you said.']|
#
# ----------SENT 292822 @34---------
# TEXT: |['Where was she buried?', 'Where was she buried? Why did you dig her up?']|
# MEAN CONF TOP100: 0.4415159523487091
#
# -- 292822 range D0 0-1, mean conf: 0.4479926824569702--
# rank 2, conf: 0.4479926824569702
# sent 672685: |['Where was I buried?', 'You were...cremated. Vaughn spread your ashes at sea.']|
#
# -- 292822 range D1 1-10, mean conf: 0.44625532627105713--
# rank 10, conf: 0.44312503933906555
# sent 115096: |["It's not unlike the Egyptians, however. Their mummified dead were buried along with personal treasures to accompany them on their journey to the afterlife.", 'Where he could squeeze in eighteen now and then.']|
#
# -- 292822 range D2 10-20, mean conf: 0.4423074722290039--
# rank 17, conf: 0.4421771466732025
# sent 409895: |['Either she was stabbed by it ...', 'Well, the statue looks a little unwieldy.']|
#
# -- 292822 range D3 20-30, mean conf: 0.44190841913223267--
# rank 25, conf: 0.441956102848053
# sent 401139: |["She wasn't even burned.", "Smoke inhalation happens really fast. I'm so sorry. I heard you say she wasn't supposed to be home tonight. Was she with her dad?"]|
#
# -- 292822 range D4 30-60, mean conf: 0.4411161541938782--
# rank 60, conf: 0.44074374437332153
# sent 668478: |['And you were struck about halfway there?', 'About that, yeah.']|
#
# ----------SENT 898773 @35---------
# TEXT: |['I see. Did her abysmal housekeeping skills finally trump her perkiness?', 'No, her bed kind of… broke.']|
# MEAN CONF TOP100: 0.40570345520973206
#
# -- 898773 range D0 0-1, mean conf: 0.4069839417934418--
# rank 1, conf: 0.4069839417934418
# sent 898738: |['I see. Did her abysmal housekeeping skills finally trump her perkiness?', 'No, her bed kind of… broke.']|
#
# -- 898773 range D1 1-10, mean conf: 0.40601471066474915--
# rank 3, conf: 0.406391978263855
# sent 188807: |['And I really did admire your skill with that violin.', "Don't you dare hurt him! Klaus: Oh, I hope I won't have to, sweetheart. But, then, that depends on you."]|
#
# -- 898773 range D2 10-20, mean conf: 0.40580177307128906--
# rank 21, conf: 0.4057692587375641
# sent 699597: |["He didn't initiate this?", 'No.']|
#
# -- 898773 range D3 20-30, mean conf: 0.40573662519454956--
# rank 30, conf: 0.4057239890098572
# sent 833178: |["I'm going to have to change the locks.Did you stage a jailbreak?", 'Stefan.']|
#
# -- 898773 range D4 30-60, mean conf: 0.40566548705101013--
# rank 50, conf: 0.40565839409828186
# sent 931963: |["I didn't stoop.", 'What happened?']|
#
# ----------SENT 593286 @36---------
# TEXT: |["No wonder they didn't answer our hail for two days. Nothing here to answer with.", 'Commander, I am detecting life signs from behind that door.']|
# MEAN CONF TOP100: 0.352264940738678
#
# -- 593286 range D0 0-1, mean conf: 0.3731744885444641--
# rank 2, conf: 0.3731744885444641
# sent 584504: |['Respectfully, sir, I refuse to answer any more questions.', "(into his ear) Malcolm, I never would've believed that you, of all people."]|
#
# -- 593286 range D1 1-10, mean conf: 0.35889530181884766--
# rank 6, conf: 0.3586328625679016
# sent 553546: |["It won't answer to my clearance, sir.", 'Computer, this is Captain Picard. Return all command functions to the stations.']|
#
# -- 593286 range D2 10-20, mean conf: 0.3552442491054535--
# rank 13, conf: 0.356062650680542
# sent 525617: |['. But I will answer to Satan.', 'What is she still doing here?']|
#
# -- 593286 range D3 20-30, mean conf: 0.35438770055770874--
# rank 22, conf: 0.35463041067123413
# sent 373148: |["She can't answer you.", "Or doesn't want to."]|
#
# -- 593286 range D4 30-60, mean conf: 0.35320791602134705--
# rank 46, conf: 0.3534671664237976
# sent 327607: |['No, answer his.', 'Okay, it was just me and her at the back of the train, and I sat near the door, so she’d have to pass by me if she wanted to switch cars. She was totally at my mercy.']|
#
# ----------SENT 870621 @37---------
# TEXT: |['Yeah, and it cuts in and out.', 'Ooh! How did you do it?']|
# MEAN CONF TOP100: 0.10574525594711304
#
# -- 870621 range D0 0-1, mean conf: 0.11344638466835022--
# rank 2, conf: 0.11344638466835022
# sent 974581: |['Yes. And in closets and underneath the beds.', 'You are deeply disturbed. I had no idea. That is adorable.']|
#
# -- 870621 range D1 1-10, mean conf: 0.11037592589855194--
# rank 9, conf: 0.10988426953554153
# sent 894861: |['Okay, well, there are no shower scenes in this one. They just try to clone me from my corpse, but my DNA gets mixed with the ape’s DNA and I end up running around with giant gorilla hands and feet.', 'Am I missing something, or isn’t that the part she was born to play?']|
#
# -- 870621 range D2 10-20, mean conf: 0.10798025131225586--
# rank 21, conf: 0.10718918591737747
# sent 222748: |['Now remember the plan, boy. If you run out of air, tug on the rope--', '--sixty-four times. No more, no less. Got it.']|
#
# -- 870621 range D3 20-30, mean conf: 0.10650119930505753--
# rank 22, conf: 0.1071365475654602
# sent 1064325: |['So this is what it comes to. Pulled out of a dumpster, tossed in the ground.', "Didn't seem right."]|
#
# -- 870621 range D4 30-60, mean conf: 0.1054595559835434--
# rank 46, conf: 0.10550053417682648
# sent 295086: |["God no, I would never let him go into the system. I, uh - I dropped out of college, I joined the fire department to support him. Your brother didn't-", 'It was a difficult situation for him.']|
#
# ----------SENT 883645 @38---------
# TEXT: |['Oh, yeah, campaigning. Rough gig.', 'What would you know about it? Just because you were Guacamole']|
# MEAN CONF TOP100: 0.05262603610754013
#
# -- 883645 range D0 0-1, mean conf: 0.05780544877052307--
# rank 1, conf: 0.05780544877052307
# sent 840334: |['Oh, yeah? Where?', 'I know this little dive bar off the beaten path']|
#
# -- 883645 range D1 1-10, mean conf: 0.05780544504523277--
# rank 11, conf: 0.05780544504523277
# sent 405347: |['Oh, yeah, yeah, yeah, yeah, yeah.', 'So business is good?']|
#
# -- 883645 range D2 10-20, mean conf: 0.057805437594652176--
# rank 14, conf: 0.05780544504523277
# sent 386851: |['Oh, yeah? Well bite my shiny metal--   Oh, nooo!', "Nobody tell Fry I'm deaf. If he found out I couldn't hear his opera, it'd break his heart."]|
#
# -- 883645 range D3 20-30, mean conf: 0.057412754744291306--
# rank 26, conf: 0.057531341910362244
# sent 731311: |['Oh yeah, me too.', 'You ordering?']|
#
# -- 883645 range D4 30-60, mean conf: 0.05259768292307854--
# rank 35, conf: 0.05585383623838425
# sent 105608: |['Oh, definitely.', 'Okay']|
#
# ----------SENT 934780 @39---------
# TEXT: |['you�re ripping up your drawings', 'yeah why not']|
# MEAN CONF TOP100: 0.01962616667151451
#
# -- 934780 range D0 0-1, mean conf: 0.02382638491690159--
# rank 2, conf: 0.02382638491690159
# sent 939853: |['you�re up early', "i'm studying for this test"]|
#
# -- 934780 range D1 1-10, mean conf: 0.022099366411566734--
# rank 10, conf: 0.02093026600778103
# sent 1043754: |['And she wishes to accomplish that by speed dating?', "I don't know."]|
#
# -- 934780 range D2 10-20, mean conf: 0.020104389637708664--
# rank 14, conf: 0.020217586308717728
# sent 309827: |['...and totally failing!', '...making beautiful music for shoppers...']|
#
# -- 934780 range D3 20-30, mean conf: 0.019731741398572922--
# rank 22, conf: 0.019875703379511833
# sent 587402: |['Commander, I am detecting life signs from behind that door.', 'Worf!']|
#
# -- 934780 range D4 30-60, mean conf: 0.019352586939930916--
# rank 34, conf: 0.019536245614290237
# sent 824051: |['19, serving 4.', 'Woooh! Nice baby! Nice one!']|

# %% [markdown]
# ## V10, V1 - det
#
# DEP: keep all except det.
#
# POS: keep all.

# %%
data_v10 = data.loc[data.head_pos!='det']
data_v10
# Out:
#           sent_id                        show_id            char_name char_id  \
# 0         1063785                    QueerAsFolk              MICHAEL  l22346
# 4          508646                  OnceUponATime           CINDERELLA  l19407
# 5           78453                      DoctorWho              BARBARA   l8667
# 6          146223                   VeronicaMars             VERONICA  l30591
# 7           19636                      DoctorWho      ELEVENTH DOCTOR   l8661
# 10        1059921                    Charmed1998                 ANDY   l6497
# 11         504657                  OnceUponATime        MARY MARGARET  l19393
# 12         672740                          Alias                 JACK   l1275
# 13         144292                   VeronicaMars             VERONICA  l30591
# 14         537460                       StarTrek              JANEWAY  l25466
# 15         923983                  SonsOfAnarchy                  JAX  l24810
# 18         662463                       StarTrek                PHLOX  l25490
# 19         642832                       StarTrek               HARPER   l1893
# 21         238693                    TheSimpsons  C. Montgomery Burns  a15869
# 22         606411                       StarTrek                 WORF  l25435
# 23         526675                   GreysAnatomy                DEREK  l12263
# 24         751240                   GilmoreGirls              RICHARD  l11615
# 26         518382                  AdventureTime   Princess Bubblegum   a3409
# 28         130438                           NCIS                 KATE  l18800
# 29         437089  MyLittlePonyFriendshipIsMagic                Spike  a13105
# 31         580866                       StarTrek               ARCHER  l25486
# 32         971419                   DawsonsCreek               DAWSON   l7946
# 33         866034              HowIMetYourMother                ROBIN  l13772
# 34        1055655                    Charmed1998                 COLE   l6502
# 35        1000771                       Seinfeld                JERRY  l23593
# 36         642447                       StarTrek               HARPER   l1893
# 38         110457                           NCIS                GIBBS  l18791
# 40         403957                       CSIVerse                 NICK   l7486
# 41         582768                       StarTrek               ARCHER  l25486
# 42         788696                    TheOfficeUS              MICHAEL  l19352
# ...           ...                            ...                  ...     ...
# 17160342   676588                          Alias                DIXON   l1277
# 17160343   603811                       StarTrek                 WORF  l25435
# 17160344   749073                   GilmoreGirls               SOOKIE  l11619
# 17160346   373719                   TheMentalist               LISBON  l17674
# 17160347   656813                       StarTrek               TRANCE   l1896
# 17160349   709703                   GilmoreGirls                 RORY  l11613
# 17160350   174190                     Smallville                 LANA  l24615
# 17160351   274814                   Supernatural                  SAM  l25967
# 17160352   548045                       StarTrek              JANEWAY  l25466
# 17160354   192729                    TheSimpsons        Homer Simpson  a15835
# 17160355   329079                        Friends                 ROSS  l10696
# 17160356   509057                  AdventureTime                 Finn   a3415
# 17160357   465269                    OneTreeHill               NATHAN  l19594
# 17160359    25432                      DoctorWho        SECOND DOCTOR   l8651
# 17160362   793175                    TheOfficeUS              MICHAEL  l19352
# 17160363  1006647                       Seinfeld               GEORGE  l23594
# 17160364   610713                       StarTrek                SPOCK  l25411
# 17160365   723387                   GilmoreGirls                 RORY  l11613
# 17160366   125325                           NCIS                 ABBY  l18806
# 17160367   732232                   GilmoreGirls                 LUKE  l11617
# 17160368   774869                        Roswell                  MAX  l23046
# 17160369   967551                   DawsonsCreek                 JOEY   l7947
# 17160370   860557              HowIMetYourMother               BARNEY  l13774
# 17160371   126524                           NCIS                 ABBY  l18806
# 17160372   387420                       Futurama                Leela   a8871
# 17160373   537886                       StarTrek              JANEWAY  l25466
# 17160374   182960                     Smallville                JIMMY  l24654
# 17160375   568148                       StarTrek                 HUNT   l1890
# 17160376   652290                       StarTrek                MCCOY  l25412
# 17160377   295962                          Bones              BRENNAN   l5146
#
#          head_info   head_pos      token  token_par  position  is_stop  \
# 0              POS        VBZ         be         be         2     True
# 4              POS         JJ     entire     entire        77    False
# 5              DEP      advcl         be       hold        34     True
# 6              DEP   compound       drug    testing         5    False
# 7              POS          .          .          .        66    False
# 10             DEP      ccomp         be      think       -18     True
# 11             POS       PRP$        her        her        45     True
# 12             POS         UH         um         um         9    False
# 13             POS        VBZ         do         do         0     True
# 14             POS         NN  deflector  deflector        61    False
# 15             POS        VBZ         be         be        26     True
# 18             DEP      nsubj  condition         be       -16    False
# 19             DEP       prep     beyond         be        24     True
# 21             POS         NN      blood      blood        63    False
# 22             POS          ,          ,          ,        72    False
# 23             DEP       mark         if         be         5     True
# 24             POS         JJ      ready      ready        19    False
# 26             POS         IN         on         on        20     True
# 28             POS         UH         no         no         0     True
# 29             POS        PRP          i          i        20     True
# 31             DEP       mark         if      agree         5     True
# 32             DEP   npadvmod     PERSON       know        15    False
# 33             POS         NN       info       info        63    False
# 34             POS          ,          ,          ,        12    False
# 35             POS        PRP        you        you         5     True
# 36             DEP   npadvmod     PERSON         be       -19    False
# 38             DEP       dobj         me       tell        -8     True
# 40             DEP       dobj         it       help        -5     True
# 41             POS        WDT       that       that        54     True
# 42             DEP  nsubjpass         he      dress         9     True
# ...            ...        ...        ...        ...       ...      ...
# 17160342       POS        VBZ         be         be        28     True
# 17160343       POS         CD   CARDINAL   CARDINAL        61     True
# 17160344       POS         NN     budget     budget        20    False
# 17160346       DEP     advmod       once      bring       -27     True
# 17160347       POS        PRP         it         it        74     True
# 17160349       DEP       pobj      honey        for        -4    False
# 17160350       DEP        aux         to         go         3     True
# 17160351       POS          .          .          .        16    False
# 17160352       DEP        aux      could       wait        27     True
# 17160354       POS        PRP         me         me        76     True
# 17160355       POS         VB       wait       wait       110    False
# 17160356       POS          .          ?          ?        34    False
# 17160357       POS        PRP        you        you         7     True
# 17160359       POS         NN     report     report        62    False
# 17160362       POS        NNP        GPE        GPE        72    False
# 17160363       DEP       mark       that        ask        14     True
# 17160364       POS         MD       will       will       113     True
# 17160365       POS        VBD         be         be         8     True
# 17160366       POS        NNP        ORG        ORG       114    False
# 17160367       POS          .          .          .       162    False
# 17160368       DEP       intj         no     PERSON         4     True
# 17160369       POS         TO         to         to       261     True
# 17160370       DEP       intj       okay         be        14    False
# 17160371       DEP      nsubj       that         be         4     True
# 17160372       POS          .          .          .        86    False
# 17160373       POS         NN      price      price       109    False
# 17160374       POS         RB       sort       sort        79    False
# 17160375       POS          .          .          .        32    False
# 17160376       POS        NNP        FAC        FAC        66    False
# 17160377       DEP       case         's     PERSON        -7     True
#
#                        head_text
# 0                      VBZ|be|be
# 4               JJ|entire|entire
# 5                  advcl|be|hold
# 6          compound|drug|testing
# 7                          .|.|.
# 10                ccomp|be|think
# 11                  PRP$|her|her
# 12                      UH|um|um
# 13                     VBZ|do|do
# 14        NN|deflector|deflector
# 15                     VBZ|be|be
# 18            nsubj|condition|be
# 19                prep|beyond|be
# 21                NN|blood|blood
# 22                         ,|,|,
# 23                    mark|if|be
# 24                JJ|ready|ready
# 26                      IN|on|on
# 28                      UH|no|no
# 29                       PRP|i|i
# 31                 mark|if|agree
# 32          npadvmod|PERSON|know
# 33                  NN|info|info
# 34                         ,|,|,
# 35                   PRP|you|you
# 36            npadvmod|PERSON|be
# 38                  dobj|me|tell
# 40                  dobj|it|help
# 41                 WDT|that|that
# 42            nsubjpass|he|dress
# ...                          ...
# 17160342               VBZ|be|be
# 17160343    CD|CARDINAL|CARDINAL
# 17160344        NN|budget|budget
# 17160346       advmod|once|bring
# 17160347               PRP|it|it
# 17160349          pobj|honey|for
# 17160350               aux|to|go
# 17160351                   .|.|.
# 17160352          aux|could|wait
# 17160354               PRP|me|me
# 17160355            VB|wait|wait
# 17160356                   .|?|?
# 17160357             PRP|you|you
# 17160359        NN|report|report
# 17160362             NNP|GPE|GPE
# 17160363           mark|that|ask
# 17160364            MD|will|will
# 17160365               VBD|be|be
# 17160366             NNP|ORG|ORG
# 17160367                   .|.|.
# 17160368          intj|no|PERSON
# 17160369                TO|to|to
# 17160370            intj|okay|be
# 17160371           nsubj|that|be
# 17160372                   .|.|.
# 17160373          NN|price|price
# 17160374            RB|sort|sort
# 17160375                   .|.|.
# 17160376             NNP|FAC|FAC
# 17160377          case|'s|PERSON
#
# [13118740 rows x 11 columns]

# %%
model_v10, SENT_CATS_v10, FEATURE_CATS_v10 = get_train(data_v10, report_test_acc=False)
SENT_MAP_v10, INV_SENT_MAP_v10 = build_maps(data_v10)
# Out:
# <131569x929612 sparse matrix of type '<class 'numpy.float64'>'
# 	with 13118740 stored elements in COOrdinate format>
# --TRAIN: train on complete matrix --
# 100%|██████████| 200.0/200 [06:44<00:00,  2.21s/it]
# 929612 929612

# %%
mi = ModelInspection(model_v10, SENT_MAP_v10, INV_SENT_MAP_v10, dialog_df=dialogs)
mi.compute()
mi.inspect_by_rank()
# Out:
# FINISH COMPUTE...
#
# ----------SENT 928397 @0---------
# TEXT: |["You know, I'm with you on Marks, Jax. But I don't know how much longer I'm gonna be able to keep playing double agent.", 'Niners are the only ones that can get us close to Marks so we can get Bobby back.']|
# MEAN CONF TOP100: 1.3698421716690063
#
# -- 928397 range D0 0-1, mean conf: 1.8243440389633179--
# rank 2, conf: 1.8243440389633179
# sent 924606: |["For every 24 hours August has to wait, he's gonna cut off another part of your guy. I mean, I'm with you, but I don't know how much longer I'm gonna be able to keep playing double agent.", 'Jesus.']|
#
# -- 928397 range D1 1-10, mean conf: 1.46809983253479--
# rank 5, conf: 1.4859862327575684
# sent 506721: |['I’m not gonna be around much longer unless we find where this belongs.', 'I think that belongs to me.']|
#
# -- 928397 range D2 10-20, mean conf: 1.4162633419036865--
# rank 21, conf: 1.4000674486160278
# sent 944546: |["ok dad first of all, i'm really sorry an now I know your not gonna believe this but-", 'you were doin chin ups on the window sill, right']|
#
# -- 928397 range D3 20-30, mean conf: 1.3842853307724--
# rank 31, conf: 1.3763394355773926
# sent 157909: |["I don't know how helpful he's actually gonna be.", "I'll tear this place down, piece by piece. Just tell me where to start."]|
#
# -- 928397 range D4 30-60, mean conf: 1.3612990379333496--
# rank 37, conf: 1.372450590133667
# sent 965937: |["I don't know, but I know it's not right, and I know that, that my failures and my shortcomings don't really have anything to do with you, but I-- I also know that if we stay together I am going to continue to take them out on you.", "You know, I've got news for you, Pacey, how you treat me is actually totally in your power."]|
#
# ----------SENT 291092 @1---------
# TEXT: |["Agent Booth? I'm, uh, Jimmy Walpert. I'm sorry that I wasn't here, but I-I got a bit sick.", "Well, that's no surprise there."]|
# MEAN CONF TOP100: 1.2416512966156006
#
# -- 291092 range D0 0-1, mean conf: 1.3559445142745972--
# rank 2, conf: 1.3559445142745972
# sent 281906: |['But I was just getting good.', "..at cheating, Bones. That's what counting cards is."]|
#
# -- 291092 range D1 1-10, mean conf: 1.3236535787582397--
# rank 6, conf: 1.3295843601226807
# sent 171563: |['I-I got a little lost along the way, but here I am.', 'Those for me?']|
#
# -- 291092 range D2 10-20, mean conf: 1.2856967449188232--
# rank 13, conf: 1.2923208475112915
# sent 227411: |["I'm glad you've got such a stimulating substitute, but I'm worried about Mrs. Krabappel.", "Oh, no worries. I heard on the four-square court she's doin' great."]|
#
# -- 291092 range D3 20-30, mean conf: 1.262695550918579--
# rank 26, conf: 1.2611098289489746
# sent 382395: |["Fine kick, sir. But I'm actually here to deliver your cut from the cigar heist.", "Oh, sweet legal tender!  Kid, tell the Donbot I'm quitting organised crime. From now on I'll stick to regular kind."]|
#
# -- 291092 range D4 30-60, mean conf: 1.2392069101333618--
# rank 36, conf: 1.2515817880630493
# sent 173081: |["Lana, I didn't mean to rattle you. There was no answer, so I started to get concerned.", "Lex, I'm fine."]|
#
# ----------SENT 589603 @2---------
# TEXT: |["My superintendent was a Betazoid, a full telepath. When he sent for you to his office, he didn't have to ask what you'd done.", "You got called into the superintendent's office? That's a story I'd like to hear."]|
# MEAN CONF TOP100: 1.237969994544983
#
# -- 589603 range D0 0-1, mean conf: 1.3553036451339722--
# rank 2, conf: 1.3553036451339722
# sent 411195: |["You know how Grissom is. If you ask him for the keys to the car he's going to ask you if you've done your homework.", "Yeah, that's what I was thinking."]|
#
# -- 589603 range D1 1-10, mean conf: 1.3211870193481445--
# rank 7, conf: 1.3133752346038818
# sent 255876: |["Nonsense! When I left PAN AM they said they'd always have a job waiting for me.", "Abe... there's no more PAN AM."]|
#
# -- 589603 range D2 10-20, mean conf: 1.2772111892700195--
# rank 19, conf: 1.2684026956558228
# sent 120035: |["Precisely. Now don't ask me what our guest was doing in an oil drum, sitting on a bomb because I haven't the foggiest.", 'Hmm. No other explanation?']|
#
# -- 589603 range D3 20-30, mean conf: 1.247801423072815--
# rank 22, conf: 1.2562108039855957
# sent 796399: |["Today is spring cleaning day here at Dunder Mifflin. And yes I know its January. I am not an idiot. But, if you do your Spring cleaning in January; guess what you don't have to do in the spring? Anything. They say a cluttered desk means a cluttered mind. Well I say that an empty desk means a...", 'Empty mind.']|
#
# -- 589603 range D4 30-60, mean conf: 1.2323060035705566--
# rank 32, conf: 1.241965889930725
# sent 425450: |['But they have taken our land. What would you have me do, Rainbow Dash?', "I don't know... but it's never too late to think of something."]|
#
# ----------SENT 364188 @3---------
# TEXT: |['How-how I like to melt stuff, and how I dislike stuff that doesn’t melt.', 'Right, okay, um-mm.']|
# MEAN CONF TOP100: 1.225007176399231
#
# -- 364188 range D0 0-1, mean conf: 1.3561720848083496--
# rank 2, conf: 1.3561720848083496
# sent 523498: |['You know ... not everybody likes to lay their guts out on the table like that, Tara.', 'Yeah, they might not like it, but they all dream about finding somebody they can do it with.']|
#
# -- 364188 range D1 1-10, mean conf: 1.30433988571167--
# rank 5, conf: 1.315793752670288
# sent 962466: |["But you don't like scary stuff.", 'I have a contradicting personality. Please continue.']|
#
# -- 364188 range D2 10-20, mean conf: 1.272014856338501--
# rank 13, conf: 1.2854993343353271
# sent 317189: |['“You know it’s not nice to trick people!”', '“You’re going to tell me what’s going on?”']|
#
# -- 364188 range D3 20-30, mean conf: 1.2472341060638428--
# rank 31, conf: 1.2400599718093872
# sent 911672: |['I think it’s lovely you call your mommy and let her know you’re going to be late for dinner. From what I know about these things, if a woman doesn’t breast-feed on time, it’s very uncomfortable for her boobies.', 'Don’t you talk about my mother’s boobies!']|
#
# -- 364188 range D4 30-60, mean conf: 1.2182697057724--
# rank 51, conf: 1.212618350982666
# sent 78080: |["Well I don't like this splitting up.", "Well, I don't mind, Ian."]|
#
# ----------SENT 43012 @4---------
# TEXT: |['You are welcome, welcome indeed. Though we know you only as a record in our charts of space and time, yet you seem to us like an old friend.', "Well, that's very kind of you to make me feel so welcome."]|
# MEAN CONF TOP100: 1.1366817951202393
#
# -- 43012 range D0 0-1, mean conf: 1.330478549003601--
# rank 2, conf: 1.330478549003601
# sent 291122: |['When someone lies with this sort of ease in their professional relationships, chances are they lie at least as much in their personal relationships.', 'Well, maybe she just lied to the wrong person.']|
#
# -- 43012 range D1 1-10, mean conf: 1.2150485515594482--
# rank 9, conf: 1.1958825588226318
# sent 382934: |['People, as you know, our young sons have become great successes in the very same field as us.', 'Alright!']|
#
# -- 43012 range D2 10-20, mean conf: 1.1746206283569336--
# rank 15, conf: 1.1744321584701538
# sent 779837: |["And that's all you're going to get. You may look like our father, but we'll fight any further paternity and inheritance claims every step of the way.", "I'm not here to make an inheritance claim."]|
#
# -- 43012 range D3 20-30, mean conf: 1.156670331954956--
# rank 27, conf: 1.1571401357650757
# sent 374128: |["I appreciate your people coming in on this, agent Lisbon. Haven't handled many homicides— none, in fact frankly, I'm looking to learn from you.", 'Not a problem, deputy Fisher.']|
#
# -- 43012 range D4 30-60, mean conf: 1.1307437419891357--
# rank 36, conf: 1.1438239812850952
# sent 953591: |['look Jimmy an I view the lighthouse as a chance ta restore the restaurant to its former glory you know its-its jus somethin from Newport for Newport', 'we think it can be a bit of both, an icon of the past...a beacon for the future']|
#
# ----------SENT 878052 @5---------
# TEXT: |['Can I get you ladies something? I was just about to mix up some Country Time.', "We're looking for Spike, actually."]|
# MEAN CONF TOP100: 1.1264667510986328
#
# -- 878052 range D0 0-1, mean conf: 1.184854507446289--
# rank 2, conf: 1.184854507446289
# sent 884227: |["Can I get you something? I don't have any coffee.", "Oh, no thank you, I, uh... You don't drink? Beverages, I mean?"]|
#
# -- 878052 range D1 1-10, mean conf: 1.18485426902771--
# rank 11, conf: 1.18485426902771
# sent 830907: |['Can I get you something?', "Yeah, sure. Why don't you tell me what happened to your neck, Jo?"]|
#
# -- 878052 range D2 10-20, mean conf: 1.1511976718902588--
# rank 17, conf: 1.1525691747665405
# sent 750399: |['Can I get you something to drink?', 'Uh, iced tea, please.']|
#
# -- 878052 range D3 20-30, mean conf: 1.135115623474121--
# rank 28, conf: 1.1309094429016113
# sent 820330: |['Really? I got something?', "Well, it's addressed to Customer Service so, it's your mail."]|
#
# -- 878052 range D4 30-60, mean conf: 1.1276419162750244--
# rank 58, conf: 1.1258070468902588
# sent 126327: |['Hey, Abby. You got something?', "Well, I've got good news and bad news. This is definitely our bat. The splinter from Sergeant Moore's head fits perfectly."]|
#
# ----------SENT 633043 @6---------
# TEXT: |['Geordi, active scanner output has increased by twenty six percent.', 'Inform Astrophysics that the new La Forge sensor array is online and awaiting major scientific discoveries.']|
# MEAN CONF TOP100: 1.0989466905593872
#
# -- 633043 range D0 0-1, mean conf: 1.220902681350708--
# rank 2, conf: 1.220902681350708
# sent 555719: |['Scanning intensity has increased by fifteen hundred percent.', 'Shields up.']|
#
# -- 633043 range D1 1-10, mean conf: 1.1903775930404663--
# rank 4, conf: 1.2154755592346191
# sent 633747: |['One moment. The phase buffer is functioning within normal parameters. Sensor efficiency has increased by six point seven percent.', "Six point seven? One of the stages must still be out of alignment. Let's try junction A nine."]|
#
# -- 633043 range D2 10-20, mean conf: 1.129779577255249--
# rank 19, conf: 1.1245883703231812
# sent 55868: |['Operation one hundred percent successful, mistress.', "Yes, I know, but I can't find the Doctor. Can you locate him, K9?"]|
#
# -- 633043 range D3 20-30, mean conf: 1.1080180406570435--
# rank 31, conf: 1.1030302047729492
# sent 605325: |['Set phasers to twenty five percent. Return fire.', 'Aye, sir.']|
#
# -- 633043 range D4 30-60, mean conf: 1.0901647806167603--
# rank 37, conf: 1.0965683460235596
# sent 543615: |['Shields to thirty five percent.', 'Reroute all available power to shields. Chakotay, initiate manual targeting.']|
#
# ----------SENT 373427 @7---------
# TEXT: |["She didn't do it.", 'How do you know?']|
# MEAN CONF TOP100: 1.094299554824829
#
# -- 373427 range D0 0-1, mean conf: 1.1529819965362549--
# rank 1, conf: 1.1529819965362549
# sent 135916: |["She didn't do it.", "You think I don't know that? I'm just telling you what they're saying all over the Beltway. I give it twenty-four hours before they ask for my resignation."]|
#
# -- 373427 range D1 1-10, mean conf: 1.1441614627838135--
# rank 6, conf: 1.1475633382797241
# sent 112411: |["He didn't do it.", 'I know.']|
#
# -- 373427 range D2 10-20, mean conf: 1.1346172094345093--
# rank 17, conf: 1.1355514526367188
# sent 641341: |['He did it.', 'Take us in.']|
#
# -- 373427 range D3 20-30, mean conf: 1.10725998878479--
# rank 26, conf: 1.1069656610488892
# sent 33402: |["It's not a cave. It's an attic. Clyde was joking again. He does that. Sort of.", 'Mister Smith, I need you.']|
#
# -- 373427 range D4 30-60, mean conf: 1.098222255706787--
# rank 46, conf: 1.102711796760559
# sent 138189: |["He didn't.", 'Okay. I just thought I heard...']|
#
# ----------SENT 957166 @8---------
# TEXT: |['Bang! Am I good or am I good?', "What do you think you're doing?"]|
# MEAN CONF TOP100: 1.0927451848983765
#
# -- 957166 range D0 0-1, mean conf: 1.2165998220443726--
# rank 2, conf: 1.2165998220443726
# sent 268966: |['Is that community theater, or are you just naturally that good?', 'This is the last time you become anybody. Ever.']|
#
# -- 957166 range D1 1-10, mean conf: 1.1508814096450806--
# rank 3, conf: 1.2077934741973877
# sent 1049234: |["Either I'm that transparent or you're that good.", "Well, I don't think I'll comment since you do have hot liquid over my head."]|
#
# -- 957166 range D2 10-20, mean conf: 1.1235477924346924--
# rank 19, conf: 1.117387056350708
# sent 384634: |["Stop telling me to take your hand! Look, Fry, your noble things keep making things worse. Can't you just be a rude, unhelpful jerk like Bender?", "When I use up the toilet paper I don't put up a new roll!"]|
#
# -- 957166 range D3 20-30, mean conf: 1.1086935997009277--
# rank 26, conf: 1.1086311340332031
# sent 1035082: |['You are not sure if you are a believer, are you?', "Oh, no, I'm a believer. Believe me. That's why I'm here. I didn't know where else to turn."]|
#
# -- 957166 range D4 30-60, mean conf: 1.0884863138198853--
# rank 36, conf: 1.0986567735671997
# sent 1048636: |['Is it just me or are you a little too eager to play this role.', "It's not a bad role to play."]|
#
# ----------SENT 245501 @9---------
# TEXT: |['When are Mom and Dad coming back?', 'Bored, are ya? Lisa, go cut me a switch.']|
# MEAN CONF TOP100: 1.0925670862197876
#
# -- 245501 range D0 0-1, mean conf: 1.2143546342849731--
# rank 2, conf: 1.2143546342849731
# sent 19455: |['Mother, are you coming?', "The answer is, of course, because they are going to be sad later. Now, we'd better get downstairs. I think they may have found the main sitting room."]|
#
# -- 245501 range D1 1-10, mean conf: 1.1750483512878418--
# rank 3, conf: 1.1959433555603027
# sent 339823: |['Incidentally, when are you coming back?', 'Today.']|
#
# -- 245501 range D2 10-20, mean conf: 1.124210000038147--
# rank 15, conf: 1.1281780004501343
# sent 870786: |['What are you gonna tell Marshall, huh? And when are you coming back?', "I honestly haven't thought it all the way through, and I don't intend to. All I know is that I'm a ticking time bomb, and if I don't do something for me right away, I swear I'm gonna explode!"]|
#
# -- 245501 range D3 20-30, mean conf: 1.1060993671417236--
# rank 25, conf: 1.1093930006027222
# sent 823542: |["And secondly, Phyllis how are those mittens coming? Because I would actually like to bring them home and pack them. I'm leaving for the day at four.", "They're almost done but my knuckles are swelling a little and-"]|
#
# -- 245501 range D4 30-60, mean conf: 1.0872876644134521--
# rank 52, conf: 1.0841646194458008
# sent 157221: |["Isn't this amazing? Oh, aren't you so glad you came, Clark? We are gonna have so much fun!", 'Okay, Lois, you got me here. You can stop laying it on.']|
#
# ----------SENT 149928 @10---------
# TEXT: |['And he bought it for eight hundred cash a couple weeks ago. Right. Bye.', "It's always business with you."]|
# MEAN CONF TOP100: 1.0838135480880737
#
# -- 149928 range D0 0-1, mean conf: 1.1826105117797852--
# rank 2, conf: 1.1826105117797852
# sent 623916: |["Captain, there's a spatial distortion heading towards us. Whatever it is, it's huge. Five light years across and it's expanding.", "Tracking it's origin. A vessel near the Zahl homeworld."]|
#
# -- 149928 range D1 1-10, mean conf: 1.1460206508636475--
# rank 4, conf: 1.1583926677703857
# sent 285681: |["Okay. Tucker Payne. He was found guilty of stealing drugs from Dr. Elliot's vet clinic. Sentenced to two years and he was paroled one month ago.", "I'll have the drug thief's parole officer bring him in for questioning. Okay?"]|
#
# -- 149928 range D2 10-20, mean conf: 1.1179161071777344--
# rank 13, conf: 1.1259641647338867
# sent 409813: |['Yeah. So the pattern starts a month ago. Our guy drugs Tara Weathers in a bar, takes her to her apartment, paints her toes, leaves. Two weeks later, he steps it up.', "Poses as a firefighter, places smoke bombs in an apartment building, only things don't work out the way that he planned. The building catches fire, and he runs."]|
#
# -- 149928 range D3 20-30, mean conf: 1.1007614135742188--
# rank 24, conf: 1.102908730506897
# sent 607172: |["I don't know about that. Quark's on a roll. In the last month, he's won two hundred and six straight games.", 'Would you care to make a wager on the outcome?']|
#
# -- 149928 range D4 30-60, mean conf: 1.07724130153656--
# rank 38, conf: 1.0823121070861816
# sent 812930: |['None. We were in the same house from ages ten to twelve. And then from fifteen to eighteen.', 'All right. Formative years.']|
#
# ----------SENT 556622 @11---------
# TEXT: |["You're going to have to destroy it in order to escape.", 'How much longer before we reach them?']|
# MEAN CONF TOP100: 1.0731450319290161
#
# -- 556622 range D0 0-1, mean conf: 1.163155198097229--
# rank 2, conf: 1.163155198097229
# sent 420050: |["Okay, be careful, David. The body's frozen, and it's in full rigor. You're going to have to tilt it.", 'Tilt it, sir?']|
#
# -- 556622 range D1 1-10, mean conf: 1.1394308805465698--
# rank 3, conf: 1.1556018590927124
# sent 326348: |["But I do not want to have everything decided for me. I spent my whole life like that. It's what I had with Barry, that was one of the reasons I left. I, I like not knowing right now and I'm sorry if that scares you but if you want to be with me you are gonna have to deal with that.", 'Ok fine.']|
#
# -- 556622 range D2 10-20, mean conf: 1.1125919818878174--
# rank 15, conf: 1.1183388233184814
# sent 156934: |["There's gonna be millions of eyes on you. You're gonna be under a magnifying glass.", 'I have pulled it off before.']|
#
# -- 556622 range D3 20-30, mean conf: 1.0859477519989014--
# rank 31, conf: 1.0803353786468506
# sent 153638: |["You can't blame yourself. You can't change who you are. As long as you live, people will try to exploit you. You father and I have tried to shelter you as long as possible, but one day we won't be there for you. And you're gonna have to carry the burden of your gifts on your own.", "Don't say that, Mom."]|
#
# -- 556622 range D4 30-60, mean conf: 1.068259596824646--
# rank 39, conf: 1.0754508972167969
# sent 526714: |["I'm gonna be doing a bloodless pulmonary valve translocation on this patient.", 'This machine is an excellent source of revenue for the hospital']|
#
# ----------SENT 288485 @12---------
# TEXT: |["Let's go see the cooked person!", 'Geez, you know our deal.']|
# MEAN CONF TOP100: 1.059644103050232
#
# -- 288485 range D0 0-1, mean conf: 1.137670874595642--
# rank 2, conf: 1.137670874595642
# sent 572728: |["Let's go see!", "You, gentlemen? In your condition? Don't be ridiculous. Mister Spock, this cafe has women that are so. (met with a Look) No, I guess not. Alone?"]|
#
# -- 288485 range D1 1-10, mean conf: 1.0785470008850098--
# rank 9, conf: 1.068269968032837
# sent 350471: |['Yeah! All right? Let’s go!', 'And may-maybe we could end up on a boat again?']|
#
# -- 288485 range D2 10-20, mean conf: 1.0637187957763672--
# rank 16, conf: 1.065537452697754
# sent 367296: |['Let’s go!!', 'Hey! Rachel! Come on!!!!']|
#
# -- 288485 range D3 20-30, mean conf: 1.0589016675949097--
# rank 28, conf: 1.0589016675949097
# sent 792278: |["Let's go!", 'Alright.']|
#
# -- 288485 range D4 30-60, mean conf: 1.0589014291763306--
# rank 46, conf: 1.0589016675949097
# sent 389631: |["I'm bored! Let's go!", "You know, Fry, I've got a little place just outside town. You could come visit, maybe?"]|
#
# ----------SENT 472923 @13---------
# TEXT: |['You want me to work for you?', 'Nope, no, no, you’ll still be your own boss I’ll just be the guy behind the curtain. And once this place returns to profitability, I’ll even let you buy it back.']|
# MEAN CONF TOP100: 1.0335907936096191
#
# -- 472923 range D0 0-1, mean conf: 1.2257921695709229--
# rank 2, conf: 1.2257921695709229
# sent 889749: |['You want me to work with you?', 'For me. You’re going to have to listen more carefully when you’re on the job.']|
#
# -- 472923 range D1 1-10, mean conf: 1.1123172044754028--
# rank 11, conf: 1.0723518133163452
# sent 229209: |['No, no. You want to make American kids work?', "You're supposed to be driving me to a tennis class I said I wanted then I changed my mind and I hate it so much I'm faking stomach aches to get out of it."]|
#
# -- 472923 range D2 10-20, mean conf: 1.0609432458877563--
# rank 17, conf: 1.0612274408340454
# sent 879416: |['You want to lay me out?', "I don't like this. They could have heart attacks."]|
#
# -- 472923 range D3 20-30, mean conf: 1.0434768199920654--
# rank 26, conf: 1.0415732860565186
# sent 1046556: |['You want me to check upstairs?', "Uh, no, no, no, that's okay really."]|
#
# -- 472923 range D4 30-60, mean conf: 1.0254865884780884--
# rank 42, conf: 1.0256932973861694
# sent 452900: |['What did you want to show me?', 'The exit.']|
#
# ----------SENT 584937 @14---------
# TEXT: |["You're leaving me very little choice.", "Shran left six hours ago. You're too late."]|
# MEAN CONF TOP100: 1.031914472579956
#
# -- 584937 range D0 0-1, mean conf: 1.193864345550537--
# rank 2, conf: 1.193864345550537
# sent 649747: |['You leave me little choice.', 'All right, then. One of us needs to go outside.']|
#
# -- 584937 range D1 1-10, mean conf: 1.0837278366088867--
# rank 7, conf: 1.075893759727478
# sent 833816: |["Matt, she threatened Matt and I'm so scared of her Elena! I am so scared of her", 'And you should be. Caroline, we all should be']|
#
# -- 584937 range D2 10-20, mean conf: 1.058182716369629--
# rank 14, conf: 1.0656013488769531
# sent 319183: |['"Aphorisms leave me a little dry."', '"How are you?"']|
#
# -- 584937 range D3 20-30, mean conf: 1.039001703262329--
# rank 28, conf: 1.0348654985427856
# sent 619537: |["You're leaving.", "I need to go someplace I can clear my head. Someplace that isn't here."]|
#
# -- 584937 range D4 30-60, mean conf: 1.0269967317581177--
# rank 59, conf: 1.0226223468780518
# sent 846095: |["I'm not leaving you. Matty!", "Mom! Don't you get it? I'm better off without you"]|
#
# ----------SENT 970705 @15---------
# TEXT: |['Jack and Jen?', 'Mm-hm. Andie and I played matchmaker tonight.']|
# MEAN CONF TOP100: 1.009331226348877
#
# -- 970705 range D0 0-1, mean conf: 1.0285099744796753--
# rank 1, conf: 1.0285099744796753
# sent 512934: |['Finn and Jake?', 'Well, guys. It looks like you caught us.']|
#
# -- 970705 range D1 1-10, mean conf: 1.0285099744796753--
# rank 7, conf: 1.0285099744796753
# sent 1009759: |['Amy and Jeffrey?', 'Yes!']|
#
# -- 970705 range D2 10-20, mean conf: 1.0285099744796753--
# rank 20, conf: 1.0285099744796753
# sent 988400: |['Kate and Leopold?', "Yeah. Hugh Jackman's a hottie."]|
#
# -- 970705 range D3 20-30, mean conf: 1.0285098552703857--
# rank 29, conf: 1.0285098552703857
# sent 277126: |['Ellen and Jo?', "I'm sorry."]|
#
# -- 970705 range D4 30-60, mean conf: 1.0234354734420776--
# rank 46, conf: 1.02524733543396
# sent 1040913: |['Jack McCarter and Kline?', "Haven't heard of them. Well, I better get to work. Congratulations."]|
#
# ----------SENT 505042 @16---------
# TEXT: |['Maleficent happened. And that is her idea of a good time.', 'Regina... Are you okay? What happened last night?']|
# MEAN CONF TOP100: 1.0089865922927856
#
# -- 505042 range D0 0-1, mean conf: 1.1474883556365967--
# rank 2, conf: 1.1474883556365967
# sent 318118: |['"Yeah, well, if it\'s tossing a vampire in with them lawyers, I\'m in. Because that was my idea of a good time."', '"My people, they are in the hospital. St. Matthews. One\'s in ICU, one\'s in the neuro-psychiatric Unit. They need protection while I hunt down the guy who put them there."']|
#
# -- 505042 range D1 1-10, mean conf: 1.0589848756790161--
# rank 7, conf: 1.0573774576187134
# sent 290785: |["It's a waste of my time.", "It's a science show."]|
#
# -- 505042 range D2 10-20, mean conf: 1.030014157295227--
# rank 16, conf: 1.0291434526443481
# sent 741677: |["It's a family secret.", 'Well, last time I checked, I was family.']|
#
# -- 505042 range D3 20-30, mean conf: 1.0181151628494263--
# rank 23, conf: 1.021781086921692
# sent 989930: |['And this is a big deal. Why?', "Because I find it morally wrong and offensive and disgusting. I mean, I didn't come here with you guys to be, you know, an accomplice to your little seedy scam."]|
#
# -- 505042 range D4 30-60, mean conf: 1.0065830945968628--
# rank 48, conf: 1.0048359632492065
# sent 193869: |["Cheer up. So you're not good at sports. It's a very small part of life.", "Sports, sports, sports, sports. Sports, sports, sports, sports. Marge, Bart rides up in the front seat today because he's a good guy at sports."]|
#
# ----------SENT 578338 @17---------
# TEXT: |["You humans obviously have emotions. I find it curious that you'd select a Vulcan as your science officer.", "Believe me, she wasn't my first choice."]|
# MEAN CONF TOP100: 1.003945231437683
#
# -- 578338 range D0 0-1, mean conf: 1.1115915775299072--
# rank 2, conf: 1.1115915775299072
# sent 299872: |['You might as well picked my name from a hat.', "Normally, I'd agree but your disapproval of Dr. Sidman's work makes me wonder if you're a religious fanatic."]|
#
# -- 578338 range D1 1-10, mean conf: 1.061470866203308--
# rank 10, conf: 1.0516225099563599
# sent 146867: |['Yep. I take it you found your Barracuda.', 'Yep. You find anything in the house? Say, plans to blow up the bus?']|
#
# -- 578338 range D2 10-20, mean conf: 1.0337040424346924--
# rank 17, conf: 1.031428575515747
# sent 623381: |['Now that you mention it, Captain, I find this region of space a real navigational challenge.', "I believe I may have found something else to pique Mister Paris's interest, Captain. It's an unidentified ship on long range sensors."]|
#
# -- 578338 range D3 20-30, mean conf: 1.0182632207870483--
# rank 28, conf: 1.0157036781311035
# sent 554499: |['Doctor, you said it would help if you knew the source of this. If I can continue my analysis of the mission records, I might find an answer.', 'Mister La Forge, what if you begin to change? What if you feel compelled to go down to the planet like the others?']|
#
# -- 578338 range D4 30-60, mean conf: 0.999580979347229--
# rank 40, conf: 1.0034420490264893
# sent 27148: |["I am not sure what to make of you, Doctor. I think perhaps it\nwould be safer to accept Ortron's theory and execute you as a spy.", "You can't do that. We're not under your authority."]|
#
# ----------SENT 408486 @18---------
# TEXT: |['Maybe this has nothing to do with the case. Maybe it was just a piece of debris left at the scene.', "No, no. I-I'm not quitting. No. I am in too deep."]|
# MEAN CONF TOP100: 1.0030046701431274
#
# -- 408486 range D0 0-1, mean conf: 1.130220890045166--
# rank 2, conf: 1.130220890045166
# sent 478831: |["I don't know. Maybe it's the birth of a new day.", 'Are you feeling all right?']|
#
# -- 408486 range D1 1-10, mean conf: 1.0609242916107178--
# rank 8, conf: 1.0594168901443481
# sent 37504: |["Maybe it's a Sunday.", 'No, I never land on Sundays. Sundays are boring.']|
#
# -- 408486 range D2 10-20, mean conf: 1.032895803451538--
# rank 17, conf: 1.0318801403045654
# sent 439822: |["Now calm down. Let me just go over to Twilight's castle and see what's what! Maybe it's just a false alarm.", 'But you said it was a false alarm!']|
#
# -- 408486 range D3 20-30, mean conf: 1.0253026485443115--
# rank 29, conf: 1.0241745710372925
# sent 1049768: |['Maybe is was just a nightmare.', "It wasn't a nightmare and it certainly wasn't a joke. There's a demon after me or us, I know it."]|
#
# -- 408486 range D4 30-60, mean conf: 1.0053819417953491--
# rank 48, conf: 1.006723403930664
# sent 743027: |["Mom, this is the place where unwanted things came to repose. Maybe it's a vest of his from the old days.", 'Our days never included Richard dressing up like that gay fellow whose tiger tried to eat him. I have definitely, positively never seen this vest. This is a party vest.']|
#
# ----------SENT 788093 @19---------
# TEXT: |["Attention everyone. Drug testers are coming in a couple of hours to test everyone's urine.", 'Waa... what? What are you talking about?']|
# MEAN CONF TOP100: 0.99741530418396
#
# -- 788093 range D0 0-1, mean conf: 1.085745096206665--
# rank 2, conf: 1.085745096206665
# sent 31968: |["Here's to Luke's last night on Bannerman Road.", 'Cheers.']|
#
# -- 788093 range D1 1-10, mean conf: 1.0717018842697144--
# rank 10, conf: 1.0641801357269287
# sent 630435: |['Conn, are we still on schedule to arrive at Mordan in thirty eight hours?', "Aye, sir. We're at warp four."]|
#
# -- 788093 range D2 10-20, mean conf: 1.0440914630889893--
# rank 15, conf: 1.0479077100753784
# sent 183409: |["They broke through the final firewall. Checkmate's gonna be here any minute.", "As long as they torture us with the A.C. on, I'll die happy."]|
#
# -- 788093 range D3 20-30, mean conf: 1.0225778818130493--
# rank 22, conf: 1.0310343503952026
# sent 1009045: |["They're on a different flight. They're scheduled to land in a half hour, only at Laguardia.", "Laguardia? All right, let's go. C'mon..."]|
#
# -- 788093 range D4 30-60, mean conf: 0.9913036823272705--
# rank 34, conf: 1.0047342777252197
# sent 330222: |['Hey, Cousin Cassie is coming to stay with us for a few days.', 'Cassie?']|
#
# ----------SENT 865307 @20---------
# TEXT: |["No, this is new. This trumps that. Freeways have exits. So do relationships. The first exit, my personal favorite, is six hours in. You meet, you talk, you have s*x, you exit when she's in the shower.", 'So every girl you have s*x with feels the immediate need to shower? Actually, yeah, I get that.']|
# MEAN CONF TOP100: 0.9908120632171631
#
# -- 865307 range D0 0-1, mean conf: 1.1893346309661865--
# rank 2, conf: 1.1893346309661865
# sent 1063498: |['He had no problem when I was with Mack.', "No offense but Hank was a lot younger than. Now he's older and he's starting to define his own sexuality, I think it's pretty unsettling to see his dad and his new male lover."]|
#
# -- 865307 range D1 1-10, mean conf: 1.0865027904510498--
# rank 3, conf: 1.1585822105407715
# sent 666096: |["Agent Vaughn has trouble sleeping when you're in the field.", 'I doubt he told you that.']|
#
# -- 865307 range D2 10-20, mean conf: 1.0398175716400146--
# rank 12, conf: 1.0539638996124268
# sent 1057304: |["Yeah, a lot of good it's done us. He's wandering around aimlessly with no idea who he is, and I'm in a coma.", "Look, you have someone out there who needs you as much as you need him. Now, if you don't have faith in that love, it's not the only thing that'll die."]|
#
# -- 865307 range D3 20-30, mean conf: 1.0098108053207397--
# rank 28, conf: 1.0068044662475586
# sent 719078: |["Okay, Belgium's done, Lisbon's calling me back, Berlin had no idea what I was talking about, and Paris is pissed.", 'At who?']|
#
# -- 865307 range D4 30-60, mean conf: 0.9805133938789368--
# rank 48, conf: 0.9769889712333679
# sent 185598: |["No. It's more like she's everywhere. She's hemorrhaging magic. That means we have less time than we thought. We have got to find her. I have no clue where she is.", 'Please concentrate. Try again.']|
#
# ----------SENT 1072756 @21---------
# TEXT: |["Doc, you're always welcome in my place.", 'Thanks, but no thanks.']|
# MEAN CONF TOP100: 0.9560781717300415
#
# -- 1072756 range D0 0-1, mean conf: 1.109656572341919--
# rank 2, conf: 1.109656572341919
# sent 69123: |["I see you're in your usual sweet affable mood, Brigadier.", "When you've quite finished grinning like a Cheshire cat, Captain Yates!"]|
#
# -- 1072756 range D1 1-10, mean conf: 1.0056450366973877--
# rank 4, conf: 1.0125102996826172
# sent 205291: |['And with the inking and application of this stamp, you are officially married. Next!', "I'm sorry, honey. I wanted so badly to give you a fancy wedding."]|
#
# -- 1072756 range D2 10-20, mean conf: 0.9822444915771484--
# rank 12, conf: 0.9903463125228882
# sent 76407: |['Oh, your health is very precious to me, for the moment. You\nsee, my employers are most interested in you.', 'The Ogrons?']|
#
# -- 1072756 range D3 20-30, mean conf: 0.9678575396537781--
# rank 22, conf: 0.9726740717887878
# sent 884907: |["Kids today. Rush rush rush. Well the point, Angel, is you're a very powerful young man, good for Faith, and there just may be future for you in Sunnydale. I see you're admiring my letter opener.", 'Well, actually, I was thinking of stabbing you through the heart with it.']|
#
# -- 1072756 range D4 30-60, mean conf: 0.9493423104286194--
# rank 52, conf: 0.9453408122062683
# sent 127612: |["You're most welcome, your highness.", 'We have a lot of desks to get to.']|
#
# ----------SENT 452076 @22---------
# TEXT: |['Quinn. You made out in my bed.', 'Hey!']|
# MEAN CONF TOP100: 0.9536902904510498
#
# -- 452076 range D0 0-1, mean conf: 1.133174180984497--
# rank 2, conf: 1.133174180984497
# sent 532405: |['I mean you meet someone in a bar, you have a few drinks, a few laughs. You make out in the car.', 'Roll over to your side.']|
#
# -- 452076 range D1 1-10, mean conf: 1.0355114936828613--
# rank 8, conf: 1.0315494537353516
# sent 783773: |['I caught em making out on the couch.', 'Dude, I caught them making out in the pantry closet in the kitchen.']|
#
# -- 452076 range D2 10-20, mean conf: 0.9954241514205933--
# rank 12, conf: 1.002037763595581
# sent 930696: |['You made a deal with him behind my back.', "If I didn't make this deal, you would've killed him."]|
#
# -- 452076 range D3 20-30, mean conf: 0.9731725454330444--
# rank 25, conf: 0.9751154780387878
# sent 345031: |['I was making a coconut phone with the professor.', 'Richard told Monica he wants to marry her!']|
#
# -- 452076 range D4 30-60, mean conf: 0.9456393122673035--
# rank 46, conf: 0.9437167644500732
# sent 249853: |["We've seen a lot of top-flight comics tonight, but that's over, because it's time to hear from Krusty the Clown. Welcome, Krusty. I grew up watching you. Oh, uh, sorry. I threw up watching you.", 'Sarah Silverman.']|
#
# ----------SENT 54159 @23---------
# TEXT: |['Sarah Jane, you may be interested to know that the Museum of Culture is currently staging an exhibition of totem poles. Among them is what has become known as the Totem of the Lost Tribe.', 'Oh, my dad wants to see that. Said they found in a cave, like it had been hidden.']|
# MEAN CONF TOP100: 0.923808753490448
#
# -- 54159 range D0 0-1, mean conf: 1.2305974960327148--
# rank 1, conf: 1.2305974960327148
# sent 54162: |['Sarah Jane, you may be interested to know that the Museum of Culture is currently staging an exhibition of totem poles. Among them is what has become known as the Totem of the Lost Tribe.', 'Oh, my dad wants to see that. Said they found in a cave, like it had been hidden.']|
#
# -- 54159 range D1 1-10, mean conf: 1.0506634712219238--
# rank 6, conf: 1.017795443534851
# sent 183673: |['Remember, Kara, a true Kryptonian embraces their destiny no matter what.', 'I love you.']|
#
# -- 54159 range D2 10-20, mean conf: 0.9623609781265259--
# rank 12, conf: 0.9759544730186462
# sent 560838: |['Hasturi knew that all the normal routes had been destroyed, so he explored all the abnormal ones.', 'Well, he certainly picked some beauties.']|
#
# -- 54159 range D3 20-30, mean conf: 0.9347063899040222--
# rank 22, conf: 0.9414792656898499
# sent 674923: |['We’ve been tracking Intel which indicates that the Jakarta Faction wants the lense and they’ve employed this man to acquire it for them.', 'His name is Cesar Martinez, he’s an Argentine resident.']|
#
# -- 54159 range D4 30-60, mean conf: 0.9093706011772156--
# rank 41, conf: 0.9128904938697815
# sent 639569: |['And thanks to that Suliban ship, they also think the Alliance has developed invisible aircraft.', "You don't have to leave technology behind to contaminate a culture. (turns to leave) You were willing       to sacrifice your life to protect them. I would not have expected that."]|
#
# ----------SENT 493880 @24---------
# TEXT: |["I'm sorry, Mom. Whatever happened in Camelot, I'm sorry we failed you.", "I know what I said last night, but, Henry, you didn't fail me. Everyone else did."]|
# MEAN CONF TOP100: 0.9166043400764465
#
# -- 493880 range D0 0-1, mean conf: 1.0512454509735107--
# rank 2, conf: 1.0512454509735107
# sent 954594: |["hi I'm Charlotte Morgan, I'm so sorry about interrupting you in group", "oooh no no that's ok"]|
#
# -- 493880 range D1 1-10, mean conf: 0.9936732053756714--
# rank 3, conf: 1.0089043378829956
# sent 657530: |["I'm sorry, Trance.", 'Harper.']|
#
# -- 493880 range D2 10-20, mean conf: 0.9690732955932617--
# rank 15, conf: 0.9746513366699219
# sent 1037082: |["Hey, I feel awful. I'm sorry about what happened.", "It's not your fault."]|
#
# -- 493880 range D3 20-30, mean conf: 0.9421144723892212--
# rank 31, conf: 0.9273697137832642
# sent 420967: |["We're sorry, Twilight.", 'Spike, take down a note. Dear Princess Celestia,']|
#
# -- 493880 range D4 30-60, mean conf: 0.9066733121871948--
# rank 54, conf: 0.8967552185058594
# sent 188888: |["Davina, I'm sorry about what happened to this kid Tim.", "I'm sorry you don't hate Klaus for what he did or want to make him pay."]|
#
# ----------SENT 751740 @25---------
# TEXT: |['Is she back at Yale?', 'Lorelai...']|
# MEAN CONF TOP100: 0.9164484739303589
#
# -- 751740 range D0 0-1, mean conf: 1.11860990524292--
# rank 2, conf: 1.11860990524292
# sent 930218: |['Is he back at the apartment?', 'Um, I guess so. Where else would he go?']|
#
# -- 751740 range D1 1-10, mean conf: 1.008192539215088--
# rank 9, conf: 0.9849874377250671
# sent 929738: |['Good. Is he ready?', "Yeah, he'll be okay."]|
#
# -- 751740 range D2 10-20, mean conf: 0.9647154808044434--
# rank 15, conf: 0.9665735363960266
# sent 485006: |['Whose grave is she standing at?', "You never went back into the school that day, Lucas. At least, the selfish version of yourself never went back. Peyton died that day and Brooke never forgave herself for leaving her behind. So the next time you think that being the best version of yourself doesn't matter, you look into Peyton's eyes. And every time you do, you'll know that is has. And that it does."]|
#
# -- 751740 range D3 20-30, mean conf: 0.9372026324272156--
# rank 22, conf: 0.9483008980751038
# sent 558884: |["Okay, then, all right, let's go see Data. He's still at Cambridge, isn't he?", 'Yes, I think he is.']|
#
# -- 751740 range D4 30-60, mean conf: 0.9090096354484558--
# rank 50, conf: 0.9060270190238953
# sent 475803: |['One of the downsides of having a roommate. Is he back for long?', 'I never know. He actually asked if you and I were gonna move back in together.']|
#
# ----------SENT 91570 @26---------
# TEXT: |["No, don't really fancy it.", "You don't have a choice, Merlin."]|
# MEAN CONF TOP100: 0.9090376496315002
#
# -- 91570 range D0 0-1, mean conf: 0.9638310074806213--
# rank 2, conf: 0.9638310074806213
# sent 1016111: |["No, don't cancel it.", "Huh. Well this is a little awkward, isn't it/"]|
#
# -- 91570 range D1 1-10, mean conf: 0.9341054558753967--
# rank 8, conf: 0.9288715124130249
# sent 1053951: |["Guys, I'm telling you I'm fine, don't sweat it.", "You sure she wasn't a Darklighter?"]|
#
# -- 91570 range D2 10-20, mean conf: 0.9174762964248657--
# rank 12, conf: 0.9231262803077698
# sent 528581: |['It really did.', "Screw this. I'm checking on Denny."]|
#
# -- 91570 range D3 20-30, mean conf: 0.9135587811470032--
# rank 23, conf: 0.9146721959114075
# sent 421443: |['Not really, no.', "Pinkie's tail's a-twitchin'. What else can I do?"]|
#
# -- 91570 range D4 30-60, mean conf: 0.9126341938972473--
# rank 44, conf: 0.9128616452217102
# sent 908275: |['No, not really.', 'Oh, come on, Raj, not even a little bit?']|
#
# ----------SENT 531719 @27---------
# TEXT: |["It's not her husband?", 'No!']|
# MEAN CONF TOP100: 0.9037038683891296
#
# -- 531719 range D0 0-1, mean conf: 1.0349678993225098--
# rank 2, conf: 1.0349678993225098
# sent 292632: |["It's definitely not her ear?", 'How could she bite of her own ear?']|
#
# -- 531719 range D1 1-10, mean conf: 0.9835370182991028--
# rank 4, conf: 0.9961158037185669
# sent 189836: |["Eugene Fisk? Isn't he your assistant?", 'No, my supervisor.']|
#
# -- 531719 range D2 10-20, mean conf: 0.9471492767333984--
# rank 13, conf: 0.9592495560646057
# sent 427327: |["Oh! It's not even my birthday!", 'Oh, sorry. Guess it was nothing.']|
#
# -- 531719 range D3 20-30, mean conf: 0.9166445732116699--
# rank 30, conf: 0.9103832840919495
# sent 299594: |["Your boyfriend's shy, isn't he? Sweet. That'll be 60 bucks.", 'Okay, I got that.']|
#
# -- 531719 range D4 30-60, mean conf: 0.8945931792259216--
# rank 38, conf: 0.9018367528915405
# sent 704759: |["You're telling me I played this insipid game for a half an hour and it's not even Luke's daughter?", "What made you think it was Luke's daughter?"]|
#
# ----------SENT 607345 @28---------
# TEXT: |['On my way.', 'We have been unable to establish two way communication so far, but we have determined that the signal is coming from somewhere in the Rutharian sector.']|
# MEAN CONF TOP100: 0.8938563466072083
#
# -- 607345 range D0 0-1, mean conf: 0.945060133934021--
# rank 1, conf: 0.945060133934021
# sent 537544: |['On my way.', 'Commander, you have the Bridge.']|
#
# -- 607345 range D1 1-10, mean conf: 0.9450600743293762--
# rank 10, conf: 0.9450600743293762
# sent 632847: |['On my way.', 'So, do you want to talk about it?']|
#
# -- 607345 range D2 10-20, mean conf: 0.9450600743293762--
# rank 14, conf: 0.9450600743293762
# sent 60398: |['On my way.', 'Over and out.']|
#
# -- 607345 range D3 20-30, mean conf: 0.9450600743293762--
# rank 25, conf: 0.9450600743293762
# sent 99959: |["Okay, I'm leaving now. On my way.", 'Oh, jeez. What are you doing?']|
#
# -- 607345 range D4 30-60, mean conf: 0.9049158692359924--
# rank 33, conf: 0.9450600147247314
# sent 538896: |['On my way.', 'Commander, if we meet any resistance, abort the mission. I have no intention of disturbing an alien race that would rather be left alone.']|
#
# ----------SENT 893145 @29---------
# TEXT: |['Sheldon, this place is so romantic.', 'Oh, I’m glad you like it. Raj picked it out.']|
# MEAN CONF TOP100: 0.8895098567008972
#
# -- 893145 range D0 0-1, mean conf: 0.9644964337348938--
# rank 2, conf: 0.9644964337348938
# sent 474550: |['Just for the night. This place is depressing, Mouth.', 'Peyton, we can’t.']|
#
# -- 893145 range D1 1-10, mean conf: 0.924759566783905--
# rank 4, conf: 0.9439536333084106
# sent 771681: |['Thank you. So, this is your place.', 'This is it.']|
#
# -- 893145 range D2 10-20, mean conf: 0.8991843461990356--
# rank 16, conf: 0.8988795280456543
# sent 969434: |['Dawson, this is certifiable.', "It's easy. You just move around, shake your ass back and forth."]|
#
# -- 893145 range D3 20-30, mean conf: 0.896367073059082--
# rank 28, conf: 0.8957362174987793
# sent 340696: |['Rachel, this is yours.', 'Aah! Why? What are these for?']|
#
# -- 893145 range D4 30-60, mean conf: 0.8871203064918518--
# rank 46, conf: 0.8862146735191345
# sent 365394: |['Phoebe, no! This is, this is insane.', 'Oh, just ask him!']|
#
# ----------SENT 585182 @30---------
# TEXT: |['A most interesting conclusion. But what if they will never learn, Riker?', 'Is this a test also?']|
# MEAN CONF TOP100: 0.8871483206748962
#
# -- 585182 range D0 0-1, mean conf: 0.9394989609718323--
# rank 2, conf: 0.9394989609718323
# sent 6870: |['Well, what else would you suggest?', 'Duggan! Your job is to stop his men from stealing the Mona Lisa. The other Mona Lisa.']|
#
# -- 585182 range D1 1-10, mean conf: 0.9272038340568542--
# rank 9, conf: 0.9205126762390137
# sent 140925: |["Don't worry. I won't have to. Everyone will know soon enough, and you know what? It couldn't have happened to a more deserving person.", "I guess she's assuming I'm going to have a baby."]|
#
# -- 585182 range D2 10-20, mean conf: 0.908303439617157--
# rank 18, conf: 0.9041557312011719
# sent 440750: |['What if they become too ambitious?!', "I never would've thought to combine Star Swirl's apparition spell with Spacium Flexibus! But what would happen if we added Somnambula's Tempus Objectus?"]|
#
# -- 585182 range D3 20-30, mean conf: 0.8972637057304382--
# rank 28, conf: 0.8966743350028992
# sent 21604: |['Yes, but will they sell them to us?', "You don't know the English soldier. He'd sell his grandmother for tuppence ha'penny."]|
#
# -- 585182 range D4 30-60, mean conf: 0.884303867816925--
# rank 43, conf: 0.8845900297164917
# sent 377531: |['Well, if you recall—', "Guys. I mean, boss. I think I found the link you're talking about. The old footage from the store's security cameras is saved on a hard drive off-site. I figured if Murphy had been casing the store, I could find him on the old footage."]|
#
# ----------SENT 869878 @31---------
# TEXT: |['I think we can change them.', 'Come here, you two.']|
# MEAN CONF TOP100: 0.8861829042434692
#
# -- 869878 range D0 0-1, mean conf: 1.021695852279663--
# rank 2, conf: 1.021695852279663
# sent 541939: |["I'm getting pretty good with the Borg language. I think I can translate them.", 'Get on it.']|
#
# -- 869878 range D1 1-10, mean conf: 0.948515772819519--
# rank 8, conf: 0.9438028931617737
# sent 65027: |['I don�t think we should disturb them.', 'Well, they can always tell me to go away.']|
#
# -- 869878 range D2 10-20, mean conf: 0.9129191637039185--
# rank 19, conf: 0.9107379913330078
# sent 818694: |['I think we could.', "I don't see how we could possibly sell these for that little without losing money. Delivery alone will cost..."]|
#
# -- 869878 range D3 20-30, mean conf: 0.9016151428222656--
# rank 24, conf: 0.9063600897789001
# sent 779874: |['I think we lost them.', 'Are you sure?']|
#
# -- 869878 range D4 30-60, mean conf: 0.8845611810684204--
# rank 57, conf: 0.8792533874511719
# sent 598664: |["Vidiian? I thought we'd moved beyond their space.", "If they shot us down you can be sure they'll be coming for us. We need to find a hiding place."]|
#
# ----------SENT 789149 @32---------
# TEXT: |["I don't know who these new people think they are. I've sat downwind of Phyllis' stinky perfumes for years. Never said a word.", "People hate people that are different from them. That's natural. But you know what makes people forget their differences? A great show. That is why I created the 'Integration Celebration'. This is the moment when Scranton and Stamford come together as one. United in applause."]|
# MEAN CONF TOP100: 0.8431043028831482
#
# -- 789149 range D0 0-1, mean conf: 0.9845429062843323--
# rank 2, conf: 0.9845429062843323
# sent 39871: |['I never said a word.', "Telepathy. You know, telepathy isn't only a prerequisite of the\nSensorites. I know sometimes what you're thinking."]|
#
# -- 789149 range D1 1-10, mean conf: 0.9178740382194519--
# rank 4, conf: 0.9528743028640747
# sent 191851: |['Actually, Homer, you brought up Ned Flanders. I never said a word --', "Look, we're past that. Marge, maybe I do curse a little, but that's the way God made me. And I'm too old to stop now."]|
#
# -- 789149 range D2 10-20, mean conf: 0.8658561706542969--
# rank 17, conf: 0.8640580177307129
# sent 1040463: |["I've never said that.", "Hmm, you don't have to. It's obvious the way you treat me. You don't even like me."]|
#
# -- 789149 range D3 20-30, mean conf: 0.8512305021286011--
# rank 30, conf: 0.8462011814117432
# sent 43301: |["Avery's boys are no friends of mine. Never said that.", 'Avery?']|
#
# -- 789149 range D4 30-60, mean conf: 0.8376169204711914--
# rank 56, conf: 0.8320529460906982
# sent 528355: |['You said the Q-word.', "It's like saying Macbeth in theater."]|
#
# ----------SENT 723047 @33---------
# TEXT: |['Wow. A room full of guys and still extremely slim pickings.', "Well, I don't know. It's a tough choice, maybe I should let my boyfriend help me choose."]|
# MEAN CONF TOP100: 0.8205380439758301
#
# -- 723047 range D0 0-1, mean conf: 0.8965331315994263--
# rank 2, conf: 0.8965331315994263
# sent 1026439: |['At the side of the road, with a pile of garbage.', 'Quality time.']|
#
# -- 723047 range D1 1-10, mean conf: 0.8635643720626831--
# rank 4, conf: 0.8830004334449768
# sent 106091: |['Well, I limited it to Naval personnel who served between Ninety and Ninety four. Still a lot of ridges and curves.', 'I might be able to lower the threshold.']|
#
# -- 723047 range D2 10-20, mean conf: 0.8383399248123169--
# rank 14, conf: 0.8394995927810669
# sent 658122: |['All right, and for those of you staying behind, I want you on high alert.', "We've made ourselves a potential target since we've let the Triumvirs know where we were."]|
#
# -- 723047 range D3 20-30, mean conf: 0.8289416432380676--
# rank 29, conf: 0.8275220990180969
# sent 580223: |["My treatment was effective, at least partially. His immune system is stabilising but his pituitary gland was severely damaged. It's all but disintegrated. Bring me the small grey cage on the second shelf. The one with the blue top.", "What's in here?"]|
#
# -- 723047 range D4 30-60, mean conf: 0.8189534544944763--
# rank 49, conf: 0.8173642158508301
# sent 735968: |['The guys, with the tire irons.', 'I think you should just show it to her and get it over with.']|
#
# ----------SENT 623255 @34---------
# TEXT: |["The evening's young, Lieutenant. Let's mingle.", 'Vulcans do not. Curious.']|
# MEAN CONF TOP100: 0.7944638133049011
#
# -- 623255 range D0 0-1, mean conf: 0.8168677091598511--
# rank 2, conf: 0.8168677091598511
# sent 100733: |["How strong? All right, boys. Let's rumble.", "It's still here!"]|
#
# -- 623255 range D1 1-10, mean conf: 0.8168156147003174--
# rank 10, conf: 0.8167891502380371
# sent 511157: |["She's flippin' crazy! Come on, Finn. Let's bail.", 'Chill out.']|
#
# -- 623255 range D2 10-20, mean conf: 0.8166018724441528--
# rank 17, conf: 0.816507875919342
# sent 512530: |["[Jake jumps into Finn's hand.] Let's roll.", 'Woah!']|
#
# -- 623255 range D3 20-30, mean conf: 0.8165078163146973--
# rank 25, conf: 0.8165078163146973
# sent 253330: |["Let's roll.", 'This just in, a fist fight is in progress in downtown Springfield. Early reports indicate -- and these are very preliminary -- that one of the fighters is a giant lizard.']|
#
# -- 623255 range D4 30-60, mean conf: 0.8057010173797607--
# rank 60, conf: 0.7793434262275696
# sent 692955: |["Let's buy flowers.", 'Yeah, lots and lots of flowers.']|
#
# ----------SENT 80500 @35---------
# TEXT: |['The information can be extracted by means of your suffering.', "Are you trying to scare me? Well, cos I'm already bloody terrified of dying. And I'll endure a lot of pain for a very long time before I give up the information that's keeping me alive. How long have you got?"]|
# MEAN CONF TOP100: 0.7764966487884521
#
# -- 80500 range D0 0-1, mean conf: 0.9667243361473083--
# rank 2, conf: 0.9667243361473083
# sent 80550: |['The information can be extracted by means of your suffering.', "Are you trying to scare me? Well, cos I'm already bloody terrified of dying. And I'll endure a lot of pain for a very long time before I give up the information that's keeping me alive. How long have you got?"]|
#
# -- 80500 range D1 1-10, mean conf: 0.8262779712677002--
# rank 3, conf: 0.8810265064239502
# sent 615172: |['My shield designs could be successfully applied to a vessel of this size.', 'Big of you to admit it, Tuvok.']|
#
# -- 80500 range D2 10-20, mean conf: 0.7951759696006775--
# rank 21, conf: 0.790381908416748
# sent 32256: |['The laws of hyper-dimensional physics cannot be changed.', "Then use them, Mister Dread. The transmat equipment. That's how you put all the ships in there, isn't it?"]|
#
# -- 80500 range D3 20-30, mean conf: 0.7892350554466248--
# rank 30, conf: 0.787705659866333
# sent 96384: |['My lady. If Arthur is to die we will lose more than that. The kingdom will lose its King.', 'While Arthur lives, there is still a King of Camelot.']|
#
# -- 80500 range D4 30-60, mean conf: 0.7722657322883606--
# rank 50, conf: 0.7704360485076904
# sent 651671: |["This fellow made these notes in the last weeks after the disaster began. I disregard these last entries. He said himself he was too sick, too far gone to be sure he wasn't already mad, and I agree, but based on the entries he made before that, I know how much time we have. The ship's computers will verify my figures.", 'Only a matter of time before we all go mad, destroy each other, till the last of us finally destroys himself.']|
#
# ----------SENT 746926 @36---------
# TEXT: |['Yeah, first row. Right in front of the kid with the humongous. . .uh, the really cute kid.', "Darn, I wanted to get a picture of her walking in. I'll get some of her in her seat."]|
# MEAN CONF TOP100: 0.7755348086357117
#
# -- 746926 range D0 0-1, mean conf: 0.8574385046958923--
# rank 2, conf: 0.8574385046958923
# sent 1052579: |['A really, really bad guy.', "Which means he's probably resurfacing if the bounty hunters are after Tyler."]|
#
# -- 746926 range D1 1-10, mean conf: 0.8148026466369629--
# rank 6, conf: 0.8134652376174927
# sent 195374: |['Ho ho ho. Very funny, wise guy.', "Aw, that's it. You just can't insult this guy. You call him a moron and he just sits there, grinning moronly."]|
#
# -- 746926 range D2 10-20, mean conf: 0.788896381855011--
# rank 13, conf: 0.7925266623497009
# sent 936387: |['Your breakup was missing a key ingredient. The only ingredient, really.', 'Which is?']|
#
# -- 746926 range D3 20-30, mean conf: 0.7822030782699585--
# rank 22, conf: 0.7842380404472351
# sent 151538: |['Yeah, the sink guy.', 'I left a tool here when I was fixing your drain.']|
#
# -- 746926 range D4 30-60, mean conf: 0.7734521627426147--
# rank 46, conf: 0.7745153307914734
# sent 100197: |['The pregnant girl, Jessica.', "Yeah. Since Matt had to kill her himself, somebody from the hospital could've seen him."]|
#
# ----------SENT 307923 @37---------
# TEXT: |['How did it taste?', "Eh, it's way worse coming up. I can tell you that."]|
# MEAN CONF TOP100: 0.7561787962913513
#
# -- 307923 range D0 0-1, mean conf: 0.851893961429596--
# rank 2, conf: 0.851893961429596
# sent 542216: |['Stupido! Foolish Florentines! A bird is a mechanical instrument that  \t\tworks according to mathematical laws. An instrument that surely I can recreate.  \t\tHow did it fail?', 'Maybe you underestimated the wingspan?']|
#
# -- 307923 range D1 1-10, mean conf: 0.8012741804122925--
# rank 9, conf: 0.7843745946884155
# sent 906240: |['How does that involve air travel?', 'We’re going to Disney World and ride the Matterhorn?']|
#
# -- 307923 range D2 10-20, mean conf: 0.7724084258079529--
# rank 21, conf: 0.7657557725906372
# sent 678752: |["He's not the one I hate. How horrible does that sound?", "Well I'm mad at her, and I don't even think he's that cute."]|
#
# -- 307923 range D3 20-30, mean conf: 0.7615967392921448--
# rank 22, conf: 0.7649092674255371
# sent 899818: |['In a world ruled by a giant beaver, mankind builds many dams to please the beaver overlord. The low-lying city of Copenhagen is flooded. Thousands die. Devastated, the Danes never invent their namesake pastry. How does one miss that?', 'This is ridiculous. You’re just making stuff up.']|
#
# -- 307923 range D4 30-60, mean conf: 0.7533556222915649--
# rank 46, conf: 0.7540044188499451
# sent 833829: |['Did it hurt?', "It's okay. A little bit every day to make you stronger, right?"]|
#
# ----------SENT 518662 @38---------
# TEXT: |["It's running backwards. There's serious witchery afoot here.", "Come on, Princess. We don't got all night."]|
# MEAN CONF TOP100: 0.7278713583946228
#
# -- 518662 range D0 0-1, mean conf: 0.7990556955337524--
# rank 2, conf: 0.7990556955337524
# sent 757422: |["Sorry, Paris. There's noise here.", "So, I'm returning your call."]|
#
# -- 518662 range D1 1-10, mean conf: 0.7854025363922119--
# rank 11, conf: 0.7710914015769958
# sent 535898: |["Addison, I'm sorry. I did all the tests. There's no fertility potential here.", 'Okay. Uh... this is good. This is, um... oh, this is just... perfect.']|
#
# -- 518662 range D2 10-20, mean conf: 0.7521685361862183--
# rank 14, conf: 0.7597554922103882
# sent 658555: |['There is in here.', "Maybe. For one of us. Promise you'll remember what I said?"]|
#
# -- 518662 range D3 20-30, mean conf: 0.7339431047439575--
# rank 26, conf: 0.7331454157829285
# sent 263947: |["There's a greater purpose here.", "You know what, I-I'm getting a little sick and tired of the greater purposes, okay? I think what I'd like to do now is save a couple of kids. If you don't mind. We'll catch up. Okay guys, let's go. C'mon."]|
#
# -- 518662 range D4 30-60, mean conf: 0.7210218906402588--
# rank 35, conf: 0.7255706787109375
# sent 260671: |["It's the lives of one thousand against the lives of six billion. There's a bigger picture here.", "Right, cause you're bigger picture kind of guys."]|
#
# ----------SENT 964068 @39---------
# TEXT: |['What? No en suite commode?', 'Excuse me?']|
# MEAN CONF TOP100: 0.6914783120155334
#
# -- 964068 range D0 0-1, mean conf: 0.7462180256843567--
# rank 2, conf: 0.7462180256843567
# sent 657211: |['No! Trance?', "Beka, it's all right. I'll be"]|
#
# -- 964068 range D1 1-10, mean conf: 0.7313203811645508--
# rank 10, conf: 0.7209598422050476
# sent 768343: |["Oh, no? I'm sorry.", 'Trains are dirty.']|
#
# -- 964068 range D2 10-20, mean conf: 0.7110614776611328--
# rank 14, conf: 0.7198502421379089
# sent 1019549: |['Oh, no?', 'Yeah. In fact, he....']|
#
# -- 964068 range D3 20-30, mean conf: 0.6997290849685669--
# rank 22, conf: 0.702888548374176
# sent 823221: |['NO!!!', 'I need you to put the Christmas tree back up.']|
#
# -- 964068 range D4 30-60, mean conf: 0.6835483312606812--
# rank 34, conf: 0.6869040131568909
# sent 179012: |['No, Dad ...', "Son, you were just telling me how you want to have a normal senior year, right? Well, how does traipsing around the globe on Jor-El's crusade fit in with that?"]|

# %% [markdown]
# ## Utility: Bench same sentences against different models
#
# Same sentence is benched against all models to determine what the model cares about.
#
# The sentences is normally choosed as a hard/simple sentence to capture.

# %%
class Bench:
    MODELS = {
        'v1': [my_model, SENT_MAP, INV_SENT_MAP],
        'v2': [model_v2, SENT_MAP_v2, INV_SENT_MAP_v2],
        'v3': [model_v3, SENT_MAP_v3, INV_SENT_MAP_v3],
        'v4': [model_v4, SENT_MAP_v4, INV_SENT_MAP_v4],
        'v5': [model_v5, SENT_MAP_v5, INV_SENT_MAP_v5],
        'v6': [model_v6, SENT_MAP_v6, INV_SENT_MAP_v6],
        'v7': [model_v7, SENT_MAP_v7, INV_SENT_MAP_v7],
        'v8': [model_v8, SENT_MAP_v8, INV_SENT_MAP_v8],
        'v9': [model_v9, SENT_MAP_v9, INV_SENT_MAP_v9],
        'v10': [model_v10, SENT_MAP_v10, INV_SENT_MAP_v10],
    }

    def __init__(self, dialog_df, models=None):
        self.dialog_df = dialog_df
        self.top_n = 100
        if models is None:
            self.models = self.MODELS.keys()
        else:
            self.models = models

    def _retrive_dialog(self, sid):
        return [self.dialog_df.loc[sid].dia1, self.dialog_df.loc[sid].dia2]
    
    def _query_sent(self, sent_cat, model):
        """Query most simular sentences to the sentence category by learned matrix multiplication model.

        Params:
            sent_cat: sent cateogry id.
            model: learned implicit MM model.
            top: limites to n top rank of each sentence (more than the rank will be ignored).
            bounds: list of sentence id, boudary of candidates to be considered (other sentences will be ignored).

        Return:
            Array consists of three elements:
                numpy array of sentence ids in acending ranking order (or conf order, the same).
                numpy array of ranks (to sent ids).
                numpy array of confidence value (to sent ids).
        """
        _sims = model.similar_users(sent_cat, N=self.top_n)
        _rank = 0
        ranks = []
        confs = []
        sents = []
        for sid, conf in _sims:
            _rank += 1
            if sid == sent_cat:  # itself
                continue
            ranks.append(_rank)
            confs.append(conf)
            sents.append(sid)
        return [np.array(sents), np.array(ranks), np.array(confs)]

    def run(self, sent_id):
#         print('TARGET: {}'.format(self._retrive_dialog(sent_id)))
#         for k, m in self.MODELS.items():
        for k in self.models:
            m = self.MODELS[k]
#             if k not in self.models:
#                 continue
            print()
            print('---------MODEL {}---------'.format(k))
            print('TARGET: {}'.format(self._retrive_dialog(sent_id)))
            sent_cat = m[2][sent_id]
            sents, ranks, confs = self._query_sent(sent_cat, m[0])
            print('MEAN CONF: {}'.format(confs.mean()))
            for i, sid in enumerate(sents[:10]):
                print()
                print('id: {}, conf: {}, rank {}'.format(m[1][sid], confs[i], ranks[i]))
                print(self._retrive_dialog(m[1][sid]))

    def sample_run(self):
        random.seed(1231312312)
        for sid in random.sample(INV_SENT_MAP.keys(), 10):
            print('++++++++++++{}++++++++++\n'.format(sid))
            self.run(sid)

# %%
bench = Bench(dialogs, models=['v1', 'v9', 'v10'])
bench.run(556622)#456590)#89799)
# bench.sample_run()
# Out:
# ---------MODEL v1---------
# TARGET: ["You're going to have to destroy it in order to escape.", 'How much longer before we reach them?']
# MEAN CONF: 1.005842924118042
#
# id: 317604, conf: 1.103016972541809, rank 2
# ['“You must be going through a canyon.”', '“Cordelia, can you hear me?”']
#
# id: 415933, conf: 1.0803239345550537, rank 3
# ["The shooting review board wants to talk to you. You're going to have to explain your tactical decision for shooting in the direction of a fellow officer.", "I'm ready when they are."]
#
# id: 237701, conf: 1.0758733749389648, rank 4
# ["Seems almost a shame I'm gonna have to bang you against a wall till you die.", "No! Let's take the eagle to Shelbyville Animal Rescue. Where you took that injured hummingbird you found on the front lawn."]
#
# id: 156934, conf: 1.0756711959838867, rank 5
# ["There's gonna be millions of eyes on you. You're gonna be under a magnifying glass.", 'I have pulled it off before.']
#
# id: 228662, conf: 1.074569821357727, rank 6
# ['I wrote a whole song for you, Bart Simpson! Least you could do is pay me full mind. I was gonna enter it in a competition.', 'Ay carumba!']
#
# id: 420050, conf: 1.0702948570251465, rank 7
# ["Okay, be careful, David. The body's frozen, and it's in full rigor. You're going to have to tilt it.", 'Tilt it, sir?']
#
# id: 683683, conf: 1.0635428428649902, rank 8
# ["Just let me get it sized and I promise you'll never have to take it off again. In fact, I'm going to insist on it.", 'No, just in a minute, okay?']
#
# id: 569106, conf: 1.0470718145370483, rank 9
# ["Captain's log, stardate 2715.1. Exchanged cargo with penal colony on Tantalus V. I've departed without going ashore.", 'I would like to have met Doctor Adams. Have you ever been to a penal colony since they started following his theories?']
#
# id: 38354, conf: 1.046904444694519, rank 10
# ["But we're only presuming infection. If we can find out how this thing got through. When it got through. Yuri, continue with Action One. I'm going to inspect the ice field.", 'Right. I should leave. Finally, I should leave. Yuri, me old mate, no point in me seeing the ice field. No point at all. No. Adelaide!']
#
# id: 630639, conf: 1.0449588298797607, rank 11
# ["I'm going to have to do a complete internal scan.", "Keep me posted, Doctor, I'll be on the Bridge."]
#
# ---------MODEL v9---------
# TARGET: ["You're going to have to destroy it in order to escape.", 'How much longer before we reach them?']
# MEAN CONF: 0.8895150423049927
#
# id: 586625, conf: 1.0538893938064575, rank 2
# ["Captain, both primary and reserve power has been drained from the shuttle. I am going to have to connect to the Enterprise in order to activate the shuttle's systems.", 'Geordi']
#
# id: 1035037, conf: 1.0261237621307373, rank 3
# ["Believe me, I'm tempted but, um, I've decided I'm not gonna use my powers no matter what.", 'Since when?']
#
# id: 631399, conf: 1.0182571411132812, rank 4
# ["If you can't stabilise the life support, we're going to have to evacuate the ship.", "I think we can do it. I'll have to get to Engineering though. La Forge to damage control team alpha. Meet me on Engineering level three."]
#
# id: 597951, conf: 1.0137691497802734, rank 5
# ["If we're going to reduce our power demands even further, we're going to have to drop the shields.", "I don't want to leave the ship defenceless this close to a hostile planet."]
#
# id: 678573, conf: 1.0109443664550781, rank 6
# ["I'm in Poland! I've tracked the prototype to a freightyard here, I'm going to destroy it!", "I got him, he's two miles away and traveling alone."]
#
# id: 949374, conf: 0.9463491439819336, rank 7
# ["Aw, crap! Forgot my toothbrush. I'm going to have to use my finger.", "See? He's a child."]
#
# id: 820540, conf: 0.9453949332237244, rank 8
# ['I am sorry that was so awkward for you two in that meeting. But I am going to have to reassemble the youth task force.', "Oh, no, I really don't think that's a good idea."]
#
# id: 69901, conf: 0.9425633549690247, rank 9
# ["No, no. No, this time I'm going to try something different. I'm\ngoing to build a portable device to detect that power source.", "Well, why didn't you do that in the first place?"]
#
# id: 549896, conf: 0.9411608576774597, rank 10
# ["If you can't interfere, then you are going to allow the Ornarans to have the felicium?", 'Yes, I am.']
#
# id: 602855, conf: 0.9321137070655823, rank 11
# ['Aye, sir. Going to impulse power, now.', 'Sensors beginning to pick up small objects, sir.']
#
# ---------MODEL v10---------
# TARGET: ["You're going to have to destroy it in order to escape.", 'How much longer before we reach them?']
# MEAN CONF: 1.0731450319290161
#
# id: 420050, conf: 1.163155198097229, rank 2
# ["Okay, be careful, David. The body's frozen, and it's in full rigor. You're going to have to tilt it.", 'Tilt it, sir?']
#
# id: 326348, conf: 1.1556018590927124, rank 3
# ["But I do not want to have everything decided for me. I spent my whole life like that. It's what I had with Barry, that was one of the reasons I left. I, I like not knowing right now and I'm sorry if that scares you but if you want to be with me you are gonna have to deal with that.", 'Ok fine.']
#
# id: 839237, conf: 1.1550670862197876, rank 4
# ["He's getting closer. I'm going to have to deal with that", 'No, no, no. Let me handle it']
#
# id: 415933, conf: 1.1493974924087524, rank 5
# ["The shooting review board wants to talk to you. You're going to have to explain your tactical decision for shooting in the direction of a fellow officer.", "I'm ready when they are."]
#
# id: 228662, conf: 1.1435308456420898, rank 6
# ['I wrote a whole song for you, Bart Simpson! Least you could do is pay me full mind. I was gonna enter it in a competition.', 'Ay carumba!']
#
# id: 630639, conf: 1.1332224607467651, rank 7
# ["I'm going to have to do a complete internal scan.", "Keep me posted, Doctor, I'll be on the Bridge."]
#
# id: 550063, conf: 1.1330090761184692, rank 8
# ["And in order to do that we're going to have to go down there.", 'What about the defence system Mrs. Manheim spoke of?']
#
# id: 683683, conf: 1.1289863586425781, rank 9
# ["Just let me get it sized and I promise you'll never have to take it off again. In fact, I'm going to insist on it.", 'No, just in a minute, okay?']
#
# id: 77593, conf: 1.1286797523498535, rank 10
# ['And I was going to paddle in it.', "It's all right, Susan. It's all right. Look, you've got some more shoes back at the ship, haven't you? Well, go and put them on. We'll wait here for you."]
#
# id: 357624, conf: 1.1273831129074097, rank 11
# ['You’re gonna have to pee on it.', 'What?!! Gross!!']
